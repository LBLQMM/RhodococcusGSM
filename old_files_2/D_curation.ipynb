# %% [markdown]
# # Genome scale model curation
# #### This notebook is currently not being used
#
#
# This notebook assigns formulas to metabolites that have more than one formula in such a way that all reactions are balanced.
#
# ### Methods
# <ol>
# <li>Assign the first formula to a metabolite if its equivalent metabolite formulas</li>
# <li>Assign metabolite formulas by checking if one formula makes all reactions the where its the only undefined metabolite balanced</li>
# <li>Repeat but allow for some reactions to be unbalanced with respect to hydrogen</li>
# <li>Assign remaining metabolites by checking if combinations of formulas are balanaced or only off by hydrogen</li>
# <li>Balance reactions that are only unbalanced by hydrogen by adding H+ to the deficient side</li>
# <li>Manual curation (only a single metabolite needs to be set </li>
# </ol>

# %%
import cobra
from IPython.display import IFrame
from itertools import product

# %% [markdown]
# # Getting and preparing the genome-scale model

# %% [markdown]
# ## Load *R.opacus* NCBI model generated by CarveMe

# %%
model = cobra.io.read_sbml_model("../models/Ropacus_annotated_curated.xml")
model
# Out:
# <Model ropacus_annotated_curated at 0x7f34791aad90>

# %%
# remove charge from the model
for m in model.metabolites:
    m.charge = 0

# %%
model.id = 'ropacus_annotated_curated'
model.name = 'Rhodococcus opacus PD630 annotated and curated'
model.description = 'Rhodococcus opacus PD630 annotated curated'

cobra.io.write_sbml_model(model, "../models/Ropacus_annotated_curated_no_charge_balanced_H.xml")

# %% [markdown]
# ## Starting MEMOTE Output

# %%
# IFrame('../data/memotes/ropacus_annotated.html', 1500, 800)

# %% [markdown]
# Define functions to print status report

# %%
def should_be_balanced(r):
    return not (r.id.startswith('EX_') or r.id.startswith('sink_') or r.id.startswith('Growth'))

def has_metabolite_with_multiple_formulas(r):
    return len([m for m in r.metabolites if len(m.formula.split(';')) > 1]) > 0
    
def status_report():
    for i in range(1,5):
        num_formulas = [m for m in model.metabolites if len(m.formula.split(';')) == i]
        print(f'{len(num_formulas)} of {len(model.metabolites)} metabolites have {i} formula(s)')
    print('\n')
    
    unbalanced = [r for r in model.reactions if should_be_balanced(r) and r.check_mass_balance() != {}]
    unbalanced_but_okay = [r for r in model.reactions if not should_be_balanced(r) and r.check_mass_balance() != {}]
    balanced = [r for r in model.reactions if r.check_mass_balance() == {}]
    
    unbalanced_multiple_formulas = [r for r in unbalanced if has_metabolite_with_multiple_formulas(r)]
    unbalanced_but_okay_multiple_formulas = [r for r in unbalanced_but_okay if has_metabolite_with_multiple_formulas(r)]
    balanced_multiple_formulas   = [r for r in   balanced if has_metabolite_with_multiple_formulas(r)]
    
    print(f'{len(unbalanced)} of the {len(model.reactions)} reactions in the model are wrongly unbalanced')
    print(f'{len(unbalanced_but_okay)} of the {len(model.reactions)} reactions in the model are properly unbalanced')
    print(f'{len(balanced)} of the {len(model.reactions)} reactions in the model are balanced')
    print('\n')
    
    print(f'{len(unbalanced_multiple_formulas)} of the {len(unbalanced)} improperly unbalanced reactions in the model have at least one metabolite with multiple formulas')
    print(f'{len(unbalanced_but_okay_multiple_formulas)} of the {len(unbalanced_but_okay)} properly unbalanced reactions in the model have at least one metabolite with multiple formulas')
    print(f'{len(balanced_multiple_formulas)} of the {len(balanced)} balanced reactions in the model have at least one metabolite with multiple formulas')

# %%
status_report()
# Out:
# 1956 of 1956 metabolites have 1 formula(s)
# 0 of 1956 metabolites have 2 formula(s)
# 0 of 1956 metabolites have 3 formula(s)
# 0 of 1956 metabolites have 4 formula(s)
#
#
# 613 of the 3025 reactions in the model are wrongly unbalanced
# 339 of the 3025 reactions in the model are properly unbalanced
# 2073 of the 3025 reactions in the model are balanced
#
#
# 0 of the 613 improperly unbalanced reactions in the model have at least one metabolite with multiple formulas
# 0 of the 339 properly unbalanced reactions in the model have at least one metabolite with multiple formulas
# 0 of the 2073 balanced reactions in the model have at least one metabolite with multiple formulas

# %%
def balanced_or_only_hydrogen_unbalanced(r):
    return should_be_balanced(r) and list(r.check_mass_balance().keys()) == ['H']

def fix_unbalanced_hydrogen(r):
    hydrogen_error = int(r.check_mass_balance()['H'])
    r.subtract_metabolites({model.metabolites.get_by_id("h_c"): hydrogen_error})

# %%
unbalanced_rxns = [r for r in model.reactions if should_be_balanced(r) and r.check_mass_balance() != {}]

for r in unbalanced_rxns:
    if balanced_or_only_hydrogen_unbalanced(r):
        fix_unbalanced_hydrogen(r)

# %%
unbalanced_rxns = [r for r in model.reactions if should_be_balanced(r) and r.check_mass_balance() != {}]

for r in unbalanced_rxns:
    mass_error = r.check_mass_balance()
    metabolites = [m.id for m in r.metabolites]
    print(r.id, mass_error)
# Out:
# AGPATr_BS {'C': -7.105427357601002e-15, 'H': -1.4210854715202004e-14, 'O': -3.552713678800501e-15, 'N': -8.881784197001252e-16}
# G3POA_BS {'C': -7.105427357601002e-15, 'N': -8.881784197001252e-16, 'O': -3.552713678800501e-15}

# %% [markdown]
# These have extremely small errors, and will be ignored. I'm not sure how to fix them

# %% [markdown]
# ## Fix equivalent metabolite formulas
# Define functions for this section

# %%
# def get_initial_number_string(substring):
#     initial_string = ''
#     for char in substring:
#         if char.isdigit():
#             initial_string += char
#         else:
#             return initial_string
#     return initial_string

# def formula_dict_from_string(formula_string):
#     formula_dict = {}
#     elements = [char for char in formula_string if char.isalpha()]
#     for element in elements:
#         string_after_element = formula_string.split(element, 1)[1]
#         coefficient = get_initial_number_string(string_after_element)
#         if coefficient == '':
#             coefficient = '1'
#         formula_dict[element] = int(coefficient)
#     return formula_dict

# def all_formulas_equivalent(m):
#     first_formula = m.formula.split(';')[0]
#     return len([f for f in m.formula.split(';') if formula_dict_from_string(f) != formula_dict_from_string(first_formula)]) > 0

# %%
# equivalent_formulas = 0
# for m in [m for m in model.metabolites if ';' in m.formula and not all_formulas_equivalent(m)]:
#     print(m.id, m.name, m.formula)
#     m.formula = m.formula.split(';')[0]
    
#     equivalent_formulas += 1

# print(f'There are {equivalent_formulas} metabolites with equivalent formulas, and they have been fixed.')
# Out:
# There are 0 metabolites with equivalent formulas, and they have been fixed.

# %%
# status_report()
# Out:
# 1952 of 1952 metabolites have 1 formula(s)
# 0 of 1952 metabolites have 2 formula(s)
# 0 of 1952 metabolites have 3 formula(s)
# 0 of 1952 metabolites have 4 formula(s)
#
#
# 610 of the 3021 reactions in the model are wrongly unbalanced
# 339 of the 3021 reactions in the model are properly unbalanced
# 2072 of the 3021 reactions in the model are balanced
#
#
# 0 of the 610 improperly unbalanced reactions in the model have at least one metabolite with multiple formulas
# 0 of the 339 properly unbalanced reactions in the model have at least one metabolite with multiple formulas
# 0 of the 2072 balanced reactions in the model have at least one metabolite with multiple formulas

# %% [markdown]
# # Assign metabolite formulas by checking if one formula makes all reactions where its the only undefined metabolite balanced
# Define functions for this section

# %%
# def m_only_undefined_metabolite(m1, r):
#     return ';' in m1.formula and len([m2 for m2 in r.metabolites if ';' in m2.formula and m1 != m2]) == 0

# def reactions_where_m_is_only_undefined_metabolite(m):
#     return [r for r in m.reactions if m_only_undefined_metabolite(m,r)]

# def fraction_of_reactions_formula_balances(m, formula, rxn_list):
#     original_formula = m.formula
#     m.formula = formula
#     balanced_reactions   = [r for r in rxn_list if r.check_mass_balance() == {}]
#     unbalanced_reactions = [r for r in rxn_list if r.check_mass_balance() != {}]
#     m.formula = original_formula
    
#     # avoid divide by zero
#     if len(balanced_reactions) + len(unbalanced_reactions) == 0:
#         return 0
#     return len(balanced_reactions) / (len(balanced_reactions) + len(unbalanced_reactions))

# %% [markdown]
# Run this function until no additional metabolites can be defined based on being the only undefined metabolite. Only assign formulas to perfect fits (Need to improve this wording)

# %%
# metabolites_that_can_be_defined = 1
# while metabolites_that_can_be_defined > 0:
#     metabolites_that_can_be_defined = 0
#     for m in [m for m in model.metabolites if ';' in m.formula]:
#         for f in m.formula.split(';'):
#             if fraction_of_reactions_formula_balances(m, f, reactions_where_m_is_only_undefined_metabolite(m)) == 1:
#                 print(m.name)
#                 print(m.formula)
#                 print(f)
#                 metabolites_that_can_be_defined += 1
#                 m.formula = f

#     print(f'{metabolites_that_can_be_defined} metabolites can be defined in this round')
# Out:
# 0 metabolites can be defined in this round

# %%
# status_report()
# Out:
# 1952 of 1952 metabolites have 1 formula(s)
# 0 of 1952 metabolites have 2 formula(s)
# 0 of 1952 metabolites have 3 formula(s)
# 0 of 1952 metabolites have 4 formula(s)
#
#
# 610 of the 3021 reactions in the model are wrongly unbalanced
# 339 of the 3021 reactions in the model are properly unbalanced
# 2072 of the 3021 reactions in the model are balanced
#
#
# 0 of the 610 improperly unbalanced reactions in the model have at least one metabolite with multiple formulas
# 0 of the 339 properly unbalanced reactions in the model have at least one metabolite with multiple formulas
# 0 of the 2072 balanced reactions in the model have at least one metabolite with multiple formulas

# %% [markdown]
# # Now repeat but allow for imperfect fitting
# Assign formulas that satisfy the greatest fraction of reactions first.
# After each loop check to see which formulas have the greatest fraction of reactions they balance

# %%
# highest_fraction = 1
# while highest_fraction > 0:
#     highest_fraction = 0
#     metabolites_that_can_be_defined = 0

#     # find highest fraction of reactions that are solved by a given formula
#     for m in [m for m in model.metabolites if ';' in m.formula]:
#         for f in m.formula.split(';'):
#             if fraction_of_reactions_formula_balances(m, f, reactions_where_m_is_only_undefined_metabolite(m)) > highest_fraction:
#                 highest_fraction = fraction_of_reactions_formula_balances(m, f, reactions_where_m_is_only_undefined_metabolite(m))

#     # assign formulas to metabolites with formula that gives a score equal to the best fraction
#     if highest_fraction > 0:
#         for m in [m for m in model.metabolites if ';' in m.formula]:
#             for f in m.formula.split(';'):
#                 if fraction_of_reactions_formula_balances(m, f, reactions_where_m_is_only_undefined_metabolite(m)) == highest_fraction:
#                     print(m.name)
#                     print(m.formula)
#                     print(f)
#                     m.formula = f
#                     metabolites_that_can_be_defined += 1

#     print(f'{metabolites_that_can_be_defined} metabolite(s) can be defined in this round with a fitting score of {highest_fraction}')
# Out:
# 0 metabolite(s) can be defined in this round with a fitting score of 0

# %%
# status_report()
# Out:
# 1952 of 1952 metabolites have 1 formula(s)
# 0 of 1952 metabolites have 2 formula(s)
# 0 of 1952 metabolites have 3 formula(s)
# 0 of 1952 metabolites have 4 formula(s)
#
#
# 610 of the 3021 reactions in the model are wrongly unbalanced
# 339 of the 3021 reactions in the model are properly unbalanced
# 2072 of the 3021 reactions in the model are balanced
#
#
# 0 of the 610 improperly unbalanced reactions in the model have at least one metabolite with multiple formulas
# 0 of the 339 properly unbalanced reactions in the model have at least one metabolite with multiple formulas
# 0 of the 2072 balanced reactions in the model have at least one metabolite with multiple formulas

# %% [markdown]
# # Assign remaining metabolites by checking if combinations of formulas are balanaced or only off by hydrogen
# Note 1: there is a preference for more verbose formulas to minimize shorthand notation<br>
# Note 2: This is only done if there are less than 10 metabolites since the number of formula combination grows roughly exponentially (i.e. 10 undefined metabolites each with 2 formulas yields 2^10 possible combinations <br>
# Define functions for this section

# %%
# def is_balanced(r):
#     return abs(sum(list(r.check_mass_balance().values()))) < 1e-5

# def balanced_or_only_hydrogen_unbalanced(r):
#     return should_be_balanced(r) and (is_balanced(r) or list(r.check_mass_balance().keys()) == ['H'])

# def reactions_off_by_more_than_hydrogen():
#     return [r for r in model.reactions if should_be_balanced(r) and not(balanced_or_only_hydrogen_unbalanced(r))]

# def chars_in_string_list(string_list):
#     total_chars = 0
#     for string in string_list:
#         total_chars += len(string)
#     return total_chars

# %%
# undefined_metabolites = [m for m in model.metabolites if ';' in m.formula]
# possible_formulas = [m.formula.split(';') for m in model.metabolites if ';' in m.formula]

# # only do this step if there is a reasonable number of undefined metbolites due to exponential growth of formula combinations
# if len(undefined_metabolites) < 10:
    
#     # inital best formulas is their original values
#     best_formulas = [m.formula for m in undefined_metabolites]
#     best_score = len(reactions_off_by_more_than_hydrogen())
#     best_length = 0

#     # goes through all permutations of formulas for undefined metabolites
#     for formulas in list(product(*possible_formulas)):
#         # assign the formulas to the metabolites
#         for count, m in enumerate(undefined_metabolites):
#             model.metabolites.get_by_id(m.id).formula = formulas[count]

#         # get the number of reactions that are off by more than hydrogen
#         unacceptable_reactions = reactions_off_by_more_than_hydrogen()
# #         print(len(unacceptable_reactions), formulas) this line give a lot of details

#         # if its the best fit replace the best formulas
#         if len(unacceptable_reactions) <= best_score:
#             if chars_in_string_list(formulas) > best_length:
#                 best_formulas = formulas
#                 best_score = len(reactions_off_by_more_than_hydrogen())
#                 best_length = chars_in_string_list(formulas)
                
# for count, m in enumerate(undefined_metabolites):
#     model.metabolites.get_by_id(m.id).formula = best_formulas[count]
#     print(f'For metabolite {m.id}, with possible formulas {possible_formulas[count]}, {best_formulas[count]} was chosen')

# %%
status_report()
# Out:
# 1952 of 1952 metabolites have 1 formula(s)
# 0 of 1952 metabolites have 2 formula(s)
# 0 of 1952 metabolites have 3 formula(s)
# 0 of 1952 metabolites have 4 formula(s)
#
#
# 610 of the 3021 reactions in the model are wrongly unbalanced
# 339 of the 3021 reactions in the model are properly unbalanced
# 2072 of the 3021 reactions in the model are balanced
#
#
# 0 of the 610 improperly unbalanced reactions in the model have at least one metabolite with multiple formulas
# 0 of the 339 properly unbalanced reactions in the model have at least one metabolite with multiple formulas
# 0 of the 2072 balanced reactions in the model have at least one metabolite with multiple formulas

# %% [markdown]
# # Balance Hydrogen
# Define function to balance hydrogen

# %%
# def only_hydrogen_unbalanced(r):
#     return list(r.check_mass_balance().keys()) == ['H'] and should_be_balanced(r)

# def fix_unbalanced_hydrogen(r):
#     hydrogen_error = int(r.check_mass_balance()['H'])
#     r.subtract_metabolites({model.metabolites.get_by_id("h_c"): hydrogen_error})

# %%
# for r in [r for r in model.reactions if only_hydrogen_unbalanced(r)]:
#     fix_unbalanced_hydrogen(r)

# %%
# status_report()
# Out:
# 1952 of 1952 metabolites have 1 formula(s)
# 0 of 1952 metabolites have 2 formula(s)
# 0 of 1952 metabolites have 3 formula(s)
# 0 of 1952 metabolites have 4 formula(s)
#
#
# 610 of the 3021 reactions in the model are wrongly unbalanced
# 339 of the 3021 reactions in the model are properly unbalanced
# 2072 of the 3021 reactions in the model are balanced
#
#
# 0 of the 610 improperly unbalanced reactions in the model have at least one metabolite with multiple formulas
# 0 of the 339 properly unbalanced reactions in the model have at least one metabolite with multiple formulas
# 0 of the 2072 balanced reactions in the model have at least one metabolite with multiple formulas

# %% [markdown]
# # Check remaining imbalances

# %%
# for r in [r for r in model.reactions if should_be_balanced(r) and r.check_mass_balance() != {}]:
#     print(r, '\n', r.check_mass_balance(), '\n')
# Out:
# 1P2CBXLCYCL: 5a2opntn_c <=> 1p2cbxl_c + h2o_c + h_c
#  {'charge': 1.0}
#
# 1P2CBXLR: 1p2cbxl_c + 2.0 h_c + nadph_c --> nadp_c + pro__L_c
#  {'charge': -1.0}
#
# 23CTI1: decoa_c --> dc2coa_c + h_c
#  {'charge': -3.0}
#
# 23CTI2: dded3coa_c --> dd2coa_c
#  {'charge': -4.0}
#
# 24DECOAR: dec4_2_coa_c + h_c + nadph_c --> dc2coa_c + nadp_c
#  {'charge': -4.0}
#
# 2AGPGAT160: 2agpg160_c + atp_c + hdca_c --> amp_c + pg160_c + ppi_c
#  {'charge': 1.0}
#
# 2AGPGAT161: 2agpg161_c + atp_c + hdcea_c --> amp_c + pg161_c + ppi_c
#  {'charge': -1.0}
#
# 2DDARAA: 2ddara_c <=> gcald_c + pyr_c
#  {'charge': -1.0}
#
# 2DGULRx: 2dhguln_c + h_c + nadh_c --> idon__L_c + nad_c
#  {'charge': -1.0}
#
# 34DHPACDO: 34dhpacet_c + o2_c --> 5cmhmsa_c + h_c
#  {'charge': 2.0}
#
# 4ABZGLUH: 4abzglu_c + h2o_c <=> 4abz_c + glu__L_c
#  {'charge': -2.0}
#
# 4CMLCL_kt: 4cml_c + h_c --> 5odhf2a_c + co2_c
#  {'charge': -2.0}
#
# 4H2KPILY: 4h2kpi_c --> pyr_c + sucsal_c
#  {'charge': -2.0}
#
# 4HOXPACMOF_1: 4hoxpac_c + fadh2_c + o2_c --> 34dhpacet_c + fad_c + h2o_c
#  {'charge': -1.0}
#
# 4HOXPACMON: 4hoxpac_c + h_c + nadh_c + o2_c --> 34dhpacet_c + h2o_c + nad_c
#  {'charge': -1.0}
#
# 4HPTNCOAK: 4hptcoa_c + atp_c --> 4poptcoa_c + adp_c + h_c
#  {'charge': 2.0}
#
# 4HPTNCOAL: 4hptn_c + atp_c + coa_c --> 4hptcoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# 4POPCOAM: 4poptcoa_c --> 3ptcoa_c + pi_c
#  {'charge': -2.0}
#
# AACLAM: acadl_c + coa_c <=> accoa_c + amp_c
#  {'charge': -2.0}
#
# AACOAR_syn: aacoa_c + h_c + nadph_c <=> 3hbcoa__R_c + nadp_c
#  {'charge': 4.0}
#
# AACPS1: ACP_c + atp_c + ttdca_c --> amp_c + myrsACP_c + ppi_c
#  {'charge': -1.0}
#
# AACPS2: ACP_c + atp_c + ttdcea_c --> amp_c + ppi_c + tdeACP_c
#  {'charge': -2.0}
#
# AACPS3: ACP_c + atp_c + hdca_c --> amp_c + palmACP_c + ppi_c
#  {'charge': -1.0}
#
# AACPS4: ACP_c + atp_c + hdcea_c --> amp_c + hdeACP_c + ppi_c
#  {'charge': -2.0}
#
# AACPS5: ACP_c + atp_c + ocdcea_c --> amp_c + octeACP_c + ppi_c
#  {'charge': -1.0}
#
# AACPS6: ACP_c + atp_c + ocdca_c --> amp_c + ocdcaACP_c + ppi_c
#  {'charge': -2.0}
#
# AACPS7: ACP_c + atp_c + ddca_c --> amp_c + ddcaACP_c + ppi_c
#  {'charge': -1.0}
#
# AACPS8: ACP_c + atp_c + dca_c --> amp_c + dcaACP_c + ppi_c
#  {'charge': -1.0}
#
# AACPS9: ACP_c + atp_c + octa_c --> amp_c + ocACP_c + ppi_c
#  {'charge': -2.0}
#
# AADa: aad_c + coa_c <=> accoa_c + amp_c
#  {'charge': -2.0}
#
# AADb: ac_c + atp_c <=> aad_c + ppi_c
#  {'charge': 2.0}
#
# AALDH: nadh_c + pacald_c <=> nad_c + pea_c
#  {'charge': 1.0}
#
# ACGAMPM: acgam6p_c <=> acgam1p_c
#  {'charge': 2.0}
#
# ACHBS: 2obut_c + h_c + pyr_c --> 2ahbut_c + co2_c
#  {'charge': 1.0}
#
# ACLS_a: h_c + pyr_c + thmpp_c --> co2_c + hethmpp_c
#  {'charge': 2.0}
#
# ACLS_d: hethmpp_c + lpam_c <=> adhlam_c + thmpp_c
#  {'charge': -2.0}
#
# ACM6PH: acmum6p_c + h2o_c --> acgam6p_c + lac__D_c
#  {'charge': -3.0}
#
# ACMANApts: acmana_e + pep_c --> acmanap_c + pyr_c
#  {'charge': 2.0}
#
# ACOAD10f: fad_c + 2.0 h_c + hptcoa_c <=> fadh2_c + hp2coa_c
#  {'charge': -2.0}
#
# ACOAD14f: fad_c + 2.0 h_c + poctacoa_c <=> fadh2_c + pocta2coa_c
#  {'charge': -2.0}
#
# ACOAD15f: fad_c + 2.0 h_c + phpcoa_c <=> fadh2_c + php2coa_c
#  {'charge': -2.0}
#
# ACOAD16f: fad_c + 2.0 h_c + phxacoa_c <=> fadh2_c + phxa2coa_c
#  {'charge': -2.0}
#
# ACOAD17f: fad_c + 2.0 h_c + pptcoa_c <=> fadh2_c + ppt2coa_c
#  {'charge': -2.0}
#
# ACOAD18f: fad_c + 2.0 h_c + pbcoa_c <=> fadh2_c + pb2coa_c
#  {'charge': -2.0}
#
# ACOAD23f: fad_c + hdcoa_c <=> fadh2_c + hd2coa_c
#  {'charge': 4.0}
#
# ACOAD26f: fad_c + odecoa_c <=> fadh2_c + ode2coa_c
#  {'charge': 4.0}
#
# ACOAD29f: fad_c + 2.0 h_c + ptslacoa_c <=> fadh2_c + ptsla2coa_c
#  {'charge': -2.0}
#
# ACOAD3: nad_c + occoa_c <=> h_c + nadh_c + oc2coa_c
#  {'charge': 4.0}
#
# ACOAD30f: fad_c + h_c + hdd4coa_c <=> fadh2_c + hdd4_2_coa_c
#  {'charge': -1.0}
#
# ACOAD31f: fad_c + lnlccoa_c <=> fadh2_c + 2.0 h_c + lnlc2coa_c
#  {'charge': 2.0}
#
# ACOAD34f: dec4coa_c + fad_c + 2.0 h_c <=> dec4_2_coa_c + fadh2_c
#  {'charge': -2.0}
#
# ACOAD3f: fad_c + occoa_c <=> fadh2_c + oc2coa_c
#  {'charge': 4.0}
#
# ACOAD4_1: dccoa_c + nad_c <=> dc2coa_c + h_c + nadh_c
#  {'charge': -4.0}
#
# ACOAD6: nad_c + tdcoa_c <=> h_c + nadh_c + td2coa_c
#  {'charge': 4.0}
#
# ACOAD6f: fad_c + tdcoa_c <=> fadh2_c + td2coa_c
#  {'charge': 4.0}
#
# ACOAM: ac_c + atp_c --> acadl_c + ppi_c
#  {'charge': 2.0}
#
# ACP1_FMN: fmn_c + h2o_c --> pi_c + ribflv_c
#  {'charge': -2.0}
#
# ACPPAT120: ddcaACP_c + h_c + pi_c --> ACP_c + ddcap_c
#  {'charge': 2.0}
#
# ACPPAT141: h_c + pi_c + tdeACP_c --> ACP_c + ttdceap_c
#  {'charge': 3.0}
#
# ACPPAT160: h_c + palmACP_c + pi_c --> ACP_c + hdcap_c
#  {'charge': 2.0}
#
# ACPPAT161: h_c + hdeACP_c + pi_c --> ACP_c + hdceap_c
#  {'charge': 3.0}
#
# ACPPAT180: h_c + ocdcaACP_c + pi_c --> ACP_c + ocdcap_c
#  {'charge': 3.0}
#
# ACPPAT181: h_c + octeACP_c + pi_c --> ACP_c + ocdceap_c
#  {'charge': 2.0}
#
# ACPS1: apoACP_c + coa_c --> ACP_c + h_c + pap_c
#  {'charge': 1.0}
#
# ACPS1_1: apoACP_c + coa_c --> ACP_c + h_c + pap_c
#  {'charge': 1.0}
#
# ACPpds: ACP_c + h2o_c --> apoACP_c + h_c + pan4p_c
#  {'charge': -1.0}
#
# ACSPHAC100: R_3hdcaa_c + atp_c + coa_c --> R_3hdcoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHAC101: R3hdec4e_c + atp_c + coa_c --> R3hdec4coa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHAC120: R_3hdda_c + atp_c + coa_c --> R_3hddcoa_c + amp_c + ppi_c
#  {'charge': -1.0}
#
# ACSPHAC121: R_3hdd5ea_c + atp_c + coa_c --> R_3hcddec5ecoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHAC121d6: R_3hdd6e_c + atp_c + coa_c --> R_3hdd6coa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHAC140: R_3httdca_c + atp_c + coa_c --> R_3hmrscoa_c + amp_c + ppi_c
#  {'charge': -1.0}
#
# ACSPHAC141: R_3hcmrs7e_c + atp_c + coa_c --> R_3hcmrs7ecoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHAC141d5: R_3htd5e_c + atp_c + coa_c --> R_3htd5coa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHAC142: R_3htd58e_c + atp_c + coa_c --> R_3htd58coa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHAC160: R_3hhdca_c + atp_c + coa_c --> R_3hhdcoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHAC40: atp_c + bhb_c + coa_c --> 3hbcoa__R_c + amp_c + ppi_c
#  {'charge': 4.0}
#
# ACSPHAC50: R_3hpt_c + atp_c + coa_c --> R_3hptcoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHAC60: R_3hhxa_c + atp_c + coa_c --> R_3hhcoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHAC70: R_3hhpa_c + atp_c + coa_c --> R_3hhpcoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHAC80: R_3hocta_c + atp_c + coa_c --> R_3hocoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHAC90: R_3hnonaa_c + atp_c + coa_c --> R_3hnonacoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHACP100: R_3hpdeca_c + atp_c + coa_c --> R_3hpdecacoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHACP40: R_3hpba_c + atp_c + coa_c --> R_3hpbcoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHACP50: R_3hppta_c + atp_c + coa_c --> R_3hpptcoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHACP60: R_3hphxa_c + atp_c + coa_c --> R_3hphxacoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHACP70: R_3hphpa_c + atp_c + coa_c --> R_3hphpcoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHACP80: R_3hpocta_c + atp_c + coa_c --> R_3hpoctacoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHACP90: R_3hpnona_c + atp_c + coa_c --> R_3hpnonacoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHACT40: R_3h4atba_c + atp_c + coa_c --> R_3h4atbcoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHACT60: R_3h6atha_c + atp_c + coa_c --> R_3h6athcoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ADCPS1: adcobhex_c + appl_c + atp_c --> adocbi_c + adp_c + h_c + pi_c
#  {'charge': 1.0}
#
# ADK2: amp_c + pppi_c <=> adp_c + ppi_c
#  {'charge': -4.0}
#
# ADMDC: amet_c + h_c --> ametam_c + co2_c
#  {'charge': -2.0}
#
# ADOCBIAH: adocbi_c + h2o_c <=> adcobhex_c + appl_c
#  {'charge': -1.0}
#
# ADPRDP: adprib_c + h2o_c --> amp_c + 2.0 h_c + r5p_c
#  {'charge': 2.0}
#
# ADPRDP_1: adprib_c + h2o_c --> amp_c + 2.0 h_c + r5p_c
#  {'charge': 2.0}
#
# ADSELK: adsel_c + atp_c --> 3padsel_c + adp_c + h_c
#  {'charge': 2.0}
#
# ADSELR: 3padsel_c + trdrd_c --> 2.0 h_c + pap_c + slnt_c + trdox_c
#  {'charge': -4.0}
#
# ADSL1r: dcamp_c <=> amp_c + fum_c
#  {'charge': -4.0}
#
# ADSS: asp__L_c + gtp_c + imp_c --> dcamp_c + gdp_c + 2.0 h_c + pi_c
#  {'charge': 4.0}
#
# AEPPYRTA: 2ameph_c + pyr_c --> Pald_c + ala__L_c + h_c
#  {'charge': 2.0}
#
# AGM3PA: anhgm3p_c + h2o_c --> LalaDgluMdap_c + anhgm_c
#  {'charge': -2.0}
#
# AGM3PApp: anhgm3p_p + h2o_p --> LalaDgluMdap_p + anhgm_p
#  {'charge': -2.0}
#
# AGM3PH: anhgm3p_c + h2o_c --> acgam_c + anhm3p_c
#  {'charge': -2.0}
#
# AGM4PCPpp: anhgm4p_p + h2o_p --> ala__D_p + anhgm3p_p
#  {'charge': 2.0}
#
# AGPAT120: 1ddecg3p_c + ddcaACP_c --> ACP_c + pa120_c
#  {'charge': 3.0}
#
# AGPAT141: 1tdec7eg3p_c + tdeACP_c --> ACP_c + pa141_c
#  {'charge': 4.0}
#
# AGPAT160: 1hdecg3p_c + palmACP_c --> ACP_c + pa160_c
#  {'charge': 1.0}
#
# AGPAT161: 1hdec9eg3p_c + hdeACP_c --> ACP_c + pa161_c
#  {'charge': 2.0}
#
# AGPAT180: 1odecg3p_c + ocdcaACP_c --> ACP_c + pa180_c
#  {'charge': 4.0}
#
# AGPAT181: 1odec11eg3p_c + octeACP_c --> ACP_c + pa181_c
#  {'charge': 3.0}
#
# AGPATr_BS: 0.01 1ag3p_BS_c + 0.07 fa11coa_c + 0.17 fa12coa_c + 0.01 fa1coa_c + 0.2 fa3coa_c + 0.34 fa4coa_c + 0.05 fa6coa_c + 0.1 pmtcoa_c + 0.03 strcoa_c + 0.03 tdcoa_c <=> 0.01 12dag3p_BS_c + coa_c
#  {'charge': -3.48, 'C': -7.105427357601002e-15, 'H': -1.4210854715202004e-14, 'O': -3.552713678800501e-15, 'N': -8.881784197001252e-16}
#
# AH6PI: ah6p__D_c <-- f6p_c
#  {'charge': -2.0}
#
# AHGDx: S2hglut_c + nad_c <=> akg_c + h_c + nadh_c
#  {'charge': -2.0}
#
# AHMMPS: air_c + 2.0 h_c --> 4ahmmp_c + gcald_c + pi_c
#  {'charge': -4.0}
#
# AIRC2: air_c + atp_c + hco3_c --> 5caiz_c + adp_c + h_c + pi_c
#  {'charge': -2.0}
#
# AIRC3: 5aizc_c <=> 5caiz_c
#  {'charge': -3.0}
#
# AIRCr: air_c + co2_c <=> 5aizc_c + h_c
#  {'charge': 1.0}
#
# AKGDa: akg_c + h_c + lpam_c <=> co2_c + sdhlam_c
#  {'charge': 1.0}
#
# AKGDb: coa_c + sdhlam_c --> dhlam_c + succoa_c
#  {'charge': -1.0}
#
# ALDD4x: h2o_c + mmalsa__S_c + nad_c --> 2.0 h_c + mmal_c + nadh_c
#  {'charge': -1.0}
#
# AMANAPEr: acmanap_c <=> acgam6p_c
#  {'charge': -2.0}
#
# AMANK: acmana_c + atp_c --> acmanap_c + adp_c + h_c
#  {'charge': 2.0}
#
# AMAOTr: 8aonn_c + amet_c <=> amob_c + dann_c
#  {'charge': -1.0}
#
# AMMQT8: 2dmmq8_c + amet_c + h_c --> ahcys_c + mql8_c
#  {'charge': -2.0}
#
# AMPEP10: gly_asp__L_c + h2o_c <=> asp__L_c + gly_c
#  {'charge': -1.0}
#
# AMPEP11: gly_pro__L_c + h2o_c --> gly_c + h_c + pro__L_c
#  {'charge': 1.0}
#
# AMPEP14: h2o_c + h_c + met_L_ala__L_c <=> ala__L_c + met__L_c
#  {'charge': -1.0}
#
# AMPEP15: h2o_c + prohisglu_c --> glu__L_c + his__L_c + pro__L_c
#  {'charge': -1.0}
#
# AMPEP18: h2o_c + serglugly_c --> glu__L_c + gly_c + ser__L_c
#  {'charge': -1.0}
#
# AMPEP5: ala_L_glu__L_c + h2o_c <=> ala__L_c + glu__L_c
#  {'charge': -1.0}
#
# AMPEP8: gly_glu__L_c + h2o_c <=> glu__L_c + gly_c
#  {'charge': -1.0}
#
# AMPTASEGGLU: glyglu_c + h2o_c --> glu__L_c + gly_c
#  {'charge': -1.0}
#
# ANHMK: anhm_c + atp_c + h2o_c --> acmum6p_c + adp_c + h_c
#  {'charge': 3.0}
#
# APAT_1: atp_c + ppa_c <=> ppad_c + ppi_c
#  {'charge': 2.0}
#
# APG3PAT120: ddcap_c + glyc3p_c --> 1ddecg3p_c + h_c + pi_c
#  {'charge': -1.0}
#
# APG3PAT141: glyc3p_c + ttdceap_c --> 1tdec7eg3p_c + h_c + pi_c
#  {'charge': -1.0}
#
# APG3PAT160: glyc3p_c + hdcap_c --> 1hdecg3p_c + h_c + pi_c
#  {'charge': -1.0}
#
# APG3PAT161: glyc3p_c + hdceap_c --> 1hdec9eg3p_c + h_c + pi_c
#  {'charge': 1.0}
#
# APG3PAT180: glyc3p_c + ocdcap_c --> 1odecg3p_c + h_c + pi_c
#  {'charge': -1.0}
#
# APG3PAT181: glyc3p_c + ocdceap_c --> 1odec11eg3p_c + h_c + pi_c
#  {'charge': -1.0}
#
# APPLDHr: aact_c + h_c + nadh_c <=> appl_c + nad_c
#  {'charge': -1.0}
#
# ARACHTA: ACP_c + arachcoa_c <=> arachACP_c + coa_c
#  {'charge': -1.0}
#
# ARGSL: argsuc_c <=> arg__L_c + fum_c
#  {'charge': -1.0}
#
# ARGSS: asp__L_c + atp_c + citr__L_c --> amp_c + argsuc_c + h_c + ppi_c
#  {'charge': 1.0}
#
# ASP3H: akg_c + asp__L_c + o2_c --> 3hasp__L_c + co2_c + succ_c
#  {'charge': 1.0}
#
# ATPPRT: atp_c + prpp_c --> ppi_c + prbatp_c
#  {'charge': 6.0}
#
# AT_MBD2: dhlam_c + ibcoa_c <=> 2mpdhl_c + coa_c + h_c
#  {'charge': 1.0}
#
# BKDA2: 3mob_c + lpam_c --> 2mpdhl_c + co2_c
#  {'charge': 1.0}
#
# BMNMSHS: bmn_c + msh_c --> bmnmsh_c + 2.0 h_c
#  {'charge': 2.0}
#
# BSCT: coa_c + 4.0 h_c + sbzcoa_c <=> benzcoa_c + succoa_c
#  {'charge': -5.0}
#
# BTS2: cys__L_c + dtbt_c <=> ala__L_c + btn_c + 2.0 h_c
#  {'charge': 1.0}
#
# BTS3r: dtbt_c + 2.0 s_c <=> btn_c + h2s_c
#  {'charge': -1.0}
#
# BZ12DOX: bz_c + h_c + nadh_c + o2_c --> bz12diol_c + nad_c
#  {'charge': 1.0}
#
# BZDIOLDH: bz12diol_c + nad_c --> catechol_c + co2_c + nadh_c
#  {'charge': -1.0}
#
# BZSCT: bzsucc_c + succoa_c <=> bzsuccoa_c + succ_c
#  {'charge': 3.0}
#
# BZSS: fum_c + tol_c <=> bzsucc_c
#  {'charge': 2.0}
#
# CARBSARAH: Ncarbsar_c + h2o_c + 2.0 h_c --> co2_c + nh4_c + sarcs_c
#  {'charge': -1.0}
#
# CATDOX: catechol_c + o2_c --> ccmuac_c + 2.0 h_c
#  {'charge': 2.0}
#
# CDGUNPD: cdigmp_c + h2o_c --> 5pg35pg_c + h_c
#  {'charge': -2.0}
#
# CDPPT160: cdpdhdecg_c + inost_c --> cmp_c + h_c + ptd1ino160_c
#  {'charge': 1.0}
#
# CHORM: chor_c --> pphn_c
#  {'charge': 2.0}
#
# CLPNH140pp: clpn140_p + h2o_p --> h_p + pa140_p + pg140_p
#  {'charge': 2.0}
#
# CMCBTFL: cmcbtt_c + fe3_e --> fcmcbtt_c
#  {'charge': -3.0, 'H': 1.0}
#
# CMCBTFU: fcmcbtt_c --> cmcbtt_c + fe3_c + h_c
#  {'charge': 4.0}
#
# CMCMSAD: 5cmhmsa_c + h2o_c + nad_c --> 5cmhm_c + 2.0 h_c + nadh_c
#  {'charge': 1.0}
#
# CMLDC: 4cml_c + h_c --> 5odhf2a_c + co2_c
#  {'charge': -2.0}
#
# CYANST: cyan_c + tsul_c --> h_c + so3_c + tcynt_c
#  {'charge': -2.0}
#
# CYO1b: 2.0 focytc_c + 0.5 o2_c --> 2.0 ficytc_c + h2o_c
#  {'charge': -4.0}
#
# CYP1: chol4en3one_c + nadh_c + o2_c --> h2o_c + h_c + hchol_c + nad_c
#  {'charge': 2.0}
#
# CYSK2_I: h_c + pser__L_c + tsul_c --> pi_c + scys__L_c
#  {'charge': -1.0}
#
# D5KGK: atp_c + d5kg_c --> adp_c + d5kgp_c + h_c
#  {'charge': 3.0}
#
# D5KGPA: d5kgp_c --> dhap_c + msa_c
#  {'charge': -3.0}
#
# DAAD12: fad_c + h2o_c + 2.0 h_c + val__D_c --> 3mob_c + fadh2_c + nh4_c
#  {'charge': -2.0}
#
# DACL: abg4_c + h2o_c + h_c <=> 4abz_c + glu__D_c
#  {'charge': -3.0}
#
# DAGK140: 12dgr140_c + atp_c --> adp_c + h_c + pa140_c
#  {'charge': 2.0}
#
# DASYN120: ctp_c + h_c + pa120_c --> cdpdddecg_c + ppi_c
#  {'charge': -2.0}
#
# DASYN140: ctp_c + h_c + pa140_c --> cdpdtdecg_c + ppi_c
#  {'charge': -2.0}
#
# DASYN141: ctp_c + h_c + pa141_c --> cdpdtdec7eg_c + ppi_c
#  {'charge': -2.0}
#
# DASYN161: ctp_c + h_c + pa161_c --> cdpdhdec9eg_c + ppi_c
#  {'charge': -2.0}
#
# DASYN180: ctp_c + h_c + pa180_c --> cdpdodecg_c + ppi_c
#  {'charge': -2.0}
#
# DASYN181: ctp_c + h_c + pa181_c --> cdpdodec11eg_c + ppi_c
#  {'charge': -2.0}
#
# DB4PS: ru5p__D_c --> db4p_c + for_c
#  {'charge': 1.0}
#
# DBTS: atp_c + co2_c + dann_c --> adp_c + dtbt_c + 3.0 h_c + pi_c
#  {'charge': 1.0}
#
# DDPGALA: 2dh3dgal6p_c <=> g3p_c + pyr_c
#  {'charge': 2.0}
#
# DGUNC: 2.0 gtp_c --> cdigmp_c + 2.0 ppi_c
#  {'charge': 2.0}
#
# DHACOAH: 23dhacoa_c + h2o_c <=> 3hadpcoa_c
#  {'charge': -5.0}
#
# DHAD3: 23dhmp_c --> 2o3mpt_c + h2o_c
#  {'charge': 1.0}
#
# DHBD: 23ddhb_c + nad_c <=> 23dhb_c + h_c + nadh_c
#  {'charge': -1.0}
#
# DHBSH: 23dhbzs_c + h2o_c --> 23dhb_c + ser__L_c
#  {'charge': -1.0}
#
# DHBZS2H: 23dhbzs2_c + h2o_c --> 2.0 23dhbzs_c + h_c
#  {'charge': 1.0}
#
# DHBZS3H: 23dhbzs3_c + h2o_c --> 23dhbzs2_c + 23dhbzs_c + h_c
#  {'charge': 1.0}
#
# DHCINDO: dhcinnm_c + o2_c --> h_c + hkntd_c
#  {'charge': 2.0}
#
# DHEDAA: 24dhhed_c --> pyr_c + sucsal_c
#  {'charge': -2.0}
#
# DHNAOT: dhna_c + octdp_c --> 2dmmq8_c + co2_c + h_c + ppi_c
#  {'charge': 2.0}
#
# DHNCOAS: h_c + sbzcoa_c --> 14dhncoa_c + h2o_c
#  {'charge': -5.0}
#
# DHPACCOAHIT: 2dhphaccoa_c + coa_c + 2.0 h2o_c --> 3hadpcoa_c + accoa_c + h2_c + h_c
#  {'charge': -4.0}
#
# DHPDO: 34dhpha_c + o2_c --> 5cmhmsa_c + h_c
#  {'charge': 2.0}
#
# DKGLCNR1: 25dkglcn_c + h_c + nadph_c --> 2dhguln_c + nadp_c
#  {'charge': 1.0}
#
# DNMPPA: dhpmp_c + h2o_c --> dhnpt_c + pi_c
#  {'charge': -2.0}
#
# DNTPPA: ahdt_c + h2o_c --> dhpmp_c + h_c + ppi_c
#  {'charge': 2.0}
#
# DRPA: 2dr5p_c --> acald_c + g3p_c
#  {'charge': 2.0}
#
# DTBTST: 2.0 amet_c + dtbt_c + s_c --> btn_c + 2.0 dad_5_c + 2.0 met__L_c
#  {'charge': -3.0}
#
# DXPRIi: dxyl5p_c + h_c + nadph_c --> 2me4p_c + nadp_c
#  {'charge': 2.0}
#
# DXPS: g3p_c + h_c + pyr_c --> co2_c + dxyl5p_c
#  {'charge': -2.0}
#
# ECOAH1_1: 3hbycoa_c <=> b2coa_c + h2o_c
#  {'charge': -4.0}
#
# ECOAH5_1: 3hddcoa_c <=> h2o_c + trans_dd2coa_c
#  {'charge': 4.0}
#
# ECOAH6: 3htdcoa_c <=> h2o_c + td2coa_c
#  {'charge': 4.0}
#
# ECOAH8: 3hodcoa_c <=> h2o_c + od2coa_c
#  {'charge': -4.0}
#
# EDA: 2ddg6p_c --> g3p_c + pyr_c
#  {'charge': 2.0}
#
# ENTERES: enter_c + 3.0 h2o_c --> 3.0 23dhbzs_c + 2.0 h_c
#  {'charge': 3.0}
#
# ENTERES2: feenter_c + 3.0 h2o_c --> 3.0 23dhbzs_c + fe3_c + 2.0 h_c
#  {'charge': 5.0}
#
# ENTERGLCT1: enter_c + udpg_c --> entermg_c + h_c + udp_c
#  {'charge': 1.0}
#
# ENTERH: enter_c + h2o_c --> 23dhbzs3_c
#  {'charge': 1.0}
#
# FA100ACPHi: dcaACP_c + h2o_c --> ACP_c + dca_c + h_c
#  {'charge': 1.0}
#
# FA120ACPHi: ddcaACP_c + h2o_c --> ACP_c + ddca_c + h_c
#  {'charge': 1.0}
#
# FA140ACPHi: h2o_c + myrsACP_c --> ACP_c + h_c + ttdca_c
#  {'charge': 1.0}
#
# FA141ACPHi: h2o_c + tdeACP_c --> ACP_c + h_c + ttdcea_c
#  {'charge': 2.0}
#
# FA160ACPHi: h2o_c + palmACP_c --> ACP_c + h_c + hdca_c
#  {'charge': 1.0}
#
# FA161ACPHi: h2o_c + hdeACP_c --> ACP_c + h_c + hdcea_c
#  {'charge': 2.0}
#
# FA80ACPHi: h2o_c + ocACP_c --> ACP_c + h_c + octa_c
#  {'charge': 2.0}
#
# FACOAE141: h2o_c + tdecoa_c --> coa_c + h_c + ttdcea_c
#  {'charge': -4.0}
#
# FACOAE1829Z12Z: h2o_c + lnlccoa_c --> coa_c + h_c + lnlc_c
#  {'charge': -4.0}
#
# FACOAE50: h2o_c + ptcoa_c --> coa_c + h_c + pta_c
#  {'charge': -4.0}
#
# FACOAE70: h2o_c + hptcoa_c --> coa_c + h_c + hpta_c
#  {'charge': -3.0}
#
# FACOAE90: h2o_c + nonacoa_c --> coa_c + h_c + nona_c
#  {'charge': -4.0}
#
# FACOAL140_ISO: atp_c + coa_c + fa1_c <=> amp_c + fa1coa_c + ppi_c
#  {'charge': 3.0}
#
# FACOAL141: atp_c + coa_c + ttdcea_c --> amp_c + ppi_c + tdecoa_c
#  {'charge': 4.0}
#
# FACOAL141t2pp: atp_c + coa_c + h_p + ttdcea_p --> amp_c + h_c + ppi_c + tdecoa_c
#  {'charge': 4.0}
#
# FACOAL150_ISO: atp_c + coa_c + fa3_c <=> amp_c + fa3coa_c + ppi_c
#  {'charge': 3.0}
#
# FACOAL150_anteiso: atp_c + coa_c + fa4_c <=> amp_c + fa4coa_c + ppi_c
#  {'charge': 3.0}
#
# FACOAL160_ISO: atp_c + coa_c + fa6_c <=> amp_c + fa6coa_c + ppi_c
#  {'charge': 3.0}
#
# FACOAL170_ISO: atp_c + coa_c + fa11_c <=> amp_c + fa11coa_c + ppi_c
#  {'charge': 3.0}
#
# FACOAL170_anteiso: atp_c + coa_c + fa12_c <=> amp_c + fa12coa_c + ppi_c
#  {'charge': 3.0}
#
# FACOAL180_2: atp_c + coa_c + ocdca_c <=> amp_c + ppi_c + strcoa_c
#  {'charge': 4.0}
#
# FACOAL1812: atp_c + coa_c + vacc_c --> amp_c + ppi_c + vacccoa_c
#  {'charge': 3.0}
#
# FACOAL181d11tpp: atp_c + coa_c + h_p + vacc_p --> amp_c + h_c + ppi_c + vacccoa_c
#  {'charge': 3.0}
#
# FACOAL181d6t2pp: atp_c + coa_c + h_p + ptsla_p --> amp_c + h_c + ppi_c + ptslacoa_c
#  {'charge': 3.0}
#
# FACOAL1821: atp_c + coa_c + lnlc_c --> amp_c + lnlccoa_c + ppi_c
#  {'charge': 4.0}
#
# FACOAL182t2pp: atp_c + coa_c + h_p + lnlc_p --> amp_c + h_c + lnlccoa_c + ppi_c
#  {'charge': 4.0}
#
# FACOAL50i: atp_c + coa_c + pta_c --> amp_c + ppi_c + ptcoa_c
#  {'charge': 4.0}
#
# FACOAL50t2pp: atp_c + coa_c + h_p + pta_p --> amp_c + h_c + ppi_c + ptcoa_c
#  {'charge': 4.0}
#
# FACOAL70t2pp: atp_c + coa_c + h_p + hpta_p --> amp_c + h_c + hptcoa_c + ppi_c
#  {'charge': 3.0}
#
# FACOAL90i: atp_c + coa_c + nona_c --> amp_c + nonacoa_c + ppi_c
#  {'charge': 4.0}
#
# FACOALP50t2pp: atp_c + coa_c + h_p + phept_p --> amp_c + h_c + ppi_c + pptcoa_c
#  {'charge': 3.0}
#
# FACOALP60t2pp: atp_c + coa_c + h_p + phehxa_p --> amp_c + h_c + phxacoa_c + ppi_c
#  {'charge': 3.0}
#
# FACOALP70t2pp: atp_c + coa_c + h_p + phehpa_p --> amp_c + h_c + phpcoa_c + ppi_c
#  {'charge': 3.0}
#
# FACOALP80t2pp: atp_c + coa_c + h_p + pheocta_p --> amp_c + h_c + poctacoa_c + ppi_c
#  {'charge': 3.0}
#
# FACOALPREPH: atp_c + coa_c + prephth_c <=> amp_c + ppi_c + prephthcoa_c
#  {'charge': 3.0}
#
# FACOAL_70_c: atp_c + coa_c + hpta_c --> amp_c + hptcoa_c + ppi_c
#  {'charge': 3.0}
#
# FADE30: 5ohhipcoa_c + fad_c + h_c --> fadh2_c + hipecoa_c
#  {'charge': -1.0}
#
# FASm220: arach_c + 3.0 h_c + mmcoa__S_c + 2.0 nadph_c --> co2_c + coa_c + h2o_c + mbhn_c + 2.0 nadp_c
#  {'charge': 1.0}
#
# FBA: fdp_c <=> dhap_c + g3p_c
#  {'charge': -2.0}
#
# FBA3: s17bp_c <=> dhap_c + e4p_c
#  {'charge': -4.0}
#
# FBACS: 24dab_c + 3hasp__L_c + asp__L_c + gly_c + h_c + n5horn_c + orn_c + ser__L_c --> fbac_kt_c + 6.0 h2o_c
#  {'charge': -1.0}
#
# FBP: fdp_c + h2o_c --> f6p_c + pi_c
#  {'charge': -4.0}
#
# FCLPA: fc1p_c <=> dhap_c + lald__L_c
#  {'charge': -2.0}
#
# FCLT2: fmcbtt_c + ppp9_c --> 2.0 h_c + mcbtt_c + pheme_c
#  {'charge': 2.0}
#
# FDMO2_1: buts_c + fmnRD_c + o2_c --> btal_c + fmn_c + h2o_c + h_c + so3_c
#  {'charge': -1.0}
#
# FDMO7: dmso2_c + 2.0 fmnh2_c + 2.0 o2_c --> fald_c + 2.0 fmn_c + 2.0 h2o_c + 5.0 h_c + mso3_c
#  {'charge': 4.0}
#
# FE3DCITCH: 2.0 cit_c + fe3_c <=> fe3dcit_c
#  {'charge': 3.0}
#
# FE3DCITR5: 2.0 fe3dcit_c + nadph_c --> 4.0 cit_c + 2.0 fe2_c + h_c + nadp_c
#  {'charge': -6.0}
#
# FE3DCITabc: atp_c + fe3dcit_e + h2o_c --> adp_c + 2.0 cit_c + fe3_c + h_c + pi_c
#  {'charge': -3.0}
#
# FE3DCITabcpp: atp_c + fe3dcit_p + h2o_c --> adp_c + 2.0 cit_c + fe3_c + h_c + pi_c
#  {'charge': -3.0}
#
# FE3DHBZS3R: 2.0 fe3dhbzs3_c + nadph_c --> 2.0 23dhbzs3_c + 2.0 fe2_c + 3.0 h_c + nadp_c
#  {'charge': 8.0}
#
# FE3PYOVDL2: fe3_e + pyovd_kt_e <=> fe3pyovd_kt_e
#  {'charge': -3.0}
#
# FEDHBZS3R1: fadh2_c + 2.0 fe3dhbzs3_c --> 2.0 23dhbzs3_c + fad_c + 2.0 fe2_c + 4.0 h_c
#  {'charge': 8.0}
#
# FEDHBZS3R2: 2.0 fe3dhbzs3_c + fmnh2_c --> 2.0 23dhbzs3_c + 2.0 fe2_c + fmn_c + 4.0 h_c
#  {'charge': 8.0}
#
# FEDHBZS3R3: 2.0 fe3dhbzs3_c + rbflvrd_c --> 2.0 23dhbzs3_c + 2.0 fe2_c + 4.0 h_c + ribflv_c
#  {'charge': 8.0}
#
# FEENTERES: feenter_c + h2o_c + h_c --> fe3dhbzs3_c
#  {'charge': -1.0}
#
# FEENTERR1: fadh2_c + 2.0 feenter_c --> 2.0 enter_c + fad_c + 2.0 fe2_c + 2.0 h_c
#  {'charge': 4.0}
#
# FEENTERR2: 2.0 feenter_c + fmnh2_c --> 2.0 enter_c + 2.0 fe2_c + fmn_c + 2.0 h_c
#  {'charge': 4.0}
#
# FEENTERR3: 2.0 feenter_c + rbflvrd_c --> 2.0 enter_c + 2.0 fe2_c + 2.0 h_c + ribflv_c
#  {'charge': 4.0}
#
# FEENTERR4: 2.0 feenter_c + nadph_c --> 2.0 enter_c + 2.0 fe2_c + h_c + nadp_c
#  {'charge': 4.0}
#
# FEOXAMR1: fadh2_c + 2.0 feoxam_c --> fad_c + 2.0 fe2_c + 2.0 feoxam_un_c + 2.0 h_c
#  {'charge': 6.0}
#
# FEOXAMR2: 2.0 feoxam_c + fmnh2_c --> 2.0 fe2_c + 2.0 feoxam_un_c + fmn_c + 2.0 h_c
#  {'charge': 6.0}
#
# FEOXAMR3: 2.0 feoxam_c + rbflvrd_c --> 2.0 fe2_c + 2.0 feoxam_un_c + 2.0 h_c + ribflv_c
#  {'charge': 6.0}
#
# FETRANS: fmcbtt_c <=> fe2_c + mcbtt_c
#  {'charge': 2.0}
#
# FFSD: h2o_c + suc6p_c --> fru_c + g6p_c
#  {'charge': -2.0}
#
# FGFT: fgam_c + 2.0 h_c + thf_c --> gar_c + h2o_c + methf_c
#  {'charge': -2.0}
#
# FPRA: fdxrd_c + h_c + nadp_c --> fdxox_c + nadph_c
#  {'charge': -1.0}
#
# FRUK: atp_c + f1p_c --> adp_c + fdp_c + h_c
#  {'charge': 4.0}
#
# FUCpts: fuc_e + pep_c --> fc1p_c + pyr_c
#  {'charge': 2.0}
#
# G1PACT: accoa_c + gam1p_c --> acgam1p_c + coa_c + h_c
#  {'charge': 2.0}
#
# G3PAT120: ddcaACP_c + glyc3p_c --> 1ddecg3p_c + ACP_c
#  {'charge': 1.0}
#
# G3PAT141: glyc3p_c + tdeACP_c --> 1tdec7eg3p_c + ACP_c
#  {'charge': 2.0}
#
# G3PAT160: glyc3p_c + palmACP_c --> 1hdecg3p_c + ACP_c
#  {'charge': 1.0}
#
# G3PAT161: glyc3p_c + hdeACP_c --> 1hdec9eg3p_c + ACP_c
#  {'charge': 4.0}
#
# G3PAT180: glyc3p_c + ocdcaACP_c --> 1odecg3p_c + ACP_c
#  {'charge': 2.0}
#
# G3PAT181: glyc3p_c + octeACP_c --> 1odec11eg3p_c + ACP_c
#  {'charge': 1.0}
#
# G3POA_BS: 0.07 fa11coa_c + 0.17 fa12coa_c + 0.01 fa1coa_c + 0.2 fa3coa_c + 0.34 fa4coa_c + 0.05 fa6coa_c + glyc3p_c + 0.1 pmtcoa_c + 0.03 strcoa_c + 0.03 tdcoa_c --> 0.01 1ag3p_BS_c + coa_c
#  {'charge': -1.48, 'C': -7.105427357601002e-15, 'N': -8.881784197001252e-16, 'O': -3.552713678800501e-15}
#
# G6PI2_2: g6p_c <=> g6p_A_c
#  {'charge': 2.0}
#
# GADOX: ga_c + o2_c --> 2.0 h_c + omaketo_c
#  {'charge': 3.0}
#
# GALpts: gal_e + pep_c <=> dgal6p_c + pyr_c
#  {'charge': 2.0}
#
# GAPD: g3p_c + nad_c + pi_c <=> 13dpg_c + h_c + nadh_c
#  {'charge': -2.0}
#
# GAPDi_nadp: 13dpg_c + h_c + nadph_c --> g3p_c + nadp_c + pi_c
#  {'charge': 2.0}
#
# GAPP: g3p_c + h2o_c --> glyald_c + pi_c
#  {'charge': -2.0}
#
# GARFT: 10fthf_c + gar_c <=> fgam_c + h_c + thf_c
#  {'charge': 2.0}
#
# GART: atp_c + for_c + gar_c --> adp_c + fgam_c + h_c + pi_c
#  {'charge': 2.0}
#
# GCCa: gly_c + h_c + lpro_c --> alpro_c + co2_c
#  {'charge': -1.0}
#
# GCCb: alpro_c + thf_c --> dhlpro_c + mlthf_c + nh4_c
#  {'charge': 1.0}
#
# GCVHADPr: gcvHL_nhLA_c + nad_c --> gcvHL_ADPr_c + ncam_c
#  {'charge': 1.0}
#
# GCVHRADPr: gcvHL_ADPr_c + h2o_c --> adprib_c + gcvHL_nhLA_c + h_c
#  {'charge': -1.0}
#
# GDPMANNDH: gdpmann_c + h2o_c + 2.0 nad_c --> gdpmanur_c + 3.0 h_c + 2.0 nadh_c
#  {'charge': 3.0}
#
# GDPTPDP: gdptp_c + h2o_c --> gtp_c + ppi_c
#  {'charge': -7.0}
#
# GDTPR: h2o_c + pppgpp_c --> 8.0 h_c + pi_c + ppgpp_c
#  {'charge': 6.0}
#
# GG15DAPAH: ggaptn_c + h2o_c --> 5aptn_c + glu__L_c
#  {'charge': -1.0}
#
# GG15DAPDxr: ggbdapal_c + h2o_c + nad_c <=> ggaptn_c + 2.0 h_c + nadh_c
#  {'charge': 1.0}
#
# GG15DAPO: gg15dap_c + h2o_c + o2_c --> ggbdapal_c + h2o2_c + nh4_c
#  {'charge': 1.0}
#
# GG15DAPS: 15dap_c + atp_c + glu__L_c --> adp_c + gg15dap_c + h_c + pi_c
#  {'charge': -1.0}
#
# GGDAPAH: ggala_B_c + h2o_c --> ala_B_c + glu__L_c
#  {'charge': -1.0}
#
# GGDAPDxr: ggbamppal_c + h2o_c + nad_c <=> ggala_B_c + 2.0 h_c + nadh_c
#  {'charge': 1.0}
#
# GGDAPO: gg13dampp_c + h2o_c + o2_c --> ggbamppal_c + h2o2_c + nh4_c
#  {'charge': 1.0}
#
# GGDAPS: 13dampp_c + atp_c + glu__L_c --> adp_c + gg13dampp_c + h_c + pi_c
#  {'charge': -1.0}
#
# GGLUCT2: gluala_c --> 5oxpro_c + ala__L_c
#  {'charge': -1.0}
#
# GGSPMDO: ggspmd_c + h2o_c + o2_c --> 13dampp_c + ggbutal_c + h2o2_c
#  {'charge': 2.0}
#
# GGSPMDS: atp_c + glu__L_c + spmd_c --> adp_c + ggspmd_c + h_c + pi_c
#  {'charge': -2.0}
#
# GGTT: ggdp_c + ipdp_c --> pendp_c + ppi_c
#  {'charge': 3.0}
#
# GLCADpts: glc__aD_e + pep_c --> g6p_A_c + pyr_c
#  {'charge': 2.0}
#
# GLCURS1: h2o_c + xylan4_c <=> glcur_c + xyl4_c
#  {'charge': -1.0}
#
# GLTPD: galt1p_c + nad_c <=> h_c + nadh_c + tag6p__D_c
#  {'charge': 2.0}
#
# GLUTARH: akg_c + glutar_c + o2_c --> S2hglut_c + co2_c + succ_c
#  {'charge': 2.0}
#
# GLUTRR: glutrna_c + h_c + nadph_c --> glu1sa_c + nadp_c + trnaglu_c
#  {'charge': -3.0}
#
# GLUTRS: atp_c + glu__L_c + trnaglu_c --> amp_c + glutrna_c + ppi_c
#  {'charge': 3.0}
#
# GLUTRS_3: atp_c + glu__L_c + trnaglu_c --> amp_c + glutrna_c + ppi_c
#  {'charge': 3.0}
#
# GLYBCOAT: glybcoa_c + h2o_c --> coa_c + glyb_c + h_c
#  {'charge': -3.0}
#
# GLYCS_I: gthrd_c + mthgxl_c --> lgt_s_c
#  {'charge': 1.0}
#
# GLYCS_II: h2o_c + lgt_s_c --> gthrd_c + h_c + lac__L_c
#  {'charge': -1.0}
#
# GLYCYSAP: gly_cys_c + h2o_c <=> cys__L_c + gly_c + h_c
#  {'charge': 1.0}
#
# GLYCYSabc: atp_c + gly_cys_e + h2o_c --> adp_c + gly_cys_c + pi_c
#  {'charge': -1.0}
#
# GLYLEUAP: gly_leu_c + h2o_c <=> gly_c + h_c + leu__L_c
#  {'charge': 1.0}
#
# GLYLEUtr: atp_c + gly_leu_e + h2o_c --> adp_c + gly_leu_c + pi_c
#  {'charge': -1.0}
#
# GLYPHEAP: gly_phe_c + h2o_c <=> gly_c + h_c + phe__L_c
#  {'charge': 1.0}
#
# GLYPHEtr: atp_c + gly_phe_e + h2o_c --> adp_c + gly_phe_c + pi_c
#  {'charge': -1.0}
#
# GLYTYRAP: gly_tyr_c + h2o_c <=> gly_c + h_c + tyr__L_c
#  {'charge': 1.0}
#
# GLYTYRabc: atp_c + gly_tyr_e + h2o_c --> adp_c + gly_tyr_c + pi_c
#  {'charge': -1.0}
#
# GPDDA4: g3pg_c + h2o_c --> glyc3p_c + glyc_c + h_c
#  {'charge': -1.0}
#
# GTMLT: ala__L_c + gthrd_c --> cgly_c + gluala_c
#  {'charge': 1.0}
#
# GTPDPK: atp_c + gtp_c --> amp_c + gdptp_c + h_c
#  {'charge': 7.0}
#
# GUI1: glcur_c <=> fruur_c
#  {'charge': 1.0}
#
# H2CD: h2isocapcoa_c + h_c --> h2o_c + isocaprecoa_c
#  {'charge': -1.0}
#
# H2CT: coa_c + h2isocap_c --> h2isocapcoa_c + h2o_c
#  {'charge': 4.0}
#
# HACD1_1: aacoa_c + h_c + nadh_c <=> 3hbycoa_c + nad_c
#  {'charge': 4.0}
#
# HACD3: 3oocoa_c + h_c + nadh_c <=> 3hocoa_c + nad_c
#  {'charge': 4.0}
#
# HACD3i: 3hocoa_c + nad_c --> 3oocoa_c + h_c + nadh_c
#  {'charge': -4.0}
#
# HACD8: 3ohodcoa_c + h_c + nadh_c <=> 3hodcoa_c + nad_c
#  {'charge': 4.0}
#
# HACD8i: 3hodcoa_c + nad_c --> 3ohodcoa_c + h_c + nadh_c
#  {'charge': -4.0}
#
# HACD9: 3hmbcoa_c + nad_c <=> 2maacoa_c + h_c + nadh_c
#  {'charge': 4.0}
#
# HACOADr: 3hmp_c + nad_c --> h_c + mmalsa__S_c + nadh_c
#  {'charge': 1.0}
#
# HBCE: 3hbcoa_c <=> 3hbcoa__R_c
#  {'charge': 4.0}
#
# HBCHLR: 3hbcoa__R_c <=> b2coa_c + h2o_c
#  {'charge': -4.0}
#
# HBRCH: 3hbcoa__R_c + h2o_c --> bhb_c + coa_c + h_c
#  {'charge': -4.0}
#
# HEMEOS: frdp_c + h2o_c + pheme_c --> hemeO_c + ppi_c
#  {'charge': 2.0}
#
# HEX4: atp_c + man_c --> adp_c + h_c + man6p_c
#  {'charge': 2.0}
#
# HEXTT: hexdp_c + ipdp_c --> hepdp_c + ppi_c
#  {'charge': 3.0}
#
# HIAA: h2o_c + hipocoa_c --> accoa_c + hia_c
#  {'charge': -4.0}
#
# HISTDa: histd_c + nad_c <=> h_c + histda_c + nadh_c
#  {'charge': -1.0}
#
# HISTDb: h2o_c + histda_c + nad_c --> 2.0 h_c + his__L_c + nadh_c
#  {'charge': 1.0}
#
# HIUH_c: 5hiu_c + h2o_c <=> 5houdic_c
#  {'charge': -1.0}
#
# HKNDDH: h2o_c + hkndd_c --> h_c + op4en_c + succ_c
#  {'charge': 1.0}
#
# HKNTDH: h2o_c + hkntd_c --> fum_c + h_c + op4en_c
#  {'charge': -1.0}
#
# HMEDR: 2.0 h_c + hmbpp_c + nadh_c --> h2o_c + ipdp_c + nad_c
#  {'charge': -4.0}
#
# HMEDS: 2mecdp_c + 2.0 fdxrd_c --> 2.0 fdxox_c + h2o_c + hmbpp_c
#  {'charge': 4.0}
#
# HMR_0260: h2o_c + vacccoa_c --> coa_c + h_c + vacc_c
#  {'charge': -3.0}
#
# HMR_6515: mercppyr_c + so3_c --> pyr_c + tsul_c
#  {'charge': 2.0}
#
# HOPNTAL2: 4hoxoh_c --> ppal_c + pyr_c
#  {'charge': -1.0}
#
# HSAE: h2o_c + hhd_c --> 4hoxoh_c + h_c
#  {'charge': 1.0}
#
# ICCT: h2o_c + isocapcoa_c --> coa_c + h_c + isocap_c
#  {'charge': -3.0}
#
# ICHORT: h2o_c + ichor_c --> 23ddhb_c + pyr_c
#  {'charge': 1.0}
#
# ILEDHr: h2o_c + ile__L_c + nad_c <=> 2o3mpt_c + h_c + nadh_c + nh4_c
#  {'charge': 1.0}
#
# KARA2: 2ahbut_c + h_c + nadph_c <=> 23dhmp_c + nadp_c
#  {'charge': -1.0}
#
# KAS1: 14.0 h_c + ibcoa_c + 5.0 malcoa_c + 10.0 nadph_c --> 5.0 co2_c + 6.0 coa_c + fa1_c + 4.0 h2o_c + 10.0 nadp_c
#  {'charge': 1.0}
#
# KAS11: 17.0 h_c + ivcoa_c + 6.0 malcoa_c + 12.0 nadph_c --> 6.0 co2_c + 7.0 coa_c + fa11_c + 5.0 h2o_c + 12.0 nadp_c
#  {'charge': 1.0}
#
# KAS12: 2mbcoa_c + 17.0 h_c + 6.0 malcoa_c + 12.0 nadph_c --> 6.0 co2_c + 7.0 coa_c + fa12_c + 5.0 h2o_c + 12.0 nadp_c
#  {'charge': 1.0}
#
# KAS3: 14.0 h_c + ivcoa_c + 5.0 malcoa_c + 10.0 nadph_c --> 5.0 co2_c + 6.0 coa_c + fa3_c + 4.0 h2o_c + 10.0 nadp_c
#  {'charge': 1.0}
#
# KAS4: 2mbcoa_c + 14.0 h_c + 5.0 malcoa_c + 10.0 nadph_c --> 5.0 co2_c + 6.0 coa_c + fa4_c + 4.0 h2o_c + 10.0 nadp_c
#  {'charge': 1.0}
#
# KAS6: 17.0 h_c + ibcoa_c + 6.0 malcoa_c + 12.0 nadph_c --> 6.0 co2_c + 7.0 coa_c + fa6_c + 5.0 h2o_c + 12.0 nadp_c
#  {'charge': 1.0}
#
# KAT18: 3opbcoa_c + coa_c --> accoa_c + phaccoa_c
#  {'charge': -4.0}
#
# KAT20: 3ovacccoa_c + coa_c --> accoa_c + hdcoa_c
#  {'charge': -4.0}
#
# KAT33: 3oxptcoa_c + coa_c --> accoa_c + ppcoa_c
#  {'charge': -4.0}
#
# LEVUACOAL: 4oxptn_c + atp_c + coa_c --> 4oxptcoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# LIPO1S24_BS: 2400.0 cdpglyc_c + d12dg_BS_c + 2400.0 udpg_c --> 2400.0 cmp_c + 4800.0 h_c + lipo1_24_BS_c + 2400.0 udp_c
#  {'charge': 2400.0}
#
# LIPO2S24_BS: 2400.0 cdpglyc_c + d12dg_BS_c + 2400.0 uacgam_c --> 2400.0 cmp_c + 4800.0 h_c + lipo2_24_BS_c + 2400.0 udp_c
#  {'charge': 2400.0}
#
# LIPO3S24_BS: 2400.0 ala__D_c + 2400.0 atp_c + 2400.0 cdpglyc_c + d12dg_BS_c + 2400.0 h2o_c --> 2400.0 amp_c + 2400.0 cmp_c + 4800.0 h_c + lipo3_24_BS_c + 2400.0 ppi_c
#  {'charge': 2400.0}
#
# LIPO4S24_BS: 2400.0 cdpglyc_c + d12dg_BS_c --> 2400.0 cmp_c + 2400.0 h_c + lipo4_24_BS_c
#  {'charge': 2400.0}
#
# LPLIPAL1G160pp: 1agpg160_p + h2o_p --> g3pg_p + h_p + hdca_p
#  {'charge': 1.0}
#
# LPLIPAL2A120: 2ddecg3p_c + h2o_c --> ddca_c + glyc3p_c + 2.0 h_c
#  {'charge': -1.0}
#
# LPLIPAL2A141: 2tdec7eg3p_c + h2o_c --> glyc3p_c + 2.0 h_c + ttdcea_c
#  {'charge': -1.0}
#
# LPLIPAL2A160: 2hdecg3p_c + h2o_c --> glyc3p_c + 2.0 h_c + hdca_c
#  {'charge': -1.0}
#
# LPLIPAL2A161: 2hdec9eg3p_c + h2o_c --> glyc3p_c + 2.0 h_c + hdcea_c
#  {'charge': -1.0}
#
# LPLIPAL2A181: 2odec11eg3p_c + h2o_c --> glyc3p_c + 2.0 h_c + ocdcea_c
#  {'charge': -1.0}
#
# LPLIPAL2G141: 2agpg141_c + h2o_c --> g3pg_c + h_c + ttdcea_c
#  {'charge': 1.0}
#
# LPLIPAL2G160: 2agpg160_c + h2o_c --> g3pg_c + h_c + hdca_c
#  {'charge': 1.0}
#
# LPLIPAL2G181: 2agpg181_c + h2o_c --> g3pg_c + h_c + ocdcea_c
#  {'charge': 1.0}
#
# L_LACD: 2.0 ficytc_c + lac__L_c --> 2.0 focytc_c + pyr_c
#  {'charge': 4.0}
#
# MACCOAT: 2maacoa_c + coa_c --> accoa_c + ppcoa_c
#  {'charge': -4.0}
#
# MAK: atp_c + malt_c <=> adp_c + h_c + malt1p_c
#  {'charge': 2.0}
#
# MALTT: 2.0 malt1p_c --> glyg4n_c + 2.0 pi_c
#  {'charge': -4.0}
#
# MAN1PT: gtp_c + h_c + man1p_c --> gdpmann_c + ppi_c
#  {'charge': -2.0}
#
# MAN1PT2: gdp_c + h_c + man1p_c --> gdpmann_c + pi_c
#  {'charge': -2.0}
#
# MAN6PI: man6p_c <=> f6p_c
#  {'charge': -2.0}
#
# MANAO: mana_c + nad_c <=> fruur_c + h_c + nadh_c
#  {'charge': 1.0}
#
# MANpts: man_e + pep_c --> man6p_c + pyr_c
#  {'charge': 2.0}
#
# MANptspp: man_p + pep_c --> man6p_c + pyr_c
#  {'charge': 2.0}
#
# MCBTS3: atp_c + bhb_c + 2.0 lys__L_c + 2.0 nadp_c + 3.5 o2_c + occoa_c + salc_c + ser__L_c --> adp_c + cmcbtt_c + co2_c + coa_c + 5.0 h2o_c + 2.0 h_c + 2.0 nadph_c + pi_c
#  {'charge': -2.0}
#
# MCCC: 3mb2coa_c + atp_c + hco3_c --> 3mgcoa_c + adp_c + h_c + pi_c
#  {'charge': 5.0}
#
# MCTP1App: murein5p5p_p --> ala__D_p + murein5px4p_p
#  {'charge': 4.0}
#
# MCTP2App: murein5p5p5p_p --> 2.0 ala__D_p + murein5px4px4p_p
#  {'charge': 6.0}
#
# MDDCP2pp: h2o_p + murein5px4px4p_p --> ala__D_p + murein4px4px4p_p
#  {'charge': -6.0}
#
# MDDEP1pp: h2o_p + murein4px4p_p --> murein4p4p_p
#  {'charge': -4.0}
#
# MDDEP3pp: h2o_p + murein5px4p_p --> murein5p4p_p
#  {'charge': -4.0}
#
# MECDPDH4E: 2mecdp_c + fdxrd_c + h_c <=> fdxo_2_2_c + h2mb4p_c + h2o_c
#  {'charge': -1.0}
#
# MEPCT: 2me4p_c + ctp_c + h_c --> 4c2me_c + ppi_c
#  {'charge': -2.0}
#
# MGCH: 3mgcoa_c + h2o_c <=> hmgcoa_c
#  {'charge': -5.0}
#
# MHPGLUT: hcys__L_c + mhpglu_c --> hpglu_c + met__L_c
#  {'charge': -4.0}
#
# MHPGLUT2: ahcys_c + h_c + mhpglu_c <=> amet_c + hpglu_c
#  {'charge': -4.0}
#
# MI3PP: h2o_c + mi3p__D_c --> inost_c + pi_c
#  {'charge': -2.0}
#
# MI3PS: g6p_c <=> mi3p__D_c
#  {'charge': 2.0}
#
# MLTGY2pp: murein4p3p_p --> anhgm3p_p + anhgm4p_p
#  {'charge': 2.0}
#
# MLTGY3pp: murein3p3p_p --> 2.0 anhgm3p_p
#  {'charge': 4.0}
#
# MLTGY4pp: murein4px4p4p_p --> anhgm4p_p + murein4px4p_p
#  {'charge': 4.0}
#
# MN6PP: h2o_c + man6p_c --> man_c + pi_c
#  {'charge': -2.0}
#
# MPTG: 2.0 uaagmda_c --> 2.0 h_c + murein5p5p_p + 2.0 udcpdp_c
#  {'charge': -2.0}
#
# MPTG2: murein5p5p_p + uaagmda_c --> h_c + murein5p5p5p_p + udcpdp_c
#  {'charge': -1.0}
#
# MSHAMID: bmnmsh_c + h2o_c --> acysbmn_c + igam_c
#  {'charge': 1.0}
#
# MUCCYCI: ccmuac_c + h_c <=> mucl_c
#  {'charge': -1.0}
#
# MUCCY_kt: CCbuttc_c + h_c --> 4cml_c
#  {'charge': 2.0}
#
# MUCLI: mucl_c <=> 5odhf2a_c
#  {'charge': -1.0}
#
# NADHHR: h2o_c + nadh_c --> nadhx__R_c
#  {'charge': 2.0}
#
# NADHXD: adp_c + nadhx__S_c --> amp_c + h_c + nadh_c + pi_c
#  {'charge': -2.0}
#
# NADPHHR: h2o_c + nadph_c --> nadphx__R_c
#  {'charge': 4.0}
#
# NADPHXD: adp_c + nadphx__S_c --> amp_c + h_c + nadph_c + pi_c
#  {'charge': -4.0}
#
# NMO: etha_c + fmnh2_c + o2_c --> acald_c + fmn_c + 6.0 h_c + no2_c
#  {'charge': 4.0}
#
# NMTHDA: atp_c + 2.0 h2o_c + mthd_c --> Ncarbsar_c + adp_c + 2.0 h_c + pi_c
#  {'charge': 1.0}
#
# NPHS: sbzcoa_c --> coa_c + dhna_c
#  {'charge': -5.0}
#
# NPHSa: h_c + sbzcoa_c --> 14dh2napcoa_c + h2o_c
#  {'charge': -1.0}
#
# NPHSb: 14dh2napcoa_c + h2o_c --> coa_c + dhna_c + h_c
#  {'charge': -4.0}
#
# NTPTP1: dgtp_c + h2o_c --> dgsn_c + pppi_c
#  {'charge': 4.0}
#
# NTPTP2: gtp_c + h2o_c --> gsn_c + pppi_c
#  {'charge': 4.0}
#
# OCAALD: oca_c --> oaa_c + pyr_c
#  {'charge': -3.0}
#
# OCOAT4: dhcrn_c + succoa_c --> dhcrncoa_c + succ_c
#  {'charge': 3.0}
#
# OP4ENH: h2o_c + op4en_c --> 4h2opntn_c
#  {'charge': -1.0}
#
# OPETDC: 5cohe_c + h_c --> 2hh24dd_c + co2_c
#  {'charge': -1.0}
#
# OPP: hepdp_c + ipdp_c --> octdp_c + ppi_c
#  {'charge': -3.0}
#
# OPTCCL: 5cohe_c + h_c --> 2hh24dd_c + co2_c
#  {'charge': -1.0}
#
# OXCOAHDH: 2oxpaccoa_c + 2.0 h2o_c + nadp_c --> 3oxdhscoa_c + 2.0 h_c + nadph_c
#  {'charge': 1.0}
#
# PACPT_1: coa_c + ppad_c <=> amp_c + ppcoa_c
#  {'charge': -2.0}
#
# PALDH: Pald_c + h2o_c --> acald_c + pi_c
#  {'charge': -2.0}
#
# PALGSKT: 5.0 gdpmanur_c + h2o_c --> 5.0 gdp_c + 5.0 h_p + prealginate__M_p
#  {'charge': -10.0}
#
# PAPA140pp: h2o_p + pa140_p --> 12dgr140_p + pi_p
#  {'charge': -2.0}
#
# PAPPT3: udcpp_c + ugmda_c --> uagmda_c + ump_c
#  {'charge': 3.0}
#
# PAP_BS: 0.01 12dag3p_BS_c + h2o_c --> 0.01 12dgr_BS_c + pi_c
#  {'charge': -2.0}
#
# PDBL_4: dhap_c + gln__L_c + r5p_c --> glu__L_c + 3.0 h2o_c + h_c + pi_c + pydx5p_c
#  {'charge': -2.0}
#
# PDIMAS: 2.0 h_c + phthiocerol_c + 2.0 tamocta_c --> 2.0 h2o_c + pdima_c
#  {'charge': -2.0}
#
# PFK: atp_c + f6p_c --> adp_c + fdp_c + h_c
#  {'charge': 4.0}
#
# PFK_2: atp_c + tag6p__D_c --> adp_c + h_c + tagdp__D_c
#  {'charge': 2.0}
#
# PGPP120pp: h2o_p + pgp120_p --> pg120_p + pi_p
#  {'charge': -2.0}
#
# PGPP140pp: h2o_p + pgp140_p --> pg140_p + pi_p
#  {'charge': -3.0}
#
# PGPP141pp: h2o_p + pgp141_p --> pg141_p + pi_p
#  {'charge': -3.0}
#
# PGPP160: h2o_c + pgp160_c --> pg160_c + pi_c
#  {'charge': -2.0}
#
# PGPP160pp: h2o_p + pgp160_p --> pg160_p + pi_p
#  {'charge': -2.0}
#
# PGPP161pp: h2o_p + pgp161_p --> pg161_p + pi_p
#  {'charge': -3.0}
#
# PGPP180pp: h2o_p + pgp180_p --> pg180_p + pi_p
#  {'charge': -2.0}
#
# PGPP181pp: h2o_p + pgp181_p --> pg181_p + pi_p
#  {'charge': -3.0}
#
# PGSA120: cdpdddecg_c + glyc3p_c --> cmp_c + h_c + pgp120_c
#  {'charge': 3.0}
#
# PGSA140: cdpdtdecg_c + glyc3p_c --> cmp_c + h_c + pgp140_c
#  {'charge': 3.0}
#
# PGSA141: cdpdtdec7eg_c + glyc3p_c --> cmp_c + h_c + pgp141_c
#  {'charge': 3.0}
#
# PGSA160: cdpdhdecg_c + glyc3p_c --> cmp_c + h_c + pgp160_c
#  {'charge': 3.0}
#
# PGSA161: cdpdhdec9eg_c + glyc3p_c --> cmp_c + h_c + pgp161_c
#  {'charge': 3.0}
#
# PGSA180: cdpdodecg_c + glyc3p_c --> cmp_c + h_c + pgp180_c
#  {'charge': 3.0}
#
# PGSA181: cdpdodec11eg_c + glyc3p_c --> cmp_c + h_c + pgp181_c
#  {'charge': 3.0}
#
# PHACOAOR: h2_c + o2_c + phaccoa_c --> 2dhphaccoa_c
#  {'charge': 4.0}
#
# PHER: phe__L_c <=> 2.0 h_c + phe__D_c
#  {'charge': 2.0}
#
# PHET: fad_c + h2o_c + 2.0 h_c + phe__D_c --> fadh2_c + nh4_c + phpyr_c
#  {'charge': -2.0}
#
# PHTHDLS: h_c + prephth_c --> co2_c + phthdl_c
#  {'charge': -1.0}
#
# PKETX: pi_c + xu5p__D_c --> actp_c + g3p_c + h2o_c
#  {'charge': 2.0}
#
# PLCD: h2o_c + ptd1ino160_c --> 12dgr160_c + h_c + mi1p__D_c
#  {'charge': -1.0}
#
# PLIPA1A120pp: h2o_p + pa120_p --> 2ddecg3p_p + ddca_p
#  {'charge': -1.0}
#
# PLIPA1A141pp: h2o_p + pa141_p --> 2tdec7eg3p_p + ttdcea_p
#  {'charge': -1.0}
#
# PLIPA1A160pp: h2o_p + pa160_p --> 2hdecg3p_p + hdca_p
#  {'charge': 1.0}
#
# PLIPA1A161pp: h2o_p + pa161_p --> 2hdec9eg3p_p + hdcea_p
#  {'charge': -1.0}
#
# PLIPA1A181pp: h2o_p + pa181_p --> 2odec11eg3p_p + ocdcea_p
#  {'charge': -1.0}
#
# PLIPA1E181d11pp: h2o_p + pe181_p --> 2agpe181_p + h_p + vacc_p
#  {'charge': 1.0}
#
# PLIPA1G160pp: h2o_p + pg160_p --> 2agpg160_p + h_p + hdca_p
#  {'charge': -1.0}
#
# PLIPA1G161pp: h2o_p + pg161_p --> 2agpg161_p + h_p + hdcea_p
#  {'charge': 1.0}
#
# PLIPA1G181d11pp: h2o_p + pg181_p --> 2agpg181_p + h_p + vacc_p
#  {'charge': 1.0}
#
# PLIPA2A180pp: h2o_p + pa180_p --> 1odecg3p_p + h_p + ocdca_p
#  {'charge': -2.0}
#
# PLIPA2G160pp: h2o_p + pg160_p --> 1agpg160_p + h_p + hdca_p
#  {'charge': -1.0}
#
# PLPS: g3p_c + gln__L_c + r5p_c --> glu__L_c + 3.0 h2o_c + h_c + pi_c + pydx5p_c
#  {'charge': -4.0}
#
# PPA2: h2o_c + pppi_c --> h_c + pi_c + ppi_c
#  {'charge': -4.0}
#
# PPGPPDP: h2o_c + ppgpp_c --> gdp_c + ppi_c
#  {'charge': -6.0}
#
# PPK2: atp_c + ppi_c --> adp_c + pppi_c
#  {'charge': 4.0}
#
# PPM2: 2dr1p_c <=> 2dr5p_c
#  {'charge': -2.0}
#
# PPND: nad_c + pphn_c --> 34hpp_c + co2_c + nadh_c
#  {'charge': -2.0}
#
# PPNDH: h_c + pphn_c --> co2_c + h2o_c + phpyr_c
#  {'charge': -2.0}
#
# PPTGS_BS: uaagmda_c --> h_c + peptido_BS_c + udcpdp_c
#  {'charge': 1.0}
#
# PPTT: ipdp_c + pendp_c --> hexdp_c + ppi_c
#  {'charge': -3.0}
#
# PRAMPC: h2o_c + prbamp_c --> prfp_c
#  {'charge': -4.0}
#
# PRASCSi: 5aizc_c + asp__L_c + atp_c --> 25aics_c + adp_c + h_c + pi_c
#  {'charge': -3.0}
#
# PRATPP: h2o_c + prbatp_c --> h_c + ppi_c + prbamp_c
#  {'charge': -2.0}
#
# PREPHACPH: h2o_c + prephthACP_c --> ACP_c + h_c + prephth_c
#  {'charge': 2.0}
#
# PREPTHS: arachACP_c + 13.0 h_c + 2.0 malcoa_c + 2.0 mmcoa__S_c + 10.0 nadph_c --> 2.0 co2_c + 4.0 coa_c + 5.0 h2o_c + 10.0 nadp_c + prephthACP_c
#  {'charge': 1.0}
#
# PREPTTA: ACP_c + prephthcoa_c <=> coa_c + prephthACP_c
#  {'charge': -5.0}
#
# PROR: pro__L_c <=> h_c + pro__D_c
#  {'charge': 1.0}
#
# PRPPS: atp_c + r5p_c <=> amp_c + h_c + prpp_c
#  {'charge': -2.0}
#
# PSD120: h_c + ps120_c --> co2_c + pe120_c
#  {'charge': -1.0}
#
# PSD141: h_c + ps141_c --> co2_c + pe141_c
#  {'charge': -1.0}
#
# PSD160: h_c + ps160_c --> co2_c + pe160_c
#  {'charge': -1.0}
#
# PSD180: h_c + ps180_c --> co2_c + pe180_c
#  {'charge': -1.0}
#
# PSD181: h_c + ps181_c --> co2_c + pe181_c
#  {'charge': -1.0}
#
# PSSA120: cdpdddecg_c + ser__L_c --> cmp_c + h_c + ps120_c
#  {'charge': 1.0}
#
# PSSA141: cdpdtdec7eg_c + ser__L_c --> cmp_c + h_c + ps141_c
#  {'charge': 1.0}
#
# PSSA160: cdpdhdecg_c + ser__L_c --> cmp_c + h_c + ps160_c
#  {'charge': 1.0}
#
# PSSA180: cdpdodecg_c + ser__L_c --> cmp_c + h_c + ps180_c
#  {'charge': 1.0}
#
# PSSA181: cdpdodec11eg_c + ser__L_c --> cmp_c + h_c + ps181_c
#  {'charge': 1.0}
#
# PSUDS: r5p_c + ura_c --> h2o_c + psd5p_c
#  {'charge': -2.0}
#
# PUNP2: dad_2_c + pi_c <=> 2dr1p_c + ade_c
#  {'charge': 2.0}
#
# PUNP6: din_c + pi_c <=> 2dr1p_c + hxan_c
#  {'charge': 2.0}
#
# PYDXS: g3p_c + gln__L_c + ru5p__D_c <=> glu__L_c + 3.0 h2o_c + h_c + pi_c + pydx5p_c
#  {'charge': -2.0}
#
# R5PP: h2o_c + r5p_c --> pi_c + rib__D_c
#  {'charge': -2.0}
#
# RBFK: atp_c + ribflv_c --> adp_c + fmn_c + h_c
#  {'charge': 2.0}
#
# RBFSa: 4r5au_c + db4p_c --> dmlz_c + 2.0 h2o_c + pi_c
#  {'charge': -2.0}
#
# RBK: atp_c + rib__D_c --> adp_c + h_c + r5p_c
#  {'charge': 2.0}
#
# RECOAH2: R_3hhcoa_c <=> h2o_c + hx2coa_c
#  {'charge': -4.0}
#
# RECOAH4: R_3hdcoa_c <=> dc2coa_c + h2o_c
#  {'charge': -4.0}
#
# RECOAH6: R_3hmrscoa_c <=> h2o_c + td2coa_c
#  {'charge': 4.0}
#
# RECOAH7: R_3hhdcoa_c <=> h2o_c + hdd2coa_c
#  {'charge': -4.0}
#
# REPHACCOAI: rephaccoa_c <=> 2oxpaccoa_c
#  {'charge': 4.0}
#
# RHACOAE100: R_3hdcoa_c + h2o_c --> R_3hdcaa_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAE120: R_3hddcoa_c + h2o_c --> R_3hdda_c + coa_c + h_c
#  {'charge': 1.0}
#
# RHACOAE121: R_3hcddec5ecoa_c + h2o_c --> R_3hdd5ea_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAE121d6: R_3hdd6coa_c + h2o_c --> R_3hdd6e_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAE140: R_3hmrscoa_c + h2o_c --> R_3httdca_c + coa_c + h_c
#  {'charge': 1.0}
#
# RHACOAE141: R_3hcmrs7ecoa_c + h2o_c --> R_3hcmrs7e_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAE141d5: R_3htd5coa_c + h2o_c --> R_3htd5e_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAE142: R_3htd58coa_c + h2o_c --> R_3htd58e_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAE160: R_3hhdcoa_c + h2o_c --> R_3hhdca_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAE50: R_3hptcoa_c + h2o_c --> R_3hpt_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAE60: R_3hhcoa_c + h2o_c --> R_3hhxa_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAE70: R_3hhpcoa_c + h2o_c --> R_3hhpa_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAE80: R_3hocoa_c + h2o_c --> R_3hocta_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAE90: R_3hnonacoa_c + h2o_c --> R_3hnonaa_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAEP100: R_3hpdecacoa_c + h2o_c --> R_3hpdeca_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAEP101: R3hdec4coa_c + h2o_c --> R3hdec4e_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAEP40: R_3hpbcoa_c + h2o_c --> R_3hpba_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAEP50: R_3hpptcoa_c + h2o_c --> R_3hppta_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAEP60: R_3hphxacoa_c + h2o_c --> R_3hphxa_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAEP70: R_3hphpcoa_c + h2o_c --> R_3hphpa_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAEP80: R_3hpoctacoa_c + h2o_c --> R_3hpocta_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAEP90: R_3hpnonacoa_c + h2o_c --> R_3hpnona_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAET40: R_3h4atbcoa_c + h2o_c --> R_3h4atba_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAET60: R_3h6athcoa_c + h2o_c --> R_3h6atha_c + coa_c + h_c
#  {'charge': -3.0}
#
# RMK: atp_c + rml_c --> adp_c + h_c + rml1p_c
#  {'charge': 2.0}
#
# RMPA: rml1p_c <=> dhap_c + lald__L_c
#  {'charge': -2.0}
#
# RPI: r5p_c <=> ru5p__D_c
#  {'charge': -2.0}
#
# RU5PS: fald_c + ru5p__D_c <-- ah6p__D_c
#  {'charge': 2.0}
#
# SALCHS4FER1: fadh2_c + 2.0 salchs4fe_c --> fad_c + 2.0 fe2_c + 4.0 h_c + 2.0 salchs4_c
#  {'charge': 8.0}
#
# SALCHS4FEabcpp: atp_c + h2o_c + salchs4fe_p --> adp_c + pi_c + salchs4fe_c
#  {'charge': -1.0}
#
# SALCOD: 2.0 h_c + nadh_c + o2_c + salc_c --> catechol_c + co2_c + h2o_c + nad_c
#  {'charge': -1.0}
#
# SBTPD: nad_c + sbt6p_c <=> f6p_c + h_c + nadh_c
#  {'charge': -2.0}
#
# SBTpts: pep_c + sbt__D_e --> pyr_c + sbt6p_c
#  {'charge': 2.0}
#
# SCYSSL: 2.0 gthrd_c + scys__L_c --> cys__L_c + gthox_c + h_c + so3_c
#  {'charge': -1.0}
#
# SELADT: atp_c + h_c + sel_c --> adsel_c + ppi_c
#  {'charge': 2.0}
#
# SEPHCHCS: akg_c + h_c + ichor_c --> 2sephchc_c + co2_c
#  {'charge': 3.0}
#
# SHCHCS3: 2sephchc_c --> 2shchc_c + pyr_c
#  {'charge': -1.0}
#
# SHCHF: fe2_c + scl_c --> 3.0 h_c + sheme_c
#  {'charge': -7.0}
#
# SHGO: S2hglut_c + o2_c --> akg_c + h2o2_c
#  {'charge': -2.0}
#
# SMIA1: fe2_e + stfrnA_e <=> istfrnA_e
#  {'charge': -2.0}
#
# SMIA1abc: atp_c + h2o_c + istfrnB_e --> adp_c + fe2_c + h_c + pi_c + stfrnB_c
#  {'charge': 2.0}
#
# SMIA2abc: atp_c + h2o_c + istfrnA_e --> adp_c + fe2_c + h_c + pi_c + stfrnA_c
#  {'charge': 2.0}
#
# SMIB1: fe2_e + stfrnB_e <=> istfrnB_e
#  {'charge': -2.0}
#
# SPMS: ametam_c + ptrc_c --> 5mta_c + h_c + spmd_c
#  {'charge': 2.0}
#
# SUCBZL: atp_c + coa_c + sucbz_c --> amp_c + ppi_c + sbzcoa_c
#  {'charge': 5.0}
#
# SUCBZS: 2shchc_c --> h2o_c + sucbz_c
#  {'charge': -2.0}
#
# SUCpts: pep_c + sucr_e --> pyr_c + suc6p_c
#  {'charge': 2.0}
#
# SUCptspp: pep_c + sucr_p --> pyr_c + suc6p_c
#  {'charge': 2.0}
#
# TALA: g3p_c + s7p_c <=> e4p_c + f6p_c
#  {'charge': -2.0}
#
# TECA1S45: 45.0 cdpglyc_c + uacgam_c + uacmam_c --> 45.0 cmp_c + gtca1_45_BS_c + 46.0 h_c + udp_c + ump_c
#  {'charge': 45.0}
#
# TECA2S45: 45.0 ala__D_c + 45.0 atp_c + 45.0 cdpglyc_c + 45.0 h2o_c + uacgam_c + uacmam_c --> 45.0 amp_c + 45.0 cmp_c + gtca2_45_BS_c + 91.0 h_c + 45.0 ppi_c + udp_c + ump_c
#  {'charge': 45.0}
#
# TECA3S45: 45.0 cdpglyc_c + h2o_c + uacgam_c + uacmam_c + 45.0 udpg_c --> 45.0 cmp_c + gtca3_45_BS_c + 91.0 h_c + 46.0 udp_c + ump_c
#  {'charge': 45.0}
#
# TETDHpp1: mql8_c + tet_p --> 2.0 h_p + mqn8_c + 2.0 tsul_p
#  {'charge': 4.0}
#
# TETDHpp2: 2dmmql8_c + tet_p --> 2dmmq8_c + 2.0 h_p + 2.0 tsul_p
#  {'charge': 4.0}
#
# TETDHpp3: q8h2_c + tet_p --> 2.0 h_p + q8_c + 2.0 tsul_p
#  {'charge': 4.0}
#
# TGBPA: tagdp__D_c <=> dhap_c + g3p_c
#  {'charge': -2.0}
#
# THZSN_1: cys__L_c + dxyl_c + fdxo_2_2_c + tyr__L_c --> 4hba_c + 4mhetz_c + co2_c + fdxrd_c + h2o_c + 2.0 h_c + nh4_c + pyr_c
#  {'charge': 1.0}
#
# TKT2: e4p_c + xu5p__D_c <=> f6p_c + g3p_c
#  {'charge': 2.0}
#
# TMDPP: pi_c + thymd_c <=> 2dr1p_c + thym_c
#  {'charge': 2.0}
#
# TNTHAC1: 4hadnt_c + tntmdh_c --> 35dnta_c + h2o_c + no2_c
#  {'charge': -1.0}
#
# TNTHAC2: 2hadnt_c + tntmdh_c --> 2m35mdntha_c + h2o_c + no2_c
#  {'charge': -1.0}
#
# TNTR1: h_c + 2.0 nadph_c + tnt_c --> 4hadnt_c + h2o_c + 2.0 nadp_c
#  {'charge': 1.0}
#
# TNTR1x: h_c + 2.0 nadh_c + tnt_c --> 4hadnt_c + h2o_c + 2.0 nad_c
#  {'charge': 1.0}
#
# TNTR2: h_c + 2.0 nadph_c + tnt_c --> 2hadnt_c + h2o_c + 2.0 nadp_c
#  {'charge': 1.0}
#
# TNTR2x: h_c + 2.0 nadh_c + tnt_c --> 2hadnt_c + h2o_c + 2.0 nad_c
#  {'charge': 1.0}
#
# TPI: dhap_c <=> g3p_c
#  {'charge': 2.0}
#
# TRPS1: 3ig3p_c + ser__L_c --> g3p_c + h2o_c + trp__L_c
#  {'charge': 2.0}
#
# TRPS3: 3ig3p_c --> g3p_c + indole_c
#  {'charge': 2.0}
#
# TTONR2pp: q8h2_c + tton_e --> 4.0 h_c + q8_c + so3_e + tsul_e
#  {'charge': 2.0}
#
# UAGDP: acgam1p_c + h_c + utp_c --> ppi_c + uacgam_c
#  {'charge': -2.0}
#
# UAMAS: ala__L_c + atp_c + uamr_c --> adp_c + h_c + pi_c + uama_c
#  {'charge': -3.0}
#
# UAPGR: h_c + nadph_c + uaccg_c --> nadp_c + uamr_c
#  {'charge': 3.0}
#
# UDCPDP: h2o_c + udcpdp_c --> h_c + pi_c + udcpp_c
#  {'charge': -2.0}
#
# UM3PL: LalaDgluMdap_c + atp_c + uamr_c --> adp_c + h_c + pi_c + ugmd_c
#  {'charge': -3.0}
#
# UM4PL: LalaDgluMdapDala_c + atp_c + uamr_c --> adp_c + h_c + pi_c + um4p_c
#  {'charge': -3.0}
#
# UPP3MT: 2.0 amet_c + uppg3_c --> 2.0 ahcys_c + dscl_c + h_c
#  {'charge': 7.0}
#
# URO_c: h2o_c + o2_c + urate_c --> 5hiu_c + h2o2_c + h_c
#  {'charge': 1.0}
#
# VCACT: accoa_c + ppcoa_c <=> 3optcoa_c + coa_c
#  {'charge': 4.0}
#
# YUMPS: r5p_c + ura_c <=> h2o_c + psd5p_c
#  {'charge': -2.0}
#
# ilvg: 2obut_c + hethmpp_c --> 2ahbut_c + thmpp_c
#  {'charge': -1.0}
#
# GUADEM: guaiacol_c + nadph_c + o2_c --> catechol_c + fald_c + h2o_c + nadp_c
#  {'charge': 1.0, 'H': 1.0}

# %% [markdown]
# ### Manual Curation
# Only one metabolite (fdxox_c) needs to be fixed manually

# %%
# model.metabolites.get_by_id('fdxox_c').formula = 'Fe2S2X'

# %%
# model.reactions.get_by_id('FRDO').check_mass_balance()

# %%
for r in [r for r in model.reactions if only_hydrogen_unbalanced(r)]:
    fix_unbalanced_hydrogen(r)

# %%
for r in [r for r in model.reactions if should_be_balanced(r) and r.check_mass_balance() != {}]:
    print(r, '\n', r.check_mass_balance(), '\n')
# Out:
# 1P2CBXLCYCL: 5a2opntn_c <=> 1p2cbxl_c + h2o_c + h_c
#  {'charge': 1.0}
#
# 1P2CBXLR: 1p2cbxl_c + 2.0 h_c + nadph_c --> nadp_c + pro__L_c
#  {'charge': -1.0}
#
# 23CTI1: decoa_c --> dc2coa_c + h_c
#  {'charge': -3.0}
#
# 23CTI2: dded3coa_c --> dd2coa_c
#  {'charge': -4.0}
#
# 24DECOAR: dec4_2_coa_c + h_c + nadph_c --> dc2coa_c + nadp_c
#  {'charge': -4.0}
#
# 2AGPGAT160: 2agpg160_c + atp_c + hdca_c --> amp_c + pg160_c + ppi_c
#  {'charge': 1.0}
#
# 2AGPGAT161: 2agpg161_c + atp_c + hdcea_c --> amp_c + pg161_c + ppi_c
#  {'charge': -1.0}
#
# 2DDARAA: 2ddara_c <=> gcald_c + pyr_c
#  {'charge': -1.0}
#
# 2DGULRx: 2dhguln_c + h_c + nadh_c --> idon__L_c + nad_c
#  {'charge': -1.0}
#
# 34DHPACDO: 34dhpacet_c + o2_c --> 5cmhmsa_c + h_c
#  {'charge': 2.0}
#
# 4ABZGLUH: 4abzglu_c + h2o_c <=> 4abz_c + glu__L_c
#  {'charge': -2.0}
#
# 4CMLCL_kt: 4cml_c + h_c --> 5odhf2a_c + co2_c
#  {'charge': -2.0}
#
# 4H2KPILY: 4h2kpi_c --> pyr_c + sucsal_c
#  {'charge': -2.0}
#
# 4HOXPACMOF_1: 4hoxpac_c + fadh2_c + o2_c --> 34dhpacet_c + fad_c + h2o_c
#  {'charge': -1.0}
#
# 4HOXPACMON: 4hoxpac_c + h_c + nadh_c + o2_c --> 34dhpacet_c + h2o_c + nad_c
#  {'charge': -1.0}
#
# 4HPTNCOAK: 4hptcoa_c + atp_c --> 4poptcoa_c + adp_c + h_c
#  {'charge': 2.0}
#
# 4HPTNCOAL: 4hptn_c + atp_c + coa_c --> 4hptcoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# 4POPCOAM: 4poptcoa_c --> 3ptcoa_c + pi_c
#  {'charge': -2.0}
#
# AACLAM: acadl_c + coa_c <=> accoa_c + amp_c
#  {'charge': -2.0}
#
# AACOAR_syn: aacoa_c + h_c + nadph_c <=> 3hbcoa__R_c + nadp_c
#  {'charge': 4.0}
#
# AACPS1: ACP_c + atp_c + ttdca_c --> amp_c + myrsACP_c + ppi_c
#  {'charge': -1.0}
#
# AACPS2: ACP_c + atp_c + ttdcea_c --> amp_c + ppi_c + tdeACP_c
#  {'charge': -2.0}
#
# AACPS3: ACP_c + atp_c + hdca_c --> amp_c + palmACP_c + ppi_c
#  {'charge': -1.0}
#
# AACPS4: ACP_c + atp_c + hdcea_c --> amp_c + hdeACP_c + ppi_c
#  {'charge': -2.0}
#
# AACPS5: ACP_c + atp_c + ocdcea_c --> amp_c + octeACP_c + ppi_c
#  {'charge': -1.0}
#
# AACPS6: ACP_c + atp_c + ocdca_c --> amp_c + ocdcaACP_c + ppi_c
#  {'charge': -2.0}
#
# AACPS7: ACP_c + atp_c + ddca_c --> amp_c + ddcaACP_c + ppi_c
#  {'charge': -1.0}
#
# AACPS8: ACP_c + atp_c + dca_c --> amp_c + dcaACP_c + ppi_c
#  {'charge': -1.0}
#
# AACPS9: ACP_c + atp_c + octa_c --> amp_c + ocACP_c + ppi_c
#  {'charge': -2.0}
#
# AADa: aad_c + coa_c <=> accoa_c + amp_c
#  {'charge': -2.0}
#
# AADb: ac_c + atp_c <=> aad_c + ppi_c
#  {'charge': 2.0}
#
# AALDH: nadh_c + pacald_c <=> nad_c + pea_c
#  {'charge': 1.0}
#
# ACGAMPM: acgam6p_c <=> acgam1p_c
#  {'charge': 2.0}
#
# ACHBS: 2obut_c + h_c + pyr_c --> 2ahbut_c + co2_c
#  {'charge': 1.0}
#
# ACLS_a: h_c + pyr_c + thmpp_c --> co2_c + hethmpp_c
#  {'charge': 2.0}
#
# ACLS_d: hethmpp_c + lpam_c <=> adhlam_c + thmpp_c
#  {'charge': -2.0}
#
# ACM6PH: acmum6p_c + h2o_c --> acgam6p_c + lac__D_c
#  {'charge': -3.0}
#
# ACMANApts: acmana_e + pep_c --> acmanap_c + pyr_c
#  {'charge': 2.0}
#
# ACOAD10f: fad_c + 2.0 h_c + hptcoa_c <=> fadh2_c + hp2coa_c
#  {'charge': -2.0}
#
# ACOAD14f: fad_c + 2.0 h_c + poctacoa_c <=> fadh2_c + pocta2coa_c
#  {'charge': -2.0}
#
# ACOAD15f: fad_c + 2.0 h_c + phpcoa_c <=> fadh2_c + php2coa_c
#  {'charge': -2.0}
#
# ACOAD16f: fad_c + 2.0 h_c + phxacoa_c <=> fadh2_c + phxa2coa_c
#  {'charge': -2.0}
#
# ACOAD17f: fad_c + 2.0 h_c + pptcoa_c <=> fadh2_c + ppt2coa_c
#  {'charge': -2.0}
#
# ACOAD18f: fad_c + 2.0 h_c + pbcoa_c <=> fadh2_c + pb2coa_c
#  {'charge': -2.0}
#
# ACOAD23f: fad_c + hdcoa_c <=> fadh2_c + hd2coa_c
#  {'charge': 4.0}
#
# ACOAD26f: fad_c + odecoa_c <=> fadh2_c + ode2coa_c
#  {'charge': 4.0}
#
# ACOAD29f: fad_c + 2.0 h_c + ptslacoa_c <=> fadh2_c + ptsla2coa_c
#  {'charge': -2.0}
#
# ACOAD3: nad_c + occoa_c <=> h_c + nadh_c + oc2coa_c
#  {'charge': 4.0}
#
# ACOAD30f: fad_c + h_c + hdd4coa_c <=> fadh2_c + hdd4_2_coa_c
#  {'charge': -1.0}
#
# ACOAD31f: fad_c + lnlccoa_c <=> fadh2_c + 2.0 h_c + lnlc2coa_c
#  {'charge': 2.0}
#
# ACOAD34f: dec4coa_c + fad_c + 2.0 h_c <=> dec4_2_coa_c + fadh2_c
#  {'charge': -2.0}
#
# ACOAD3f: fad_c + occoa_c <=> fadh2_c + oc2coa_c
#  {'charge': 4.0}
#
# ACOAD4_1: dccoa_c + nad_c <=> dc2coa_c + h_c + nadh_c
#  {'charge': -4.0}
#
# ACOAD6: nad_c + tdcoa_c <=> h_c + nadh_c + td2coa_c
#  {'charge': 4.0}
#
# ACOAD6f: fad_c + tdcoa_c <=> fadh2_c + td2coa_c
#  {'charge': 4.0}
#
# ACOAM: ac_c + atp_c --> acadl_c + ppi_c
#  {'charge': 2.0}
#
# ACP1_FMN: fmn_c + h2o_c --> pi_c + ribflv_c
#  {'charge': -2.0}
#
# ACPPAT120: ddcaACP_c + h_c + pi_c --> ACP_c + ddcap_c
#  {'charge': 2.0}
#
# ACPPAT141: h_c + pi_c + tdeACP_c --> ACP_c + ttdceap_c
#  {'charge': 3.0}
#
# ACPPAT160: h_c + palmACP_c + pi_c --> ACP_c + hdcap_c
#  {'charge': 2.0}
#
# ACPPAT161: h_c + hdeACP_c + pi_c --> ACP_c + hdceap_c
#  {'charge': 3.0}
#
# ACPPAT180: h_c + ocdcaACP_c + pi_c --> ACP_c + ocdcap_c
#  {'charge': 3.0}
#
# ACPPAT181: h_c + octeACP_c + pi_c --> ACP_c + ocdceap_c
#  {'charge': 2.0}
#
# ACPS1: apoACP_c + coa_c --> ACP_c + h_c + pap_c
#  {'charge': 1.0}
#
# ACPS1_1: apoACP_c + coa_c --> ACP_c + h_c + pap_c
#  {'charge': 1.0}
#
# ACPpds: ACP_c + h2o_c --> apoACP_c + h_c + pan4p_c
#  {'charge': -1.0}
#
# ACSPHAC100: R_3hdcaa_c + atp_c + coa_c --> R_3hdcoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHAC101: R3hdec4e_c + atp_c + coa_c --> R3hdec4coa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHAC120: R_3hdda_c + atp_c + coa_c --> R_3hddcoa_c + amp_c + ppi_c
#  {'charge': -1.0}
#
# ACSPHAC121: R_3hdd5ea_c + atp_c + coa_c --> R_3hcddec5ecoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHAC121d6: R_3hdd6e_c + atp_c + coa_c --> R_3hdd6coa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHAC140: R_3httdca_c + atp_c + coa_c --> R_3hmrscoa_c + amp_c + ppi_c
#  {'charge': -1.0}
#
# ACSPHAC141: R_3hcmrs7e_c + atp_c + coa_c --> R_3hcmrs7ecoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHAC141d5: R_3htd5e_c + atp_c + coa_c --> R_3htd5coa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHAC142: R_3htd58e_c + atp_c + coa_c --> R_3htd58coa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHAC160: R_3hhdca_c + atp_c + coa_c --> R_3hhdcoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHAC40: atp_c + bhb_c + coa_c --> 3hbcoa__R_c + amp_c + ppi_c
#  {'charge': 4.0}
#
# ACSPHAC50: R_3hpt_c + atp_c + coa_c --> R_3hptcoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHAC60: R_3hhxa_c + atp_c + coa_c --> R_3hhcoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHAC70: R_3hhpa_c + atp_c + coa_c --> R_3hhpcoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHAC80: R_3hocta_c + atp_c + coa_c --> R_3hocoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHAC90: R_3hnonaa_c + atp_c + coa_c --> R_3hnonacoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHACP100: R_3hpdeca_c + atp_c + coa_c --> R_3hpdecacoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHACP40: R_3hpba_c + atp_c + coa_c --> R_3hpbcoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHACP50: R_3hppta_c + atp_c + coa_c --> R_3hpptcoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHACP60: R_3hphxa_c + atp_c + coa_c --> R_3hphxacoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHACP70: R_3hphpa_c + atp_c + coa_c --> R_3hphpcoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHACP80: R_3hpocta_c + atp_c + coa_c --> R_3hpoctacoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHACP90: R_3hpnona_c + atp_c + coa_c --> R_3hpnonacoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHACT40: R_3h4atba_c + atp_c + coa_c --> R_3h4atbcoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ACSPHACT60: R_3h6atha_c + atp_c + coa_c --> R_3h6athcoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# ADCPS1: adcobhex_c + appl_c + atp_c --> adocbi_c + adp_c + h_c + pi_c
#  {'charge': 1.0}
#
# ADK2: amp_c + pppi_c <=> adp_c + ppi_c
#  {'charge': -4.0}
#
# ADMDC: amet_c + h_c --> ametam_c + co2_c
#  {'charge': -2.0}
#
# ADOCBIAH: adocbi_c + h2o_c <=> adcobhex_c + appl_c
#  {'charge': -1.0}
#
# ADPRDP: adprib_c + h2o_c --> amp_c + 2.0 h_c + r5p_c
#  {'charge': 2.0}
#
# ADPRDP_1: adprib_c + h2o_c --> amp_c + 2.0 h_c + r5p_c
#  {'charge': 2.0}
#
# ADSELK: adsel_c + atp_c --> 3padsel_c + adp_c + h_c
#  {'charge': 2.0}
#
# ADSELR: 3padsel_c + trdrd_c --> 2.0 h_c + pap_c + slnt_c + trdox_c
#  {'charge': -4.0}
#
# ADSL1r: dcamp_c <=> amp_c + fum_c
#  {'charge': -4.0}
#
# ADSS: asp__L_c + gtp_c + imp_c --> dcamp_c + gdp_c + 2.0 h_c + pi_c
#  {'charge': 4.0}
#
# AEPPYRTA: 2ameph_c + pyr_c --> Pald_c + ala__L_c + h_c
#  {'charge': 2.0}
#
# AGM3PA: anhgm3p_c + h2o_c --> LalaDgluMdap_c + anhgm_c
#  {'charge': -2.0}
#
# AGM3PApp: anhgm3p_p + h2o_p --> LalaDgluMdap_p + anhgm_p
#  {'charge': -2.0}
#
# AGM3PH: anhgm3p_c + h2o_c --> acgam_c + anhm3p_c
#  {'charge': -2.0}
#
# AGM4PCPpp: anhgm4p_p + h2o_p --> ala__D_p + anhgm3p_p
#  {'charge': 2.0}
#
# AGPAT120: 1ddecg3p_c + ddcaACP_c --> ACP_c + pa120_c
#  {'charge': 3.0}
#
# AGPAT141: 1tdec7eg3p_c + tdeACP_c --> ACP_c + pa141_c
#  {'charge': 4.0}
#
# AGPAT160: 1hdecg3p_c + palmACP_c --> ACP_c + pa160_c
#  {'charge': 1.0}
#
# AGPAT161: 1hdec9eg3p_c + hdeACP_c --> ACP_c + pa161_c
#  {'charge': 2.0}
#
# AGPAT180: 1odecg3p_c + ocdcaACP_c --> ACP_c + pa180_c
#  {'charge': 4.0}
#
# AGPAT181: 1odec11eg3p_c + octeACP_c --> ACP_c + pa181_c
#  {'charge': 3.0}
#
# AGPATr_BS: 0.01 1ag3p_BS_c + 0.07 fa11coa_c + 0.17 fa12coa_c + 0.01 fa1coa_c + 0.2 fa3coa_c + 0.34 fa4coa_c + 0.05 fa6coa_c + 0.1 pmtcoa_c + 0.03 strcoa_c + 0.03 tdcoa_c <=> 0.01 12dag3p_BS_c + coa_c
#  {'charge': -3.48, 'C': -7.105427357601002e-15, 'H': -1.4210854715202004e-14, 'O': -3.552713678800501e-15, 'N': -8.881784197001252e-16}
#
# AH6PI: ah6p__D_c <-- f6p_c
#  {'charge': -2.0}
#
# AHGDx: S2hglut_c + nad_c <=> akg_c + h_c + nadh_c
#  {'charge': -2.0}
#
# AHMMPS: air_c + 2.0 h_c --> 4ahmmp_c + gcald_c + pi_c
#  {'charge': -4.0}
#
# AIRC2: air_c + atp_c + hco3_c --> 5caiz_c + adp_c + h_c + pi_c
#  {'charge': -2.0}
#
# AIRC3: 5aizc_c <=> 5caiz_c
#  {'charge': -3.0}
#
# AIRCr: air_c + co2_c <=> 5aizc_c + h_c
#  {'charge': 1.0}
#
# AKGDa: akg_c + h_c + lpam_c <=> co2_c + sdhlam_c
#  {'charge': 1.0}
#
# AKGDb: coa_c + sdhlam_c --> dhlam_c + succoa_c
#  {'charge': -1.0}
#
# ALDD4x: h2o_c + mmalsa__S_c + nad_c --> 2.0 h_c + mmal_c + nadh_c
#  {'charge': -1.0}
#
# AMANAPEr: acmanap_c <=> acgam6p_c
#  {'charge': -2.0}
#
# AMANK: acmana_c + atp_c --> acmanap_c + adp_c + h_c
#  {'charge': 2.0}
#
# AMAOTr: 8aonn_c + amet_c <=> amob_c + dann_c
#  {'charge': -1.0}
#
# AMMQT8: 2dmmq8_c + amet_c + h_c --> ahcys_c + mql8_c
#  {'charge': -2.0}
#
# AMPEP10: gly_asp__L_c + h2o_c <=> asp__L_c + gly_c
#  {'charge': -1.0}
#
# AMPEP11: gly_pro__L_c + h2o_c --> gly_c + h_c + pro__L_c
#  {'charge': 1.0}
#
# AMPEP14: h2o_c + h_c + met_L_ala__L_c <=> ala__L_c + met__L_c
#  {'charge': -1.0}
#
# AMPEP15: h2o_c + prohisglu_c --> glu__L_c + his__L_c + pro__L_c
#  {'charge': -1.0}
#
# AMPEP18: h2o_c + serglugly_c --> glu__L_c + gly_c + ser__L_c
#  {'charge': -1.0}
#
# AMPEP5: ala_L_glu__L_c + h2o_c <=> ala__L_c + glu__L_c
#  {'charge': -1.0}
#
# AMPEP8: gly_glu__L_c + h2o_c <=> glu__L_c + gly_c
#  {'charge': -1.0}
#
# AMPTASEGGLU: glyglu_c + h2o_c --> glu__L_c + gly_c
#  {'charge': -1.0}
#
# ANHMK: anhm_c + atp_c + h2o_c --> acmum6p_c + adp_c + h_c
#  {'charge': 3.0}
#
# APAT_1: atp_c + ppa_c <=> ppad_c + ppi_c
#  {'charge': 2.0}
#
# APG3PAT120: ddcap_c + glyc3p_c --> 1ddecg3p_c + h_c + pi_c
#  {'charge': -1.0}
#
# APG3PAT141: glyc3p_c + ttdceap_c --> 1tdec7eg3p_c + h_c + pi_c
#  {'charge': -1.0}
#
# APG3PAT160: glyc3p_c + hdcap_c --> 1hdecg3p_c + h_c + pi_c
#  {'charge': -1.0}
#
# APG3PAT161: glyc3p_c + hdceap_c --> 1hdec9eg3p_c + h_c + pi_c
#  {'charge': 1.0}
#
# APG3PAT180: glyc3p_c + ocdcap_c --> 1odecg3p_c + h_c + pi_c
#  {'charge': -1.0}
#
# APG3PAT181: glyc3p_c + ocdceap_c --> 1odec11eg3p_c + h_c + pi_c
#  {'charge': -1.0}
#
# APPLDHr: aact_c + h_c + nadh_c <=> appl_c + nad_c
#  {'charge': -1.0}
#
# ARACHTA: ACP_c + arachcoa_c <=> arachACP_c + coa_c
#  {'charge': -1.0}
#
# ARGSL: argsuc_c <=> arg__L_c + fum_c
#  {'charge': -1.0}
#
# ARGSS: asp__L_c + atp_c + citr__L_c --> amp_c + argsuc_c + h_c + ppi_c
#  {'charge': 1.0}
#
# ASP3H: akg_c + asp__L_c + o2_c --> 3hasp__L_c + co2_c + succ_c
#  {'charge': 1.0}
#
# ATPPRT: atp_c + prpp_c --> ppi_c + prbatp_c
#  {'charge': 6.0}
#
# AT_MBD2: dhlam_c + ibcoa_c <=> 2mpdhl_c + coa_c + h_c
#  {'charge': 1.0}
#
# BKDA2: 3mob_c + lpam_c --> 2mpdhl_c + co2_c
#  {'charge': 1.0}
#
# BMNMSHS: bmn_c + msh_c --> bmnmsh_c + 2.0 h_c
#  {'charge': 2.0}
#
# BSCT: coa_c + 4.0 h_c + sbzcoa_c <=> benzcoa_c + succoa_c
#  {'charge': -5.0}
#
# BTS2: cys__L_c + dtbt_c <=> ala__L_c + btn_c + 2.0 h_c
#  {'charge': 1.0}
#
# BTS3r: dtbt_c + 2.0 s_c <=> btn_c + h2s_c
#  {'charge': -1.0}
#
# BZ12DOX: bz_c + h_c + nadh_c + o2_c --> bz12diol_c + nad_c
#  {'charge': 1.0}
#
# BZDIOLDH: bz12diol_c + nad_c --> catechol_c + co2_c + nadh_c
#  {'charge': -1.0}
#
# BZSCT: bzsucc_c + succoa_c <=> bzsuccoa_c + succ_c
#  {'charge': 3.0}
#
# BZSS: fum_c + tol_c <=> bzsucc_c
#  {'charge': 2.0}
#
# CARBSARAH: Ncarbsar_c + h2o_c + 2.0 h_c --> co2_c + nh4_c + sarcs_c
#  {'charge': -1.0}
#
# CATDOX: catechol_c + o2_c --> ccmuac_c + 2.0 h_c
#  {'charge': 2.0}
#
# CDGUNPD: cdigmp_c + h2o_c --> 5pg35pg_c + h_c
#  {'charge': -2.0}
#
# CDPPT160: cdpdhdecg_c + inost_c --> cmp_c + h_c + ptd1ino160_c
#  {'charge': 1.0}
#
# CHORM: chor_c --> pphn_c
#  {'charge': 2.0}
#
# CLPNH140pp: clpn140_p + h2o_p --> h_p + pa140_p + pg140_p
#  {'charge': 2.0}
#
# CMCBTFL: cmcbtt_c + fe3_e --> fcmcbtt_c
#  {'charge': -3.0, 'H': 1.0}
#
# CMCBTFU: fcmcbtt_c --> cmcbtt_c + fe3_c + h_c
#  {'charge': 4.0}
#
# CMCMSAD: 5cmhmsa_c + h2o_c + nad_c --> 5cmhm_c + 2.0 h_c + nadh_c
#  {'charge': 1.0}
#
# CMLDC: 4cml_c + h_c --> 5odhf2a_c + co2_c
#  {'charge': -2.0}
#
# COCO2: co_c + 2.0 fdxox_c + h2o_c <=> co2_c + 2.0 fdxrd_c + 2.0 h_c
#  {'X': -2.0}
#
# CYANST: cyan_c + tsul_c --> h_c + so3_c + tcynt_c
#  {'charge': -2.0}
#
# CYO1b: 2.0 focytc_c + 0.5 o2_c --> 2.0 ficytc_c + h2o_c
#  {'charge': -4.0}
#
# CYP1: chol4en3one_c + nadh_c + o2_c --> h2o_c + h_c + hchol_c + nad_c
#  {'charge': 2.0}
#
# CYSK2_I: h_c + pser__L_c + tsul_c --> pi_c + scys__L_c
#  {'charge': -1.0}
#
# D5KGK: atp_c + d5kg_c --> adp_c + d5kgp_c + h_c
#  {'charge': 3.0}
#
# D5KGPA: d5kgp_c --> dhap_c + msa_c
#  {'charge': -3.0}
#
# DAAD12: fad_c + h2o_c + 2.0 h_c + val__D_c --> 3mob_c + fadh2_c + nh4_c
#  {'charge': -2.0}
#
# DACL: abg4_c + h2o_c + h_c <=> 4abz_c + glu__D_c
#  {'charge': -3.0}
#
# DAGK140: 12dgr140_c + atp_c --> adp_c + h_c + pa140_c
#  {'charge': 2.0}
#
# DASYN120: ctp_c + h_c + pa120_c --> cdpdddecg_c + ppi_c
#  {'charge': -2.0}
#
# DASYN140: ctp_c + h_c + pa140_c --> cdpdtdecg_c + ppi_c
#  {'charge': -2.0}
#
# DASYN141: ctp_c + h_c + pa141_c --> cdpdtdec7eg_c + ppi_c
#  {'charge': -2.0}
#
# DASYN161: ctp_c + h_c + pa161_c --> cdpdhdec9eg_c + ppi_c
#  {'charge': -2.0}
#
# DASYN180: ctp_c + h_c + pa180_c --> cdpdodecg_c + ppi_c
#  {'charge': -2.0}
#
# DASYN181: ctp_c + h_c + pa181_c --> cdpdodec11eg_c + ppi_c
#  {'charge': -2.0}
#
# DB4PS: ru5p__D_c --> db4p_c + for_c
#  {'charge': 1.0}
#
# DBTS: atp_c + co2_c + dann_c --> adp_c + dtbt_c + 3.0 h_c + pi_c
#  {'charge': 1.0}
#
# DDPGALA: 2dh3dgal6p_c <=> g3p_c + pyr_c
#  {'charge': 2.0}
#
# DGUNC: 2.0 gtp_c --> cdigmp_c + 2.0 ppi_c
#  {'charge': 2.0}
#
# DHACOAH: 23dhacoa_c + h2o_c <=> 3hadpcoa_c
#  {'charge': -5.0}
#
# DHAD3: 23dhmp_c --> 2o3mpt_c + h2o_c
#  {'charge': 1.0}
#
# DHBD: 23ddhb_c + nad_c <=> 23dhb_c + h_c + nadh_c
#  {'charge': -1.0}
#
# DHBSH: 23dhbzs_c + h2o_c --> 23dhb_c + ser__L_c
#  {'charge': -1.0}
#
# DHBZS2H: 23dhbzs2_c + h2o_c --> 2.0 23dhbzs_c + h_c
#  {'charge': 1.0}
#
# DHBZS3H: 23dhbzs3_c + h2o_c --> 23dhbzs2_c + 23dhbzs_c + h_c
#  {'charge': 1.0}
#
# DHCINDO: dhcinnm_c + o2_c --> h_c + hkntd_c
#  {'charge': 2.0}
#
# DHEDAA: 24dhhed_c --> pyr_c + sucsal_c
#  {'charge': -2.0}
#
# DHNAOT: dhna_c + octdp_c --> 2dmmq8_c + co2_c + h_c + ppi_c
#  {'charge': 2.0}
#
# DHNCOAS: h_c + sbzcoa_c --> 14dhncoa_c + h2o_c
#  {'charge': -5.0}
#
# DHPACCOAHIT: 2dhphaccoa_c + coa_c + 2.0 h2o_c --> 3hadpcoa_c + accoa_c + h2_c + h_c
#  {'charge': -4.0}
#
# DHPDO: 34dhpha_c + o2_c --> 5cmhmsa_c + h_c
#  {'charge': 2.0}
#
# DKGLCNR1: 25dkglcn_c + h_c + nadph_c --> 2dhguln_c + nadp_c
#  {'charge': 1.0}
#
# DNMPPA: dhpmp_c + h2o_c --> dhnpt_c + pi_c
#  {'charge': -2.0}
#
# DNTPPA: ahdt_c + h2o_c --> dhpmp_c + h_c + ppi_c
#  {'charge': 2.0}
#
# DRPA: 2dr5p_c --> acald_c + g3p_c
#  {'charge': 2.0}
#
# DTBTST: 2.0 amet_c + dtbt_c + s_c --> btn_c + 2.0 dad_5_c + 2.0 met__L_c
#  {'charge': -3.0}
#
# DXPRIi: dxyl5p_c + h_c + nadph_c --> 2me4p_c + nadp_c
#  {'charge': 2.0}
#
# DXPS: g3p_c + h_c + pyr_c --> co2_c + dxyl5p_c
#  {'charge': -2.0}
#
# ECOAH1_1: 3hbycoa_c <=> b2coa_c + h2o_c
#  {'charge': -4.0}
#
# ECOAH5_1: 3hddcoa_c <=> h2o_c + trans_dd2coa_c
#  {'charge': 4.0}
#
# ECOAH6: 3htdcoa_c <=> h2o_c + td2coa_c
#  {'charge': 4.0}
#
# ECOAH8: 3hodcoa_c <=> h2o_c + od2coa_c
#  {'charge': -4.0}
#
# EDA: 2ddg6p_c --> g3p_c + pyr_c
#  {'charge': 2.0}
#
# ENTERES: enter_c + 3.0 h2o_c --> 3.0 23dhbzs_c + 2.0 h_c
#  {'charge': 3.0}
#
# ENTERES2: feenter_c + 3.0 h2o_c --> 3.0 23dhbzs_c + fe3_c + 2.0 h_c
#  {'charge': 5.0}
#
# ENTERGLCT1: enter_c + udpg_c --> entermg_c + h_c + udp_c
#  {'charge': 1.0}
#
# ENTERH: enter_c + h2o_c --> 23dhbzs3_c
#  {'charge': 1.0}
#
# FA100ACPHi: dcaACP_c + h2o_c --> ACP_c + dca_c + h_c
#  {'charge': 1.0}
#
# FA120ACPHi: ddcaACP_c + h2o_c --> ACP_c + ddca_c + h_c
#  {'charge': 1.0}
#
# FA140ACPHi: h2o_c + myrsACP_c --> ACP_c + h_c + ttdca_c
#  {'charge': 1.0}
#
# FA141ACPHi: h2o_c + tdeACP_c --> ACP_c + h_c + ttdcea_c
#  {'charge': 2.0}
#
# FA160ACPHi: h2o_c + palmACP_c --> ACP_c + h_c + hdca_c
#  {'charge': 1.0}
#
# FA161ACPHi: h2o_c + hdeACP_c --> ACP_c + h_c + hdcea_c
#  {'charge': 2.0}
#
# FA80ACPHi: h2o_c + ocACP_c --> ACP_c + h_c + octa_c
#  {'charge': 2.0}
#
# FACOAE141: h2o_c + tdecoa_c --> coa_c + h_c + ttdcea_c
#  {'charge': -4.0}
#
# FACOAE1829Z12Z: h2o_c + lnlccoa_c --> coa_c + h_c + lnlc_c
#  {'charge': -4.0}
#
# FACOAE50: h2o_c + ptcoa_c --> coa_c + h_c + pta_c
#  {'charge': -4.0}
#
# FACOAE70: h2o_c + hptcoa_c --> coa_c + h_c + hpta_c
#  {'charge': -3.0}
#
# FACOAE90: h2o_c + nonacoa_c --> coa_c + h_c + nona_c
#  {'charge': -4.0}
#
# FACOAL140_ISO: atp_c + coa_c + fa1_c <=> amp_c + fa1coa_c + ppi_c
#  {'charge': 3.0}
#
# FACOAL141: atp_c + coa_c + ttdcea_c --> amp_c + ppi_c + tdecoa_c
#  {'charge': 4.0}
#
# FACOAL141t2pp: atp_c + coa_c + h_p + ttdcea_p --> amp_c + h_c + ppi_c + tdecoa_c
#  {'charge': 4.0}
#
# FACOAL150_ISO: atp_c + coa_c + fa3_c <=> amp_c + fa3coa_c + ppi_c
#  {'charge': 3.0}
#
# FACOAL150_anteiso: atp_c + coa_c + fa4_c <=> amp_c + fa4coa_c + ppi_c
#  {'charge': 3.0}
#
# FACOAL160_ISO: atp_c + coa_c + fa6_c <=> amp_c + fa6coa_c + ppi_c
#  {'charge': 3.0}
#
# FACOAL170_ISO: atp_c + coa_c + fa11_c <=> amp_c + fa11coa_c + ppi_c
#  {'charge': 3.0}
#
# FACOAL170_anteiso: atp_c + coa_c + fa12_c <=> amp_c + fa12coa_c + ppi_c
#  {'charge': 3.0}
#
# FACOAL180_2: atp_c + coa_c + ocdca_c <=> amp_c + ppi_c + strcoa_c
#  {'charge': 4.0}
#
# FACOAL1812: atp_c + coa_c + vacc_c --> amp_c + ppi_c + vacccoa_c
#  {'charge': 3.0}
#
# FACOAL181d11tpp: atp_c + coa_c + h_p + vacc_p --> amp_c + h_c + ppi_c + vacccoa_c
#  {'charge': 3.0}
#
# FACOAL181d6t2pp: atp_c + coa_c + h_p + ptsla_p --> amp_c + h_c + ppi_c + ptslacoa_c
#  {'charge': 3.0}
#
# FACOAL1821: atp_c + coa_c + lnlc_c --> amp_c + lnlccoa_c + ppi_c
#  {'charge': 4.0}
#
# FACOAL182t2pp: atp_c + coa_c + h_p + lnlc_p --> amp_c + h_c + lnlccoa_c + ppi_c
#  {'charge': 4.0}
#
# FACOAL50i: atp_c + coa_c + pta_c --> amp_c + ppi_c + ptcoa_c
#  {'charge': 4.0}
#
# FACOAL50t2pp: atp_c + coa_c + h_p + pta_p --> amp_c + h_c + ppi_c + ptcoa_c
#  {'charge': 4.0}
#
# FACOAL70t2pp: atp_c + coa_c + h_p + hpta_p --> amp_c + h_c + hptcoa_c + ppi_c
#  {'charge': 3.0}
#
# FACOAL90i: atp_c + coa_c + nona_c --> amp_c + nonacoa_c + ppi_c
#  {'charge': 4.0}
#
# FACOALP50t2pp: atp_c + coa_c + h_p + phept_p --> amp_c + h_c + ppi_c + pptcoa_c
#  {'charge': 3.0}
#
# FACOALP60t2pp: atp_c + coa_c + h_p + phehxa_p --> amp_c + h_c + phxacoa_c + ppi_c
#  {'charge': 3.0}
#
# FACOALP70t2pp: atp_c + coa_c + h_p + phehpa_p --> amp_c + h_c + phpcoa_c + ppi_c
#  {'charge': 3.0}
#
# FACOALP80t2pp: atp_c + coa_c + h_p + pheocta_p --> amp_c + h_c + poctacoa_c + ppi_c
#  {'charge': 3.0}
#
# FACOALPREPH: atp_c + coa_c + prephth_c <=> amp_c + ppi_c + prephthcoa_c
#  {'charge': 3.0}
#
# FACOAL_70_c: atp_c + coa_c + hpta_c --> amp_c + hptcoa_c + ppi_c
#  {'charge': 3.0}
#
# FADE30: 5ohhipcoa_c + fad_c + h_c --> fadh2_c + hipecoa_c
#  {'charge': -1.0}
#
# FASm220: arach_c + 3.0 h_c + mmcoa__S_c + 2.0 nadph_c --> co2_c + coa_c + h2o_c + mbhn_c + 2.0 nadp_c
#  {'charge': 1.0}
#
# FBA: fdp_c <=> dhap_c + g3p_c
#  {'charge': -2.0}
#
# FBA3: s17bp_c <=> dhap_c + e4p_c
#  {'charge': -4.0}
#
# FBACS: 24dab_c + 3hasp__L_c + asp__L_c + gly_c + h_c + n5horn_c + orn_c + ser__L_c --> fbac_kt_c + 6.0 h2o_c
#  {'charge': -1.0}
#
# FBP: fdp_c + h2o_c --> f6p_c + pi_c
#  {'charge': -4.0}
#
# FCLPA: fc1p_c <=> dhap_c + lald__L_c
#  {'charge': -2.0}
#
# FCLT2: fmcbtt_c + ppp9_c --> 2.0 h_c + mcbtt_c + pheme_c
#  {'charge': 2.0}
#
# FDMO2_1: buts_c + fmnRD_c + o2_c --> btal_c + fmn_c + h2o_c + h_c + so3_c
#  {'charge': -1.0}
#
# FDMO7: dmso2_c + 2.0 fmnh2_c + 2.0 o2_c --> fald_c + 2.0 fmn_c + 2.0 h2o_c + 5.0 h_c + mso3_c
#  {'charge': 4.0}
#
# FE3DCITCH: 2.0 cit_c + fe3_c <=> fe3dcit_c
#  {'charge': 3.0}
#
# FE3DCITR5: 2.0 fe3dcit_c + nadph_c --> 4.0 cit_c + 2.0 fe2_c + h_c + nadp_c
#  {'charge': -6.0}
#
# FE3DCITabc: atp_c + fe3dcit_e + h2o_c --> adp_c + 2.0 cit_c + fe3_c + h_c + pi_c
#  {'charge': -3.0}
#
# FE3DCITabcpp: atp_c + fe3dcit_p + h2o_c --> adp_c + 2.0 cit_c + fe3_c + h_c + pi_c
#  {'charge': -3.0}
#
# FE3DHBZS3R: 2.0 fe3dhbzs3_c + nadph_c --> 2.0 23dhbzs3_c + 2.0 fe2_c + 3.0 h_c + nadp_c
#  {'charge': 8.0}
#
# FE3PYOVDL2: fe3_e + pyovd_kt_e <=> fe3pyovd_kt_e
#  {'charge': -3.0}
#
# FEDHBZS3R1: fadh2_c + 2.0 fe3dhbzs3_c --> 2.0 23dhbzs3_c + fad_c + 2.0 fe2_c + 4.0 h_c
#  {'charge': 8.0}
#
# FEDHBZS3R2: 2.0 fe3dhbzs3_c + fmnh2_c --> 2.0 23dhbzs3_c + 2.0 fe2_c + fmn_c + 4.0 h_c
#  {'charge': 8.0}
#
# FEDHBZS3R3: 2.0 fe3dhbzs3_c + rbflvrd_c --> 2.0 23dhbzs3_c + 2.0 fe2_c + 4.0 h_c + ribflv_c
#  {'charge': 8.0}
#
# FEENTERES: feenter_c + h2o_c + h_c --> fe3dhbzs3_c
#  {'charge': -1.0}
#
# FEENTERR1: fadh2_c + 2.0 feenter_c --> 2.0 enter_c + fad_c + 2.0 fe2_c + 2.0 h_c
#  {'charge': 4.0}
#
# FEENTERR2: 2.0 feenter_c + fmnh2_c --> 2.0 enter_c + 2.0 fe2_c + fmn_c + 2.0 h_c
#  {'charge': 4.0}
#
# FEENTERR3: 2.0 feenter_c + rbflvrd_c --> 2.0 enter_c + 2.0 fe2_c + 2.0 h_c + ribflv_c
#  {'charge': 4.0}
#
# FEENTERR4: 2.0 feenter_c + nadph_c --> 2.0 enter_c + 2.0 fe2_c + h_c + nadp_c
#  {'charge': 4.0}
#
# FEOXAMR1: fadh2_c + 2.0 feoxam_c --> fad_c + 2.0 fe2_c + 2.0 feoxam_un_c + 2.0 h_c
#  {'charge': 6.0}
#
# FEOXAMR2: 2.0 feoxam_c + fmnh2_c --> 2.0 fe2_c + 2.0 feoxam_un_c + fmn_c + 2.0 h_c
#  {'charge': 6.0}
#
# FEOXAMR3: 2.0 feoxam_c + rbflvrd_c --> 2.0 fe2_c + 2.0 feoxam_un_c + 2.0 h_c + ribflv_c
#  {'charge': 6.0}
#
# FETRANS: fmcbtt_c <=> fe2_c + mcbtt_c
#  {'charge': 2.0}
#
# FFSD: h2o_c + suc6p_c --> fru_c + g6p_c
#  {'charge': -2.0}
#
# FGFT: fgam_c + 2.0 h_c + thf_c --> gar_c + h2o_c + methf_c
#  {'charge': -2.0}
#
# FPRA: fdxrd_c + h_c + nadp_c --> fdxox_c + nadph_c
#  {'charge': -1.0, 'X': 1.0}
#
# FRUK: atp_c + f1p_c --> adp_c + fdp_c + h_c
#  {'charge': 4.0}
#
# FUCpts: fuc_e + pep_c --> fc1p_c + pyr_c
#  {'charge': 2.0}
#
# G1PACT: accoa_c + gam1p_c --> acgam1p_c + coa_c + h_c
#  {'charge': 2.0}
#
# G3PAT120: ddcaACP_c + glyc3p_c --> 1ddecg3p_c + ACP_c
#  {'charge': 1.0}
#
# G3PAT141: glyc3p_c + tdeACP_c --> 1tdec7eg3p_c + ACP_c
#  {'charge': 2.0}
#
# G3PAT160: glyc3p_c + palmACP_c --> 1hdecg3p_c + ACP_c
#  {'charge': 1.0}
#
# G3PAT161: glyc3p_c + hdeACP_c --> 1hdec9eg3p_c + ACP_c
#  {'charge': 4.0}
#
# G3PAT180: glyc3p_c + ocdcaACP_c --> 1odecg3p_c + ACP_c
#  {'charge': 2.0}
#
# G3PAT181: glyc3p_c + octeACP_c --> 1odec11eg3p_c + ACP_c
#  {'charge': 1.0}
#
# G3POA_BS: 0.07 fa11coa_c + 0.17 fa12coa_c + 0.01 fa1coa_c + 0.2 fa3coa_c + 0.34 fa4coa_c + 0.05 fa6coa_c + glyc3p_c + 0.1 pmtcoa_c + 0.03 strcoa_c + 0.03 tdcoa_c --> 0.01 1ag3p_BS_c + coa_c
#  {'charge': -1.48, 'C': -7.105427357601002e-15, 'N': -8.881784197001252e-16, 'O': -3.552713678800501e-15}
#
# G6PI2_2: g6p_c <=> g6p_A_c
#  {'charge': 2.0}
#
# GADOX: ga_c + o2_c --> 2.0 h_c + omaketo_c
#  {'charge': 3.0}
#
# GALpts: gal_e + pep_c <=> dgal6p_c + pyr_c
#  {'charge': 2.0}
#
# GAPD: g3p_c + nad_c + pi_c <=> 13dpg_c + h_c + nadh_c
#  {'charge': -2.0}
#
# GAPDi_nadp: 13dpg_c + h_c + nadph_c --> g3p_c + nadp_c + pi_c
#  {'charge': 2.0}
#
# GAPP: g3p_c + h2o_c --> glyald_c + pi_c
#  {'charge': -2.0}
#
# GARFT: 10fthf_c + gar_c <=> fgam_c + h_c + thf_c
#  {'charge': 2.0}
#
# GART: atp_c + for_c + gar_c --> adp_c + fgam_c + h_c + pi_c
#  {'charge': 2.0}
#
# GCCa: gly_c + h_c + lpro_c --> alpro_c + co2_c
#  {'charge': -1.0}
#
# GCCb: alpro_c + thf_c --> dhlpro_c + mlthf_c + nh4_c
#  {'charge': 1.0}
#
# GCVHADPr: gcvHL_nhLA_c + nad_c --> gcvHL_ADPr_c + ncam_c
#  {'charge': 1.0}
#
# GCVHRADPr: gcvHL_ADPr_c + h2o_c --> adprib_c + gcvHL_nhLA_c + h_c
#  {'charge': -1.0}
#
# GDPMANNDH: gdpmann_c + h2o_c + 2.0 nad_c --> gdpmanur_c + 3.0 h_c + 2.0 nadh_c
#  {'charge': 3.0}
#
# GDPTPDP: gdptp_c + h2o_c --> gtp_c + ppi_c
#  {'charge': -7.0}
#
# GDTPR: h2o_c + pppgpp_c --> 8.0 h_c + pi_c + ppgpp_c
#  {'charge': 6.0}
#
# GG15DAPAH: ggaptn_c + h2o_c --> 5aptn_c + glu__L_c
#  {'charge': -1.0}
#
# GG15DAPDxr: ggbdapal_c + h2o_c + nad_c <=> ggaptn_c + 2.0 h_c + nadh_c
#  {'charge': 1.0}
#
# GG15DAPO: gg15dap_c + h2o_c + o2_c --> ggbdapal_c + h2o2_c + nh4_c
#  {'charge': 1.0}
#
# GG15DAPS: 15dap_c + atp_c + glu__L_c --> adp_c + gg15dap_c + h_c + pi_c
#  {'charge': -1.0}
#
# GGDAPAH: ggala_B_c + h2o_c --> ala_B_c + glu__L_c
#  {'charge': -1.0}
#
# GGDAPDxr: ggbamppal_c + h2o_c + nad_c <=> ggala_B_c + 2.0 h_c + nadh_c
#  {'charge': 1.0}
#
# GGDAPO: gg13dampp_c + h2o_c + o2_c --> ggbamppal_c + h2o2_c + nh4_c
#  {'charge': 1.0}
#
# GGDAPS: 13dampp_c + atp_c + glu__L_c --> adp_c + gg13dampp_c + h_c + pi_c
#  {'charge': -1.0}
#
# GGLUCT2: gluala_c --> 5oxpro_c + ala__L_c
#  {'charge': -1.0}
#
# GGSPMDO: ggspmd_c + h2o_c + o2_c --> 13dampp_c + ggbutal_c + h2o2_c
#  {'charge': 2.0}
#
# GGSPMDS: atp_c + glu__L_c + spmd_c --> adp_c + ggspmd_c + h_c + pi_c
#  {'charge': -2.0}
#
# GGTT: ggdp_c + ipdp_c --> pendp_c + ppi_c
#  {'charge': 3.0}
#
# GLCADpts: glc__aD_e + pep_c --> g6p_A_c + pyr_c
#  {'charge': 2.0}
#
# GLCURS1: h2o_c + xylan4_c <=> glcur_c + xyl4_c
#  {'charge': -1.0}
#
# GLTPD: galt1p_c + nad_c <=> h_c + nadh_c + tag6p__D_c
#  {'charge': 2.0}
#
# GLUSfx: akg_c + 2.0 fdxrd_c + gln__L_c + 2.0 h_c --> 2.0 fdxox_c + 2.0 glu__L_c
#  {'X': 2.0}
#
# GLUTARH: akg_c + glutar_c + o2_c --> S2hglut_c + co2_c + succ_c
#  {'charge': 2.0}
#
# GLUTRR: glutrna_c + h_c + nadph_c --> glu1sa_c + nadp_c + trnaglu_c
#  {'charge': -3.0}
#
# GLUTRS: atp_c + glu__L_c + trnaglu_c --> amp_c + glutrna_c + ppi_c
#  {'charge': 3.0}
#
# GLUTRS_3: atp_c + glu__L_c + trnaglu_c --> amp_c + glutrna_c + ppi_c
#  {'charge': 3.0}
#
# GLYBCOAT: glybcoa_c + h2o_c --> coa_c + glyb_c + h_c
#  {'charge': -3.0}
#
# GLYCS_I: gthrd_c + mthgxl_c --> lgt_s_c
#  {'charge': 1.0}
#
# GLYCS_II: h2o_c + lgt_s_c --> gthrd_c + h_c + lac__L_c
#  {'charge': -1.0}
#
# GLYCYSAP: gly_cys_c + h2o_c <=> cys__L_c + gly_c + h_c
#  {'charge': 1.0}
#
# GLYCYSabc: atp_c + gly_cys_e + h2o_c --> adp_c + gly_cys_c + pi_c
#  {'charge': -1.0}
#
# GLYLEUAP: gly_leu_c + h2o_c <=> gly_c + h_c + leu__L_c
#  {'charge': 1.0}
#
# GLYLEUtr: atp_c + gly_leu_e + h2o_c --> adp_c + gly_leu_c + pi_c
#  {'charge': -1.0}
#
# GLYPHEAP: gly_phe_c + h2o_c <=> gly_c + h_c + phe__L_c
#  {'charge': 1.0}
#
# GLYPHEtr: atp_c + gly_phe_e + h2o_c --> adp_c + gly_phe_c + pi_c
#  {'charge': -1.0}
#
# GLYTYRAP: gly_tyr_c + h2o_c <=> gly_c + h_c + tyr__L_c
#  {'charge': 1.0}
#
# GLYTYRabc: atp_c + gly_tyr_e + h2o_c --> adp_c + gly_tyr_c + pi_c
#  {'charge': -1.0}
#
# GPDDA4: g3pg_c + h2o_c --> glyc3p_c + glyc_c + h_c
#  {'charge': -1.0}
#
# GTMLT: ala__L_c + gthrd_c --> cgly_c + gluala_c
#  {'charge': 1.0}
#
# GTPDPK: atp_c + gtp_c --> amp_c + gdptp_c + h_c
#  {'charge': 7.0}
#
# GUI1: glcur_c <=> fruur_c
#  {'charge': 1.0}
#
# H2CD: h2isocapcoa_c + h_c --> h2o_c + isocaprecoa_c
#  {'charge': -1.0}
#
# H2CT: coa_c + h2isocap_c --> h2isocapcoa_c + h2o_c
#  {'charge': 4.0}
#
# HACD1_1: aacoa_c + h_c + nadh_c <=> 3hbycoa_c + nad_c
#  {'charge': 4.0}
#
# HACD3: 3oocoa_c + h_c + nadh_c <=> 3hocoa_c + nad_c
#  {'charge': 4.0}
#
# HACD3i: 3hocoa_c + nad_c --> 3oocoa_c + h_c + nadh_c
#  {'charge': -4.0}
#
# HACD8: 3ohodcoa_c + h_c + nadh_c <=> 3hodcoa_c + nad_c
#  {'charge': 4.0}
#
# HACD8i: 3hodcoa_c + nad_c --> 3ohodcoa_c + h_c + nadh_c
#  {'charge': -4.0}
#
# HACD9: 3hmbcoa_c + nad_c <=> 2maacoa_c + h_c + nadh_c
#  {'charge': 4.0}
#
# HACOADr: 3hmp_c + nad_c --> h_c + mmalsa__S_c + nadh_c
#  {'charge': 1.0}
#
# HBCE: 3hbcoa_c <=> 3hbcoa__R_c
#  {'charge': 4.0}
#
# HBCHLR: 3hbcoa__R_c <=> b2coa_c + h2o_c
#  {'charge': -4.0}
#
# HBRCH: 3hbcoa__R_c + h2o_c --> bhb_c + coa_c + h_c
#  {'charge': -4.0}
#
# HEMEOS: frdp_c + h2o_c + pheme_c --> hemeO_c + ppi_c
#  {'charge': 2.0}
#
# HEX4: atp_c + man_c --> adp_c + h_c + man6p_c
#  {'charge': 2.0}
#
# HEXTT: hexdp_c + ipdp_c --> hepdp_c + ppi_c
#  {'charge': 3.0}
#
# HIAA: h2o_c + hipocoa_c --> accoa_c + hia_c
#  {'charge': -4.0}
#
# HISTDa: histd_c + nad_c <=> h_c + histda_c + nadh_c
#  {'charge': -1.0}
#
# HISTDb: h2o_c + histda_c + nad_c --> 2.0 h_c + his__L_c + nadh_c
#  {'charge': 1.0}
#
# HIUH_c: 5hiu_c + h2o_c <=> 5houdic_c
#  {'charge': -1.0}
#
# HKNDDH: h2o_c + hkndd_c --> h_c + op4en_c + succ_c
#  {'charge': 1.0}
#
# HKNTDH: h2o_c + hkntd_c --> fum_c + h_c + op4en_c
#  {'charge': -1.0}
#
# HMEDR: 2.0 h_c + hmbpp_c + nadh_c --> h2o_c + ipdp_c + nad_c
#  {'charge': -4.0}
#
# HMEDS: 2mecdp_c + 2.0 fdxrd_c --> 2.0 fdxox_c + h2o_c + hmbpp_c
#  {'charge': 4.0, 'X': 2.0}
#
# HMR_0260: h2o_c + vacccoa_c --> coa_c + h_c + vacc_c
#  {'charge': -3.0}
#
# HMR_6515: mercppyr_c + so3_c --> pyr_c + tsul_c
#  {'charge': 2.0}
#
# HOPNTAL2: 4hoxoh_c --> ppal_c + pyr_c
#  {'charge': -1.0}
#
# HSAE: h2o_c + hhd_c --> 4hoxoh_c + h_c
#  {'charge': 1.0}
#
# ICCT: h2o_c + isocapcoa_c --> coa_c + h_c + isocap_c
#  {'charge': -3.0}
#
# ICHORT: h2o_c + ichor_c --> 23ddhb_c + pyr_c
#  {'charge': 1.0}
#
# ILEDHr: h2o_c + ile__L_c + nad_c <=> 2o3mpt_c + h_c + nadh_c + nh4_c
#  {'charge': 1.0}
#
# KARA2: 2ahbut_c + h_c + nadph_c <=> 23dhmp_c + nadp_c
#  {'charge': -1.0}
#
# KAS1: 14.0 h_c + ibcoa_c + 5.0 malcoa_c + 10.0 nadph_c --> 5.0 co2_c + 6.0 coa_c + fa1_c + 4.0 h2o_c + 10.0 nadp_c
#  {'charge': 1.0}
#
# KAS11: 17.0 h_c + ivcoa_c + 6.0 malcoa_c + 12.0 nadph_c --> 6.0 co2_c + 7.0 coa_c + fa11_c + 5.0 h2o_c + 12.0 nadp_c
#  {'charge': 1.0}
#
# KAS12: 2mbcoa_c + 17.0 h_c + 6.0 malcoa_c + 12.0 nadph_c --> 6.0 co2_c + 7.0 coa_c + fa12_c + 5.0 h2o_c + 12.0 nadp_c
#  {'charge': 1.0}
#
# KAS3: 14.0 h_c + ivcoa_c + 5.0 malcoa_c + 10.0 nadph_c --> 5.0 co2_c + 6.0 coa_c + fa3_c + 4.0 h2o_c + 10.0 nadp_c
#  {'charge': 1.0}
#
# KAS4: 2mbcoa_c + 14.0 h_c + 5.0 malcoa_c + 10.0 nadph_c --> 5.0 co2_c + 6.0 coa_c + fa4_c + 4.0 h2o_c + 10.0 nadp_c
#  {'charge': 1.0}
#
# KAS6: 17.0 h_c + ibcoa_c + 6.0 malcoa_c + 12.0 nadph_c --> 6.0 co2_c + 7.0 coa_c + fa6_c + 5.0 h2o_c + 12.0 nadp_c
#  {'charge': 1.0}
#
# KAT18: 3opbcoa_c + coa_c --> accoa_c + phaccoa_c
#  {'charge': -4.0}
#
# KAT20: 3ovacccoa_c + coa_c --> accoa_c + hdcoa_c
#  {'charge': -4.0}
#
# KAT33: 3oxptcoa_c + coa_c --> accoa_c + ppcoa_c
#  {'charge': -4.0}
#
# KGD2: co2_c + 2.0 fdxrd_c + h_c + succoa_c <-- akg_c + coa_c + 2.0 fdxox_c
#  {'X': 2.0}
#
# LEVUACOAL: 4oxptn_c + atp_c + coa_c --> 4oxptcoa_c + amp_c + ppi_c
#  {'charge': 3.0}
#
# LIPO1S24_BS: 2400.0 cdpglyc_c + d12dg_BS_c + 2400.0 udpg_c --> 2400.0 cmp_c + 4800.0 h_c + lipo1_24_BS_c + 2400.0 udp_c
#  {'charge': 2400.0}
#
# LIPO2S24_BS: 2400.0 cdpglyc_c + d12dg_BS_c + 2400.0 uacgam_c --> 2400.0 cmp_c + 4800.0 h_c + lipo2_24_BS_c + 2400.0 udp_c
#  {'charge': 2400.0}
#
# LIPO3S24_BS: 2400.0 ala__D_c + 2400.0 atp_c + 2400.0 cdpglyc_c + d12dg_BS_c + 2400.0 h2o_c --> 2400.0 amp_c + 2400.0 cmp_c + 4800.0 h_c + lipo3_24_BS_c + 2400.0 ppi_c
#  {'charge': 2400.0}
#
# LIPO4S24_BS: 2400.0 cdpglyc_c + d12dg_BS_c --> 2400.0 cmp_c + 2400.0 h_c + lipo4_24_BS_c
#  {'charge': 2400.0}
#
# LPLIPAL1G160pp: 1agpg160_p + h2o_p --> g3pg_p + h_p + hdca_p
#  {'charge': 1.0}
#
# LPLIPAL2A120: 2ddecg3p_c + h2o_c --> ddca_c + glyc3p_c + 2.0 h_c
#  {'charge': -1.0}
#
# LPLIPAL2A141: 2tdec7eg3p_c + h2o_c --> glyc3p_c + 2.0 h_c + ttdcea_c
#  {'charge': -1.0}
#
# LPLIPAL2A160: 2hdecg3p_c + h2o_c --> glyc3p_c + 2.0 h_c + hdca_c
#  {'charge': -1.0}
#
# LPLIPAL2A161: 2hdec9eg3p_c + h2o_c --> glyc3p_c + 2.0 h_c + hdcea_c
#  {'charge': -1.0}
#
# LPLIPAL2A181: 2odec11eg3p_c + h2o_c --> glyc3p_c + 2.0 h_c + ocdcea_c
#  {'charge': -1.0}
#
# LPLIPAL2G141: 2agpg141_c + h2o_c --> g3pg_c + h_c + ttdcea_c
#  {'charge': 1.0}
#
# LPLIPAL2G160: 2agpg160_c + h2o_c --> g3pg_c + h_c + hdca_c
#  {'charge': 1.0}
#
# LPLIPAL2G181: 2agpg181_c + h2o_c --> g3pg_c + h_c + ocdcea_c
#  {'charge': 1.0}
#
# L_LACD: 2.0 ficytc_c + lac__L_c --> 2.0 focytc_c + pyr_c
#  {'charge': 4.0}
#
# MACCOAT: 2maacoa_c + coa_c --> accoa_c + ppcoa_c
#  {'charge': -4.0}
#
# MAK: atp_c + malt_c <=> adp_c + h_c + malt1p_c
#  {'charge': 2.0}
#
# MALTT: 2.0 malt1p_c --> glyg4n_c + 2.0 pi_c
#  {'charge': -4.0}
#
# MAN1PT: gtp_c + h_c + man1p_c --> gdpmann_c + ppi_c
#  {'charge': -2.0}
#
# MAN1PT2: gdp_c + h_c + man1p_c --> gdpmann_c + pi_c
#  {'charge': -2.0}
#
# MAN6PI: man6p_c <=> f6p_c
#  {'charge': -2.0}
#
# MANAO: mana_c + nad_c <=> fruur_c + h_c + nadh_c
#  {'charge': 1.0}
#
# MANpts: man_e + pep_c --> man6p_c + pyr_c
#  {'charge': 2.0}
#
# MANptspp: man_p + pep_c --> man6p_c + pyr_c
#  {'charge': 2.0}
#
# MCBTS3: atp_c + bhb_c + 2.0 lys__L_c + 2.0 nadp_c + 3.5 o2_c + occoa_c + salc_c + ser__L_c --> adp_c + cmcbtt_c + co2_c + coa_c + 5.0 h2o_c + 2.0 h_c + 2.0 nadph_c + pi_c
#  {'charge': -2.0}
#
# MCCC: 3mb2coa_c + atp_c + hco3_c --> 3mgcoa_c + adp_c + h_c + pi_c
#  {'charge': 5.0}
#
# MCTP1App: murein5p5p_p --> ala__D_p + murein5px4p_p
#  {'charge': 4.0}
#
# MCTP2App: murein5p5p5p_p --> 2.0 ala__D_p + murein5px4px4p_p
#  {'charge': 6.0}
#
# MDDCP2pp: h2o_p + murein5px4px4p_p --> ala__D_p + murein4px4px4p_p
#  {'charge': -6.0}
#
# MDDEP1pp: h2o_p + murein4px4p_p --> murein4p4p_p
#  {'charge': -4.0}
#
# MDDEP3pp: h2o_p + murein5px4p_p --> murein5p4p_p
#  {'charge': -4.0}
#
# MECDPDH4E: 2mecdp_c + fdxrd_c + h_c <=> fdxo_2_2_c + h2mb4p_c + h2o_c
#  {'charge': -1.0}
#
# MEPCT: 2me4p_c + ctp_c + h_c --> 4c2me_c + ppi_c
#  {'charge': -2.0}
#
# MGCH: 3mgcoa_c + h2o_c <=> hmgcoa_c
#  {'charge': -5.0}
#
# MHPGLUT: hcys__L_c + mhpglu_c --> hpglu_c + met__L_c
#  {'charge': -4.0}
#
# MHPGLUT2: ahcys_c + h_c + mhpglu_c <=> amet_c + hpglu_c
#  {'charge': -4.0}
#
# MI3PP: h2o_c + mi3p__D_c --> inost_c + pi_c
#  {'charge': -2.0}
#
# MI3PS: g6p_c <=> mi3p__D_c
#  {'charge': 2.0}
#
# MLTGY2pp: murein4p3p_p --> anhgm3p_p + anhgm4p_p
#  {'charge': 2.0}
#
# MLTGY3pp: murein3p3p_p --> 2.0 anhgm3p_p
#  {'charge': 4.0}
#
# MLTGY4pp: murein4px4p4p_p --> anhgm4p_p + murein4px4p_p
#  {'charge': 4.0}
#
# MN6PP: h2o_c + man6p_c --> man_c + pi_c
#  {'charge': -2.0}
#
# MPTG: 2.0 uaagmda_c --> 2.0 h_c + murein5p5p_p + 2.0 udcpdp_c
#  {'charge': -2.0}
#
# MPTG2: murein5p5p_p + uaagmda_c --> h_c + murein5p5p5p_p + udcpdp_c
#  {'charge': -1.0}
#
# MSHAMID: bmnmsh_c + h2o_c --> acysbmn_c + igam_c
#  {'charge': 1.0}
#
# MUCCYCI: ccmuac_c + h_c <=> mucl_c
#  {'charge': -1.0}
#
# MUCCY_kt: CCbuttc_c + h_c --> 4cml_c
#  {'charge': 2.0}
#
# MUCLI: mucl_c <=> 5odhf2a_c
#  {'charge': -1.0}
#
# NADHHR: h2o_c + nadh_c --> nadhx__R_c
#  {'charge': 2.0}
#
# NADHXD: adp_c + nadhx__S_c --> amp_c + h_c + nadh_c + pi_c
#  {'charge': -2.0}
#
# NADPHHR: h2o_c + nadph_c --> nadphx__R_c
#  {'charge': 4.0}
#
# NADPHXD: adp_c + nadphx__S_c --> amp_c + h_c + nadph_c + pi_c
#  {'charge': -4.0}
#
# NMO: etha_c + fmnh2_c + o2_c --> acald_c + fmn_c + 6.0 h_c + no2_c
#  {'charge': 4.0}
#
# NMTHDA: atp_c + 2.0 h2o_c + mthd_c --> Ncarbsar_c + adp_c + 2.0 h_c + pi_c
#  {'charge': 1.0}
#
# NPHS: sbzcoa_c --> coa_c + dhna_c
#  {'charge': -5.0}
#
# NPHSa: h_c + sbzcoa_c --> 14dh2napcoa_c + h2o_c
#  {'charge': -1.0}
#
# NPHSb: 14dh2napcoa_c + h2o_c --> coa_c + dhna_c + h_c
#  {'charge': -4.0}
#
# NTPTP1: dgtp_c + h2o_c --> dgsn_c + pppi_c
#  {'charge': 4.0}
#
# NTPTP2: gtp_c + h2o_c --> gsn_c + pppi_c
#  {'charge': 4.0}
#
# OCAALD: oca_c --> oaa_c + pyr_c
#  {'charge': -3.0}
#
# OCOAT4: dhcrn_c + succoa_c --> dhcrncoa_c + succ_c
#  {'charge': 3.0}
#
# OP4ENH: h2o_c + op4en_c --> 4h2opntn_c
#  {'charge': -1.0}
#
# OPETDC: 5cohe_c + h_c --> 2hh24dd_c + co2_c
#  {'charge': -1.0}
#
# OPP: hepdp_c + ipdp_c --> octdp_c + ppi_c
#  {'charge': -3.0}
#
# OPTCCL: 5cohe_c + h_c --> 2hh24dd_c + co2_c
#  {'charge': -1.0}
#
# OXCOAHDH: 2oxpaccoa_c + 2.0 h2o_c + nadp_c --> 3oxdhscoa_c + 2.0 h_c + nadph_c
#  {'charge': 1.0}
#
# PACPT_1: coa_c + ppad_c <=> amp_c + ppcoa_c
#  {'charge': -2.0}
#
# PALDH: Pald_c + h2o_c --> acald_c + pi_c
#  {'charge': -2.0}
#
# PALGSKT: 5.0 gdpmanur_c + h2o_c --> 5.0 gdp_c + 5.0 h_p + prealginate__M_p
#  {'charge': -10.0}
#
# PAPA140pp: h2o_p + pa140_p --> 12dgr140_p + pi_p
#  {'charge': -2.0}
#
# PAPPT3: udcpp_c + ugmda_c --> uagmda_c + ump_c
#  {'charge': 3.0}
#
# PAP_BS: 0.01 12dag3p_BS_c + h2o_c --> 0.01 12dgr_BS_c + pi_c
#  {'charge': -2.0}
#
# PDBL_4: dhap_c + gln__L_c + r5p_c --> glu__L_c + 3.0 h2o_c + h_c + pi_c + pydx5p_c
#  {'charge': -2.0}
#
# PDIMAS: 2.0 h_c + phthiocerol_c + 2.0 tamocta_c --> 2.0 h2o_c + pdima_c
#  {'charge': -2.0}
#
# PFK: atp_c + f6p_c --> adp_c + fdp_c + h_c
#  {'charge': 4.0}
#
# PFK_2: atp_c + tag6p__D_c --> adp_c + h_c + tagdp__D_c
#  {'charge': 2.0}
#
# PGPP120pp: h2o_p + pgp120_p --> pg120_p + pi_p
#  {'charge': -2.0}
#
# PGPP140pp: h2o_p + pgp140_p --> pg140_p + pi_p
#  {'charge': -3.0}
#
# PGPP141pp: h2o_p + pgp141_p --> pg141_p + pi_p
#  {'charge': -3.0}
#
# PGPP160: h2o_c + pgp160_c --> pg160_c + pi_c
#  {'charge': -2.0}
#
# PGPP160pp: h2o_p + pgp160_p --> pg160_p + pi_p
#  {'charge': -2.0}
#
# PGPP161pp: h2o_p + pgp161_p --> pg161_p + pi_p
#  {'charge': -3.0}
#
# PGPP180pp: h2o_p + pgp180_p --> pg180_p + pi_p
#  {'charge': -2.0}
#
# PGPP181pp: h2o_p + pgp181_p --> pg181_p + pi_p
#  {'charge': -3.0}
#
# PGSA120: cdpdddecg_c + glyc3p_c --> cmp_c + h_c + pgp120_c
#  {'charge': 3.0}
#
# PGSA140: cdpdtdecg_c + glyc3p_c --> cmp_c + h_c + pgp140_c
#  {'charge': 3.0}
#
# PGSA141: cdpdtdec7eg_c + glyc3p_c --> cmp_c + h_c + pgp141_c
#  {'charge': 3.0}
#
# PGSA160: cdpdhdecg_c + glyc3p_c --> cmp_c + h_c + pgp160_c
#  {'charge': 3.0}
#
# PGSA161: cdpdhdec9eg_c + glyc3p_c --> cmp_c + h_c + pgp161_c
#  {'charge': 3.0}
#
# PGSA180: cdpdodecg_c + glyc3p_c --> cmp_c + h_c + pgp180_c
#  {'charge': 3.0}
#
# PGSA181: cdpdodec11eg_c + glyc3p_c --> cmp_c + h_c + pgp181_c
#  {'charge': 3.0}
#
# PHACOAOR: h2_c + o2_c + phaccoa_c --> 2dhphaccoa_c
#  {'charge': 4.0}
#
# PHER: phe__L_c <=> 2.0 h_c + phe__D_c
#  {'charge': 2.0}
#
# PHET: fad_c + h2o_c + 2.0 h_c + phe__D_c --> fadh2_c + nh4_c + phpyr_c
#  {'charge': -2.0}
#
# PHTHDLS: h_c + prephth_c --> co2_c + phthdl_c
#  {'charge': -1.0}
#
# PKETX: pi_c + xu5p__D_c --> actp_c + g3p_c + h2o_c
#  {'charge': 2.0}
#
# PLCD: h2o_c + ptd1ino160_c --> 12dgr160_c + h_c + mi1p__D_c
#  {'charge': -1.0}
#
# PLIPA1A120pp: h2o_p + pa120_p --> 2ddecg3p_p + ddca_p
#  {'charge': -1.0}
#
# PLIPA1A141pp: h2o_p + pa141_p --> 2tdec7eg3p_p + ttdcea_p
#  {'charge': -1.0}
#
# PLIPA1A160pp: h2o_p + pa160_p --> 2hdecg3p_p + hdca_p
#  {'charge': 1.0}
#
# PLIPA1A161pp: h2o_p + pa161_p --> 2hdec9eg3p_p + hdcea_p
#  {'charge': -1.0}
#
# PLIPA1A181pp: h2o_p + pa181_p --> 2odec11eg3p_p + ocdcea_p
#  {'charge': -1.0}
#
# PLIPA1E181d11pp: h2o_p + pe181_p --> 2agpe181_p + h_p + vacc_p
#  {'charge': 1.0}
#
# PLIPA1G160pp: h2o_p + pg160_p --> 2agpg160_p + h_p + hdca_p
#  {'charge': -1.0}
#
# PLIPA1G161pp: h2o_p + pg161_p --> 2agpg161_p + h_p + hdcea_p
#  {'charge': 1.0}
#
# PLIPA1G181d11pp: h2o_p + pg181_p --> 2agpg181_p + h_p + vacc_p
#  {'charge': 1.0}
#
# PLIPA2A180pp: h2o_p + pa180_p --> 1odecg3p_p + h_p + ocdca_p
#  {'charge': -2.0}
#
# PLIPA2G160pp: h2o_p + pg160_p --> 1agpg160_p + h_p + hdca_p
#  {'charge': -1.0}
#
# PLPS: g3p_c + gln__L_c + r5p_c --> glu__L_c + 3.0 h2o_c + h_c + pi_c + pydx5p_c
#  {'charge': -4.0}
#
# PPA2: h2o_c + pppi_c --> h_c + pi_c + ppi_c
#  {'charge': -4.0}
#
# PPGPPDP: h2o_c + ppgpp_c --> gdp_c + ppi_c
#  {'charge': -6.0}
#
# PPK2: atp_c + ppi_c --> adp_c + pppi_c
#  {'charge': 4.0}
#
# PPM2: 2dr1p_c <=> 2dr5p_c
#  {'charge': -2.0}
#
# PPND: nad_c + pphn_c --> 34hpp_c + co2_c + nadh_c
#  {'charge': -2.0}
#
# PPNDH: h_c + pphn_c --> co2_c + h2o_c + phpyr_c
#  {'charge': -2.0}
#
# PPTGS_BS: uaagmda_c --> h_c + peptido_BS_c + udcpdp_c
#  {'charge': 1.0}
#
# PPTT: ipdp_c + pendp_c --> hexdp_c + ppi_c
#  {'charge': -3.0}
#
# PRAMPC: h2o_c + prbamp_c --> prfp_c
#  {'charge': -4.0}
#
# PRASCSi: 5aizc_c + asp__L_c + atp_c --> 25aics_c + adp_c + h_c + pi_c
#  {'charge': -3.0}
#
# PRATPP: h2o_c + prbatp_c --> h_c + ppi_c + prbamp_c
#  {'charge': -2.0}
#
# PREPHACPH: h2o_c + prephthACP_c --> ACP_c + h_c + prephth_c
#  {'charge': 2.0}
#
# PREPTHS: arachACP_c + 13.0 h_c + 2.0 malcoa_c + 2.0 mmcoa__S_c + 10.0 nadph_c --> 2.0 co2_c + 4.0 coa_c + 5.0 h2o_c + 10.0 nadp_c + prephthACP_c
#  {'charge': 1.0}
#
# PREPTTA: ACP_c + prephthcoa_c <=> coa_c + prephthACP_c
#  {'charge': -5.0}
#
# PROR: pro__L_c <=> h_c + pro__D_c
#  {'charge': 1.0}
#
# PRPPS: atp_c + r5p_c <=> amp_c + h_c + prpp_c
#  {'charge': -2.0}
#
# PSD120: h_c + ps120_c --> co2_c + pe120_c
#  {'charge': -1.0}
#
# PSD141: h_c + ps141_c --> co2_c + pe141_c
#  {'charge': -1.0}
#
# PSD160: h_c + ps160_c --> co2_c + pe160_c
#  {'charge': -1.0}
#
# PSD180: h_c + ps180_c --> co2_c + pe180_c
#  {'charge': -1.0}
#
# PSD181: h_c + ps181_c --> co2_c + pe181_c
#  {'charge': -1.0}
#
# PSSA120: cdpdddecg_c + ser__L_c --> cmp_c + h_c + ps120_c
#  {'charge': 1.0}
#
# PSSA141: cdpdtdec7eg_c + ser__L_c --> cmp_c + h_c + ps141_c
#  {'charge': 1.0}
#
# PSSA160: cdpdhdecg_c + ser__L_c --> cmp_c + h_c + ps160_c
#  {'charge': 1.0}
#
# PSSA180: cdpdodecg_c + ser__L_c --> cmp_c + h_c + ps180_c
#  {'charge': 1.0}
#
# PSSA181: cdpdodec11eg_c + ser__L_c --> cmp_c + h_c + ps181_c
#  {'charge': 1.0}
#
# PSUDS: r5p_c + ura_c --> h2o_c + psd5p_c
#  {'charge': -2.0}
#
# PUNP2: dad_2_c + pi_c <=> 2dr1p_c + ade_c
#  {'charge': 2.0}
#
# PUNP6: din_c + pi_c <=> 2dr1p_c + hxan_c
#  {'charge': 2.0}
#
# PYDXS: g3p_c + gln__L_c + ru5p__D_c <=> glu__L_c + 3.0 h2o_c + h_c + pi_c + pydx5p_c
#  {'charge': -2.0}
#
# R5PP: h2o_c + r5p_c --> pi_c + rib__D_c
#  {'charge': -2.0}
#
# RBFK: atp_c + ribflv_c --> adp_c + fmn_c + h_c
#  {'charge': 2.0}
#
# RBFSa: 4r5au_c + db4p_c --> dmlz_c + 2.0 h2o_c + pi_c
#  {'charge': -2.0}
#
# RBK: atp_c + rib__D_c --> adp_c + h_c + r5p_c
#  {'charge': 2.0}
#
# RECOAH2: R_3hhcoa_c <=> h2o_c + hx2coa_c
#  {'charge': -4.0}
#
# RECOAH4: R_3hdcoa_c <=> dc2coa_c + h2o_c
#  {'charge': -4.0}
#
# RECOAH6: R_3hmrscoa_c <=> h2o_c + td2coa_c
#  {'charge': 4.0}
#
# RECOAH7: R_3hhdcoa_c <=> h2o_c + hdd2coa_c
#  {'charge': -4.0}
#
# REPHACCOAI: rephaccoa_c <=> 2oxpaccoa_c
#  {'charge': 4.0}
#
# RHACOAE100: R_3hdcoa_c + h2o_c --> R_3hdcaa_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAE120: R_3hddcoa_c + h2o_c --> R_3hdda_c + coa_c + h_c
#  {'charge': 1.0}
#
# RHACOAE121: R_3hcddec5ecoa_c + h2o_c --> R_3hdd5ea_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAE121d6: R_3hdd6coa_c + h2o_c --> R_3hdd6e_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAE140: R_3hmrscoa_c + h2o_c --> R_3httdca_c + coa_c + h_c
#  {'charge': 1.0}
#
# RHACOAE141: R_3hcmrs7ecoa_c + h2o_c --> R_3hcmrs7e_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAE141d5: R_3htd5coa_c + h2o_c --> R_3htd5e_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAE142: R_3htd58coa_c + h2o_c --> R_3htd58e_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAE160: R_3hhdcoa_c + h2o_c --> R_3hhdca_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAE50: R_3hptcoa_c + h2o_c --> R_3hpt_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAE60: R_3hhcoa_c + h2o_c --> R_3hhxa_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAE70: R_3hhpcoa_c + h2o_c --> R_3hhpa_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAE80: R_3hocoa_c + h2o_c --> R_3hocta_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAE90: R_3hnonacoa_c + h2o_c --> R_3hnonaa_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAEP100: R_3hpdecacoa_c + h2o_c --> R_3hpdeca_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAEP101: R3hdec4coa_c + h2o_c --> R3hdec4e_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAEP40: R_3hpbcoa_c + h2o_c --> R_3hpba_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAEP50: R_3hpptcoa_c + h2o_c --> R_3hppta_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAEP60: R_3hphxacoa_c + h2o_c --> R_3hphxa_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAEP70: R_3hphpcoa_c + h2o_c --> R_3hphpa_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAEP80: R_3hpoctacoa_c + h2o_c --> R_3hpocta_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAEP90: R_3hpnonacoa_c + h2o_c --> R_3hpnona_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAET40: R_3h4atbcoa_c + h2o_c --> R_3h4atba_c + coa_c + h_c
#  {'charge': -3.0}
#
# RHACOAET60: R_3h6athcoa_c + h2o_c --> R_3h6atha_c + coa_c + h_c
#  {'charge': -3.0}
#
# RMK: atp_c + rml_c --> adp_c + h_c + rml1p_c
#  {'charge': 2.0}
#
# RMPA: rml1p_c <=> dhap_c + lald__L_c
#  {'charge': -2.0}
#
# RPI: r5p_c <=> ru5p__D_c
#  {'charge': -2.0}
#
# RU5PS: fald_c + ru5p__D_c <-- ah6p__D_c
#  {'charge': 2.0}
#
# SALCHS4FER1: fadh2_c + 2.0 salchs4fe_c --> fad_c + 2.0 fe2_c + 4.0 h_c + 2.0 salchs4_c
#  {'charge': 8.0}
#
# SALCHS4FEabcpp: atp_c + h2o_c + salchs4fe_p --> adp_c + pi_c + salchs4fe_c
#  {'charge': -1.0}
#
# SALCOD: 2.0 h_c + nadh_c + o2_c + salc_c --> catechol_c + co2_c + h2o_c + nad_c
#  {'charge': -1.0}
#
# SBTPD: nad_c + sbt6p_c <=> f6p_c + h_c + nadh_c
#  {'charge': -2.0}
#
# SBTpts: pep_c + sbt__D_e --> pyr_c + sbt6p_c
#  {'charge': 2.0}
#
# SCYSSL: 2.0 gthrd_c + scys__L_c --> cys__L_c + gthox_c + h_c + so3_c
#  {'charge': -1.0}
#
# SELADT: atp_c + h_c + sel_c --> adsel_c + ppi_c
#  {'charge': 2.0}
#
# SEPHCHCS: akg_c + h_c + ichor_c --> 2sephchc_c + co2_c
#  {'charge': 3.0}
#
# SHCHCS3: 2sephchc_c --> 2shchc_c + pyr_c
#  {'charge': -1.0}
#
# SHCHF: fe2_c + scl_c --> 3.0 h_c + sheme_c
#  {'charge': -7.0}
#
# SHGO: S2hglut_c + o2_c --> akg_c + h2o2_c
#  {'charge': -2.0}
#
# SIRA2: 6.0 fdxox_c + 3.0 h2o_c + h2s_c <-- 6.0 fdxrd_c + 8.0 h_c + so3_c
#  {'X': -6.0}
#
# SMIA1: fe2_e + stfrnA_e <=> istfrnA_e
#  {'charge': -2.0}
#
# SMIA1abc: atp_c + h2o_c + istfrnB_e --> adp_c + fe2_c + h_c + pi_c + stfrnB_c
#  {'charge': 2.0}
#
# SMIA2abc: atp_c + h2o_c + istfrnA_e --> adp_c + fe2_c + h_c + pi_c + stfrnA_c
#  {'charge': 2.0}
#
# SMIB1: fe2_e + stfrnB_e <=> istfrnB_e
#  {'charge': -2.0}
#
# SPMS: ametam_c + ptrc_c --> 5mta_c + h_c + spmd_c
#  {'charge': 2.0}
#
# SUCBZL: atp_c + coa_c + sucbz_c --> amp_c + ppi_c + sbzcoa_c
#  {'charge': 5.0}
#
# SUCBZS: 2shchc_c --> h2o_c + sucbz_c
#  {'charge': -2.0}
#
# SUCpts: pep_c + sucr_e --> pyr_c + suc6p_c
#  {'charge': 2.0}
#
# SUCptspp: pep_c + sucr_p --> pyr_c + suc6p_c
#  {'charge': 2.0}
#
# TALA: g3p_c + s7p_c <=> e4p_c + f6p_c
#  {'charge': -2.0}
#
# TECA1S45: 45.0 cdpglyc_c + uacgam_c + uacmam_c --> 45.0 cmp_c + gtca1_45_BS_c + 46.0 h_c + udp_c + ump_c
#  {'charge': 45.0}
#
# TECA2S45: 45.0 ala__D_c + 45.0 atp_c + 45.0 cdpglyc_c + 45.0 h2o_c + uacgam_c + uacmam_c --> 45.0 amp_c + 45.0 cmp_c + gtca2_45_BS_c + 91.0 h_c + 45.0 ppi_c + udp_c + ump_c
#  {'charge': 45.0}
#
# TECA3S45: 45.0 cdpglyc_c + h2o_c + uacgam_c + uacmam_c + 45.0 udpg_c --> 45.0 cmp_c + gtca3_45_BS_c + 91.0 h_c + 46.0 udp_c + ump_c
#  {'charge': 45.0}
#
# TETDHpp1: mql8_c + tet_p --> 2.0 h_p + mqn8_c + 2.0 tsul_p
#  {'charge': 4.0}
#
# TETDHpp2: 2dmmql8_c + tet_p --> 2dmmq8_c + 2.0 h_p + 2.0 tsul_p
#  {'charge': 4.0}
#
# TETDHpp3: q8h2_c + tet_p --> 2.0 h_p + q8_c + 2.0 tsul_p
#  {'charge': 4.0}
#
# TGBPA: tagdp__D_c <=> dhap_c + g3p_c
#  {'charge': -2.0}
#
# THZSN_1: cys__L_c + dxyl_c + fdxo_2_2_c + tyr__L_c --> 4hba_c + 4mhetz_c + co2_c + fdxrd_c + h2o_c + 2.0 h_c + nh4_c + pyr_c
#  {'charge': 1.0}
#
# TKT2: e4p_c + xu5p__D_c <=> f6p_c + g3p_c
#  {'charge': 2.0}
#
# TMDPP: pi_c + thymd_c <=> 2dr1p_c + thym_c
#  {'charge': 2.0}
#
# TNTHAC1: 4hadnt_c + tntmdh_c --> 35dnta_c + h2o_c + no2_c
#  {'charge': -1.0}
#
# TNTHAC2: 2hadnt_c + tntmdh_c --> 2m35mdntha_c + h2o_c + no2_c
#  {'charge': -1.0}
#
# TNTR1: h_c + 2.0 nadph_c + tnt_c --> 4hadnt_c + h2o_c + 2.0 nadp_c
#  {'charge': 1.0}
#
# TNTR1x: h_c + 2.0 nadh_c + tnt_c --> 4hadnt_c + h2o_c + 2.0 nad_c
#  {'charge': 1.0}
#
# TNTR2: h_c + 2.0 nadph_c + tnt_c --> 2hadnt_c + h2o_c + 2.0 nadp_c
#  {'charge': 1.0}
#
# TNTR2x: h_c + 2.0 nadh_c + tnt_c --> 2hadnt_c + h2o_c + 2.0 nad_c
#  {'charge': 1.0}
#
# TPI: dhap_c <=> g3p_c
#  {'charge': 2.0}
#
# TRPS1: 3ig3p_c + ser__L_c --> g3p_c + h2o_c + trp__L_c
#  {'charge': 2.0}
#
# TRPS3: 3ig3p_c --> g3p_c + indole_c
#  {'charge': 2.0}
#
# TTONR2pp: q8h2_c + tton_e --> 4.0 h_c + q8_c + so3_e + tsul_e
#  {'charge': 2.0}
#
# UAGDP: acgam1p_c + h_c + utp_c --> ppi_c + uacgam_c
#  {'charge': -2.0}
#
# UAMAS: ala__L_c + atp_c + uamr_c --> adp_c + h_c + pi_c + uama_c
#  {'charge': -3.0}
#
# UAPGR: h_c + nadph_c + uaccg_c --> nadp_c + uamr_c
#  {'charge': 3.0}
#
# UDCPDP: h2o_c + udcpdp_c --> h_c + pi_c + udcpp_c
#  {'charge': -2.0}
#
# UM3PL: LalaDgluMdap_c + atp_c + uamr_c --> adp_c + h_c + pi_c + ugmd_c
#  {'charge': -3.0}
#
# UM4PL: LalaDgluMdapDala_c + atp_c + uamr_c --> adp_c + h_c + pi_c + um4p_c
#  {'charge': -3.0}
#
# UPP3MT: 2.0 amet_c + uppg3_c --> 2.0 ahcys_c + dscl_c + h_c
#  {'charge': 7.0}
#
# URO_c: h2o_c + o2_c + urate_c --> 5hiu_c + h2o2_c + h_c
#  {'charge': 1.0}
#
# VCACT: accoa_c + ppcoa_c <=> 3optcoa_c + coa_c
#  {'charge': 4.0}
#
# YUMPS: r5p_c + ura_c <=> h2o_c + psd5p_c
#  {'charge': -2.0}
#
# ilvg: 2obut_c + hethmpp_c --> 2ahbut_c + thmpp_c
#  {'charge': -1.0}
#
# GUADEM: guaiacol_c + nadph_c + o2_c --> catechol_c + fald_c + h2o_c + nadp_c
#  {'charge': 1.0, 'H': 1.0}

# %%
status_report()
# Out:
# 1952 of 1952 metabolites have 1 formula(s)
# 0 of 1952 metabolites have 2 formula(s)
# 0 of 1952 metabolites have 3 formula(s)
# 0 of 1952 metabolites have 4 formula(s)
#
#
# 614 of the 3021 reactions in the model are wrongly unbalanced
# 339 of the 3021 reactions in the model are properly unbalanced
# 2068 of the 3021 reactions in the model are balanced
#
#
# 0 of the 614 improperly unbalanced reactions in the model have at least one metabolite with multiple formulas
# 0 of the 339 properly unbalanced reactions in the model have at least one metabolite with multiple formulas
# 0 of the 2068 balanced reactions in the model have at least one metabolite with multiple formulas

# %% [markdown]
# # Save the curated model

# %%
# model.id = 'ropacus_annotated_curated'
# model.name = 'Rhodococcus opacus PD630 annotated and curated'
# model.description = 'Rhodococcus opacus PD630 annotated curated'

# cobra.io.write_sbml_model(model, "../models/Ropacus_annotated_curated.xml")

# %%
# model
# Out:
# <Model ropacus_annotated_curated at 0x7f2cce1b1050>

# %% [markdown]
# # Check memote of current model

# %%
# IFrame('../data/memotes/ropacus_annotated_curated.html', 1500, 800)
