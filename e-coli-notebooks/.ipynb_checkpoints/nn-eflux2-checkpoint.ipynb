# %% [markdown]
# # Predicting fluxes from transcripts using a neural network

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import cross_val_score
from sklearn.metrics import r2_score
from scipy.stats import spearmanr, pearsonr
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score, cross_val_predict, ShuffleSplit
from tpot import TPOTRegressor
import seaborn as sns
import random, copy, torch
import torch.utils.data as utils_data
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.autograd import Variable
import torchvision
from torchvision import datasets, models, transforms
import time, os, random
import torch.nn.functional as F
import torch.nn.init as init
import cobra
np.set_printoptions(precision=4, linewidth=180)
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# # Load input files

# %%
# Load reaction names
reactionNames = np.loadtxt('ishii-flux-names.csv',delimiter=',', skiprows=0,usecols=0,dtype='str')

# %%
# Load metabolic model
cModel = cobra.io.read_sbml_model('iJO1366.xml')

# %%
# Select flux indicies for plotting
reactionDict = {'PGI':2076,'PFK':2063,'FBA':1150,'TPI':2455,'PYK':2265,'PDH':2046,'GND':1422,'RPE':2311,'RPI':2312,'TALA':2397,'ICL':1551,'MALS':1713}
ishiiDict = {2076:2.247179186,2063:2.495301258,1150:2.495301258,2455:2.495301258,2265:1.399624166,2046:3.722827564,1422:.6439079794,2311:.2684455913,2312:.3754514687,2397:.1783978343,1551:.3268244693,1713:.3268244693}

# %%
# Load train and test data
# Training data is from eflux2 samples 2 to 8, representing different KEIO KO strains and growth conditions
# Test data is eflux2 sample1, the WT reference sample
train_x, train_y = [],[]
for i in range(2,9):
    train_x.append(np.loadtxt('ishii-trans-'+str(i)+'.csv',delimiter=',',skiprows=0,usecols=1))
    train_y.append(np.loadtxt('ishii-flux-'+str(i)+'.csv'))
test_x, test_y = np.loadtxt('ishii-trans-1.csv',delimiter=',',skiprows=0,usecols=1),np.loadtxt('ishii-flux-1.csv')
train_x, train_y = np.array(train_x), np.array(train_y)

# %% [markdown]
# # Define and run neural network

# %%
use_cuda = torch.cuda.is_available()

# %%
# Set up data type for torch and metabolic model
print('Will we use cuda?',use_cuda)
dtype = torch.cuda.FloatTensor if use_cuda else torch.FloatTensor

# Define number of steps for NN to learn, the longer the better except for overfitting
#num_steps = 4000000 #  requires a GPU cluster
num_steps = 500

# Convert metabolic model to tensor
my_matrix =Variable((torch.from_numpy( np.array(cobra.util.array.create_stoichiometric_matrix(cModel))).type(dtype)))
# Out:
# Will we use cuda? False

# %% [markdown]
# Define neural network class

# %%
class Model(torch.nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        width_start = 4110
        width = 101
        width_end = 1
        self.fclin1 = torch.nn.Linear(width_start,width)   #in, out numbers
        self.fclin2 = torch.nn.Linear(width, width)        #in, out numbers
        self.fclin3 = torch.nn.Linear(width, width)        #in, out numbers
        self.fclin4 = torch.nn.Linear(width, width)        #in, out numbers
        self.fclin5 = torch.nn.Linear(width, width)        #in, out numbers
        self.fclin6 = torch.nn.Linear(width, width)        #in, out numbers
        self.fclin7 = torch.nn.Linear(width, width)        #in, out numbers
        self.fclin8 = torch.nn.Linear(width, width)        #in, out numbers
        self.fclin9 = torch.nn.Linear(width, width)        #in, out numbers
        self.fclin10 = torch.nn.Linear(width, width)       #in, out numbers
        self.fclin11 = torch.nn.Linear(width, width)       #in, out numbers
        self.fclin12 = torch.nn.Linear(width, width)       #in, out numbers
        self.fclin13 = torch.nn.Linear(width, width)       #in, out numbers
        self.fclin14 = torch.nn.Linear(width, width)       #in, out numbers
        self.fclin15 = torch.nn.Linear(width, width_end)   #in, out numbers
        self.reluNN1 =  torch.nn.LeakyReLU(inplace=True)
        self.reluNN2 =  torch.nn.LeakyReLU(inplace=True)
        self.reluNN3 =  torch.nn.LeakyReLU(inplace=True)
        self.reluNN4 =  torch.nn.LeakyReLU(inplace=True)
        self.reluNN5 =  torch.nn.LeakyReLU(inplace=True)
        self.reluNN6 =  torch.nn.LeakyReLU(inplace=True)
        self.reluNN7 =  torch.nn.LeakyReLU(inplace=True)
        self.reluNN8 =  torch.nn.LeakyReLU(inplace=True)
        self.reluNN9 =  torch.nn.LeakyReLU(inplace=True)
        self.reluNN10 = torch.nn.LeakyReLU(inplace=True)
        self.reluNN11 = torch.nn.LeakyReLU(inplace=True)
        self.reluNN12 = torch.nn.LeakyReLU(inplace=True)
        self.reluNN13 = torch.nn.LeakyReLU(inplace=True)
        self.reluNN14 = torch.nn.LeakyReLU(inplace=True)
        self.reluNN15 = torch.nn.LeakyReLU(inplace=True)
    def forward(self, inp):
        net = self.reluNN1(self.fclin1(inp))
        net = self.reluNN2(self.fclin2(net))
        net = self.reluNN3(self.fclin3(net))
#        net = self.reluNN4(self.fclin4(net))
#        net = self.reluNN5(self.fclin5(net))
#        net = self.reluNN6(self.fclin6(net))
#        net = self.reluNN7(self.fclin7(net))
#        net = self.reluNN8(self.fclin8(net))
#        net = self.reluNN9(self.fclin9(net))
#        net = self.reluNN10(self.fclin10(net))
#        net = self.reluNN11(self.fclin11(net))
#        net = self.reluNN12(self.fclin12(net))
#        net = self.reluNN13(self.fclin13(net))
#        net = self.reluNN14(self.fclin14(net))
        net = self.reluNN15(self.fclin15(net))
        return net

class Regress_Loss(torch.nn.Module):

    def __init__(self):
        super(Regress_Loss,self).__init__()

    def forward(self,x,y):
        a = torch.mm(my_matrix,x)
        loss = torch.dot(a,a)
        return loss

# %% [markdown]
# Run NN

# %%
dim = 1 # dimensionality of input data
nnPredictions, eflux2, absError = [],[],[]
for r in ishiiDict:
    print('Working on reaction:',reactionNames[r])

    # Define working variables
    x = train_x
    y = train_y[:,r]
    print(y)
    y = np.transpose(np.array([y]))
    xmin = x.min()
    xmax = x.max()
    ymin = y.min()
    ymax = y.max()

    # Normalize data for a NN
    x = ( (x - xmin) / (xmax - xmin) )
    y = (y - ymin) / (ymax - ymin)
    x_test = np.transpose(test_x)
    y_test = np.transpose(test_y[r])
    print(y_test)
    x_test = ( (x_test - xmin) / (xmax - xmin) )
    y_test = (y_test - ymin) / (ymax - ymin)

    # Convert data to tensor
    x = Variable(torch.from_numpy(x).type(dtype))
    y = Variable(torch.from_numpy(y).type(dtype))
    x_test = Variable(torch.from_numpy(np.array([x_test])).type(dtype))
    y_test = Variable(torch.from_numpy(np.array([y_test])).type(dtype))

    # Set up some hyperparameters
    model = Model()
    criterion = torch.nn.SmoothL1Loss()
    optimizer = torch.optim.Adam(model.parameters(), lr = 0.00001)
    loss2 = []

    # Do back propagation on NN
    for i in range(num_steps):
        optimizer.zero_grad()
        loss =  criterion(model(x), y)
        loss2.append(loss.data[0])
        if i%50==0:
            print('Step',i,'|  loss=',loss.data[0])
            print('   Predicted Y test',model(x_test),' |  Actual Y test',y_test)
        loss.backward()
        optimizer.step()
    predict = model(x_test).data.numpy().reshape(-1,1)[0]
    predict = (ymax-ymin)*predict
    predict = ymin+predict
    nnPredictions.append(predict[0])
    print('   Neural Network:',predict[0],'|   Eflux2 prediction:',test_y[r])
    eflux2.append(float(test_y[r]))
    absError.append(abs(predict[0]-float(test_y[r])))
    del model
    del x,y,x_test,y_test
# Out:
# Working on reaction: R_PGI
# [2.1324 0.0751 2.0988 2.4739 2.2118 3.4172 2.6157]
# 2.296128682
# Step 0 |  loss= tensor(0.1724)
#    Predicted Y test tensor([[ 0.1053]])  |  Actual Y test tensor([ 0.6646])
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:41 UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:43 UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# Step 50 |  loss= tensor(0.1545)
#    Predicted Y test tensor([[ 0.1392]])  |  Actual Y test tensor([ 0.6646])
# Step 100 |  loss= tensor(0.1374)
#    Predicted Y test tensor([[ 0.1755]])  |  Actual Y test tensor([ 0.6646])
# Step 150 |  loss= tensor(0.1193)
#    Predicted Y test tensor([[ 0.2175]])  |  Actual Y test tensor([ 0.6646])
# Step 200 |  loss= tensor(1.00000e-02 *
#        9.9207)
#    Predicted Y test tensor([[ 0.2697]])  |  Actual Y test tensor([ 0.6646])
# Step 250 |  loss= tensor(1.00000e-02 *
#        7.7542)
#    Predicted Y test tensor([[ 0.3365]])  |  Actual Y test tensor([ 0.6646])
# Step 300 |  loss= tensor(1.00000e-02 *
#        5.7840)
#    Predicted Y test tensor([[ 0.4169]])  |  Actual Y test tensor([ 0.6646])
# Step 350 |  loss= tensor(1.00000e-02 *
#        4.4938)
#    Predicted Y test tensor([[ 0.4953]])  |  Actual Y test tensor([ 0.6646])
# Step 400 |  loss= tensor(1.00000e-02 *
#        3.9313)
#    Predicted Y test tensor([[ 0.5524]])  |  Actual Y test tensor([ 0.6646])
# Step 450 |  loss= tensor(1.00000e-02 *
#        3.7180)
#    Predicted Y test tensor([[ 0.5836]])  |  Actual Y test tensor([ 0.6646])
#    Neural Network: 2.066393 |   Eflux2 prediction: 2.296128682
# Working on reaction: R_PFK
# [2.2757 0.6835 1.6063 2.2704 3.0567 2.3758 1.5415]
# 1.790151679
# Step 0 |  loss= tensor(0.1921)
#    Predicted Y test tensor(1.00000e-04 *
#        [[-1.5822]])  |  Actual Y test tensor([ 0.4663])
# Step 50 |  loss= tensor(0.1856)
#    Predicted Y test tensor(1.00000e-02 *
#        [[ 1.1979]])  |  Actual Y test tensor([ 0.4663])
# Step 100 |  loss= tensor(0.1605)
#    Predicted Y test tensor(1.00000e-02 *
#        [[ 6.0229]])  |  Actual Y test tensor([ 0.4663])
# Step 150 |  loss= tensor(0.1315)
#    Predicted Y test tensor([[ 0.1240]])  |  Actual Y test tensor([ 0.4663])
# Step 200 |  loss= tensor(0.1051)
#    Predicted Y test tensor([[ 0.1916]])  |  Actual Y test tensor([ 0.4663])
# Step 250 |  loss= tensor(1.00000e-02 *
#        8.0640)
#    Predicted Y test tensor([[ 0.2690]])  |  Actual Y test tensor([ 0.4663])
# Step 300 |  loss= tensor(1.00000e-02 *
#        6.1654)
#    Predicted Y test tensor([[ 0.3500]])  |  Actual Y test tensor([ 0.4663])
# Step 350 |  loss= tensor(1.00000e-02 *
#        4.9956)
#    Predicted Y test tensor([[ 0.4249]])  |  Actual Y test tensor([ 0.4663])
# Step 400 |  loss= tensor(1.00000e-02 *
#        4.4465)
#    Predicted Y test tensor([[ 0.4830]])  |  Actual Y test tensor([ 0.4663])
# Step 450 |  loss= tensor(1.00000e-02 *
#        4.2118)
#    Predicted Y test tensor([[ 0.5155]])  |  Actual Y test tensor([ 0.4663])
#    Neural Network: 1.945795 |   Eflux2 prediction: 1.790151679
# Working on reaction: R_FBA
# [2.2757 0.6835 1.6063 2.2704 3.0567 2.3758 1.5415]
# 1.790151679
# Step 0 |  loss= tensor(0.1530)
#    Predicted Y test tensor(1.00000e-02 *
#        [[ 7.7474]])  |  Actual Y test tensor([ 0.4663])
# Step 50 |  loss= tensor(0.1413)
#    Predicted Y test tensor([[ 0.1030]])  |  Actual Y test tensor([ 0.4663])
# Step 100 |  loss= tensor(0.1283)
#    Predicted Y test tensor([[ 0.1334]])  |  Actual Y test tensor([ 0.4663])
# Step 150 |  loss= tensor(0.1093)
#    Predicted Y test tensor([[ 0.1817]])  |  Actual Y test tensor([ 0.4663])
# Step 200 |  loss= tensor(1.00000e-02 *
#        8.6016)
#    Predicted Y test tensor([[ 0.2518]])  |  Actual Y test tensor([ 0.4663])
# Step 250 |  loss= tensor(1.00000e-02 *
#        6.4954)
#    Predicted Y test tensor([[ 0.3354]])  |  Actual Y test tensor([ 0.4663])
# Step 300 |  loss= tensor(1.00000e-02 *
#        5.0178)
#    Predicted Y test tensor([[ 0.4260]])  |  Actual Y test tensor([ 0.4663])
# Step 350 |  loss= tensor(1.00000e-02 *
#        4.4392)
#    Predicted Y test tensor([[ 0.4883]])  |  Actual Y test tensor([ 0.4663])
# Step 400 |  loss= tensor(1.00000e-02 *
#        4.2004)
#    Predicted Y test tensor([[ 0.5205]])  |  Actual Y test tensor([ 0.4663])
# Step 450 |  loss= tensor(1.00000e-02 *
#        4.0089)
#    Predicted Y test tensor([[ 0.5367]])  |  Actual Y test tensor([ 0.4663])
#    Neural Network: 1.9786818 |   Eflux2 prediction: 1.790151679
# Working on reaction: R_TPI
# [4.2052 1.9268 3.241  4.2691 5.5051 4.5562 3.0175]
# 3.378207362
# Step 0 |  loss= tensor(0.1863)
#    Predicted Y test tensor(1.00000e-04 *
#        [[-8.3949]])  |  Actual Y test tensor([ 0.4056])
# Step 50 |  loss= tensor(0.1862)
#    Predicted Y test tensor(1.00000e-04 *
#        [[-6.2562]])  |  Actual Y test tensor([ 0.4056])
# Step 100 |  loss= tensor(0.1860)
#    Predicted Y test tensor(1.00000e-04 *
#        [[-4.0665]])  |  Actual Y test tensor([ 0.4056])
# Step 150 |  loss= tensor(0.1859)
#    Predicted Y test tensor(1.00000e-04 *
#        [[-1.2258]])  |  Actual Y test tensor([ 0.4056])
# Step 200 |  loss= tensor(0.1600)
#    Predicted Y test tensor(1.00000e-02 *
#        [[ 4.9573]])  |  Actual Y test tensor([ 0.4056])
# Step 250 |  loss= tensor(0.1233)
#    Predicted Y test tensor([[ 0.1320]])  |  Actual Y test tensor([ 0.4056])
# Step 300 |  loss= tensor(1.00000e-02 *
#        9.3295)
#    Predicted Y test tensor([[ 0.2163]])  |  Actual Y test tensor([ 0.4056])
# Step 350 |  loss= tensor(1.00000e-02 *
#        6.9181)
#    Predicted Y test tensor([[ 0.3063]])  |  Actual Y test tensor([ 0.4056])
# Step 400 |  loss= tensor(1.00000e-02 *
#        5.4539)
#    Predicted Y test tensor([[ 0.3882]])  |  Actual Y test tensor([ 0.4056])
# Step 450 |  loss= tensor(1.00000e-02 *
#        4.7746)
#    Predicted Y test tensor([[ 0.4503]])  |  Actual Y test tensor([ 0.4056])
#    Neural Network: 3.676063 |   Eflux2 prediction: 3.378207362
# Working on reaction: R_PYK
# [3.6181 0.9454 2.3245 2.953  5.3915 3.1325 0.7349]
# 1.563415101
# Step 0 |  loss= tensor(0.1405)
#    Predicted Y test tensor(1.00000e-03 *
#        [[ 4.0873]])  |  Actual Y test tensor([ 0.1779])
# Step 50 |  loss= tensor(0.1277)
#    Predicted Y test tensor(1.00000e-02 *
#        [[ 3.5947]])  |  Actual Y test tensor([ 0.1779])
# Step 100 |  loss= tensor(0.1142)
#    Predicted Y test tensor(1.00000e-02 *
#        [[ 7.0901]])  |  Actual Y test tensor([ 0.1779])
# Step 150 |  loss= tensor(1.00000e-02 *
#        9.9681)
#    Predicted Y test tensor([[ 0.1132]])  |  Actual Y test tensor([ 0.1779])
# Step 200 |  loss= tensor(1.00000e-02 *
#        8.1923)
#    Predicted Y test tensor([[ 0.1753]])  |  Actual Y test tensor([ 0.1779])
# Step 250 |  loss= tensor(1.00000e-02 *
#        6.8277)
#    Predicted Y test tensor([[ 0.2359]])  |  Actual Y test tensor([ 0.1779])
# Step 300 |  loss= tensor(1.00000e-02 *
#        5.7705)
#    Predicted Y test tensor([[ 0.2989]])  |  Actual Y test tensor([ 0.1779])
# Step 350 |  loss= tensor(1.00000e-02 *
#        5.0858)
#    Predicted Y test tensor([[ 0.3542]])  |  Actual Y test tensor([ 0.1779])
# Step 400 |  loss= tensor(1.00000e-02 *
#        4.6488)
#    Predicted Y test tensor([[ 0.3925]])  |  Actual Y test tensor([ 0.1779])
# Step 450 |  loss= tensor(1.00000e-02 *
#        4.2760)
#    Predicted Y test tensor([[ 0.4154]])  |  Actual Y test tensor([ 0.1779])
#    Neural Network: 2.7405684 |   Eflux2 prediction: 1.563415101
# Working on reaction: R_PDH
# [1.1700e-11 1.7262e+00 3.6700e-11 2.0255e+00 6.9636e-01 1.1800e-11 4.6524e-01]
# 1.100181514
# Step 0 |  loss= tensor(0.1102)
#    Predicted Y test tensor(1.00000e-02 *
#        [[ 8.4035]])  |  Actual Y test tensor([ 0.5432])
# Step 50 |  loss= tensor(0.1038)
#    Predicted Y test tensor([[ 0.1085]])  |  Actual Y test tensor([ 0.5432])
# Step 100 |  loss= tensor(1.00000e-02 *
#        9.7033)
#    Predicted Y test tensor([[ 0.1385]])  |  Actual Y test tensor([ 0.5432])
# Step 150 |  loss= tensor(1.00000e-02 *
#        9.0301)
#    Predicted Y test tensor([[ 0.1729]])  |  Actual Y test tensor([ 0.5432])
# Step 200 |  loss= tensor(1.00000e-02 *
#        8.3805)
#    Predicted Y test tensor([[ 0.2134]])  |  Actual Y test tensor([ 0.5432])
# Step 250 |  loss= tensor(1.00000e-02 *
#        7.8193)
#    Predicted Y test tensor([[ 0.2596]])  |  Actual Y test tensor([ 0.5432])
# Step 300 |  loss= tensor(1.00000e-02 *
#        7.4663)
#    Predicted Y test tensor([[ 0.2998]])  |  Actual Y test tensor([ 0.5432])
# Step 350 |  loss= tensor(1.00000e-02 *
#        7.2504)
#    Predicted Y test tensor([[ 0.3275]])  |  Actual Y test tensor([ 0.5432])
# Step 400 |  loss= tensor(1.00000e-02 *
#        7.0707)
#    Predicted Y test tensor([[ 0.3441]])  |  Actual Y test tensor([ 0.5432])
# Step 450 |  loss= tensor(1.00000e-02 *
#        6.8789)
#    Predicted Y test tensor([[ 0.3549]])  |  Actual Y test tensor([ 0.5432])
#    Neural Network: 0.73562 |   Eflux2 prediction: 1.100181514
# Working on reaction: R_GND
# [2.3606 2.3625 1.3387 2.2266 2.0942 1.6932 1.0185]
# 1.691451557
# Step 0 |  loss= tensor(0.2683)
#    Predicted Y test tensor(1.00000e-04 *
#        [[-2.1740]])  |  Actual Y test tensor([ 0.5007])
# Step 50 |  loss= tensor(0.2601)
#    Predicted Y test tensor(1.00000e-02 *
#        [[ 1.2779]])  |  Actual Y test tensor([ 0.5007])
# Step 100 |  loss= tensor(0.2347)
#    Predicted Y test tensor(1.00000e-02 *
#        [[ 5.4674]])  |  Actual Y test tensor([ 0.5007])
# Step 150 |  loss= tensor(0.2101)
#    Predicted Y test tensor(1.00000e-02 *
#        [[ 9.8056]])  |  Actual Y test tensor([ 0.5007])
# Step 200 |  loss= tensor(0.1833)
#    Predicted Y test tensor([[ 0.1498]])  |  Actual Y test tensor([ 0.5007])
# Step 250 |  loss= tensor(0.1494)
#    Predicted Y test tensor([[ 0.2247]])  |  Actual Y test tensor([ 0.5007])
# Step 300 |  loss= tensor(0.1164)
#    Predicted Y test tensor([[ 0.3146]])  |  Actual Y test tensor([ 0.5007])
# Step 350 |  loss= tensor(1.00000e-02 *
#        8.8052)
#    Predicted Y test tensor([[ 0.4214]])  |  Actual Y test tensor([ 0.5007])
# Step 400 |  loss= tensor(1.00000e-02 *
#        7.2344)
#    Predicted Y test tensor([[ 0.5149]])  |  Actual Y test tensor([ 0.5007])
# Step 450 |  loss= tensor(1.00000e-02 *
#        6.5764)
#    Predicted Y test tensor([[ 0.5769]])  |  Actual Y test tensor([ 0.5007])
#    Neural Network: 1.8394943 |   Eflux2 prediction: 1.691451557
# Working on reaction: R_RPE
# [1.2926 1.3666 0.6757 1.2105 1.1962 0.8364 0.4664]
# 0.867799311
# Step 0 |  loss= tensor(0.2439)
#    Predicted Y test tensor(1.00000e-03 *
#        [[-1.0522]])  |  Actual Y test tensor([ 0.4459])
# Step 50 |  loss= tensor(0.2437)
#    Predicted Y test tensor(1.00000e-04 *
#        [[-7.2082]])  |  Actual Y test tensor([ 0.4459])
# Step 100 |  loss= tensor(0.2435)
#    Predicted Y test tensor(1.00000e-04 *
#        [[-3.4865]])  |  Actual Y test tensor([ 0.4459])
# Step 150 |  loss= tensor(0.2316)
#    Predicted Y test tensor(1.00000e-02 *
#        [[ 1.7847]])  |  Actual Y test tensor([ 0.4459])
# Step 200 |  loss= tensor(0.1801)
#    Predicted Y test tensor([[ 0.1133]])  |  Actual Y test tensor([ 0.4459])
# Step 250 |  loss= tensor(0.1368)
#    Predicted Y test tensor([[ 0.2119]])  |  Actual Y test tensor([ 0.4459])
# Step 300 |  loss= tensor(0.1013)
#    Predicted Y test tensor([[ 0.3183]])  |  Actual Y test tensor([ 0.4459])
# Step 350 |  loss= tensor(1.00000e-02 *
#        7.7644)
#    Predicted Y test tensor([[ 0.4221]])  |  Actual Y test tensor([ 0.4459])
# Step 400 |  loss= tensor(1.00000e-02 *
#        6.5538)
#    Predicted Y test tensor([[ 0.5063]])  |  Actual Y test tensor([ 0.4459])
# Step 450 |  loss= tensor(1.00000e-02 *
#        5.9854)
#    Predicted Y test tensor([[ 0.5615]])  |  Actual Y test tensor([ 0.4459])
#    Neural Network: 0.99674904 |   Eflux2 prediction: 0.867799311
# Working on reaction: R_RPI
# [-1.0536 -0.9852 -0.6519 -1.002  -0.8877 -0.8419 -0.5412]
# -0.810324773
# Step 0 |  loss= tensor(0.1370)
#    Predicted Y test tensor(1.00000e-04 *
#        [[-1.4143]])  |  Actual Y test tensor([ 0.4747])
# Step 50 |  loss= tensor(0.1324)
#    Predicted Y test tensor(1.00000e-02 *
#        [[ 1.1081]])  |  Actual Y test tensor([ 0.4747])
# Step 100 |  loss= tensor(0.1191)
#    Predicted Y test tensor(1.00000e-02 *
#        [[ 4.6671]])  |  Actual Y test tensor([ 0.4747])
# Step 150 |  loss= tensor(0.1046)
#    Predicted Y test tensor(1.00000e-02 *
#        [[ 8.9667]])  |  Actual Y test tensor([ 0.4747])
# Step 200 |  loss= tensor(1.00000e-02 *
#        8.9075)
#    Predicted Y test tensor([[ 0.1435]])  |  Actual Y test tensor([ 0.4747])
# Step 250 |  loss= tensor(1.00000e-02 *
#        7.7017)
#    Predicted Y test tensor([[ 0.1947]])  |  Actual Y test tensor([ 0.4747])
# Step 300 |  loss= tensor(1.00000e-02 *
#        6.5929)
#    Predicted Y test tensor([[ 0.2555]])  |  Actual Y test tensor([ 0.4747])
# Step 350 |  loss= tensor(1.00000e-02 *
#        5.8710)
#    Predicted Y test tensor([[ 0.3100]])  |  Actual Y test tensor([ 0.4747])
# Step 400 |  loss= tensor(1.00000e-02 *
#        5.4823)
#    Predicted Y test tensor([[ 0.3441]])  |  Actual Y test tensor([ 0.4747])
# Step 450 |  loss= tensor(1.00000e-02 *
#        5.2266)
#    Predicted Y test tensor([[ 0.3583]])  |  Actual Y test tensor([ 0.4747])
#    Neural Network: -0.86858875 |   Eflux2 prediction: -0.810324773
# Working on reaction: R_TALA
# [-1.0402  0.034  -0.8101 -1.0653 -1.6063 -1.2572 -0.8374]
# -0.861606754
# Step 0 |  loss= tensor(1.00000e-02 *
#        8.8979)
#    Predicted Y test tensor(1.00000e-02 *
#        [[ 9.6284]])  |  Actual Y test tensor([ 0.4540])
# Step 50 |  loss= tensor(1.00000e-02 *
#        8.3025)
#    Predicted Y test tensor([[ 0.1153]])  |  Actual Y test tensor([ 0.4540])
# Step 100 |  loss= tensor(1.00000e-02 *
#        7.8234)
#    Predicted Y test tensor([[ 0.1317]])  |  Actual Y test tensor([ 0.4540])
# Step 150 |  loss= tensor(1.00000e-02 *
#        7.3095)
#    Predicted Y test tensor([[ 0.1499]])  |  Actual Y test tensor([ 0.4540])
# Step 200 |  loss= tensor(1.00000e-02 *
#        6.6851)
#    Predicted Y test tensor([[ 0.1741]])  |  Actual Y test tensor([ 0.4540])
# Step 250 |  loss= tensor(1.00000e-02 *
#        5.9673)
#    Predicted Y test tensor([[ 0.2048]])  |  Actual Y test tensor([ 0.4540])
# Step 300 |  loss= tensor(1.00000e-02 *
#        5.0653)
#    Predicted Y test tensor([[ 0.2503]])  |  Actual Y test tensor([ 0.4540])
# Step 350 |  loss= tensor(1.00000e-02 *
#        4.2487)
#    Predicted Y test tensor([[ 0.3043]])  |  Actual Y test tensor([ 0.4540])
# Step 400 |  loss= tensor(1.00000e-02 *
#        3.7243)
#    Predicted Y test tensor([[ 0.3480]])  |  Actual Y test tensor([ 0.4540])
# Step 450 |  loss= tensor(1.00000e-02 *
#        3.4313)
#    Predicted Y test tensor([[ 0.3672]])  |  Actual Y test tensor([ 0.4540])
#    Neural Network: -1.0007073 |   Eflux2 prediction: -0.861606754
# Working on reaction: R_ICL
# [6.2766e-01 3.2300e-10 1.6947e-01 7.7800e-12 3.8400e-11 4.5776e-01 4.0200e-11]
# 1.98e-11
# Step 0 |  loss= tensor(1.00000e-02 *
#        9.5807)
#    Predicted Y test tensor(1.00000e-02 *
#        [[ 7.4655]])  |  Actual Y test tensor(1.00000e-11 *
#        [ 1.9150])
# Step 50 |  loss= tensor(1.00000e-02 *
#        8.9428)
#    Predicted Y test tensor([[ 0.1059]])  |  Actual Y test tensor(1.00000e-11 *
#        [ 1.9150])
# Step 100 |  loss= tensor(1.00000e-02 *
#        8.4394)
#    Predicted Y test tensor([[ 0.1343]])  |  Actual Y test tensor(1.00000e-11 *
#        [ 1.9150])
# Step 150 |  loss= tensor(1.00000e-02 *
#        7.9009)
#    Predicted Y test tensor([[ 0.1706]])  |  Actual Y test tensor(1.00000e-11 *
#        [ 1.9150])
# Step 200 |  loss= tensor(1.00000e-02 *
#        7.4665)
#    Predicted Y test tensor([[ 0.2082]])  |  Actual Y test tensor(1.00000e-11 *
#        [ 1.9150])
# Step 250 |  loss= tensor(1.00000e-02 *
#        7.1564)
#    Predicted Y test tensor([[ 0.2368]])  |  Actual Y test tensor(1.00000e-11 *
#        [ 1.9150])
# Step 300 |  loss= tensor(1.00000e-02 *
#        6.9086)
#    Predicted Y test tensor([[ 0.2510]])  |  Actual Y test tensor(1.00000e-11 *
#        [ 1.9150])
# Step 350 |  loss= tensor(1.00000e-02 *
#        6.6297)
#    Predicted Y test tensor([[ 0.2579]])  |  Actual Y test tensor(1.00000e-11 *
#        [ 1.9150])
# Step 400 |  loss= tensor(1.00000e-02 *
#        6.2989)
#    Predicted Y test tensor([[ 0.2625]])  |  Actual Y test tensor(1.00000e-11 *
#        [ 1.9150])
# Step 450 |  loss= tensor(1.00000e-02 *
#        5.9246)
#    Predicted Y test tensor([[ 0.2658]])  |  Actual Y test tensor(1.00000e-11 *
#        [ 1.9150])
#    Neural Network: 0.16848104 |   Eflux2 prediction: 1.98e-11
# Working on reaction: R_MALS
# [6.2791e-01 1.8000e-04 1.6965e-01 2.3600e-04 1.7200e-04 4.5801e-01 1.8300e-04]
# 0.000224
# Step 0 |  loss= tensor(0.1008)
#    Predicted Y test tensor(1.00000e-02 *
#        [[ 5.3197]])  |  Actual Y test tensor(1.00000e-05 *
#        [ 8.2837])
# Step 50 |  loss= tensor(1.00000e-02 *
#        9.2286)
#    Predicted Y test tensor(1.00000e-02 *
#        [[ 9.2832]])  |  Actual Y test tensor(1.00000e-05 *
#        [ 8.2837])
# Step 100 |  loss= tensor(1.00000e-02 *
#        8.6586)
#    Predicted Y test tensor([[ 0.1220]])  |  Actual Y test tensor(1.00000e-05 *
#        [ 8.2837])
# Step 150 |  loss= tensor(1.00000e-02 *
#        8.0857)
#    Predicted Y test tensor([[ 0.1579]])  |  Actual Y test tensor(1.00000e-05 *
#        [ 8.2837])
# Step 200 |  loss= tensor(1.00000e-02 *
#        7.6214)
#    Predicted Y test tensor([[ 0.1942]])  |  Actual Y test tensor(1.00000e-05 *
#        [ 8.2837])
# Step 250 |  loss= tensor(1.00000e-02 *
#        7.2360)
#    Predicted Y test tensor([[ 0.2323]])  |  Actual Y test tensor(1.00000e-05 *
#        [ 8.2837])
# Step 300 |  loss= tensor(1.00000e-02 *
#        6.9952)
#    Predicted Y test tensor([[ 0.2526]])  |  Actual Y test tensor(1.00000e-05 *
#        [ 8.2837])
# Step 350 |  loss= tensor(1.00000e-02 *
#        6.7752)
#    Predicted Y test tensor([[ 0.2639]])  |  Actual Y test tensor(1.00000e-05 *
#        [ 8.2837])
# Step 400 |  loss= tensor(1.00000e-02 *
#        6.5006)
#    Predicted Y test tensor([[ 0.2704]])  |  Actual Y test tensor(1.00000e-05 *
#        [ 8.2837])
# Step 450 |  loss= tensor(1.00000e-02 *
#        6.1800)
#    Predicted Y test tensor([[ 0.2736]])  |  Actual Y test tensor(1.00000e-05 *
#        [ 8.2837])
#    Neural Network: 0.174682 |   Eflux2 prediction: 0.000224

# %%
# Load reaction labels
labels=[i for i in reactionDict]

# %% [markdown]
# # Plot results

# %%
# Plot scatter plot of fluxes
plt.rcParams['figure.figsize'] = (5,5)
plt.scatter(nnPredictions,eflux2,label=labels)
X_plot = np.linspace(-1, 4.5, 100)
Y_plot = X_plot
plt.plot(X_plot, Y_plot, color='r')
plt.xlim(-1,3)
plt.axis('equal')
for i in range(len(nnPredictions)):
    xy = (nnPredictions[i]+.1,eflux2[i]+.1)
    plt.annotate(labels[i],xy)
plt.xlabel(r'NN predicted flux measurement (mmol/gDW/h)')
plt.ylabel(r'Eflux2 synthetic data (mmol/gDW/h)')
plt.tight_layout()
#plt.show()
plt.savefig('rf-eflux2.pdf')

# %%
# Histogram plot of errors
g=sns.distplot(absError,hist=True)
plt.xlabel(r'Abolute error of NN vs Eflux2 base (mmol/gDW/h)')
plt.ylabel(r'Normalized frequency')
plt.xlim(0,3)
#plt.show()
plt.savefig('nn-eflux2-error.pdf')
# Out:
# /usr/local/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462 UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.

# %%
# Zoom of histogram error
g=sns.distplot(absError,hist=True)
plt.xlabel(r'Abolute error of NN vs Eflux2 base (mmol/gDW/h)')
plt.ylabel(r'Normalized frequency')
plt.xlim(0,2)
plt.ylim(0,1)
#plt.show()
plt.savefig('nn-eflux2-error-zoom.pdf')
# Out:
# /usr/local/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462 UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
