# %% [markdown]
# ### **Notebook to make predictions with reprocessed Yoneda data and SPOT**

# %% [markdown]
# ##### **Import python packages**

# %%
import os
import sys
import pandas as pd
import numpy as np
import cobra
import scipy.stats
#import cplex
# %matplotlib inline

import matplotlib
from matplotlib import pyplot as plt
from matplotlib.offsetbox import (TextArea, DrawingArea, OffsetImage,
                                  AnnotationBbox)
from matplotlib.cbook import get_sample_data
import matplotlib.image as mpimg

from edd_utils import login, export_study, export_metadata

# %% [markdown]
# ##### **Load data**

# %%
# Study to Download
study_slug = 'biodesign_yoneda_set3_reprocessed'
# EDD server
edd_server = 'public-edd.jbei.org'
user       = 'schenkch'

# %%
session = login(edd_server=edd_server, user=user)

df = export_study(session, study_slug, edd_server=edd_server)
#df.head()
# Out:
# Password for schenkch:  ···············
# HBox(children=(FloatProgress(value=0.0, max=192297.0), HTML(value='')))

# %% [markdown]
# ##### **Filter transcriptomics data from all EDD data into different dataframes**

# %%
df_Trans = df[df['Protocol'].str.contains('Transcriptomics')]
df_Trans.head()
# Out:
#    Study ID                         Study Name  Line ID        Line Name  \
# 0     14400  Biodesign_Yoneda_set3_reprocessed    15006   EVOL33-LN-G-R1
# 1     14400  Biodesign_Yoneda_set3_reprocessed    15007   EVOL33-LN-G-R2
# 2     14400  Biodesign_Yoneda_set3_reprocessed    15008   EVOL33-LN-G-R3
# 3     14400  Biodesign_Yoneda_set3_reprocessed    14991  EVOL33-LN-LP-R1
# 4     14400  Biodesign_Yoneda_set3_reprocessed    14992  EVOL33-LN-LP-R2
#
#                                     Line Description         Protocol  \
# 0  R. Opacus adaptively evolved strain1 with 1.0 ...  Transcriptomics
# 1  R. Opacus adaptively evolved strain1 with 1.0 ...  Transcriptomics
# 2  R. Opacus adaptively evolved strain1 with 1.0 ...  Transcriptomics
# 3  R. Opacus adaptively evolved strain1 with 0.75...  Transcriptomics
# 4  R. Opacus adaptively evolved strain1 with 0.75...  Transcriptomics
#
#    Assay ID       Assay Name Formal Type Measurement Type  Compartment Units  \
# 0     15030   EVOL33-LN-G-R1         NaN   WP_000104864_1            0  FPKM
# 1     15031   EVOL33-LN-G-R2         NaN   WP_000104864_1            0  FPKM
# 2     15032   EVOL33-LN-G-R3         NaN   WP_000104864_1            0  FPKM
# 3     15015  EVOL33-LN-LP-R1         NaN   WP_000104864_1            0  FPKM
# 4     15016  EVOL33-LN-LP-R2         NaN   WP_000104864_1            0  FPKM
#
#    Value  Hours
# 0    0.0   14.0
# 1    0.0   14.0
# 2    0.0   14.0
# 3    0.0   24.0
# 4    0.0   24.0

# %% [markdown]
# ##### **Load Genome Scale Model**

# %%
file_name =  '../GSMs/Ropacus_annotated_curated_with_phenol_custom_biomass.xml'
model = cobra.io.read_sbml_model(file_name)

# %% [markdown]
# ##### **Import SPOT Code**

# %%
OptlangDir = '../EFLUX2_SPOT'
sys.path.append(OptlangDir)
from ensemblemethods import SPOT

# %% [markdown]
# ##### **Transform data to dataframe with just index as gene identifiers and one column for values**
# ##### !!!!TODO: Generalize for multiple time points

# %%
#Function to construct df from EFLUX2 functions: Needs to be modified for multiple time points!!!!!
def construct_trans_df(transdata, linename):
    transdataWTPR1 = transdata[transdata['Line Name']==linename]
    transdataWTPR1new = transdataWTPR1.filter(['Value', 'Measurement Type'])
    transdataWTPR1new2 = transdataWTPR1new.set_index('Measurement Type')
    return transdataWTPR1new2

# %% [markdown]
# #### **SPOT Predictions**

# %%
#Function for EFLUX2 and SPOT Predictions:
def spot_pred(model, transcriptdf, linename, substrate, sub_uptake_rate=100):    
    with model:
        medium = model.medium
        if substrate=='phenol':
            model.objective = 'Growth_Phenol'
            medium = {key:1000 for (key,value) in model.medium.items()}
            model.reactions.get_by_id('Growth_Glucose').upper_bound = 0
            model.reactions.get_by_id('Growth_Glucose').lower_bound = 0
            model.reactions.get_by_id('Growth').upper_bound = 0
            model.reactions.get_by_id('Growth').lower_bound = 0
            medium["EX_glc__D_e"] = 0
            #medium["EX_phenol_e"] = sub_uptake_rate
            #model.reactions.get_by_id('EX_phenol_e').upper_bound = -sub_uptake_rate
            #model.reactions.get_by_id('EX_phenol_e').lower_bound = -sub_uptake_rate
            model.reactions.get_by_id('EX_glc__D_e').upper_bound = 0
            model.reactions.get_by_id('EX_glc__D_e').lower_bound = 0
            #medium["EX_phenol_e"] = sub_uptake_rate
        elif substrate=='glucose':
            model.objective = 'Growth_Glucose'
            medium = {key:1000 for (key,value) in model.medium.items()}
            model.reactions.get_by_id('Growth_Phenol').upper_bound = 0
            model.reactions.get_by_id('Growth_Phenol').lower_bound = 0
            model.reactions.get_by_id('Growth').upper_bound = 0
            model.reactions.get_by_id('Growth').lower_bound = 0
            #medium["EX_glc__D_e"] = sub_uptake_rate
            medium["EX_phenol_e"] = 0
            #model.reactions.get_by_id('EX_glc__D_e').upper_bound = -sub_uptake_rate
            #model.reactions.get_by_id('EX_glc__D_e').lower_bound = -sub_uptake_rate
            model.reactions.get_by_id('EX_phenol_e').upper_bound = 0
            model.reactions.get_by_id('EX_phenol_e').lower_bound = 0
        else:
            print('Unknown substrate: Please choose among phenol and glucose')
        model.medium = medium
        spotsol = SPOT(model, transcriptdf)
        display(model.medium)
    return spotsol

# %%
#Function for predictions for three replicates and averaging the solutions and calculating the standard deviation:
def spot_pred_for_three_reps(model, transcriptdf, linename1, linename2, linename3, substrate):
    #call prediction functions for individual spot predictions for all 3 replicates:
    transdata_R1 = construct_trans_df(transcriptdf, linename1)
    transdata_R2 = construct_trans_df(transcriptdf, linename2)
    transdata_R3 = construct_trans_df(transcriptdf, linename3)
 
    spotsol_R1 = spot_pred(model, transdata_R1, linename1, substrate)
    spotsol_R2 = spot_pred(model, transdata_R2, linename2, substrate)
    spotsol_R3 = spot_pred(model, transdata_R3, linename3, substrate)
    
    #spot calculations:
    spotsol_R1_df = pd.DataFrame(spotsol_R1, columns=['fluxes'])
    spotsol_R2_df = pd.DataFrame(spotsol_R2, columns=['fluxes'])
    spotsol_R3_df = pd.DataFrame(spotsol_R3, columns=['fluxes'])
    spotsol_all = pd.concat([spotsol_R1_df, spotsol_R2_df, spotsol_R3_df], axis=1)
    
    spotsol = pd.DataFrame(spotsol_all.mean(axis=1), columns=['fluxes'])
    spotsol_std = spotsol_all.std(axis=1)
    
    return spotsol, spotsol_std

# %%
spotsol, spotsol_std = spot_pred_for_three_reps(model, df_Trans, 'WT-LN-G-R1', 'WT-LN-G-R2','WT-LN-G-R3', 'glucose')
# Out:
# {'EX_glc__D_e': 1000,
#  'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000}
# {'EX_glc__D_e': 1000,
#  'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000}
# {'EX_glc__D_e': 1000,
#  'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000}
# {'EX_glc__D_e': 1000,
#  'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000}
# {'EX_glc__D_e': 1000,
#  'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000}
# {'EX_glc__D_e': 1000,
#  'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000}

# %% [markdown]
# ##### **Save solution to data frame**

# %%
spotsoldf = pd.DataFrame(spotsol, columns=['fluxes'])
spotsolstddf = pd.DataFrame(spotsol_std, columns=['stds'])

# %%
spotsoldf.loc['Growth_Glucose']
# Out:
# fluxes   -0.000001
# Name: Growth_Glucose, dtype: float64

# %%
for ind in spotsoldf.index:
    if 'Growth' in str(ind):
        display(ind)
# Out:
# 'Growth'
# 'Growth_Phenol'
# 'Growth_Glucose'

# %%
spotsoldf.loc['Growth_Phenol']
# Out:
# fluxes    0.0
# Name: Growth_Phenol, dtype: float64

# %% [markdown]
# ##### **Check External Metabolites solution**

# %%
exchange_list = []
for ind in spotsoldf.index:
    if 'EX_' in str(ind):
        exchange_list.append(ind)

# %%
spotsoldf.loc[exchange_list,:]
for i in exchange_list:
    if abs(spotsoldf.loc[i,:].values)>=0.0001:
        display(spotsoldf.loc[i,:])
# Out:
# fluxes   -0.008965
# Name: EX_glc__D_e, dtype: float64
# fluxes    0.034954
# Name: EX_h2o_e, dtype: float64
# fluxes    0.012618
# Name: EX_h_e, dtype: float64
# fluxes    0.006347
# Name: EX_succ_e, dtype: float64
# fluxes    0.028921
# Name: EX_co2_e, dtype: float64
# fluxes   -0.032086
# Name: EX_o2_e, dtype: float64

# %% [markdown]
# #### **Plot solutions: Comparison of SPOT predictions and 13c measurements**

# %% [markdown]
# ##### **Add Glucose SPOT flux values to glucose fluxes dataframe**

# %%
def get_flux_value(reaction_id, solution):
    if reaction_id.startswith('reverse_'):
        reaction_id = reaction_id.split('reverse_')[1]
        return -1*solution.fluxes[reaction_id]
    else:
        return solution.fluxes[reaction_id]
def get_std_value(reaction_id, solution):
    if reaction_id.startswith('reverse_'):
        reaction_id = reaction_id.split('reverse_')[1]
        return -1*solution.stds[reaction_id]
    else:
        return solution.stds[reaction_id]

# %% [markdown]
# ##### **Scale up solution to compare with 13C MFA measurements**

# %%
def scale_predictions(observed_fluxes, predictions, stdpredictions, substrate, method):
    scalepred_stds = pd.DataFrame(index=stdpredictions.index, columns= ['stds'], dtype=np.float64)
    scalepred_fluxes = pd.DataFrame(index=predictions.index, columns= ['fluxes'], dtype=np.float64)
    if substrate == 'phenol':
        phenoluptakerow = observed_fluxes[observed_fluxes['Pathway']=='Phenol Uptake']
        sourceuptake = float(phenoluptakerow['Flux'])
        scalepred_fluxes = predictions*(sourceuptake/(-1*predictions.loc['EX_phenol_e']))
    elif substrate == 'glucose':
        glucoseuptakerow = observed_fluxes[observed_fluxes['Pathway']=='Glucose Uptake']
        sourceuptake = float(glucoseuptakerow['Flux'])
        scalepred_fluxes = predictions*(sourceuptake/(-1*predictions.loc['EX_glc__D_e']))
    else:   
        print('Unknown Substrate')
    for ind in stdpredictions.index:
        if abs(stdpredictions.loc[ind,'stds'])<1e-5:
            scalepred_stds.loc[ind,'stds'] = stdpredictions.loc[ind,'stds']
        else:
            scalepred_stds.loc[ind,'stds'] = (stdpredictions.loc[ind,'stds']/predictions.loc[ind,'fluxes'])*scalepred_fluxes.loc[ind, 'fluxes']
    return scalepred_fluxes, scalepred_stds

# %% [markdown]
# ##### **Add predictions to 13c data frame**

# %%
def add_pred_fluxes_to_13c_df(observed_fluxes, predictions, stdpredictions, substrate, method, strain):
    predicted_fluxes = []
    predicted_stds = []
    scalepred_fluxes, scalepred_stds = scale_predictions(observed_fluxes, predictions, stdpredictions, substrate, method)
    for _, row in observed_fluxes.iterrows():
        reactions = row['Forward Reactions']
        flux_value_pred = 0
        std_value_pred = 0
        for x in [x.strip('() ') for x in reactions.split(' or ')]:
            and_split = [y.strip('() ') for y in x.split(' and ')]
            flux_value_pred += min([get_flux_value(v, scalepred_fluxes) for v in and_split])
            std_value_pred += min([get_std_value(v,scalepred_stds) for v in and_split])
        predicted_fluxes.append(flux_value_pred)
        predicted_stds.append(std_value_pred)

    observed_fluxes[str(method) + ' ' + str(strain) + ' Value'] = predicted_fluxes
    observed_fluxes[str(method) + ' ' + str(strain) + ' std Value'] = predicted_stds
    
    return observed_fluxes

# %% [markdown]
# ##### **Load 13cdata**

# %% [markdown]
# #####  **Get 13C MFA measured fluxes for phenol**

# %%
glucose_fluxes = pd.read_csv('../13C_flux_data/13C_glucose_flux_data.csv')

# Remove rows that do not have a mapping to the GSM
glucose_fluxes.dropna(inplace=True)
print(f'There are {len(glucose_fluxes)} fluxes that can be compared between the MFA and FBA')
glucose_fluxes
# Out:
# There are 32 fluxes that can be compared between the MFA and FBA
#                       Pathway  \
# 0              Glucose Uptake
# 1                 EMP Pathway
# 2                 EMP Pathway
# 3                 EMP Pathway
# 4                 EMP Pathway
# 5                 EMP Pathway
# 6                 EMP Pathway
# 7                 EMP Pathway
# 8                 EMP Pathway
# 9                 EMP Pathway
# 10  Pentose Phosphate Pathway
# 11  Pentose Phosphate Pathway
# 12  Pentose Phosphate Pathway
# 13  Pentose Phosphate Pathway
# 14  Pentose Phosphate Pathway
# 15  Pentose Phosphate Pathway
# 16  Pentose Phosphate Pathway
# 17  Pentose Phosphate Pathway
# 18  Pentose Phosphate Pathway
# 19                 ED Pathway
# 20                 ED Pathway
# 21                  TCA Cycle
# 22                  TCA Cycle
# 23                  TCA Cycle
# 24                  TCA Cycle
# 25                  TCA Cycle
# 26                  TCA Cycle
# 27                  TCA Cycle
# 28                  TCA Cycle
# 29                  TCA Cycle
# 30           Glyoxylate Shunt
# 31           Glyoxylate Shunt
#
#                                     Forward Reactions  \
# 0                                 reverse_EX_glc__D_e
# 1                                                 PGI
# 2                                  PFK or reverse_FBP
# 3                                                 FBA
# 4                                                 TPI
# 5                                                GAPD
# 6                                         reverse_PGK
# 7                                PGM_1 or reverse_PGM
# 8                                                 ENO
# 9   reverse_PPS or FRUpts2pp or SBTpts or MNLpts o...
# 10                                    G6PDH2r and PGL
# 11                                                GND
# 12                                                RPE
# 13                                        reverse_RPI
# 14                                               TKT2
# 15                                               TKT2
# 16                                               TKT1
# 17                                               TALA
# 18                                       reverse_TALA
# 19                                                EDA
# 20                                                EDD
# 21                                                PDH
# 22                                 CS or reverse_CITL
# 23                      ACONT or ( ACONTa and ACONTb)
# 24                                    ICDHx or ICDHyr
# 25                                     AKGDH or OOR3r
# 26  3OADPCOAT or OCOAT3r or SUCBZT1 or SUCBZT2 or ...
# 27  SUCDi or reverse_FRD2 or reverse_FRD3 or rever...
# 28                                                FUM
# 29                     MDH or MDH3 or MDH2 or DMALRED
# 30                                                ICL
# 31                                               MALS
#
#                        Reaction Location on map    Flux  \
# 0         Gluc.ext + ATP -> G6P       (50, 460)  100.00
# 1                   G6P <-> F6P     (-150, 430)   -1.61
# 2              F6P + ATP -> FBP     (-220, 195)    0.00
# 3            FBP <-> DHAP + GAP     (-140, 115)    0.00
# 4                  DHAP <-> GAP     (-270, 150)    0.00
# 5                 GAP <-> G1,3P      (-220, 30)   86.56
# 6    G1,3P <-> 3PG + ATP + NADH     (-220, -55)   86.56
# 7                   3PG <-> 2PG    (-220, -135)   78.52
# 8                   2PG <-> PEP    (-220, -215)   78.52
# 9             PEP <-> Pyr + ATP    (-220, -295)   19.02
# 10          G6P <-> 6PG + NADPH       (50, 380)  100.00
# 11   6PG <-> Ru5P + CO2 + NADPH      (275, 350)    6.62
# 12                 Ru5P <-> X5P      (380, 190)    2.12
# 13                 Ru5P <-> R5P      (270, 230)    4.50
# 14           X5P <-> TKC2 + GAP      (270, 100)    2.12
# 15           TKC2 + E4P <-> F6P       (10, 280)    0.15
# 16           TKC2 + R5P <-> S7P      (120, 230)    1.96
# 17           TAC3 + GAP <-> F6P      (-70, 190)    1.96
# 18           S7P <-> TAC3 + E4P       (50, 230)    1.97
# 19                 6PG <-> KDPG     (-300, 350)   93.38
# 20           KDPG <-> Pyr + GAP      (-300, 50)   93.38
# 21   Pyr <-> AcCoA + CO2 + NADH    (-220, -370)  135.41
# 22          OAC + AcCoA <-> Cit     (-55, -340)   69.04
# 23                 Cit <-> ICit     (145, -310)   69.04
# 24   ICit <-> AKG + CO2 + NADPH     (290, -310)   69.04
# 25  AKG <-> SucCoA + CO2 + NADH     (290, -195)   61.60
# 26         SucCoA <-> Suc + ATP      (290, -55)   59.88
# 27          Suc <-> Fum + FADH2      (160, -55)   61.60
# 28                  Fum <-> Mal       (10, -55)   63.27
# 29           Mal <-> OAC + NADH     (-60, -180)   25.97
# 30          ICit -> Glyox + Suc     (180, -140)    0.00
# 31         Glyox + AcCoA -> Mal      (90, -140)    0.00
#
#     90% Confidence Lower Bound  90% Confidence Upper Bound
# 0                       100.00                      100.00
# 1                        -2.09                        1.42
# 2                         0.00                        1.91
# 3                         0.00                        1.91
# 4                         0.00                        1.91
# 5                        82.61                       88.84
# 6                        82.61                       88.84
# 7                        71.65                       81.26
# 8                        71.65                       81.26
# 9                       -10.89                       75.15
# 10                       96.96                      100.00
# 11                        2.07                       10.92
# 12                       -0.89                        4.37
# 13                        2.95                        6.55
# 14                       -0.89                        4.37
# 15                       -1.36                        1.11
# 16                        0.46                        3.34
# 17                        0.46                        3.34
# 18                        0.46                        3.34
# 19                       89.08                       94.98
# 20                       89.08                       94.98
# 21                      116.26                      196.60
# 22                       58.52                       82.65
# 23                       58.52                       82.65
# 24                       10.08                       82.65
# 25                        2.27                       75.99
# 26                        0.87                       74.45
# 27                       50.51                       75.99
# 28                       22.17                       77.49
# 29                      -50.27                       78.90
# 30                        0.00                       60.46
# 31                        0.00                       60.46

# %% [markdown]
# ##### **Add  Glucose EFLUX2 and SPOT flux values to phenol fluxes dataframe**

# %%
obspred_fluxes = add_pred_fluxes_to_13c_df(glucose_fluxes, spotsoldf, spotsolstddf, 'glucose', 'SPOT', 'WT')

# %%
obspred_fluxes
# Out:
#                       Pathway  \
# 0              Glucose Uptake
# 1                 EMP Pathway
# 2                 EMP Pathway
# 3                 EMP Pathway
# 4                 EMP Pathway
# 5                 EMP Pathway
# 6                 EMP Pathway
# 7                 EMP Pathway
# 8                 EMP Pathway
# 9                 EMP Pathway
# 10  Pentose Phosphate Pathway
# 11  Pentose Phosphate Pathway
# 12  Pentose Phosphate Pathway
# 13  Pentose Phosphate Pathway
# 14  Pentose Phosphate Pathway
# 15  Pentose Phosphate Pathway
# 16  Pentose Phosphate Pathway
# 17  Pentose Phosphate Pathway
# 18  Pentose Phosphate Pathway
# 19                 ED Pathway
# 20                 ED Pathway
# 21                  TCA Cycle
# 22                  TCA Cycle
# 23                  TCA Cycle
# 24                  TCA Cycle
# 25                  TCA Cycle
# 26                  TCA Cycle
# 27                  TCA Cycle
# 28                  TCA Cycle
# 29                  TCA Cycle
# 30           Glyoxylate Shunt
# 31           Glyoxylate Shunt
#
#                                     Forward Reactions  \
# 0                                 reverse_EX_glc__D_e
# 1                                                 PGI
# 2                                  PFK or reverse_FBP
# 3                                                 FBA
# 4                                                 TPI
# 5                                                GAPD
# 6                                         reverse_PGK
# 7                                PGM_1 or reverse_PGM
# 8                                                 ENO
# 9   reverse_PPS or FRUpts2pp or SBTpts or MNLpts o...
# 10                                    G6PDH2r and PGL
# 11                                                GND
# 12                                                RPE
# 13                                        reverse_RPI
# 14                                               TKT2
# 15                                               TKT2
# 16                                               TKT1
# 17                                               TALA
# 18                                       reverse_TALA
# 19                                                EDA
# 20                                                EDD
# 21                                                PDH
# 22                                 CS or reverse_CITL
# 23                      ACONT or ( ACONTa and ACONTb)
# 24                                    ICDHx or ICDHyr
# 25                                     AKGDH or OOR3r
# 26  3OADPCOAT or OCOAT3r or SUCBZT1 or SUCBZT2 or ...
# 27  SUCDi or reverse_FRD2 or reverse_FRD3 or rever...
# 28                                                FUM
# 29                     MDH or MDH3 or MDH2 or DMALRED
# 30                                                ICL
# 31                                               MALS
#
#                        Reaction Location on map    Flux  \
# 0         Gluc.ext + ATP -> G6P       (50, 460)  100.00
# 1                   G6P <-> F6P     (-150, 430)   -1.61
# 2              F6P + ATP -> FBP     (-220, 195)    0.00
# 3            FBP <-> DHAP + GAP     (-140, 115)    0.00
# 4                  DHAP <-> GAP     (-270, 150)    0.00
# 5                 GAP <-> G1,3P      (-220, 30)   86.56
# 6    G1,3P <-> 3PG + ATP + NADH     (-220, -55)   86.56
# 7                   3PG <-> 2PG    (-220, -135)   78.52
# 8                   2PG <-> PEP    (-220, -215)   78.52
# 9             PEP <-> Pyr + ATP    (-220, -295)   19.02
# 10          G6P <-> 6PG + NADPH       (50, 380)  100.00
# 11   6PG <-> Ru5P + CO2 + NADPH      (275, 350)    6.62
# 12                 Ru5P <-> X5P      (380, 190)    2.12
# 13                 Ru5P <-> R5P      (270, 230)    4.50
# 14           X5P <-> TKC2 + GAP      (270, 100)    2.12
# 15           TKC2 + E4P <-> F6P       (10, 280)    0.15
# 16           TKC2 + R5P <-> S7P      (120, 230)    1.96
# 17           TAC3 + GAP <-> F6P      (-70, 190)    1.96
# 18           S7P <-> TAC3 + E4P       (50, 230)    1.97
# 19                 6PG <-> KDPG     (-300, 350)   93.38
# 20           KDPG <-> Pyr + GAP      (-300, 50)   93.38
# 21   Pyr <-> AcCoA + CO2 + NADH    (-220, -370)  135.41
# 22          OAC + AcCoA <-> Cit     (-55, -340)   69.04
# 23                 Cit <-> ICit     (145, -310)   69.04
# 24   ICit <-> AKG + CO2 + NADPH     (290, -310)   69.04
# 25  AKG <-> SucCoA + CO2 + NADH     (290, -195)   61.60
# 26         SucCoA <-> Suc + ATP      (290, -55)   59.88
# 27          Suc <-> Fum + FADH2      (160, -55)   61.60
# 28                  Fum <-> Mal       (10, -55)   63.27
# 29           Mal <-> OAC + NADH     (-60, -180)   25.97
# 30          ICit -> Glyox + Suc     (180, -140)    0.00
# 31         Glyox + AcCoA -> Mal      (90, -140)    0.00
#
#     90% Confidence Lower Bound  90% Confidence Upper Bound  SPOT WT Value  \
# 0                       100.00                      100.00     100.000000
# 1                        -2.09                        1.42     100.111373
# 2                         0.00                        1.91      70.053129
# 3                         0.00                        1.91      70.039672
# 4                         0.00                        1.91     100.385611
# 5                        82.61                       88.84     200.799936
# 6                        82.61                       88.84     200.799936
# 7                        71.65                       81.26     200.799863
# 8                        71.65                       81.26     200.883173
# 9                       -10.89                       75.15      52.540800
# 10                       96.96                      100.00      -0.041765
# 11                        2.07                       10.92      -0.008289
# 12                       -0.89                        4.37       0.137819
# 13                        2.95                        6.55      -0.137342
# 14                       -0.89                        4.37       0.086497
# 15                       -1.36                        1.11       0.086497
# 16                        0.46                        3.34       0.058973
# 17                        0.46                        3.34       0.072100
# 18                        0.46                        3.34      -0.072100
# 19                       89.08                       94.98       0.037191
# 20                       89.08                       94.98       0.028933
# 21                      116.26                      196.60       0.113282
# 22                       58.52                       82.65     142.472389
# 23                       58.52                       82.65     142.486682
# 24                       10.08                       82.65      87.759957
# 25                        2.27                       75.99      -0.026546
# 26                        0.87                       74.45      82.104756
# 27                       50.51                       75.99      66.034164
# 28                       22.17                       77.49      66.031696
# 29                      -50.27                       78.90      66.039183
# 30                        0.00                       60.46      54.726725
# 31                        0.00                       60.46      -0.007155
#
#     SPOT WT std Value
# 0       -4.704920e+01
# 1        4.711850e+01
# 2        2.905634e+01
# 3        2.905551e+01
# 4        4.723929e+01
# 5        9.448144e+01
# 6       -9.448144e+01
# 7       -1.492781e+01
# 8        9.450630e+01
# 9        3.447989e+01
# 10       1.031262e-06
# 11       5.579045e-07
# 12       8.506375e-06
# 13      -8.576446e-06
# 14       5.204148e-06
# 15       5.204148e-06
# 16       3.592786e-06
# 17       4.323390e-06
# 18      -4.323390e-06
# 19       1.758575e-06
# 20       1.404357e-06
# 21       1.407419e-01
# 22       4.882204e+01
# 23       4.883717e+01
# 24       5.119806e+01
# 25       1.492636e-06
# 26      -5.411516e+01
# 27       3.058975e+01
# 28       3.124120e+01
# 29       3.122525e+01
# 30       2.414652e+01
# 31       1.010539e-06

# %% [markdown]
# #### Plot SPOT vs 13C MFA

# %%
def scatterplotcomp_obs_vs_pred(obspred_fluxes, substrate, method, linename, strain):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.plot(ax.get_xlim(), ax.get_ylim(), ls="--", c=".3")

    for pathway in list(set(obspred_fluxes['Pathway'])):
        pathway_df = obspred_fluxes[obspred_fluxes['Pathway'] == pathway]

        measured_flux_list = list(pathway_df['Flux'])
        simulated_flux_list = list(pathway_df[str(method) + ' ' + str(strain) + ' Value'])

        ax.scatter(measured_flux_list, simulated_flux_list, label=pathway)


    # Dashed line
    x = np.linspace(*ax.get_xlim())
    ax.plot(x, x, ls="--", c=".3")
    if substrate=='phenol':
        sub = 'Phenol'
    elif substrate=='glucose':
        sub = 'Glucose'
    else:
        print("Unknown substrate")
    plt.title(r''+str(sub)+  ' 13C MFA vs. '+ str(method) + ' Fluxes for ' +linename, fontSize=20)
    plt.xlabel(r'13C MFA flux (per 100 mmol '+str(sub)+  ' uptake)')
    plt.ylabel(r''+ str(method) + ' flux (per 100 mmol of '+str(sub)+  ' uptake)')
    plt.legend()
    plt.show()

# %%
scatterplotcomp_obs_vs_pred(obspred_fluxes, substrate='glucose', method='SPOT', linename='WT-LN-G', strain='WT')

# %%
import matplotlib
import matplotlib.cm as cm
def scatterplotcomp_obs_vs_pred_withstd(obspred_fluxes, substrate, method, linename, strain):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.plot(ax.get_xlim(), ax.get_ylim(), ls="--", c=".3")

    for pathway in list(set(obspred_fluxes['Pathway'])):
        pathway_df = obspred_fluxes[obspred_fluxes['Pathway'] == pathway]
        
        measured_flux_list = list(pathway_df['Flux'])
        simulated_flux_list = list(pathway_df[str(method) + ' ' +  str(strain) + ' Value'])
        simulated_std_list = list(pathway_df[str(method) + ' ' +  str(strain) + ' std Value'])
        measured_std_list = list(pathway_df['90% Confidence Upper Bound']-pathway_df['Flux'])
        
        
        sc = ax.scatter(measured_flux_list, simulated_flux_list, label=pathway)
        ax.errorbar(
                measured_flux_list, simulated_flux_list, xerr=[std1 for std1 in measured_std_list], yerr=[1.9*std for std in simulated_std_list],
                    ecolor="gray", ls='none',
                    alpha=0.8)

    # Dashed line
    x = np.linspace(*ax.get_xlim())
    ax.plot(x, x, ls="--", c=".3")
    if substrate=='phenol':
        sub = 'Phenol'
    elif substrate=='glucose':
        sub = 'Glucose'
    else:
        print("Unknown substrate")
    plt.title(r''+str(sub)+  ' 13C MFA vs. '+ str(method) + ' Fluxes for ' +linename, fontSize=20)
    plt.xlabel(r'13C MFA flux (per 100 mmol '+str(sub)+  ' uptake)')
    plt.ylabel(r''+ str(method) + ' flux (per 100 mmol of '+str(sub)+  ' uptake)')
    plt.legend()
    plt.show()

# %%
scatterplotcomp_obs_vs_pred_withstd(obspred_fluxes, substrate='glucose', method='SPOT',linename='WT-LN-G', strain='WT')

# %% [markdown]
# ##### **EVOL33-LN-G**

# %%
spotsol_evol33, spotsol_std_evol33 = spot_pred_for_three_reps(model, df_Trans, 'EVOL33-LN-G-R1', 'EVOL33-LN-G-R2','EVOL33-LN-G-R3', 'glucose')
# Out:
# {'EX_glc__D_e': 1000,
#  'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000}
# {'EX_glc__D_e': 1000,
#  'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000}
# {'EX_glc__D_e': 1000,
#  'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000}
# {'EX_glc__D_e': 1000,
#  'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000}
# {'EX_glc__D_e': 1000,
#  'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000}
# {'EX_glc__D_e': 1000,
#  'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000}

# %% [markdown]
# ##### **Save solution to data frame**

# %%
spotsoldf_evol33 = pd.DataFrame(spotsol_evol33, columns=['fluxes'])
spotsolstddf_evol33 = pd.DataFrame(spotsol_std_evol33, columns=['stds'])

# %% [markdown]
# ##### **Add  Glucose EVOL33 EFLUX2 and SPOT flux values to glucosel fluxes dataframe**

# %%
obspred_fluxes = add_pred_fluxes_to_13c_df(obspred_fluxes, spotsoldf_evol33, spotsolstddf_evol33, 'glucose', 'SPOT', 'EVOL33')

# %%
obspred_fluxes
# Out:
#                       Pathway  \
# 0              Glucose Uptake
# 1                 EMP Pathway
# 2                 EMP Pathway
# 3                 EMP Pathway
# 4                 EMP Pathway
# 5                 EMP Pathway
# 6                 EMP Pathway
# 7                 EMP Pathway
# 8                 EMP Pathway
# 9                 EMP Pathway
# 10  Pentose Phosphate Pathway
# 11  Pentose Phosphate Pathway
# 12  Pentose Phosphate Pathway
# 13  Pentose Phosphate Pathway
# 14  Pentose Phosphate Pathway
# 15  Pentose Phosphate Pathway
# 16  Pentose Phosphate Pathway
# 17  Pentose Phosphate Pathway
# 18  Pentose Phosphate Pathway
# 19                 ED Pathway
# 20                 ED Pathway
# 21                  TCA Cycle
# 22                  TCA Cycle
# 23                  TCA Cycle
# 24                  TCA Cycle
# 25                  TCA Cycle
# 26                  TCA Cycle
# 27                  TCA Cycle
# 28                  TCA Cycle
# 29                  TCA Cycle
# 30           Glyoxylate Shunt
# 31           Glyoxylate Shunt
#
#                                     Forward Reactions  \
# 0                                 reverse_EX_glc__D_e
# 1                                                 PGI
# 2                                  PFK or reverse_FBP
# 3                                                 FBA
# 4                                                 TPI
# 5                                                GAPD
# 6                                         reverse_PGK
# 7                                PGM_1 or reverse_PGM
# 8                                                 ENO
# 9   reverse_PPS or FRUpts2pp or SBTpts or MNLpts o...
# 10                                    G6PDH2r and PGL
# 11                                                GND
# 12                                                RPE
# 13                                        reverse_RPI
# 14                                               TKT2
# 15                                               TKT2
# 16                                               TKT1
# 17                                               TALA
# 18                                       reverse_TALA
# 19                                                EDA
# 20                                                EDD
# 21                                                PDH
# 22                                 CS or reverse_CITL
# 23                      ACONT or ( ACONTa and ACONTb)
# 24                                    ICDHx or ICDHyr
# 25                                     AKGDH or OOR3r
# 26  3OADPCOAT or OCOAT3r or SUCBZT1 or SUCBZT2 or ...
# 27  SUCDi or reverse_FRD2 or reverse_FRD3 or rever...
# 28                                                FUM
# 29                     MDH or MDH3 or MDH2 or DMALRED
# 30                                                ICL
# 31                                               MALS
#
#                        Reaction Location on map    Flux  \
# 0         Gluc.ext + ATP -> G6P       (50, 460)  100.00
# 1                   G6P <-> F6P     (-150, 430)   -1.61
# 2              F6P + ATP -> FBP     (-220, 195)    0.00
# 3            FBP <-> DHAP + GAP     (-140, 115)    0.00
# 4                  DHAP <-> GAP     (-270, 150)    0.00
# 5                 GAP <-> G1,3P      (-220, 30)   86.56
# 6    G1,3P <-> 3PG + ATP + NADH     (-220, -55)   86.56
# 7                   3PG <-> 2PG    (-220, -135)   78.52
# 8                   2PG <-> PEP    (-220, -215)   78.52
# 9             PEP <-> Pyr + ATP    (-220, -295)   19.02
# 10          G6P <-> 6PG + NADPH       (50, 380)  100.00
# 11   6PG <-> Ru5P + CO2 + NADPH      (275, 350)    6.62
# 12                 Ru5P <-> X5P      (380, 190)    2.12
# 13                 Ru5P <-> R5P      (270, 230)    4.50
# 14           X5P <-> TKC2 + GAP      (270, 100)    2.12
# 15           TKC2 + E4P <-> F6P       (10, 280)    0.15
# 16           TKC2 + R5P <-> S7P      (120, 230)    1.96
# 17           TAC3 + GAP <-> F6P      (-70, 190)    1.96
# 18           S7P <-> TAC3 + E4P       (50, 230)    1.97
# 19                 6PG <-> KDPG     (-300, 350)   93.38
# 20           KDPG <-> Pyr + GAP      (-300, 50)   93.38
# 21   Pyr <-> AcCoA + CO2 + NADH    (-220, -370)  135.41
# 22          OAC + AcCoA <-> Cit     (-55, -340)   69.04
# 23                 Cit <-> ICit     (145, -310)   69.04
# 24   ICit <-> AKG + CO2 + NADPH     (290, -310)   69.04
# 25  AKG <-> SucCoA + CO2 + NADH     (290, -195)   61.60
# 26         SucCoA <-> Suc + ATP      (290, -55)   59.88
# 27          Suc <-> Fum + FADH2      (160, -55)   61.60
# 28                  Fum <-> Mal       (10, -55)   63.27
# 29           Mal <-> OAC + NADH     (-60, -180)   25.97
# 30          ICit -> Glyox + Suc     (180, -140)    0.00
# 31         Glyox + AcCoA -> Mal      (90, -140)    0.00
#
#     90% Confidence Lower Bound  90% Confidence Upper Bound  SPOT WT Value  \
# 0                       100.00                      100.00     100.000000
# 1                        -2.09                        1.42     100.111373
# 2                         0.00                        1.91      70.053129
# 3                         0.00                        1.91      70.039672
# 4                         0.00                        1.91     100.385611
# 5                        82.61                       88.84     200.799936
# 6                        82.61                       88.84     200.799936
# 7                        71.65                       81.26     200.799863
# 8                        71.65                       81.26     200.883173
# 9                       -10.89                       75.15      52.540800
# 10                       96.96                      100.00      -0.041765
# 11                        2.07                       10.92      -0.008289
# 12                       -0.89                        4.37       0.137819
# 13                        2.95                        6.55      -0.137342
# 14                       -0.89                        4.37       0.086497
# 15                       -1.36                        1.11       0.086497
# 16                        0.46                        3.34       0.058973
# 17                        0.46                        3.34       0.072100
# 18                        0.46                        3.34      -0.072100
# 19                       89.08                       94.98       0.037191
# 20                       89.08                       94.98       0.028933
# 21                      116.26                      196.60       0.113282
# 22                       58.52                       82.65     142.472389
# 23                       58.52                       82.65     142.486682
# 24                       10.08                       82.65      87.759957
# 25                        2.27                       75.99      -0.026546
# 26                        0.87                       74.45      82.104756
# 27                       50.51                       75.99      66.034164
# 28                       22.17                       77.49      66.031696
# 29                      -50.27                       78.90      66.039183
# 30                        0.00                       60.46      54.726725
# 31                        0.00                       60.46      -0.007155
#
#     SPOT WT std Value  SPOT EVOL33 Value  SPOT EVOL33 std Value
# 0       -4.704920e+01         100.000000          -4.356947e+01
# 1        4.711850e+01         100.087173           4.354607e+01
# 2        2.905634e+01          70.042595           2.710639e+01
# 3        2.905551e+01          70.031994           2.710869e+01
# 4        4.723929e+01         100.314984           4.345712e+01
# 5        9.448144e+01         200.660255           8.688614e+01
# 6       -9.448144e+01         200.660255          -8.688614e+01
# 7       -1.492781e+01         200.658283          -1.475124e+01
# 8        9.450630e+01         200.723597           8.684682e+01
# 9        3.447989e+01          61.598886           2.600548e+01
# 10       1.031262e-06          -0.032215           2.208691e-06
# 11       5.579045e-07          -0.004049           3.075055e-07
# 12       8.506375e-06           0.115268           6.467799e-06
# 13      -8.576446e-06          -0.112287          -6.308319e-06
# 14       5.204148e-06           0.071939           4.071483e-06
# 15       5.204148e-06           0.071939           4.071483e-06
# 16       3.592786e-06           0.050604           2.820904e-06
# 17       4.323390e-06           0.061132           3.452030e-06
# 18      -4.323390e-06          -0.061132          -3.452030e-06
# 19       1.758575e-06           0.030889           2.799180e-06
# 20       1.404357e-06           0.024676           2.469380e-06
# 21       1.407419e-01           0.013417           1.007189e-06
# 22       4.882204e+01         126.168435           6.051639e+01
# 23       4.883717e+01         126.179686           6.050782e+01
# 24       5.119806e+01          57.741218           2.885983e+01
# 25       1.492636e-06          -0.019767           1.251185e-06
# 26      -5.411516e+01          57.925816          -2.843865e+01
# 27       3.058975e+01          51.209615           2.046393e+01
# 28       3.124120e+01          51.227938           3.477059e+01
# 29       3.122525e+01          51.228714           3.477382e+01
# 30       2.414652e+01          68.438469           6.871232e+01
# 31       1.010539e-06          -0.006777           4.441318e-07

# %% [markdown]
# #### Plot SPOT vs 13C MFA

# %%
scatterplotcomp_obs_vs_pred(obspred_fluxes, substrate='glucose', method='SPOT', linename='EVOL33-LN-G', strain= 'EVOL33')

# %%
scatterplotcomp_obs_vs_pred_withstd(obspred_fluxes, substrate='glucose', method='SPOT',linename='EVOL33-LN-G', strain='EVOL33')

# %% [markdown]
# ##### **EVOL40-LN-G**

# %%
spotsol_evol40, spotsol_std_evol40 = spot_pred_for_three_reps(model, df_Trans, 'EVOL40-LN-G-R1', 'EVOL40-LN-G-R2','EVOL40-LN-G-R3', 'glucose')
# Out:
# {'EX_glc__D_e': 1000,
#  'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000}
# {'EX_glc__D_e': 1000,
#  'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000}
# {'EX_glc__D_e': 1000,
#  'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000}
# {'EX_glc__D_e': 1000,
#  'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000}
# {'EX_glc__D_e': 1000,
#  'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000}
# {'EX_glc__D_e': 1000,
#  'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000}

# %% [markdown]
# ##### **Save solution to data frame**

# %%
spotsoldf_evol40 = pd.DataFrame(spotsol_evol40, columns=['fluxes'])
spotsolstddf_evol40 = pd.DataFrame(spotsol_std_evol40, columns=['stds'])

# %% [markdown]
# ##### **Add  Glucose EVOL40 EFLUX2 and SPOT flux values to glucose fluxes dataframe**

# %%
obspred_fluxes = add_pred_fluxes_to_13c_df(obspred_fluxes, spotsoldf_evol40, spotsolstddf_evol40, 'glucose', 'SPOT', 'EVOL40')

# %%
obspred_fluxes
# Out:
#                       Pathway  \
# 0              Glucose Uptake
# 1                 EMP Pathway
# 2                 EMP Pathway
# 3                 EMP Pathway
# 4                 EMP Pathway
# 5                 EMP Pathway
# 6                 EMP Pathway
# 7                 EMP Pathway
# 8                 EMP Pathway
# 9                 EMP Pathway
# 10  Pentose Phosphate Pathway
# 11  Pentose Phosphate Pathway
# 12  Pentose Phosphate Pathway
# 13  Pentose Phosphate Pathway
# 14  Pentose Phosphate Pathway
# 15  Pentose Phosphate Pathway
# 16  Pentose Phosphate Pathway
# 17  Pentose Phosphate Pathway
# 18  Pentose Phosphate Pathway
# 19                 ED Pathway
# 20                 ED Pathway
# 21                  TCA Cycle
# 22                  TCA Cycle
# 23                  TCA Cycle
# 24                  TCA Cycle
# 25                  TCA Cycle
# 26                  TCA Cycle
# 27                  TCA Cycle
# 28                  TCA Cycle
# 29                  TCA Cycle
# 30           Glyoxylate Shunt
# 31           Glyoxylate Shunt
#
#                                     Forward Reactions  \
# 0                                 reverse_EX_glc__D_e
# 1                                                 PGI
# 2                                  PFK or reverse_FBP
# 3                                                 FBA
# 4                                                 TPI
# 5                                                GAPD
# 6                                         reverse_PGK
# 7                                PGM_1 or reverse_PGM
# 8                                                 ENO
# 9   reverse_PPS or FRUpts2pp or SBTpts or MNLpts o...
# 10                                    G6PDH2r and PGL
# 11                                                GND
# 12                                                RPE
# 13                                        reverse_RPI
# 14                                               TKT2
# 15                                               TKT2
# 16                                               TKT1
# 17                                               TALA
# 18                                       reverse_TALA
# 19                                                EDA
# 20                                                EDD
# 21                                                PDH
# 22                                 CS or reverse_CITL
# 23                      ACONT or ( ACONTa and ACONTb)
# 24                                    ICDHx or ICDHyr
# 25                                     AKGDH or OOR3r
# 26  3OADPCOAT or OCOAT3r or SUCBZT1 or SUCBZT2 or ...
# 27  SUCDi or reverse_FRD2 or reverse_FRD3 or rever...
# 28                                                FUM
# 29                     MDH or MDH3 or MDH2 or DMALRED
# 30                                                ICL
# 31                                               MALS
#
#                        Reaction Location on map    Flux  \
# 0         Gluc.ext + ATP -> G6P       (50, 460)  100.00
# 1                   G6P <-> F6P     (-150, 430)   -1.61
# 2              F6P + ATP -> FBP     (-220, 195)    0.00
# 3            FBP <-> DHAP + GAP     (-140, 115)    0.00
# 4                  DHAP <-> GAP     (-270, 150)    0.00
# 5                 GAP <-> G1,3P      (-220, 30)   86.56
# 6    G1,3P <-> 3PG + ATP + NADH     (-220, -55)   86.56
# 7                   3PG <-> 2PG    (-220, -135)   78.52
# 8                   2PG <-> PEP    (-220, -215)   78.52
# 9             PEP <-> Pyr + ATP    (-220, -295)   19.02
# 10          G6P <-> 6PG + NADPH       (50, 380)  100.00
# 11   6PG <-> Ru5P + CO2 + NADPH      (275, 350)    6.62
# 12                 Ru5P <-> X5P      (380, 190)    2.12
# 13                 Ru5P <-> R5P      (270, 230)    4.50
# 14           X5P <-> TKC2 + GAP      (270, 100)    2.12
# 15           TKC2 + E4P <-> F6P       (10, 280)    0.15
# 16           TKC2 + R5P <-> S7P      (120, 230)    1.96
# 17           TAC3 + GAP <-> F6P      (-70, 190)    1.96
# 18           S7P <-> TAC3 + E4P       (50, 230)    1.97
# 19                 6PG <-> KDPG     (-300, 350)   93.38
# 20           KDPG <-> Pyr + GAP      (-300, 50)   93.38
# 21   Pyr <-> AcCoA + CO2 + NADH    (-220, -370)  135.41
# 22          OAC + AcCoA <-> Cit     (-55, -340)   69.04
# 23                 Cit <-> ICit     (145, -310)   69.04
# 24   ICit <-> AKG + CO2 + NADPH     (290, -310)   69.04
# 25  AKG <-> SucCoA + CO2 + NADH     (290, -195)   61.60
# 26         SucCoA <-> Suc + ATP      (290, -55)   59.88
# 27          Suc <-> Fum + FADH2      (160, -55)   61.60
# 28                  Fum <-> Mal       (10, -55)   63.27
# 29           Mal <-> OAC + NADH     (-60, -180)   25.97
# 30          ICit -> Glyox + Suc     (180, -140)    0.00
# 31         Glyox + AcCoA -> Mal      (90, -140)    0.00
#
#     90% Confidence Lower Bound  90% Confidence Upper Bound  SPOT WT Value  \
# 0                       100.00                      100.00     100.000000
# 1                        -2.09                        1.42     100.111373
# 2                         0.00                        1.91      70.053129
# 3                         0.00                        1.91      70.039672
# 4                         0.00                        1.91     100.385611
# 5                        82.61                       88.84     200.799936
# 6                        82.61                       88.84     200.799936
# 7                        71.65                       81.26     200.799863
# 8                        71.65                       81.26     200.883173
# 9                       -10.89                       75.15      52.540800
# 10                       96.96                      100.00      -0.041765
# 11                        2.07                       10.92      -0.008289
# 12                       -0.89                        4.37       0.137819
# 13                        2.95                        6.55      -0.137342
# 14                       -0.89                        4.37       0.086497
# 15                       -1.36                        1.11       0.086497
# 21           0.006849           2.547541e-07
# 22         137.538558           2.481931e+01
# 23         137.543439           2.482046e+01
# 24         135.784843           2.718762e+01
# 25          -0.009001           1.338895e-07
# 26         128.495088          -1.686640e+01
# 27          59.736687          -4.620253e+00
# 28          59.740779           2.030455e+01
# 29          59.742390           2.030266e+01
# 30           1.758596           3.050642e+00
# 31          -0.002873           2.232612e-07

# %% [markdown]
# #### Plot SPOT vs 13C MFA

# %%
scatterplotcomp_obs_vs_pred(obspred_fluxes, substrate='glucose', method='SPOT',linename='EVOL40-LN-G', strain='EVOL40')

# %%
scatterplotcomp_obs_vs_pred_withstd(obspred_fluxes, substrate='glucose', method='SPOT', linename='EVOL40-LN-G', strain='EVOL40')

# %% [markdown]
# ### Map glucose SPOT fluxes

# %%
def map_flux_results(data_df, flux_column):
    fig, ax = plt.subplots(figsize=(15, 20), dpi=50)
    xy = (0.5, 0.5)
    arr_img = plt.imread('./unlabeled_flux_map.png')
    imagebox = OffsetImage(arr_img)
    imagebox.image.axes = ax
    ab = AnnotationBbox(imagebox, xy)
    ax.add_artist(ab)

    for _, row in data_df.iterrows():
        if pd.isnull(row['Location on map'])!=True:
            location =  row['Location on map'].replace('(', '').replace(')', '')
            location_list = location.split(',')
            location_tuple = tuple((int(location_list[0]), int(location_list[1])))

            offsetbox = TextArea(f'{row[flux_column]:.1f}',textprops=dict(fontsize=22))
            ab = AnnotationBbox(offsetbox, xy,
                                xybox=location_tuple,
                                xycoords='data',
                                boxcoords="offset points",
                                frameon=False)
            ax.add_artist(ab)
    # Fix the display limits to see everything
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.set_xticks([])
    ax.set_yticks([])

    plt.show()

# %%
map_flux_results(obspred_fluxes, 'SPOT WT Value')

# %% [markdown]
# ### Get r<sup>2</sup>  values

# %%
# remove Energy molecule reactions as they are outliers
r_squared_df = glucose_fluxes[~glucose_fluxes['Reaction'].isin(['ATP -> ATP.ext', 'NADH <-> NADPH'])]

_, _, Spot_r, _, _ = scipy.stats.linregress(r_squared_df['Flux'], r_squared_df['SPOT WT Value'])

print(f'SPOT vs 13C-MFA r-squared: {Spot_r**2:.4F}')
# Out:
# SPOT vs 13C-MFA r-squared: 0.1239

# %%
r_squared_df
# Out:
#                       Pathway  \
# 0              Glucose Uptake
# 1                 EMP Pathway
# 2                 EMP Pathway
# 3                 EMP Pathway
# 4                 EMP Pathway
# 5                 EMP Pathway
# 6                 EMP Pathway
# 7                 EMP Pathway
# 8                 EMP Pathway
# 9                 EMP Pathway
# 10  Pentose Phosphate Pathway
# 11  Pentose Phosphate Pathway
# 12  Pentose Phosphate Pathway
# 13  Pentose Phosphate Pathway
# 14  Pentose Phosphate Pathway
# 15  Pentose Phosphate Pathway
# 16  Pentose Phosphate Pathway
# 17  Pentose Phosphate Pathway
# 18  Pentose Phosphate Pathway
# 19                 ED Pathway
# 20                 ED Pathway
# 21                  TCA Cycle
# 22                  TCA Cycle
# 23                  TCA Cycle
# 24                  TCA Cycle
# 25                  TCA Cycle
# 26                  TCA Cycle
# 27                  TCA Cycle
# 28                  TCA Cycle
# 29                  TCA Cycle
# 30           Glyoxylate Shunt
# 31           Glyoxylate Shunt
#
#                                     Forward Reactions  \
# 0                                 reverse_EX_glc__D_e
# 1                                                 PGI
# 2                                  PFK or reverse_FBP
# 3                                                 FBA
# 4                                                 TPI
# 5                                                GAPD
# 6                                         reverse_PGK
# 7                                PGM_1 or reverse_PGM
# 8                                                 ENO
# 9   reverse_PPS or FRUpts2pp or SBTpts or MNLpts o...
# 10                                    G6PDH2r and PGL
# 11                                                GND
# 12                                                RPE
# 13                                        reverse_RPI
# 14                                               TKT2
# 15                                               TKT2
# 16                                               TKT1
# 17                                               TALA
# 18                                       reverse_TALA
# 19                                                EDA
# 20                                                EDD
# 21                                                PDH
# 22                                 CS or reverse_CITL
# 23                      ACONT or ( ACONTa and ACONTb)
# 24                                    ICDHx or ICDHyr
# 25                                     AKGDH or OOR3r
# 26  3OADPCOAT or OCOAT3r or SUCBZT1 or SUCBZT2 or ...
# 27  SUCDi or reverse_FRD2 or reverse_FRD3 or rever...
# 28                                                FUM
# 29                     MDH or MDH3 or MDH2 or DMALRED
# 30                                                ICL
# 31                                               MALS
#
#                        Reaction Location on map    Flux  \
# 0         Gluc.ext + ATP -> G6P       (50, 460)  100.00
# 1                   G6P <-> F6P     (-150, 430)   -1.61
# 2              F6P + ATP -> FBP     (-220, 195)    0.00
# 3            FBP <-> DHAP + GAP     (-140, 115)    0.00
# 4                  DHAP <-> GAP     (-270, 150)    0.00
# 5                 GAP <-> G1,3P      (-220, 30)   86.56
# 6    G1,3P <-> 3PG + ATP + NADH     (-220, -55)   86.56
# 7                   3PG <-> 2PG    (-220, -135)   78.52
# 8                   2PG <-> PEP    (-220, -215)   78.52
# 9             PEP <-> Pyr + ATP    (-220, -295)   19.02
# 10          G6P <-> 6PG + NADPH       (50, 380)  100.00
# 11   6PG <-> Ru5P + CO2 + NADPH      (275, 350)    6.62
# 12                 Ru5P <-> X5P      (380, 190)    2.12
# 13                 Ru5P <-> R5P      (270, 230)    4.50
# 14           X5P <-> TKC2 + GAP      (270, 100)    2.12
# 15           TKC2 + E4P <-> F6P       (10, 280)    0.15
# 16           TKC2 + R5P <-> S7P      (120, 230)    1.96
# 17           TAC3 + GAP <-> F6P      (-70, 190)    1.96
# 18           S7P <-> TAC3 + E4P       (50, 230)    1.97
# 19                 6PG <-> KDPG     (-300, 350)   93.38
# 20           KDPG <-> Pyr + GAP      (-300, 50)   93.38
# 21   Pyr <-> AcCoA + CO2 + NADH    (-220, -370)  135.41
# 22          OAC + AcCoA <-> Cit     (-55, -340)   69.04
# 23                 Cit <-> ICit     (145, -310)   69.04
# 24   ICit <-> AKG + CO2 + NADPH     (290, -310)   69.04
# 25  AKG <-> SucCoA + CO2 + NADH     (290, -195)   61.60
# 26         SucCoA <-> Suc + ATP      (290, -55)   59.88
# 27          Suc <-> Fum + FADH2      (160, -55)   61.60
# 28                  Fum <-> Mal       (10, -55)   63.27
# 29           Mal <-> OAC + NADH     (-60, -180)   25.97
# 30          ICit -> Glyox + Suc     (180, -140)    0.00
# 31         Glyox + AcCoA -> Mal      (90, -140)    0.00
#
#     90% Confidence Lower Bound  90% Confidence Upper Bound  SPOT WT Value  \
# 0                       100.00                      100.00     100.000000
# 1                        -2.09                        1.42     100.111373
# 2                         0.00                        1.91      70.053129
# 3                         0.00                        1.91      70.039672
# 4                         0.00                        1.91     100.385611
# 5                        82.61                       88.84     200.799936
# 6                        82.61                       88.84     200.799936
# 7                        71.65                       81.26     200.799863
# 8                        71.65                       81.26     200.883173
# 9                       -10.89                       75.15      52.540800
# 10                       96.96                      100.00      -0.041765
# 11                        2.07                       10.92      -0.008289
# 12                       -0.89                        4.37       0.137819
# 13                        2.95                        6.55      -0.137342
# 14                       -0.89                        4.37       0.086497
# 15                       -1.36                        1.11       0.086497
# 16                        0.46                        3.34       0.058973
# 17                        0.46                        3.34       0.072100
# 18                        0.46                        3.34      -0.072100
# 19                       89.08                       94.98       0.037191
# 20                       89.08                       94.98       0.028933
# 21                      116.26                      196.60       0.113282
# 22                       58.52                       82.65     142.472389
# 23                       58.52                       82.65     142.486682
# 24                       10.08                       82.65      87.759957
# 25                        2.27                       75.99      -0.026546
# 26                        0.87                       74.45      82.104756
# 27                       50.51                       75.99      66.034164
# 28                       22.17                       77.49      66.031696
# Yoneda WT 1.0 g/L Glucose, 1.0 g/l ammonium sul...                       0.027
# Yoneda Evol33 1.0 g/L Glucose, 1.0 g/l ammonium...                       0.043
# Yoneda Evol40 1.0 g/L Glucose, 1.0 g/l ammonium...                      -0.063
# Yoneda WT 1.0 g/L Glucose, 0.05 g/l ammonium su...                       0.021
# Yoneda Evol33 1.0 g/L Glucose, 0.05 g/l ammoniu...                       0.033
# Yoneda Evol40 1.0 g/L Glucose, 0.05 g/l ammoniu...                       0.017
# Henson WT 0.5 g/L Phenol                                                 1.422
# Henson PVHG6 0.5 g/L Phenol                                              2.069
#
#                                                     substrate consumption rate std dev  \
# Yoneda WT 1.5 g/L Phenol                                                         0.033
# Yoneda Evol33 1.5 g/L Phenol                                                     0.021
# Yoneda Evol40 1.5 g/L Phenol                                                     0.030
# Yoneda WT 1.0 g/L Glucose, 1.0 g/l ammonium sul...                               0.000
# Yoneda Evol33 1.0 g/L Glucose, 1.0 g/l ammonium...                               0.000
# Yoneda Evol40 1.0 g/L Glucose, 1.0 g/l ammonium...                               0.000
# Yoneda WT 1.0 g/L Glucose, 0.05 g/l ammonium su...                               0.000
# Yoneda Evol33 1.0 g/L Glucose, 0.05 g/l ammoniu...                               0.000
# Yoneda Evol40 1.0 g/L Glucose, 0.05 g/l ammoniu...                               0.000
# Henson WT 0.5 g/L Phenol                                                         0.129
# Henson PVHG6 0.5 g/L Phenol                                                      0.023
#
#                                                     growth rate  \
# Yoneda WT 1.5 g/L Phenol                                  0.019
# Yoneda Evol33 1.5 g/L Phenol                              0.034
# Yoneda Evol40 1.5 g/L Phenol                              0.034
# Yoneda WT 1.0 g/L Glucose, 1.0 g/l ammonium sul...        0.032
# Yoneda Evol33 1.0 g/L Glucose, 1.0 g/l ammonium...        0.031
# Yoneda Evol40 1.0 g/L Glucose, 1.0 g/l ammonium...        0.031
# Yoneda WT 1.0 g/L Glucose, 0.05 g/l ammonium su...        0.039
# Yoneda Evol33 1.0 g/L Glucose, 0.05 g/l ammoniu...        0.033
# Yoneda Evol40 1.0 g/L Glucose, 0.05 g/l ammoniu...        0.034
# Henson WT 0.5 g/L Phenol                                  0.065
# Henson PVHG6 0.5 g/L Phenol                               0.080
#
#                                                     growth rate std dev  \
# Yoneda WT 1.5 g/L Phenol                                          0.001
# Yoneda Evol33 1.5 g/L Phenol                                      0.002
# Yoneda Evol40 1.5 g/L Phenol                                      0.001
# Yoneda WT 1.0 g/L Glucose, 1.0 g/l ammonium sul...                0.000
# Yoneda Evol33 1.0 g/L Glucose, 1.0 g/l ammonium...                0.000
# Yoneda Evol40 1.0 g/L Glucose, 1.0 g/l ammonium...                0.000
# Yoneda WT 1.0 g/L Glucose, 0.05 g/l ammonium su...                0.000
# Yoneda Evol33 1.0 g/L Glucose, 0.05 g/l ammoniu...                0.000
# Yoneda Evol40 1.0 g/L Glucose, 0.05 g/l ammoniu...                0.000
# Henson WT 0.5 g/L Phenol                                          0.001
# Henson PVHG6 0.5 g/L Phenol                                       0.003
#
#                                                     yield coefficient  \
# Yoneda WT 1.5 g/L Phenol                                        0.027
# Yoneda Evol33 1.5 g/L Phenol                                    0.033
# Yoneda Evol40 1.5 g/L Phenol                                    0.036
# Yoneda WT 1.0 g/L Glucose, 1.0 g/l ammonium sul...              1.150
# Yoneda Evol33 1.0 g/L Glucose, 1.0 g/l ammonium...              0.726
# Yoneda Evol40 1.0 g/L Glucose, 1.0 g/l ammonium...             -0.500
# Yoneda WT 1.0 g/L Glucose, 0.05 g/l ammonium su...              1.834
# Yoneda Evol33 1.0 g/L Glucose, 0.05 g/l ammoniu...              1.006
# Yoneda Evol40 1.0 g/L Glucose, 0.05 g/l ammoniu...              2.029
# Henson WT 0.5 g/L Phenol                                        0.046
# Henson PVHG6 0.5 g/L Phenol                                     0.039
#
#                                                     yield coefficient std dev
# Yoneda WT 1.5 g/L Phenol                                                0.003
# Yoneda Evol33 1.5 g/L Phenol                                            0.002
# Yoneda Evol40 1.5 g/L Phenol                                            0.002
# Yoneda WT 1.0 g/L Glucose, 1.0 g/l ammonium sul...                      0.000
# Yoneda Evol33 1.0 g/L Glucose, 1.0 g/l ammonium...                      0.000
# Yoneda Evol40 1.0 g/L Glucose, 1.0 g/l ammonium...                      0.000
# Yoneda WT 1.0 g/L Glucose, 0.05 g/l ammonium su...                      0.000
# Yoneda Evol33 1.0 g/L Glucose, 0.05 g/l ammoniu...                      0.000
# Yoneda Evol40 1.0 g/L Glucose, 0.05 g/l ammoniu...                      0.000
# Henson WT 0.5 g/L Phenol                                                0.005
# Henson PVHG6 0.5 g/L Phenol                                             0.002

# %%
new_index = pd.Series(['WT-HN-HP','EVOL33-HN-HP', 'EVOL40-HN-HP', 'WT-HN-G', 'EVOL33-HN-G', 'EVOL40-HN-G', 'WT-LN-G', 'EVOL33-LN-G', 'EVOL40-LN-G', 'WT-P', 'PVHG-P'])
consumption_and_growth_data = consumption_and_growth_data.set_index([new_index])

# %% [markdown]
# ##### **For comparison of predicted and observed growth rates: scale predicted growth rate by multiplying with (observed substrate uptake / predicted substrate uptake)**

# %%
def scale_growth_to_sub(solgrowth, soluptake, sub_uptake_2comp):
    factor = abs(sub_uptake_2comp/(-soluptake))
    solgrowthnew = solgrowth*factor
    return solgrowthnew

# %%
scaledgrowthratespot_wtlng = scale_growth_to_sub(spotsoldf.loc['Growth_Glucose',:].values[0], spotsoldf.loc['EX_glc__D_e',:].values[0],consumption_and_growth_data.loc['WT-LN-G', 'substrate consumption rate'])
scaledgrowthratespot_evol33lng = scale_growth_to_sub(spotsoldf_evol33.loc['Growth_Glucose',:].values[0], spotsoldf_evol33.loc['EX_glc__D_e',:].values[0],consumption_and_growth_data.loc['EVOL33-LN-G',  'substrate consumption rate'])
scaledgrowthratespot_evol40lng = scale_growth_to_sub(spotsoldf_evol40.loc['Growth_Glucose',:].values[0], spotsoldf_evol40.loc['EX_glc__D_e',:].values[0],consumption_and_growth_data.loc['EVOL40-LN-G',  'substrate consumption rate'])

# %%
allgrowthrates=pd.DataFrame(index=['WT-LN-G', 'EVOL33-LN-G', 'EVOL40-LN-G'], columns=['Growth_Glucose_SPOT' ], dtype=float)
allgrowthrates.at['WT-LN-G','Growth_Glucose_SPOT'] = scaledgrowthratespot_wtlng
allgrowthrates.at['EVOL33-LN-G','Growth_Glucose_SPOT'] = scaledgrowthratespot_evol33lng
allgrowthrates.at['EVOL40-LN-G','Growth_Glucose_SPOT'] = scaledgrowthratespot_evol40lng

# %%
#Scatterplot of solutions
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm
from scipy.stats import linregress

def maefunc(y_predict, y_actual):
    """Mean Absolute Error.
    Multioutput case included."""

    if y_actual.ndim == 1:
        return np.mean(np.abs([y_a - y_p for y_a, y_p in zip(y_actual, y_predict)]))
    else:
        return [
            np.mean(
                np.abs([y_a - y_p for y_a, y_p in zip(y_actual[:, i], y_predict[:, i])])
            )
            for i in range(y_actual.shape[1])
        ]
    
def scatterplotcompare(observed, predicted, labels, strtitle):
    fig, ax = plt.subplots(figsize=(8, 8))
    
    lims = [
                np.min([observed, predicted]),  # min of both axes
                np.max([observed, predicted]),  # max of both axes
            ]
    ax.set_xlim(lims)
    
    # Plot Diagonal Dashed Line
    ax.plot(lims, lims, ls="--", color=".8", zorder=0)
    for i in range(0, len(observed)):
        ax.scatter(observed[i], predicted[i])
        ax.annotate(str(labels[i]),(observed[i],predicted[i]))
        
    #calculate statistical quantities:
    rss = np.sum((predicted - observed) ** 2)
    tss = np.sum((predicted - predicted.mean()) ** 2)
    
    #r2_1 = round(1 - rss / tss,2) #other way to calculate rsquared
    _, _, growth_r, _, _ = scipy.stats.linregress(observed, predicted)

    #r2 = round(r2_score(observed, predicted),2) #other way to calculate rsquared
    mse = np.round(1/len(observed) * rss,2) 
    rmse = np.round(np.sqrt(1/len(observed) * rss),2)
    mae_score = round(maefunc(observed, predicted),2)
    
    plt.xlabel(r'Observed growth rates [$mmol/gDW/hr$]')
    plt.ylabel(r'Predicted growth rates [$mmol/gDW/hr$]')
    plt.title(r'Growth rates: Observed vs. Predicted ('+strtitle+'), \n' + f"$R^2$={growth_r**2:.2F}, MAE={mae_score}, MSE = {mse}, RMSE={rmse}", fontsize=18)
    plt.show()

# %%
new_index = pd.Series(['WT-HN-HP','EVOL33-HN-HP', 'EVOL40-HN-HP', 'WT-HN-G', 'EVOL33-HN-G', 'EVOL40-HN-G', 'WT-LN-G', 'EVOL33-LN-G', 'EVOL40-LN-G', 'WT-P', 'PVHG-P'])
consumption_and_growth_data = consumption_and_growth_data.set_index([new_index])

# %%
allindices=[str(row) for row in allgrowthrates.index]
scatterplotcompare(consumption_and_growth_data.loc[allindices, 'growth rate'], allgrowthrates.loc[:,'Growth_Glucose_SPOT'], allindices, 'SPOT')

# %%
allgrowthrates.to_csv('allgrowthratesGlucoseSPOT.csv', index=True, header= True)
