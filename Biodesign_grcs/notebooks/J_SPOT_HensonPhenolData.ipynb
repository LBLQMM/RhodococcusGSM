# %% [markdown]
# ## **Notebook to make predictions with reprocessed Henson data and SPOT**

# %% [markdown]
# ### SPOT predictions and evaluations
# This notebook predicts fluxes for R. opacus cultures growing with phenol. The data was published in [Henson (2018)](https://www.sciencedirect.com/science/article/pii/S1096717618300910).
#
# #### **Data Labels old vs. new:**
#
# #### Henson:
# * WT 0.5g/L Phenol 		(WT-P-R) ->**WT-P**
# * PVHG6 0.5g/L  Phenol 	(PVHG6-P-R) ->**PVHG-P**
#
# ### Method:
# <ol>
# <li>Predict fluxes with SPOT</li>
# <li>Compare predictions with 13CMFA: Scatter plots and flux maps</li>
# <li>Load file with observed growth rates (Notebook E)</li>
# <li>Compare growth rate predictions with growth rate observations</li>
# </ol>

# %% [markdown]
# ##### **Import python packages**

# %%
import os
import sys
import pandas as pd
import numpy as np
import cobra
import scipy.stats
#import cplex
# %matplotlib inline

import matplotlib
from matplotlib import pyplot as plt
from matplotlib.offsetbox import (TextArea, DrawingArea, OffsetImage,
                                  AnnotationBbox)
from matplotlib.cbook import get_sample_data
import matplotlib.image as mpimg

from edd_utils import login, export_study, export_metadata

# %% [markdown]
# ##### **Load data**

# %%
# Study to Download
study_slug = 'biodesign_henson2018_reprocessed'
# EDD server
edd_server = 'public-edd.jbei.org'
user       = 'schenkch'

# %%
session = login(edd_server=edd_server, user=user)

df = export_study(session, study_slug, edd_server=edd_server)
#df.head()
# Out:
# Password for schenkch:  ···············
# HBox(children=(FloatProgress(value=0.0, max=440493.0), HTML(value='')))

# %% [markdown]
# ##### **Filter transcriptomics data from all EDD data into different dataframes**

# %%
df_Trans = df[df['Protocol'].str.contains('Transcriptomics')]
df_Trans.head()
# Out:
#    Study ID                        Study Name  Line ID Line Name  \
# 0     14409  Biodesign_Henson2018_reprocessed    14905   WT-M-R1
# 1     14409  Biodesign_Henson2018_reprocessed    14905   WT-M-R1
# 2     14409  Biodesign_Henson2018_reprocessed    14906   WT-M-R2
# 3     14409  Biodesign_Henson2018_reprocessed    14906   WT-M-R2
# 4     14409  Biodesign_Henson2018_reprocessed    14907   WT-M-R3
#
#                                     Line Description         Protocol  \
# 0  R. Opacus wild type strain with Mixture of all...  Transcriptomics
# 1  R. Opacus wild type strain with Mixture of all...  Transcriptomics
# 2  R. Opacus wild type strain with Mixture of all...  Transcriptomics
# 3  R. Opacus wild type strain with Mixture of all...  Transcriptomics
# 4  R. Opacus wild type strain with Mixture of all...  Transcriptomics
#
#    Assay ID Assay Name Formal Type Measurement Type  Compartment Units  Value  \
# 0     14948    WT-M-R1         NaN   WP_000104864_1            0  FPKM    0.0
# 1     14948    WT-M-R1         NaN   WP_000104864_1            0  FPKM    0.0
# 2     14949    WT-M-R2         NaN   WP_000104864_1            0  FPKM    0.0
# 3     14949    WT-M-R2         NaN   WP_000104864_1            0  FPKM    0.0
# 4     14950    WT-M-R3         NaN   WP_000104864_1            0  FPKM    0.0
#
#    Hours
# 0   20.0
# 1   32.0
# 2   20.0
# 3   32.0
# 4   20.0

# %% [markdown]
# ##### **Load Genome Scale Model**

# %%
file_name =  '../GSMs/Ropacus_annotated_curated_with_phenol_custom_biomass.xml'
model = cobra.io.read_sbml_model(file_name)

# %% [markdown]
# ##### **Import EFLUX2 and SPOT Code**

# %%
OptlangDir = '../EFLUX2_SPOT'
sys.path.append(OptlangDir)
from ensemblemethods import SPOT

# %% [markdown]
# ##### **Transform data to dataframe with just index as gene identifiers and one column for values**
# ##### !!!!TODO: Generalize for multiple time points

# %%
#Function to construct df from EFLUX2 functions: Needs to be modified for multiple time points!!!!!
def construct_trans_df(transdata, linename):
    transdataWTPR1 = transdata[transdata['Line Name']==linename]
    transdataWTPR1new = transdataWTPR1.filter(['Value', 'Measurement Type'])
    transdataWTPR1new2 = transdataWTPR1new.set_index('Measurement Type')
    return transdataWTPR1new2

# %% [markdown]
# #### **SPOT Predictions**

# %%
#Function for EFLUX2 and SPOT Predictions:
def spot_pred(model, transcriptdf, linename, substrate, sub_uptake_rate=100):    
    with model:
        medium = model.medium
        if substrate=='phenol':
            model.objective = 'Growth_Phenol'
            medium = {key:1000 for (key,value) in model.medium.items()}
            model.reactions.get_by_id('Growth_Glucose').upper_bound = 0
            model.reactions.get_by_id('Growth_Glucose').lower_bound = 0
            model.reactions.get_by_id('Growth').upper_bound = 0
            model.reactions.get_by_id('Growth').lower_bound = 0
            model.reactions.get_by_id('Growth_Phenol').lower_bound = 0
            medium["EX_glc__D_e"] = 0
            #medium["EX_phenol_e"] = sub_uptake_rate
            #model.reactions.get_by_id('EX_phenol_e').upper_bound = -sub_uptake_rate
            #model.reactions.get_by_id('EX_phenol_e').lower_bound = -sub_uptake_rate
            model.reactions.get_by_id('EX_glc__D_e').upper_bound = 0
            model.reactions.get_by_id('EX_glc__D_e').lower_bound = 0
            #medium["EX_phenol_e"] = sub_uptake_rate
        elif substrate=='glucose':
            model.objective = 'Growth_Glucose'
            medium = {key:1000 for (key,value) in model.medium.items()}
            model.reactions.get_by_id('Growth_Phenol').upper_bound = 0
            model.reactions.get_by_id('Growth_Phenol').lower_bound = 0
            model.reactions.get_by_id('Growth').upper_bound = 0
            model.reactions.get_by_id('Growth').lower_bound = 0
            #model.reactions.get_by_id('Growth_Glucose').lower_bound = 0
            #medium["EX_glc__D_e"] = sub_uptake_rate
            medium["EX_phenol_e"] = 0
            #model.reactions.get_by_id('EX_glc__D_e').upper_bound = -sub_uptake_rate
            #model.reactions.get_by_id('EX_glc__D_e').lower_bound = -sub_uptake_rate
            model.reactions.get_by_id('EX_phenol_e').upper_bound = 0
            model.reactions.get_by_id('EX_phenol_e').lower_bound = 0
        else:
            print('Unknown substrate: Please choose among phenol and glucose')
        model.medium = medium
        spotsol = SPOT(model, transcriptdf)
        display(model.medium)
    return spotsol

# %%
#Function for predictions for three replicates and averaging the solutions and calculating the standard deviation:
def spot_pred_for_three_reps(model, transcriptdf, linename1, linename2, linename3, substrate):
    #call prediction functions for individual spot predictions for all 3 replicates:
    transdata_R1 = construct_trans_df(transcriptdf, linename1)
    transdata_R2 = construct_trans_df(transcriptdf, linename2)
    transdata_R3 = construct_trans_df(transcriptdf, linename3)
 
    spotsol_R1 = spot_pred(model, transdata_R1, linename1, substrate)
    spotsol_R2 = spot_pred(model, transdata_R2, linename2, substrate)
    spotsol_R3 = spot_pred(model, transdata_R3, linename3, substrate)
    
    #spot calculations:
    spotsol_R1_df = pd.DataFrame(spotsol_R1, columns=['fluxes'])
    spotsol_R2_df = pd.DataFrame(spotsol_R2, columns=['fluxes'])
    spotsol_R3_df = pd.DataFrame(spotsol_R3, columns=['fluxes'])
    spotsol_all = pd.concat([spotsol_R1_df, spotsol_R2_df, spotsol_R3_df], axis=1)
    
    spotsol = pd.DataFrame(spotsol_all.mean(axis=1), columns=['fluxes'])
    spotsol_std = spotsol_all.std(axis=1)
    
    return spotsol, spotsol_std

# %%
spotsol, spotsol_std = spot_pred_for_three_reps(model, df_Trans, 'WT-P-R1', 'WT-P-R2','WT-P-R3', 'phenol')
# Out:
# {'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000,
#  'EX_phenol_e': 1000.0}
# {'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000,
#  'EX_phenol_e': 1000.0}
# {'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000,
#  'EX_phenol_e': 1000.0}
# {'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000,
#  'EX_phenol_e': 1000.0}
# {'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000,
#  'EX_phenol_e': 1000.0}
# {'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000,
#  'EX_phenol_e': 1000.0}

# %% [markdown]
# ##### **Save solution to data frame**

# %%
spotsoldf = pd.DataFrame(spotsol, columns=['fluxes'])
spotsolstddf = pd.DataFrame(spotsol_std, columns=['stds'])

# %%
spotsol.loc['Growth_Phenol']
# Out:
# fluxes   -6.865427e-07
# Name: Growth_Phenol, dtype: float64

# %% [markdown]
# ##### **Check External Metabolites solution**

# %%
exchange_list = []
for ind in spotsoldf.index:
    if 'EX_' in str(ind):
        exchange_list.append(ind)

# %%
spotsoldf.loc[exchange_list,:]
for i in exchange_list:
    if spotsoldf.loc[i,:].values>=0.0001:
        display(spotsoldf.loc[i,:])
# Out:
# fluxes    0.141758
# Name: EX_h_e, dtype: float64
# fluxes    0.001384
# Name: EX_leu__L_e, dtype: float64
# fluxes    0.004106
# Name: EX_acac_e, dtype: float64
# fluxes    0.002878
# Name: EX_acald_e, dtype: float64
# fluxes    0.064964
# Name: EX_succ_e, dtype: float64
# fluxes    0.110103
# Name: EX_co2_e, dtype: float64
# fluxes    0.002216
# Name: EX_fum_e, dtype: float64
# fluxes    0.000254
# Name: EX_pdima_e, dtype: float64
# fluxes    0.001945
# Name: EX_val__L_e, dtype: float64

# %% [markdown]
# #### **Plot solutions: Comparison of SPOT predictions and 13c measurements**

# %% [markdown]
# ##### **Add Phenol SPOT flux values to phenol fluxes dataframe**

# %%
def get_flux_value(reaction_id, solution):
    if reaction_id.startswith('reverse_'):
        reaction_id = reaction_id.split('reverse_')[1]
        return -1*solution.fluxes[reaction_id]
    else:
        return solution.fluxes[reaction_id]
def get_std_value(reaction_id, solution):
    if reaction_id.startswith('reverse_'):
        reaction_id = reaction_id.split('reverse_')[1]
        return -1*solution.stds[reaction_id]
    else:
        return solution.stds[reaction_id]

# %% [markdown]
# ##### **Scale up solution to compare with 13C MFA measurements**

# %%
def scale_predictions(observed_fluxes, predictions, stdpredictions, substrate, method):
    scalepred_stds = pd.DataFrame(index=stdpredictions.index, columns= ['stds'], dtype=np.float64)
    scalepred_fluxes = pd.DataFrame(index=predictions.index, columns= ['fluxes'], dtype=np.float64)
    if substrate == 'phenol':
        phenoluptakerow = observed_fluxes[observed_fluxes['Pathway']=='Phenol Uptake']
        sourceuptake = float(phenoluptakerow['Flux'])
        scalepred_fluxes = predictions*(sourceuptake/(-1*predictions.loc['EX_phenol_e']))
    elif substrate == 'glucose':
        glucoseuptakerow = observed_fluxes[observed_fluxes['Pathway']=='Glucose Uptake']
        sourceuptake = float(glucoseuptakerow['Flux'])
        scalepred_fluxes = predictions*(sourceuptake/(-1*predictions.loc['EX_glc__D_e']))
    else:   
        print('Unknown Substrate')
    for ind in stdpredictions.index:
        if abs(stdpredictions.loc[ind,'stds'])<1e-5:
            scalepred_stds.loc[ind,'stds'] = stdpredictions.loc[ind,'stds']
        else:
            scalepred_stds.loc[ind,'stds'] = (stdpredictions.loc[ind,'stds']/predictions.loc[ind,'fluxes'])*scalepred_fluxes.loc[ind, 'fluxes']
    return scalepred_fluxes, scalepred_stds

# %% [markdown]
# ##### **Add predictions to 13c data frame**

# %%
def add_pred_fluxes_to_13c_df(observed_fluxes, predictions, stdpredictions, substrate, method, strain):
    predicted_fluxes = []
    predicted_stds = []
    scalepred_fluxes, scalepred_stds = scale_predictions(observed_fluxes, predictions, stdpredictions, substrate, method)
    for _, row in observed_fluxes.iterrows():
        reactions = row['Forward Reactions']
        flux_value_pred = 0
        std_value_pred = 0
        for x in [x.strip('() ') for x in reactions.split(' or ')]:
            and_split = [y.strip('() ') for y in x.split(' and ')]
            flux_value_pred += min([get_flux_value(v, scalepred_fluxes) for v in and_split])
            std_value_pred += min([get_std_value(v,scalepred_stds) for v in and_split])
        predicted_fluxes.append(flux_value_pred)
        predicted_stds.append(std_value_pred)

    observed_fluxes[str(method) + ' ' + str(strain) + ' Value'] = predicted_fluxes
    observed_fluxes[str(method) + ' ' + str(strain) + ' std Value'] = predicted_stds
    
    return observed_fluxes

# %% [markdown]
# ##### **Load 13cdata**

# %% [markdown]
# #####  **Get 13C MFA measured fluxes for phenol**

# %%
phenol_fluxes = pd.read_csv('../13C_flux_data/13C_phenol_flux_data.csv')

# Remove rows that do not have a mapping to the GSM
phenol_fluxes.dropna(subset = ["Forward Reactions"], inplace=True)
print(f'There are {len(phenol_fluxes)} fluxes that can be compared between the MFA and FBA')
phenol_fluxes
# Out:
# There are 43 fluxes that can be compared between the MFA and FBA
#                       Pathway  \
# 0               Phenol Uptake
# 1                 EMP Pathway
# 2                 EMP Pathway
# 3                 EMP Pathway
# 4                 EMP Pathway
# 5                 EMP Pathway
# 6                 EMP Pathway
# 7                 EMP Pathway
# 8                 EMP Pathway
# 9                 EMP Pathway
# 10  Pentose Phosphate Pathway
# 11  Pentose Phosphate Pathway
# 12  Pentose Phosphate Pathway
# 13  Pentose Phosphate Pathway
# 14  Pentose Phosphate Pathway
# 15  Pentose Phosphate Pathway
# 16  Pentose Phosphate Pathway
# 17  Pentose Phosphate Pathway
# 18  Pentose Phosphate Pathway
# 19                 ED Pathway
# 20                 ED Pathway
# 21                  TCA Cycle
# 22                  TCA Cycle
# 23                  TCA Cycle
# 24                  TCA Cycle
# 25                  TCA Cycle
# 26                  TCA Cycle
# 27                  TCA Cycle
# 28                  TCA Cycle
# 29                  TCA Cycle
# 30           Glyoxylate Shunt
# 31           Glyoxylate Shunt
# 32      Anaplerotic Reactions
# 33      Anaplerotic Reactions
# 34      Anaplerotic Reactions
# 35      Anaplerotic Reactions
# 64         Transhydrogenation
# 65                  Transport
# 66                  Transport
# 68                  Transport
# 69                  Transport
# 70                  Transport
# 71           Biomass Equation
#
#                                     Forward Reactions  \
# 0                                              PHEMOX
# 1                                                 PGI
# 2                                  PFK or reverse_FBP
# 3                                                 FBA
# 4                                                 TPI
# 5                                                GAPD
# 6                                         reverse_PGK
# 7                                PGM_1 or reverse_PGM
# 8                                                 ENO
# 9   PPS or reverse_FRUpts2pp or reverse_SBTpts or ...
# 10                                    G6PDH2r and PGL
# 11                                                GND
# 12                                                RPE
# 13                                        reverse_RPI
# 14                                               TKT2
# 15                                               TKT2
# 16                                               TKT1
# 17                                               TALA
# 18                                       reverse_TALA
# 19                                                EDA
# 20                                                EDD
# 21                                                PDH
# 22                                 CS or reverse_CITL
# 23                      ACONT or ( ACONTa and ACONTb)
# 24                                    ICDHx or ICDHyr
# 25                                     AKGDH or OOR3r
# 26  3OADPCOAT or OCOAT3r or SUCBZT1 or SUCBZT2 or ...
# 27  SUCDi or reverse_FRD2 or reverse_FRD3 or rever...
# 28                                                FUM
# 29                     MDH or MDH3 or MDH2 or DMALRED
# 30                                                ICL
# 31                                               MALS
# 32                                   PEPCK_re or PPCK
# 33                                                PPC
# 34                                                 PC
# 35                                         ME1 or ME2
# 64            FRNDPR2r or FLNDPR2r or reverse_NADTRHD
# 65                                               ATPM
# 66                                       reverse_CO2t
# 68                                                O2t
# 69                                               NH4t
# 70                                              SO4t2
# 71          Growth or Growth_Phenol or Growth_Glucose
#
#                                              Reaction Location on map  \
# 0                        Phenol.ext -> AcCoA + SucCoA     ( 80, -450)
# 1                                         G6P <-> F6P     (-150, 430)
# 2                                    F6P + ATP -> FBP     (-220, 195)
# 3                                  FBP <-> DHAP + GAP     (-140, 115)
# 4                                        DHAP <-> GAP     (-270, 150)
# 5                                       GAP <-> G1,3P      (-220, 30)
# 6                          G1,3P <-> 3PG + ATP + NADH     (-220, -55)
# 7                                         3PG <-> 2PG    (-220, -135)
# 8                                         2PG <-> PEP    (-220, -215)
# 9                                   PEP <-> Pyr + ATP    (-220, -295)
# 10                                G6P <-> 6PG + NADPH       (50, 380)
# 11                         6PG <-> Ru5P + CO2 + NADPH      (275, 350)
# 12                                       Ru5P <-> X5P      (380, 190)
# 13                                       Ru5P <-> R5P      (270, 230)
# 14                                 X5P <-> TKC2 + GAP      (270, 100)
# 15                                 TKC2 + E4P <-> F6P       (10, 280)
# 16                                 TKC2 + R5P <-> S7P      (120, 230)
# 17                                 TAC3 + GAP <-> F6P      (-70, 190)
# 18                                 S7P <-> TAC3 + E4P       (50, 230)
# 19                                       6PG <-> KDPG     (-300, 350)
# 20                                 KDPG <-> Pyr + GAP      (-300, 50)
# 21                         Pyr <-> AcCoA + CO2 + NADH    (-220, -370)
# 22                                 OAC + AcCoA -> Cit     (-55, -340)
# 23                                        Cit -> ICit     (145, -310)
# 24                          ICit -> AKG + CO2 + NADPH     (290, -310)
# 25                         AKG -> SucCoA + CO2 + NADH     (290, -195)
# 26                                SucCoA -> Suc + ATP      (290, -55)
# 27                                 Suc -> Fum + FADH2      (160, -55)
# 28                                         Fum -> Mal       (10, -55)
# 29                                  Mal -> OAC + NADH     (-60, -180)
# 30                                ICit -> Glyox + Suc     (180, -140)
# 31                               Glyox + AcCoA -> Mal      (90, -140)
# 32                             OAC + ATP -> PEP + CO2             NaN
# 33                                   PEP + CO2 -> OAC             NaN
# 34                             Pyr + CO2 + ATP -> OAC             NaN
# 35                           Mal <-> Pyr + CO2 + NADH             NaN
# 64                                     NADH <-> NADPH             NaN
# 65                                     ATP -> ATP.ext             NaN
# 66                                     CO2 -> CO2.ext             NaN
# 68                                       O2.ext -> O2             NaN
# 69                                     NH3.ext -> NH3             NaN
# 70                                     SO4.ext -> SO4             NaN
# 71  0.515*Ala + 0.174*Arg + 0.153*Asn + 0.439*Asp ...             NaN
#
#             Flux  90% Confidence Lower Bound  90% Confidence Upper Bound
# 0   1.000000e+02                1.000000e+02                    100.0000
# 1  -4.793000e-01               -1.421900e+00                      0.9306
# 2  -2.000000e+00               -2.000000e+00                     -0.7683
# 3  -2.000000e+00               -2.000000e+00                     -0.7683
# 4  -2.000000e+00               -2.000000e+00                     -0.7683
# 5  -1.079070e+01               -1.122350e+01                     -9.1040
# 6  -1.079070e+01               -1.122350e+01                     -9.1040
# 7  -1.625380e+01               -1.695560e+01                    -13.6034
# 8  -1.625380e+01               -1.695560e+01                    -13.6034
# 9   2.999990e+01                0.000000e+00                     30.0000
# 10 -5.767000e-01               -2.018100e+00                      0.3824
# 11  4.646000e-01               -1.659900e+00                      1.8755
# 12 -1.187400e+00               -2.611500e+00                     -0.2468
# 13  1.652100e+00                9.081000e-01                      2.1385
# 14 -1.187400e+00               -2.611500e+00                     -0.2468
# 15 -1.187400e+00               -1.909000e+00                     -0.7099
# 16  2.130000e-14               -7.076000e-01                      0.4698
# 17  7.110000e-15               -7.076000e-01                      0.4698
# 18  8.530000e-14               -7.076000e-01                      0.4698
# 19 -1.041300e+00               -2.524300e+00                      0.2447
# 20 -1.041300e+00               -2.524300e+00                      0.2447
# 21  5.923270e+01                5.668260e+01                     62.0459
# 22  1.144391e+02                1.102766e+02                    118.4800
# 23  1.144391e+02                1.102766e+02                    118.4800
# 24  1.134677e+02                1.068011e+02                    118.4800
# 25  1.086053e+02                1.017297e+02                    113.8305
# 26  2.074789e+02                2.005620e+02                    212.7536
# 27  2.085767e+02                2.032666e+02                    212.8305
# 28  2.096703e+02                2.043514e+02                    213.8762
# 29  1.710231e+02                1.292999e+02                    174.5648
# 30  9.714000e-01                7.110000e-15                      4.5567
# 31  9.714000e-01                0.000000e+00                      4.5567
# 32  9.777180e+01                1.292690e+01                    100.0000
# 33  4.890390e+01                0.000000e+00                     59.1635
# 34  1.000000e-07                0.000000e+00                     44.8577
# 35  3.961870e+01                3.704340e+01                    100.0000
# 64  1.443160e+01                1.108700e+00                     27.2447
# 65  6.800864e+02                6.131475e+02                    787.5166
# 66  3.764570e+02                3.650427e+02                    386.6854
# 68  4.336956e+02                4.207564e+02                    445.9396
# 69  2.575270e+01                2.412740e+01                     27.0206
# 70  4.177000e-01                3.913000e-01                      0.4383
# 71  4.693400e+00                4.397200e+00                      4.9245

# %%
obspred_fluxes = add_pred_fluxes_to_13c_df(phenol_fluxes, spotsoldf, spotsolstddf, 'phenol', 'SPOT', 'WT')

# %%
obspred_fluxes
# Out:
#                       Pathway  \
# 0               Phenol Uptake
# 1                 EMP Pathway
# 2                 EMP Pathway
# 3                 EMP Pathway
# 4                 EMP Pathway
# 5                 EMP Pathway
# 6                 EMP Pathway
# 7                 EMP Pathway
# 8                 EMP Pathway
# 9                 EMP Pathway
# 10  Pentose Phosphate Pathway
# 11  Pentose Phosphate Pathway
# 12  Pentose Phosphate Pathway
# 13  Pentose Phosphate Pathway
# 14  Pentose Phosphate Pathway
# 15  Pentose Phosphate Pathway
# 16  Pentose Phosphate Pathway
# 17  Pentose Phosphate Pathway
# 18  Pentose Phosphate Pathway
# 19                 ED Pathway
# 20                 ED Pathway
# 21                  TCA Cycle
# 22                  TCA Cycle
# 23                  TCA Cycle
# 24                  TCA Cycle
# 25                  TCA Cycle
# 26                  TCA Cycle
# 27                  TCA Cycle
# 28                  TCA Cycle
# 29                  TCA Cycle
# 30           Glyoxylate Shunt
# 31           Glyoxylate Shunt
# 32      Anaplerotic Reactions
# 33      Anaplerotic Reactions
# 34      Anaplerotic Reactions
# 35      Anaplerotic Reactions
# 64         Transhydrogenation
# 65                  Transport
# 66                  Transport
# 68                  Transport
# 69                  Transport
# 70                  Transport
# 71           Biomass Equation
#
#                                     Forward Reactions  \
# 0                                              PHEMOX
# 1                                                 PGI
# 2                                  PFK or reverse_FBP
# 3                                                 FBA
# 4                                                 TPI
# 5                                                GAPD
# 6                                         reverse_PGK
# 7                                PGM_1 or reverse_PGM
# 8                                                 ENO
# 9   PPS or reverse_FRUpts2pp or reverse_SBTpts or ...
# 10                                    G6PDH2r and PGL
# 11                                                GND
# 12                                                RPE
# 13                                        reverse_RPI
# 14                                               TKT2
# 15                                               TKT2
# 16                                               TKT1
# 17                                               TALA
# 18                                       reverse_TALA
# 19                                                EDA
# 20                                                EDD
# 21                                                PDH
# 22                                 CS or reverse_CITL
# 23                      ACONT or ( ACONTa and ACONTb)
# 24                                    ICDHx or ICDHyr
# 25                                     AKGDH or OOR3r
# 26  3OADPCOAT or OCOAT3r or SUCBZT1 or SUCBZT2 or ...
# 27  SUCDi or reverse_FRD2 or reverse_FRD3 or rever...
# 28                                                FUM
# 29                     MDH or MDH3 or MDH2 or DMALRED
# 30                                                ICL
# 31                                               MALS
# 32                                   PEPCK_re or PPCK
# 33                                                PPC
# 34                                                 PC
# 35                                         ME1 or ME2
# 64            FRNDPR2r or FLNDPR2r or reverse_NADTRHD
# 65                                               ATPM
# 66                                       reverse_CO2t
# 68                                                O2t
# 69                                               NH4t
# 70                                              SO4t2
# 71          Growth or Growth_Phenol or Growth_Glucose
#
#                                              Reaction Location on map  \
# 0                        Phenol.ext -> AcCoA + SucCoA     ( 80, -450)
# 1                                         G6P <-> F6P     (-150, 430)
# 2                                    F6P + ATP -> FBP     (-220, 195)
# 3                                  FBP <-> DHAP + GAP     (-140, 115)
# 4                                        DHAP <-> GAP     (-270, 150)
# 5                                       GAP <-> G1,3P      (-220, 30)
# 6                          G1,3P <-> 3PG + ATP + NADH     (-220, -55)
# 7                                         3PG <-> 2PG    (-220, -135)
# 8                                         2PG <-> PEP    (-220, -215)
# 9                                   PEP <-> Pyr + ATP    (-220, -295)
# 10                                G6P <-> 6PG + NADPH       (50, 380)
# 11                         6PG <-> Ru5P + CO2 + NADPH      (275, 350)
# 12                                       Ru5P <-> X5P      (380, 190)
# 13                                       Ru5P <-> R5P      (270, 230)
# 14                                 X5P <-> TKC2 + GAP      (270, 100)
# 15                                 TKC2 + E4P <-> F6P       (10, 280)
# 16                                 TKC2 + R5P <-> S7P      (120, 230)
# 17                                 TAC3 + GAP <-> F6P      (-70, 190)
# 18                                 S7P <-> TAC3 + E4P       (50, 230)
# 19                                       6PG <-> KDPG     (-300, 350)
# 20                                 KDPG <-> Pyr + GAP      (-300, 50)
# 21                         Pyr <-> AcCoA + CO2 + NADH    (-220, -370)
# 22                                 OAC + AcCoA -> Cit     (-55, -340)
# 23                                        Cit -> ICit     (145, -310)
# 24                          ICit -> AKG + CO2 + NADPH     (290, -310)
# 25                         AKG -> SucCoA + CO2 + NADH     (290, -195)
# 26                                SucCoA -> Suc + ATP      (290, -55)
# 27                                 Suc -> Fum + FADH2      (160, -55)
# 28                                         Fum -> Mal       (10, -55)
# 29                                  Mal -> OAC + NADH     (-60, -180)
# 30                                ICit -> Glyox + Suc     (180, -140)
# 31                               Glyox + AcCoA -> Mal      (90, -140)
# 32                             OAC + ATP -> PEP + CO2             NaN
# 33                                   PEP + CO2 -> OAC             NaN
# 34                             Pyr + CO2 + ATP -> OAC             NaN
# 35                           Mal <-> Pyr + CO2 + NADH             NaN
# 64                                     NADH <-> NADPH             NaN
# 65                                     ATP -> ATP.ext             NaN
# 66                                     CO2 -> CO2.ext             NaN
# 68                                       O2.ext -> O2             NaN
# 69                                     NH3.ext -> NH3             NaN
# 70                                     SO4.ext -> SO4             NaN
# 71  0.515*Ala + 0.174*Arg + 0.153*Asn + 0.439*Asp ...             NaN
#
#             Flux  90% Confidence Lower Bound  90% Confidence Upper Bound  \
# 0   1.000000e+02                1.000000e+02                    100.0000
# 1  -4.793000e-01               -1.421900e+00                      0.9306
# 2  -2.000000e+00               -2.000000e+00                     -0.7683
# 3  -2.000000e+00               -2.000000e+00                     -0.7683
# 4  -2.000000e+00               -2.000000e+00                     -0.7683
# 5  -1.079070e+01               -1.122350e+01                     -9.1040
# 6  -1.079070e+01               -1.122350e+01                     -9.1040
# 7  -1.625380e+01               -1.695560e+01                    -13.6034
# 8  -1.625380e+01               -1.695560e+01                    -13.6034
# 9   2.999990e+01                0.000000e+00                     30.0000
# 10 -5.767000e-01               -2.018100e+00                      0.3824
# 11  4.646000e-01               -1.659900e+00                      1.8755
# 12 -1.187400e+00               -2.611500e+00                     -0.2468
# 13  1.652100e+00                9.081000e-01                      2.1385
# 14 -1.187400e+00               -2.611500e+00                     -0.2468
# 15 -1.187400e+00               -1.909000e+00                     -0.7099
# 16  2.130000e-14               -7.076000e-01                      0.4698
# 17  7.110000e-15               -7.076000e-01                      0.4698
# 18  8.530000e-14               -7.076000e-01                      0.4698
# 19 -1.041300e+00               -2.524300e+00                      0.2447
# 20 -1.041300e+00               -2.524300e+00                      0.2447
# 21  5.923270e+01                5.668260e+01                     62.0459
# 22  1.144391e+02                1.102766e+02                    118.4800
# 23  1.144391e+02                1.102766e+02                    118.4800
# 24  1.134677e+02                1.068011e+02                    118.4800
# 25  1.086053e+02                1.017297e+02                    113.8305
# 26  2.074789e+02                2.005620e+02                    212.7536
# 27  2.085767e+02                2.032666e+02                    212.8305
# 28  2.096703e+02                2.043514e+02                    213.8762
# 29  1.710231e+02                1.292999e+02                    174.5648
# 30  9.714000e-01                7.110000e-15                      4.5567
# 31  9.714000e-01                0.000000e+00                      4.5567
# 32  9.777180e+01                1.292690e+01                    100.0000
# 33  4.890390e+01                0.000000e+00                     59.1635
# 34  1.000000e-07                0.000000e+00                     44.8577
# 35  3.961870e+01                3.704340e+01                    100.0000
# 64  1.443160e+01                1.108700e+00                     27.2447
# 65  6.800864e+02                6.131475e+02                    787.5166
# 66  3.764570e+02                3.650427e+02                    386.6854
# 68  4.336956e+02                4.207564e+02                    445.9396
# 69  2.575270e+01                2.412740e+01                     27.0206
# 70  4.177000e-01                3.913000e-01                      0.4383
# 71  4.693400e+00                4.397200e+00                      4.9245
#
#     SPOT WT Value  SPOT WT std Value
# 0      100.000000       4.719413e+01
# 1        0.012896       4.866315e-06
# 2        0.016038       1.298500e-06
# 3        0.015889       1.699595e-06
# 4        0.035352       8.300419e-06
# 5        0.067906       1.931627e-02
# 6        0.067906      -1.931627e-02
# 7        2.479148      -3.931667e-03
# 8        4.237742       7.227108e+00
# 9      -55.161255      -2.515300e+01
# 10      -0.005384       8.155931e-07
# 11       0.001151       6.873114e-07
# 12       0.006285       5.532623e-07
# 13      -0.004575      -6.373689e-07
# 14       0.004524       3.455140e-07
# 15       0.004524       3.455140e-07
# 16       0.003602       2.425292e-07
# 17       0.004439       4.381430e-07
# 18      -0.004439      -4.381430e-07
# 19       0.000620       3.170561e-07
# 20      -0.000271       2.707367e-07
# 21       0.000973       1.671858e-06
# 22      72.951876       1.741424e+01
# 23      72.952904       1.794428e+01
# 24      -0.011500       3.025168e+00
# 25      -0.001874       8.916102e-07
# 26      96.558426       4.369049e+01
# 27      81.575057       2.337228e+01
# 28      78.572391       2.020886e+01
# 29      91.784484       9.528154e+00
# 30      72.964404       1.742474e+01
# 31      13.212487       1.566831e+01
# 32      50.924018       2.375262e+01
# 33       0.001846       1.758858e-06
# 34      32.079103       1.705905e+01
# 35       0.000950       5.932415e-07
# 64       2.276870       3.263755e+00
# 65      -0.000863       3.095498e-07
# 66     149.049368      -3.853687e+01
# 68     273.133972       8.451769e+01
# 69       2.981704       2.703950e+00
# 70       0.004464       2.294448e-06
# 71      -0.000929       3.048679e-07

# %% [markdown]
# ### Plot SPOT vs 13C MFA

# %%
def scatterplotcomp_obs_vs_pred(obspred_fluxes, substrate, method, linename, strain):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.plot(ax.get_xlim(), ax.get_ylim(), ls="--", c=".3")

    for pathway in list(set(obspred_fluxes['Pathway'])):
        pathway_df = obspred_fluxes[obspred_fluxes['Pathway'] == pathway]

        measured_flux_list = list(pathway_df['Flux'])
        simulated_flux_list = list(pathway_df[str(method) + ' ' + str(strain) + ' Value'])

        ax.scatter(measured_flux_list, simulated_flux_list, label=pathway)


    # Dashed line
    x = np.linspace(*ax.get_xlim())
    ax.plot(x, x, ls="--", c=".3")
    if substrate=='phenol':
        sub = 'Phenol'
    elif substrate=='glucose':
        sub = 'Glucose'
    else:
        print("Unknown substrate")
    plt.title(r''+str(sub)+  ' 13C MFA vs. '+ str(method) + ' Fluxes for ' +linename, fontSize=20)
    plt.xlabel(r'13C MFA flux (per 100 mmol '+str(sub)+  ' uptake)')
    plt.ylabel(r''+ str(method) + ' flux (per 100 mmol of '+str(sub)+  ' uptake)')
    plt.legend()
    plt.show()

# %%
scatterplotcomp_obs_vs_pred(obspred_fluxes, substrate='phenol', method='SPOT', linename='WT-P', strain='WT')

# %%
import matplotlib
import matplotlib.cm as cm
def scatterplotcomp_obs_vs_pred_withstd(obspred_fluxes, substrate, method, linename, strain):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.plot(ax.get_xlim(), ax.get_ylim(), ls="--", c=".3")

    for pathway in list(set(obspred_fluxes['Pathway'])):
        pathway_df = obspred_fluxes[obspred_fluxes['Pathway'] == pathway]
        
        measured_flux_list = list(pathway_df['Flux'])
        simulated_flux_list = list(pathway_df[str(method) + ' ' +  str(strain) + ' Value'])
        simulated_std_list = list(pathway_df[str(method) + ' ' +  str(strain) + ' std Value'])
        measured_std_list = list(pathway_df['90% Confidence Upper Bound']-pathway_df['Flux'])
        
        
        sc = ax.scatter(measured_flux_list, simulated_flux_list, label=pathway)
        ax.errorbar(
                measured_flux_list, simulated_flux_list, xerr=[std1 for std1 in measured_std_list], yerr=[1.9*std for std in simulated_std_list],
                    ecolor="gray", ls='none',
                    alpha=0.8)

    # Dashed line
    x = np.linspace(*ax.get_xlim())
    ax.plot(x, x, ls="--", c=".3")
    if substrate=='phenol':
        sub = 'Phenol'
    elif substrate=='glucose':
        sub = 'Glucose'
    else:
        print("Unknown substrate")
    plt.title(r''+str(sub)+  ' 13C MFA vs. '+ str(method) + ' Fluxes for ' +linename, fontSize=20)
    plt.xlabel(r'13C MFA flux (per 100 mmol '+str(sub)+  ' uptake)')
    plt.ylabel(r''+ str(method) + ' flux (per 100 mmol of '+str(sub)+  ' uptake)')
    plt.legend()
    plt.show()

# %%
scatterplotcomp_obs_vs_pred_withstd(obspred_fluxesnew, substrate='phenol', method='SPOT', linename='WT-P', strain='WT')

# %% [markdown]
# ##### **PVHG**

# %%
spotsol_PVHG, spotsol_std_PVHG = spot_pred_for_three_reps(model, df_Trans, 'PVHG-P-R1', 'PVHG-P-R2','PVHG-P-R3', 'phenol')
# Out:
# {'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000,
#  'EX_phenol_e': 1000.0}
# {'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000,
#  'EX_phenol_e': 1000.0}
# {'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000,
#  'EX_phenol_e': 1000.0}
# {'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000,
#  'EX_phenol_e': 1000.0}
# {'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000,
#  'EX_phenol_e': 1000.0}
# {'EX_h2o_e': 1000,
#  'EX_h_e': 1000,
#  'EX_cl_e': 1000,
#  'EX_pi_e': 1000,
#  'EX_nh4_e': 1000,
#  'EX_fe3_e': 1000,
#  'EX_k_e': 1000,
#  'EX_ca2_e': 1000,
#  'EX_mg2_e': 1000,
#  'EX_mn2_e': 1000,
#  'EX_cobalt2_e': 1000,
#  'EX_zn2_e': 1000,
#  'EX_cu2_e': 1000,
#  'EX_o2_e': 1000,
#  'EX_fe2_e': 1000,
#  'EX_mobd_e': 1000,
#  'EX_so4_e': 1000,
#  'EX_phenol_e': 1000.0}

# %% [markdown]
# ##### **Save solution to data frame**

# %%
spotsoldf_PVHG = pd.DataFrame(spotsol_PVHG, columns=['fluxes'])
spotsolstddf_PVHG = pd.DataFrame(spotsol_std_PVHG, columns=['stds'])

# %% [markdown]
# ##### **Add Phenol PVHG EFLUX2 and SPOT flux values to phenol fluxes dataframe**

# %%
obspred_fluxes = add_pred_fluxes_to_13c_df(obspred_fluxes, spotsoldf_PVHG, spotsolstddf_PVHG, 'phenol', 'SPOT', 'WT')

# %%
obspred_fluxes
# Out:
#                       Pathway  \
# 0               Phenol Uptake
# 1                 EMP Pathway
# 2                 EMP Pathway
# 3                 EMP Pathway
# 4                 EMP Pathway
# 5                 EMP Pathway
# 6                 EMP Pathway
# 7                 EMP Pathway
# 8                 EMP Pathway
# 9                 EMP Pathway
# 10  Pentose Phosphate Pathway
# 11  Pentose Phosphate Pathway
# 12  Pentose Phosphate Pathway
# 13  Pentose Phosphate Pathway
# 14  Pentose Phosphate Pathway
# 15  Pentose Phosphate Pathway
# 16  Pentose Phosphate Pathway
# 17  Pentose Phosphate Pathway
# 18  Pentose Phosphate Pathway
# 19                 ED Pathway
# 20                 ED Pathway
# 21                  TCA Cycle
# 22                  TCA Cycle
# 23                  TCA Cycle
# 24                  TCA Cycle
# 25                  TCA Cycle
# 26                  TCA Cycle
# 27                  TCA Cycle
# 28                  TCA Cycle
# 29                  TCA Cycle
# 30           Glyoxylate Shunt
# 31           Glyoxylate Shunt
# 32      Anaplerotic Reactions
# 33      Anaplerotic Reactions
# 34      Anaplerotic Reactions
# 35      Anaplerotic Reactions
# 64         Transhydrogenation
# 65                  Transport
# 66                  Transport
# 68                  Transport
# 69                  Transport
# 70                  Transport
# 71           Biomass Equation
#
#                                     Forward Reactions  \
# 0                                              PHEMOX
# 1                                                 PGI
# 2                                  PFK or reverse_FBP
# 3                                                 FBA
# 4                                                 TPI
# 5                                                GAPD
# 6                                         reverse_PGK
# 7                                PGM_1 or reverse_PGM
# 8                                                 ENO
# 9   PPS or reverse_FRUpts2pp or reverse_SBTpts or ...
# 10                                    G6PDH2r and PGL
# 11                                                GND
# 12                                                RPE
# 13                                        reverse_RPI
# 14                                               TKT2
# 15                                               TKT2
# 16                                               TKT1
# 17                                               TALA
# 18                                       reverse_TALA
# 19                                                EDA
# 20                                                EDD
# 21                                                PDH
# 22                                 CS or reverse_CITL
# 23                      ACONT or ( ACONTa and ACONTb)
# 24                                    ICDHx or ICDHyr
# 25                                     AKGDH or OOR3r
# 26  3OADPCOAT or OCOAT3r or SUCBZT1 or SUCBZT2 or ...
# 27  SUCDi or reverse_FRD2 or reverse_FRD3 or rever...
# 28                                                FUM
# 29                     MDH or MDH3 or MDH2 or DMALRED
# 30                                                ICL
# 31                                               MALS
# 32                                   PEPCK_re or PPCK
# 33                                                PPC
# 34                                                 PC
# 35                                         ME1 or ME2
# 64            FRNDPR2r or FLNDPR2r or reverse_NADTRHD
# 65                                               ATPM
# 66                                       reverse_CO2t
# 68                                                O2t
# 69                                               NH4t
# 70                                              SO4t2
# 71          Growth or Growth_Phenol or Growth_Glucose
#
#                                              Reaction Location on map  \
# 0                        Phenol.ext -> AcCoA + SucCoA     ( 80, -450)
# 1                                         G6P <-> F6P     (-150, 430)
# 2                                    F6P + ATP -> FBP     (-220, 195)
# 3                                  FBP <-> DHAP + GAP     (-140, 115)
# 4                                        DHAP <-> GAP     (-270, 150)
# 5                                       GAP <-> G1,3P      (-220, 30)
# 6                          G1,3P <-> 3PG + ATP + NADH     (-220, -55)
# 7                                         3PG <-> 2PG    (-220, -135)
# 8                                         2PG <-> PEP    (-220, -215)
# 9                                   PEP <-> Pyr + ATP    (-220, -295)
# 10                                G6P <-> 6PG + NADPH       (50, 380)
# 11                         6PG <-> Ru5P + CO2 + NADPH      (275, 350)
# 12                                       Ru5P <-> X5P      (380, 190)
# 13                                       Ru5P <-> R5P      (270, 230)
# 14                                 X5P <-> TKC2 + GAP      (270, 100)
# 15                                 TKC2 + E4P <-> F6P       (10, 280)
# 16                                 TKC2 + R5P <-> S7P      (120, 230)
# 17                                 TAC3 + GAP <-> F6P      (-70, 190)
# 18                                 S7P <-> TAC3 + E4P       (50, 230)
# 19                                       6PG <-> KDPG     (-300, 350)
# 20                                 KDPG <-> Pyr + GAP      (-300, 50)
# 21                         Pyr <-> AcCoA + CO2 + NADH    (-220, -370)
# 22                                 OAC + AcCoA -> Cit     (-55, -340)
# 23                                        Cit -> ICit     (145, -310)
# 24                          ICit -> AKG + CO2 + NADPH     (290, -310)
# 25                         AKG -> SucCoA + CO2 + NADH     (290, -195)
# 26                                SucCoA -> Suc + ATP      (290, -55)
# 27                                 Suc -> Fum + FADH2      (160, -55)
# 28                                         Fum -> Mal       (10, -55)
# 29                                  Mal -> OAC + NADH     (-60, -180)
# 30                                ICit -> Glyox + Suc     (180, -140)
# 31                               Glyox + AcCoA -> Mal      (90, -140)
# 32                             OAC + ATP -> PEP + CO2             NaN
# 33                                   PEP + CO2 -> OAC             NaN
# 34                             Pyr + CO2 + ATP -> OAC             NaN
# 35                           Mal <-> Pyr + CO2 + NADH             NaN
# 64                                     NADH <-> NADPH             NaN
# 65                                     ATP -> ATP.ext             NaN
# 66                                     CO2 -> CO2.ext             NaN
# 68                                       O2.ext -> O2             NaN
# 69                                     NH3.ext -> NH3             NaN
# 70                                     SO4.ext -> SO4             NaN
# 71  0.515*Ala + 0.174*Arg + 0.153*Asn + 0.439*Asp ...             NaN
#
#             Flux  90% Confidence Lower Bound  90% Confidence Upper Bound  \
# 0   1.000000e+02                1.000000e+02                    100.0000
# 1  -4.793000e-01               -1.421900e+00                      0.9306
# 2  -2.000000e+00               -2.000000e+00                     -0.7683
# 3  -2.000000e+00               -2.000000e+00                     -0.7683
# 4  -2.000000e+00               -2.000000e+00                     -0.7683
# 5  -1.079070e+01               -1.122350e+01                     -9.1040
# 6  -1.079070e+01               -1.122350e+01                     -9.1040
# 7  -1.625380e+01               -1.695560e+01                    -13.6034
# 8  -1.625380e+01               -1.695560e+01                    -13.6034
# 9   2.999990e+01                0.000000e+00                     30.0000
# 10 -5.767000e-01               -2.018100e+00                      0.3824
# 11  4.646000e-01               -1.659900e+00                      1.8755
# 12 -1.187400e+00               -2.611500e+00                     -0.2468
# 13  1.652100e+00                9.081000e-01                      2.1385
# 14 -1.187400e+00               -2.611500e+00                     -0.2468
# 15 -1.187400e+00               -1.909000e+00                     -0.7099
# 16  2.130000e-14               -7.076000e-01                      0.4698
# 17  7.110000e-15               -7.076000e-01                      0.4698
# 18  8.530000e-14               -7.076000e-01                      0.4698
# 19 -1.041300e+00               -2.524300e+00                      0.2447
# 20 -1.041300e+00               -2.524300e+00                      0.2447
# 21  5.923270e+01                5.668260e+01                     62.0459
# 22  1.144391e+02                1.102766e+02                    118.4800
# 23  1.144391e+02                1.102766e+02                    118.4800
# 24  1.134677e+02                1.068011e+02                    118.4800
# 25  1.086053e+02                1.017297e+02                    113.8305
# 26  2.074789e+02                2.005620e+02                    212.7536
# 27  2.085767e+02                2.032666e+02                    212.8305
# 28  2.096703e+02                2.043514e+02                    213.8762
# 29  1.710231e+02                1.292999e+02                    174.5648
# 30  9.714000e-01                7.110000e-15                      4.5567
# 31  9.714000e-01                0.000000e+00                      4.5567
# 32  9.777180e+01                1.292690e+01                    100.0000
# 33  4.890390e+01                0.000000e+00                     59.1635
# 34  1.000000e-07                0.000000e+00                     44.8577
# 35  3.961870e+01                3.704340e+01                    100.0000
# 64  1.443160e+01                1.108700e+00                     27.2447
# 65  6.800864e+02                6.131475e+02                    787.5166
# 66  3.764570e+02                3.650427e+02                    386.6854
# 68  4.336956e+02                4.207564e+02                    445.9396
# 69  2.575270e+01                2.412740e+01                     27.0206
# 70  4.177000e-01                3.913000e-01                      0.4383
# 71  4.693400e+00                4.397200e+00                      4.9245
#
#     SPOT WT Value  SPOT WT std Value
# 0      100.000000       1.914048e+01
# 1        0.041488       4.970488e-06
# 2       -0.001485      -3.845459e-07
# 3        0.001359       1.790499e-07
# 4        0.132959       6.149714e-02
# 5        0.287776       1.347200e-01
# 6        0.287776      -1.347200e-01
# 7       53.476891      -3.533150e-01
# 8      103.294634       6.299113e+01
# 9     -433.571700      -1.447305e+01
# 10      -0.013548       9.319305e-07
# 11      -0.000246       1.379541e-07
# 12       0.033386       4.389314e-06
# 13      -0.031514      -4.114792e-06
# 14       0.023000       2.976859e-06
# 15       0.023000       2.976859e-06
# 16       0.016224       2.121020e-06
# 17       0.019398       2.524877e-06
# 18      -0.019398      -2.524877e-06
# 19       0.007805       1.241882e-06
# 20       0.004770       8.933000e-07
# 21      -0.002324       2.742114e-07
# 22     256.160277       9.558079e+01
# 23     256.163134       9.565106e+01
# 24      -0.053677       2.882583e+00
# 25      -0.005902       7.651574e-07
# 26      80.529001      -1.501926e+00
# 27     262.250615       7.532117e+01
# 28     262.249654       7.532551e+01
# 29     273.886433       4.667589e+01
# 30     256.216811       9.560257e+01
# 31      50.124307       3.319016e+01
# 32     330.281786       6.353286e+01
# 33       0.011301       1.972345e-06
# 34     312.512181       3.268624e+01
# 35      38.489643       4.757928e+01
# 64      -0.031505      -3.778369e-06
# 65      -0.002242       2.872032e-07
# 66     303.978449      -3.671777e+01
# 68     441.236036       6.504742e+01
# 69      -0.141179       6.983660e-02
# 70       0.050335       9.651558e-06
# 71      -0.002577       3.226548e-07

# %% [markdown]
# #### Plot SPOT vs 13C MFA

# %%
scatterplotcomp_obs_vs_pred(obspred_fluxesnew2, substrate='phenol', method='SPOT', linename='PVHG-P', strain='WT')

# %%
scatterplotcomp_obs_vs_pred_withstd(obspred_fluxesnew2, substrate='phenol', method='SPOT',linename='PVHG-P', strain='WT')

# %% [markdown]
# ### Map phenol SPOT fluxes

# %%
def map_flux_results(data_df, flux_column):
    fig, ax = plt.subplots(figsize=(15, 20), dpi=50)
    xy = (0.5, 0.5)
    arr_img = plt.imread('./unlabeled_flux_map.png')
    imagebox = OffsetImage(arr_img)
    imagebox.image.axes = ax
    ab = AnnotationBbox(imagebox, xy)
    ax.add_artist(ab)

    for _, row in data_df.iterrows():
        if pd.isnull(row['Location on map'])!=True:
            location =  row['Location on map'].replace('(', '').replace(')', '')
            location_list = location.split(',')
            location_tuple = tuple((int(location_list[0]), int(location_list[1])))

            offsetbox = TextArea(f'{row[flux_column]:.1f}',textprops=dict(fontsize=22))
            ab = AnnotationBbox(offsetbox, xy,
                                xybox=location_tuple,
                                xycoords='data',
                                boxcoords="offset points",
                                frameon=False)
            ax.add_artist(ab)
    # Fix the display limits to see everything
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.set_xticks([])
    ax.set_yticks([])

    plt.show()

# %%
map_flux_results(obspred_fluxes, 'SPOT WT Value')

# %% [markdown]
# ### Get r<sup>2</sup>  values

# %%
# remove Energy molecule reactions as they are outliers
r_squared_df = phenol_fluxes[~phenol_fluxes['Reaction'].isin(['ATP -> ATP.ext', 'NADH <-> NADPH'])]

_, _, Spot_r, _, _ = scipy.stats.linregress(r_squared_df['Flux'], r_squared_df['SPOT WT Value'])

print(f'SPOT vs 13C-MFA r-squared: {Spot_r**2:.4F}')
# Out:
# SPOT vs 13C-MFA r-squared: 0.3951

# %%
r_squared_df
# Out:
#                       Pathway  \
# 0               Phenol Uptake
# 1                 EMP Pathway
# 2                 EMP Pathway
# 3                 EMP Pathway
# 4                 EMP Pathway
# 5                 EMP Pathway
# 6                 EMP Pathway
# 7                 EMP Pathway
# 8                 EMP Pathway
# 9                 EMP Pathway
# 10  Pentose Phosphate Pathway
# 11  Pentose Phosphate Pathway
# 12  Pentose Phosphate Pathway
# 13  Pentose Phosphate Pathway
# 14  Pentose Phosphate Pathway
# 15  Pentose Phosphate Pathway
# 16  Pentose Phosphate Pathway
# 17  Pentose Phosphate Pathway
# 18  Pentose Phosphate Pathway
# 19                 ED Pathway
# 20                 ED Pathway
# 21                  TCA Cycle
# 22                  TCA Cycle
# 23                  TCA Cycle
# 24                  TCA Cycle
# 25                  TCA Cycle
# 26                  TCA Cycle
# 27                  TCA Cycle
# 28                  TCA Cycle
# 29                  TCA Cycle
# 30           Glyoxylate Shunt
# 31           Glyoxylate Shunt
# 32      Anaplerotic Reactions
# 33      Anaplerotic Reactions
# 34      Anaplerotic Reactions
# 35      Anaplerotic Reactions
# 66                  Transport
# 68                  Transport
# 69                  Transport
# 70                  Transport
# 71           Biomass Equation
#
#                                     Forward Reactions  \
# 0                                              PHEMOX
# 1                                                 PGI
# 2                                  PFK or reverse_FBP
# 3                                                 FBA
# 4                                                 TPI
# 5                                                GAPD
# 6                                         reverse_PGK
# 7                                PGM_1 or reverse_PGM
# 8                                                 ENO
# 9   PPS or reverse_FRUpts2pp or reverse_SBTpts or ...
# 10                                    G6PDH2r and PGL
# 11                                                GND
# 12                                                RPE
# 13                                        reverse_RPI
# 14                                               TKT2
# 15                                               TKT2
# 16                                               TKT1
# 17                                               TALA
# 18                                       reverse_TALA
# 19                                                EDA
# 20                                                EDD
# 21                                                PDH
# 22                                 CS or reverse_CITL
# 23                      ACONT or ( ACONTa and ACONTb)
# 24                                    ICDHx or ICDHyr
# 25                                     AKGDH or OOR3r
# 26  3OADPCOAT or OCOAT3r or SUCBZT1 or SUCBZT2 or ...
# 27  SUCDi or reverse_FRD2 or reverse_FRD3 or rever...
# 28                                                FUM
# 29                     MDH or MDH3 or MDH2 or DMALRED
# 30                                                ICL
# 31                                               MALS
# 32                                   PEPCK_re or PPCK
# 33                                                PPC
# 34                                                 PC
# 35                                         ME1 or ME2
# 66                                       reverse_CO2t
# 68                                                O2t
# 69                                               NH4t
# 70                                              SO4t2
# 71          Growth or Growth_Phenol or Growth_Glucose
#
#                                              Reaction Location on map  \
# 0                        Phenol.ext -> AcCoA + SucCoA     ( 80, -450)
# 1                                         G6P <-> F6P     (-150, 430)
# 2                                    F6P + ATP -> FBP     (-220, 195)
# 3                                  FBP <-> DHAP + GAP     (-140, 115)
# 4                                        DHAP <-> GAP     (-270, 150)
# 5                                       GAP <-> G1,3P      (-220, 30)
# 6                          G1,3P <-> 3PG + ATP + NADH     (-220, -55)
# 7                                         3PG <-> 2PG    (-220, -135)
# 8                                         2PG <-> PEP    (-220, -215)
# 9                                   PEP <-> Pyr + ATP    (-220, -295)
# 10                                G6P <-> 6PG + NADPH       (50, 380)
# 11                         6PG <-> Ru5P + CO2 + NADPH      (275, 350)
# 12                                       Ru5P <-> X5P      (380, 190)
# 13                                       Ru5P <-> R5P      (270, 230)
# 14                                 X5P <-> TKC2 + GAP      (270, 100)
# 15                                 TKC2 + E4P <-> F6P       (10, 280)
# 16                                 TKC2 + R5P <-> S7P      (120, 230)
# 17                                 TAC3 + GAP <-> F6P      (-70, 190)
# 18                                 S7P <-> TAC3 + E4P       (50, 230)
# 19                                       6PG <-> KDPG     (-300, 350)
# 20                                 KDPG <-> Pyr + GAP      (-300, 50)
# 21                         Pyr <-> AcCoA + CO2 + NADH    (-220, -370)
# 22                                 OAC + AcCoA -> Cit     (-55, -340)
# 23                                        Cit -> ICit     (145, -310)
# 24                          ICit -> AKG + CO2 + NADPH     (290, -310)
# 25                         AKG -> SucCoA + CO2 + NADH     (290, -195)
# 26                                SucCoA -> Suc + ATP      (290, -55)
# 27                                 Suc -> Fum + FADH2      (160, -55)
# 28                                         Fum -> Mal       (10, -55)
# 29                                  Mal -> OAC + NADH     (-60, -180)
# 30                                ICit -> Glyox + Suc     (180, -140)
# 31                               Glyox + AcCoA -> Mal      (90, -140)
# 32                             OAC + ATP -> PEP + CO2             NaN
# 33                                   PEP + CO2 -> OAC             NaN
# 34                             Pyr + CO2 + ATP -> OAC             NaN
# 35                           Mal <-> Pyr + CO2 + NADH             NaN
# 66                                     CO2 -> CO2.ext             NaN
# 68                                       O2.ext -> O2             NaN
# 69                                     NH3.ext -> NH3             NaN
# 70                                     SO4.ext -> SO4             NaN
# 71  0.515*Ala + 0.174*Arg + 0.153*Asn + 0.439*Asp ...             NaN
#
#             Flux  90% Confidence Lower Bound  90% Confidence Upper Bound  \
# 0   1.000000e+02                1.000000e+02                    100.0000
# 1  -4.793000e-01               -1.421900e+00                      0.9306
# 2  -2.000000e+00               -2.000000e+00                     -0.7683
# 3  -2.000000e+00               -2.000000e+00                     -0.7683
# 4  -2.000000e+00               -2.000000e+00                     -0.7683
# 5  -1.079070e+01               -1.122350e+01                     -9.1040
# 6  -1.079070e+01               -1.122350e+01                     -9.1040
# 7  -1.625380e+01               -1.695560e+01                    -13.6034
# 8  -1.625380e+01               -1.695560e+01                    -13.6034
# 9   2.999990e+01                0.000000e+00                     30.0000
# 10 -5.767000e-01               -2.018100e+00                      0.3824
# 11  4.646000e-01               -1.659900e+00                      1.8755
# 12 -1.187400e+00               -2.611500e+00                     -0.2468
# 13  1.652100e+00                9.081000e-01                      2.1385
# 14 -1.187400e+00               -2.611500e+00                     -0.2468
# 15 -1.187400e+00               -1.909000e+00                     -0.7099
# 16  2.130000e-14               -7.076000e-01                      0.4698
# 17  7.110000e-15               -7.076000e-01                      0.4698
# 18  8.530000e-14               -7.076000e-01                      0.4698
# 19 -1.041300e+00               -2.524300e+00                      0.2447
# 20 -1.041300e+00               -2.524300e+00                      0.2447
# 21  5.923270e+01                5.668260e+01                     62.0459
# 22  1.144391e+02                1.102766e+02                    118.4800
# 23  1.144391e+02                1.102766e+02                    118.4800
# 24  1.134677e+02                1.068011e+02                    118.4800
# 25  1.086053e+02                1.017297e+02                    113.8305
# 26  2.074789e+02                2.005620e+02                    212.7536
# 27  2.085767e+02                2.032666e+02                    212.8305
# 28  2.096703e+02                2.043514e+02                    213.8762
# 29  1.710231e+02                1.292999e+02                    174.5648
# 30  9.714000e-01                7.110000e-15                      4.5567
# 31  9.714000e-01                0.000000e+00                      4.5567
# 32  9.777180e+01                1.292690e+01                    100.0000
# 33  4.890390e+01                0.000000e+00                     59.1635
# 34  1.000000e-07                0.000000e+00                     44.8577
# 35  3.961870e+01                3.704340e+01                    100.0000
# 66  3.764570e+02                3.650427e+02                    386.6854
# 68  4.336956e+02                4.207564e+02                    445.9396
# 69  2.575270e+01                2.412740e+01                     27.0206
# 70  4.177000e-01                3.913000e-01                      0.4383
# 71  4.693400e+00                4.397200e+00                      4.9245
#
#     SPOT WT Value  SPOT WT std Value
# 0      100.000000       1.914048e+01
# 1        0.041488       4.970488e-06
# 2       -0.001485      -3.845459e-07
# 3        0.001359       1.790499e-07
# 4        0.132959       6.149714e-02
# 5        0.287776       1.347200e-01
# 6        0.287776      -1.347200e-01
# 7       53.476891      -3.533150e-01
# 8      103.294634       6.299113e+01
# 9     -433.571700      -1.447305e+01
# 10      -0.013548       9.319305e-07
# 11      -0.000246       1.379541e-07
# 12       0.033386       4.389314e-06
# 13      -0.031514      -4.114792e-06
# 14       0.023000       2.976859e-06
# 15       0.023000       2.976859e-06
# 16       0.016224       2.121020e-06
# 17       0.019398       2.524877e-06
# 18      -0.019398      -2.524877e-06
# 19       0.007805       1.241882e-06
# 20       0.004770       8.933000e-07
# 21      -0.002324       2.742114e-07
# 22     256.160277       9.558079e+01
# 23     256.163134       9.565106e+01
# 24      -0.053677       2.882583e+00
# 25      -0.005902       7.651574e-07
# 26      80.529001      -1.501926e+00
# 27     262.250615       7.532117e+01
# 28     262.249654       7.532551e+01
# 29     273.886433       4.667589e+01
# 30     256.216811       9.560257e+01
# 31      50.124307       3.319016e+01
# 32     330.281786       6.353286e+01
# 33       0.011301       1.972345e-06
# 34     312.512181       3.268624e+01
# 35      38.489643       4.757928e+01
# 66     303.978449      -3.671777e+01
# 68     441.236036       6.504742e+01
# 69      -0.141179       6.983660e-02
# 70       0.050335       9.651558e-06
# 71      -0.002577       3.226548e-07

# %% [markdown]
# #### Load observed growth rates and plot phenol growth rates

# %%
consumption_and_growth_data = pd.read_csv('../consumption_and_growth_data/consumption_and_growth_data.csv', index_col=0)
consumption_and_growth_data
# Out:
#                                                     substrate consumption rate  \
# Yoneda WT 1.5 g/L Phenol                                                 0.703
# Yoneda Evol33 1.5 g/L Phenol                                             1.014
# Yoneda Evol40 1.5 g/L Phenol                                             0.943
# Yoneda WT 1.0 g/L Glucose, 1.0 g/l ammonium sul...                       0.027
# Yoneda Evol33 1.0 g/L Glucose, 1.0 g/l ammonium...                       0.043
# Yoneda Evol40 1.0 g/L Glucose, 1.0 g/l ammonium...                      -0.063
# Yoneda WT 1.0 g/L Glucose, 0.05 g/l ammonium su...                       0.021
# Yoneda Evol33 1.0 g/L Glucose, 0.05 g/l ammoniu...                       0.033
# Yoneda Evol40 1.0 g/L Glucose, 0.05 g/l ammoniu...                       0.017
# Henson WT 0.5 g/L Phenol                                                 1.422
# Henson PVHG6 0.5 g/L Phenol                                              2.069
#
#                                                     substrate consumption rate std dev  \
# Yoneda WT 1.5 g/L Phenol                                                         0.033
# Yoneda Evol33 1.5 g/L Phenol                                                     0.021
# Yoneda Evol40 1.5 g/L Phenol                                                     0.030
# Yoneda WT 1.0 g/L Glucose, 1.0 g/l ammonium sul...                               0.000
# Yoneda Evol33 1.0 g/L Glucose, 1.0 g/l ammonium...                               0.000
# Yoneda Evol40 1.0 g/L Glucose, 1.0 g/l ammonium...                               0.000
# Yoneda WT 1.0 g/L Glucose, 0.05 g/l ammonium su...                               0.000
# Yoneda Evol33 1.0 g/L Glucose, 0.05 g/l ammoniu...                               0.000
# Yoneda Evol40 1.0 g/L Glucose, 0.05 g/l ammoniu...                               0.000
# Henson WT 0.5 g/L Phenol                                                         0.129
# Henson PVHG6 0.5 g/L Phenol                                                      0.023
#
#                                                     growth rate  \
# Yoneda WT 1.5 g/L Phenol                                  0.019
# Yoneda Evol33 1.5 g/L Phenol                              0.034
# Yoneda Evol40 1.5 g/L Phenol                              0.034
# Yoneda WT 1.0 g/L Glucose, 1.0 g/l ammonium sul...        0.032
# Yoneda Evol33 1.0 g/L Glucose, 1.0 g/l ammonium...        0.031
# Yoneda Evol40 1.0 g/L Glucose, 1.0 g/l ammonium...        0.031
# Yoneda WT 1.0 g/L Glucose, 0.05 g/l ammonium su...        0.039
# Yoneda Evol33 1.0 g/L Glucose, 0.05 g/l ammoniu...        0.033
# Yoneda Evol40 1.0 g/L Glucose, 0.05 g/l ammoniu...        0.034
# Henson WT 0.5 g/L Phenol                                  0.065
# Henson PVHG6 0.5 g/L Phenol                               0.080
#
#                                                     growth rate std dev  \
# Yoneda WT 1.5 g/L Phenol                                          0.001
# Yoneda Evol33 1.5 g/L Phenol                                      0.002
# Yoneda Evol40 1.5 g/L Phenol                                      0.001
# Yoneda WT 1.0 g/L Glucose, 1.0 g/l ammonium sul...                0.000
# Yoneda Evol33 1.0 g/L Glucose, 1.0 g/l ammonium...                0.000
# Yoneda Evol40 1.0 g/L Glucose, 1.0 g/l ammonium...                0.000
# Yoneda WT 1.0 g/L Glucose, 0.05 g/l ammonium su...                0.000
# Yoneda Evol33 1.0 g/L Glucose, 0.05 g/l ammoniu...                0.000
# Yoneda Evol40 1.0 g/L Glucose, 0.05 g/l ammoniu...                0.000
# Henson WT 0.5 g/L Phenol                                          0.001
# Henson PVHG6 0.5 g/L Phenol                                       0.003
#
#                                                     yield coefficient  \
# Yoneda WT 1.5 g/L Phenol                                        0.027
# Yoneda Evol33 1.5 g/L Phenol                                    0.033
# Yoneda Evol40 1.5 g/L Phenol                                    0.036
# Yoneda WT 1.0 g/L Glucose, 1.0 g/l ammonium sul...              1.150
# Yoneda Evol33 1.0 g/L Glucose, 1.0 g/l ammonium...              0.726
# Yoneda Evol40 1.0 g/L Glucose, 1.0 g/l ammonium...             -0.500
# Yoneda WT 1.0 g/L Glucose, 0.05 g/l ammonium su...              1.834
# Yoneda Evol33 1.0 g/L Glucose, 0.05 g/l ammoniu...              1.006
# Yoneda Evol40 1.0 g/L Glucose, 0.05 g/l ammoniu...              2.029
# Henson WT 0.5 g/L Phenol                                        0.046
# Henson PVHG6 0.5 g/L Phenol                                     0.039
#
#                                                     yield coefficient std dev
# Yoneda WT 1.5 g/L Phenol                                                0.003
# Yoneda Evol33 1.5 g/L Phenol                                            0.002
# Yoneda Evol40 1.5 g/L Phenol                                            0.002
# Yoneda WT 1.0 g/L Glucose, 1.0 g/l ammonium sul...                      0.000
# Yoneda Evol33 1.0 g/L Glucose, 1.0 g/l ammonium...                      0.000
# Yoneda Evol40 1.0 g/L Glucose, 1.0 g/l ammonium...                      0.000
# Yoneda WT 1.0 g/L Glucose, 0.05 g/l ammonium su...                      0.000
# Yoneda Evol33 1.0 g/L Glucose, 0.05 g/l ammoniu...                      0.000
# Yoneda Evol40 1.0 g/L Glucose, 0.05 g/l ammoniu...                      0.000
# Henson WT 0.5 g/L Phenol                                                0.005
# Henson PVHG6 0.5 g/L Phenol                                             0.002

# %%
new_index = pd.Series(['WT-HN-HP','EVOL33-HN-HP', 'EVOL40-HN-HP', 'WT-HN-G', 'EVOL33-HN-G', 'EVOL40-HN-G', 'WT-LN-G', 'EVOL33-LN-G', 'EVOL40-LN-G', 'WT-P', 'PVHG-P'])
consumption_and_growth_data = consumption_and_growth_data.set_index([new_index])

# %% [markdown]
# ##### **For comparison of predicted and observed growth rates: scale predicted growth rate by multiplying with (observed substrate uptake / predicted substrate uptake)**

# %%
def scale_growth_to_sub(solgrowth, soluptake, sub_uptake_2comp):
    if soluptake<=1e-6:
        solgrowthnew = solgrowth
    else:
        factor = abs(sub_uptake_2comp/(-soluptake))
        solgrowthnew = solgrowth*factor
    return solgrowthnew

# %%
scaledgrowthratespot_wtp = scale_growth_to_sub(spotsoldf.loc['Growth_Phenol',:].values[0], spotsoldf.loc['EX_glc__D_e',:].values[0],consumption_and_growth_data.loc['WT-P', 'substrate consumption rate'])
scaledgrowthratespot_pvhgp = scale_growth_to_sub(spotsoldf_PVHG.loc['Growth_Phenol',:].values[0], spotsoldf_PVHG.loc['EX_glc__D_e',:].values[0],consumption_and_growth_data.loc['PVHG-P',  'substrate consumption rate'])

# %% [markdown]
# ##### **Load Glucose growth rates to compare in same plot**

# %%
allgrowthratesglucose = pd.read_csv('allgrowthratesGlucoseSPOT.csv', index_col=0)
allgrowthratesglucose
# Out:
#              Growth_Glucose_SPOT
# WT-LN-G            -3.398487e-06
# EVOL33-LN-G        -4.251739e-06
# EVOL40-LN-G        -9.403108e-07

# %%
allgrowthrates=pd.DataFrame(index=['WT-P', 'PVHG-P', 'WT-LN-G', 'EVOL33-LN-G', 'EVOL40-LN-G'], columns=['Growth_SPOT'], dtype=float)

# %%
allgrowthrates.at['WT-P','Growth_SPOT'] = scaledgrowthratespot_wtp
allgrowthrates.at['PVHG-P','Growth_SPOT'] = scaledgrowthratespot_pvhgp

# %%
allgrowthrates.at['WT-LN-G','Growth_SPOT'] = allgrowthratesglucose.loc['WT-LN-G','Growth_Glucose_SPOT']
allgrowthrates.at['EVOL33-LN-G','Growth_SPOT'] = allgrowthratesglucose.loc['EVOL33-LN-G','Growth_Glucose_SPOT']
allgrowthrates.at['EVOL40-LN-G','Growth_SPOT'] = allgrowthratesglucose.loc['EVOL40-LN-G', 'Growth_Glucose_SPOT']
allgrowthrates
# Out:
#               Growth_SPOT
# WT-P        -6.863938e-07
# PVHG-P      -6.919804e-07
# WT-LN-G     -3.398487e-06
# EVOL33-LN-G -4.251739e-06
# EVOL40-LN-G -9.403108e-07

# %%
#Scatterplot of solutions
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm
from scipy.stats import linregress

def maefunc(y_predict, y_actual):
    """Mean Absolute Error.
    Multioutput case included."""

    if y_actual.ndim == 1:
        return np.mean(np.abs([y_a - y_p for y_a, y_p in zip(y_actual, y_predict)]))
    else:
        return [
            np.mean(
                np.abs([y_a - y_p for y_a, y_p in zip(y_actual[:, i], y_predict[:, i])])
            )
            for i in range(y_actual.shape[1])
        ]
    
def scatterplotcompare(observed, predicted, labels, strtitle):
    fig, ax = plt.subplots(figsize=(8, 8))
    
    lims = [
                np.min([observed, predicted]),  # min of both axes
                np.max([observed, predicted]),  # max of both axes
            ]
    ax.set_xlim(lims)
    
    # Plot Diagonal Dashed Line
    ax.plot(lims, lims, ls="--", color=".8", zorder=0)
    for i in range(0, len(observed)):
        ax.scatter(observed[i], predicted[i])
        ax.annotate(str(labels[i]),(observed[i],predicted[i]))
        
    #calculate statistical quantities:
    rss = np.sum((predicted - observed) ** 2)
    tss = np.sum((predicted - predicted.mean()) ** 2)
    
    #r2_1 = round(1 - rss / tss,2) #other way to calculate rsquared
    _, _, growth_r, _, _ = scipy.stats.linregress(observed, predicted)

    #r2 = round(r2_score(observed, predicted),2) #other way to calculate rsquared
    mse = np.round(1/len(observed) * rss,2) 
    rmse = np.round(np.sqrt(1/len(observed) * rss),2)
    mae_score = round(maefunc(observed, predicted),2)
    
    plt.xlabel(r'Observed growth rates [$mmol/gDW/hr$]')
    plt.ylabel(r'Predicted growth rates [$mmol/gDW/hr$]')
    plt.title(r'Growth rates: Observed vs. Predicted ('+strtitle+'), \n' + f"$R^2$={growth_r**2:.2F}, MAE={mae_score}, MSE = {mse}, RMSE={rmse}", fontsize=18)
    plt.show()

# %%
new_index = pd.Series(['WT-HN-HP','EVOL33-HN-HP', 'EVOL40-HN-HP', 'WT-HN-G', 'EVOL33-HN-G', 'EVOL40-HN-G', 'WT-LN-G', 'EVOL33-LN-G', 'EVOL40-LN-G', 'WT-P', 'PVHG-P'])
consumption_and_growth_data = consumption_and_growth_data.set_index([new_index])

# %%
allindices=[str(row) for row in allgrowthrates.index]
scatterplotcompare(consumption_and_growth_data.loc[['WT-P', 'PVHG-P'], 'growth rate'], allgrowthrates.loc[['WT-P', 'PVHG-P'],'Growth_SPOT'], allindices, 'SPOT')

# %%
allindices=[str(row) for row in allgrowthrates.index]
scatterplotcompare(consumption_and_growth_data.loc[allindices, 'growth rate'], allgrowthrates.loc[allindices,'Growth_SPOT'], allindices, 'SPOT')

# %%
allgrowthrates.to_csv('allgrowthratesSPOT.csv', index=True, header= True)
