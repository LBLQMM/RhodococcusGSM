# %% [markdown]
# # Transcriptomic and Proteomic based flux predictions
# This notebook integrates Transcriptomic measurements into flux profiles

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import cobra

# %% [markdown]
# ### Load Transcriptomics Data

# %%
yoneda_data = pd.read_csv('../../EDD_Yoneda_data/Yoneda_set3_transcriptomics_data.csv')

# remove blank columns
yoneda_data = yoneda_data[[col for col in yoneda_data.columns if 'Unnamed' not in col]]

yoneda_data.head()
# Out:
#   Line Name Measurement Type  Time  Value   Units
# 0   WT-G-R1   PD630_LPD06575    14    708  counts
# 1   WT-G-R1   PD630_LPD06576    14   6513  counts
# 2   WT-G-R1   PD630_LPD00131    14   1015  counts
# 3   WT-G-R1   PD630_LPD06740    14    289  counts
# 4   WT-G-R1   PD630_LPD06741    14   1159  counts

# %% [markdown]
# ### Make a dictionary where keys are measured gene names and the values are lists of  measured values and  add measured values to the lists

# %%
genes = list(set(yoneda_data['Measurement Type']))
gene_dictionary = {gene:[] for gene in genes}

conditions = list(set(yoneda_data['Line Name']))

for condition in conditions:
    print(condition)
    condition_df = yoneda_data[yoneda_data['Line Name'] == condition]
#     print(condition_df.head())
    for gene in genes:
        try:
            gene_value = float(condition_df[condition_df['Measurement Type'] == gene]['Value'])
            gene_dictionary[gene].append(gene_value)
        except:
            gene_dictionary[gene].append('none')
# Out:
# EVOL40-L-R1
# EVOL40-G-R1
# WT-G-R1
# EVOL33-G-R1
# EVOL33-L-R1
# EVOL40-H-R1
# WT-L-R1
# EVOL33-H-R1

# %% [markdown]
# ### Remove genes that do have multiple measurements for a single run

# %%
new_gene_dictionary = {}
for gene, values in gene_dictionary.items():
    if len(values) == 8:
        new_gene_dictionary[gene] = values
    else:
        print(len(values), gene, values)

# %% [markdown]
# ### Convert the gene dictionary to a dataframe

# %%
transcriptomic_df = pd.DataFrame.from_dict(new_gene_dictionary, orient='index', columns=conditions)
transcriptomic_df
# Out:
#                EVOL40-L-R1 EVOL40-G-R1 WT-G-R1 EVOL33-G-R1 EVOL33-L-R1  \
# PD630_LPD15471        none        none    none        none        none
# PD630_LPD07867          56          39      21          25          31
# PD630_LPD08755        none        none    none        none        none
# PD630_LPD14956        none        none    none        none        none
# PD630_LPD13951        none        none    none        none        none
# ...                    ...         ...     ...         ...         ...
# PD630_LPD10395        none        none    none        none        none
# PD630_LPD00992         117          90      68          55          83
# PD630_LPD09349        none        none    none        none        none
# PD630_LPD08166        none        none    none        none        none
# PD630_LPD07210           3           4       3           2           2
#
#                 EVOL40-H-R1 WT-L-R1 EVOL33-H-R1
# PD630_LPD15471  5.39838e+06    none        none
# PD630_LPD07867  5.39838e+06      44          38
# PD630_LPD08755  5.39838e+06    none        none
# PD630_LPD14956  5.39838e+06    none        none
# PD630_LPD13951  5.39838e+06    none        none
# ...                     ...     ...         ...
# PD630_LPD10395  5.39838e+06    none        none
# PD630_LPD00992         none      54         393
# PD630_LPD09349  5.39838e+06    none        none
# PD630_LPD08166  5.39838e+06    none        none
# PD630_LPD07210  5.39838e+06       2           4
#
# [15685 rows x 8 columns]

# %% [markdown]
# ### Load LPD to WP mapping

# %%
gene_mapping_df = pd.read_csv('../gene_converter/LPD_RS_WP_gene_mapping.csv')

# remove blank columns
gene_mapping_df = gene_mapping_df[[col for col in gene_mapping_df.columns if 'Unnamed' not in col]]

gene_mapping_df.head()
# Out:
#     Gene ID (RS)   Gene ID (LPD)    Gene ID (WP)  \
# 0  PD630_RS00005  Pd630_LPD00001            none
# 1  PD630_RS00010  Pd630_LPD00002  WP_005569241.1
# 2  PD630_RS00015  Pd630_LPD00003  WP_007296166.1
# 3  PD630_RS00020  Pd630_LPD00004  WP_005237760.1
# 4  PD630_RS00025  Pd630_LPD00005  WP_005237761.1
#
#                                        Annotation
# 0  chromosomal replication initiator protein DnaA
# 1                 DNA polymerase III subunit beta
# 2                6-phosphogluconate dehydrogenase
# 3         DNA replication and repair protein RecF
# 4                            hypothetical protein

# %% [markdown]
# ### Add WP annoation to transcriptomic_df

# %%
# make dicitonary where keys are LPD IDs and values are WP IDs 
LPD_to_WP_dictionary = {row['Gene ID (LPD)']:row['Gene ID (WP)'] for _, row in gene_mapping_df.iterrows()}

# WP_genes = []
# for index, _ in transcriptomic_df.iterrows():
#     try:
#         WP_genes.append(LPD_to_WP_dictionary[index])
#     except:
#         WP_genes.append('Unknown')
#         print(f'{index} does not have a matching known WP Id')

# transcriptomic_df['WP_gene'] = WP_genes

# transcriptomic_df['WP_gene'] = [LPD_to_WP_dictionary[index] for index, _ in transcriptomic_df.iterrows()]

# transcriptomic_df

index = 'Pd630_LPD00003'
print(LPD_to_WP_dictionary[index])
# Out:
# WP_007296166.1

# %%
print(len([gene for gene in list(transcriptomic_df.index) if gene not in list(LPD_to_WP_dictionary.keys())]))
# Out:
# 15685

# %%
yoneda_ids = list(transcriptomic_df.index)
mapping_ids = list(LPD_to_WP_dictionary.keys())

print(yoneda_ids[:20])
print(mapping_ids[:20])
# Out:
# ['PD630_LPD15471', 'PD630_LPD07867', 'PD630_LPD08755', 'PD630_LPD14956', 'PD630_LPD13951', 'PD630_LPD02317', 'PD630_LPD10425', 'PD630_LPD13694', 'PD630_LPD05166', 'PD630_LPD02798', 'PD630_LPD10189', 'PD630_LPD12451', 'PD630_LPD02143', 'PD630_LPD06206', 'PD630_LPD12587', 'PD630_LPD07583', 'PD630_LPD04932', 'PD630_LPD13359', 'PD630_LPD08127', 'PD630_LPD02555']
# ['Pd630_LPD00001', 'Pd630_LPD00002', 'Pd630_LPD00003', 'Pd630_LPD00004', 'Pd630_LPD00005', 'Pd630_LPD00006', 'Pd630_LPD00007', 'Pd630_LPD00008', 'Pd630_LPD00009', 'Pd630_LPD00011', 'Pd630_LPD00012', 'Pd630_LPD00013', 'Pd630_LPD00014', 'Pd630_LPD00015', 'Pd630_LPD00016', 'Pd630_LPD00017', 'Pd630_LPD00018', 'Pd630_LPD00019', 'Pd630_LPD00020', 'Pd630_LPD00021']

# %% [markdown]
# # The problem is the capitalization of PD vs Pd

# %%
test = list(LPD_to_WP_dictionary.keys())
test.sort(reverse=True)
test
# Out:
# ['none',
#  'Pd630_LPD17037',
#  'Pd630_LPD17036',
#  'Pd630_LPD17035',
#  'Pd630_LPD17033',
#  'Pd630_LPD17032',
#  'Pd630_LPD17031',
#  'Pd630_LPD11089',
#  'Pd630_LPD11088',
#  'Pd630_LPD11087',
#  'Pd630_LPD11084',
#  'Pd630_LPD11083',
#  'Pd630_LPD11082',
#  'Pd630_LPD11081',
#  'Pd630_LPD11080',
#  'Pd630_LPD11078',
#  'Pd630_LPD11076',
#  'Pd630_LPD11075',
#  'Pd630_LPD11074',
#  'Pd630_LPD11073',
#  'Pd630_LPD11070',
#  'Pd630_LPD11069',
#  'Pd630_LPD11068',
#  'Pd630_LPD11067',
#  'Pd630_LPD11066',
#  'Pd630_LPD11065',
#  'Pd630_LPD11063',
#  'Pd630_LPD11061',
#  'Pd630_LPD11060',
#  'Pd630_LPD11059',
#  'Pd630_LPD11057',
#  'Pd630_LPD11056',
#  'Pd630_LPD11053',
#  'Pd630_LPD11052',
#  'Pd630_LPD11051',
#  'Pd630_LPD11050',
#  'Pd630_LPD11049',
#  'Pd630_LPD11046',
#  'Pd630_LPD11044',
#  'Pd630_LPD11041',
#  'Pd630_LPD11040',
#  'Pd630_LPD11039',
#  'Pd630_LPD11037',
#  'Pd630_LPD11033',
#  'Pd630_LPD11029',
#  'Pd630_LPD11026',
#  'Pd630_LPD11024',
#  'Pd630_LPD11022',
#  'Pd630_LPD11020',
#  'Pd630_LPD11017',
#  'Pd630_LPD11016',
#  'Pd630_LPD11015',
#  'Pd630_LPD11010',
#  'Pd630_LPD11009',
#  'Pd630_LPD11006',
#  'Pd630_LPD11003',
#  'Pd630_LPD11001',
#  'Pd630_LPD10125',
#  'Pd630_LPD10124',
#  'Pd630_LPD10123',
#  'Pd630_LPD10122',
#  'Pd630_LPD10121',
#  'Pd630_LPD10120',
#  'Pd630_LPD10117',
#  'Pd630_LPD10116',
#  'Pd630_LPD10115',
#  'Pd630_LPD10109',
#  'Pd630_LPD10108',
#  'Pd630_LPD10104',
#  'Pd630_LPD10102',
#  'Pd630_LPD10101',
#  'Pd630_LPD10100',
#  'Pd630_LPD10099',
#  'Pd630_LPD10098',
#  'Pd630_LPD10097',
#  'Pd630_LPD10094',
#  'Pd630_LPD10091',
#  'Pd630_LPD10090',
#  'Pd630_LPD10088',
#  'Pd630_LPD10077',
#  'Pd630_LPD10076',
#  'Pd630_LPD10075',
#  'Pd630_LPD10072',
#  'Pd630_LPD10067',
#  'Pd630_LPD10066',
#  'Pd630_LPD10065',
#  'Pd630_LPD10064',
#  'Pd630_LPD10063',
#  'Pd630_LPD10061',
#  'Pd630_LPD10058',
#  'Pd630_LPD10057',
#  'Pd630_LPD10056',
#  'Pd630_LPD10054',
#  'Pd630_LPD10053',
#  'Pd630_LPD10052',
#  'Pd630_LPD10051',
#  'Pd630_LPD10048',
#  'Pd630_LPD10047',
#  'Pd630_LPD10045',
#  'Pd630_LPD10044',
#  'Pd630_LPD10043',
#  'Pd630_LPD10040',
#  'Pd630_LPD10039',
#  'Pd630_LPD10038',
#  'Pd630_LPD10037',
#  'Pd630_LPD10036',
#  'Pd630_LPD10035',
#  'Pd630_LPD10034',
#  'Pd630_LPD10031',
#  'Pd630_LPD10030',
#  'Pd630_LPD10027',
#  'Pd630_LPD10026',
#  'Pd630_LPD10025',
#  'Pd630_LPD10024',
#  'Pd630_LPD10023',
#  'Pd630_LPD10022',
#  'Pd630_LPD10021',
#  'Pd630_LPD10020',
#  'Pd630_LPD10019',
#  'Pd630_LPD10014',
#  'Pd630_LPD10012',
#  'Pd630_LPD10011',
#  'Pd630_LPD10008',
#  'Pd630_LPD10007',
#  'Pd630_LPD10004',
#  'Pd630_LPD09209',
#  'Pd630_LPD09208',
#  'Pd630_LPD09207',
#  'Pd630_LPD09203',
#  'Pd630_LPD09196',
#  'Pd630_LPD09194',
#  'Pd630_LPD09193',
#  'Pd630_LPD09190',
#  'Pd630_LPD09189',
#  'Pd630_LPD09187',
#  'Pd630_LPD09186',
#  'Pd630_LPD09185',
#  'Pd630_LPD09184',
#  'Pd630_LPD09183',
#  'Pd630_LPD09181',
#  'Pd630_LPD09177',
#  'Pd630_LPD09176',
#  'Pd630_LPD09175',
#  'Pd630_LPD09170',
#  'Pd630_LPD09169',
#  'Pd630_LPD09166',
#  'Pd630_LPD09164',
#  'Pd630_LPD09162',
#  'Pd630_LPD09159',
#  'Pd630_LPD09158',
#  'Pd630_LPD09157',
#  'Pd630_LPD09155',
#  'Pd630_LPD09154',
#  'Pd630_LPD09153',
#  'Pd630_LPD09151',
#  'Pd630_LPD09150',
#  'Pd630_LPD09149',
#  'Pd630_LPD09145',
#  'Pd630_LPD09144',
#  'Pd630_LPD09141',
#  'Pd630_LPD09140',
#  'Pd630_LPD09139',
#  'Pd630_LPD09138',
#  'Pd630_LPD09137',
#  'Pd630_LPD09136',
#  'Pd630_LPD09135',
#  'Pd630_LPD09132',
#  'Pd630_LPD09131',
#  'Pd630_LPD09128',
#  'Pd630_LPD09127',
#  'Pd630_LPD09126',
#  'Pd630_LPD09125',
#  'Pd630_LPD09124',
#  'Pd630_LPD09121',
#  'Pd630_LPD09120',
#  'Pd630_LPD09118',
#  'Pd630_LPD09117',
#  'Pd630_LPD09116',
#  'Pd630_LPD09115',
#  'Pd630_LPD09114',
#  'Pd630_LPD09110',
#  'Pd630_LPD09109',
#  'Pd630_LPD09108',
#  'Pd630_LPD09107',
#  'Pd630_LPD09105',
#  'Pd630_LPD09104',
#  'Pd630_LPD09103',
#  'Pd630_LPD09102',
#  'Pd630_LPD09101',
#  'Pd630_LPD09100',
#  'Pd630_LPD09099',
#  'Pd630_LPD09097',
#  'Pd630_LPD09095',
#  'Pd630_LPD09093',
#  'Pd630_LPD09091',
#  'Pd630_LPD09090',
#  'Pd630_LPD09089',
#  'Pd630_LPD09084',
#  'Pd630_LPD09083',
#  'Pd630_LPD09080',
#  'Pd630_LPD09079',
#  'Pd630_LPD09078',
#  'Pd630_LPD09076',
#  'Pd630_LPD09075',
#  'Pd630_LPD09074',
#  'Pd630_LPD09072',
#  'Pd630_LPD09066',
#  'Pd630_LPD09065',
#  'Pd630_LPD09063',
#  'Pd630_LPD09062',
#  'Pd630_LPD09061',
#  'Pd630_LPD09059',
#  'Pd630_LPD09056',
#  'Pd630_LPD09055',
#  'Pd630_LPD09054',
#  'Pd630_LPD09053',
#  'Pd630_LPD09052',
#  'Pd630_LPD09050',
#  'Pd630_LPD09049',
#  'Pd630_LPD09047',
#  'Pd630_LPD09046',
#  'Pd630_LPD09045',
#  'Pd630_LPD09044',
#  'Pd630_LPD09043',
#  'Pd630_LPD09042',
#  'Pd630_LPD09040',
#  'Pd630_LPD09039',
#  'Pd630_LPD09035',
#  'Pd630_LPD09034',
#  'Pd630_LPD09028',
#  'Pd630_LPD09025',
#  'Pd630_LPD09024',
#  'Pd630_LPD09023',
#  'Pd630_LPD09022',
#  'Pd630_LPD09021',
#  'Pd630_LPD09019',
#  'Pd630_LPD09018',
#  'Pd630_LPD09017',
#  'Pd630_LPD09016',
#  'Pd630_LPD09015',
#  'Pd630_LPD09013',
#  'Pd630_LPD09012',
#  'Pd630_LPD09011',
#  'Pd630_LPD09010',
#  'Pd630_LPD09009',
#  'Pd630_LPD09008',
#  'Pd630_LPD09007',
#  'Pd630_LPD09006',
#  'Pd630_LPD09005',
#  'Pd630_LPD09004',
#  'Pd630_LPD09003',
#  'Pd630_LPD09002',
#  'Pd630_LPD09001',
#  'Pd630_LPD08053',
#  'Pd630_LPD08052',
#  'Pd630_LPD08050',
#  'Pd630_LPD08047',
#  'Pd630_LPD08046',
#  'Pd630_LPD08045',
#  'Pd630_LPD08044',
#  'Pd630_LPD08043',
#  'Pd630_LPD08042',
#  'Pd630_LPD08041',
#  'Pd630_LPD08040',
#  'Pd630_LPD08039',
#  'Pd630_LPD08038',
#  'Pd630_LPD08037',
#  'Pd630_LPD08036',
#  'Pd630_LPD08035',
#  'Pd630_LPD08034',
#  'Pd630_LPD08033',
#  'Pd630_LPD08032',
#  'Pd630_LPD08031',
#  'Pd630_LPD08030',
#  'Pd630_LPD08029',
#  'Pd630_LPD08028',
#  'Pd630_LPD08027',
#  'Pd630_LPD08026',
#  'Pd630_LPD08024',
#  'Pd630_LPD08023',
#  'Pd630_LPD08022',
#  'Pd630_LPD08021',
#  'Pd630_LPD08020',
#  'Pd630_LPD08019',
#  'Pd630_LPD08018',
#  'Pd630_LPD08017',
#  'Pd630_LPD08016',
#  'Pd630_LPD08015',
#  'Pd630_LPD08014',
#  'Pd630_LPD08013',
#  'Pd630_LPD08012',
#  'Pd630_LPD08011',
#  'Pd630_LPD08010',
#  'Pd630_LPD08009',
#  'Pd630_LPD08008',
#  'Pd630_LPD08007',
#  'Pd630_LPD08006',
#  'Pd630_LPD08005',
#  'Pd630_LPD08004',
#  'Pd630_LPD08003',
#  'Pd630_LPD08002',
#  'Pd630_LPD08001',
#  'Pd630_LPD08000',
#  'Pd630_LPD07997',
#  'Pd630_LPD07996',
#  'Pd630_LPD07995',
#  'Pd630_LPD07994',
#  'Pd630_LPD07993',
#  'Pd630_LPD07992',
#  'Pd630_LPD07991',
#  'Pd630_LPD07990',
#  'Pd630_LPD07989',
#  'Pd630_LPD07988',
#  'Pd630_LPD07987',
#  'Pd630_LPD07986',
#  'Pd630_LPD07985',
#  'Pd630_LPD07984',
#  'Pd630_LPD07983',
#  'Pd630_LPD07982',
#  'Pd630_LPD07981',
#  'Pd630_LPD07980',
#  'Pd630_LPD07979',
#  'Pd630_LPD07978',
#  'Pd630_LPD07977',
#  'Pd630_LPD07976',
#  'Pd630_LPD07974',
#  'Pd630_LPD07973',
#  'Pd630_LPD07972',
#  'Pd630_LPD07971',
#  'Pd630_LPD07970',
#  'Pd630_LPD07969',
#  'Pd630_LPD07968',
#  'Pd630_LPD07967',
#  'Pd630_LPD07966',
#  'Pd630_LPD07965',
#  'Pd630_LPD07964',
#  'Pd630_LPD07963',
#  'Pd630_LPD07961',
#  'Pd630_LPD07960',
#  'Pd630_LPD07959',
#  'Pd630_LPD07958',
#  'Pd630_LPD07957',
#  'Pd630_LPD07956',
#  'Pd630_LPD07954',
#  'Pd630_LPD07953',
#  'Pd630_LPD07952',
#  'Pd630_LPD07951',
#  'Pd630_LPD07950',
#  'Pd630_LPD07949',
#  'Pd630_LPD07948',
#  'Pd630_LPD07947',
#  'Pd630_LPD07946',
#  'Pd630_LPD07945',
#  'Pd630_LPD07944',
#  'Pd630_LPD07943',
#  'Pd630_LPD07942',
#  'Pd630_LPD07941',
#  'Pd630_LPD07940',
#  'Pd630_LPD07938',
#  'Pd630_LPD07937',
#  'Pd630_LPD07935',
#  'Pd630_LPD07934',
#  'Pd630_LPD07933',
#  'Pd630_LPD07932',
#  'Pd630_LPD07931',
#  'Pd630_LPD07926',
#  'Pd630_LPD07925',
#  'Pd630_LPD07924',
#  'Pd630_LPD07923',
#  'Pd630_LPD07922',
#  'Pd630_LPD07921',
#  'Pd630_LPD07920',
#  'Pd630_LPD07919',
#  'Pd630_LPD07918',
#  'Pd630_LPD07917',
#  'Pd630_LPD07916',
#  'Pd630_LPD07915',
#  'Pd630_LPD07914',
#  'Pd630_LPD07913',
#  'Pd630_LPD07912',
#  'Pd630_LPD07911',
#  'Pd630_LPD07910',
#  'Pd630_LPD07909',
#  'Pd630_LPD07907',
#  'Pd630_LPD07906',
#  'Pd630_LPD07905',
#  'Pd630_LPD07904',
#  'Pd630_LPD07903',
#  'Pd630_LPD07902',
#  'Pd630_LPD07901',
#  'Pd630_LPD07900',
#  'Pd630_LPD07899',
#  'Pd630_LPD07898',
#  'Pd630_LPD07897',
#  'Pd630_LPD07896',
#  'Pd630_LPD07895',
#  'Pd630_LPD07894',
#  'Pd630_LPD07893',
#  'Pd630_LPD07892',
#  'Pd630_LPD07886',
#  'Pd630_LPD07885',
#  'Pd630_LPD07882',
#  'Pd630_LPD07881',
#  'Pd630_LPD07880',
#  'Pd630_LPD07879',
#  'Pd630_LPD07877',
#  'Pd630_LPD07876',
#  'Pd630_LPD07875',
#  'Pd630_LPD07874',
#  'Pd630_LPD07873',
#  'Pd630_LPD07872',
#  'Pd630_LPD07871',
#  'Pd630_LPD07870',
#  'Pd630_LPD07869',
#  'Pd630_LPD07868',
#  'Pd630_LPD07867',
#  'Pd630_LPD07866',
#  'Pd630_LPD07865',
#  'Pd630_LPD07864',
#  'Pd630_LPD07863',
#  'Pd630_LPD07862',
#  'Pd630_LPD07861',
#  'Pd630_LPD07860',
#  'Pd630_LPD07859',
#  'Pd630_LPD07858',
#  'Pd630_LPD07857',
#  'Pd630_LPD07856',
#  'Pd630_LPD07855',
#  'Pd630_LPD07854',
#  'Pd630_LPD07853',
#  'Pd630_LPD07852',
#  'Pd630_LPD07851',
#  'Pd630_LPD07850',
#  'Pd630_LPD07849',
#  'Pd630_LPD07848',
#  'Pd630_LPD07847',
#  'Pd630_LPD07846',
#  'Pd630_LPD07845',
#  'Pd630_LPD07844',
#  'Pd630_LPD07842',
#  'Pd630_LPD07841',
#  'Pd630_LPD07839',
#  'Pd630_LPD07838',
#  'Pd630_LPD07837',
#  'Pd630_LPD07836',
#  'Pd630_LPD07835',
#  'Pd630_LPD07834',
#  'Pd630_LPD07833',
#  'Pd630_LPD07828',
#  'Pd630_LPD07827',
#  'Pd630_LPD07826',
#  'Pd630_LPD07825',
#  'Pd630_LPD07824',
#  'Pd630_LPD07823',
#  'Pd630_LPD07821',
#  'Pd630_LPD07820',
#  'Pd630_LPD07819',
#  'Pd630_LPD07818',
#  'Pd630_LPD07817',
#  'Pd630_LPD07816',
#  'Pd630_LPD07815',
#  'Pd630_LPD07814',
#  'Pd630_LPD07813',
#  'Pd630_LPD07812',
#  'Pd630_LPD07811',
#  'Pd630_LPD07810',
#  'Pd630_LPD07809',
#  'Pd630_LPD07808',
#  'Pd630_LPD07807',
#  'Pd630_LPD07806',
#  'Pd630_LPD07805',
#  'Pd630_LPD07804',
#  'Pd630_LPD07803',
#  'Pd630_LPD07802',
#  'Pd630_LPD07801',
#  'Pd630_LPD07799',
#  'Pd630_LPD07798',
#  'Pd630_LPD07797',
#  'Pd630_LPD07796',
#  'Pd630_LPD07795',
#  'Pd630_LPD07793',
#  'Pd630_LPD07792',
#  'Pd630_LPD07791',
#  'Pd630_LPD07788',
#  'Pd630_LPD07787',
#  'Pd630_LPD07786',
#  'Pd630_LPD07785',
#  'Pd630_LPD07784',
#  'Pd630_LPD07783',
#  'Pd630_LPD07782',
#  'Pd630_LPD07781',
#  'Pd630_LPD07780',
#  'Pd630_LPD07779',
#  'Pd630_LPD07778',
#  'Pd630_LPD07777',
#  'Pd630_LPD07776',
#  'Pd630_LPD07775',
#  'Pd630_LPD07774',
#  'Pd630_LPD07773',
#  'Pd630_LPD07772',
#  'Pd630_LPD07771',
#  'Pd630_LPD07770',
#  'Pd630_LPD07769',
#  'Pd630_LPD07768',
#  'Pd630_LPD07767',
#  'Pd630_LPD07765',
#  'Pd630_LPD07764',
#  'Pd630_LPD07763',
#  'Pd630_LPD07762',
#  'Pd630_LPD07760',
#  'Pd630_LPD07759',
#  'Pd630_LPD07758',
#  'Pd630_LPD07756',
#  'Pd630_LPD07755',
#  'Pd630_LPD07752',
#  'Pd630_LPD07751',
#  'Pd630_LPD07750',
#  'Pd630_LPD07749',
#  'Pd630_LPD07748',
#  'Pd630_LPD07747',
#  'Pd630_LPD07746',
#  'Pd630_LPD07745',
#  'Pd630_LPD07744',
#  'Pd630_LPD07743',
#  'Pd630_LPD07742',
#  'Pd630_LPD07741',
#  'Pd630_LPD07740',
#  'Pd630_LPD07739',
#  'Pd630_LPD07738',
#  'Pd630_LPD07737',
#  'Pd630_LPD07736',
#  'Pd630_LPD07735',
#  'Pd630_LPD07734',
#  'Pd630_LPD07733',
#  'Pd630_LPD07732',
#  'Pd630_LPD07731',
#  'Pd630_LPD07730',
#  'Pd630_LPD07729',
#  'Pd630_LPD07728',
#  'Pd630_LPD07726',
#  'Pd630_LPD07725',
#  'Pd630_LPD07724',
#  'Pd630_LPD07723',
#  'Pd630_LPD07722',
#  'Pd630_LPD07721',
#  'Pd630_LPD07716',
#  'Pd630_LPD07715',
#  'Pd630_LPD07714',
#  'Pd630_LPD07713',
#  'Pd630_LPD07712',
#  'Pd630_LPD07711',
#  'Pd630_LPD07710',
#  'Pd630_LPD07708',
#  'Pd630_LPD07707',
#  'Pd630_LPD07706',
#  'Pd630_LPD07705',
#  'Pd630_LPD07704',
#  'Pd630_LPD07703',
#  'Pd630_LPD07702',
#  'Pd630_LPD07701',
#  'Pd630_LPD07699',
#  'Pd630_LPD07698',
#  'Pd630_LPD07697',
#  'Pd630_LPD07696',
#  'Pd630_LPD07695',
#  'Pd630_LPD07694',
#  'Pd630_LPD07693',
#  'Pd630_LPD07692',
#  'Pd630_LPD07691',
#  'Pd630_LPD07690',
#  'Pd630_LPD07689',
#  'Pd630_LPD07688',
#  'Pd630_LPD07687',
#  'Pd630_LPD07685',
#  'Pd630_LPD07682',
#  'Pd630_LPD07681',
#  'Pd630_LPD07680',
#  'Pd630_LPD07679',
#  'Pd630_LPD07678',
#  'Pd630_LPD07676',
#  'Pd630_LPD07675',
#  'Pd630_LPD07674',
#  'Pd630_LPD07673',
#  'Pd630_LPD07672',
#  'Pd630_LPD07671',
#  'Pd630_LPD07670',
#  'Pd630_LPD07669',
#  'Pd630_LPD07668',
#  'Pd630_LPD07666',
#  'Pd630_LPD07665',
#  'Pd630_LPD07664',
#  'Pd630_LPD07663',
#  'Pd630_LPD07662',
#  'Pd630_LPD07661',
#  'Pd630_LPD07660',
#  'Pd630_LPD07658',
#  'Pd630_LPD07657',
#  'Pd630_LPD07656',
#  'Pd630_LPD07655',
#  'Pd630_LPD07654',
#  'Pd630_LPD07653',
#  'Pd630_LPD07652',
#  'Pd630_LPD07651',
#  'Pd630_LPD07650',
#  'Pd630_LPD07649',
#  'Pd630_LPD07648',
#  'Pd630_LPD07647',
#  'Pd630_LPD07646',
#  'Pd630_LPD07645',
#  'Pd630_LPD07643',
#  'Pd630_LPD07642',
#  'Pd630_LPD07641',
#  'Pd630_LPD07640',
#  'Pd630_LPD07639',
#  'Pd630_LPD07637',
#  'Pd630_LPD07636',
#  'Pd630_LPD07635',
#  'Pd630_LPD07634',
#  'Pd630_LPD07633',
#  'Pd630_LPD07632',
#  'Pd630_LPD07631',
#  'Pd630_LPD07629',
#  'Pd630_LPD07628',
#  'Pd630_LPD07627',
#  'Pd630_LPD07626',
#  'Pd630_LPD07625',
#  'Pd630_LPD07624',
#  'Pd630_LPD07623',
#  'Pd630_LPD07622',
#  'Pd630_LPD07621',
#  'Pd630_LPD07620',
#  'Pd630_LPD07619',
#  'Pd630_LPD07618',
#  'Pd630_LPD07616',
#  'Pd630_LPD07615',
#  'Pd630_LPD07614',
#  'Pd630_LPD07613',
#  'Pd630_LPD07612',
#  'Pd630_LPD07611',
#  'Pd630_LPD07609',
#  'Pd630_LPD07608',
#  'Pd630_LPD07607',
#  'Pd630_LPD07606',
#  'Pd630_LPD07605',
#  'Pd630_LPD07604',
#  'Pd630_LPD07603',
#  'Pd630_LPD07602',
#  'Pd630_LPD07600',
#  'Pd630_LPD07599',
#  'Pd630_LPD07598',
#  'Pd630_LPD07597',
#  'Pd630_LPD07596',
#  'Pd630_LPD07595',
#  'Pd630_LPD07594',
#  'Pd630_LPD07593',
#  'Pd630_LPD07592',
#  'Pd630_LPD07591',
#  'Pd630_LPD07590',
#  'Pd630_LPD07589',
#  'Pd630_LPD07588',
#  'Pd630_LPD07587',
#  'Pd630_LPD07586',
#  'Pd630_LPD07585',
#  'Pd630_LPD07584',
#  'Pd630_LPD07583',
#  'Pd630_LPD07582',
#  'Pd630_LPD07581',
#  'Pd630_LPD07580',
#  'Pd630_LPD07579',
#  'Pd630_LPD07578',
#  'Pd630_LPD07577',
#  'Pd630_LPD07575',
#  'Pd630_LPD07574',
#  'Pd630_LPD07573',
#  'Pd630_LPD07572',
#  'Pd630_LPD07571',
#  'Pd630_LPD07570',
#  'Pd630_LPD07569',
#  'Pd630_LPD07567',
#  'Pd630_LPD07566',
#  'Pd630_LPD07565',
#  'Pd630_LPD07564',
#  'Pd630_LPD07563',
#  'Pd630_LPD07562',
#  ...]

# %%
transcriptomic_df
# Out:
#                EVOL40-L-R1 EVOL40-G-R1 WT-G-R1 EVOL33-G-R1 EVOL33-L-R1  \
# PD630_LPD15471        none        none    none        none        none
# PD630_LPD07867          56          39      21          25          31
# PD630_LPD08755        none        none    none        none        none
# PD630_LPD14956        none        none    none        none        none
# PD630_LPD13951        none        none    none        none        none
# ...                    ...         ...     ...         ...         ...
# PD630_LPD10395        none        none    none        none        none
# PD630_LPD00992         117          90      68          55          83
# PD630_LPD09349        none        none    none        none        none
# PD630_LPD08166        none        none    none        none        none
# PD630_LPD07210           3           4       3           2           2
#
#                 EVOL40-H-R1 WT-L-R1 EVOL33-H-R1
# PD630_LPD15471  5.39838e+06    none        none
# PD630_LPD07867  5.39838e+06      44          38
# PD630_LPD08755  5.39838e+06    none        none
# PD630_LPD14956  5.39838e+06    none        none
# PD630_LPD13951  5.39838e+06    none        none
# ...                     ...     ...         ...
# PD630_LPD10395  5.39838e+06    none        none
# PD630_LPD00992         none      54         393
# PD630_LPD09349  5.39838e+06    none        none
# PD630_LPD08166  5.39838e+06    none        none
# PD630_LPD07210  5.39838e+06       2           4
#
# [15685 rows x 8 columns]

# %% [markdown]
# ### This is a rewrite of the above code that is more succinct, but takes a lot longer to run

# %%
# gene_dictionary_2 = {}

# for x, gene in enumerate(genes):
#     if x % 100 == 0:
#         print(x)
        
#     values = []
#     for condition in conditions:
        
#         row = yoneda_data[(yoneda_data['Measurement Type'] == gene) & (yoneda_data['Line Name']==condition)]
#         try:
#             values.append(float(row.Value[0]))
#         except:
#             values.append('no measurement')
            
            
            
# #             print(row.Value[0])
# #         print(row)
# #         print(yoneda_data[
# #                 (yoneda_data['Measurement Type'] == gene & yoneda_data['Line Name'] == condition)]['Value'])
        
# #     print()
