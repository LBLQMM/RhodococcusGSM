# %% [markdown]
# # Transcriptomic and Proteomic based flux predictions
# This notebook integrates Transcriptomic measurements into flux profiles

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import cobra

# %% [markdown]
# ### Load Transcriptomics Data

# %%
yoneda_data = pd.read_csv('../../EDD_Yoneda_data/Yoneda_set3_transcriptomics_data.csv')

# remove blank columns
yoneda_data = yoneda_data[[col for col in yoneda_data.columns if 'Unnamed' not in col]]

yoneda_data.head()
# Out:
#   Line Name Measurement Type  Time  Value   Units
# 0   WT-G-R1   PD630_LPD06575    14    708  counts
# 1   WT-G-R1   PD630_LPD06576    14   6513  counts
# 2   WT-G-R1   PD630_LPD00131    14   1015  counts
# 3   WT-G-R1   PD630_LPD06740    14    289  counts
# 4   WT-G-R1   PD630_LPD06741    14   1159  counts

# %% [markdown]
# ### Make a dictionary where keys are measured gene names and the values are lists of  measured values and  add measured values to the lists

# %%
# Make dictionary of blank lists
genes = list(set(yoneda_data['Measurement Type']))
print(f'There are {len(genes)} measured genes')
gene_dictionary = {gene:[] for gene in genes}

# Add measured values to the list
conditions = list(set(yoneda_data['Line Name']))
for condition in conditions:
    print(condition)
    condition_df = yoneda_data[yoneda_data['Line Name'] == condition]
    for gene in genes:
        try:
            gene_value = float(condition_df[condition_df['Measurement Type'] == gene]['Value'])
            gene_dictionary[gene].append(gene_value)
        except:
            gene_dictionary[gene].append('none')
# Out:
# There are 15685 measured genes
# WT-L-R1
# EVOL33-G-R1
# EVOL33-L-R1
# EVOL40-G-R1
# WT-G-R1
# EVOL40-H-R1
# EVOL33-H-R1
# EVOL40-L-R1

# %% [markdown]
# ### Remove genes that do have multiple measurements for a single run

# %%
new_gene_dictionary = {}
for gene, values in gene_dictionary.items():
    if len(values) == 8:
        new_gene_dictionary[gene] = values
    else:
        print(len(values), gene, values)

# %% [markdown]
# ### Convert the gene dictionary to a dataframe

# %%
transcriptomic_df = pd.DataFrame.from_dict(new_gene_dictionary, orient='index', columns=conditions)
transcriptomic_df.head()
# Out:
#                WT-L-R1 EVOL33-G-R1 EVOL33-L-R1 EVOL40-G-R1 WT-G-R1  \
# PD630_LPD07585      55          74          56         363      79
# PD630_LPD09981    none        none        none        none    none
# PD630_LPD04716       5           8          17          13       9
# PD630_LPD12853    none        none        none        none    none
# PD630_LPD04787     579         269         411         437     334
#
#                 EVOL40-H-R1 EVOL33-H-R1 EVOL40-L-R1
# PD630_LPD07585  5.39838e+06          92         336
# PD630_LPD09981  5.39838e+06        none        none
# PD630_LPD04716         none         284          15
# PD630_LPD12853  5.39838e+06        none        none
# PD630_LPD04787         none         513         694

# %% [markdown]
# ### Load LPD to WP mapping

# %%
gene_mapping_df = pd.read_csv('../gene_converter/LPD_RS_WP_gene_mapping.csv')
print(f'There are {len(gene_mapping_df)} mapped genes')

# remove blank columns
gene_mapping_df = gene_mapping_df[[col for col in gene_mapping_df.columns if 'Unnamed' not in col]]

gene_mapping_df.head()
# Out:
# There are 8390 mapped genes
#     Gene ID (RS)   Gene ID (LPD)    Gene ID (WP)  \
# 0  PD630_RS00005  PD630_LPD00001            none
# 1  PD630_RS00010  PD630_LPD00002  WP_005569241.1
# 2  PD630_RS00015  PD630_LPD00003  WP_007296166.1
# 3  PD630_RS00020  PD630_LPD00004  WP_005237760.1
# 4  PD630_RS00025  PD630_LPD00005  WP_005237761.1
#
#                                        Annotation
# 0  chromosomal replication initiator protein DnaA
# 1                 DNA polymerase III subunit beta
# 2                6-phosphogluconate dehydrogenase
# 3         DNA replication and repair protein RecF
# 4                            hypothetical protein

# %% [markdown]
# # Why are there only  8390 mapped genes when there are 15685 measured genes

# %% [markdown]
# ### Add WP annoation to transcriptomic data

# %%
# make dicitonary where keys are LPD IDs and values are WP IDs 
LPD_to_WP_dictionary = {row['Gene ID (LPD)']:row['Gene ID (WP)'] for _, row in gene_mapping_df.iterrows()}


not_matched = 0
WP_genes = []
for index, _ in transcriptomic_df.iterrows():
    try:
        WP_genes.append(LPD_to_WP_dictionary[index])
    except:
        WP_genes.append('Unknown')
        not_matched += 1

transcriptomic_df['WP_gene'] = WP_genes
print(f'There are {not_matched} genes that have an LPD measurement without a WP mapping')
transcriptomic_df.head()
# Out:
# There are 8002 genes that have an LPD measurement without a WP mapping
#                WT-L-R1 EVOL33-G-R1 EVOL33-L-R1 EVOL40-G-R1 WT-G-R1  \
# PD630_LPD07585      55          74          56         363      79
# PD630_LPD09981    none        none        none        none    none
# PD630_LPD04716       5           8          17          13       9
# PD630_LPD12853    none        none        none        none    none
# PD630_LPD04787     579         269         411         437     334
#
#                 EVOL40-H-R1 EVOL33-H-R1 EVOL40-L-R1         WP_gene
# PD630_LPD07585  5.39838e+06          92         336  WP_009475287.1
# PD630_LPD09981  5.39838e+06        none        none         Unknown
# PD630_LPD04716         none         284          15  WP_007298935.1
# PD630_LPD12853  5.39838e+06        none        none         Unknown
# PD630_LPD04787         none         513         694  WP_011593468.1

# %% [markdown]
# ### Check measured values for genes without known WP ids

# %%
unknown_df = transcriptomic_df[transcriptomic_df['WP_gene'] == 'Unknown']
unknown_df.head()
# Out:
#                WT-L-R1 EVOL33-G-R1 EVOL33-L-R1 EVOL40-G-R1 WT-G-R1  \
# PD630_LPD09981    none        none        none        none    none
# PD630_LPD12853    none        none        none        none    none
# PD630_LPD09197      92          32          53          52      38
# PD630_LPD12755    none        none        none        none    none
# PD630_LPD11317    none        none        none        none    none
#
#                 EVOL40-H-R1 EVOL33-H-R1 EVOL40-L-R1  WP_gene
# PD630_LPD09981  5.39838e+06        none        none  Unknown
# PD630_LPD12853  5.39838e+06        none        none  Unknown
# PD630_LPD09197  5.39838e+06         111         174  Unknown
# PD630_LPD12755  5.39838e+06        none        none  Unknown
# PD630_LPD11317  5.39838e+06        none        none  Unknown

# %% [markdown]
# ### Determine how many genes are in the genome scale model and how many of them have known mappings to LPD data

# %% [markdown]
# ### Load model

# %%
model = cobra.io.read_sbml_model("../GSMs/Ropacus_annotated_curated_with_phenol_custom_biomass.xml")
model
# Out:
# <Model ropacus_annotated_curated at 0x7f8745482510>

# %% [markdown]
# ### Get list of genes

# %%
model_genes = [g.id for g in model.genes]
print(f'The genome scale model has {len(model_genes)} genes')
# Out:
# The genome scale model has 1576 genes

# %% [markdown]
# ### Determine how many genes have known LPD numbers

# %%
WP_to_LPD_dictionary = {v.replace('.', '_'):k for k,v in LPD_to_WP_dictionary.items()}

for k,v in list(WP_to_LPD_dictionary.items())[:5]:
    print(k, v)
# Out:
# none PD630_LPD17031
# WP_005569241_1 PD630_LPD00002
# WP_007296166_1 PD630_LPD00003
# WP_005237760_1 PD630_LPD00004
# WP_005237761_1 PD630_LPD00005

# %%
model_genes[:10]
# Out:
# ['WP_187300246_1',
#  'WP_025432775_1',
#  'WP_005248578_1',
#  'WP_025433613_1',
#  'WP_005249637_1',
#  'WP_005248999_1',
#  'WP_025433301_1',
#  'WP_005246696_1',
#  'WP_005244822_1',
#  'WP_005250095_1']

# %%
# Switch keys and values of the mapping dictionary
WP_to_LPD_dictionary = {v:k for k,v in LPD_to_WP_dictionary.items()}


mapped_model_genes = 0
for g in model_genes:
    try:
        WP_to_LPD_dictionary[g]
    except:
        mapped_model_genes += 1
        
print(mapped_model_genes)
#     print(WP_to_LPD_dictionary[g])
# known_LPD 
# for g in model.genes:
# Out:
# 1576

# %%
print(len([gene for gene in list(transcriptomic_df.index) if gene not in list(LPD_to_WP_dictionary.keys())]))
# Out:
# 8002

# %%
yoneda_ids = list(transcriptomic_df.index)
mapping_ids = list(LPD_to_WP_dictionary.keys())

print(yoneda_ids[:20])
print(mapping_ids[:20])
# Out:
# ['PD630_LPD07585', 'PD630_LPD09981', 'PD630_LPD04716', 'PD630_LPD12853', 'PD630_LPD04787', 'PD630_LPD09197', 'PD630_LPD02409', 'PD630_LPD04348', 'PD630_LPD14036', 'PD630_LPD00157', 'PD630_LPD04430', 'PD630_LPD03302', 'PD630_LPD12755', 'PD630_LPD11317', 'PD630_LPD08485', 'PD630_LPD08255', 'PD630_LPD03078', 'PD630_LPD16010', 'PD630_LPD10214', 'PD630_LPD11102']
# ['PD630_LPD00001', 'PD630_LPD00002', 'PD630_LPD00003', 'PD630_LPD00004', 'PD630_LPD00005', 'PD630_LPD00006', 'PD630_LPD00007', 'PD630_LPD00008', 'PD630_LPD00009', 'PD630_LPD00011', 'PD630_LPD00012', 'PD630_LPD00013', 'PD630_LPD00014', 'PD630_LPD00015', 'PD630_LPD00016', 'PD630_LPD00017', 'PD630_LPD00018', 'PD630_LPD00019', 'PD630_LPD00020', 'PD630_LPD00021']

# %%
test = list(LPD_to_WP_dictionary.keys())
test.sort(reverse=True)
test
# Out:
# ['none',
#  'PD630_LPD17037',
#  'PD630_LPD17036',
#  'PD630_LPD17035',
#  'PD630_LPD17033',
#  'PD630_LPD17032',
#  'PD630_LPD17031',
#  'PD630_LPD17030',
#  'PD630_LPD11084',
#  'PD630_LPD11083',
#  'PD630_LPD11082',
#  'PD630_LPD11081',
#  'PD630_LPD11080',
#  'PD630_LPD11078',
#  'PD630_LPD11076',
#  'PD630_LPD11075',
#  'PD630_LPD11074',
#  'PD630_LPD11073',
#  'PD630_LPD11070',
#  'PD630_LPD11069',
#  'PD630_LPD11068',
#  'PD630_LPD11067',
#  'PD630_LPD11066',
#  'PD630_LPD11065',
#  'PD630_LPD11063',
#  'PD630_LPD11061',
#  'PD630_LPD11060',
#  'PD630_LPD11059',
#  'PD630_LPD11057',
#  'PD630_LPD11056',
#  'PD630_LPD11053',
#  'PD630_LPD11052',
#  'PD630_LPD11051',
#  'PD630_LPD11050',
#  'PD630_LPD11049',
#  'PD630_LPD11046',
#  'PD630_LPD11044',
#  'PD630_LPD11041',
#  'PD630_LPD11040',
#  'PD630_LPD11039',
#  'PD630_LPD11037',
#  'PD630_LPD11033',
#  'PD630_LPD11029',
#  'PD630_LPD11026',
#  'PD630_LPD11024',
#  'PD630_LPD11022',
#  'PD630_LPD11020',
#  'PD630_LPD11017',
#  'PD630_LPD11016',
#  'PD630_LPD11015',
#  'PD630_LPD11010',
#  'PD630_LPD11009',
#  'PD630_LPD11006',
#  'PD630_LPD11003',
#  'PD630_LPD11001',
#  'PD630_LPD10125',
#  'PD630_LPD10124',
#  'PD630_LPD10123',
#  'PD630_LPD10122',
#  'PD630_LPD10121',
#  'PD630_LPD10120',
#  'PD630_LPD10117',
#  'PD630_LPD10116',
#  'PD630_LPD10115',
#  'PD630_LPD10109',
#  'PD630_LPD10108',
#  'PD630_LPD10104',
#  'PD630_LPD10102',
#  'PD630_LPD10101',
#  'PD630_LPD10100',
#  'PD630_LPD10099',
#  'PD630_LPD10098',
#  'PD630_LPD10097',
#  'PD630_LPD10094',
#  'PD630_LPD10091',
#  'PD630_LPD10090',
#  'PD630_LPD10088',
#  'PD630_LPD10077',
#  'PD630_LPD10076',
#  'PD630_LPD10075',
#  'PD630_LPD10072',
#  'PD630_LPD10067',
#  'PD630_LPD10066',
#  'PD630_LPD10065',
#  'PD630_LPD10064',
#  'PD630_LPD10063',
#  'PD630_LPD10061',
#  'PD630_LPD10058',
#  'PD630_LPD10057',
#  'PD630_LPD10056',
#  'PD630_LPD10054',
#  'PD630_LPD10053',
#  'PD630_LPD10052',
#  'PD630_LPD10051',
#  'PD630_LPD10048',
#  'PD630_LPD10047',
#  'PD630_LPD10045',
#  'PD630_LPD10044',
#  'PD630_LPD10043',
#  'PD630_LPD10040',
#  'PD630_LPD10039',
#  'PD630_LPD10038',
#  'PD630_LPD10037',
#  'PD630_LPD10036',
#  'PD630_LPD10035',
#  'PD630_LPD10034',
#  'PD630_LPD10031',
#  'PD630_LPD10030',
#  'PD630_LPD10027',
#  'PD630_LPD10026',
#  'PD630_LPD10025',
#  'PD630_LPD10024',
#  'PD630_LPD10023',
#  'PD630_LPD10022',
#  'PD630_LPD10021',
#  'PD630_LPD09043',
#  'PD630_LPD09042',
#  'PD630_LPD09040',
#  'PD630_LPD09039',
#  'PD630_LPD09035',
#  'PD630_LPD09034',
#  'PD630_LPD09028',
#  'PD630_LPD09025',
#  'PD630_LPD09024',
#  'PD630_LPD09023',
#  'PD630_LPD09022',
#  'PD630_LPD09021',
#  'PD630_LPD09019',
#  'PD630_LPD09018',
#  'PD630_LPD09017',
#  'PD630_LPD09016',
#  'PD630_LPD09015',
#  'PD630_LPD09013',
#  'PD630_LPD09012',
#  'PD630_LPD09011',
#  'PD630_LPD09010',
#  'PD630_LPD09009',
#  'PD630_LPD09008',
#  'PD630_LPD09007',
#  'PD630_LPD09006',
#  'PD630_LPD09005',
#  'PD630_LPD09004',
#  'PD630_LPD09003',
#  'PD630_LPD09002',
#  'PD630_LPD09001',
#  'PD630_LPD08053',
#  'PD630_LPD08052',
#  'PD630_LPD08050',
#  'PD630_LPD08047',
#  'PD630_LPD08046',
#  'PD630_LPD08045',
#  'PD630_LPD08044',
#  'PD630_LPD08043',
#  'PD630_LPD08042',
#  'PD630_LPD08041',
#  'PD630_LPD08040',
#  'PD630_LPD08039',
#  'PD630_LPD08038',
#  'PD630_LPD08037',
#  'PD630_LPD08036',
#  'PD630_LPD08035',
#  'PD630_LPD08034',
#  'PD630_LPD08033',
#  'PD630_LPD08032',
#  'PD630_LPD08031',
#  'PD630_LPD08030',
#  'PD630_LPD08029',
#  'PD630_LPD08028',
#  'PD630_LPD08027',
#  'PD630_LPD08026',
#  'PD630_LPD08024',
#  'PD630_LPD08023',
#  'PD630_LPD08022',
#  'PD630_LPD08021',
#  'PD630_LPD08020',
#  'PD630_LPD08019',
#  'PD630_LPD08018',
#  'PD630_LPD08017',
#  'PD630_LPD08016',
#  'PD630_LPD08015',
#  'PD630_LPD08014',
#  'PD630_LPD08013',
#  'PD630_LPD08012',
#  'PD630_LPD08011',
#  'PD630_LPD08010',
#  'PD630_LPD08009',
#  'PD630_LPD08008',
#  'PD630_LPD08007',
#  'PD630_LPD08006',
#  'PD630_LPD08005',
#  'PD630_LPD08004',
#  'PD630_LPD08003',
#  'PD630_LPD08002',
#  'PD630_LPD08001',
#  'PD630_LPD08000',
#  'PD630_LPD07997',
#  'PD630_LPD07996',
#  'PD630_LPD07995',
#  'PD630_LPD07994',
#  'PD630_LPD07993',
#  'PD630_LPD07992',
#  'PD630_LPD07991',
#  'PD630_LPD07990',
#  'PD630_LPD07989',
#  'PD630_LPD07988',
#  'PD630_LPD07987',
#  'PD630_LPD07986',
#  'PD630_LPD07985',
#  'PD630_LPD07984',
#  'PD630_LPD07983',
#  'PD630_LPD07982',
#  'PD630_LPD07981',
#  'PD630_LPD07980',
#  'PD630_LPD07979',
#  'PD630_LPD07978',
#  'PD630_LPD07977',
#  'PD630_LPD07976',
#  'PD630_LPD07974',
#  'PD630_LPD07973',
#  'PD630_LPD07972',
#  'PD630_LPD07971',
#  'PD630_LPD07970',
#  'PD630_LPD07969',
#  'PD630_LPD07968',
#  'PD630_LPD07967',
#  'PD630_LPD07966',
#  'PD630_LPD07965',
#  'PD630_LPD07964',
#  'PD630_LPD07963',
#  'PD630_LPD07961',
#  'PD630_LPD07960',
#  'PD630_LPD07959',
#  'PD630_LPD07958',
#  'PD630_LPD07957',
#  'PD630_LPD07956',
#  'PD630_LPD07954',
#  'PD630_LPD07953',
#  'PD630_LPD07952',
#  'PD630_LPD07951',
#  'PD630_LPD07950',
#  'PD630_LPD07949',
#  'PD630_LPD07948',
#  'PD630_LPD07947',
#  'PD630_LPD07946',
#  'PD630_LPD07945',
#  'PD630_LPD07944',
#  'PD630_LPD07943',
#  'PD630_LPD07942',
#  'PD630_LPD07941',
#  'PD630_LPD07940',
#  'PD630_LPD07938',
#  'PD630_LPD07937',
#  'PD630_LPD07935',
#  'PD630_LPD07934',
#  'PD630_LPD07933',
#  'PD630_LPD07932',
#  'PD630_LPD07931',
#  'PD630_LPD07926',
#  'PD630_LPD07925',
#  'PD630_LPD07924',
#  'PD630_LPD07923',
#  'PD630_LPD07922',
#  'PD630_LPD07921',
#  'PD630_LPD07920',
#  'PD630_LPD07919',
#  'PD630_LPD07918',
#  'PD630_LPD07917',
#  'PD630_LPD07916',
#  'PD630_LPD07915',
#  'PD630_LPD07914',
#  'PD630_LPD07913',
#  'PD630_LPD07912',
#  'PD630_LPD07911',
#  'PD630_LPD07910',
#  'PD630_LPD07909',
#  'PD630_LPD07907',
#  'PD630_LPD07906',
#  'PD630_LPD07905',
#  'PD630_LPD07904',
#  'PD630_LPD07903',
#  'PD630_LPD07902',
#  'PD630_LPD07901',
#  'PD630_LPD07900',
#  'PD630_LPD07899',
#  'PD630_LPD07898',
#  'PD630_LPD07897',
#  'PD630_LPD07896',
#  'PD630_LPD07895',
#  'PD630_LPD07894',
#  'PD630_LPD07893',
#  'PD630_LPD07892',
#  'PD630_LPD07886',
#  'PD630_LPD07885',
#  'PD630_LPD07882',
#  'PD630_LPD07881',
#  'PD630_LPD07880',
#  'PD630_LPD07879',
#  'PD630_LPD07877',
#  'PD630_LPD07876',
#  'PD630_LPD07875',
#  'PD630_LPD07874',
#  'PD630_LPD07873',
#  'PD630_LPD07872',
#  'PD630_LPD07871',
#  'PD630_LPD07870',
#  'PD630_LPD07869',
#  'PD630_LPD07868',
#  'PD630_LPD07867',
#  'PD630_LPD07866',
#  'PD630_LPD07865',
#  'PD630_LPD07864',
#  'PD630_LPD07863',
#  'PD630_LPD07862',
#  'PD630_LPD07861',
#  'PD630_LPD07860',
#  'PD630_LPD07859',
#  'PD630_LPD07858',
#  'PD630_LPD07857',
#  'PD630_LPD07856',
#  'PD630_LPD07855',
#  'PD630_LPD07854',
#  'PD630_LPD07853',
#  'PD630_LPD07852',
#  'PD630_LPD07851',
#  'PD630_LPD07850',
#  'PD630_LPD07849',
#  'PD630_LPD07848',
#  'PD630_LPD07847',
#  'PD630_LPD07846',
#  'PD630_LPD07845',
#  'PD630_LPD07844',
#  'PD630_LPD07842',
#  'PD630_LPD07841',
#  'PD630_LPD07839',
#  'PD630_LPD07838',
#  'PD630_LPD07837',
#  'PD630_LPD07836',
#  'PD630_LPD07835',
#  'PD630_LPD07834',
#  'PD630_LPD07833',
#  'PD630_LPD07828',
#  'PD630_LPD07827',
#  'PD630_LPD07826',
#  'PD630_LPD07825',
#  'PD630_LPD07824',
#  'PD630_LPD07823',
#  'PD630_LPD07821',
#  'PD630_LPD07820',
#  'PD630_LPD07819',
#  'PD630_LPD07818',
#  'PD630_LPD07817',
#  'PD630_LPD07816',
#  'PD630_LPD07815',
#  'PD630_LPD07814',
#  'PD630_LPD07813',
#  'PD630_LPD07812',
#  'PD630_LPD07811',
#  'PD630_LPD07810',
#  'PD630_LPD07809',
#  'PD630_LPD07808',
#  'PD630_LPD07807',
#  'PD630_LPD07806',
#  'PD630_LPD07805',
#  'PD630_LPD07804',
#  'PD630_LPD07803',
#  'PD630_LPD07802',
#  'PD630_LPD07801',
#  'PD630_LPD07799',
#  'PD630_LPD07798',
#  'PD630_LPD07797',
#  'PD630_LPD07796',
#  'PD630_LPD07795',
#  'PD630_LPD07793',
#  'PD630_LPD07792',
#  'PD630_LPD07791',
#  'PD630_LPD07788',
#  'PD630_LPD07787',
#  'PD630_LPD07786',
#  'PD630_LPD07785',
#  'PD630_LPD07784',
#  'PD630_LPD07783',
#  'PD630_LPD07782',
#  'PD630_LPD07781',
#  'PD630_LPD07780',
#  'PD630_LPD07779',
#  'PD630_LPD07778',
#  'PD630_LPD07777',
#  'PD630_LPD07776',
#  'PD630_LPD07775',
#  'PD630_LPD07774',
#  'PD630_LPD07773',
#  'PD630_LPD07772',
#  'PD630_LPD07771',
#  'PD630_LPD07770',
#  'PD630_LPD07769',
#  'PD630_LPD07768',
#  'PD630_LPD07767',
#  'PD630_LPD07765',
#  'PD630_LPD07764',
#  'PD630_LPD07763',
#  'PD630_LPD07762',
#  'PD630_LPD07760',
#  'PD630_LPD07759',
#  'PD630_LPD07758',
#  'PD630_LPD07756',
#  'PD630_LPD07755',
#  'PD630_LPD07752',
#  'PD630_LPD07751',
#  'PD630_LPD07750',
#  'PD630_LPD07749',
#  'PD630_LPD07748',
#  'PD630_LPD07747',
#  'PD630_LPD07746',
#  'PD630_LPD07745',
#  'PD630_LPD07744',
#  'PD630_LPD07743',
#  'PD630_LPD07742',
#  'PD630_LPD07741',
#  'PD630_LPD07740',
#  'PD630_LPD07739',
#  'PD630_LPD07738',
#  'PD630_LPD07737',
#  'PD630_LPD07736',
#  'PD630_LPD07735',
#  'PD630_LPD07734',
#  'PD630_LPD07733',
#  'PD630_LPD07732',
#  'PD630_LPD07731',
#  'PD630_LPD07730',
#  'PD630_LPD07729',
#  'PD630_LPD07728',
#  'PD630_LPD07726',
#  'PD630_LPD07725',
#  'PD630_LPD07724',
#  'PD630_LPD07723',
#  'PD630_LPD07722',
#  'PD630_LPD07721',
#  'PD630_LPD07716',
#  'PD630_LPD07715',
#  'PD630_LPD07714',
#  'PD630_LPD07713',
#  'PD630_LPD07712',
#  'PD630_LPD07711',
#  'PD630_LPD07710',
#  'PD630_LPD07708',
#  'PD630_LPD07707',
#  'PD630_LPD07706',
#  'PD630_LPD07705',
#  'PD630_LPD07704',
#  'PD630_LPD07703',
#  'PD630_LPD07702',
#  'PD630_LPD07701',
#  'PD630_LPD07699',
#  'PD630_LPD07698',
#  'PD630_LPD07697',
#  'PD630_LPD07696',
#  'PD630_LPD07695',
#  'PD630_LPD07694',
#  'PD630_LPD07693',
#  'PD630_LPD07692',
#  'PD630_LPD07691',
#  'PD630_LPD07690',
#  'PD630_LPD07689',
#  'PD630_LPD07688',
#  'PD630_LPD07687',
#  'PD630_LPD07685',
#  'PD630_LPD07682',
#  'PD630_LPD07681',
#  'PD630_LPD07680',
#  'PD630_LPD07679',
#  'PD630_LPD07678',
#  'PD630_LPD07676',
#  'PD630_LPD07675',
#  'PD630_LPD07674',
#  'PD630_LPD07673',
#  'PD630_LPD07672',
#  'PD630_LPD07671',
#  'PD630_LPD07670',
#  'PD630_LPD07669',
#  'PD630_LPD07668',
#  'PD630_LPD07666',
#  'PD630_LPD07665',
#  'PD630_LPD07664',
#  'PD630_LPD07663',
#  'PD630_LPD07662',
#  'PD630_LPD07661',
#  'PD630_LPD07660',
#  'PD630_LPD07658',
#  'PD630_LPD07657',
#  'PD630_LPD07656',
#  'PD630_LPD07655',
#  'PD630_LPD07654',
#  'PD630_LPD07653',
#  'PD630_LPD07652',
#  'PD630_LPD07651',
#  'PD630_LPD07650',
#  'PD630_LPD07649',
#  'PD630_LPD07648',
#  'PD630_LPD07647',
#  'PD630_LPD07646',
#  'PD630_LPD07645',
#  'PD630_LPD07643',
#  'PD630_LPD07642',
#  'PD630_LPD07641',
#  'PD630_LPD07640',
#  'PD630_LPD07639',
#  'PD630_LPD07637',
#  'PD630_LPD07636',
#  'PD630_LPD07635',
#  'PD630_LPD07634',
#  'PD630_LPD07633',
#  'PD630_LPD07632',
#  'PD630_LPD07631',
#  'PD630_LPD07629',
#  'PD630_LPD07628',
#  'PD630_LPD07627',
#  'PD630_LPD07626',
#  'PD630_LPD07625',
#  'PD630_LPD07624',
#  'PD630_LPD07623',
#  'PD630_LPD07622',
#  'PD630_LPD07621',
#  'PD630_LPD07620',
#  'PD630_LPD07619',
#  'PD630_LPD07618',
#  'PD630_LPD07616',
#  'PD630_LPD07615',
#  'PD630_LPD07614',
#  'PD630_LPD07613',
#  'PD630_LPD07612',
#  'PD630_LPD07611',
#  'PD630_LPD07609',
#  'PD630_LPD07608',
#  'PD630_LPD07607',
#  'PD630_LPD07606',
#  'PD630_LPD07605',
#  'PD630_LPD07604',
#  'PD630_LPD07603',
#  'PD630_LPD07602',
#  'PD630_LPD07600',
#  'PD630_LPD07599',
#  'PD630_LPD07598',
#  'PD630_LPD07597',
#  'PD630_LPD07596',
#  'PD630_LPD07595',
#  'PD630_LPD07594',
#  'PD630_LPD07593',
#  'PD630_LPD07592',
#  'PD630_LPD07591',
#  'PD630_LPD07590',
#  'PD630_LPD07589',
#  'PD630_LPD07588',
#  'PD630_LPD07587',
#  'PD630_LPD07586',
#  'PD630_LPD07585',
#  'PD630_LPD07584',
#  'PD630_LPD07583',
#  'PD630_LPD07582',
#  'PD630_LPD07581',
#  'PD630_LPD07580',
#  'PD630_LPD07579',
#  'PD630_LPD07578',
#  'PD630_LPD07577',
#  'PD630_LPD07575',
#  'PD630_LPD07574',
#  'PD630_LPD07573',
#  'PD630_LPD07572',
#  'PD630_LPD07571',
#  'PD630_LPD07570',
#  'PD630_LPD07569',
#  'PD630_LPD07567',
#  'PD630_LPD07566',
#  'PD630_LPD07565',
#  'PD630_LPD07564',
#  'PD630_LPD07563',
#  'PD630_LPD07562',
#  ...]

# %%
transcriptomic_df
# Out:
#                WT-L-R1 EVOL33-G-R1 EVOL33-L-R1 EVOL40-G-R1 WT-G-R1  \
# PD630_LPD07585      55          74          56         363      79
# PD630_LPD09981    none        none        none        none    none
# PD630_LPD04716       5           8          17          13       9
# PD630_LPD12853    none        none        none        none    none
# PD630_LPD04787     579         269         411         437     334
# ...                ...         ...         ...         ...     ...
# PD630_LPD09404    none        none        none        none    none
# PD630_LPD14064    none        none        none        none    none
# PD630_LPD08219    none        none        none        none    none
# PD630_LPD03448    1778         471         868         937     566
# PD630_LPD03736     996         371         743         618     454
#
#                 EVOL40-H-R1 EVOL33-H-R1 EVOL40-L-R1         WP_gene
# PD630_LPD07585  5.39838e+06          92         336  WP_009475287.1
# PD630_LPD09981  5.39838e+06        none        none         Unknown
# PD630_LPD04716         none         284          15  WP_007298935.1
# PD630_LPD12853  5.39838e+06        none        none         Unknown
# PD630_LPD04787         none         513         694  WP_011593468.1
# ...                     ...         ...         ...             ...
# PD630_LPD09404  5.39838e+06        none        none         Unknown
# PD630_LPD14064  5.39838e+06        none        none         Unknown
# PD630_LPD08219  5.39838e+06        none        none         Unknown
# PD630_LPD03448         none        1328        1705  WP_003936557.1
# PD630_LPD03736         none        1215        1731  WP_012691708.1
#
# [15685 rows x 9 columns]

# %% [markdown]
# ### This is a rewrite of the above code that is more succinct, but takes a lot longer to run

# %%
# gene_dictionary_2 = {}

# for x, gene in enumerate(genes):
#     if x % 100 == 0:
#         print(x)
        
#     values = []
#     for condition in conditions:
        
#         row = yoneda_data[(yoneda_data['Measurement Type'] == gene) & (yoneda_data['Line Name']==condition)]
#         try:
#             values.append(float(row.Value[0]))
#         except:
#             values.append('no measurement')
            
            
            
# #             print(row.Value[0])
# #         print(row)
# #         print(yoneda_data[
# #                 (yoneda_data['Measurement Type'] == gene & yoneda_data['Line Name'] == condition)]['Value'])
        
# #     print()
