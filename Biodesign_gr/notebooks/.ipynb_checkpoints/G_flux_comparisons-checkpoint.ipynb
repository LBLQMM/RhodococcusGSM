# %% [markdown]
# ## Flux comparions
# The goal of this notebook is to compare the predictions of the R. opacus PD630 GSM with the fluxes from 13C-Metabolic Flux Analysis (13C-MFA)

# %% [markdown]
# ### Setup imports

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import cobra
import pandas as pd
import numpy as np
from edd_utils import login, export_study, export_metadata

# %% [markdown]
# ### Import most recent GSM

# %%
edd_study_slug = 'input-test-study'
edd_server = 'public-edd.agilebiofoundry.org'
user= 'garrettroell'
session = login(edd_server=edd_server, user=user)
# df = utils.load_study(edd_study_slug=edd_study_slug,edd_server=edd_server,
#   default_to_system_user=False)
# Out:
# Password for garrettroell:  ················

# %%
df = export_study(session, edd_study_slug, edd_server=edd_server)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
df
# Out:
# Empty DataFrame
# Columns: [Study ID, Study Name, Line ID, Line Name, Line Description, Protocol, Assay ID, Assay Name, Formal Type, Measurement Type, Compartment, Units, Value, Hours]
# Index: []

# %%
model_path = "../GSMs/Ropacus_annotated_curated.xml"
model = cobra.io.read_sbml_model(model_path)
model
# Out:
# <Model ropacus_curated_with_5_deleted_reactions at 0x7f4ec5f5b290>

# %% [markdown]
# ### Run glucose flux FBA

# %%
model.objective = "Growth"
with model:
    medium = model.medium
    medium["EX_glc__D_e"] = 10.0
    model.medium = medium
    solution = model.optimize()
    print(solution)
# Out:
# <Solution 0.792 at 0x7f4ec407fad0>

# %% [markdown]
# ### Get 13C MFA measured fluxes

# %%
glucose_flux_path = "../13C_glucose_flux_data.csv"
measured_glucose_df = pd.read_csv(glucose_flux_path)
measured_glucose_df
# Out:
#             Pathway Reaction ID Reversed?                           Reaction  \
# 0    Glucose Uptake         NaN       NaN              Gluc.ext + ATP -> G6P
# 1        Glycolysis         PGI     False                        G6P <-> F6P
# 2               NaN         NaN       NaN                   F6P + ATP -> FBP
# 3               NaN         FBA     False                 FBP <-> DHAP + GAP
# 4               NaN         TPI     False                       DHAP <-> GAP
# ..              ...         ...       ...                                ...
# 97              NaN         NaN       NaN                 AcCoA <-> Ac + ATP
# 98              NaN         NaN       NaN               Ser <-> Gly + MEETHF
# 99              NaN         NaN       NaN  Gly <-> CO2 + MEETHF + NADH + NH3
# 100             NaN         NaN       NaN         Thr <-> Gly + AcCoA + NADH
# 101             NaN         NaN       NaN                     NADH <-> NADPH
#
#              Flux  90% Confidence Lower Bound  90% Confidence Upper Bound  \
# 0    1.000000e+02                      100.00                1.000000e+02
# 1   -1.610000e+00                       -2.09                1.420000e+00
# 2    0.000000e+00                        0.00                1.910000e+00
# 3    0.000000e+00                        0.00                1.910000e+00
# 4    0.000000e+00                        0.00                1.910000e+00
# ..            ...                         ...                         ...
# 97   6.350000e-02                        0.00                         inf
# 98   2.830500e+00                        0.00                2.250000e+06
# 99   1.000000e-07                        0.00                7.363000e-01
# 100  1.000000e-07                        0.00                4.679000e-01
# 101  1.000000e-07                        0.00                3.390000e+06
#
#      Unnamed: 7  Unnamed: 8
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# ..          ...         ...
# 97          NaN         NaN
# 98          NaN         NaN
# 99          NaN         NaN
# 100         NaN         NaN
# 101         NaN         NaN
#
# [102 rows x 9 columns]

# %% [markdown]
# Eliminate all rows that do not have a defined reactionID

# %%
measured_glucose_df = measured_glucose_df[~pd.isnull(measured_glucose_df['Reaction ID'])]
measured_glucose_df
# Out:
#              Pathway Reaction ID Reversed?                     Reaction  \
# 1         Glycolysis         PGI     False                  G6P <-> F6P
# 3                NaN         FBA     False           FBP <-> DHAP + GAP
# 4                NaN         TPI     False                 DHAP <-> GAP
# 17        ED Pathway         EDA     False                 6PG <-> KDPG
# 18               NaN         EDD     False           KDPG <-> Pyr + GAP
# 19         TCA Cycle         PDH     False   Pyr <-> AcCoA + CO2 + NADH
# 20               NaN          CS     False          OAC + AcCoA <-> Cit
# 21               NaN       ACONT     False                 Cit <-> ICit
# 23               NaN       AKGDH     False  AKG <-> SucCoA + CO2 + NADH
# 24               NaN      SUCOAS      True         SucCoA <-> Suc + ATP
# 26               NaN         FUM     False                  Fum <-> Mal
# 28  Glyoxylate Shunt         ICL     False          ICit -> Glyox + Suc
# 29               NaN        MALS     False         Glyox + AcCoA -> Mal
#
#       Flux  90% Confidence Lower Bound  90% Confidence Upper Bound  \
# 1    -1.61                       -2.09                        1.42
# 3     0.00                        0.00                        1.91
# 4     0.00                        0.00                        1.91
# 17   93.38                       89.08                       94.98
# 18   93.38                       89.08                       94.98
# 19  135.41                      116.26                      196.60
# 20   69.04                       58.52                       82.65
# 21   69.04                       58.52                       82.65
# 23   61.60                        2.27                       75.99
# 24   59.88                        0.87                       74.45
# 26   63.27                       22.17                       77.49
# 28    0.00                        0.00                       60.46
# 29    0.00                        0.00                       60.46
#
#     Unnamed: 7  Unnamed: 8
# 1          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# 17         NaN         NaN
# 18         NaN         NaN
# 19         NaN         NaN
# 20         NaN         NaN
# 21         NaN         NaN
# 23         NaN         NaN
# 24         NaN         NaN
# 26         NaN         NaN
# 28         NaN         NaN
# 29         NaN         NaN

# %%
measured_flux_dict = {}
measured_reaction_ids = list(measured_glucose_df['Reaction ID'])
for reaction_id in measured_reaction_ids:
#     print(measured_glucose_df[measured_glucose_df['Reaction ID'] == reaction_id]['Reversed?'].values[0])
    measured_flux = measured_glucose_df[measured_glucose_df['Reaction ID'] == reaction_id]['Flux'].values[0] / 10
#     if measured_glucose_df[measured_glucose_df['Reaction ID'] == reaction_id]['Reversed?'].values[0]:
#         measured_flux = -1 * measured_flux
    measured_flux_dict[reaction_id] = measured_flux
measured_flux_dict
# Out:
# {'PGI': -0.161,
#  'FBA': 0.0,
#  'TPI': 0.0,
#  'EDA': 9.338,
#  'EDD': 9.338,
#  'PDH': 13.541,
#  'CS': 6.904000000000001,
#  'ACONT': 6.904000000000001,
#  'AKGDH': 6.16,
#  'SUCOAS': 5.988,
#  'FUM': 6.327,
#  'ICL': 0.0,
#  'MALS': 0.0}

# %% [markdown]
# ### Get FBA simulated fluxes

# %%
simulated_flux_dict = {}
measured_reaction_ids = list(measured_glucose_df['Reaction ID'])
for reaction_id in measured_reaction_ids:
    simulated_flux_dict[reaction_id] = solution.fluxes[reaction_id]

simulated_flux_dict
# Out:
# {'PGI': 9.84244787353533,
#  'FBA': 3.4584590069982055,
#  'TPI': 8.664556409477848,
#  'EDA': 0.0,
#  'EDD': 0.0,
#  'PDH': 10.31572719800959,
#  'CS': 0.8099224524147426,
#  'ACONT': 0.0,
#  'AKGDH': 0.0,
#  'SUCOAS': 0.3897839608735944,
#  'FUM': 0.5445055288905867,
#  'ICL': 0.0,
#  'MALS': 0.0006855438868607469}

# %% [markdown]
# ### Plot FBA vs measured fluxes

# %%
measured_flux_list = list(measured_flux_dict.values())
simulated_flux_list = list(simulated_flux_dict.values())
labels = list(measured_flux_dict.keys())

fig, ax = plt.subplots(figsize=(8, 8))
ax.scatter(measured_flux_list, simulated_flux_list)
# ax.plot(ax.get_xlim(), ax.get_ylim(), ls="--", c=".3")
x = np.linspace(*ax.get_xlim())
ax.plot(x, x, ls="--", c=".3")
for i in range(len(labels)):
    xy = (measured_flux_list[i]+.1,simulated_flux_list[i]+.1)
    ax.annotate(labels[i],xy)
plt.title(r'R. opacus 13C MFA vs FBA Fluxes', fontSize=20)
plt.xlabel(r'13C MFA flux measurement (mmol/gDW/h)')
plt.ylabel(r'FBA flux prediction (mmol/gDW/h)')
plt.show()

# %% [markdown]
# ### Simulate with pfba

# %%
pfba_solution = cobra.flux_analysis.pfba(model)
len(pfba_solution.fluxes)
# Out:
# 2380

# %%
pfba_flux_dict = {}
measured_reaction_ids = list(measured_glucose_df['Reaction ID'])
for reaction_id in measured_reaction_ids:
    pfba_flux_dict[reaction_id] = pfba_solution.fluxes[reaction_id]

pfba_flux_dict
# Out:
# {'PGI': 9.84244787353533,
#  'FBA': 3.458459006998263,
#  'TPI': 8.664556409477836,
#  'EDA': 0.0,
#  'EDD': 0.0,
#  'PDH': 10.08134273911265,
#  'CS': 0.8099224524147427,
#  'ACONT': 0.8099224524147427,
#  'AKGDH': 0.0,
#  'SUCOAS': 0.38978396087359546,
#  'FUM': 0.5445055288899306,
#  'ICL': 0.0,
#  'MALS': 0.0006855438868608678}

# %%
measured_flux_list = list(measured_flux_dict.values())
simulated_flux_list = list(pfba_flux_dict.values())
labels = list(measured_flux_dict.keys())

fig, ax = plt.subplots(figsize=(8, 8))
ax.scatter(measured_flux_list, simulated_flux_list)
x = np.linspace(*ax.get_xlim())
ax.plot(x, x, ls="--", c=".3")
for i in range(len(labels)):
    xy = (measured_flux_list[i]+.1,simulated_flux_list[i]+.1)
    ax.annotate(labels[i],xy)
plt.title(r'R. opacus 13C MFA vs FBA Fluxes', fontSize=20)
plt.xlabel(r'13C MFA flux measurement (mmol/gDW/h)')
plt.ylabel(r'pFBA flux prediction (mmol/gDW/h)')
plt.show()

# %% [markdown]
# ### Simulate with geometric FBA

# %%
# geometric_fba_sol = cobra.flux_analysis.geometric_fba(model)
# len(geometric_fba_sol.fluxes)

# %%
for r in model.metabolites.get_by_id('mal__L_c').reactions:
    print(r.name, r)
# Out:
# Malic enzyme (NAD) ME1: mal__L_c + nad_c --> co2_c + nadh_c + pyr_c
# Alpha ketoglutaratemalate transporter AKGMAL: akg_c + mal__L_e <=> akg_e + mal__L_c
# Fumarase FUM: fum_c + h2o_c <=> mal__L_c
# Malate transport via proton symport (2 H) MALt2_2: 2.0 h_e + mal__L_e --> 2.0 h_c + mal__L_c
# L malate reversible transport via proton symport MALt2r: h_e + mal__L_e <=> h_c + mal__L_c
# Malate dehydrogenase (ubiquinone 8 as acceptor) MDH2: mal__L_c + q8_c --> oaa_c + q8h2_c
# (S)-Malate:(acceptor) oxidoreductase DMALRED: fad_c + mal__L_c --> fadh2_c + oaa_c
# Malate transport via diffusion (periplasm to cytosol) MALtpp: h_p + mal__L_p <=> h_c + mal__L_c
# Malate dehydrogenase MDH: mal__L_c + nad_c <=> h_c + nadh_c + oaa_c
# Malate dehydrogenase (menaquinone 8 as acceptor) MDH3: mal__L_c + mqn8_c --> mql8_c + oaa_c
# Malic enzyme (NADP) ME2: mal__L_c + nadp_c --> co2_c + nadph_c + pyr_c
# Malate transport via proton symport (2 H) (periplasm) MALt2_2pp: 2.0 h_p + mal__L_p --> 2.0 h_c + mal__L_c
# Malate synthase MALS: accoa_c + glx_c + h2o_c --> coa_c + h_c + mal__L_c

# %%
model.get_by_id('')
