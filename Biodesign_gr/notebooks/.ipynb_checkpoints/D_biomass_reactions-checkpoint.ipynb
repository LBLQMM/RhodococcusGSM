# %% [markdown]
# # Biomass composition ➟  biomass reaction
# The purpose of this notebook is to convert biomass composition measurements into biomass equations for various R. opacus strains growing on various substrates

# %%
import cobra
import pandas as pd

# %% [markdown]
# ### Get biomass composition data (.csv import is a temporary. In the future this data will be from EDD)

# %%
biomass_comp_filename = '../../EDD_Ropacus_Multiomics/EDD_Ropacus_Multiomics_BiomassComp.csv'
biomass_comp_df = pd.read_csv(biomass_comp_filename)
cols_to_drop = [col for col in biomass_comp_df.columns if 'Unnamed' in col]
biomass_comp_df.drop(cols_to_drop, inplace=True, axis=1)
# biomass_comp_df.head()
biomass_comp_df
# Out:
#        Line Name      Measurement Type  Time (hrs)  Value Units
# 0    RoWT_PHE-R2         Lipid Content        25.5  14.08     %
# 1    RoWT_PHE-R2  Carbohydrate Content        25.5  17.21     %
# 2    RoWT_PHE-R2       Protein Content        25.5  38.84     %
# 3      RoP1_L-R1         Lipid Content        25.5  16.44     %
# 4      RoP1_L-R1  Carbohydrate Content        25.5  12.47     %
# 5      RoP1_L-R1       Protein Content        25.5  39.43     %
# 6      RoP1_H-R3         Lipid Content        46.5  14.94     %
# 7      RoP1_H-R3  Carbohydrate Content        46.5  13.68     %
# 8      RoP1_H-R3       Protein Content        46.5  45.23     %
# 9     RoWT_PV-R2         Lipid Content        27.0  15.28     %
# 10    RoWT_PV-R2  Carbohydrate Content        27.0   9.37     %
# 11    RoWT_PV-R2       Protein Content        27.0  43.11     %
# 12    RoPV1_L-R2         Lipid Content        27.0  20.27     %
# 13    RoPV1_L-R2  Carbohydrate Content        27.0  10.11     %
# 14    RoPV1_L-R2       Protein Content        27.0  38.90     %
# 15    RoPV1_H-R2         Lipid Content        55.5  16.67     %
# 16    RoPV1_H-R2  Carbohydrate Content        55.5   8.74     %
# 17    RoPV1_H-R2       Protein Content        55.5  46.24     %
# 18   RoWT_PVH-R2         Lipid Content        18.0  14.86     %
# 19   RoWT_PVH-R2  Carbohydrate Content        18.0  14.02     %
# 20   RoWT_PVH-R2       Protein Content        18.0  36.06     %
# 21   RoPVH5_L-R2         Lipid Content        18.0  20.25     %
# 22   RoPVH5_L-R2  Carbohydrate Content        18.0  19.08     %
# 23   RoPVH5_L-R2       Protein Content        18.0  38.37     %
# 24   RoPVH5_H-R1         Lipid Content        28.5  15.07     %
# 25   RoPVH5_H-R1  Carbohydrate Content        28.5  16.61     %
# 26   RoPVH5_H-R1       Protein Content        28.5  46.70     %
# 27  RoWT_PVHG-R1         Lipid Content        15.0   9.09     %
# 28  RoWT_PVHG-R1  Carbohydrate Content        15.0  14.83     %
# 29  RoWT_PVHG-R1       Protein Content        15.0  39.08     %
# 30  RoPVHG6_L-R2         Lipid Content        15.0  18.87     %
# 31  RoPVHG6_L-R2  Carbohydrate Content        15.0  17.03     %
# 32  RoPVHG6_L-R2       Protein Content        15.0  39.68     %
# 33  RoPVHG6_H-R1         Lipid Content        44.5  10.81     %
# 34  RoPVHG6_H-R1  Carbohydrate Content        44.5  12.97     %
# 35  RoPVHG6_H-R1       Protein Content        44.5  42.22     %
# 36   RoWT_BEN-R2         Lipid Content        23.5   6.94     %
# 37   RoWT_BEN-R2  Carbohydrate Content        23.5  12.63     %
# 38   RoWT_BEN-R2       Protein Content        23.5  42.51     %
# 39     RoB2_L-R1         Lipid Content        23.5  13.33     %
# 40     RoB2_L-R1  Carbohydrate Content        23.5  16.63     %
# 41     RoB2_L-R1       Protein Content        23.5  43.29     %
# 42     RoB2_H-R1         Lipid Content        70.0   8.33     %
# 43     RoB2_H-R1  Carbohydrate Content        70.0  18.57     %
# 44     RoB2_H-R1       Protein Content        70.0  46.92     %
# 45   RoWT_GLC-R2         Lipid Content        35.0  40.26     %
# 46   RoWT_GLC-R2  Carbohydrate Content        35.0  14.64     %
# 47   RoWT_GLC-R2       Protein Content        35.0  24.04     %
# 48   RoGlc1_L-R3         Lipid Content        35.0  35.82     %
# 49   RoGlc1_L-R3  Carbohydrate Content        35.0  14.06     %
# 50   RoGlc1_L-R3       Protein Content        35.0  24.57     %
# 51   RoGlc1_H-R2         Lipid Content        38.5  49.15     %
# 52   RoGlc1_H-R2  Carbohydrate Content        38.5  16.56     %
# 53   RoGlc1_H-R2       Protein Content        38.5  25.63     %

# %% [markdown]
# ### Define a function to take in a condition name and return a dictionary of macromolecule compositions
# The 10 times multiplier makes the units mg macromolecule/g dry cell weight

# %%
def composition_name_to_dictionary(name, biomass_df):
    biomass_comp_df = biomass_df[biomass_df['Line Name'] == name]
    biomass_dictionary = {}
    for _, row in biomass_comp_df.iterrows():
        biomass_dictionary[row['Measurement Type']] = row['Value']
    return biomass_dictionary

# %%
print('WT with phenol:', composition_name_to_dictionary('RoWT_PHE-R2', biomass_comp_df))
print('WT with glucose:',composition_name_to_dictionary('RoWT_GLC-R2', biomass_comp_df))
# Out:
# WT with phenol: {'Lipid Content': 14.08, 'Carbohydrate Content': 17.21, 'Protein Content': 38.84}
# WT with glucose: {'Lipid Content': 40.26, 'Carbohydrate Content': 14.64, 'Protein Content': 24.04}

# %% [markdown]
# ### Pull up original biomass equation

# %%
model = cobra.io.read_sbml_model("../GSMs/Ropacus_annotated_curated_with_phenol.xml")

# %% [markdown]
# Split into biomass reactions into substrates and products

# %%
original_biomass_reaction = model.reactions.get_by_id('Growth')
substrate_str = original_biomass_reaction.reaction.split('-->')[0]
product_str = original_biomass_reaction.reaction.split('-->')[1]

# %% [markdown]
# Print the biomass equation's metabolites and reaction coefficients

# %%
substrate_list = substrate_str.split('+')
product_list = product_str.split('+')

substrate_dict = {item.strip().split(' ')[1] : item.strip().split(' ')[0] for item in substrate_list}
product_dict = {item.strip().split(' ')[1] : item.strip().split(' ')[0] for item in product_list}

print('substrates')
placeholder = [print(f'{float(substrate_dict[met]):.6f}', model.metabolites.get_by_id(met).name) for met in substrate_dict]
print()
print('products')
placeholder = [print(f'{float(product_dict[met]):.6f}', model.metabolites.get_by_id(met).name) for met in product_dict]
# Out:
# substrates
# 0.000216 10-Formyltetrahydrofolate
# 0.498716 L-Alanine
# 0.000216 S-Adenosyl-L-methionine
# 0.287170 L-Arginine
# 0.234029 L-Asparagine
# 0.234029 L-Aspartate
# 52.547151 ATP
# 0.005053 Calcium
# 0.005053 Chloride
# 0.000559 Coenzyme A
# 0.000097 Co2+
# 0.129616 CTP
# 0.000688 Cu2+
# 0.088911 L-Cysteine
# 0.025403 DATP
# 0.026229 DCTP
# 0.026229 DGTP
# 0.025403 DTTP
# 0.000216 Flavin adenine dinucleotide oxidized
# 0.006519 Fe2+
# 0.007580 Fe3+
# 0.255489 L-Glutamine
# 0.255489 L-Glutamate
# 0.594780 Glycine
# 0.000971 Glycerol teichoic acid  n45   unlinked  unsubstituted C151H297N2O238P46
# 0.000971 Glycerol teichoic acid  n45   unlinked  D ala substituted C286H612N47O328P46
# 0.000971 Glycerol teichoic acid  n45   unlinked  glucose substituted C421H749N2O464P46
# 0.208826 GTP
# 47.184845 H2O
# 0.091976 L-Histidine
# 0.282060 L-Isoleucine
# 0.189503 Potassium
# 0.437399 L-Leucine
# 0.000049 Lipoteichoic acid  n24   linked  glucose substituted C26236H47072O25500P2400
# 0.000049 Lipoteichoic acid  n24   linked  N acetyl D glucosamine C31036H54272N2400O25500P2400
# 0.000049 Lipoteichoic acid  n24   linked  D alanine substituted C19036H39872N2400O18300P2400
# 0.000049 Lipoteichoic acid  n24   linked  unsubstituted C11836H23072O13500P2400
# 0.333158 L-Lysine
# 0.149206 L-Methionine
# 0.008422 Magnesium
# 0.000216 5,10-Methylenetetrahydrofolate
# 0.000671 Mn2+
# 0.000097 Menaquinol 8
# 0.001778 Nicotinamide adenine dinucleotide
# 0.000434 Nicotinamide adenine dinucleotide phosphate
# 0.009709 Peptidoglycan subunit of Bacillus subtilis C40H62N8O21
# 0.179865 L-Phenylalanine
# 0.214611 L-Proline
# 0.000216 Pyridoxal 5'-phosphate
# 0.000216 Riboflavin
# 0.209502 L-Serine
# 0.004212 Sulfate
# 0.000216 5,6,7,8-Tetrahydrofolate
# 0.000216 Thiamine diphosphate
# 0.246292 L-Threonine
# 0.055186 L-Tryptophan
# 0.133876 L-Tyrosine
# 0.139904 UTP
# 0.410827 L-Valine
# 0.000331 Zinc
#
# products
# 52.377416 ADP
# 52.377416 H+
# 52.373204 Phosphate
# 0.751345 Diphosphate

# %%
for met in substrate_dict:
    if substrate_type_dict[met] == 'protein':
        print(float(substrate_dict[met]), substrate_masses[met], float(substrate_dict[met]) * substrate_masses[met])
#         mass += float(substrate_dict[met]) * substrate_masses[met]
# print(biomass_type, mass)

# %%
amino_acid_df = pd.read_csv('../biomass_equation_data/r_opacus_amino_acid_data.csv')
substrate_df = pd.read_csv('../biomass_equation_data/subtitlis_biomass_equation_data.csv')
substrate_df
# Out:
#     coefficient                                               name  \
# 0      0.000216                          10-Formyltetrahydrofolate
# 1      0.498716                                          L-Alanine
# 2      0.000216                            S-Adenosyl-L-methionine
# 3      0.287170                                         L-Arginine
# 4      0.234029                                       L-Asparagine
# 5      0.234029                                        L-Aspartate
# 6     52.547151                                                ATP
# 7      0.005053                                            Calcium
# 8      0.005053                                           Chloride
# 9      0.000559                                          CoenzymeA
# 10     0.000097                                               Co2+
# 11     0.129616                                                CTP
# 12     0.000688                                               Cu2+
# 13     0.088911                                         L-Cysteine
# 14     0.025403                                               DATP
# 15     0.026229                                               DCTP
# 16     0.026229                                               DGTP
# 17     0.025403                                               DTTP
# 18     0.000216                  Flavinadeninedinucleotideoxidized
# 19     0.006519                                               Fe2+
# 20     0.007580                                               Fe3+
# 21     0.255489                                        L-Glutamine
# 22     0.255489                                        L-Glutamate
# 23     0.594780                                            Glycine
# 24     0.000971  Glycerolteichoicacidn45unlinkedunsubstitutedC1...
# 25     0.000971  Glycerolteichoicacidn45unlinkedDalasubstituted...
# 26     0.000971  Glycerolteichoicacidn45unlinkedglucosesubstitu...
# 27     0.208826                                                GTP
# 28    47.184845                                                H2O
# 29     0.091976                                        L-Histidine
# 30     0.282060                                       L-Isoleucine
# 31     0.189503                                          Potassium
# 32     0.437399                                          L-Leucine
# 33     0.000049  Lipoteichoicacidn24linkedglucosesubstitutedC26...
# 34     0.000049  Lipoteichoicacidn24linkedNacetylDglucosamineC3...
# 35     0.000049  Lipoteichoicacidn24linkedDalaninesubstitutedC1...
# 36     0.000049  Lipoteichoicacidn24linkedunsubstitutedC11836H2...
# 37     0.333158                                           L-Lysine
# 38     0.149206                                       L-Methionine
# 39     0.008422                                          Magnesium
# 40     0.000216                      510-Methylenetetrahydrofolate
# 41     0.000671                                               Mn2+
# 42     0.000097                                        Menaquinol8
# 43     0.001778                    Nicotinamideadeninedinucleotide
# 44     0.000434           Nicotinamideadeninedinucleotidephosphate
# 45     0.009709  PeptidoglycansubunitofBacillussubtilisC40H62N8O21
# 46     0.179865                                    L-Phenylalanine
# 47     0.214611                                          L-Proline
# 48     0.000216                               Pyridoxal5-phosphate
# 49     0.000216                                         Riboflavin
# 50     0.209502                                           L-Serine
# 51     0.004212                                            Sulfate
# 52     0.000216                              5678-Tetrahydrofolate
# 53     0.000216                                Thiaminediphosphate
# 54     0.246292                                        L-Threonine
# 55     0.055186                                       L-Tryptophan
# 56     0.133876                                         L-Tyrosine
# 57     0.139904                                                UTP
# 58     0.410827                                           L-Valine
# 59     0.000331                                               Zinc
#
#      abbreviation         category  molecular_weight
# 0        10fthf_c   carbon carrier           471.430
# 1        ala__L_c          protein            89.094
# 2          amet_c   carbon carrier           399.446
# 3        arg__L_c          protein           175.212
# 4        asn__L_c          protein           132.119
# 5        asp__L_c          protein           132.095
# 6           atp_c  energy molecule           503.150
# 7           ca2_c             salt            40.078
# 8            cl_c             salt            35.450
# 9           coa_c   carbon carrier           763.502
# 10      cobalt2_c             salt            58.933
# 11          ctp_c  energy molecule           479.124
# 12          cu2_c             salt            63.546
# 13       cys__L_c          protein           121.154
# 14         datp_c          nucleic           487.151
# 15         dctp_c          nucleic           463.125
# 16         dgtp_c          nucleic           503.150
# 17         dttp_c          nucleic           478.136
# 18          fad_c  energy molecule           783.541
# 19          fe2_c             salt            55.845
# 20          fe3_c             salt            55.845
# 21       gln__L_c          protein           146.146
# 22       glu__L_c          protein           146.122
# 23          gly_c          protein            75.067
# 24  gtca1_45_BS_c            lipid          7373.617
# 25  gtca2_45_BS_c            lipid         11382.847
# 26  gtca3_45_BS_c            lipid         14687.977
# 27          gtp_c  energy molecule           519.149
# 28          h2o_c            water            18.015
# 29       his__L_c          protein           155.157
# 30       ile__L_c          protein           131.175
# 31            k_c             salt            39.098
# 32       leu__L_c          protein           131.175
# 33  lipo1_24_BS_c            lipid        844881.272
# 34  lipo2_24_BS_c            lipid        943408.472
# 35  lipo3_24_BS_c            lipid        669568.472
# 36  lipo4_24_BS_c            lipid        455742.872
# 37       lys__L_c          protein           147.198
# 38       met__L_c          protein           149.208
# 39          mg2_c             salt            24.305
# 40        mlthf_c   carbon carrier           455.431
# 41          mn2_c             salt            54.938
# 42         mql8_c  energy molecule           719.151
# 43          nad_c  energy molecule           662.422
# 44         nadp_c  energy molecule           740.385
# 45   peptido_BS_c     carbohydrate           990.971
# 46       phe__L_c          protein           165.192
# 47       pro__L_c          protein           115.132
# 48       pydx5p_c  energy molecule           245.127
# 49       ribflv_c  energy molecule           376.369
# 50       ser__L_c          protein           105.093
# 51          so4_c             salt            96.056
# 52          thf_c   carbon carrier           443.420
# 53        thmpp_c  energy molecule           422.289
# 54       thr__L_c          protein           119.120
# 55       trp__L_c          protein           204.229
# 56       tyr__L_c          protein           181.191
# 57          utp_c  energy molecule           480.108
# 58       val__L_c          protein           117.148
# 59          zn2_c             salt            65.380
