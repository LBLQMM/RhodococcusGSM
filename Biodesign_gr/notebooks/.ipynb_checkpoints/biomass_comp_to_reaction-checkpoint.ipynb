# %% [markdown]
# # Biomass composition ➟  biomass reaction
# The purpose of this notebook is to convert biomass composition measurements into biomass equations for various R. opacus strains growing on various substrates

# %%
import cobra
import pandas as pd

# %% [markdown]
# ### Get biomass composition data (.csv import is a temporary. In the future this data will be from EDD)

# %%
biomass_comp_filename = '../../EDD_Ropacus_Multiomics/EDD_Ropacus_Multiomics_BiomassComp.csv'
biomass_comp_df = pd.read_csv(biomass_comp_filename)
biomass_comp_df
# Out:
#        Line Name      Measurement Type  Time (hrs)  Value Units  Unnamed: 5  \
# 0    RoWT_PHE-R2         Lipid Content        25.5  14.08     %         NaN
# 1    RoWT_PHE-R2  Carbohydrate Content        25.5  17.21     %         NaN
# 2    RoWT_PHE-R2       Protein Content        25.5  38.84     %         NaN
# 3      RoP1_L-R1         Lipid Content        25.5  16.44     %         NaN
# 4      RoP1_L-R1  Carbohydrate Content        25.5  12.47     %         NaN
# 5      RoP1_L-R1       Protein Content        25.5  39.43     %         NaN
# 6      RoP1_H-R3         Lipid Content        46.5  14.94     %         NaN
# 7      RoP1_H-R3  Carbohydrate Content        46.5  13.68     %         NaN
# 8      RoP1_H-R3       Protein Content        46.5  45.23     %         NaN
# 9     RoWT_PV-R2         Lipid Content        27.0  15.28     %         NaN
# 10    RoWT_PV-R2  Carbohydrate Content        27.0   9.37     %         NaN
# 11    RoWT_PV-R2       Protein Content        27.0  43.11     %         NaN
# 12    RoPV1_L-R2         Lipid Content        27.0  20.27     %         NaN
# 13    RoPV1_L-R2  Carbohydrate Content        27.0  10.11     %         NaN
# 14    RoPV1_L-R2       Protein Content        27.0  38.90     %         NaN
# 15    RoPV1_H-R2         Lipid Content        55.5  16.67     %         NaN
# 16    RoPV1_H-R2  Carbohydrate Content        55.5   8.74     %         NaN
# 17    RoPV1_H-R2       Protein Content        55.5  46.24     %         NaN
# 18   RoWT_PVH-R2         Lipid Content        18.0  14.86     %         NaN
# 19   RoWT_PVH-R2  Carbohydrate Content        18.0  14.02     %         NaN
# 20   RoWT_PVH-R2       Protein Content        18.0  36.06     %         NaN
# 21   RoPVH5_L-R2         Lipid Content        18.0  20.25     %         NaN
# 22   RoPVH5_L-R2  Carbohydrate Content        18.0  19.08     %         NaN
# 23   RoPVH5_L-R2       Protein Content        18.0  38.37     %         NaN
# 24   RoPVH5_H-R1         Lipid Content        28.5  15.07     %         NaN
# 25   RoPVH5_H-R1  Carbohydrate Content        28.5  16.61     %         NaN
# 26   RoPVH5_H-R1       Protein Content        28.5  46.70     %         NaN
# 27  RoWT_PVHG-R1         Lipid Content        15.0   9.09     %         NaN
# 28  RoWT_PVHG-R1  Carbohydrate Content        15.0  14.83     %         NaN
# 29  RoWT_PVHG-R1       Protein Content        15.0  39.08     %         NaN
# 30  RoPVHG6_L-R2         Lipid Content        15.0  18.87     %         NaN
# 31  RoPVHG6_L-R2  Carbohydrate Content        15.0  17.03     %         NaN
# 32  RoPVHG6_L-R2       Protein Content        15.0  39.68     %         NaN
# 33  RoPVHG6_H-R1         Lipid Content        44.5  10.81     %         NaN
# 34  RoPVHG6_H-R1  Carbohydrate Content        44.5  12.97     %         NaN
# 35  RoPVHG6_H-R1       Protein Content        44.5  42.22     %         NaN
# 36   RoWT_BEN-R2         Lipid Content        23.5   6.94     %         NaN
# 37   RoWT_BEN-R2  Carbohydrate Content        23.5  12.63     %         NaN
# 38   RoWT_BEN-R2       Protein Content        23.5  42.51     %         NaN
# 39     RoB2_L-R1         Lipid Content        23.5  13.33     %         NaN
# 40     RoB2_L-R1  Carbohydrate Content        23.5  16.63     %         NaN
# 41     RoB2_L-R1       Protein Content        23.5  43.29     %         NaN
# 42     RoB2_H-R1         Lipid Content        70.0   8.33     %         NaN
# 43     RoB2_H-R1  Carbohydrate Content        70.0  18.57     %         NaN
# 44     RoB2_H-R1       Protein Content        70.0  46.92     %         NaN
# 45   RoWT_GLC-R2         Lipid Content        35.0  40.26     %         NaN
# 46   RoWT_GLC-R2  Carbohydrate Content        35.0  14.64     %         NaN
# 47   RoWT_GLC-R2       Protein Content        35.0  24.04     %         NaN
# 48   RoGlc1_L-R3         Lipid Content        35.0  35.82     %         NaN
# 49   RoGlc1_L-R3  Carbohydrate Content        35.0  14.06     %         NaN
# 50   RoGlc1_L-R3       Protein Content        35.0  24.57     %         NaN
# 51   RoGlc1_H-R2         Lipid Content        38.5  49.15     %         NaN
# 52   RoGlc1_H-R2  Carbohydrate Content        38.5  16.56     %         NaN
# 53   RoGlc1_H-R2       Protein Content        38.5  25.63     %         NaN
#
#     Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11
# 0          NaN         NaN         NaN         NaN          NaN          NaN
# 1          NaN         NaN         NaN         NaN          NaN          NaN
# 2          NaN         NaN         NaN         NaN          NaN          NaN
# 3          NaN         NaN         NaN         NaN          NaN          NaN
# 4          NaN         NaN         NaN         NaN          NaN          NaN
# 5          NaN         NaN         NaN         NaN          NaN          NaN
# 6          NaN         NaN         NaN         NaN          NaN          NaN
# 7          NaN         NaN         NaN         NaN          NaN          NaN
# 8          NaN         NaN         NaN         NaN          NaN          NaN
# 9          NaN         NaN         NaN         NaN          NaN          NaN
# 10         NaN         NaN         NaN         NaN          NaN          NaN
# 11         NaN         NaN         NaN         NaN          NaN          NaN
# 12         NaN         NaN         NaN         NaN          NaN          NaN
# 13         NaN         NaN         NaN         NaN          NaN          NaN
# 14         NaN         NaN         NaN         NaN          NaN          NaN
# 15         NaN         NaN         NaN         NaN          NaN          NaN
# 16         NaN         NaN         NaN         NaN          NaN          NaN
# 17         NaN         NaN         NaN         NaN          NaN          NaN
# 18         NaN         NaN         NaN         NaN          NaN          NaN
# 19         NaN         NaN         NaN         NaN          NaN          NaN
# 20         NaN         NaN         NaN         NaN          NaN          NaN
# 21         NaN         NaN         NaN         NaN          NaN          NaN
# 22         NaN         NaN         NaN         NaN          NaN          NaN
# 23         NaN         NaN         NaN         NaN          NaN          NaN
# 24         NaN         NaN         NaN         NaN          NaN          NaN
# 25         NaN         NaN         NaN         NaN          NaN          NaN
# 26         NaN         NaN         NaN         NaN          NaN          NaN
# 27         NaN         NaN         NaN         NaN          NaN          NaN
# 28         NaN         NaN         NaN         NaN          NaN          NaN
# 29         NaN         NaN         NaN         NaN          NaN          NaN
# 30         NaN         NaN         NaN         NaN          NaN          NaN
# 31         NaN         NaN         NaN         NaN          NaN          NaN
# 32         NaN         NaN         NaN         NaN          NaN          NaN
# 33         NaN         NaN         NaN         NaN          NaN          NaN
# 34         NaN         NaN         NaN         NaN          NaN          NaN
# 35         NaN         NaN         NaN         NaN          NaN          NaN
# 36         NaN         NaN         NaN         NaN          NaN          NaN
# 37         NaN         NaN         NaN         NaN          NaN          NaN
# 38         NaN         NaN         NaN         NaN          NaN          NaN
# 39         NaN         NaN         NaN         NaN          NaN          NaN
# 40         NaN         NaN         NaN         NaN          NaN          NaN
# 41         NaN         NaN         NaN         NaN          NaN          NaN
# 42         NaN         NaN         NaN         NaN          NaN          NaN
# 43         NaN         NaN         NaN         NaN          NaN          NaN
# 44         NaN         NaN         NaN         NaN          NaN          NaN
# 45         NaN         NaN         NaN         NaN          NaN          NaN
# 46         NaN         NaN         NaN         NaN          NaN          NaN
# 47         NaN         NaN         NaN         NaN          NaN          NaN
# 48         NaN         NaN         NaN         NaN          NaN          NaN
# 49         NaN         NaN         NaN         NaN          NaN          NaN
# 50         NaN         NaN         NaN         NaN          NaN          NaN
# 51         NaN         NaN         NaN         NaN          NaN          NaN
# 52         NaN         NaN         NaN         NaN          NaN          NaN
# 53         NaN         NaN         NaN         NaN          NaN          NaN

# %% [markdown]
# ### Break out individual conditions

# %%
WT_phenol_biomass_comp_df = biomass_comp_df[biomass_comp_df['Line Name'] == 'RoWT_PHE-R2']
WT_phenol_biomass_comp_df
# Out:
#      Line Name      Measurement Type  Time (hrs)  Value Units  Unnamed: 5  \
# 0  RoWT_PHE-R2         Lipid Content        25.5  14.08     %         NaN
# 1  RoWT_PHE-R2  Carbohydrate Content        25.5  17.21     %         NaN
# 2  RoWT_PHE-R2       Protein Content        25.5  38.84     %         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11
# 0         NaN         NaN         NaN         NaN          NaN          NaN
# 1         NaN         NaN         NaN         NaN          NaN          NaN
# 2         NaN         NaN         NaN         NaN          NaN          NaN

# %%
P1_L_phenol_biomass_comp_df = biomass_comp_df[biomass_comp_df['Line Name'] == 'RoP1_L-R1']
P1_L_phenol_biomass_comp_df
# Out:
#    Line Name      Measurement Type  Time (hrs)  Value Units  Unnamed: 5  \
# 3  RoP1_L-R1         Lipid Content        25.5  16.44     %         NaN
# 4  RoP1_L-R1  Carbohydrate Content        25.5  12.47     %         NaN
# 5  RoP1_L-R1       Protein Content        25.5  39.43     %         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11
# 3         NaN         NaN         NaN         NaN          NaN          NaN
# 4         NaN         NaN         NaN         NaN          NaN          NaN
# 5         NaN         NaN         NaN         NaN          NaN          NaN

# %%
P1_H_phenol_biomass_comp_df = biomass_comp_df[biomass_comp_df['Line Name'] == 'RoP1_H-R3']
P1_H_phenol_biomass_comp_df
# Out:
#    Line Name      Measurement Type  Time (hrs)  Value Units  Unnamed: 5  \
# 6  RoP1_H-R3         Lipid Content        46.5  14.94     %         NaN
# 7  RoP1_H-R3  Carbohydrate Content        46.5  13.68     %         NaN
# 8  RoP1_H-R3       Protein Content        46.5  45.23     %         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11
# 6         NaN         NaN         NaN         NaN          NaN          NaN
# 7         NaN         NaN         NaN         NaN          NaN          NaN
# 8         NaN         NaN         NaN         NaN          NaN          NaN

# %% [markdown]
# ### Pull up original biomass equation

# %%
model = cobra.io.read_sbml_model("../GSMs/Ropacus_annotated_curated.xml")

# %% [markdown]
# Split into biomass reactions into substrates and products

# %%
original_biomass_reaction = model.reactions.get_by_id('Growth')
substrate_str = original_biomass_reaction.reaction.split('-->')[0]
product_str = original_biomass_reaction.reaction.split('-->')[1]

# %% [markdown]
# Print the biomass equation's metabolites and reaction coefficients

# %%
substrate_list = substrate_str.split('+')
product_list = product_str.split('+')

substrate_dict = {item.strip().split(' ')[1] : item.strip().split(' ')[0] for item in substrate_list}
product_dict = {item.strip().split(' ')[1] : item.strip().split(' ')[0] for item in product_list}

print('substrates')
placeholder = [print(f'{float(substrate_dict[met]):.6f}', model.metabolites.get_by_id(met).name) for met in substrate_dict]
print()
print('products')
placeholder = [print(f'{float(product_dict[met]):.6f}', model.metabolites.get_by_id(met).name) for met in product_dict]
# Out:
# substrates
# 0.000216 10-Formyltetrahydrofolate
# 0.498716 L-Alanine
# 0.000216 S-Adenosyl-L-methionine
# 0.287170 L-Arginine
# 0.234029 L-Asparagine
# 0.234029 L-Aspartate
# 52.547151 ATP
# 0.005053 Calcium
# 0.005053 Chloride
# 0.000559 Coenzyme A
# 0.000097 Co2+
# 0.129616 CTP
# 0.000688 Cu2+
# 0.088911 L-Cysteine
# 0.025403 DATP
# 0.026229 DCTP
# 0.026229 DGTP
# 0.025403 DTTP
# 0.000216 Flavin adenine dinucleotide oxidized
# 0.006519 Fe2+
# 0.007580 Fe3+
# 0.255489 L-Glutamine
# 0.255489 L-Glutamate
# 0.594780 Glycine
# 0.000971 Glycerol teichoic acid  n45   unlinked  unsubstituted C151H297N2O238P46
# 0.000971 Glycerol teichoic acid  n45   unlinked  D ala substituted C286H612N47O328P46
# 0.000971 Glycerol teichoic acid  n45   unlinked  glucose substituted C421H749N2O464P46
# 0.208826 GTP
# 47.184845 H2O
# 0.091976 L-Histidine
# 0.282060 L-Isoleucine
# 0.189503 Potassium
# 0.437399 L-Leucine
# 0.000049 Lipoteichoic acid  n24   linked  glucose substituted C26236H47072O25500P2400
# 0.000049 Lipoteichoic acid  n24   linked  N acetyl D glucosamine C31036H54272N2400O25500P2400
# 0.000049 Lipoteichoic acid  n24   linked  D alanine substituted C19036H39872N2400O18300P2400
# 0.000049 Lipoteichoic acid  n24   linked  unsubstituted C11836H23072O13500P2400
# 0.333158 L-Lysine
# 0.149206 L-Methionine
# 0.008422 Magnesium
# 0.000216 5,10-Methylenetetrahydrofolate
# 0.000671 Mn2+
# 0.000097 Menaquinol 8
# 0.001778 Nicotinamide adenine dinucleotide
# 0.000434 Nicotinamide adenine dinucleotide phosphate
# 0.009709 Peptidoglycan subunit of Bacillus subtilis C40H62N8O21
# 0.179865 L-Phenylalanine
# 0.214611 L-Proline
# 0.000216 Pyridoxal 5'-phosphate
# 0.000216 Riboflavin
# 0.209502 L-Serine
# 0.004212 Sulfate
# 0.000216 5,6,7,8-Tetrahydrofolate
# 0.000216 Thiamine diphosphate
# 0.246292 L-Threonine
# 0.055186 L-Tryptophan
# 0.133876 L-Tyrosine
# 0.139904 UTP
# 0.410827 L-Valine
# 0.000331 Zinc
#
# products
# 52.377416 ADP
# 52.377416 H+
# 52.373204 Phosphate
# 0.751345 Diphosphate

# %% [markdown]
# Define the types of each biomass reaction metabolite. These will be used to quantify the amount of dry cell weight each group takes up.

# %%
substrate_type_dict = {
    '10fthf_c' : 'carbon carrier',
    'ala__L_c': 'protein',
    'amet_c': 'carbon carrier',
    'arg__L_c': 'protein',
    'asn__L_c': 'protein',
    'asp__L_c': 'protein',
    'atp_c': 'energy molecule',
    'ca2_c': 'salt',
    'cl_c': 'salt',
    'coa_c': 'carbon carrier',
    'cobalt2_c': 'salt',
    'ctp_c': 'energy molecule',
    'cu2_c': 'salt',
    'cys__L_c': 'protein',
    'datp_c': 'nucleic acid',
    'dctp_c': 'nucleic acid',
    'dgtp_c': 'nucleic acid',
    'dttp_c': 'nucleic acid',
    'fad_c': 'energy molecule',
    'fe2_c': 'salt',
    'fe3_c': 'salt',
    'gln__L_c': 'protein',
    'glu__L_c': 'protein',
    'gly_c': 'protein',
    'gtca1_45_BS_c': 'lipid',
    'gtca2_45_BS_c': 'lipid',
    'gtca3_45_BS_c': 'lipid',
    'gtp_c': 'energy molecule',
    'h2o_c': 'n/a',
    'his__L_c': 'protein',
    'ile__L_c': 'protein',
    'k_c': 'salt',
    'leu__L_c': 'protein',
    'lipo1_24_BS_c': 'lipid',
    'lipo2_24_BS_c': 'lipid',
    'lipo3_24_BS_c': 'lipid',
    'lipo4_24_BS_c': 'lipid',
    'lys__L_c': 'protein',
    'met__L_c': 'protein',
    'mg2_c': 'salt',
    'mlthf_c': 'carbon carrier',
    'mn2_c': 'salt',
    'mql8_c': 'energy molecule',
    'nad_c': 'energy molecule',
    'nadp_c': 'energy molecule',
    'peptido_BS_c': 'carbohydrate',
    'phe__L_c': 'protein',
    'pro__L_c': 'protein',
    'pydx5p_c': 'energy molecule',
    'ribflv_c': 'energy molecule',
    'ser__L_c': 'protein',
    'so4_c': 'salt',
    'thf_c': 'carbon carrier',
    'thmpp_c': 'energy molecule',
    'thr__L_c': 'protein',
    'trp__L_c': 'protein',
    'tyr__L_c': 'protein',
    'utp_c': 'energy molecule',
    'val__L_c': 'protein',
    'zn2_c': 'salt',
}

# %% [markdown]
# Define a dictionary that has the molar mass of each metablite in g/mol or mg/mmol (equivalent units). These will be used to quantify the amount of dry cell weight each metabolite makes up.

# %%
element_masses = {
    'H': 1.008,
    'C': 12.011,
    'N': 14.007,
    'O': 15.999,
    'P': 30.974,
    'S': 32.06,
    'Cl': 35.45,
    'K': 39.098,
    'Ca': 40.078,
    'Cu': 63.546,
    'Mn': 54.938,
    'Fe': 55.845,
    'Co': 58.933,
    'Mg': 24.305,
    'Zn': 65.38
}

substrate_masses = {}

for met in substrate_dict:
    element_dict = model.metabolites.get_by_id(met).elements
    molar_mass = 0
    for element in element_dict:
        molar_mass += element_masses[element] * element_dict[element]
    substrate_masses[met] = molar_mass    
substrate_masses
# Out:
# {'10fthf_c': 471.42999999999995,
#  'ala__L_c': 89.094,
#  'amet_c': 399.44599999999997,
#  'arg__L_c': 175.212,
#  'asn__L_c': 132.119,
#  'asp__L_c': 132.095,
#  'atp_c': 503.15,
#  'ca2_c': 40.078,
#  'cl_c': 35.45,
#  'coa_c': 763.502,
#  'cobalt2_c': 58.933,
#  'ctp_c': 479.124,
#  'cu2_c': 63.546,
#  'cys__L_c': 121.154,
#  'datp_c': 487.15099999999995,
#  'dctp_c': 463.125,
#  'dgtp_c': 503.15,
#  'dttp_c': 478.1360000000001,
#  'fad_c': 783.5409999999999,
#  'fe2_c': 55.845,
#  'fe3_c': 55.845,
#  'gln__L_c': 146.146,
#  'glu__L_c': 146.122,
#  'gly_c': 75.067,
#  'gtca1_45_BS_c': 7373.617,
#  'gtca2_45_BS_c': 11382.847,
#  'gtca3_45_BS_c': 14687.976999999999,
#  'gtp_c': 519.149,
#  'h2o_c': 18.015,
#  'his__L_c': 155.157,
#  'ile__L_c': 131.175,
#  'k_c': 39.098,
#  'leu__L_c': 131.175,
#  'lipo1_24_BS_c': 844881.272,
#  'lipo2_24_BS_c': 943408.472,
#  'lipo3_24_BS_c': 669568.472,
#  'lipo4_24_BS_c': 455742.872,
#  'lys__L_c': 147.198,
#  'met__L_c': 149.20800000000003,
#  'mg2_c': 24.305,
#  'mlthf_c': 455.4309999999999,
#  'mn2_c': 54.938,
#  'mql8_c': 719.151,
#  'nad_c': 662.4219999999999,
#  'nadp_c': 740.385,
#  'peptido_BS_c': 990.971,
#  'phe__L_c': 165.19199999999998,
#  'pro__L_c': 115.132,
#  'pydx5p_c': 245.12699999999998,
#  'ribflv_c': 376.369,
#  'ser__L_c': 105.09299999999999,
#  'so4_c': 96.05600000000001,
#  'thf_c': 443.41999999999996,
#  'thmpp_c': 422.289,
#  'thr__L_c': 119.12,
#  'trp__L_c': 204.22899999999998,
#  'tyr__L_c': 181.19099999999997,
#  'utp_c': 480.10800000000006,
#  'val__L_c': 117.14800000000001,
#  'zn2_c': 65.38}

# %% [markdown]
# ### Calculate the mass that each group makes up in the Default biomass equation

# %%
biomass_types = set(substrate_type_dict.values())

for biomass_type in biomass_types:
    
    mass = 0
    for met in substrate_dict:
        if substrate_type_dict[met] == biomass_type:
            mass += float(substrate_dict[met]) * substrate_masses[met]
    print(biomass_type, mass)
# Out:
# lipid 173.90320979912588
# nucleic acid 49.86635926461023
# n/a 850.0349822009696
# carbon carrier 0.8101036482552552
# energy molecule 26678.746144703928
# protein 656.0539383052892
# salt 9.295469045918262
# carbohydrate 9.620852655189088

# %%
for met in substrate_dict:
    if substrate_type_dict[met] == 'protein':
        print(float(substrate_dict[met]), substrate_masses[met])
#         mass += float(substrate_dict[met]) * substrate_masses[met]
print(biomass_type, mass)
# Out:
# carbohydrate 665.6747909604783
