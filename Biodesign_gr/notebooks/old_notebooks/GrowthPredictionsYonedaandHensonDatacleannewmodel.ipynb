# %% [markdown]
# ### **Notebook to calculate biomass growth rate observations and predictions for Yoneda and Henson data**

# %%
#Python packages:
import numpy as np
import sys
import os
import pandas as pd
import cobra
import math
from scipy.stats import linregress
from scipy import mean

# %% [markdown]
# #### **Load Yoneda and Henson Data**

# %%
from edd_utils import login, export_study, export_metadata
# Study to Download
study_slug = 'biodesign_yoneda_set2'#multiomics-data-for-wt-strain-c157'
study_slug2 = 'biodesign_henson2108'
# EDD server
edd_server = 'public-edd.jbei.org'#agilebiofoundry.org'#'edd.jbei.org'
user       = 'schenkch'

# %%
session = login(edd_server=edd_server, user=user)
# Out:
# Password for schenkch:  ···············

# %%
#Export data from EDD as 2 dataframes:
df: pd.DataFrame

# filename = TBD
    
try:
    df = export_study(session, study_slug, edd_server=edd_server)
    df2 = export_study(session, study_slug2, edd_server=edd_server)
except (NameError, AttributeError, KeyError):
    try:
        df = pd.read_csv(filename)
    except:
        print(f'ERROR! Alternative loading of data from disk at {DISKDF} failed!')
    else:
        print(f'OK! Alternative loading of data from disk at {DISKDF} was successful.')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=135.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=46512.0), HTML(value='')))

# %%
#df = export_study(session, study_slug, edd_server=edd_server)
df.head()
df2.head()
# Out:
#    Study ID            Study Name  Line ID Line Name  \
# 0     13556  Biodesign_Henson2108    14299   WT-P-R1
# 1     13556  Biodesign_Henson2108    14299   WT-P-R1
# 2     13556  Biodesign_Henson2108    14299   WT-P-R1
# 3     13556  Biodesign_Henson2108    14299   WT-P-R1
# 4     13556  Biodesign_Henson2108    14299   WT-P-R1
#
#                                     Line Description Protocol  Assay ID  \
# 0  R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14323
# 1  R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14323
# 2  R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14323
# 3  R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14323
# 4  R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14323
#
#   Assay Name Formal Type Measurement Type  Compartment Units    Value  Hours
# 0    WT-P-R1     cid:996           phenol            0   g/L  0.50000    0.0
# 1    WT-P-R1     cid:996           phenol            0   g/L  0.45308    8.0
# 2    WT-P-R1     cid:996           phenol            0   g/L  0.39683   20.0
# 3    WT-P-R1     cid:996           phenol            0   g/L  0.39879   24.0
# 4    WT-P-R1     cid:996           phenol            0   g/L  0.21632   32.0

# %%
#dataDir =  '../../EDD_Yoneda_data'
#ODdata_xls = load_workbook(os.path.join(dataDir, 'Yoneda_set2_ODD_data.xlsx'))
#ODdata_xls = (os.path.join(dataDir, 'Yoneda_set2_ODD_data.xlsx'))#, index_col=None)#if multiple sheets specify sheet as well e.g. 'Sheet2'
#ODfile = ODdata_xls.to_csv('csvfile.csv', encoding='utf-8', index=False)
#display(ODfile)
#ODfile = os.path.join(dataDir, 'Yoneda_set2_ODD_data.csv')
#Subfile = os.path.join(dataDir, 'Yoneda_set2_Metabolomics_data.csv')

OD = df[df['Protocol'].str.contains('OD600')]#pd.read_csv(ODfile)
#OD['Biomass Conc'] = OD['Value']#GRAMS_BIOMASS_PER_LITER_PER_OD*OD['Value']
#Sub = pd.read_csv(Subfile)
Sub = df[df['Protocol'].str.contains('HPLC')]

display(OD)
display(Sub)
print(f'substrate data has {len(Sub)} lines')
print(f'OD data has {len(OD)} lines')
# Out:
#     Study ID             Study Name  Line ID   Line Name  \
# 0      13800  Biodesign_Yoneda_set2    14200       WT-R1
# 1      13800  Biodesign_Yoneda_set2    14200       WT-R1
# 2      13800  Biodesign_Yoneda_set2    14200       WT-R1
# 3      13800  Biodesign_Yoneda_set2    14200       WT-R1
# 4      13800  Biodesign_Yoneda_set2    14200       WT-R1
# ..       ...                    ...      ...         ...
# 58     13800  Biodesign_Yoneda_set2    14213  EVOL33-G-N
# 59     13800  Biodesign_Yoneda_set2    14213  EVOL33-G-N
# 60     13800  Biodesign_Yoneda_set2    14214  EVOL40-G-N
# 61     13800  Biodesign_Yoneda_set2    14214  EVOL40-G-N
# 62     13800  Biodesign_Yoneda_set2    14214  EVOL40-G-N
#
#                                      Line Description Protocol  Assay ID  \
# 0   R. Opacus wild type strain with 1.50 g/l pheno...    OD600     14218
# 1   R. Opacus wild type strain with 1.50 g/l pheno...    OD600     14218
# 2   R. Opacus wild type strain with 1.50 g/l pheno...    OD600     14218
# 3   R. Opacus wild type strain with 1.50 g/l pheno...    OD600     14218
# 4   R. Opacus wild type strain with 1.50 g/l pheno...    OD600     14218
# ..                                                ...      ...       ...
# 58  R. Opacus adaptively evolved strain1 with 1.0 ...    OD600     14231
# 59  R. Opacus adaptively evolved strain1 with 1.0 ...    OD600     14231
# 60  R. Opacus adaptively evolved strain2 with 1.0 ...    OD600     14232
# 61  R. Opacus adaptively evolved strain2 with 1.0 ...    OD600     14232
# 62  R. Opacus adaptively evolved strain2 with 1.0 ...    OD600     14232
#
#     Assay Name Formal Type Measurement Type  Compartment Units  Value  \
# 0        WT-R1         NaN  Optical Density            0   NaN  0.300
# 1        WT-R1         NaN  Optical Density            0   NaN  0.424
# 2        WT-R1         NaN  Optical Density            0   NaN  0.687
# 3        WT-R1         NaN  Optical Density            0   NaN  0.814
# 4        WT-R1         NaN  Optical Density            0   NaN  0.942
# ..         ...         ...              ...          ...   ...    ...
# 58  EVOL33-G-N         NaN  Optical Density            0   NaN  1.413
# 59  EVOL33-G-N         NaN  Optical Density            0   NaN  1.308
# 60  EVOL40-G-N         NaN  Optical Density            0   NaN  0.300
# 61  EVOL40-G-N         NaN  Optical Density            0   NaN  1.670
# 62  EVOL40-G-N         NaN  Optical Density            0   NaN  1.411
#
#        Hours
# 0    0.00000
# 1   16.61361
# 2   41.23694
# 3   52.08611
# 4   61.72028
# ..       ...
# 58  16.61361
# 59  41.23694
# 60   0.00000
# 61  16.61361
# 62  41.23694
#
# [63 rows x 14 columns]
#      Study ID             Study Name  Line ID   Line Name  \
# 63      13800  Biodesign_Yoneda_set2    14200       WT-R1
# 64      13800  Biodesign_Yoneda_set2    14200       WT-R1
# 65      13800  Biodesign_Yoneda_set2    14200       WT-R1
# 66      13800  Biodesign_Yoneda_set2    14200       WT-R1
# 67      13800  Biodesign_Yoneda_set2    14200       WT-R1
# ..        ...                    ...      ...         ...
# 130     13800  Biodesign_Yoneda_set2    14216  Control-R2
# 131     13800  Biodesign_Yoneda_set2    14216  Control-R2
# 132     13800  Biodesign_Yoneda_set2    14217  Control-R3
# 133     13800  Biodesign_Yoneda_set2    14217  Control-R3
# 134     13800  Biodesign_Yoneda_set2    14217  Control-R3
#
#                                       Line Description Protocol  Assay ID  \
# 63   R. Opacus wild type strain with 1.50 g/l pheno...     HPLC     14233
# 64   R. Opacus wild type strain with 1.50 g/l pheno...     HPLC     14233
# 65   R. Opacus wild type strain with 1.50 g/l pheno...     HPLC     14233
# 66   R. Opacus wild type strain with 1.50 g/l pheno...     HPLC     14233
# 67   R. Opacus wild type strain with 1.50 g/l pheno...     HPLC     14233
# ..                                                 ...      ...       ...
# 130     1.5 g/l phenol in minimal medium without cells     HPLC     14249
# 131     1.5 g/l phenol in minimal medium without cells     HPLC     14249
# 132     1.5 g/l phenol in minimal medium without cells     HPLC     14250
# 133     1.5 g/l phenol in minimal medium without cells     HPLC     14250
# 134     1.5 g/l phenol in minimal medium without cells     HPLC     14250
#
#      Assay Name Formal Type Measurement Type  Compartment Units    Value  \
# 63        WT-R1     cid:996           phenol            0   g/L  1.53118
# 64        WT-R1     cid:996           phenol            0   g/L  1.38327
# 65        WT-R1     cid:996           phenol            0   g/L  1.10857
# 66        WT-R1     cid:996           phenol            0   g/L  0.84795
# 67        WT-R1     cid:996           phenol            0   g/L  0.76695
# ..          ...         ...              ...          ...   ...      ...
# 130  Control-R2     cid:996           phenol            0   g/L  1.57873
# 131  Control-R2     cid:996           phenol            0   g/L  1.45370
# 132  Control-R3     cid:996           phenol            0   g/L  1.56640
# 133  Control-R3     cid:996           phenol            0   g/L  1.58753
# 134  Control-R3     cid:996           phenol            0   g/L  1.50125
#
#         Hours
# 63    0.00000
# 64   16.61361
# 65   41.23694
# 66   52.08611
# 67   61.72028
# ..        ...
# 130  41.23694
# 131  61.72028
# 132   0.00000
# 133  41.23694
# 134  61.72028
#
# [72 rows x 14 columns]
# substrate data has 72 lines
# OD data has 63 lines

# %%
ODHen = df2[df2['Protocol'].str.contains('OD600')]#pd.read_csv(ODfile)
#OD['Biomass Conc'] = OD['Value']#GRAMS_BIOMASS_PER_LITER_PER_OD*OD['Value']
#Sub = pd.read_csv(Subfile)
SubHen = df2[df2['Protocol'].str.contains('HPLC')]

display(ODHen)
display(SubHen)
print(f'substrate data has {len(SubHen)} lines')
print(f'OD data has {len(ODHen)} lines')
# Out:
#      Study ID            Study Name  Line ID   Line Name  \
# 48      13556  Biodesign_Henson2108    14299     WT-P-R1
# 49      13556  Biodesign_Henson2108    14299     WT-P-R1
# 50      13556  Biodesign_Henson2108    14299     WT-P-R1
# 51      13556  Biodesign_Henson2108    14299     WT-P-R1
# 52      13556  Biodesign_Henson2108    14299     WT-P-R1
# 53      13556  Biodesign_Henson2108    14299     WT-P-R1
# 54      13556  Biodesign_Henson2108    14299     WT-P-R1
# 55      13556  Biodesign_Henson2108    14299     WT-P-R1
# 56      13556  Biodesign_Henson2108    14299     WT-P-R1
# 57      13556  Biodesign_Henson2108    14299     WT-P-R1
# 58      13556  Biodesign_Henson2108    14300     WT-P-R2
# 59      13556  Biodesign_Henson2108    14300     WT-P-R2
# 60      13556  Biodesign_Henson2108    14300     WT-P-R2
# 61      13556  Biodesign_Henson2108    14300     WT-P-R2
# 62      13556  Biodesign_Henson2108    14300     WT-P-R2
# 63      13556  Biodesign_Henson2108    14300     WT-P-R2
# 64      13556  Biodesign_Henson2108    14300     WT-P-R2
# 65      13556  Biodesign_Henson2108    14300     WT-P-R2
# 66      13556  Biodesign_Henson2108    14300     WT-P-R2
# 67      13556  Biodesign_Henson2108    14300     WT-P-R2
# 68      13556  Biodesign_Henson2108    14301     WT-P-R3
# 69      13556  Biodesign_Henson2108    14301     WT-P-R3
# 70      13556  Biodesign_Henson2108    14301     WT-P-R3
# 71      13556  Biodesign_Henson2108    14301     WT-P-R3
# 72      13556  Biodesign_Henson2108    14301     WT-P-R3
# 73      13556  Biodesign_Henson2108    14301     WT-P-R3
# 74      13556  Biodesign_Henson2108    14301     WT-P-R3
# 75      13556  Biodesign_Henson2108    14301     WT-P-R3
# 76      13556  Biodesign_Henson2108    14301     WT-P-R3
# 77      13556  Biodesign_Henson2108    14301     WT-P-R3
# 78      13556  Biodesign_Henson2108    14311  PVHG6-P-R1
# 79      13556  Biodesign_Henson2108    14311  PVHG6-P-R1
# 80      13556  Biodesign_Henson2108    14311  PVHG6-P-R1
# 81      13556  Biodesign_Henson2108    14311  PVHG6-P-R1
# 82      13556  Biodesign_Henson2108    14311  PVHG6-P-R1
# 83      13556  Biodesign_Henson2108    14311  PVHG6-P-R1
# 84      13556  Biodesign_Henson2108    14311  PVHG6-P-R1
# 85      13556  Biodesign_Henson2108    14311  PVHG6-P-R1
# 86      13556  Biodesign_Henson2108    14311  PVHG6-P-R1
# 87      13556  Biodesign_Henson2108    14311  PVHG6-P-R1
# 88      13556  Biodesign_Henson2108    14312  PVHG6-P-R2
# 89      13556  Biodesign_Henson2108    14312  PVHG6-P-R2
# 90      13556  Biodesign_Henson2108    14312  PVHG6-P-R2
# 91      13556  Biodesign_Henson2108    14312  PVHG6-P-R2
# 92      13556  Biodesign_Henson2108    14312  PVHG6-P-R2
# 93      13556  Biodesign_Henson2108    14312  PVHG6-P-R2
# 94      13556  Biodesign_Henson2108    14312  PVHG6-P-R2
# 95      13556  Biodesign_Henson2108    14312  PVHG6-P-R2
# 96      13556  Biodesign_Henson2108    14312  PVHG6-P-R2
# 97      13556  Biodesign_Henson2108    14312  PVHG6-P-R2
# 98      13556  Biodesign_Henson2108    14313  PVHG6-P-R3
# 99      13556  Biodesign_Henson2108    14313  PVHG6-P-R3
# 100     13556  Biodesign_Henson2108    14313  PVHG6-P-R3
# 101     13556  Biodesign_Henson2108    14313  PVHG6-P-R3
# 102     13556  Biodesign_Henson2108    14313  PVHG6-P-R3
# 103     13556  Biodesign_Henson2108    14313  PVHG6-P-R3
# 104     13556  Biodesign_Henson2108    14313  PVHG6-P-R3
# 105     13556  Biodesign_Henson2108    14313  PVHG6-P-R3
# 106     13556  Biodesign_Henson2108    14313  PVHG6-P-R3
# 107     13556  Biodesign_Henson2108    14313  PVHG6-P-R3
#
#                                       Line Description Protocol  Assay ID  \
# 48   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14329
# 49   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14329
# 50   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14329
# 51   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14329
# 52   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14329
# 53   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14329
# 54   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14329
# 55   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14329
# 56   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14329
# 57   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14329
# 58   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14330
# 59   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14330
# 60   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14330
# 61   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14330
# 62   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14330
# 63   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14330
# 64   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14330
# 65   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14330
# 66   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14330
# 67   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14330
# 68   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14331
# 69   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14331
# 70   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14331
# 71   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14331
# 72   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14331
# 73   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14331
# 74   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14331
# 75   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14331
# 76   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14331
# 77   R. Opacus wild type strain with 0.5 g/l PHE as...    OD600     14331
# 78   R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14332
# 79   R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14332
# 80   R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14332
# 81   R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14332
# 82   R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14332
# 83   R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14332
# 84   R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14332
# 85   R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14332
# 86   R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14332
# 87   R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14332
# 88   R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14333
# 89   R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14333
# 90   R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14333
# 91   R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14333
# 92   R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14333
# 93   R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14333
# 94   R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14333
# 95   R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14333
# 96   R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14333
# 97   R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14333
# 98   R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14334
# 99   R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14334
# 100  R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14334
# 101  R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14334
# 102  R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14334
# 103  R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14334
# 104  R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14334
# 105  R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14334
# 106  R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14334
# 107  R. Opacus adaptively evolved strain6 with 0.5 ...    OD600     14334
#
#      Assay Name Formal Type Measurement Type  Compartment Units    Value  \
# 48      WT-P-R1         NaN  Optical Density            0   NaN  0.05000
# 49      WT-P-R1         NaN  Optical Density            0   NaN  0.09559
# 50      WT-P-R1         NaN  Optical Density            0   NaN  0.20540
# 51      WT-P-R1         NaN  Optical Density            0   NaN  0.28440
# 52      WT-P-R1         NaN  Optical Density            0   NaN  0.38354
# 53      WT-P-R1         NaN  Optical Density            0   NaN  0.44556
# 54      WT-P-R1         NaN  Optical Density            0   NaN  0.51350
# 55      WT-P-R1         NaN  Optical Density            0   NaN  0.54095
# 56      WT-P-R1         NaN  Optical Density            0   NaN  0.54194
# 57      WT-P-R1         NaN  Optical Density            0   NaN  0.59783
# 58      WT-P-R2         NaN  Optical Density            0   NaN  0.05000
# 59      WT-P-R2         NaN  Optical Density            0   NaN  0.07485
# 60      WT-P-R2         NaN  Optical Density            0   NaN  0.18525
# 61      WT-P-R2         NaN  Optical Density            0   NaN  0.27018
# 62      WT-P-R2         NaN  Optical Density            0   NaN  0.36952
# 63      WT-P-R2         NaN  Optical Density            0   NaN  0.44734
# 64      WT-P-R2         NaN  Optical Density            0   NaN  0.48684
# 65      WT-P-R2         NaN  Optical Density            0   NaN  0.54905
# 66      WT-P-R2         NaN  Optical Density            0   NaN  0.56604
# 67      WT-P-R2         NaN  Optical Density            0   NaN  0.62094
# 68      WT-P-R3         NaN  Optical Density            0   NaN  0.05000
# 69      WT-P-R3         NaN  Optical Density            0   NaN  0.11060
# 70      WT-P-R3         NaN  Optical Density            0   NaN  0.20896
# 71      WT-P-R3         NaN  Optical Density            0   NaN  0.29882
# 72      WT-P-R3         NaN  Optical Density            0   NaN  0.40942
# 73      WT-P-R3         NaN  Optical Density            0   NaN  0.46017
# 74      WT-P-R3         NaN  Optical Density            0   NaN  0.50204
# 75      WT-P-R3         NaN  Optical Density            0   NaN  0.55261
# 76      WT-P-R3         NaN  Optical Density            0   NaN  0.55517
# 77      WT-P-R3         NaN  Optical Density            0   NaN  0.60158
# 78   PVHG6-P-R1         NaN  Optical Density            0   NaN  0.05000
# 79   PVHG6-P-R1         NaN  Optical Density            0   NaN  0.11040
# 80   PVHG6-P-R1         NaN  Optical Density            0   NaN  0.28302
# 81   PVHG6-P-R1         NaN  Optical Density            0   NaN  0.39223
# 82   PVHG6-P-R1         NaN  Optical Density            0   NaN  0.57690
# 83   PVHG6-P-R1         NaN  Optical Density            0   NaN  0.82713
# 84   PVHG6-P-R1         NaN  Optical Density            0   NaN  0.96558
# 85   PVHG6-P-R1         NaN  Optical Density            0   NaN  1.08902
# 86   PVHG6-P-R1         NaN  Optical Density            0   NaN  1.06828
# 87   PVHG6-P-R1         NaN  Optical Density            0   NaN  1.04240
# 88   PVHG6-P-R2         NaN  Optical Density            0   NaN  0.05000
# 89   PVHG6-P-R2         NaN  Optical Density            0   NaN  0.10823
# 90   PVHG6-P-R2         NaN  Optical Density            0   NaN  0.29270
# 91   PVHG6-P-R2         NaN  Optical Density            0   NaN  0.39381
# 92   PVHG6-P-R2         NaN  Optical Density            0   NaN  0.59645
# 93   PVHG6-P-R2         NaN  Optical Density            0   NaN  0.82239
# 94   PVHG6-P-R2         NaN  Optical Density            0   NaN  0.86722
# 95   PVHG6-P-R2         NaN  Optical Density            0   NaN  1.09000
# 96   PVHG6-P-R2         NaN  Optical Density            0   NaN  1.08842
# 97   PVHG6-P-R2         NaN  Optical Density            0   NaN  1.07835
# 98   PVHG6-P-R3         NaN  Optical Density            0   NaN  0.05000
# 99   PVHG6-P-R3         NaN  Optical Density            0   NaN  0.11277
# 100  PVHG6-P-R3         NaN  Optical Density            0   NaN  0.28460
# 101  PVHG6-P-R3         NaN  Optical Density            0   NaN  0.39579
# 102  PVHG6-P-R3         NaN  Optical Density            0   NaN  0.59210
# 103  PVHG6-P-R3         NaN  Optical Density            0   NaN  0.80363
# 104  PVHG6-P-R3         NaN  Optical Density            0   NaN  0.91285
# 105  PVHG6-P-R3         NaN  Optical Density            0   NaN  1.04853
# 106  PVHG6-P-R3         NaN  Optical Density            0   NaN  1.05248
# 107  PVHG6-P-R3         NaN  Optical Density            0   NaN  1.03747
#
#      Hours
# 48     0.0
# 49     9.0
# 50    19.0
# 51    24.0
# 52    33.0
# 53    44.0
# 54    55.0
# 55    70.0
# 56    82.0
# 57   100.0
# 58     0.0
# 59    14.0
# 60    20.0
# 61    24.0
# 62    28.0
# 63    34.0
# 64    38.0
# 65    43.0
# 66    48.0
# 67    52.0
# 68     0.0
# 69    14.0
# 70    20.0
# 71    24.0
# 72    28.0
# 73    34.0
# 74    38.0
# 75    43.0
# 76    48.0
# 77    52.0
# 78     0.0
# 79     9.0
# 80    19.0
# 81    24.0
# 82    33.0
# 83    44.0
# 84    55.0
# 85    70.0
# 86    82.0
# 87   100.0
# 88     0.0
# 89    14.0
# 90    20.0
# 91    24.0
# 92    28.0
# 93    34.0
# 94    38.0
# 95    43.0
# 96    48.0
# 97    52.0
# 98     0.0
# 99    14.0
# 100   20.0
# 101   24.0
# 102   28.0
# 103   34.0
# 104   38.0
# 105   43.0
# 106   48.0
# 107   52.0
#     Study ID            Study Name  Line ID   Line Name  \
# 0      13556  Biodesign_Henson2108    14299     WT-P-R1
# 1      13556  Biodesign_Henson2108    14299     WT-P-R1
# 2      13556  Biodesign_Henson2108    14299     WT-P-R1
# 3      13556  Biodesign_Henson2108    14299     WT-P-R1
# 4      13556  Biodesign_Henson2108    14299     WT-P-R1
# 5      13556  Biodesign_Henson2108    14299     WT-P-R1
# 6      13556  Biodesign_Henson2108    14299     WT-P-R1
# 7      13556  Biodesign_Henson2108    14299     WT-P-R1
# 8      13556  Biodesign_Henson2108    14300     WT-P-R2
# 9      13556  Biodesign_Henson2108    14300     WT-P-R2
# 10     13556  Biodesign_Henson2108    14300     WT-P-R2
# 11     13556  Biodesign_Henson2108    14300     WT-P-R2
# 12     13556  Biodesign_Henson2108    14300     WT-P-R2
# 13     13556  Biodesign_Henson2108    14300     WT-P-R2
# 14     13556  Biodesign_Henson2108    14300     WT-P-R2
# 15     13556  Biodesign_Henson2108    14300     WT-P-R2
# 16     13556  Biodesign_Henson2108    14301     WT-P-R3
# 17     13556  Biodesign_Henson2108    14301     WT-P-R3
# 18     13556  Biodesign_Henson2108    14301     WT-P-R3
# 19     13556  Biodesign_Henson2108    14301     WT-P-R3
# 20     13556  Biodesign_Henson2108    14301     WT-P-R3
# 21     13556  Biodesign_Henson2108    14301     WT-P-R3
# 22     13556  Biodesign_Henson2108    14301     WT-P-R3
# 23     13556  Biodesign_Henson2108    14301     WT-P-R3
# 24     13556  Biodesign_Henson2108    14311  PVHG6-P-R1
# 25     13556  Biodesign_Henson2108    14311  PVHG6-P-R1
# 26     13556  Biodesign_Henson2108    14311  PVHG6-P-R1
# 27     13556  Biodesign_Henson2108    14311  PVHG6-P-R1
# 28     13556  Biodesign_Henson2108    14311  PVHG6-P-R1
# 29     13556  Biodesign_Henson2108    14311  PVHG6-P-R1
# 30     13556  Biodesign_Henson2108    14311  PVHG6-P-R1
# 31     13556  Biodesign_Henson2108    14311  PVHG6-P-R1
# 32     13556  Biodesign_Henson2108    14312  PVHG6-P-R2
# 33     13556  Biodesign_Henson2108    14312  PVHG6-P-R2
# 34     13556  Biodesign_Henson2108    14312  PVHG6-P-R2
# 35     13556  Biodesign_Henson2108    14312  PVHG6-P-R2
# 36     13556  Biodesign_Henson2108    14312  PVHG6-P-R2
# 37     13556  Biodesign_Henson2108    14312  PVHG6-P-R2
# 38     13556  Biodesign_Henson2108    14312  PVHG6-P-R2
# 39     13556  Biodesign_Henson2108    14312  PVHG6-P-R2
# 40     13556  Biodesign_Henson2108    14313  PVHG6-P-R3
# 41     13556  Biodesign_Henson2108    14313  PVHG6-P-R3
# 42     13556  Biodesign_Henson2108    14313  PVHG6-P-R3
# 43     13556  Biodesign_Henson2108    14313  PVHG6-P-R3
# 44     13556  Biodesign_Henson2108    14313  PVHG6-P-R3
# 45     13556  Biodesign_Henson2108    14313  PVHG6-P-R3
# 46     13556  Biodesign_Henson2108    14313  PVHG6-P-R3
# 47     13556  Biodesign_Henson2108    14313  PVHG6-P-R3
#
#                                      Line Description Protocol  Assay ID  \
# 0   R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14323
# 1   R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14323
# 2   R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14323
# 3   R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14323
# 4   R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14323
# 5   R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14323
# 6   R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14323
# 7   R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14323
# 8   R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14324
# 9   R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14324
# 10  R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14324
# 11  R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14324
# 12  R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14324
# 13  R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14324
# 14  R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14324
# 15  R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14324
# 16  R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14325
# 17  R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14325
# 18  R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14325
# 19  R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14325
# 20  R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14325
# 21  R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14325
# 22  R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14325
# 23  R. Opacus wild type strain with 0.5 g/l PHE as...     HPLC     14325
# 24  R. Opacus adaptively evolved strain6 with 0.5 ...     HPLC     14326
# 25  R. Opacus adaptively evolved strain6 with 0.5 ...     HPLC     14326
# 26  R. Opacus adaptively evolved strain6 with 0.5 ...     HPLC     14326
# 27  R. Opacus adaptively evolved strain6 with 0.5 ...     HPLC     14326
# 28  R. Opacus adaptively evolved strain6 with 0.5 ...     HPLC     14326
# 29  R. Opacus adaptively evolved strain6 with 0.5 ...     HPLC     14326
# 30  R. Opacus adaptively evolved strain6 with 0.5 ...     HPLC     14326
# 31  R. Opacus adaptively evolved strain6 with 0.5 ...     HPLC     14326
# 32  R. Opacus adaptively evolved strain6 with 0.5 ...     HPLC     14327
# 33  R. Opacus adaptively evolved strain6 with 0.5 ...     HPLC     14327
# 34  R. Opacus adaptively evolved strain6 with 0.5 ...     HPLC     14327
# 35  R. Opacus adaptively evolved strain6 with 0.5 ...     HPLC     14327
# 36  R. Opacus adaptively evolved strain6 with 0.5 ...     HPLC     14327
# 37  R. Opacus adaptively evolved strain6 with 0.5 ...     HPLC     14327
# 38  R. Opacus adaptively evolved strain6 with 0.5 ...     HPLC     14327
# 39  R. Opacus adaptively evolved strain6 with 0.5 ...     HPLC     14327
# 40  R. Opacus adaptively evolved strain6 with 0.5 ...     HPLC     14328
# 41  R. Opacus adaptively evolved strain6 with 0.5 ...     HPLC     14328
# 42  R. Opacus adaptively evolved strain6 with 0.5 ...     HPLC     14328
# 43  R. Opacus adaptively evolved strain6 with 0.5 ...     HPLC     14328
# 44  R. Opacus adaptively evolved strain6 with 0.5 ...     HPLC     14328
# 45  R. Opacus adaptively evolved strain6 with 0.5 ...     HPLC     14328
# 46  R. Opacus adaptively evolved strain6 with 0.5 ...     HPLC     14328
# 47  R. Opacus adaptively evolved strain6 with 0.5 ...     HPLC     14328
#
#     Assay Name Formal Type Measurement Type  Compartment Units    Value  Hours
# 0      WT-P-R1     cid:996           phenol            0   g/L  0.50000    0.0
# 1      WT-P-R1     cid:996           phenol            0   g/L  0.45308    8.0
# 2      WT-P-R1     cid:996           phenol            0   g/L  0.39683   20.0
# 3      WT-P-R1     cid:996           phenol            0   g/L  0.39879   24.0
# 4      WT-P-R1     cid:996           phenol            0   g/L  0.21632   32.0
# 5      WT-P-R1     cid:996           phenol            0   g/L  0.19566   44.0
# 6      WT-P-R1     cid:996           phenol            0   g/L  0.11259   48.0
# 7      WT-P-R1     cid:996           phenol            0   g/L  0.10284   60.0
# 8      WT-P-R2     cid:996           phenol            0   g/L  0.50000    0.0
# 9      WT-P-R2     cid:996           phenol            0   g/L  0.38768    8.0
# 10     WT-P-R2     cid:996           phenol            0   g/L  0.39656   20.0
# 11     WT-P-R2     cid:996           phenol            0   g/L  0.39196   24.0
# 12     WT-P-R2     cid:996           phenol            0   g/L  0.24746   32.0
# 13     WT-P-R2     cid:996           phenol            0   g/L  0.17639   44.0
# 14     WT-P-R2     cid:996           phenol            0   g/L  0.16352   48.0
# 15     WT-P-R2     cid:996           phenol            0   g/L  0.10163   60.0
# 16     WT-P-R3     cid:996           phenol            0   g/L  0.50000    0.0
# 17     WT-P-R3     cid:996           phenol            0   g/L  0.40445    8.0
# 18     WT-P-R3     cid:996           phenol            0   g/L  0.39213   20.0
# 19     WT-P-R3     cid:996           phenol            0   g/L  0.40259   24.0
# 20     WT-P-R3     cid:996           phenol            0   g/L  0.26148   32.0
# 21     WT-P-R3     cid:996           phenol            0   g/L  0.16939   44.0
# 22     WT-P-R3     cid:996           phenol            0   g/L  0.12861   48.0
# 23     WT-P-R3     cid:996           phenol            0   g/L  0.11875   60.0
# 24  PVHG6-P-R1     cid:996           phenol            0   g/L  0.50000    0.0
# 25  PVHG6-P-R1     cid:996           phenol            0   g/L  0.43818    8.0
# 26  PVHG6-P-R1     cid:996           phenol            0   g/L  0.39068   20.0
# 27  PVHG6-P-R1     cid:996           phenol            0   g/L  0.40487   24.0
# 28  PVHG6-P-R1     cid:996           phenol            0   g/L  0.04500   32.0
# 29  PVHG6-P-R1     cid:996           phenol            0   g/L  0.00872   44.0
# 30  PVHG6-P-R1     cid:996           phenol            0   g/L  0.00872   48.0
# 31  PVHG6-P-R1     cid:996           phenol            0   g/L  0.00872   60.0
# 32  PVHG6-P-R2     cid:996           phenol            0   g/L  0.50000    0.0
# 33  PVHG6-P-R2     cid:996           phenol            0   g/L  0.43044    8.0
# 34  PVHG6-P-R2     cid:996           phenol            0   g/L  0.42956   20.0
# 35  PVHG6-P-R2     cid:996           phenol            0   g/L  0.41112   24.0
# 36  PVHG6-P-R2     cid:996           phenol            0   g/L  0.00872   32.0
# 37  PVHG6-P-R2     cid:996           phenol            0   g/L  0.00872   44.0
# 38  PVHG6-P-R2     cid:996           phenol            0   g/L  0.00872   48.0
# 39  PVHG6-P-R2     cid:996           phenol            0   g/L  0.00872   60.0
# 40  PVHG6-P-R3     cid:996           phenol            0   g/L  0.50000    0.0
# 41  PVHG6-P-R3     cid:996           phenol            0   g/L  0.43764    8.0
# 42  PVHG6-P-R3     cid:996           phenol            0   g/L  0.41138   20.0
# 43  PVHG6-P-R3     cid:996           phenol            0   g/L  0.41410   24.0
# 44  PVHG6-P-R3     cid:996           phenol            0   g/L  0.00872   32.0
# 45  PVHG6-P-R3     cid:996           phenol            0   g/L  0.00872   44.0
# 46  PVHG6-P-R3     cid:996           phenol            0   g/L  0.00872   48.0
# 47  PVHG6-P-R3     cid:996           phenol            0   g/L  0.00872   60.0
# substrate data has 48 lines
# OD data has 60 lines

# %%
GRAMS_BIOMASS_PER_LITER_PER_OD = 0.368 # 1 OD = 0.35 g/L of biomass

# %%
#Predictions:
#display(WTR1)

#growth_rate = 
#display(WTR1.loc[0,'Value'])
#growth1 = math.log((WTR1.loc[1,'Value']*GRAMS_BIOMASS_PER_LITER_PER_OD)/(WTR1.loc[0,'Value']*GRAMS_BIOMASS_PER_LITER_PER_OD))
#growth_rate1 = growth1/(WTR1.loc[1,'Hours']-WTR1.loc[0,'Hours'])
#display(growth_rate)
def calcquantities(ODdata, Subdata, molar_mass, max_time=0):
    if max_time != 0:
        ODdata = ODdata[ODdata['Hours'] < max_time]
        Subdata = Subdata[Subdata['Hours'] < max_time]
#growth is the slope of log(biomass) vs. time
#     ODdata=WTR1OD
#     Subdata=WTR1Sub
    inittime=ODdata[['Hours']].idxmin()#calculate index of initial time in dataframe
    growth_rate, _, _, _, _ = linregress(ODdata['Hours'].to_numpy(), [math.log(val) for val in ODdata['Biomass Conc'].to_numpy()])
    initindex = inittime.values[0]

    # biomass X = X0*e^(μ*t)
    biomass_sim = [ODdata.loc[inittime,'Biomass Conc'].values[0]*math.exp(growth_rate*time) for time in ODdata['Hours']]
    #display(biomass_sim)

    # actual consumption = S0 - S
    inittimesub = Subdata[['Hours']].idxmin()#calculate index of initial time in dataframe
    initindexsub = inittimesub.values[0]
    #display(initindex)
    timestartsub = Subdata.loc[inittimesub+1, 'Hours'].values
    #display(timestartsub)
    sub_consumed = [Subdata.loc[inittimesub,'Value'].values[0]*1000/molar_mass - sub_value for sub_value in Subdata['Value']*1000/molar_mass]
    #display(sub_consumed)
    
    # new biomass X = X0 - X
    biomass_sim_growth = [sim_val - ODdata.loc[inittime,'Biomass Conc'].values[0] for sim_val in biomass_sim]
    #display(biomass_sim_growth)
    # yield is the amount of biomass that can be made from a mmol of substrate
    yield_coeff, _, _, _, _ = linregress(sub_consumed, biomass_sim_growth[0:len(sub_consumed)])#this should be done differently!!!!
    # S = S0 - (1/yield)*X
    print('YC', yield_coeff)
    substrate_sim = [Subdata.loc[inittimesub,'Value'] - 1/yield_coeff*val for val in biomass_sim_growth]
    
    # units work out to mmol substrate consumed / (g biomass * hr)
    substrate_consumption_rate = (1/yield_coeff) * growth_rate
    print('Sub', substrate_consumption_rate)
    
    total_time = ODdata['Hours'][ODdata.index[-1]] - ODdata.loc[initindex,'Hours']
    times = ODdata['Hours'].values

    return growth_rate, yield_coeff, substrate_consumption_rate, total_time, times

# %% [markdown]
# #### **Yoneda WT with 1.5g/L Phenol**

# %%
strindlist = ['WT-R1', 'WT-R2', 'WT-R3']

# %%
for i in strindlist:
    if i=='WT-R1':
        WTR1OD = OD[OD['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        WTR1Sub = Sub[Sub['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        #newvals = GRAMS_BIOMASS_PER_LITER_PER_OD*WTR1OD.loc['Value'].to_numpy()
        WTR1OD.loc[:,'Biomass Conc'] = GRAMS_BIOMASS_PER_LITER_PER_OD*WTR1OD.loc[:,'Value']#newvals
    if i=='WT-R2':
        WTR2OD = OD[OD['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        WTR2Sub = Sub[Sub['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        #newvals = GRAMS_BIOMASS_PER_LITER_PER_OD*WTR1OD.loc['Value'].to_numpy()
        WTR2OD.loc[:,'Biomass Conc'] = GRAMS_BIOMASS_PER_LITER_PER_OD*WTR2OD.loc[:,'Value']#newvals
    if i=='WT-R3':
        WTR3OD = OD[OD['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        WTR3Sub = Sub[Sub['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        #newvals = GRAMS_BIOMASS_PER_LITER_PER_OD*WTR1OD.loc['Value'].to_numpy()
        WTR3OD.loc[:,'Biomass Conc'] = GRAMS_BIOMASS_PER_LITER_PER_OD*WTR3OD.loc[:,'Value']#newvals

# %%
growth_rateWTR1, yield_coeffWTR1, substrate_consumption_rateWTR1, total_timeWTR1, timesWTR1 = calcquantities(WTR1OD, WTR1Sub, molar_mass=94.11)
growth_rateWTR2, yield_coeffWTR2, substrate_consumption_rateWTR2, total_timeWTR2, timesWTR2 = calcquantities(WTR2OD, WTR2Sub, molar_mass=94.11)
growth_rateWTR3, yield_coeffWTR3, substrate_consumption_rateWTR3, total_timeWTR3, timesWTR3 = calcquantities(WTR3OD, WTR3Sub, molar_mass=94.11)
# Out:
# YC 0.027827318038384764
# Sub 0.6710108805808497
# YC 0.024876645223976222
# Sub 0.7050026931406864
# YC 0.032157638171491094
# Sub 0.6285659287272015

# %% [markdown]
# ##### **Create dataframe and add results**

# %%
#create dataframe for all results:
indlist = ['growth_rate', 'yield_coeff', 'substrate_consumption_rate', 'growth_rate_std', 'yield_coeff_std', 'substr_cons_rate_std']
strainslist = ['WT-R', 'EVOL33-R', 'EVOL40-R', 'WT-G', 'EVOL33-G', 'EVOL40-G', 'WT-G-N', 'EVOL33-G-N', 'EVOL40-G-N', 'WT-P-R', 'PVHG6-P-R']
growthandsubstrdata = pd.DataFrame(index=strainslist, columns=indlist)
growthandsubstrdata.at['WT-R',:]=[np.average([growth_rateWTR1,growth_rateWTR2,growth_rateWTR3]), np.average([yield_coeffWTR1,yield_coeffWTR2, yield_coeffWTR3]), np.average([substrate_consumption_rateWTR1, substrate_consumption_rateWTR2, substrate_consumption_rateWTR3]), np.std([growth_rateWTR1,growth_rateWTR2,growth_rateWTR3]), np.std([yield_coeffWTR1,yield_coeffWTR2, yield_coeffWTR3]), np.std([substrate_consumption_rateWTR1, substrate_consumption_rateWTR2, substrate_consumption_rateWTR3])]
display(growthandsubstrdata)
# Out:
#            growth_rate yield_coeff substrate_consumption_rate growth_rate_std  \
# WT-R         0.0188079   0.0282872                   0.668193       0.0010963
# EVOL33-R           NaN         NaN                        NaN             NaN
# EVOL40-R           NaN         NaN                        NaN             NaN
# WT-G               NaN         NaN                        NaN             NaN
# EVOL33-G           NaN         NaN                        NaN             NaN
# EVOL40-G           NaN         NaN                        NaN             NaN
# WT-G-N             NaN         NaN                        NaN             NaN
# EVOL33-G-N         NaN         NaN                        NaN             NaN
# EVOL40-G-N         NaN         NaN                        NaN             NaN
# WT-P-R             NaN         NaN                        NaN             NaN
# PVHG6-P-R          NaN         NaN                        NaN             NaN
#
#            yield_coeff_std substr_cons_rate_std
# WT-R            0.00299019            0.0312687
# EVOL33-R               NaN                  NaN
# EVOL40-R               NaN                  NaN
# WT-G                   NaN                  NaN
# EVOL33-G               NaN                  NaN
# EVOL40-G               NaN                  NaN
# WT-G-N                 NaN                  NaN
# EVOL33-G-N             NaN                  NaN
# EVOL40-G-N             NaN                  NaN
# WT-P-R                 NaN                  NaN
# PVHG6-P-R              NaN                  NaN

# %% [markdown]
# #### **Yoneda Evol33 with 1.5g/L Phenol**

# %%
strindlist = ['EVOL33-R1', 'EVOL33-R2', 'EVOL33-R3']

# %%
for i in strindlist:
    if i=='EVOL33-R1':
        EVOL33R1OD = OD[OD['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        EVOL33R1Sub = Sub[Sub['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        #newvals = GRAMS_BIOMASS_PER_LITER_PER_OD*EVOL33R1OD.loc['Value'].to_numpy()
        EVOL33R1OD.loc[:,'Biomass Conc'] = GRAMS_BIOMASS_PER_LITER_PER_OD*EVOL33R1OD.loc[:,'Value']#newvals
    if i=='EVOL33-R2':
        EVOL33R2OD = OD[OD['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        EVOL33R2Sub = Sub[Sub['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        #newvals = GRAMS_BIOMASS_PER_LITER_PER_OD*EVOL33R1OD.loc['Value'].to_numpy()
        EVOL33R2OD.loc[:,'Biomass Conc'] = GRAMS_BIOMASS_PER_LITER_PER_OD*EVOL33R2OD.loc[:,'Value']#newvals
    if i=='EVOL33-R3':
        EVOL33R3OD = OD[OD['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        EVOL33R3Sub = Sub[Sub['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        #newvals = GRAMS_BIOMASS_PER_LITER_PER_OD*EVOL33R1OD.loc['Value'].to_numpy()
        EVOL33R3OD.loc[:,'Biomass Conc'] = GRAMS_BIOMASS_PER_LITER_PER_OD*EVOL33R3OD.loc[:,'Value']#newvals

# %%
growth_rateEVOL33R1, yield_coeffEVOL33R1, substrate_consumption_rateEVOL33R1, total_timeEVOL33R1, timesEVOL33R1 = calcquantities(EVOL33R1OD, EVOL33R1Sub, molar_mass=94.11)
growth_rateEVOL33R2, yield_coeffEVOL33R2, substrate_consumption_rateEVOL33R2, total_timeEVOL33R2, timesEVOL33R2 = calcquantities(EVOL33R2OD, EVOL33R2Sub, molar_mass=94.11)
growth_rateEVOL33R3, yield_coeffEVOL33R3, substrate_consumption_rateEVOL33R3, total_timeEVOL33R3, timesEVOL33R3 = calcquantities(EVOL33R3OD, EVOL33R3Sub, molar_mass=94.11)
# Out:
# YC 0.028037553149950746
# Sub 0.9616343282845016
# YC 0.03288253826088062
# Sub 0.9237370203865367
# YC 0.03186926792938403
# Sub 0.9041486727592701

# %% [markdown]
# ##### **Add results to dataframe**

# %%
#create dataframe for all results:
#indlist = ['growth_rate', 'yield_coeff', 'substrate_consumption_rate', 'growth_rate_std']
#strainslist = ['WT-R', 'EVOL33-R', 'EVOL40-R', 'WT-G', 'EVOL33-G', 'EVOL40-G', 'WT-G-N', 'EVOL33-G-N', 'EVOL40-G-N', 'WT-P-R', 'PVHG6-P-R']
#growthandsubstrdata = pd.DataFrame(index=strainslist, columns=indlist)
growthandsubstrdata.at['EVOL33-R',:]=[np.average([growth_rateEVOL33R1,growth_rateEVOL33R2,growth_rateEVOL33R3]), np.average([yield_coeffEVOL33R1,yield_coeffEVOL33R2, yield_coeffEVOL33R3]), np.average([substrate_consumption_rateEVOL33R1, substrate_consumption_rateEVOL33R2, substrate_consumption_rateEVOL33R3]),np.std([growth_rateEVOL33R1,growth_rateEVOL33R2,growth_rateEVOL33R3]), np.std([yield_coeffEVOL33R1,yield_coeffEVOL33R2, yield_coeffEVOL33R3]), np.std([substrate_consumption_rateEVOL33R1, substrate_consumption_rateEVOL33R2, substrate_consumption_rateEVOL33R3])]
display(growthandsubstrdata)
# Out:
#            growth_rate yield_coeff substrate_consumption_rate growth_rate_std  \
# WT-R         0.0188079   0.0282872                   0.668193       0.0010963
# EVOL33-R     0.0287171   0.0309298                    0.92984      0.00139503
# EVOL40-R           NaN         NaN                        NaN             NaN
# WT-G               NaN         NaN                        NaN             NaN
# EVOL33-G           NaN         NaN                        NaN             NaN
# EVOL40-G           NaN         NaN                        NaN             NaN
# WT-G-N             NaN         NaN                        NaN             NaN
# EVOL33-G-N         NaN         NaN                        NaN             NaN
# EVOL40-G-N         NaN         NaN                        NaN             NaN
# WT-P-R             NaN         NaN                        NaN             NaN
# PVHG6-P-R          NaN         NaN                        NaN             NaN
#
#            yield_coeff_std substr_cons_rate_std
# WT-R            0.00299019            0.0312687
# EVOL33-R        0.00208653            0.0238619
# EVOL40-R               NaN                  NaN
# WT-G                   NaN                  NaN
# EVOL33-G               NaN                  NaN
# EVOL40-G               NaN                  NaN
# WT-G-N                 NaN                  NaN
# EVOL33-G-N             NaN                  NaN
# EVOL40-G-N             NaN                  NaN
# WT-P-R                 NaN                  NaN
# PVHG6-P-R              NaN                  NaN

# %% [markdown]
# #### **Yoneda Evol40 with 1.5g/L Phenol**

# %%
strindlist = ['EVOL40-R1', 'EVOL40-R2', 'EVOL40-R3']

# %%
for i in strindlist:
    if i=='EVOL40-R1':
        EVOL40R1OD = OD[OD['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        EVOL40R1Sub = Sub[Sub['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        #newvals = GRAMS_BIOMASS_PER_LITER_PER_OD*EVOL40R1OD.loc['Value'].to_numpy()
        EVOL40R1OD.loc[:,'Biomass Conc'] = GRAMS_BIOMASS_PER_LITER_PER_OD*EVOL40R1OD.loc[:,'Value']#newvals
    if i=='EVOL40-R2':
        EVOL40R2OD = OD[OD['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        EVOL40R2Sub = Sub[Sub['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        #newvals = GRAMS_BIOMASS_PER_LITER_PER_OD*EVOL40R1OD.loc['Value'].to_numpy()
        EVOL40R2OD.loc[:,'Biomass Conc'] = GRAMS_BIOMASS_PER_LITER_PER_OD*EVOL40R2OD.loc[:,'Value']#newvals
    if i=='EVOL40-R3':
        EVOL40R3OD = OD[OD['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        EVOL40R3Sub = Sub[Sub['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        #newvals = GRAMS_BIOMASS_PER_LITER_PER_OD*EVOL40R1OD.loc['Value'].to_numpy()
        EVOL40R3OD.loc[:,'Biomass Conc'] = GRAMS_BIOMASS_PER_LITER_PER_OD*EVOL40R3OD.loc[:,'Value']#newvals

# %%
growth_rateEVOL40R1, yield_coeffEVOL40R1, substrate_consumption_rateEVOL40R1, total_timeEVOL40R1, timesEVOL40R1 = calcquantities(EVOL40R1OD, EVOL40R1Sub, molar_mass=94.11)
growth_rateEVOL40R2, yield_coeffEVOL40R2, substrate_consumption_rateEVOL40R2, total_timeEVOL40R2, timesEVOL40R2 = calcquantities(EVOL40R2OD, EVOL40R2Sub, molar_mass=94.11)
growth_rateEVOL40R3, yield_coeffEVOL40R3, substrate_consumption_rateEVOL40R3, total_timeEVOL40R3, timesEVOL40R3 = calcquantities(EVOL40R3OD, EVOL40R3Sub, molar_mass=94.11)
# Out:
# YC 0.030022929822034385
# Sub 0.9075724886904972
# YC 0.03436356000982102
# Sub 0.8660165805735885
# YC 0.03388219470406636
# Sub 0.8609269368883709

# %% [markdown]
# ##### **Add results to dataframe**

# %%
#create dataframe for all results:
#indlist = ['growth_rate', 'yield_coeff', 'substrate_consumption_rate', 'growth_rate_std']
#strainslist = ['WT-R', 'EVOL40-R', 'EVOL40-R', 'WT-G', 'EVOL40-G', 'EVOL40-G', 'WT-G-N', 'EVOL33-G-N', 'EVOL40-G-N', 'WT-P-R', 'PVHG6-P-R']
#growthandsubstrdata = pd.DataFrame(index=strainslist, columns=indlist)
growthandsubstrdata.at['EVOL40-R',:]=[np.average([growth_rateEVOL40R1,growth_rateEVOL40R2,growth_rateEVOL40R3]), np.average([yield_coeffEVOL40R1,yield_coeffEVOL40R2, yield_coeffEVOL40R3]), np.average([substrate_consumption_rateEVOL40R1, substrate_consumption_rateEVOL40R2, substrate_consumption_rateEVOL40R3]), np.std([growth_rateEVOL40R1,growth_rateEVOL40R2,growth_rateEVOL40R3]), np.std([yield_coeffEVOL40R1,yield_coeffEVOL40R2, yield_coeffEVOL40R3]), np.std([substrate_consumption_rateEVOL40R1, substrate_consumption_rateEVOL40R2, substrate_consumption_rateEVOL40R3])]
display(growthandsubstrdata)
# Out:
#            growth_rate yield_coeff substrate_consumption_rate growth_rate_std  \
# WT-R         0.0188079   0.0282872                   0.668193       0.0010963
# EVOL33-R     0.0287171   0.0309298                    0.92984      0.00139503
# EVOL40-R     0.0287258   0.0327562                   0.878172      0.00107233
# WT-G               NaN         NaN                        NaN             NaN
# EVOL33-G           NaN         NaN                        NaN             NaN
# EVOL40-G           NaN         NaN                        NaN             NaN
# WT-G-N             NaN         NaN                        NaN             NaN
# EVOL33-G-N         NaN         NaN                        NaN             NaN
# EVOL40-G-N         NaN         NaN                        NaN             NaN
# WT-P-R             NaN         NaN                        NaN             NaN
# PVHG6-P-R          NaN         NaN                        NaN             NaN
#
#            yield_coeff_std substr_cons_rate_std
# WT-R            0.00299019            0.0312687
# EVOL33-R        0.00208653            0.0238619
# EVOL40-R         0.0019427            0.0208929
# WT-G                   NaN                  NaN
# EVOL33-G               NaN                  NaN
# EVOL40-G               NaN                  NaN
# WT-G-N                 NaN                  NaN
# EVOL33-G-N             NaN                  NaN
# EVOL40-G-N             NaN                  NaN
# WT-P-R                 NaN                  NaN
# PVHG6-P-R              NaN                  NaN

# %% [markdown]
# #### **Yoneda WT with 1.0g/L Glucose, 1.0 g/l Ammonium Sulfate**

# %%
WTGOD = OD[OD['Line Name']=='WT-G']#pd.read_csv(ODfile)
WTGSub = Sub[Sub['Line Name']=='WT-G']#pd.read_csv(ODfile)
#newvals = GRAMS_BIOMASS_PER_LITER_PER_OD*WTGOD.loc['Value'].to_numpy()
WTGOD.loc[:,'Biomass Conc'] = GRAMS_BIOMASS_PER_LITER_PER_OD*WTGOD.loc[:,'Value']#newvals

# %%
growth_rateWTG, yield_coeffWTG, substrate_consumption_rateWTG, total_timeWTG, timesWTG = calcquantities(WTGOD, WTGSub, molar_mass=180.16)
# Out:
# YC 1.2092167902833597
# Sub 0.02605723782268901

# %% [markdown]
# ##### **Add results to dataframe**

# %%
#create dataframe for all results:
#indlist = ['growth_rate', 'yield_coeff', 'substrate_consumption_rate', 'growth_rate_std']
#strainslist = ['WT-R', 'EVOL33-R', 'EVOL40-R', 'WT-G', 'EVOL33-G', 'EVOL40-G', 'WT-G-N', 'EVOL33-G-N', 'EVOL40-G-N', 'WT-P-R', 'PVHG6-P-R']
#growthandsubstrdata = pd.DataFrame(index=strainslist, columns=indlist)
growthandsubstrdata.at['WT-G',:]=[growth_rateWTG, yield_coeffWTG, substrate_consumption_rateWTG, 0.0, 0.0, 0.0]
display(growthandsubstrdata)
# Out:
#            growth_rate yield_coeff substrate_consumption_rate growth_rate_std  \
# WT-R         0.0188079   0.0282872                   0.668193       0.0010963
# EVOL33-R     0.0287171   0.0309298                    0.92984      0.00139503
# EVOL40-R     0.0287258   0.0327562                   0.878172      0.00107233
# WT-G         0.0315088     1.20922                  0.0260572               0
# EVOL33-G           NaN         NaN                        NaN             NaN
# EVOL40-G           NaN         NaN                        NaN             NaN
# WT-G-N             NaN         NaN                        NaN             NaN
# EVOL33-G-N         NaN         NaN                        NaN             NaN
# EVOL40-G-N         NaN         NaN                        NaN             NaN
# WT-P-R             NaN         NaN                        NaN             NaN
# PVHG6-P-R          NaN         NaN                        NaN             NaN
#
#            yield_coeff_std substr_cons_rate_std
# WT-R            0.00299019            0.0312687
# EVOL33-R        0.00208653            0.0238619
# EVOL40-R         0.0019427            0.0208929
# WT-G                     0                    0
# EVOL33-G               NaN                  NaN
# EVOL40-G               NaN                  NaN
# WT-G-N                 NaN                  NaN
# EVOL33-G-N             NaN                  NaN
# EVOL40-G-N             NaN                  NaN
# WT-P-R                 NaN                  NaN
# PVHG6-P-R              NaN                  NaN

# %% [markdown]
# #### **Yoneda EVOL33 with 1.0g/L Glucose, 1.0 g/l Ammonium Sulfate**

# %%
EVOL33GOD = OD[OD['Line Name']=='EVOL33-G']#pd.read_csv(ODfile)
EVOL33GSub = Sub[Sub['Line Name']=='EVOL33-G']#pd.read_csv(ODfile)
#newvals = GRAMS_BIOMASS_PER_LITER_PER_OD*EVOL33GOD.loc['Value'].to_numpy()
EVOL33GOD.loc[:,'Biomass Conc'] = GRAMS_BIOMASS_PER_LITER_PER_OD*EVOL33GOD.loc[:,'Value']#newvals

# %%
growth_rateEVOL33G, yield_coeffEVOL33G, substrate_consumption_rateEVOL33G, total_timeEVOL33G, timesEVOL33G = calcquantities(EVOL33GOD, WTGSub, molar_mass=180.16)
# Out:
# YC 1.1832168895748088
# Sub 0.026325331169341448

# %% [markdown]
# ##### **Add results to dataframe**

# %%
#create dataframe for all results:
#indlist = ['growth_rate', 'yield_coeff', 'substrate_consumption_rate', 'growth_rate_std']
#strainslist = ['WT-R', 'EVOL33-R', 'EVOL40-R', 'WT-G', 'EVOL33-G', 'EVOL40-G', 'WT-G-N', 'EVOL33-G-N', 'EVOL40-G-N', 'WT-P-R', 'PVHG6-P-R']
#growthandsubstrdata = pd.DataFrame(index=strainslist, columns=indlist)
growthandsubstrdata.at['EVOL33-G',:]=[growth_rateEVOL33G, yield_coeffEVOL33G, substrate_consumption_rateEVOL33G, 0.0, 0.0, 0.0]
display(growthandsubstrdata)
# Out:
#            growth_rate yield_coeff substrate_consumption_rate growth_rate_std  \
# WT-R         0.0188079   0.0282872                   0.668193       0.0010963
# EVOL33-R     0.0287171   0.0309298                    0.92984      0.00139503
# EVOL40-R     0.0287258   0.0327562                   0.878172      0.00107233
# WT-G         0.0315088     1.20922                  0.0260572               0
# EVOL33-G     0.0311486     1.18322                  0.0263253               0
# EVOL40-G           NaN         NaN                        NaN             NaN
# WT-G-N             NaN         NaN                        NaN             NaN
# EVOL33-G-N         NaN         NaN                        NaN             NaN
# EVOL40-G-N         NaN         NaN                        NaN             NaN
# WT-P-R             NaN         NaN                        NaN             NaN
# PVHG6-P-R          NaN         NaN                        NaN             NaN
#
#            yield_coeff_std substr_cons_rate_std
# WT-R            0.00299019            0.0312687
# EVOL33-R        0.00208653            0.0238619
# EVOL40-R         0.0019427            0.0208929
# WT-G                     0                    0
# EVOL33-G                 0                    0
# EVOL40-G               NaN                  NaN
# WT-G-N                 NaN                  NaN
# EVOL33-G-N             NaN                  NaN
# EVOL40-G-N             NaN                  NaN
# WT-P-R                 NaN                  NaN
# PVHG6-P-R              NaN                  NaN

# %% [markdown]
# #### **Yoneda EVOL40 with 1.0g/L Glucose, 1.0 g/l Ammonium Sulfate**

# %%
EVOL40GOD = OD[OD['Line Name']=='EVOL40-G']#pd.read_csv(ODfile)
EVOL40GSub = Sub[Sub['Line Name']=='EVOL40-G']#pd.read_csv(ODfile)
#newvals = GRAMS_BIOMASS_PER_LITER_PER_OD*EVOL40GOD.loc['Value'].to_numpy()
EVOL40GOD.loc[:,'Biomass Conc'] = GRAMS_BIOMASS_PER_LITER_PER_OD*EVOL40GOD.loc[:,'Value']#newvals

# %%
growth_rateEVOL40G, yield_coeffEVOL40G, substrate_consumption_rateEVOL40G, total_timeEVOL40G, timesEVOL40G = calcquantities(EVOL40GOD, EVOL40GSub, molar_mass=180.16)
# Out:
# YC -0.5257346324170699
# Sub -0.059464757011802157

# %% [markdown]
# ##### **Add results to dataframe**

# %%
#create dataframe for all results:
#indlist = ['growth_rate', 'yield_coeff', 'substrate_consumption_rate', 'growth_rate_std']
#strainslist = ['WT-R', 'EVOL33-R', 'EVOL40-R', 'WT-G', 'EVOL33-G', 'EVOL40-G', 'WT-G-N', 'EVOL40-G-N', 'EVOL40-G-N', 'WT-P-R', 'PVHG6-P-R']
#growthandsubstrdata = pd.DataFrame(index=strainslist, columns=indlist)
growthandsubstrdata.at['EVOL40-G',:]=[growth_rateEVOL40G, yield_coeffEVOL40G, substrate_consumption_rateEVOL40G, 0.0, 0.0, 0.0]
display(growthandsubstrdata)
# Out:
#            growth_rate yield_coeff substrate_consumption_rate growth_rate_std  \
# WT-R         0.0188079   0.0282872                   0.668193       0.0010963
# EVOL33-R     0.0287171   0.0309298                    0.92984      0.00139503
# EVOL40-R     0.0287258   0.0327562                   0.878172      0.00107233
# WT-G         0.0315088     1.20922                  0.0260572               0
# EVOL33-G     0.0311486     1.18322                  0.0263253               0
# EVOL40-G     0.0312627   -0.525735                 -0.0594648               0
# WT-G-N             NaN         NaN                        NaN             NaN
# EVOL33-G-N         NaN         NaN                        NaN             NaN
# EVOL40-G-N         NaN         NaN                        NaN             NaN
# WT-P-R             NaN         NaN                        NaN             NaN
# PVHG6-P-R          NaN         NaN                        NaN             NaN
#
#            yield_coeff_std substr_cons_rate_std
# WT-R            0.00299019            0.0312687
# EVOL33-R        0.00208653            0.0238619
# EVOL40-R         0.0019427            0.0208929
# WT-G                     0                    0
# EVOL33-G                 0                    0
# EVOL40-G                 0                    0
# WT-G-N                 NaN                  NaN
# EVOL33-G-N             NaN                  NaN
# EVOL40-G-N             NaN                  NaN
# WT-P-R                 NaN                  NaN
# PVHG6-P-R              NaN                  NaN

# %% [markdown]
# #### **Yoneda WT with 1.0g/L Glucose, 0.05 g/l Ammonium Sulfate**

# %%
WTGNOD = OD[OD['Line Name'].str.contains('WT-G-N')]#pd.read_csv(ODfile)
WTGNSub = Sub[Sub['Line Name'].str.contains('WT-G-N')]#pd.read_csv(ODfile)
#newvals = GRAMS_BIOMASS_PER_LITER_PER_OD*WTGNOD.loc['Value'].to_numpy()
WTGNOD.loc[:,'Biomass Conc'] = GRAMS_BIOMASS_PER_LITER_PER_OD*WTGNOD.loc[:,'Value']#newvals

# %%
growth_rateWTGN, yield_coeffWTGN, substrate_consumption_rateWTGN, total_timeWTGN, timesWTGN = calcquantities(WTGNOD, WTGNSub, molar_mass=180.16)
# Out:
# YC 1.9281822253644023
# Sub 0.020228504126781063

# %% [markdown]
# ##### **Add results to dataframe**

# %%
#create dataframe for all results:
#indlist = ['growth_rate', 'yield_coeff', 'substrate_consumption_rate', 'growth_rate_std']
#strainslist = ['WT-R', 'EVOL33-R', 'EVOL40-R', 'WT-G', 'EVOL33-G', 'EVOL40-G', 'WT-G-N', 'EVOL33-G-N', 'EVOL40-G-N', 'WT-P-R', 'PVHG6-P-R']
#growthandsubstrdata = pd.DataFrame(index=strainslist, columns=indlist)
growthandsubstrdata.at['WT-G-N',:]=[growth_rateWTGN, yield_coeffWTGN, substrate_consumption_rateWTGN, 0.0, 0.0, 0.0]
display(growthandsubstrdata)
# Out:
#            growth_rate yield_coeff substrate_consumption_rate growth_rate_std  \
# WT-R         0.0188079   0.0282872                   0.668193       0.0010963
# EVOL33-R     0.0287171   0.0309298                    0.92984      0.00139503
# EVOL40-R     0.0287258   0.0327562                   0.878172      0.00107233
# WT-G         0.0315088     1.20922                  0.0260572               0
# EVOL33-G     0.0311486     1.18322                  0.0263253               0
# EVOL40-G     0.0312627   -0.525735                 -0.0594648               0
# WT-G-N       0.0390042     1.92818                  0.0202285               0
# EVOL33-G-N         NaN         NaN                        NaN             NaN
# EVOL40-G-N         NaN         NaN                        NaN             NaN
# WT-P-R             NaN         NaN                        NaN             NaN
# PVHG6-P-R          NaN         NaN                        NaN             NaN
#
#            yield_coeff_std substr_cons_rate_std
# WT-R            0.00299019            0.0312687
# EVOL33-R        0.00208653            0.0238619
# EVOL40-R         0.0019427            0.0208929
# WT-G                     0                    0
# EVOL33-G                 0                    0
# EVOL40-G                 0                    0
# WT-G-N                   0                    0
# EVOL33-G-N             NaN                  NaN
# EVOL40-G-N             NaN                  NaN
# WT-P-R                 NaN                  NaN
# PVHG6-P-R              NaN                  NaN

# %% [markdown]
# #### **Yoneda EVOL33 with 1.0g/L Glucose, 0.05 g/l Ammonium Sulfate**

# %%
EVOL33GNOD = OD[OD['Line Name'].str.contains('EVOL33-G-N')]#pd.read_csv(ODfile)
EVOL33GNSub = Sub[Sub['Line Name'].str.contains('EVOL33-G-N')]#pd.read_csv(ODfile)
#newvals = GRAMS_BIOMASS_PER_LITER_PER_OD*EVOL33GNOD.loc['Value'].to_numpy()
EVOL33GNOD.loc[:,'Biomass Conc'] = GRAMS_BIOMASS_PER_LITER_PER_OD*EVOL33GNOD.loc[:,'Value']#newvals

# %%
growth_rateEVOL33GN, yield_coeffEVOL33GN, substrate_consumption_rateEVOL33GN, total_timeEVOL33GN, timesEVOL33GN = calcquantities(EVOL33GNOD, EVOL33GNSub, molar_mass=180.16)
# Out:
# YC 1.0577876589076527
# Sub 0.030952776740702657

# %% [markdown]
# ##### **Add results to dataframe**

# %%
#create dataframe for all results:
#indlist = ['growth_rate', 'yield_coeff', 'substrate_consumption_rate', 'growth_rate_std']
#strainslist = ['WT-R', 'EVOL33-R', 'EVOL40-R', 'WT-G', 'EVOL33-G', 'EVOL40-G', 'WT-G-N', 'EVOL33-G-N', 'EVOL40-G-N', 'WT-P-R', 'PVHG6-P-R']
#growthandsubstrdata = pd.DataFrame(index=strainslist, columns=indlist)
growthandsubstrdata.at['EVOL33-G-N',:]=[growth_rateEVOL33GN, yield_coeffEVOL33GN, substrate_consumption_rateEVOL33GN, 0.0, 0.0, 0.0]
display(growthandsubstrdata)
# Out:
#            growth_rate yield_coeff substrate_consumption_rate growth_rate_std  \
# WT-R         0.0188079   0.0282872                   0.668193       0.0010963
# EVOL33-R     0.0287171   0.0309298                    0.92984      0.00139503
# EVOL40-R     0.0287258   0.0327562                   0.878172      0.00107233
# WT-G         0.0315088     1.20922                  0.0260572               0
# EVOL33-G     0.0311486     1.18322                  0.0263253               0
# EVOL40-G     0.0312627   -0.525735                 -0.0594648               0
# WT-G-N       0.0390042     1.92818                  0.0202285               0
# EVOL33-G-N   0.0327415     1.05779                  0.0309528               0
# EVOL40-G-N         NaN         NaN                        NaN             NaN
# WT-P-R             NaN         NaN                        NaN             NaN
# PVHG6-P-R          NaN         NaN                        NaN             NaN
#
#            yield_coeff_std substr_cons_rate_std
# WT-R            0.00299019            0.0312687
# EVOL33-R        0.00208653            0.0238619
# EVOL40-R         0.0019427            0.0208929
# WT-G                     0                    0
# EVOL33-G                 0                    0
# EVOL40-G                 0                    0
# WT-G-N                   0                    0
# EVOL33-G-N               0                    0
# EVOL40-G-N             NaN                  NaN
# WT-P-R                 NaN                  NaN
# PVHG6-P-R              NaN                  NaN

# %% [markdown]
# #### **Yoneda EVOL40 with 1.0g/L Glucose, 0.05 g/l Ammonium Sulfate**

# %%
EVOL40GNOD = OD[OD['Line Name'].str.contains('EVOL40-G-N')]#pd.read_csv(ODfile)
EVOL40GNSub = Sub[Sub['Line Name'].str.contains('EVOL40-G-N')]#pd.read_csv(ODfile)
#newvals = GRAMS_BIOMASS_PER_LITER_PER_OD*EVOL40GNOD.loc['Value'].to_numpy()
EVOL40GNOD.loc[:,'Biomass Conc'] = GRAMS_BIOMASS_PER_LITER_PER_OD*EVOL40GNOD.loc[:,'Value']#newvals

# %%
growth_rateEVOL40GN, yield_coeffEVOL40GN, substrate_consumption_rateEVOL40GN, total_timeEVOL40GN, timesEVOL40GN = calcquantities(EVOL40GNOD, EVOL40GNSub, molar_mass=180.16)
# Out:
# YC 2.133006254267917
# Sub 0.016013118115174904

# %% [markdown]
# ##### **Add results to dataframe**

# %%
#create dataframe for all results:
#indlist = ['growth_rate', 'yield_coeff', 'substrate_consumption_rate', 'growth_rate_std']
#strainslist = ['WT-R', 'EVOL33-R', 'EVOL40-R', 'WT-G', 'EVOL33-G', 'EVOL40-G', 'WT-G-N', 'EVOL33-G-N', 'EVOL40-G-N', 'WT-P-R', 'PVHG6-P-R']
#growthandsubstrdata = pd.DataFrame(index=strainslist, columns=indlist)
growthandsubstrdata.at['EVOL40-G-N',:]=[growth_rateEVOL40GN, yield_coeffEVOL40GN, substrate_consumption_rateEVOL40GN,  0.0, 0.0, 0.0]
display(growthandsubstrdata)
# Out:
#            growth_rate yield_coeff substrate_consumption_rate growth_rate_std  \
# WT-R         0.0188079   0.0282872                   0.668193       0.0010963
# EVOL33-R     0.0287171   0.0309298                    0.92984      0.00139503
# EVOL40-R     0.0287258   0.0327562                   0.878172      0.00107233
# WT-G         0.0315088     1.20922                  0.0260572               0
# EVOL33-G     0.0311486     1.18322                  0.0263253               0
# EVOL40-G     0.0312627   -0.525735                 -0.0594648               0
# WT-G-N       0.0390042     1.92818                  0.0202285               0
# EVOL33-G-N   0.0327415     1.05779                  0.0309528               0
# EVOL40-G-N   0.0341561     2.13301                  0.0160131               0
# WT-P-R             NaN         NaN                        NaN             NaN
# PVHG6-P-R          NaN         NaN                        NaN             NaN
#
#            yield_coeff_std substr_cons_rate_std
# WT-R            0.00299019            0.0312687
# EVOL33-R        0.00208653            0.0238619
# EVOL40-R         0.0019427            0.0208929
# WT-G                     0                    0
# EVOL33-G                 0                    0
# EVOL40-G                 0                    0
# WT-G-N                   0                    0
# EVOL33-G-N               0                    0
# EVOL40-G-N               0                    0
# WT-P-R                 NaN                  NaN
# PVHG6-P-R              NaN                  NaN

# %% [markdown]
# #### **Henson WT with 0.5g/l Phenol**

# %%
strindlist = ['WT-P-R1', 'WT-P-R2', 'WT-P-R3']

# %%
for i in strindlist:
    if i=='WT-P-R1':
        WTPR1OD = ODHen[ODHen['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        WTPR1Sub = SubHen[SubHen['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        #newvals = GRAMS_BIOMASS_PER_LITER_PER_OD*WTPR1OD.loc['Value'].to_numpy()
        WTPR1OD.loc[:,'Biomass Conc'] = GRAMS_BIOMASS_PER_LITER_PER_OD*WTPR1OD.loc[:,'Value']#newvals
    if i=='WT-P-R2':
        WTPR2OD = ODHen[ODHen['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        WTPR2Sub = SubHen[SubHen['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        #newvals = GRAMS_BIOMASS_PER_LITER_PER_OD*WTPR1OD.loc['Value'].to_numpy()
        WTPR2OD.loc[:,'Biomass Conc'] = GRAMS_BIOMASS_PER_LITER_PER_OD*WTPR2OD.loc[:,'Value']#newvals
    if i=='WT-P-R3':
        WTPR3OD = ODHen[ODHen['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        WTPR3Sub = SubHen[SubHen['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        #newvals = GRAMS_BIOMASS_PER_LITER_PER_OD*WTPR1OD.loc['Value'].to_numpy()
        WTPR3OD.loc[:,'Biomass Conc'] = GRAMS_BIOMASS_PER_LITER_PER_OD*WTPR3OD.loc[:,'Value']#newvals

# %%
growth_rateWTPR1, yield_coeffWTPR1, substrate_consumption_rateWTPR1, total_timeWTPR1, timesWTPR1 = calcquantities(WTPR1OD, WTPR1Sub, molar_mass=94.11)#, max_time=40)
growth_rateWTPR2, yield_coeffWTPR2, substrate_consumption_rateWTPR2, total_timeWTPR2, timesWTPR2 = calcquantities(WTPR2OD, WTPR2Sub, molar_mass=94.11)#, max_time=34)
growth_rateWTPR3, yield_coeffWTPR3, substrate_consumption_rateWTPR3, total_timeWTPR3, timesWTPR3 = calcquantities(WTPR3OD, WTPR3Sub, molar_mass=94.11)#, max_time=34)
# Out:
# YC 0.011876866116438851
# Sub 1.8165942877253125
# YC 0.032219937001509186
# Sub 1.6070231573739304
# YC 0.025794501662175083
# Sub 1.8600895743835884

# %% [markdown]
# ##### **Add results to dataframe**

# %%
#create dataframe for all results:
#indlist = ['growth_rate', 'yield_coeff', 'substrate_consumption_rate', 'growth_rate_std']
#strainslist = ['WT-R', 'EVOL33-R', 'EVOL40-R', 'WT-G', 'EVOL33-G', 'EVOL40-G', 'WT-G-N', 'EVOL33-G-N', 'EVOL40-G-N', 'WT-P-R', 'PVHG6-P-R']
#growthandsubstrdata = pd.DataFrame(index=strainslist, columns=indlist)
growthandsubstrdata.at['WT-P-R',:]=[np.average([growth_rateWTPR1,growth_rateWTPR2,growth_rateWTPR3]), np.average([yield_coeffWTPR1,yield_coeffWTPR2, yield_coeffWTPR3]), np.average([substrate_consumption_rateWTPR1, substrate_consumption_rateWTPR2, substrate_consumption_rateWTPR3]), np.std([growth_rateWTPR1,growth_rateWTPR2,growth_rateWTPR3]), np.std([yield_coeffWTPR1,yield_coeffWTPR2, yield_coeffWTPR3]), np.std([substrate_consumption_rateWTPR1, substrate_consumption_rateWTPR2, substrate_consumption_rateWTPR3])]
display(growthandsubstrdata)
# Out:
#            growth_rate yield_coeff substrate_consumption_rate growth_rate_std  \
# WT-R         0.0188079   0.0282872                   0.668193       0.0010963
# EVOL33-R     0.0287171   0.0309298                    0.92984      0.00139503
# EVOL40-R     0.0287258   0.0327562                   0.878172      0.00107233
# WT-G         0.0315088     1.20922                  0.0260572               0
# EVOL33-G     0.0311486     1.18322                  0.0263253               0
# EVOL40-G     0.0312627   -0.525735                 -0.0594648               0
# WT-G-N       0.0390042     1.92818                  0.0202285               0
# EVOL33-G-N   0.0327415     1.05779                  0.0309528               0
# EVOL40-G-N   0.0341561     2.13301                  0.0160131               0
# WT-P-R       0.0404446   0.0232971                    1.76124       0.0134323
# PVHG6-P-R          NaN         NaN                        NaN             NaN
#
#            yield_coeff_std substr_cons_rate_std
# WT-R            0.00299019            0.0312687
# EVOL33-R        0.00208653            0.0238619
# EVOL40-R         0.0019427            0.0208929
# WT-G                     0                    0
# EVOL33-G                 0                    0
# EVOL40-G                 0                    0
# WT-G-N                   0                    0
# EVOL33-G-N               0                    0
# EVOL40-G-N               0                    0
# WT-P-R           0.0084907             0.110481
# PVHG6-P-R              NaN                  NaN

# %% [markdown]
# #### **Henson PVHG6 with 0.5g/l Phenol**

# %%
strindlist = ['PVHG6-P-R1', 'PVHG6-P-R2', 'PVHG6-P-R3']

# %%
for i in strindlist:
    if i=='PVHG6-P-R1':
        PVHG6R1OD = ODHen[ODHen['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        PVHG6R1Sub = SubHen[SubHen['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        #newvals = GRAMS_BIOMASS_PER_LITER_PER_OD*PVHG6R1OD.loc['Value'].to_numpy()
        PVHG6R1OD.loc[:,'Biomass Conc'] = GRAMS_BIOMASS_PER_LITER_PER_OD*PVHG6R1OD.loc[:,'Value']#newvals
    if i=='PVHG6-P-R2':
        PVHG6R2OD = ODHen[ODHen['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        PVHG6R2Sub = SubHen[SubHen['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        #newvals = GRAMS_BIOMASS_PER_LITER_PER_OD*PVHG6R1OD.loc['Value'].to_numpy()
        PVHG6R2OD.loc[:,'Biomass Conc'] = GRAMS_BIOMASS_PER_LITER_PER_OD*PVHG6R2OD.loc[:,'Value']#newvals
    if i=='PVHG6-P-R3':
        PVHG6R3OD = ODHen[ODHen['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        PVHG6R3Sub = SubHen[SubHen['Line Name'].str.contains(str(i))]#pd.read_csv(ODfile)
        #newvals = GRAMS_BIOMASS_PER_LITER_PER_OD*PVHG6R1OD.loc['Value'].to_numpy()
        PVHG6R3OD.loc[:,'Biomass Conc'] = GRAMS_BIOMASS_PER_LITER_PER_OD*PVHG6R3OD.loc[:,'Value']#newvals

# %%
growth_ratePVHG6R1, yield_coeffPVHG6R1, substrate_consumption_ratePVHG6R1, total_timePVHG6R1, timesPVHG6R1 = calcquantities(PVHG6R1OD, PVHG6R1Sub, molar_mass=94.11)
growth_ratePVHG6R2, yield_coeffPVHG6R2, substrate_consumption_ratePVHG6R2, total_timePVHG6R2, timesPVHG6R2 = calcquantities(PVHG6R2OD, PVHG6R2Sub, molar_mass=94.11)
growth_ratePVHG6R3, yield_coeffPVHG6R3, substrate_consumption_ratePVHG6R3, total_timePVHG6R3, timesPVHG6R3 = calcquantities(PVHG6R3OD, PVHG6R3Sub, molar_mass=94.11)
# Out:
# YC 0.01235463630742676
# Sub 2.2465691059502366
# YC 0.02878055463989326
# Sub 2.1787588195483405
# YC 0.02782772382531321
# Sub 2.2224170427259313

# %% [markdown]
# ##### **Add results to dataframe**

# %%
#create dataframe for all results:
#indlist = ['growth_rate', 'yield_coeff', 'substrate_consumption_rate', 'growth_rate_std', 'yield_coeff_std', 'substr_cons_rate_std']
#strainslist = ['WT-R', 'EVOL33-R', 'EVOL40-R', 'WT-G', 'EVOL33-G', 'EVOL40-G', 'WT-G-N', 'EVOL33-G-N', 'EVOL40-G-N', 'WT-P-R', 'PVHG6-P-R']
#growthandsubstrdata = pd.DataFrame(index=strainslist, columns=indlist)
growthandsubstrdata.at['PVHG6-P-R',:]=[np.average([growth_ratePVHG6R1,growth_ratePVHG6R2,growth_ratePVHG6R3]), np.average([yield_coeffPVHG6R1,yield_coeffPVHG6R2, yield_coeffPVHG6R3]), np.average([substrate_consumption_ratePVHG6R1, substrate_consumption_ratePVHG6R2, substrate_consumption_ratePVHG6R3]), np.std([growth_ratePVHG6R1, growth_ratePVHG6R2, growth_ratePVHG6R3]), np.std([yield_coeffPVHG6R1,yield_coeffPVHG6R2, yield_coeffPVHG6R3]), np.std([substrate_consumption_ratePVHG6R1, substrate_consumption_ratePVHG6R2, substrate_consumption_ratePVHG6R3])]
display(growthandsubstrdata)
# Out:
#            growth_rate yield_coeff substrate_consumption_rate growth_rate_std  \
# WT-R         0.0188079   0.0282872                   0.668193       0.0010963
# EVOL33-R     0.0287171   0.0309298                    0.92984      0.00139503
# EVOL40-R     0.0287258   0.0327562                   0.878172      0.00107233
# WT-G         0.0315088     1.20922                  0.0260572               0
# EVOL33-G     0.0311486     1.18322                  0.0263253               0
# EVOL40-G     0.0312627   -0.525735                 -0.0594648               0
# WT-G-N       0.0390042     1.92818                  0.0202285               0
# EVOL33-G-N   0.0327415     1.05779                  0.0309528               0
# EVOL40-G-N   0.0341561     2.13301                  0.0160131               0
# WT-P-R       0.0404446   0.0232971                    1.76124       0.0134323
# PVHG6-P-R    0.0507687   0.0229876                    2.21591       0.0162766
#
#            yield_coeff_std substr_cons_rate_std
# WT-R            0.00299019            0.0312687
# EVOL33-R        0.00208653            0.0238619
# EVOL40-R         0.0019427            0.0208929
# WT-G                     0                    0
# EVOL33-G                 0                    0
# EVOL40-G                 0                    0
# WT-G-N                   0                    0
# EVOL33-G-N               0                    0
# EVOL40-G-N               0                    0
# WT-P-R           0.0084907             0.110481
# PVHG6-P-R       0.00752872            0.0280626

# %% [markdown]
# #### **Getting and preparing the metabolic model**

# %%
file_name =  "../../Ropacus_annotated_curated_with_phenol_custom_biomass.xml"
model = cobra.io.read_sbml_model(file_name)

# %% [markdown]
# #### **Calculate growth rate prediction via FBA and pFBA**

# %%
growthandsubstrdata['FBA_growth_rate']=pd.Series(np.zeros(len(growthandsubstrdata['growth_rate'])), index=growthandsubstrdata.index)
growthandsubstrdata['pFBA_growth_rate']=pd.Series(np.zeros(len(growthandsubstrdata['growth_rate'])), index=growthandsubstrdata.index)
display(growthandsubstrdata)
# Out:
#            growth_rate yield_coeff substrate_consumption_rate growth_rate_std  \
# WT-R         0.0188079   0.0282872                   0.668193       0.0010963
# EVOL33-R     0.0287171   0.0309298                    0.92984      0.00139503
# EVOL40-R     0.0287258   0.0327562                   0.878172      0.00107233
# WT-G         0.0315088     1.20922                  0.0260572               0
# EVOL33-G     0.0311486     1.18322                  0.0263253               0
# EVOL40-G     0.0312627   -0.525735                 -0.0594648               0
# WT-G-N       0.0390042     1.92818                  0.0202285               0
# EVOL33-G-N   0.0327415     1.05779                  0.0309528               0
# EVOL40-G-N   0.0341561     2.13301                  0.0160131               0
# WT-P-R       0.0404446   0.0232971                    1.76124       0.0134323
# PVHG6-P-R    0.0507687   0.0229876                    2.21591       0.0162766
#
#            yield_coeff_std substr_cons_rate_std  FBA_growth_rate  \
# WT-R            0.00299019            0.0312687              0.0
# EVOL33-R        0.00208653            0.0238619              0.0
# EVOL40-R         0.0019427            0.0208929              0.0
# WT-G                     0                    0              0.0
# EVOL33-G                 0                    0              0.0
# EVOL40-G                 0                    0              0.0
# WT-G-N                   0                    0              0.0
# EVOL33-G-N               0                    0              0.0
# EVOL40-G-N               0                    0              0.0
# WT-P-R           0.0084907             0.110481              0.0
# PVHG6-P-R       0.00752872            0.0280626              0.0
#
#             pFBA_growth_rate
# WT-R                     0.0
# EVOL33-R                 0.0
# EVOL40-R                 0.0
# WT-G                     0.0
# EVOL33-G                 0.0
# EVOL40-G                 0.0
# WT-G-N                   0.0
# EVOL33-G-N               0.0
# EVOL40-G-N               0.0
# WT-P-R                   0.0
# PVHG6-P-R                0.0

# %%
for index in growthandsubstrdata.index:
    with model:
        medium = model.medium
        if '-G' in index:
            model.objective = 'Growth_Glucose'
            #model.objective = 'Growth'
            sub_uptake_rate = growthandsubstrdata.loc[index,'substrate_consumption_rate']
            medium["EX_glc__D_e"] = sub_uptake_rate
            medium["EX_phenol_e"] = 0.0
            growth = 'Growth_Glucose'
            #print(index)
        else:
            model.objective = 'Growth_Phenol'
            #model.objective = 'Growth'
            sub_uptake_rate = growthandsubstrdata.loc[index,'substrate_consumption_rate']
            medium["EX_glc__D_e"] = 0.0
            medium["EX_phenol_e"] = sub_uptake_rate
            growth = 'Growth_Phenol'
            
            #print(index)
        model.medium = medium
        
        FBA_solution = model.optimize().objective_value
        try:
            pFBA_solution = cobra.flux_analysis.pfba(model).fluxes[growth]
        except:
            print('model for ' + index + ' is infeasible')
        #cobra.flux_analysis.pfba(model).objective_value#This is sum of all fluxes


            
        growthandsubstrdata.loc[index,'FBA_growth_rate'] = FBA_solution
        growthandsubstrdata.loc[index,'pFBA_growth_rate'] = pFBA_solution
# Out:
# model for EVOL40-G is infeasible

# %%
display(growthandsubstrdata)
# Out:
#            growth_rate yield_coeff substrate_consumption_rate growth_rate_std  \
# WT-R         0.0188079   0.0282872                   0.668193       0.0010963
# EVOL33-R     0.0287171   0.0309298                    0.92984      0.00139503
# EVOL40-R     0.0287258   0.0327562                   0.878172      0.00107233
# WT-G         0.0315088     1.20922                  0.0260572               0
# EVOL33-G     0.0311486     1.18322                  0.0263253               0
# EVOL40-G     0.0312627   -0.525735                 -0.0594648               0
# WT-G-N       0.0390042     1.92818                  0.0202285               0
# EVOL33-G-N   0.0327415     1.05779                  0.0309528               0
# EVOL40-G-N   0.0341561     2.13301                  0.0160131               0
# WT-P-R       0.0404446   0.0232971                    1.76124       0.0134323
# PVHG6-P-R    0.0507687   0.0229876                    2.21591       0.0162766
#
#            yield_coeff_std substr_cons_rate_std  FBA_growth_rate  \
# WT-R            0.00299019            0.0312687         0.063811
# EVOL33-R        0.00208653            0.0238619         0.088797
# EVOL40-R         0.0019427            0.0208929         0.083863
# WT-G                     0                    0         0.003081
# EVOL33-G                 0                    0         0.003113
# EVOL40-G                 0                    0         0.059478
# WT-G-N                   0                    0         0.002392
# EVOL33-G-N               0                    0         0.003660
# EVOL40-G-N               0                    0         0.001893
# WT-P-R           0.0084907             0.110481         0.168193
# PVHG6-P-R       0.00752872            0.0280626         0.211614
#
#             pFBA_growth_rate
# WT-R                0.063811
# EVOL33-R            0.088797
# EVOL40-R            0.083863
# WT-G                0.003081
# EVOL33-G            0.003113
# EVOL40-G            0.003113
# WT-G-N              0.002392
# EVOL33-G-N          0.003660
# EVOL40-G-N          0.001893
# WT-P-R              0.168193
# PVHG6-P-R           0.211614

# %% [markdown]
# ####  **Generate scatter plot to compare observed and predicted growth rates (FBA, pFBA)**

# %%
#Scatterplot of solutions
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm

def maefunc(y_predict, y_actual):
    """Mean Absolute Error.
    Multioutput case included."""

    if y_actual.ndim == 1:
        return np.mean(np.abs([y_a - y_p for y_a, y_p in zip(y_actual, y_predict)]))
    else:
        return [
            np.mean(
                np.abs([y_a - y_p for y_a, y_p in zip(y_actual[:, i], y_predict[:, i])])
            )
            for i in range(y_actual.shape[1])
        ]
    
def scatterplotcompare(observed, predicted, labels, strtitle):
    fig, ax = plt.subplots(figsize=(8, 8))
    #res = stats.linregress(observed.to_numpy().astype(float), predicted.to_numpy())
    #print(res.rvalue**2)
    lims = [
                np.min([observed, predicted]),  # min of both axes
                np.max([observed, predicted]),  # max of both axes
            ]
    ax.set_xlim(lims)
    #ax.plot([0.0, 0.2], [0.0, 0.2], 'k',  c='0.55')
    # Plot Diagonal Dashed Line
    ax.plot(lims, lims, ls="--", color=".8", zorder=0)
    for i in range(0, len(observed)):
        ax.scatter(observed[i], predicted[i])
        ax.annotate(str(labels[i]),(observed[i],predicted[i]))
    #ax.annotate("r-squared = {:.3f}".format(round(r2_score(observed, predicted))), (0, 1))
    #plt.plot(observed, res.intercept + res.slope*observed, 'k', label='fitted line')
    rss = np.sum((predicted - observed) ** 2)
    tss = np.sum((predicted - predicted.mean()) ** 2)
    r2_1 = round(1 - rss / tss,2)
    #display(r2_1)
    #r2 = round(r2_score(observed, predicted),2)
    mse = np.round(1/len(observed) * rss,2) 
    rmse = np.round(np.sqrt(1/len(observed) * rss),2)
    #display(rmse)
    #display(r2_score(observed, predicted))
    mae_score = round(maefunc(observed, predicted),2)
    plt.xlabel(r'Observed growth rates [$mmol/gDW/hr$]')
    plt.ylabel(r'Predicted growth rates [$mmol/gDW/hr$]')
    plt.title(r'Growth rates: Observed vs. Predicted ('+strtitle+'), \n' + f"$R^2$={r2_1}, MAE={mae_score}, MSE = {mse}, RMSE={rmse}", fontsize=18)
    plt.show()

# %%
scatterplotcompare(growthandsubstrdata['growth_rate'], growthandsubstrdata['FBA_growth_rate'], growthandsubstrdata.index, 'FBA')
scatterplotcompare(growthandsubstrdata['growth_rate'], growthandsubstrdata['pFBA_growth_rate'], growthandsubstrdata.index, 'pFBA')
