# %% [markdown]
# ### **Notebook to compare transcript measurements with 13C flux measurements**

# %% [markdown]
# ##### **Import python packages**

# %%
import pandas as pd
import numpy as np
import cobra
from matplotlib import pyplot as plt

from edd_utils import login, export_study, export_metadata

# %% [markdown]
# ##### **Load Yondeda 2016 data**

# %%
# Study to Download
study_slug = 'biodesign_yoneda_set3_reprocessed'
# EDD server
edd_server = 'public-edd.jbei.org'
user       = 'garrettroell'

# %%
session = login(edd_server=edd_server, user=user)

df = export_study(session, study_slug, edd_server=edd_server)
# Out:
# Password for garrettroell:  ················
# HBox(children=(FloatProgress(value=0.0, max=192297.0), HTML(value='')))

# %% [markdown]
# ##### **Filter transcriptomics data from all EDD data into different dataframes**

# %%
trans_df = df[df['Protocol'].str.contains('Transcriptomics')]
trans_df.head()
# Out:
#    Study ID                         Study Name  Line ID        Line Name  \
# 0     14400  Biodesign_Yoneda_set3_reprocessed    15006   EVOL33-LN-G-R1
# 1     14400  Biodesign_Yoneda_set3_reprocessed    15007   EVOL33-LN-G-R2
# 2     14400  Biodesign_Yoneda_set3_reprocessed    15008   EVOL33-LN-G-R3
# 3     14400  Biodesign_Yoneda_set3_reprocessed    14991  EVOL33-LN-LP-R1
# 4     14400  Biodesign_Yoneda_set3_reprocessed    14992  EVOL33-LN-LP-R2
#
#                                     Line Description         Protocol  \
# 0  R. Opacus adaptively evolved strain1 with 1.0 ...  Transcriptomics
# 1  R. Opacus adaptively evolved strain1 with 1.0 ...  Transcriptomics
# 2  R. Opacus adaptively evolved strain1 with 1.0 ...  Transcriptomics
# 3  R. Opacus adaptively evolved strain1 with 0.75...  Transcriptomics
# 4  R. Opacus adaptively evolved strain1 with 0.75...  Transcriptomics
#
#    Assay ID       Assay Name Formal Type Measurement Type  Compartment Units  \
# 0     15030   EVOL33-LN-G-R1         NaN   WP_000104864_1            0  FPKM
# 1     15031   EVOL33-LN-G-R2         NaN   WP_000104864_1            0  FPKM
# 2     15032   EVOL33-LN-G-R3         NaN   WP_000104864_1            0  FPKM
# 3     15015  EVOL33-LN-LP-R1         NaN   WP_000104864_1            0  FPKM
# 4     15016  EVOL33-LN-LP-R2         NaN   WP_000104864_1            0  FPKM
#
#    Value  Hours
# 0    0.0   14.0
# 1    0.0   14.0
# 2    0.0   14.0
# 3    0.0   24.0
# 4    0.0   24.0

# %% [markdown]
# #####  **Get glucose 13C MFA measured fluxes**

# %%
glucose_fluxes = pd.read_csv('../13C_flux_data/13C_glucose_flux_data.csv')

# Remove rows that do not have a mapping to the GSM
glucose_fluxes.dropna(inplace=True)
print(f'There are {len(glucose_fluxes)} fluxes that can be compared between the MFA and FBA')
glucose_fluxes
# Out:
# There are 31 fluxes that can be compared between the MFA and FBA
#                       Pathway  \
# 0              Glucose Uptake
# 1                 EMP Pathway
# 2                 EMP Pathway
# 3                 EMP Pathway
# 4                 EMP Pathway
# 5                 EMP Pathway
# 6                 EMP Pathway
# 7                 EMP Pathway
# 8                 EMP Pathway
# 10  Pentose Phosphate Pathway
# 11  Pentose Phosphate Pathway
# 12  Pentose Phosphate Pathway
# 13  Pentose Phosphate Pathway
# 14  Pentose Phosphate Pathway
# 15  Pentose Phosphate Pathway
# 16  Pentose Phosphate Pathway
# 17  Pentose Phosphate Pathway
# 18  Pentose Phosphate Pathway
# 19                 ED Pathway
# 20                 ED Pathway
# 21                  TCA Cycle
# 22                  TCA Cycle
# 23                  TCA Cycle
# 24                  TCA Cycle
# 25                  TCA Cycle
# 26                  TCA Cycle
# 27                  TCA Cycle
# 28                  TCA Cycle
# 29                  TCA Cycle
# 30           Glyoxylate Shunt
# 31           Glyoxylate Shunt
#
#                                     Forward Reactions  \
# 0                                 reverse_EX_glc__D_e
# 1                                                 PGI
# 2                                  PFK or reverse_FBP
# 3                                                 FBA
# 4                                                 TPI
# 5                                                GAPD
# 6                                         reverse_PGK
# 7                                PGM_1 or reverse_PGM
# 8   reverse_PPS or FRUpts2pp or SBTpts or MNLpts o...
# 10                                    G6PDH2r and PGL
# 11                                                GND
# 12                                                RPE
# 13                                        reverse_RPI
# 14                                               TKT2
# 15                                               TKT2
# 16                                               TKT1
# 17                                               TALA
# 18                                       reverse_TALA
# 19                                                EDA
# 20                                                EDD
# 21                                                PDH
# 22                                 CS or reverse_CITL
# 23                      ACONT or ( ACONTa and ACONTb)
# 24                                    ICDHx or ICDHyr
# 25                                     AKGDH or OOR3r
# 26  3OADPCOAT or OCOAT3r or SUCBZT1 or SUCBZT2 or ...
# 27  SUCDi or reverse_FRD2 or reverse_FRD3 or rever...
# 28                                                FUM
# 29                     MDH or MDH3 or MDH2 or DMALRED
# 30                                                ICL
# 31                                               MALS
#
#                        Reaction Location on map    Flux  \
# 0         Gluc.ext + ATP -> G6P       (50, 460)  100.00
# 1                   G6P <-> F6P     (-150, 430)   -1.61
# 2              F6P + ATP -> FBP     (-220, 195)    0.00
# 3            FBP <-> DHAP + GAP     (-140, 115)    0.00
# 4                  DHAP <-> GAP     (-270, 150)    0.00
# 5                 GAP <-> G1,3P      (-220, 30)   86.56
# 6    G1,3P <-> 3PG + ATP + NADH     (-220, -55)   86.56
# 7                   3PG <-> 2PG    (-220, -135)   78.52
# 8                   2PG <-> PEP    (-220, -215)   78.52
# 10          G6P <-> 6PG + NADPH       (50, 380)  100.00
# 11   6PG <-> Ru5P + CO2 + NADPH      (275, 350)    6.62
# 12                 Ru5P <-> X5P      (380, 190)    2.12
# 13                 Ru5P <-> R5P      (270, 230)    4.50
# 14           X5P <-> TKC2 + GAP      (270, 100)    2.12
# 15           TKC2 + E4P <-> F6P       (10, 280)    0.15
# 16           TKC2 + R5P <-> S7P      (120, 230)    1.96
# 17           TAC3 + GAP <-> F6P      (-70, 190)    1.96
# 18           S7P <-> TAC3 + E4P       (50, 230)    1.97
# 19                 6PG <-> KDPG     (-300, 350)   93.38
# 20           KDPG <-> Pyr + GAP      (-300, 50)   93.38
# 21   Pyr <-> AcCoA + CO2 + NADH    (-220, -370)  135.41
# 22          OAC + AcCoA <-> Cit     (-55, -340)   69.04
# 23                 Cit <-> ICit     (145, -310)   69.04
# 24   ICit <-> AKG + CO2 + NADPH     (290, -310)   69.04
# 25  AKG <-> SucCoA + CO2 + NADH     (290, -195)   61.60
# 26         SucCoA <-> Suc + ATP      (290, -55)   59.88
# 27          Suc <-> Fum + FADH2      (160, -55)   61.60
# 28                  Fum <-> Mal       (10, -55)   63.27
# 29           Mal <-> OAC + NADH     (-60, -180)   25.97
# 30          ICit -> Glyox + Suc     (180, -140)    0.00
# 31         Glyox + AcCoA -> Mal      (90, -140)    0.00
#
#     90% Confidence Lower Bound  90% Confidence Upper Bound
# 0                       100.00                      100.00
# 1                        -2.09                        1.42
# 2                         0.00                        1.91
# 3                         0.00                        1.91
# 4                         0.00                        1.91
# 5                        82.61                       88.84
# 6                        82.61                       88.84
# 7                        71.65                       81.26
# 8                        71.65                       81.26
# 10                       96.96                      100.00
# 11                        2.07                       10.92
# 12                       -0.89                        4.37
# 13                        2.95                        6.55
# 14                       -0.89                        4.37
# 15                       -1.36                        1.11
# 16                        0.46                        3.34
# 17                        0.46                        3.34
# 18                        0.46                        3.34
# 19                       89.08                       94.98
# 20                       89.08                       94.98
# 21                      116.26                      196.60
# 22                       58.52                       82.65
# 23                       58.52                       82.65
# 24                       10.08                       82.65
# 25                        2.27                       75.99
# 26                        0.87                       74.45
# 27                       50.51                       75.99
# 28                       22.17                       77.49
# 29                      -50.27                       78.90
# 30                        0.00                       60.46
# 31                        0.00                       60.46

# %% [markdown]
# ##### **Load Genome Scale Model**

# %%
file_name =  '../GSMs/Ropacus_annotated_curated_with_phenol_custom_biomass.xml'
model = cobra.io.read_sbml_model(file_name)

# %% [markdown]
# #### Define functions to find transcript levels for a reaction given a transcriptomic dataframe ####

# %%
def create_gprdict(model):   
    gpr_dict = dict()
    for rxn in model.reactions:
        if rxn.gene_reaction_rule:
            temp = set()
            for x in [x.strip('() ') for x in rxn.gene_reaction_rule.split(' or ')]:
                temp.add(frozenset(y.strip('() ') for y in x.split(' and ')))
            gpr_dict[rxn.id] = temp
    return gpr_dict

"""
    Calculates bound value based on transcriptomics data for reactions in gene reaction rule
    
    NOTE: 
    If a reaction R1 has the GPR of 'A and B', it would be parsed to { {A, B} } in gpr_dict['R1']. Then t for R1 would be sum( [ min(A, B) ] ) = min(A, B).
    If a reaction R1 has the GPR of 'A or B', it would be parsed to { {A}, {B} } in gpr_dict['R1']. Then t for R1 would be sum( [ min(A), min(B) ] ) = sum( [A, B] ).
    If a reaction R1 has the GPR of '(A and B) or (C and D)', it would be parsed to { {A, B}, {C, D} } in gpr_dict['R1']. Then t for R1 would be sum( [ min(A, B), min(C, D) ] ).
    
        Parameters
        ----------
        model : cobrapy model.
        Transcriptomics : pandas dataframe with transcriptomics data.Data frame has gene identifiers as index and just one column with transcript values.  
        rxn : cobrapy model reaction
        
        
        Returns
        -------
        transscript bound value: float.
"""

def findtransboundval_forgprrxns(model, Transcriptomics,rxn, newinf=np.inf):
    finaltransval = 0
    listids = []
    for parallel_gene in create_gprdict(model)[rxn.id]:
        transvals = []
        for gene in parallel_gene:
            if gene in Transcriptomics.index:
                transvals.append(Transcriptomics.loc[gene].values)
            else:
                transvals.append(np.inf)
            mintransval=np.min(transvals)
            if mintransval == np.inf:
                mintransval= newinf
        finaltransval = finaltransval + mintransval
#         if finaltransval==newinfbound:
#             display(rxn.id)
#             listids.append(rxn.id)
    return finaltransval

# %% [markdown]
# #### Define a function to get the input transcriptomic dataframe for findtransboundval_forgprrxns ####

# %%
def constructTransdffrompred(transdata, linename):
    transdataWTPR1 = transdata[transdata['Line Name']==linename]
    transdataWTPR1new = transdataWTPR1.filter(['Value', 'Measurement Type'])
    transdataWTPR1new2 = transdataWTPR1new.set_index('Measurement Type')
    return transdataWTPR1new2

# %% [markdown]
# #### Loop over conditions and rows to add transcriptomic values to the dataframe

# %%
glucose_conditions = [
    'EVOL33-LN-G-R1',
    'EVOL33-LN-G-R2',
    'EVOL33-LN-G-R3',
    'EVOL40-LN-G-R1',
    'EVOL40-LN-G-R2',
    'EVOL40-LN-G-R3',
    'WT-LN-G-R1',
    'WT-LN-G-R2',
    'WT-LN-G-R3'
]

for condition in glucose_conditions:

    # get the transcriptomic df for the condition
    transcriptomics_df = constructTransdffrompred(trans_df, condition)

    # define a list to hold all transcript measurements for a condtion
    transcript_measurements = [] 

    # loop over the 13C MFA reactions
    for _, row in glucose_fluxes.iterrows():

        # get the reaction ids associated with the flux for that row
        reaction_id_string = row['Forward Reactions']
        mfa_reaction = row['Reaction']

        # remove directionality
        reaction_id_string = reaction_id_string.replace('reverse_', '')

        # convert to an array of parallel sets of reactions
        reaction_ids = reaction_id_string.split(' or ')

        # define a value to act as a counter
        transcript_level = 0

        for reaction_id in reaction_ids:
            # remove spaces and parentheses
            reaction_id = reaction_id.strip('() ')

            if ' and ' in reaction_id:
                series_reactions = reaction_id.split(' and ')
                # loop over reactions that have and relationships and add min value to the transcript total
                series_transcripts = []
                for series_reaction in series_reactions:
                    # get transcript level for a given reaction in the genome scale model
                    rxn = model.reactions.get_by_id(series_reaction)
                    transcript_level = findtransboundval_forgprrxns(model, transcriptomics_df, rxn, newinf=np.inf)
                    series_transcripts.append(transcript_level)
                # only add the minimum transcript level of reactions connected by 'and' relations
                transcript_level += min(series_transcripts)
            else:
                rxn = model.reactions.get_by_id(reaction_id)
                if rxn.id in create_gprdict(model).keys():
                    reaction_transcripts =  findtransboundval_forgprrxns(model, transcriptomics_df, rxn)
                    transcript_level += reaction_transcripts
                else:
                    pass

        transcript_measurements.append(transcript_level)

    glucose_fluxes[condition + ' transcripts'] = transcript_measurements

glucose_fluxes.head()
# Out:
#           Pathway    Forward Reactions               Reaction Location on map  \
# 0  Glucose Uptake  reverse_EX_glc__D_e  Gluc.ext + ATP -> G6P       (50, 460)
# 1     EMP Pathway                  PGI            G6P <-> F6P     (-150, 430)
# 2     EMP Pathway   PFK or reverse_FBP       F6P + ATP -> FBP     (-220, 195)
# 3     EMP Pathway                  FBA     FBP <-> DHAP + GAP     (-140, 115)
# 4     EMP Pathway                  TPI           DHAP <-> GAP     (-270, 150)
#
#      Flux  90% Confidence Lower Bound  90% Confidence Upper Bound  \
# 0  100.00                      100.00                      100.00
# 1   -1.61                       -2.09                        1.42
# 2    0.00                        0.00                        1.91
# 3    0.00                        0.00                        1.91
# 4    0.00                        0.00                        1.91
#
#    EVOL33-LN-G-R1 transcripts  EVOL33-LN-G-R2 transcripts  \
# 0                     0.00000                     0.00000
# 1                   339.77434                   333.37109
# 2                   642.00867                   599.81818
# 3                   113.47081                   103.43466
# 4                   100.92202                   101.01041
#
#    EVOL33-LN-G-R3 transcripts  EVOL40-LN-G-R1 transcripts  \
# 0                     0.00000                     0.00000
# 1                   325.13618                   282.25838
# 2                   617.06697                   667.32051
# 3                   116.04595                    88.28107
# 4                   118.81306                    79.72413
#
#    EVOL40-LN-G-R2 transcripts  EVOL40-LN-G-R3 transcripts  \
# 0                     0.00000                     0.00000
# 1                   282.34734                   271.35304
# 2                   648.11338                   625.11398
# 3                   102.10006                    85.06621
# 4                    76.11263                    86.29313
#
#    WT-LN-G-R1 transcripts  WT-LN-G-R2 transcripts  WT-LN-G-R3 transcripts
# 0                 0.00000                 0.00000                 0.00000
# 1               270.55161               242.91212               285.06464
# 2               704.42129               648.56446               741.30736
# 3               100.31113                98.25414               109.88136
# 4                79.60794                63.17894                72.44159

# %% [markdown]
# #### Convert transcipts to average and standard deviation for each strain

# %%
strains = ['WT', 'EVOL33', 'EVOL40']

for strain in strains:
    # isolate the trials for a single strain
    strain_cols = [col for col in glucose_fluxes.columns if strain in col]
    strain_df = glucose_fluxes[strain_cols]
    
    # calculate the average and standard deviation for each row
    avg_col = strain_df.mean(axis=1)
    std_col = strain_df.std(axis=1)
    
    # drop the single trial values
    glucose_fluxes.drop(strain_cols, axis=1, inplace=True)
    
    # add the average and standard deviation columns
    glucose_fluxes[f'{strain} trans avg'] = avg_col
    glucose_fluxes[f'{strain} trans std'] = std_col
    
glucose_fluxes
# Out:
#                       Pathway  \
# 0              Glucose Uptake
# 1                 EMP Pathway
# 2                 EMP Pathway
# 3                 EMP Pathway
# 4                 EMP Pathway
# 5                 EMP Pathway
# 6                 EMP Pathway
# 7                 EMP Pathway
# 8                 EMP Pathway
# 10  Pentose Phosphate Pathway
# 11  Pentose Phosphate Pathway
# 12  Pentose Phosphate Pathway
# 13  Pentose Phosphate Pathway
# 14  Pentose Phosphate Pathway
# 15  Pentose Phosphate Pathway
# 16  Pentose Phosphate Pathway
# 17  Pentose Phosphate Pathway
# 18  Pentose Phosphate Pathway
# 19                 ED Pathway
# 20                 ED Pathway
# 21                  TCA Cycle
# 22                  TCA Cycle
# 23                  TCA Cycle
# 24                  TCA Cycle
# 25                  TCA Cycle
# 26                  TCA Cycle
# 27                  TCA Cycle
# 28                  TCA Cycle
# 29                  TCA Cycle
# 30           Glyoxylate Shunt
# 31           Glyoxylate Shunt
#
#                                     Forward Reactions  \
# 0                                 reverse_EX_glc__D_e
# 1                                                 PGI
# 2                                  PFK or reverse_FBP
# 3                                                 FBA
# 4                                                 TPI
# 5                                                GAPD
# 6                                         reverse_PGK
# 7                                PGM_1 or reverse_PGM
# 8   reverse_PPS or FRUpts2pp or SBTpts or MNLpts o...
# 10                                    G6PDH2r and PGL
# 11                                                GND
# 12                                                RPE
# 13                                        reverse_RPI
# 14                                               TKT2
# 15                                               TKT2
# 16                                               TKT1
# 17                                               TALA
# 18                                       reverse_TALA
# 19                                                EDA
# 20                                                EDD
# 21                                                PDH
# 22                                 CS or reverse_CITL
# 23                      ACONT or ( ACONTa and ACONTb)
# 24                                    ICDHx or ICDHyr
# 25                                     AKGDH or OOR3r
# 26  3OADPCOAT or OCOAT3r or SUCBZT1 or SUCBZT2 or ...
# 27  SUCDi or reverse_FRD2 or reverse_FRD3 or rever...
# 28                                                FUM
# 29                     MDH or MDH3 or MDH2 or DMALRED
# 30                                                ICL
# 31                                               MALS
#
#                        Reaction Location on map    Flux  \
# 0         Gluc.ext + ATP -> G6P       (50, 460)  100.00
# 1                   G6P <-> F6P     (-150, 430)   -1.61
# 2              F6P + ATP -> FBP     (-220, 195)    0.00
# 3            FBP <-> DHAP + GAP     (-140, 115)    0.00
# 4                  DHAP <-> GAP     (-270, 150)    0.00
# 5                 GAP <-> G1,3P      (-220, 30)   86.56
# 6    G1,3P <-> 3PG + ATP + NADH     (-220, -55)   86.56
# 7                   3PG <-> 2PG    (-220, -135)   78.52
# 8                   2PG <-> PEP    (-220, -215)   78.52
# 10          G6P <-> 6PG + NADPH       (50, 380)  100.00
# 11   6PG <-> Ru5P + CO2 + NADPH      (275, 350)    6.62
# 12                 Ru5P <-> X5P      (380, 190)    2.12
# 13                 Ru5P <-> R5P      (270, 230)    4.50
# 14           X5P <-> TKC2 + GAP      (270, 100)    2.12
# 15           TKC2 + E4P <-> F6P       (10, 280)    0.15
# 16           TKC2 + R5P <-> S7P      (120, 230)    1.96
# 17           TAC3 + GAP <-> F6P      (-70, 190)    1.96
# 18           S7P <-> TAC3 + E4P       (50, 230)    1.97
# 19                 6PG <-> KDPG     (-300, 350)   93.38
# 20           KDPG <-> Pyr + GAP      (-300, 50)   93.38
# 21   Pyr <-> AcCoA + CO2 + NADH    (-220, -370)  135.41
# 22          OAC + AcCoA <-> Cit     (-55, -340)   69.04
# 23                 Cit <-> ICit     (145, -310)   69.04
# 24   ICit <-> AKG + CO2 + NADPH     (290, -310)   69.04
# 25  AKG <-> SucCoA + CO2 + NADH     (290, -195)   61.60
# 26         SucCoA <-> Suc + ATP      (290, -55)   59.88
# 27          Suc <-> Fum + FADH2      (160, -55)   61.60
# 28                  Fum <-> Mal       (10, -55)   63.27
# 29           Mal <-> OAC + NADH     (-60, -180)   25.97
# 30          ICit -> Glyox + Suc     (180, -140)    0.00
# 31         Glyox + AcCoA -> Mal      (90, -140)    0.00
#
#     90% Confidence Lower Bound  90% Confidence Upper Bound  WT trans avg  \
# 0                       100.00                      100.00      0.000000
# 1                        -2.09                        1.42    266.176123
# 2                         0.00                        1.91    698.097703
# 3                         0.00                        1.91    102.815543
# 4                         0.00                        1.91     71.742823
# 5                        82.61                       88.84    284.768950
# 6                        82.61                       88.84    145.175877
# 7                        71.65                       81.26    287.466580
# 8                        71.65                       81.26   1163.355667
# 10                       96.96                      100.00    110.676987
# 11                        2.07                       10.92    471.191313
# 12                       -0.89                        4.37      5.030090
# 13                        2.95                        6.55      7.209780
# 14                       -0.89                        4.37    175.757137
# 15                       -1.36                        1.11    175.757137
# 16                        0.46                        3.34    175.757137
# 17                        0.46                        3.34   1040.257653
# 18                        0.46                        3.34   1040.257653
# 19                       89.08                       94.98     16.428923
# 20                       89.08                       94.98     97.464723
# 21                      116.26                      196.60    583.636950
# 22                       58.52                       82.65    284.292290
# 23                       58.52                       82.65    829.618287
# 24                       10.08                       82.65    855.228267
# 25                        2.27                       75.99     13.093893
# 26                        0.87                       74.45    499.867923
# 27                       50.51                       75.99    622.198550
# 28                       22.17                       77.49    221.099460
# 29                      -50.27                       78.90   1086.920473
# 30                        0.00                       60.46   3305.980403
# 31                        0.00                       60.46   1025.339483
#
#     WT trans std  EVOL33 trans avg  EVOL33 trans std  EVOL40 trans avg  \
# 0       0.000000          0.000000          0.000000          0.000000
# 1      21.414187        332.760537          7.338155        278.652920
# 2      46.693706        619.631273         21.211815        646.849290
# 3       6.205008        110.983807          6.663336         91.815780
# 4       8.236760        106.915163         10.303976         80.709963
# 5       8.442706        335.548963         24.206507        255.928620
# 6      16.847036        211.693833         18.395998        158.604067
# 7      11.728371        304.978637         12.899062        306.866667
# 8      64.796167       1372.141210        129.057724       1210.067060
# 10     10.192412        152.246413          2.015697        152.830153
# 11     36.211853        575.287273         24.548292        542.540407
# 12      1.648509          5.320103          1.118471          5.703120
# 13      0.968517          8.009983          1.001284          7.337750
# 14     24.975930        173.082233         14.527429        185.121843
# 15     24.975930        173.082233         14.527429        185.121843
# 16     24.975930        173.082233         14.527429        185.121843
# 17     23.418182       1039.780753         47.773407       1046.157020
# 18     23.418182       1039.780753         47.773407       1046.157020
# 19      2.610192         17.886347          1.265582         15.620260
# 20     14.009448        109.674723          9.668186         80.148600
# 21     11.511223        417.228050         45.543557        499.861060
# 22     22.291917        347.495337         18.442668        290.614947
# 23     56.705340        704.868833         59.376656        807.002620
# 24     12.858383       1026.151523         51.113596        954.620617
# 25      0.965061         13.217423          1.319378         12.609863
# 26     41.194444        572.045723         23.856831        578.878810
# 27     44.475414        744.238050         44.217063        696.144543
# 28      8.266292        255.906717         10.770753        266.397400
# 29    233.369980       1425.938453         78.123358       1341.390707
# 30   1659.547935       1076.966933        723.525724        223.402363
# 31    188.781737        706.891703        127.396874        832.811007
#
#     EVOL40 trans std
# 0           0.000000
# 1           6.322038
# 2          21.131641
# 3           9.050339
# 4           5.161351
# 5          38.898973
# 6           4.766068
# 7          14.052888
# 8          63.525768
# 10         14.788734
# 11         21.807244
# 12          0.582065
# 13          0.769497
# 14         10.348100
# 15         10.348100
# 16         10.348100
# 17         52.628052
# 18         52.628052
# 19          0.641253
# 20          4.735105
# 21         21.784416
# 22         14.283996
# 23         96.044481
# 24         76.874016
# 25          0.587155
# 26         24.555157
# 27         68.049013
# 28         14.078647
# 29         69.669091
# 30         64.890243
# 31        148.342435

# %%
# save data to csv
glucose_fluxes.to_csv('../transcript_vs_flux_data/glucose.csv')

# %% [markdown]
# #### Could normalize fluxes here

# %% [markdown]
# #### Define plotting function

# %%
def plot_transcripts_vs_fluxes(flux_trans_df, substrate, strain):
    fig, ax = plt.subplots(figsize=(8, 8))

    for pathway in list(set(flux_trans_df['Pathway'])):
        pathway_df = flux_trans_df[flux_trans_df['Pathway'] == pathway]

        transcript_list = list(pathway_df[f'{strain} trans avg'])
        flux_list = list(pathway_df['Flux'])
        
        transcript_std_list = list(pathway_df[f'{strain} trans std'])
        flux_lower_std_list = list(pathway_df['Flux'] - pathway_df['90% Confidence Lower Bound'])
        flux_upper_std_list = list(pathway_df['90% Confidence Upper Bound'] - pathway_df['Flux'])

        ax.scatter(transcript_list, flux_list, label=pathway)
        
        ax.errorbar(
            transcript_list,
            flux_list, 
            xerr=[std1 for std1 in transcript_std_list], 
            yerr = [
                flux_lower_std_list,
                flux_upper_std_list
            ],
            ecolor="gray", 
            ls='none',
            alpha=0.3
        )        
    # Dashed line
    # x = np.linspace(*ax.get_xlim())
    # ax.plot(x, x, ls="--", c=".3")
    plt.title(f'{strain} {substrate.capitalize()} Transcripts vs. Fluxes', fontSize=20)
    plt.xlabel('Transcript Level (Fragments Per Kilobase Million)')
    plt.ylabel('Flux (mmol reaction per 100 mmol of '+str(substrate)+  ' uptake)')
    plt.legend()
    plt.show()

# %%
plot_transcripts_vs_fluxes(glucose_fluxes, 'glucose', 'WT')
plot_transcripts_vs_fluxes(glucose_fluxes, 'glucose', 'EVOL33')
plot_transcripts_vs_fluxes(glucose_fluxes, 'glucose', 'EVOL40')

# %% [markdown]
# ---
# ## Compare phenol transcripts and fluxes

# %% [markdown]
# #### **Load Henson 2018 data**

# %%
# Study to Download
study_slug = 'biodesign_henson2018_reprocessed'
# EDD server
edd_server = 'public-edd.jbei.org'
user       = 'garrettroell'

# %%
session = login(edd_server=edd_server, user=user)

df = export_study(session, study_slug, edd_server=edd_server)
# Out:
# Password for garrettroell:  ················
# HBox(children=(FloatProgress(value=0.0, max=440493.0), HTML(value='')))

# %% [markdown]
# ##### **Filter transcriptomics data from all EDD data into different dataframes**

# %%
trans_df = df[df['Protocol'].str.contains('Transcriptomics')]
trans_df.head()
# Out:
#    Study ID                        Study Name  Line ID Line Name  \
# 0     14409  Biodesign_Henson2018_reprocessed    14905   WT-M-R1
# 1     14409  Biodesign_Henson2018_reprocessed    14905   WT-M-R1
# 2     14409  Biodesign_Henson2018_reprocessed    14906   WT-M-R2
# 3     14409  Biodesign_Henson2018_reprocessed    14906   WT-M-R2
# 4     14409  Biodesign_Henson2018_reprocessed    14907   WT-M-R3
#
#                                     Line Description         Protocol  \
# 0  R. Opacus wild type strain with Mixture of all...  Transcriptomics
# 1  R. Opacus wild type strain with Mixture of all...  Transcriptomics
# 2  R. Opacus wild type strain with Mixture of all...  Transcriptomics
# 3  R. Opacus wild type strain with Mixture of all...  Transcriptomics
# 4  R. Opacus wild type strain with Mixture of all...  Transcriptomics
#
#    Assay ID Assay Name Formal Type Measurement Type  Compartment Units  Value  \
# 0     14948    WT-M-R1         NaN   WP_000104864_1            0  FPKM    0.0
# 1     14948    WT-M-R1         NaN   WP_000104864_1            0  FPKM    0.0
# 2     14949    WT-M-R2         NaN   WP_000104864_1            0  FPKM    0.0
# 3     14949    WT-M-R2         NaN   WP_000104864_1            0  FPKM    0.0
# 4     14950    WT-M-R3         NaN   WP_000104864_1            0  FPKM    0.0
#
#    Hours
# 0   20.0
# 1   32.0
# 2   20.0
# 3   32.0
# 4   20.0

# %% [markdown]
# #####  **Get phenol 13C MFA measured fluxes**

# %%
phenol_fluxes = pd.read_csv('../13C_flux_data/13C_phenol_flux_data.csv')

# Remove rows that do not have a mapping to the GSM
phenol_fluxes.dropna(inplace=True)
print(f'There are {len(phenol_fluxes)} fluxes that can be compared between the MFA and FBA')
phenol_fluxes
# Out:
# There are 32 fluxes that can be compared between the MFA and FBA
#                       Pathway  \
# 0               Phenol Uptake
# 1                 EMP Pathway
# 2                 EMP Pathway
# 3                 EMP Pathway
# 4                 EMP Pathway
# 5                 EMP Pathway
# 6                 EMP Pathway
# 7                 EMP Pathway
# 8                 EMP Pathway
# 9                 EMP Pathway
# 10  Pentose Phosphate Pathway
# 11  Pentose Phosphate Pathway
# 12  Pentose Phosphate Pathway
# 13  Pentose Phosphate Pathway
# 14  Pentose Phosphate Pathway
# 15  Pentose Phosphate Pathway
# 16  Pentose Phosphate Pathway
# 17  Pentose Phosphate Pathway
# 18  Pentose Phosphate Pathway
# 19                 ED Pathway
# 20                 ED Pathway
# 21                  TCA Cycle
# 22                  TCA Cycle
# 23                  TCA Cycle
# 24                  TCA Cycle
# 25                  TCA Cycle
# 26                  TCA Cycle
# 27                  TCA Cycle
# 28                  TCA Cycle
# 29                  TCA Cycle
# 30           Glyoxylate Shunt
# 31           Glyoxylate Shunt
#
#                                     Forward Reactions  \
# 0                                              PHEMOX
# 1                                                 PGI
# 2                                  PFK or reverse_FBP
# 3                                                 FBA
# 4                                                 TPI
# 5                                                GAPD
# 6                                         reverse_PGK
# 7                                PGM_1 or reverse_PGM
# 8                                                 ENO
# 9   PPS or reverse_FRUpts2pp or reverse_SBTpts or ...
# 10                                    G6PDH2r and PGL
# 11                                                GND
# 12                                                RPE
# 13                                        reverse_RPI
# 14                                               TKT2
# 15                                               TKT2
# 16                                               TKT1
# 17                                               TALA
# 18                                       reverse_TALA
# 19                                                EDA
# 20                                                EDD
# 21                                                PDH
# 22                                 CS or reverse_CITL
# 23                      ACONT or ( ACONTa and ACONTb)
# 24                                    ICDHx or ICDHyr
# 25                                     AKGDH or OOR3r
# 26  3OADPCOAT or OCOAT3r or SUCBZT1 or SUCBZT2 or ...
# 27  SUCDi or reverse_FRD2 or reverse_FRD3 or rever...
# 28                                                FUM
# 29                     MDH or MDH3 or MDH2 or DMALRED
# 30                                                ICL
# 31                                               MALS
#
#                         Reaction Location on map          Flux  \
# 0   Phenol.ext -> AcCoA + SucCoA     ( 80, -450)  1.000000e+02
# 1                    G6P <-> F6P     (-150, 430) -4.793000e-01
# 2               F6P + ATP -> FBP     (-220, 195) -2.000000e+00
# 3             FBP <-> DHAP + GAP     (-140, 115) -2.000000e+00
# 4                   DHAP <-> GAP     (-270, 150) -2.000000e+00
# 5                  GAP <-> G1,3P      (-220, 30) -1.079070e+01
# 6     G1,3P <-> 3PG + ATP + NADH     (-220, -55) -1.079070e+01
# 7                    3PG <-> 2PG    (-220, -135) -1.625380e+01
# 8                    2PG <-> PEP    (-220, -215) -1.625380e+01
# 9              PEP <-> Pyr + ATP    (-220, -295)  2.999990e+01
# 10           G6P <-> 6PG + NADPH       (50, 380) -5.767000e-01
# 11    6PG <-> Ru5P + CO2 + NADPH      (275, 350)  4.646000e-01
# 12                  Ru5P <-> X5P      (380, 190) -1.187400e+00
# 13                  Ru5P <-> R5P      (270, 230)  1.652100e+00
# 14            X5P <-> TKC2 + GAP      (270, 100) -1.187400e+00
# 15            TKC2 + E4P <-> F6P       (10, 280) -1.187400e+00
# 16            TKC2 + R5P <-> S7P      (120, 230)  2.130000e-14
# 17            TAC3 + GAP <-> F6P      (-70, 190)  7.110000e-15
# 18            S7P <-> TAC3 + E4P       (50, 230)  8.530000e-14
# 19                  6PG <-> KDPG     (-300, 350) -1.041300e+00
# 20            KDPG <-> Pyr + GAP      (-300, 50) -1.041300e+00
# 21    Pyr <-> AcCoA + CO2 + NADH    (-220, -370)  5.923270e+01
# 22            OAC + AcCoA -> Cit     (-55, -340)  1.144391e+02
# 23                   Cit -> ICit     (145, -310)  1.144391e+02
# 24     ICit -> AKG + CO2 + NADPH     (290, -310)  1.134677e+02
# 25    AKG -> SucCoA + CO2 + NADH     (290, -195)  1.086053e+02
# 26           SucCoA -> Suc + ATP      (290, -55)  2.074789e+02
# 27            Suc -> Fum + FADH2      (160, -55)  2.085767e+02
# 28                    Fum -> Mal       (10, -55)  2.096703e+02
# 29             Mal -> OAC + NADH     (-60, -180)  1.710231e+02
# 30           ICit -> Glyox + Suc     (180, -140)  9.714000e-01
# 31          Glyox + AcCoA -> Mal      (90, -140)  9.714000e-01
#
#     90% Confidence Lower Bound  90% Confidence Upper Bound
# 0                 1.000000e+02                    100.0000
# 1                -1.421900e+00                      0.9306
# 2                -2.000000e+00                     -0.7683
# 3                -2.000000e+00                     -0.7683
# 4                -2.000000e+00                     -0.7683
# 5                -1.122350e+01                     -9.1040
# 6                -1.122350e+01                     -9.1040
# 7                -1.695560e+01                    -13.6034
# 8                -1.695560e+01                    -13.6034
# 9                 0.000000e+00                     30.0000
# 10               -2.018100e+00                      0.3824
# 11               -1.659900e+00                      1.8755
# 12               -2.611500e+00                     -0.2468
# 13                9.081000e-01                      2.1385
# 14               -2.611500e+00                     -0.2468
# 15               -1.909000e+00                     -0.7099
# 16               -7.076000e-01                      0.4698
# 17               -7.076000e-01                      0.4698
# 18               -7.076000e-01                      0.4698
# 19               -2.524300e+00                      0.2447
# 20               -2.524300e+00                      0.2447
# 21                5.668260e+01                     62.0459
# 22                1.102766e+02                    118.4800
# 23                1.102766e+02                    118.4800
# 24                1.068011e+02                    118.4800
# 25                1.017297e+02                    113.8305
# 26                2.005620e+02                    212.7536
# 27                2.032666e+02                    212.8305
# 28                2.043514e+02                    213.8762
# 29                1.292999e+02                    174.5648
# 30                7.110000e-15                      4.5567
# 31                0.000000e+00                      4.5567

# %%
[line for line in set(list(trans_df['Line Name'])) if '-P-' in line]
# Out:
# ['PVHG-P-R3', 'PVHG-P-R2', 'WT-P-R1', 'WT-P-R3', 'PVHG-P-R1', 'WT-P-R2']

# %%
phenol_conditions = [
    'WT-P-R1',
    'WT-P-R2',
    'WT-P-R3',
    'PVHG-P-R1',
    'PVHG-P-R2',
    'PVHG-P-R3',
]

for condition in phenol_conditions:

    # get the transcriptomic df for the condition
    transcriptomics_df = constructTransdffrompred(trans_df, condition)

    # define a list to hold all transcript measurements for a condtion
    transcript_measurements = [] 

    # loop over the 13C MFA reactions
    for _, row in phenol_fluxes.iterrows():

        # get the reaction ids associated with the flux for that row
        reaction_id_string = row['Forward Reactions']
        mfa_reaction = row['Reaction']

        # remove directionality
        reaction_id_string = reaction_id_string.replace('reverse_', '')

        # convert to an array of parallel sets of reactions
        reaction_ids = reaction_id_string.split(' or ')

        # define a value to act as a counter
        transcript_level = 0

        for reaction_id in reaction_ids:
            # remove spaces and parentheses
            reaction_id = reaction_id.strip('() ')

            if ' and ' in reaction_id:
                series_reactions = reaction_id.split(' and ')
                # loop over reactions that have and relationships and add min value to the transcript total
                series_transcripts = []
                for series_reaction in series_reactions:
                    # get transcript level for a given reaction in the genome scale model
                    rxn = model.reactions.get_by_id(series_reaction)
                    transcript_level = findtransboundval_forgprrxns(model, transcriptomics_df, rxn, newinf=np.inf)
                    series_transcripts.append(transcript_level)
                # only add the minimum transcript level of reactions connected by 'and' relations
                transcript_level += min(series_transcripts)
            else:
                rxn = model.reactions.get_by_id(reaction_id)
                if rxn.id in create_gprdict(model).keys():
                    reaction_transcripts =  findtransboundval_forgprrxns(model, transcriptomics_df, rxn)
                    transcript_level += reaction_transcripts
                else:
                    pass

        transcript_measurements.append(transcript_level)

    phenol_fluxes[condition + ' transcripts'] = transcript_measurements

phenol_fluxes.head()
# Out:
#          Pathway   Forward Reactions                      Reaction  \
# 0  Phenol Uptake              PHEMOX  Phenol.ext -> AcCoA + SucCoA
# 1    EMP Pathway                 PGI                   G6P <-> F6P
# 2    EMP Pathway  PFK or reverse_FBP              F6P + ATP -> FBP
# 3    EMP Pathway                 FBA            FBP <-> DHAP + GAP
# 4    EMP Pathway                 TPI                  DHAP <-> GAP
#
#   Location on map      Flux  90% Confidence Lower Bound  \
# 0     ( 80, -450)  100.0000                    100.0000
# 1     (-150, 430)   -0.4793                     -1.4219
# 2     (-220, 195)   -2.0000                     -2.0000
# 3     (-140, 115)   -2.0000                     -2.0000
# 4     (-270, 150)   -2.0000                     -2.0000
#
#    90% Confidence Upper Bound  WT-P-R1 transcripts  WT-P-R2 transcripts  \
# 0                    100.0000              0.00000              0.00000
# 1                      0.9306            617.74220            701.54889
# 2                     -0.7683           1033.37976            960.04318
# 3                     -0.7683            283.42121            276.29118
# 4                     -0.7683            137.66675            124.24864
#
#    WT-P-R3 transcripts  PVHG-P-R1 transcripts  PVHG-P-R2 transcripts  \
# 0              0.00000                0.00000                0.00000
# 1            769.60990             2140.20677             1674.03135
# 2            822.33970             1542.33060             1425.57987
# 3            276.27965              124.91224              136.59720
# 4            103.12969              799.56933              516.73819
#
#    PVHG-P-R3 transcripts
# 0                0.00000
# 1             1737.58061
# 2             1309.80100
# 3              146.31124
# 4              390.85564

# %% [markdown]
# #### Convert transcipts to average and standard deviation for each strain

# %%
strains = ['WT', 'PVHG']

for strain in strains:
    # isolate the trials for a single strain
    strain_cols = [col for col in phenol_fluxes.columns if strain in col]
    strain_df = phenol_fluxes[strain_cols]
    
    # calculate the average and standard deviation for each row
    avg_col = strain_df.mean(axis=1)
    std_col = strain_df.std(axis=1)
    
    # drop the single trial values
    phenol_fluxes.drop(strain_cols, axis=1, inplace=True)
    
    # add the average and standard deviation columns
    phenol_fluxes[f'{strain} trans avg'] = avg_col
    phenol_fluxes[f'{strain} trans std'] = std_col
    
phenol_fluxes
# Out:
#                       Pathway  \
# 0               Phenol Uptake
# 1                 EMP Pathway
# 2                 EMP Pathway
# 3                 EMP Pathway
# 4                 EMP Pathway
# 5                 EMP Pathway
# 6                 EMP Pathway
# 7                 EMP Pathway
# 8                 EMP Pathway
# 9                 EMP Pathway
# 10  Pentose Phosphate Pathway
# 11  Pentose Phosphate Pathway
# 12  Pentose Phosphate Pathway
# 13  Pentose Phosphate Pathway
# 14  Pentose Phosphate Pathway
# 15  Pentose Phosphate Pathway
# 16  Pentose Phosphate Pathway
# 17  Pentose Phosphate Pathway
# 18  Pentose Phosphate Pathway
# 19                 ED Pathway
# 20                 ED Pathway
# 21                  TCA Cycle
# 22                  TCA Cycle
# 23                  TCA Cycle
# 24                  TCA Cycle
# 25                  TCA Cycle
# 26                  TCA Cycle
# 27                  TCA Cycle
# 28                  TCA Cycle
# 29                  TCA Cycle
# 30           Glyoxylate Shunt
# 31           Glyoxylate Shunt
#
#                                     Forward Reactions  \
# 0                                              PHEMOX
# 1                                                 PGI
# 2                                  PFK or reverse_FBP
# 3                                                 FBA
# 4                                                 TPI
# 5                                                GAPD
# 6                                         reverse_PGK
# 7                                PGM_1 or reverse_PGM
# 8                                                 ENO
# 9   PPS or reverse_FRUpts2pp or reverse_SBTpts or ...
# 10                                    G6PDH2r and PGL
# 11                                                GND
# 12                                                RPE
# 13                                        reverse_RPI
# 14                                               TKT2
# 15                                               TKT2
# 16                                               TKT1
# 17                                               TALA
# 18                                       reverse_TALA
# 19                                                EDA
# 20                                                EDD
# 21                                                PDH
# 22                                 CS or reverse_CITL
# 23                      ACONT or ( ACONTa and ACONTb)
# 24                                    ICDHx or ICDHyr
# 25                                     AKGDH or OOR3r
# 26  3OADPCOAT or OCOAT3r or SUCBZT1 or SUCBZT2 or ...
# 27  SUCDi or reverse_FRD2 or reverse_FRD3 or rever...
# 28                                                FUM
# 29                     MDH or MDH3 or MDH2 or DMALRED
# 30                                                ICL
# 31                                               MALS
#
#                         Reaction Location on map          Flux  \
# 0   Phenol.ext -> AcCoA + SucCoA     ( 80, -450)  1.000000e+02
# 1                    G6P <-> F6P     (-150, 430) -4.793000e-01
# 2               F6P + ATP -> FBP     (-220, 195) -2.000000e+00
# 3             FBP <-> DHAP + GAP     (-140, 115) -2.000000e+00
# 4                   DHAP <-> GAP     (-270, 150) -2.000000e+00
# 5                  GAP <-> G1,3P      (-220, 30) -1.079070e+01
# 6     G1,3P <-> 3PG + ATP + NADH     (-220, -55) -1.079070e+01
# 7                    3PG <-> 2PG    (-220, -135) -1.625380e+01
# 8                    2PG <-> PEP    (-220, -215) -1.625380e+01
# 9              PEP <-> Pyr + ATP    (-220, -295)  2.999990e+01
# 10           G6P <-> 6PG + NADPH       (50, 380) -5.767000e-01
# 11    6PG <-> Ru5P + CO2 + NADPH      (275, 350)  4.646000e-01
# 12                  Ru5P <-> X5P      (380, 190) -1.187400e+00
# 13                  Ru5P <-> R5P      (270, 230)  1.652100e+00
# 14            X5P <-> TKC2 + GAP      (270, 100) -1.187400e+00
# 15            TKC2 + E4P <-> F6P       (10, 280) -1.187400e+00
# 16            TKC2 + R5P <-> S7P      (120, 230)  2.130000e-14
# 17            TAC3 + GAP <-> F6P      (-70, 190)  7.110000e-15
# 18            S7P <-> TAC3 + E4P       (50, 230)  8.530000e-14
# 19                  6PG <-> KDPG     (-300, 350) -1.041300e+00
# 20            KDPG <-> Pyr + GAP      (-300, 50) -1.041300e+00
# 21    Pyr <-> AcCoA + CO2 + NADH    (-220, -370)  5.923270e+01
# 22            OAC + AcCoA -> Cit     (-55, -340)  1.144391e+02
# 23                   Cit -> ICit     (145, -310)  1.144391e+02
# 24     ICit -> AKG + CO2 + NADPH     (290, -310)  1.134677e+02
# 25    AKG -> SucCoA + CO2 + NADH     (290, -195)  1.086053e+02
# 26           SucCoA -> Suc + ATP      (290, -55)  2.074789e+02
# 27            Suc -> Fum + FADH2      (160, -55)  2.085767e+02
# 28                    Fum -> Mal       (10, -55)  2.096703e+02
# 29             Mal -> OAC + NADH     (-60, -180)  1.710231e+02
# 30           ICit -> Glyox + Suc     (180, -140)  9.714000e-01
# 31          Glyox + AcCoA -> Mal      (90, -140)  9.714000e-01
#
#     90% Confidence Lower Bound  90% Confidence Upper Bound  WT trans avg  \
# 0                 1.000000e+02                    100.0000      0.000000
# 1                -1.421900e+00                      0.9306    696.300330
# 2                -2.000000e+00                     -0.7683    938.587547
# 3                -2.000000e+00                     -0.7683    278.664013
# 4                -2.000000e+00                     -0.7683    121.681693
# 5                -1.122350e+01                     -9.1040    643.131200
# 6                -1.122350e+01                     -9.1040    248.181850
# 7                -1.695560e+01                    -13.6034   1127.095023
# 8                -1.695560e+01                    -13.6034    723.037943
# 9                 0.000000e+00                     30.0000  11117.591307
# 10               -2.018100e+00                      0.3824    181.511260
# 11               -1.659900e+00                      1.8755    873.934243
# 12               -2.611500e+00                     -0.2468     28.905307
# 13                9.081000e-01                      2.1385     62.698733
# 14               -2.611500e+00                     -0.2468    314.743667
# 15               -1.909000e+00                     -0.7099    314.743667
# 16               -7.076000e-01                      0.4698    314.743667
# 17               -7.076000e-01                      0.4698    727.256440
# 18               -7.076000e-01                      0.4698    727.256440
# 19               -2.524300e+00                      0.2447     35.958907
# 20               -2.524300e+00                      0.2447    209.983850
# 21                5.668260e+01                     62.0459    368.305430
# 22                1.102766e+02                    118.4800   1093.824733
# 23                1.102766e+02                    118.4800    251.281587
# 24                1.068011e+02                    118.4800   2855.736610
# 25                1.017297e+02                    113.8305     19.866243
# 26                2.005620e+02                    212.7536   1739.195597
# 27                2.032666e+02                    212.8305   1548.586137
# 28                2.043514e+02                    213.8762    722.805243
# 29                1.292999e+02                    174.5648   2379.258347
# 30                7.110000e-15                      4.5567   9159.632093
# 31                0.000000e+00                      4.5567     95.489353
#
#     WT trans std  PVHG trans avg  PVHG trans std
# 0       0.000000        0.000000        0.000000
# 1      76.069771     1850.606243      252.806202
# 2     107.143525     1425.903823      116.265138
# 3       4.119857      135.940227       10.714617
# 4      17.411032      569.054387      209.319035
# 5     304.813089     2840.484830     1720.028077
# 6      33.099830     1464.069057      795.337400
# 7      81.094821     1401.809063      347.580784
# 8     134.930480     1996.697800       99.280352
# 9    1264.572977     4677.789707      429.433164
# 10     41.685752      358.159900       47.894166
# 11    120.027203     1822.558453      464.848005
# 12      2.784289       96.499790        5.247955
# 13     15.399531      198.252433       19.919540
# 14    181.466707      439.041500      238.812829
# 15    181.466707      439.041500      238.812829
# 16    181.466707      439.041500      238.812829
# 17     90.963701      886.563040      167.278943
# 18     90.963701      886.563040      167.278943
# 19      7.318225       25.038337       10.437971
# 20      7.412740       45.654400        8.846433
# 21     14.559643       53.051980        2.674783
# 22    208.148280     3931.933930     1305.142683
# 23     24.621830      119.989907        9.819019
# 24    914.637360     5559.380250     1822.599640
# 25      3.968269        7.857423        1.046971
# 26    589.276223     6866.626290     3089.508076
# 27    660.034337     2228.401383      648.351202
# 28    128.061091      939.187710      267.966406
# 29    113.219175     5193.758543     1068.913037
# 30   4761.726973    12336.833207     8460.402936
# 31     33.619702      136.113453       46.987607

# %%
# save data to csv
phenol_fluxes.to_csv('../transcript_vs_flux_data/phenol.csv')

# %% [markdown]
# #### Plot phenol transcripts vs fluxes

# %%
plot_transcripts_vs_fluxes(phenol_fluxes, 'phenol', 'WT')
plot_transcripts_vs_fluxes(phenol_fluxes, 'phenol', 'PVHG')
