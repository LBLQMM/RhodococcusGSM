# %% [markdown]
# # Biomass composition ➟  biomass reaction
# The purpose of this notebook is to convert biomass composition measurements into biomass equations for various R. opacus strains growing on various substrates

# %%
import cobra
import pandas as pd

# %% [markdown]
# ### Get biomass composition data (.csv import is a temporary. In the future this data will be from EDD)

# %%
biomass_comp_filename = '../../EDD_Ropacus_Multiomics/EDD_Ropacus_Multiomics_BiomassComp.csv'
biomass_comp_df = pd.read_csv(biomass_comp_filename)
cols_to_drop = [col for col in biomass_comp_df.columns if 'Unnamed' in col]
biomass_comp_df.drop(cols_to_drop, inplace=True, axis=1)
biomass_comp_df.head()
# Out:
#      Line Name      Measurement Type  Time (hrs)  Value Units
# 0  RoWT_PHE-R2         Lipid Content        25.5  14.08     %
# 1  RoWT_PHE-R2  Carbohydrate Content        25.5  17.21     %
# 2  RoWT_PHE-R2       Protein Content        25.5  38.84     %
# 3    RoP1_L-R1         Lipid Content        25.5  16.44     %
# 4    RoP1_L-R1  Carbohydrate Content        25.5  12.47     %

# %% [markdown]
# ### Define a function to take in a condition name and return a dictionary of macromolecule compositions
# The 10 times multiplier makes the units mg macromolecule/g dry cell weight

# %%
def composition_name_to_dictionary(name, biomass_df):
    biomass_comp_df = biomass_df[biomass_df['Line Name'] == name]
    biomass_dictionary = {}
    for _, row in biomass_comp_df.iterrows():
        biomass_dictionary[row['Measurement Type']] = row['Value']
    return biomass_dictionary

# %%
WT_phenol_composition = composition_name_to_dictionary('RoWT_PHE-R2', biomass_comp_df)
WT_glucose_composition = composition_name_to_dictionary('RoWT_GLC-R2', biomass_comp_df)

print('WT with phenol:', WT_phenol_composition)
print('WT with glucose:', WT_glucose_composition)
# Out:
# WT with phenol: {'Lipid Content': 14.08, 'Carbohydrate Content': 17.21, 'Protein Content': 38.84}
# WT with glucose: {'Lipid Content': 40.26, 'Carbohydrate Content': 14.64, 'Protein Content': 24.04}

# %% [markdown]
# ### Pull up original biomass equation

# %%
model = cobra.io.read_sbml_model("../GSMs/Ropacus_annotated_curated_with_phenol.xml")
original_biomass_reaction = model.reactions.get_by_id('Growth')
original_biomass_reaction.reaction
# Out:
# '0.000216499790822049 10fthf_c + 0.498715520392769 ala__L_c + 0.000216499790822049 amet_c + 0.287169982631549 arg__L_c + 0.234028507069996 asn__L_c + 0.234028507069996 asp__L_c + 52.5471506268106 atp_c + 0.00505327987098101 ca2_c + 0.00505327987098101 cl_c + 0.000559210222033633 coa_c + 9.70851079919502e-05 cobalt2_c + 0.129616385977893 ctp_c + 0.000688333415662927 cu2_c + 0.088910541899028 cys__L_c + 0.0254032893571737 datp_c + 0.0262294836261852 dctp_c + 0.0262294836261852 dgtp_c + 0.0254032893571737 dttp_c + 0.000216499790822049 fad_c + 0.00651926500165946 fe2_c + 0.00758040523201147 fe3_c + 0.255489170191616 gln__L_c + 0.255489170191616 glu__L_c + 0.594780263899724 gly_c + 0.000970851079919502 gtca1_45_BS_c + 0.000970851079919502 gtca2_45_BS_c + 0.000970851079919502 gtca3_45_BS_c + 0.208826183886365 gtp_c + 47.1848449736869 h2o_c + 0.0919764896094138 his__L_c + 0.282060393397933 ile__L_c + 0.189503334842727 k_c + 0.437398507887213 leu__L_c + 4.85425539959751e-05 lipo1_24_BS_c + 4.85425539959751e-05 lipo2_24_BS_c + 4.85425539959751e-05 lipo3_24_BS_c + 4.85425539959751e-05 lipo4_24_BS_c + 0.333158227436256 lys__L_c + 0.149206219068509 met__L_c + 0.00842213311830168 mg2_c + 0.000216499790822049 mlthf_c + 0.000670858096224376 mn2_c + 9.70851079919502e-05 mql8_c + 0.00177762832733261 nad_c + 0.000433970432724018 nadp_c + 0.00970851079919502 peptido_BS_c + 0.179864725321287 phe__L_c + 0.214611485471606 pro__L_c + 0.000216499790822049 pydx5p_c + 0.000216499790822049 ribflv_c + 0.209501896237989 ser__L_c + 0.0042115519846908 so4_c + 0.000216499790822049 thf_c + 0.000216499790822049 thmpp_c + 0.246292297911539 thr__L_c + 0.0551860879358643 trp__L_c + 0.13387648051658 tyr__L_c + 0.13990352402072 utp_c + 0.410827284680896 val__L_c + 0.00033106021825255 zn2_c --> 52.3774157616572 adp_c + 52.3774157616572 h_c + 52.3732042096725 pi_c + 0.751344563302943 ppi_c'

# %% [markdown]
# ### Load dataframe with substrate metabolite information

# %%
substrate_df = pd.read_csv('../biomass_equation_data/subtitlis_biomass_equation_data.csv')
substrate_df
# Out:
#     coefficient                                               name  \
# 0      0.000216                          10-Formyltetrahydrofolate
# 1      0.498716                                          L-Alanine
# 2      0.000216                            S-Adenosyl-L-methionine
# 3      0.287170                                         L-Arginine
# 4      0.234029                                       L-Asparagine
# 5      0.234029                                        L-Aspartate
# 6     52.547151                                                ATP
# 7      0.005053                                            Calcium
# 8      0.005053                                           Chloride
# 9      0.000559                                          CoenzymeA
# 10     0.000097                                               Co2+
# 11     0.129616                                                CTP
# 12     0.000688                                               Cu2+
# 13     0.088911                                         L-Cysteine
# 14     0.025403                                               DATP
# 15     0.026229                                               DCTP
# 16     0.026229                                               DGTP
# 17     0.025403                                               DTTP
# 18     0.000216                  Flavinadeninedinucleotideoxidized
# 19     0.006519                                               Fe2+
# 20     0.007580                                               Fe3+
# 21     0.255489                                        L-Glutamine
# 22     0.255489                                        L-Glutamate
# 23     0.594780                                            Glycine
# 24     0.000971  Glycerolteichoicacidn45unlinkedunsubstitutedC1...
# 25     0.000971  Glycerolteichoicacidn45unlinkedDalasubstituted...
# 26     0.000971  Glycerolteichoicacidn45unlinkedglucosesubstitu...
# 27     0.208826                                                GTP
# 28    47.184845                                                H2O
# 29     0.091976                                        L-Histidine
# 30     0.282060                                       L-Isoleucine
# 31     0.189503                                          Potassium
# 32     0.437399                                          L-Leucine
# 33     0.000049  Lipoteichoicacidn24linkedglucosesubstitutedC26...
# 34     0.000049  Lipoteichoicacidn24linkedNacetylDglucosamineC3...
# 35     0.000049  Lipoteichoicacidn24linkedDalaninesubstitutedC1...
# 36     0.000049  Lipoteichoicacidn24linkedunsubstitutedC11836H2...
# 37     0.333158                                           L-Lysine
# 38     0.149206                                       L-Methionine
# 39     0.008422                                          Magnesium
# 40     0.000216                      510-Methylenetetrahydrofolate
# 41     0.000671                                               Mn2+
# 42     0.000097                                        Menaquinol8
# 43     0.001778                    Nicotinamideadeninedinucleotide
# 44     0.000434           Nicotinamideadeninedinucleotidephosphate
# 45     0.009709  PeptidoglycansubunitofBacillussubtilisC40H62N8O21
# 46     0.179865                                    L-Phenylalanine
# 47     0.214611                                          L-Proline
# 48     0.000216                               Pyridoxal5-phosphate
# 49     0.000216                                         Riboflavin
# 50     0.209502                                           L-Serine
# 51     0.004212                                            Sulfate
# 52     0.000216                              5678-Tetrahydrofolate
# 53     0.000216                                Thiaminediphosphate
# 54     0.246292                                        L-Threonine
# 55     0.055186                                       L-Tryptophan
# 56     0.133876                                         L-Tyrosine
# 57     0.139904                                                UTP
# 58     0.410827                                           L-Valine
# 59     0.000331                                               Zinc
#
#      abbreviation         category  molecular_weight
# 0        10fthf_c   carbon carrier           471.430
# 1        ala__L_c          protein            89.094
# 2          amet_c   carbon carrier           399.446
# 3        arg__L_c          protein           175.212
# 4        asn__L_c          protein           132.119
# 5        asp__L_c          protein           132.095
# 6           atp_c  energy molecule           503.150
# 7           ca2_c             salt            40.078
# 8            cl_c             salt            35.450
# 9           coa_c   carbon carrier           763.502
# 10      cobalt2_c             salt            58.933
# 11          ctp_c  energy molecule           479.124
# 12          cu2_c             salt            63.546
# 13       cys__L_c          protein           121.154
# 14         datp_c          nucleic           487.151
# 15         dctp_c          nucleic           463.125
# 16         dgtp_c          nucleic           503.150
# 17         dttp_c          nucleic           478.136
# 18          fad_c  energy molecule           783.541
# 19          fe2_c             salt            55.845
# 20          fe3_c             salt            55.845
# 21       gln__L_c          protein           146.146
# 22       glu__L_c          protein           146.122
# 23          gly_c          protein            75.067
# 24  gtca1_45_BS_c            lipid          7373.617
# 25  gtca2_45_BS_c            lipid         11382.847
# 26  gtca3_45_BS_c            lipid         14687.977
# 27          gtp_c  energy molecule           519.149
# 28          h2o_c            water            18.015
# 29       his__L_c          protein           155.157
# 30       ile__L_c          protein           131.175
# 31            k_c             salt            39.098
# 32       leu__L_c          protein           131.175
# 33  lipo1_24_BS_c            lipid        844881.272
# 34  lipo2_24_BS_c            lipid        943408.472
# 35  lipo3_24_BS_c            lipid        669568.472
# 36  lipo4_24_BS_c            lipid        455742.872
# 37       lys__L_c          protein           147.198
# 38       met__L_c          protein           149.208
# 39          mg2_c             salt            24.305
# 40        mlthf_c   carbon carrier           455.431
# 41          mn2_c             salt            54.938
# 42         mql8_c  energy molecule           719.151
# 43          nad_c  energy molecule           662.422
# 44         nadp_c  energy molecule           740.385
# 45   peptido_BS_c     carbohydrate           990.971
# 46       phe__L_c          protein           165.192
# 47       pro__L_c          protein           115.132
# 48       pydx5p_c  energy molecule           245.127
# 49       ribflv_c  energy molecule           376.369
# 50       ser__L_c          protein           105.093
# 51          so4_c             salt            96.056
# 52          thf_c   carbon carrier           443.420
# 53        thmpp_c  energy molecule           422.289
# 54       thr__L_c          protein           119.120
# 55       trp__L_c          protein           204.229
# 56       tyr__L_c          protein           181.191
# 57          utp_c  energy molecule           480.108
# 58       val__L_c          protein           117.148
# 59          zn2_c             salt            65.380

# %% [markdown]
# ### Calculate the macromolecule distribution in the Subtilis biomass equation

# %%
subtilis_mg_protein = 0
subtilis_mg_lipid = 0
subtilis_mg_carbohydrate = 0

for met in list(substrate_df['abbreviation']):
    met_category = list(substrate_df[substrate_df['abbreviation'] == met]['category'])[0]
    met_molar_mass = list(substrate_df[substrate_df['abbreviation'] == met]['molecular_weight'])[0]
    met_coefficient = list(substrate_df[substrate_df['abbreviation'] == met]['coefficient'])[0]
    
    if met_category == 'protein':
        subtilis_mg_protein += met_molar_mass*met_coefficient
    if met_category == 'lipid':
        subtilis_mg_lipid += met_molar_mass*met_coefficient
    if met_category == 'carbohydrate':
        subtilis_mg_carbohydrate += met_molar_mass*met_coefficient

print(f'subtiltis mg of protein / g dry cell weight: {subtilis_mg_protein:.2f} mg')
print(f'subtiltis mg of lipid / g dry cell weight: {subtilis_mg_lipid:.2f} mg')
print(f'subtiltis mg of carbohydrate / g dry cell weight: {subtilis_mg_carbohydrate:.2f} mg')
# Out:
# subtiltis mg of protein / g dry cell weight: 656.05 mg
# subtiltis mg of lipid / g dry cell weight: 175.24 mg
# subtiltis mg of carbohydrate / g dry cell weight: 9.62 mg

# %% [markdown]
# ### Make Phenol Biomass Equation

# %% [markdown]
# Calculate the scaling factor for each macromolecule

# %%
ropacus_phenol_mg_protein = 10* WT_phenol_composition['Protein Content']
ropacus_phenol_mg_lipid = 10* WT_phenol_composition['Lipid Content']
ropacus_phenol_mg_carbohydrate = 10* WT_phenol_composition['Carbohydrate Content']

lipid_multiplier = ropacus_phenol_mg_protein / subtilis_mg_lipid
protein_multiplier = ropacus_phenol_mg_lipid/ subtilis_mg_protein
carbohydrate_multiplier = ropacus_phenol_mg_carbohydrate/ subtilis_mg_carbohydrate

# print(f'R. opacus phenol mg of protein / g dry cell weight: {ropacus_phenol_mg_protein:.2f} mg')
# print(f'R. opacus phenol mg of lipid / g dry cell weight: {ropacus_phenol_mg_lipid:.2f} mg')
# print(f'R. opacus phenol mg of carbohydrate / g dry cell weight: {ropacus_phenol_mg_carbohydrate:.2f} mg\n')

print(f'The lipid content is {lipid_multiplier:.3f} times higher in R. opacus with phenol than in B. Subtilis.')
print(f'The protein content is {protein_multiplier:.3f} times higher in R. opacus with phenol than in B. Subtilis.')
print(f'The carbohydrate content is {carbohydrate_multiplier:.3f} times higher in R. opacus with phenol than in B. Subtilis.')
# Out:
# The lipid content is 2.216 times higher in R. opacus with phenol than in B. Subtilis.
# The protein content is 0.215 times higher in R. opacus with phenol than in B. Subtilis.
# The carbohydrate content is 17.887 times higher in R. opacus with phenol than in B. Subtilis.

# %% [markdown]
# Create a new reaction for phenol biomass

# %%
# phenol_growth_equation = model.reactions.get_by_id('Growth').copy()
phenol_growth_equation = cobra.Reaction()
phenol_growth_equation.name = 'Phenol biomass reaction'
phenol_growth_equation.id = 'Growth_Phenol'
phenol_growth_equation
# Out:
# <Reaction Growth_Phenol at 0x7fac6388e790>

# %%
for met in list(model.reactions.get_by_id('Growth').metabolites):
    print(met)
# list(model.reactions.get_by_id('Growth').metabolites)
# Out:
# 10fthf_c
# ala__L_c
# amet_c
# arg__L_c
# asn__L_c
# asp__L_c
# atp_c
# ca2_c
# cl_c
# coa_c
# cobalt2_c
# ctp_c
# cu2_c
# cys__L_c
# datp_c
# dctp_c
# dgtp_c
# dttp_c
# fad_c
# fe2_c
# fe3_c
# gln__L_c
# glu__L_c
# gly_c
# gtca1_45_BS_c
# gtca2_45_BS_c
# gtca3_45_BS_c
# gtp_c
# h2o_c
# his__L_c
# ile__L_c
# k_c
# leu__L_c
# lipo1_24_BS_c
# lipo2_24_BS_c
# lipo3_24_BS_c
# lipo4_24_BS_c
# lys__L_c
# met__L_c
# mg2_c
# mlthf_c
# mn2_c
# mql8_c
# nad_c
# nadp_c
# peptido_BS_c
# phe__L_c
# pro__L_c
# pydx5p_c
# ribflv_c
# ser__L_c
# so4_c
# thf_c
# thmpp_c
# thr__L_c
# trp__L_c
# tyr__L_c
# utp_c
# val__L_c
# zn2_c
# adp_c
# h_c
# pi_c
# ppi_c

# %%
metabolites_to_add = {}

# for met in list(substrate_df['abbreviation']):
for met in list(model.reactions.get_by_id('Growth').metabolites):
    met_category = list(substrate_df[substrate_df['abbreviation'] == met]['category'])[0]
    met_subtilis_coefficient = list(substrate_df[substrate_df['abbreviation'] == met]['coefficient'])[0]
    metabolite = model.metabolites.get_by_id(met)
    
    if met_category == 'protein':
        met_ropacus_coefficient = protein_multiplier*met_subtilis_coefficient
    elif met_category == 'lipid':
        met_ropacus_coefficient = lipid_multiplier*met_subtilis_coefficient
    elif met_category == 'carbohydrate':
        met_ropacus_coefficient = carbohydrate_multiplier*met_subtilis_coefficient
    else:
        met_ropacus_coefficient = met_subtilis_coefficient
        
    metabolites_to_add[metabolite] = met_ropacus_coefficient
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-6709a8770bf2> in <module>
#       3 # for met in list(substrate_df['abbreviation']):
#       4 for met in list(model.reactions.get_by_id('Growth').metabolites):
# ----> 5     met_category = list(substrate_df[substrate_df['abbreviation'] == met]['category'])[0]
#       6     met_subtilis_coefficient = list(substrate_df[substrate_df['abbreviation'] == met]['coefficient'])[0]
#       7     metabolite = model.metabolites.get_by_id(met)
#
# IndexError: list index out of range

# %%
metabolites_to_add
# Out:
# {<Metabolite 10fthf_c at 0x7fac66b27a90>: 0.00021600000000000002,
#  <Metabolite ala__L_c at 0x7fac66a66ed0>: 0.10703270532982996,
#  <Metabolite amet_c at 0x7fac66b0e3d0>: 0.00021600000000000002,
#  <Metabolite arg__L_c at 0x7fac669b5b50>: 0.06163143350036347,
#  <Metabolite asn__L_c at 0x7fac669af110>: 0.05022649563205266,
#  <Metabolite asp__L_c at 0x7fac66a56050>: 0.05022649563205266,
#  <Metabolite atp_c at 0x7fac66b371d0>: 52.547151,
#  <Metabolite ca2_c at 0x7fac669282d0>: 0.005053,
#  <Metabolite cl_c at 0x7fac66a72390>: 0.005053,
#  <Metabolite coa_c at 0x7fac66b4a710>: 0.000559,
#  <Metabolite cobalt2_c at 0x7fac6694de10>: 9.7e-05,
#  <Metabolite ctp_c at 0x7fac66a44e90>: 0.129616,
#  <Metabolite cu2_c at 0x7fac66992dd0>: 0.000688,
#  <Metabolite cys__L_c at 0x7fac66a88c90>: 0.0190817717169301,
#  <Metabolite datp_c at 0x7fac669ec4d0>: 0.025403,
#  <Metabolite dctp_c at 0x7fac66907090>: 0.026229000000000002,
#  <Metabolite dgtp_c at 0x7fac669f0250>: 0.026229000000000002,
#  <Metabolite dttp_c at 0x7fac668c07d0>: 0.025403,
#  <Metabolite fad_c at 0x7fac66a658d0>: 0.00021600000000000002,
#  <Metabolite fe2_c at 0x7fac6696ad10>: 0.006519,
#  <Metabolite fe3_c at 0x7fac668dea50>: 0.00758,
#  <Metabolite gln__L_c at 0x7fac66a88750>: 0.05483216670813233,
#  <Metabolite glu__L_c at 0x7fac66b37910>: 0.05483216670813233,
#  <Metabolite gly_c at 0x7fac66999590>: 0.12764962919993797,
#  <Metabolite gtca1_45_BS_c at 0x7fac66737f90>: 0.0021521013239706715,
#  <Metabolite gtca2_45_BS_c at 0x7fac66739610>: 0.0021521013239706715,
#  <Metabolite gtca3_45_BS_c at 0x7fac66739810>: 0.0021521013239706715,
#  <Metabolite gtp_c at 0x7fac66b04c10>: 0.208826,
#  <Metabolite h2o_c at 0x7fac66b3cf90>: 47.184845,
#  <Metabolite his__L_c at 0x7fac66a8c810>: 0.019739571430265803,
#  <Metabolite ile__L_c at 0x7fac66989b10>: 0.060534742950560716,
#  <Metabolite k_c at 0x7fac6697e690>: 0.189503,
#  <Metabolite leu__L_c at 0x7fac66b0ea90>: 0.09387306258183474,
#  <Metabolite lipo1_24_BS_c at 0x7fac66811050>: 0.00010860243550418423,
#  <Metabolite lipo2_24_BS_c at 0x7fac668112d0>: 0.00010860243550418423,
#  <Metabolite lipo3_24_BS_c at 0x7fac668114d0>: 0.00010860243550418423,
#  <Metabolite lipo4_24_BS_c at 0x7fac668116d0>: 0.00010860243550418423,
#  <Metabolite lys__L_c at 0x7fac66961d50>: 0.07150121921549638,
#  <Metabolite met__L_c at 0x7fac6699c810>: 0.03202207635496477,
#  <Metabolite mg2_c at 0x7fac6694a510>: 0.008422,
#  <Metabolite mlthf_c at 0x7fac668b5ad0>: 0.00021600000000000002,
#  <Metabolite mn2_c at 0x7fac6694c3d0>: 0.000671,
#  <Metabolite mql8_c at 0x7fac669d21d0>: 9.7e-05,
#  <Metabolite nad_c at 0x7fac66b47950>: 0.001778,
#  <Metabolite nadp_c at 0x7fac66b4aad0>: 0.000434,
#  <Metabolite peptido_BS_c at 0x7fac6677e5d0>: 0.17366804881273015,
#  <Metabolite phe__L_c at 0x7fac66973a10>: 0.038602005037235355,
#  <Metabolite pro__L_c at 0x7fac669d4f90>: 0.0460590715428022,
#  <Metabolite pydx5p_c at 0x7fac669b4d10>: 0.00021600000000000002,
#  <Metabolite ribflv_c at 0x7fac66a7d850>: 0.00021600000000000002,
#  <Metabolite ser__L_c at 0x7fac66a8a410>: 0.04496259560954539,
#  <Metabolite so4_c at 0x7fac66974190>: 0.004212,
#  <Metabolite thf_c at 0x7fac669a0ed0>: 0.00021600000000000002,
#  <Metabolite thmpp_c at 0x7fac66a3fa50>: 0.00021600000000000002,
#  <Metabolite thr__L_c at 0x7fac66a8ab50>: 0.05285833833503333,
#  <Metabolite trp__L_c at 0x7fac6685d990>: 0.011843828704777862,
#  <Metabolite tyr__L_c at 0x7fac668615d0>: 0.0287320047055565,
#  <Metabolite utp_c at 0x7fac668f8290>: 0.139904,
#  <Metabolite val__L_c at 0x7fac6685de50>: 0.08817027172286042,
#  <Metabolite zn2_c at 0x7fac6694fa90>: 0.000331}

# %% [markdown]
# ### Add glucose biomass equation to model
