# %% [markdown]
# # Predict metabolic flux distribution from transcriptomics data using E-Flux2 and Random Forest

# %% [markdown]
# ### Load libraries

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from scipy.optimize import minimize
from sklearn.ensemble import RandomForestRegressor
import numpy as np
import pandas as pd
import seaborn as sns
import cobra
import cplex

# %% [markdown]
# ### Load a metabolic model and parse gene-reaction rules

# %%
model = cobra.io.read_sbml_model("/scratch/garrettroell/OpacusBiodesign/Biodesign_gr/GSMs/Ropacus_annotated_curated.xml")

# %%
mets = [m.id for m in model.metabolites]
rxns = [r.id for r in model.reactions]
nrow = len(mets)
ncol = len(rxns)
print(nrow, ncol)
# Out:
# 1581 2380

# %%
c = [r.objective_coefficient for r in model.reactions]
S = cobra.util.create_stoichiometric_matrix(model, array_type='DataFrame')

# %%
for r in model.reactions:
    if r.objective_coefficient !=0:
        print(r.id)
# Out:
# Growth

# %% [markdown]
# The keys of gpr_dict are reaction ids and the values are gene-product-reactions. Genes that have 'or' relations are split into separate frozen sets, while genes that have 'and' connections are put into the same frozen set.
#
# Some GPRs and their associated values in the gpr_dict are: (These examples are from E. coli model iJO1366)
# 1. b4036 --> {frozenset({'b4036'})}
# 2. (b0241 or b0929 or b1377 or b2215) --> {frozenset({'b0241'}), frozenset({'b1377'}), frozenset({'b0929'}), frozenset({'b2215'})}
# 3. (b4034 and b4033 and b4032 and b4035) --> {frozenset({'b4035', 'b4034', 'b4033', 'b4032'})}

# %%
gpr_dict = dict()
for r in model.reactions:
    if r.gene_reaction_rule:
        temp = set()
        for x in [x.strip('() ') for x in r.gene_reaction_rule.split(' or ')]:
            temp.add(frozenset(y.strip('() ') for y in x.split(' and ')))
        gpr_dict[r.id] = temp

# %%
gpr_dict
# Out:
# {'12PPDStpp': {frozenset({'WP_187300246_1'})},
#  '12PPDt': {frozenset({'WP_187300246_1'})},
#  '14GLUCANabcpp': {frozenset({'WP_005249637_1', 'WP_025432775_1'}),
#   frozenset({'WP_005248578_1', 'WP_025433613_1'}),
#   frozenset({'WP_005248578_1', 'WP_025432775_1'})},
#  '2AGPEAT120': {frozenset({'WP_005248999_1'})},
#  '2AGPEAT140': {frozenset({'WP_005248999_1'})},
#  '2AGPEAT141': {frozenset({'WP_005248999_1'})},
#  '2AGPEAT160': {frozenset({'WP_005248999_1'})},
#  '2AGPEAT161': {frozenset({'WP_005248999_1'})},
#  '2AGPEAT180': {frozenset({'WP_005248999_1'})},
#  '2AGPEAT181': {frozenset({'WP_005248999_1'})},
#  '2AGPGAT120': {frozenset({'WP_005248999_1'})},
#  '2AGPGAT140': {frozenset({'WP_005248999_1'})},
#  '2AGPGAT141': {frozenset({'WP_005248999_1'})},
#  '2AGPGAT160': {frozenset({'WP_005248999_1'})},
#  '2AGPGAT161': {frozenset({'WP_005248999_1'})},
#  '2AGPGAT180': {frozenset({'WP_005248999_1'})},
#  '2AGPGAT181': {frozenset({'WP_005248999_1'})},
#  '2DHGLCK': {frozenset({'WP_025433301_1'})},
#  '2DHGLCNkt_tpp': {frozenset({'WP_005246696_1'})},
#  '2HH24DDH': {frozenset({'WP_005244822_1'})},
#  '2HH24DDH1': {frozenset({'WP_005244822_1'})},
#  '3_4DHBZ1t_pp': {frozenset({'WP_080578199_1'})},
#  '34HPPOR': {frozenset({'WP_005252000_1'}), frozenset({'WP_005250095_1'})},
#  '3AMACHYD': {frozenset({'WP_005239747_1'}), frozenset({'WP_005245250_1'})},
#  '3HBCOAHL': {frozenset({'WP_005241234_1'}), frozenset({'WP_005239921_1'})},
#  '3HCINNMH': {frozenset({'WP_005237913_1'})},
#  '3HOXPACt2pp': {frozenset({'WP_005248143_1'}), frozenset({'WP_025433549_1'})},
#  '3hoxpactex': {frozenset({'WP_025432619_1'})},
#  '3HPAOX': {frozenset({'WP_025433337_1'}),
#   frozenset({'WP_005251125_1', 'WP_025433337_1'})},
#  '3HPPPNH': {frozenset({'WP_005237913_1'})},
#  '3MBt2pp': {frozenset({'WP_005243991_1'})},
#  '3MBt4pp': {frozenset({'WP_005243991_1'})},
#  '3MBZALDH': {frozenset({'WP_025433317_1'})},
#  '3MBZDH': {frozenset({'WP_005250914_1'})},
#  '3MCAT23DOX': {frozenset({'WP_005237880_1'})},
#  '3OADPCOAT': {frozenset({'WP_005244597_1'})},
#  '3OAR100': {frozenset({'WP_005246520_1'}),
#   frozenset({'WP_005241305_1'}),
#   frozenset({'WP_005245262_1'}),
#   frozenset({'WP_005248537_1'}),
#   frozenset({'WP_005248746_1'}),
#   frozenset({'WP_025433919_1'}),
#   frozenset({'WP_005252932_1'})},
#  '3OAR120': {frozenset({'WP_005246520_1'}),
#   frozenset({'WP_005241305_1'}),
#   frozenset({'WP_005245262_1'}),
#   frozenset({'WP_005248537_1'}),
#   frozenset({'WP_005248746_1'}),
#   frozenset({'WP_025433919_1'}),
#   frozenset({'WP_005252932_1'})},
#  '3OAR121': {frozenset({'WP_005246520_1'}),
#   frozenset({'WP_005241305_1'}),
#   frozenset({'WP_005245262_1'}),
#   frozenset({'WP_005248537_1'}),
#   frozenset({'WP_005248746_1'}),
#   frozenset({'WP_025433919_1'}),
#   frozenset({'WP_005252932_1'})},
#  '3OAR140': {frozenset({'WP_005246520_1'}),
#   frozenset({'WP_005241305_1'}),
#   frozenset({'WP_005245262_1'}),
#   frozenset({'WP_005248537_1'}),
#   frozenset({'WP_005248746_1'}),
#   frozenset({'WP_025433919_1'}),
#   frozenset({'WP_005252932_1'})},
#  '3OAR141': {frozenset({'WP_005246520_1'}),
#   frozenset({'WP_005241305_1'}),
#   frozenset({'WP_005245262_1'}),
#   frozenset({'WP_005248537_1'}),
#   frozenset({'WP_005248746_1'}),
#   frozenset({'WP_025433919_1'}),
#   frozenset({'WP_005252932_1'})},
#  '3OAR160': {frozenset({'WP_005246520_1'}),
#   frozenset({'WP_005241305_1'}),
#   frozenset({'WP_005245262_1'}),
#   frozenset({'WP_005248537_1'}),
#   frozenset({'WP_005248746_1'}),
#   frozenset({'WP_025433919_1'}),
#   frozenset({'WP_005252932_1'})},
#  '3OAR161': {frozenset({'WP_005246520_1'}),
#   frozenset({'WP_005241305_1'}),
#   frozenset({'WP_005245262_1'}),
#   frozenset({'WP_005248537_1'}),
#   frozenset({'WP_005248746_1'}),
#   frozenset({'WP_025433919_1'}),
#   frozenset({'WP_005252932_1'})},
#  '3OAR180': {frozenset({'WP_005246520_1'}),
#   frozenset({'WP_005241305_1'}),
#   frozenset({'WP_005245262_1'}),
#   frozenset({'WP_005248537_1'}),
#   frozenset({'WP_005248746_1'}),
#   frozenset({'WP_025433919_1'}),
#   frozenset({'WP_005252932_1'})},
#  '3OAR181': {frozenset({'WP_005246520_1'}),
#   frozenset({'WP_005241305_1'}),
#   frozenset({'WP_005245262_1'}),
#   frozenset({'WP_005248537_1'}),
#   frozenset({'WP_005248746_1'}),
#   frozenset({'WP_025433919_1'}),
#   frozenset({'WP_005252932_1'})},
#  '3OAR40': {frozenset({'WP_005246520_1'}),
#   frozenset({'WP_005241305_1'}),
#   frozenset({'WP_005245262_1'}),
#   frozenset({'WP_005248537_1'}),
#   frozenset({'WP_005248746_1'}),
#   frozenset({'WP_025433919_1'}),
#   frozenset({'WP_005252932_1'})},
#  '3OAR60': {frozenset({'WP_005246520_1'}),
#   frozenset({'WP_005241305_1'}),
#   frozenset({'WP_005245262_1'}),
#   frozenset({'WP_005248537_1'}),
#   frozenset({'WP_005248746_1'}),
#   frozenset({'WP_025433919_1'}),
#   frozenset({'WP_005252932_1'})},
#  '3OAR80': {frozenset({'WP_005246520_1'}),
#   frozenset({'WP_005241305_1'}),
#   frozenset({'WP_005245262_1'}),
#   frozenset({'WP_005248537_1'}),
#   frozenset({'WP_005248746_1'}),
#   frozenset({'WP_025433919_1'}),
#   frozenset({'WP_005252932_1'})},
#  '3OAS100': {frozenset({'WP_005246169_1'})},
#  '3OAS120': {frozenset({'WP_005246169_1'})},
#  '3OAS121': {frozenset({'WP_005246169_1'})},
#  '3OAS140': {frozenset({'WP_005246169_1'})},
#  '3OAS141': {frozenset({'WP_005246169_1'})},
#  '3OAS160': {frozenset({'WP_005246169_1'})},
#  '3OAS161': {frozenset({'WP_005246169_1'})},
#  '3OAS180': {frozenset({'WP_005246169_1'})},
#  '3OAS181': {frozenset({'WP_005246169_1'})},
#  '3OAS60': {frozenset({'WP_005246169_1'})},
#  '3OAS80': {frozenset({'WP_005246169_1'})},
#  '3OXCOAT': {frozenset({'WP_005250766_1'}), frozenset({'WP_005251119_1'})},
#  '3OXOADPt_pp': {frozenset({'WP_005241413_1'})},
#  '3PEPTabcpp': {frozenset({'WP_005237762_1',
#              'WP_005237763_1',
#              'WP_005238098_1'}),
#   frozenset({'WP_005237762_1',
#              'WP_005237763_1',
#              'WP_005243360_1',
#              'WP_005248478_1'}),
#   frozenset({'WP_005237762_1',
#              'WP_005237763_1',
#              'WP_005238098_1',
#              'WP_005248478_1'})},
#  '4ABUTD': {frozenset({'WP_005239499_1'})},
#  '4CMLCL_kt': {frozenset({'WP_025433264_1'})},
#  '4H2KPILY': {frozenset({'WP_025432001_1'}), frozenset({'WP_005243411_1'})},
#  '4HBCOAH': {frozenset({'WP_025433939_1'})},
#  '4HBHYOX': {frozenset({'WP_005251081_1'})},
#  '4HBZR': {frozenset({'WP_005250106_1', 'WP_025431770_1', 'WP_025433439_1'})},
#  '4HOXPACMOF': {frozenset({'WP_005251125_1'})},
#  '4HOXPACt2pp': {frozenset({'WP_005242497_1'}),
#   frozenset({'WP_025433549_1'}),
#   frozenset({'WP_025432012_1'}),
#   frozenset({'WP_005243329_1'}),
#   frozenset({'WP_005248143_1'})},
#  '4HTHRS': {frozenset({'WP_005252945_1'})},
#  '4MBZALDH': {frozenset({'WP_025433317_1'})},
#  '4MBZDH': {frozenset({'WP_005250914_1'})},
#  '4MCAT23DOX': {frozenset({'WP_005237880_1'})},
#  '4OD': {frozenset({'WP_005238985_1'})},
#  '4OD2': {frozenset({'WP_005238985_1'})},
#  '4PEPTabcpp': {frozenset({'WP_005237762_1',
#              'WP_005237763_1',
#              'WP_005238098_1'}),
#   frozenset({'WP_005237762_1',
#              'WP_005237763_1',
#              'WP_005243360_1',
#              'WP_005248478_1'}),
#   frozenset({'WP_005237762_1',
#              'WP_005237763_1',
#              'WP_005238098_1',
#              'WP_005248478_1'})},
#  '5DGLCNR': {frozenset({'WP_005250033_1'}), frozenset({'WP_005245383_1'})},
#  'AACPS1': {frozenset({'WP_005248999_1'})},
#  'AACPS2': {frozenset({'WP_005248999_1'})},
#  'AACPS3': {frozenset({'WP_005248999_1'})},
#  'AACPS4': {frozenset({'WP_005248999_1'})},
#  'AACPS5': {frozenset({'WP_005248999_1'})},
#  'AACPS6': {frozenset({'WP_005248999_1'})},
#  'AACPS7': {frozenset({'WP_005248999_1'})},
#  'AACPS8': {frozenset({'WP_005248999_1'})},
#  'AACPS9': {frozenset({'WP_005248999_1'})},
#  'AAMYL': {frozenset({'WP_080578204_1'})},
#  'ABTA': {frozenset({'WP_005245861_1'}),
#   frozenset({'WP_005244800_1'}),
#   frozenset({'WP_005238605_1'}),
#   frozenset({'WP_005239956_1'})},
#  'ABUTD': {frozenset({'WP_005238606_1'}), frozenset({'WP_005251153_1'})},
#  'ABUTt2pp': {frozenset({'WP_005239220_1'}), frozenset({'WP_005251210_1'})},
#  'ABUTt2r': {frozenset({'WP_005246592_1'}), frozenset({'WP_005251210_1'})},
#  'ACACCT': {frozenset({'WP_005251310_1'}),
#   frozenset({'WP_005244597_1', 'WP_005251310_1'}),
#   frozenset({'WP_005241236_1'}),
#   frozenset({'WP_005241236_1', 'WP_005251310_1'})},
#  'ACACT1r': {frozenset({'WP_005243703_1'}),
#   frozenset({'WP_005238450_1'}),
#   frozenset({'WP_005242715_1'}),
#   frozenset({'WP_005248351_1'}),
#   frozenset({'WP_005249328_1'}),
#   frozenset({'WP_005252295_1'}),
#   frozenset({'WP_005244682_1'}),
#   frozenset({'WP_005251119_1'}),
#   frozenset({'WP_005250252_1'}),
#   frozenset({'WP_025431983_1'}),
#   frozenset({'WP_143767565_1'}),
#   frozenset({'WP_005250766_1'}),
#   frozenset({'WP_005243389_1'})},
#  'ACACt2': {frozenset({'WP_005251827_1'})},
#  'ACACt2pp': {frozenset({'WP_005251827_1'})},
#  'ACACT2r': {frozenset({'WP_005243703_1'}),
#   frozenset({'WP_005238450_1'}),
#   frozenset({'WP_005242715_1'}),
#   frozenset({'WP_005249328_1'}),
#   frozenset({'WP_005244682_1'}),
#   frozenset({'WP_005251119_1'}),
#   frozenset({'WP_025431983_1'}),
#   frozenset({'WP_143767565_1'})},
#  'ACACT3r': {frozenset({'WP_005243703_1'}),
#   frozenset({'WP_005238450_1'}),
#   frozenset({'WP_005242715_1'}),
#   frozenset({'WP_005249328_1'}),
#   frozenset({'WP_005244682_1'}),
#   frozenset({'WP_005251119_1'}),
#   frozenset({'WP_025431983_1'}),
#   frozenset({'WP_143767565_1'})},
#  'ACACT4r': {frozenset({'WP_005243703_1'}),
#   frozenset({'WP_005238450_1'}),
#   frozenset({'WP_005242715_1'}),
#   frozenset({'WP_005249328_1'}),
#   frozenset({'WP_005244682_1'}),
#   frozenset({'WP_005251119_1'}),
#   frozenset({'WP_025431983_1'}),
#   frozenset({'WP_143767565_1'})},
#  'ACACT5r': {frozenset({'WP_005243703_1'}),
#   frozenset({'WP_005238450_1'}),
#   frozenset({'WP_005242715_1'}),
#   frozenset({'WP_005249328_1'}),
#   frozenset({'WP_005244682_1'}),
#   frozenset({'WP_005251119_1'}),
#   frozenset({'WP_025431983_1'}),
#   frozenset({'WP_143767565_1'})},
#  'ACACT5r_1': {frozenset({'WP_005249328_1'})},
#  'ACACT6r': {frozenset({'WP_005243703_1'}),
#   frozenset({'WP_005238450_1'}),
#   frozenset({'WP_005242715_1'}),
#   frozenset({'WP_005249328_1'}),
#   frozenset({'WP_005244682_1'}),
#   frozenset({'WP_005251119_1'}),
#   frozenset({'WP_025431983_1'}),
#   frozenset({'WP_143767565_1'})},
#  'ACACT6r_1': {frozenset({'WP_005249328_1'})},
#  'ACACT7r': {frozenset({'WP_005243703_1'}),
#   frozenset({'WP_005238450_1'}),
#   frozenset({'WP_005242715_1'}),
#   frozenset({'WP_005249328_1'}),
#   frozenset({'WP_005244682_1'}),
#   frozenset({'WP_005251119_1'}),
#   frozenset({'WP_025431983_1'}),
#   frozenset({'WP_143767565_1'})},
#  'ACACT8r': {frozenset({'WP_005243703_1'}),
#   frozenset({'WP_005238450_1'}),
#   frozenset({'WP_005242715_1'}),
#   frozenset({'WP_005244682_1'}),
#   frozenset({'WP_005251119_1'}),
#   frozenset({'WP_143767565_1'})},
#  'ACALD': {frozenset({'WP_025433818_1'}), frozenset({'WP_025431774_1'})},
#  'ACALDt': {frozenset({'spontaneous'})},
#  'ACCOAC': {frozenset({'WP_025432470_1'}),
#   frozenset({'WP_005250640_1'}),
#   frozenset({'WP_005248832_1'}),
#   frozenset({'WP_005239994_1'}),
#   frozenset({'WP_005239994_1', 'WP_025431917_1'})},
#  'ACCOAL': {frozenset({'WP_143767522_1'}), frozenset({'WP_005250868_1'})},
#  'ACGAMPM': {frozenset({'WP_005239736_1'})},
#  'ACGApts': {frozenset({'WP_005252854_1'}),
#   frozenset({'WP_005252854_1', 'WP_025432990_1'}),
#   frozenset({'WP_005252852_1', 'WP_005252854_1', 'WP_025432990_1'})},
#  'ACGAptspp': {frozenset({'WP_005252852_1'}),
#   frozenset({'WP_005252852_1', 'WP_005252854_1'}),
#   frozenset({'WP_005252854_1', 'WP_025432990_1'}),
#   frozenset({'WP_005252852_1', 'WP_005252854_1', 'WP_025432990_1'})},
#  'ACGK': {frozenset({'WP_005247368_1'})},
#  'ACGS': {frozenset({'WP_005240737_1'}), frozenset({'WP_005247369_1'})},
#  'ACHBS': {frozenset({'WP_080578309_1'}),
#   frozenset({'WP_005249200_1'}),
#   frozenset({'WP_005244751_1'}),
#   frozenset({'WP_037181410_1'}),
#   frozenset({'WP_005244775_1'}),
#   frozenset({'WP_025433810_1'})},
#  'ACKr': {frozenset({'WP_005251699_1'}), frozenset({'WP_037183117_1'})},
#  'ACLS': {frozenset({'WP_080578309_1'}),
#   frozenset({'WP_005249200_1'}),
#   frozenset({'WP_037181780_1'}),
#   frozenset({'WP_005244751_1'}),
#   frozenset({'WP_005240383_1'}),
#   frozenset({'WP_037181410_1'}),
#   frozenset({'WP_005244775_1'}),
#   frozenset({'WP_005240381_1', 'WP_005240383_1'}),
#   frozenset({'WP_025433810_1'}),
#   frozenset({'WP_005240383_1', 'WP_080578309_1'})},
#  'ACMANApts': {frozenset({'WP_025432990_1'})},
#  'ACNAMt2': {frozenset({'WP_005249307_1'}), frozenset({'WP_005245604_1'})},
#  'ACNML': {frozenset({'WP_005243568_1'})},
#  'ACOAD1': {frozenset({'WP_005250947_1'}),
#   frozenset({'WP_005243899_1'}),
#   frozenset({'WP_005239548_1'}),
#   frozenset({'WP_005250612_1'})},
#  'ACOAD1f': {frozenset({'WP_005241270_1'}),
#   frozenset({'WP_005252874_1'}),
#   frozenset({'WP_005245270_1'}),
#   frozenset({'WP_005244551_1'}),
#   frozenset({'WP_005252230_1'}),
#   frozenset({'WP_005252736_1'}),
#   frozenset({'WP_005243698_1'}),
#   frozenset({'WP_005245237_1'})},
#  'ACOAD2': {frozenset({'WP_005250947_1'}),
#   frozenset({'WP_005243899_1'}),
#   frozenset({'WP_005250612_1'})},
#  'ACOAD20': {frozenset({'WP_005250612_1'}), frozenset({'WP_005239548_1'})},
#  'ACOAD2f': {frozenset({'WP_005241270_1'}),
#   frozenset({'WP_005252874_1'}),
#   frozenset({'WP_005245270_1'}),
#   frozenset({'WP_005244551_1'}),
#   frozenset({'WP_005252230_1'}),
#   frozenset({'WP_005252736_1'}),
#   frozenset({'WP_005243698_1'}),
#   frozenset({'WP_005245237_1'})},
#  'ACOAD3f': {frozenset({'WP_005252874_1'}),
#   frozenset({'WP_005245270_1'}),
#   frozenset({'WP_005244551_1'}),
#   frozenset({'WP_005252230_1'}),
#   frozenset({'WP_005252736_1'}),
#   frozenset({'WP_005243698_1'}),
#   frozenset({'WP_005245237_1'})},
#  'ACOAD4_1': {frozenset({'WP_005250947_1'}), frozenset({'WP_005243899_1'})},
#  'ACOAD4f': {frozenset({'WP_005252874_1'}),
#   frozenset({'WP_005245270_1'}),
#   frozenset({'WP_005244551_1'}),
#   frozenset({'WP_005252230_1'}),
#   frozenset({'WP_005252736_1'}),
#   frozenset({'WP_005243698_1'}),
#   frozenset({'WP_005245237_1'})},
#  'ACOAD5_1': {frozenset({'WP_005250947_1'}), frozenset({'WP_005243899_1'})},
#  'ACOAD5f': {frozenset({'WP_005252874_1'}),
#   frozenset({'WP_005245270_1'}),
#   frozenset({'WP_005244551_1'}),
#   frozenset({'WP_005252230_1'}),
#   frozenset({'WP_005252736_1'}),
#   frozenset({'WP_005243698_1'}),
#   frozenset({'WP_005245237_1'})},
#  'ACOAD6f': {frozenset({'WP_005252874_1'}),
#   frozenset({'WP_005245270_1'}),
#   frozenset({'WP_005244551_1'}),
#   frozenset({'WP_005252230_1'}),
#   frozenset({'WP_005252736_1'}),
#   frozenset({'WP_005243698_1'}),
#   frozenset({'WP_005245237_1'})},
#  'ACOAD7f': {frozenset({'WP_005252874_1'}),
#   frozenset({'WP_005245270_1'}),
#   frozenset({'WP_005244551_1'}),
#   frozenset({'WP_005252230_1'}),
#   frozenset({'WP_005252736_1'}),
#   frozenset({'WP_005243698_1'}),
#   frozenset({'WP_005245237_1'})},
#  'ACOAD8f': {frozenset({'WP_005252874_1'}),
#   frozenset({'WP_005245270_1'}),
#   frozenset({'WP_005244551_1'}),
#   frozenset({'WP_005252230_1'}),
#   frozenset({'WP_005252736_1'}),
#   frozenset({'WP_005243698_1'}),
#   frozenset({'WP_005245237_1'})},
#  'ACOADH2': {frozenset({'WP_005250612_1'}), frozenset({'WP_005239548_1'})},
#  'ACOATA': {frozenset({'WP_005248538_1'}),
#   frozenset({'WP_005247839_1'}),
#   frozenset({'WP_005247960_1'}),
#   frozenset({'WP_005246169_1'})},
#  'ACODA': {frozenset({'WP_005243094_1'})},
#  'ACODA_1': {frozenset({'WP_005243094_1'})},
#  'ACONT': {frozenset({'WP_005241829_1'}), frozenset({'WP_005245879_1'})},
#  'ACONTa': {frozenset({'WP_005251340_1'}), frozenset({'WP_005245879_1'})},
#  'ACONTb': {frozenset({'WP_005251340_1'}), frozenset({'WP_005245879_1'})},
#  'ACOTA': {frozenset({'WP_005247366_1'}), frozenset({'WP_005244889_1'})},
#  'ACS': {frozenset({'WP_005239563_1'}),
#   frozenset({'WP_005248479_1'}),
#   frozenset({'WP_005250868_1'}),
#   frozenset({'WP_025432750_1'})},
#  'ACS2': {frozenset({'WP_005250389_1'}),
#   frozenset({'WP_005248479_1'}),
#   frozenset({'WP_005250868_1'}),
#   frozenset({'WP_080578205_1'})},
#  'ACSERtpp': {frozenset({'WP_025431693_1'})},
#  'ACt2rpp': {frozenset({'WP_005243991_1'}), frozenset({'WP_005244433_1'})},
#  'ACt4pp': {frozenset({'WP_025433374_1'}), frozenset({'WP_005243991_1'})},
#  'ACTD': {frozenset({'WP_005243585_1'})},
#  'ACTD2': {frozenset({'WP_025432402_1'}),
#   frozenset({'WP_005243580_1', 'WP_005245694_1', 'WP_025431990_1'})},
#  'ACTDa': {frozenset({'WP_005243585_1'})},
#  'ACTNabc': {frozenset({'WP_005239421_1',
#              'WP_005239423_1',
#              'WP_005239455_1'})},
#  'ACTNabc1': {frozenset({'WP_005239421_1',
#              'WP_005239423_1',
#              'WP_005239455_1'})},
#  'ADA': {frozenset({'WP_005239892_1'}), frozenset({'WP_025432207_1'})},
#  'ADCL': {frozenset({'WP_025433076_1'}),
#   frozenset({'WP_025431868_1'}),
#   frozenset({'WP_005241656_1'})},
#  'ADCS': {frozenset({'WP_025433076_1'}),
#   frozenset({'WP_005249080_1'}),
#   frozenset({'WP_025432227_1'})},
#  'ADD': {frozenset({'WP_005246368_1'})},
#  'ADK1': {frozenset({'WP_005239670_1'})},
#  'ADK2': {frozenset({'WP_005239670_1'})},
#  'ADK3': {frozenset({'WP_005239670_1'})},
#  'ADK4': {frozenset({'WP_005239670_1'})},
#  'ADNCYC': {frozenset({'WP_005252163_1'}),
#   frozenset({'WP_005248480_1'}),
#   frozenset({'WP_005251722_1'}),
#   frozenset({'WP_025432979_1'}),
#   frozenset({'WP_043943784_1'})},
#  'ADNK1': {frozenset({'WP_005247724_1'})},
#  'ADNK3': {frozenset({'WP_005247724_1'})},
#  'ADNK4': {frozenset({'WP_005247724_1'})},
#  'ADNt2': {frozenset({'WP_143767469_1'}), frozenset({'WP_005244607_1'})},
#  'ADNt2pp': {frozenset({'WP_143767469_1'})},
#  'ADNUC': {frozenset({'WP_025432641_1'})},
#  'ADPRDP': {frozenset({'WP_179443393_1'}),
#   frozenset({'WP_025432322_1'}),
#   frozenset({'WP_005243172_1'})},
#  'ADPT': {frozenset({'WP_025432422_1'})},
#  'ADSK': {frozenset({'WP_005252902_1', 'WP_025432985_1'}),
#   frozenset({'WP_005238162_1'})},
#  'ADSL1r': {frozenset({'WP_005249233_1'}), frozenset({'WP_005244448_1'})},
#  'ADSL2r': {frozenset({'WP_005249233_1'}), frozenset({'WP_005244448_1'})},
#  'ADSS': {frozenset({'WP_187300172_1'}), frozenset({'WP_005238467_1'})},
#  'AGDC': {frozenset({'WP_005252860_1'})},
#  'AGM3PA': {frozenset({'WP_187300219_1'})},
#  'AGM3PH': {frozenset({'WP_005243714_1'})},
#  'AGM4PA': {frozenset({'WP_187300219_1'})},
#  'AGM4PH': {frozenset({'WP_005243714_1'})},
#  'AGMH': {frozenset({'WP_005243714_1'})},
#  'AGMPTRCtpp': {frozenset({'WP_005238627_1'}), frozenset({'WP_005246692_1'})},
#  'AGPAT120': {frozenset({'WP_025432325_1'})},
#  'AGPAT140': {frozenset({'WP_025432325_1'})},
#  'AGPAT141': {frozenset({'WP_025432325_1'})},
#  'AGPAT160': {frozenset({'WP_005238713_1'}),
#   frozenset({'WP_025432883_1'}),
#   frozenset({'WP_005251979_1'}),
#   frozenset({'WP_025432325_1'})},
#  'AGPAT161': {frozenset({'WP_025432325_1'}), frozenset({'WP_005251979_1'})},
#  'AGPAT180': {frozenset({'WP_025432325_1'}), frozenset({'WP_005251979_1'})},
#  'AGPAT181': {frozenset({'WP_025432325_1'}), frozenset({'WP_005251979_1'})},
#  'AGPR': {frozenset({'WP_005247372_1'})},
#  'AHCi': {frozenset({'WP_005240051_1'})},
#  'AHMMPS': {frozenset({'WP_005251724_1'})},
#  'AHSERL2': {frozenset({'WP_025433060_1'})},
#  'AICART': {frozenset({'WP_005238563_1'})},
#  'AIRC2': {frozenset({'WP_005243340_1'})},
#  'AIRC3': {frozenset({'WP_005243340_1'})},
#  'AIRCr': {frozenset({'WP_005240011_1', 'WP_043943902_1'}),
#   frozenset({'WP_005240011_1', 'WP_025432288_1'})},
#  'AKGDb': {frozenset({'WP_037181377_1'})},
#  'AKGDH': {frozenset({'WP_005249853_1'}),
#   frozenset({'WP_005244823_1'}),
#   frozenset({'WP_063624762_1'})},
#  'AKGMAL': {frozenset({'WP_025433491_1'})},
#  'AKGt2r': {frozenset({'WP_005241413_1'})},
#  'AKGt2rpp': {frozenset({'WP_005241413_1'}), frozenset({'WP_005251525_1'})},
#  'ALAabc': {frozenset({'WP_005250966_1'}),
#   frozenset({'WP_005244316_1', 'WP_005244318_1', 'WP_005244465_1'})},
#  'ALAabcpp': {frozenset({'WP_005244316_1', 'WP_005244318_1'}),
#   frozenset({'WP_005244318_1', 'WP_005244465_1'}),
#   frozenset({'WP_005244316_1', 'WP_005244318_1', 'WP_005244465_1'}),
#   frozenset({'WP_005247450_1',
#              'WP_005247455_1',
#              'WP_005247457_1',
#              'WP_025432851_1',
#              'WP_025432852_1'})},
#  'ALAALAabcpp': {frozenset({'WP_005243362_1',
#              'WP_005252471_1',
#              'WP_025432082_1',
#              'WP_143767516_1'}),
#   frozenset({'WP_005243362_1',
#              'WP_005252471_1',
#              'WP_025432082_1',
#              'WP_050983264_1',
#              'WP_143767516_1'}),
#   frozenset({'WP_005237762_1', 'WP_005237763_1', 'WP_025433508_1'}),
#   frozenset({'WP_005252471_1',
#              'WP_025432082_1',
#              'WP_050983264_1',
#              'WP_143767516_1'}),
#   frozenset({'WP_005237762_1',
#              'WP_005237763_1',
#              'WP_005248477_1',
#              'WP_025433508_1'}),
#   frozenset({'WP_005237762_1',
#              'WP_005237763_1',
#              'WP_005248477_1',
#              'WP_025431616_1',
#              'WP_025433508_1'}),
#   frozenset({'WP_005237762_1',
#              'WP_005237763_1',
#              'WP_025433508_1',
#              'WP_050983264_1'}),
#   frozenset({'WP_005243362_1',
#              'WP_005252471_1',
#              'WP_025432082_1',
#              'WP_050983264_1'})},
#  'ALAALAD': {frozenset({'WP_005239875_1'})},
#  'ALAALAr': {frozenset({'WP_005240416_1'})},
#  'ALAD_L': {frozenset({'WP_005252938_1'}), frozenset({'WP_005249214_1'})},
#  'ALAGLUE': {frozenset({'WP_025433404_1'})},
#  'ALAR': {frozenset({'WP_005239745_1'})},
#  'ALAt2pp': {frozenset({'WP_005251594_1'})},
#  'ALAt2r': {frozenset({'WP_005250600_1'}), frozenset({'WP_005251594_1'})},
#  'ALATA_L': {frozenset({'WP_005240147_1'}),
#   frozenset({'WP_005239188_1'}),
#   frozenset({'WP_005249323_1'})},
#  'ALCD1': {frozenset({'WP_005239448_1'}), frozenset({'WP_005242359_1'})},
#  'ALCD19': {frozenset({'WP_005250820_1'}),
#   frozenset({'WP_005239439_1'}),
#   frozenset({'WP_005250184_1'})},
#  'ALCD19y': {frozenset({'WP_025431940_1'}), frozenset({'WP_025431806_1'})},
#  'ALCD2ir': {frozenset({'WP_025433904_1'}),
#   frozenset({'WP_005249807_1'}),
#   frozenset({'WP_005245235_1'})},
#  'ALCD2x': {frozenset({'WP_005250184_1'}),
#   frozenset({'WP_005242373_1'}),
#   frozenset({'WP_005249807_1'}),
#   frozenset({'WP_005239448_1'}),
#   frozenset({'WP_005251155_1'}),
#   frozenset({'WP_005245235_1'}),
#   frozenset({'WP_005239439_1'}),
#   frozenset({'WP_005250820_1'}),
#   frozenset({'WP_025433904_1'}),
#   frozenset({'WP_005242122_1'})},
#  'ALCD2y': {frozenset({'WP_005250050_1'}), frozenset({'WP_025433158_1'})},
#  'ALCD3': {frozenset({'WP_005239448_1'}), frozenset({'WP_005239439_1'})},
#  'ALCD4': {frozenset({'WP_005239448_1'}), frozenset({'WP_005239439_1'})},
#  'ALDD1': {frozenset({'WP_005243452_1'}),
#   frozenset({'WP_005250991_1'}),
#   frozenset({'WP_025433158_1'}),
#   frozenset({'WP_005251153_1'})},
#  'ALDD19xr': {frozenset({'WP_005241094_1'}), frozenset({'WP_005239591_1'})},
#  'ALDD2x': {frozenset({'WP_037182429_1'}),
#   frozenset({'WP_005239499_1'}),
#   frozenset({'WP_005239950_1'}),
#   frozenset({'WP_005245755_1'}),
#   frozenset({'WP_005239950_1', 'WP_005244585_1'}),
#   frozenset({'WP_005245403_1'}),
#   frozenset({'WP_005252419_1'}),
#   frozenset({'WP_005250047_1'}),
#   frozenset({'WP_005251153_1'})},
#  'ALDD2y': {frozenset({'WP_025433420_1'}), frozenset({'WP_005239499_1'})},
#  'ALDD3': {frozenset({'WP_005251153_1'})},
#  'ALDD31': {frozenset({'WP_005239499_1'})},
#  'ALDD31_1': {frozenset({'WP_005251153_1'})},
#  'ALDD3y': {frozenset({'WP_005239499_1'})},
#  'ALDD4': {frozenset({'WP_005251153_1'})},
#  'ALDD6': {frozenset({'WP_005251153_1'})},
#  'ALLTAHr': {frozenset({'WP_025433273_1'})},
#  'ALLTAMH': {frozenset({'WP_005250837_1'})},
#  'ALLTN': {frozenset({'WP_005244835_1'}), frozenset({'WP_005246368_1'})},
#  'ALLTNt2r': {frozenset({'WP_025433272_1'})},
#  'ALLTNt2rpp': {frozenset({'WP_005244837_1'})},
#  'ALR2': {frozenset({'WP_005242785_1'}),
#   frozenset({'WP_037182698_1'}),
#   frozenset({'WP_025431921_1'})},
#  'AM3PA': {frozenset({'WP_187300219_1'})},
#  'AM4PA': {frozenset({'WP_187300219_1'})},
#  'AMALT1': {frozenset({'WP_005244400_1'})},
#  'AMALT2': {frozenset({'WP_005244400_1'})},
#  'AMALT3': {frozenset({'WP_005244400_1'})},
#  'AMALT4': {frozenset({'WP_005244400_1'})},
#  'AMANK': {frozenset({'WP_025433212_1'})},
#  'AMID4': {frozenset({'WP_005247916_1'})},
#  'AMMQLT8': {frozenset({'WP_025431587_1'}),
#   frozenset({'WP_005248734_1'}),
#   frozenset({'WP_005251354_1'})},
#  'AMMQT8': {frozenset({'WP_005252082_1'})},
#  'AMMQT8_2': {frozenset({'WP_005563989_1'}), frozenset({'WP_005248734_1'})},
#  'AMPTASECG': {frozenset({'WP_005248200_1'}), frozenset({'WP_005247736_1'})},
#  'AMPTASEPG': {frozenset({'WP_005247736_1'})},
#  'ANPRT': {frozenset({'WP_005247709_1'})},
#  'ANS': {frozenset({'WP_005247495_1'}), frozenset({'WP_005246579_1'})},
#  'AP4AH': {frozenset({'WP_005240964_1'})},
#  'AP4AS': {frozenset({'WP_005244958_1'})},
#  'APENTAMAH': {frozenset({'WP_005249247_1'})},
#  'APH120': {frozenset({'WP_011598391_1'})},
#  'APH140': {frozenset({'WP_011598391_1'})},
#  'APH141': {frozenset({'WP_011598391_1'})},
#  'APH160': {frozenset({'WP_011598391_1'})},
#  'APH161': {frozenset({'WP_011598391_1'})},
#  'APH180': {frozenset({'WP_011598391_1'})},
#  'APH181': {frozenset({'WP_011598391_1'})},
#  'APRAUR': {frozenset({'WP_005240942_1'}), frozenset({'WP_005252720_1'})},
#  'APTNAT': {frozenset({'WP_005244800_1'})},
#  'ARABRr': {frozenset({'WP_005241223_1'})},
#  'ARBabc': {frozenset({'WP_005243476_1'}), frozenset({'WP_025432120_1'})},
#  'ARBabcpp': {frozenset({'WP_005243476_1'}),
#   frozenset({'WP_025433359_1'}),
#   frozenset({'WP_005248812_1', 'WP_025433359_1'})},
#  'ARBt2r': {frozenset({'WP_005244703_1'}), frozenset({'WP_005245401_1'})},
#  'ARBt3ipp': {frozenset({'WP_005239871_1'}), frozenset({'WP_025431793_1'})},
#  'ARBTpts': {frozenset({'WP_005252852_1'})},
#  'ARGabc': {frozenset({'WP_005240751_1', 'WP_025432117_1'}),
#   frozenset({'WP_005247430_1', 'WP_179443303_1'}),
#   frozenset({'WP_005249622_1'})},
#  'ARGabcpp': {frozenset({'WP_005242885_1', 'WP_179443303_1'}),
#   frozenset({'WP_005247430_1', 'WP_164709508_1'}),
#   frozenset({'WP_005245037_1', 'WP_005249629_1'}),
#   frozenset({'WP_005249622_1'}),
#   frozenset({'WP_005247432_1', 'WP_005249629_1'}),
#   frozenset({'WP_005255435_1', 'WP_164709508_1'}),
#   frozenset({'WP_179443303_1'}),
#   frozenset({'WP_025432387_1'}),
#   frozenset({'WP_005247430_1', 'WP_179443303_1'})},
#  'ARGAGMt7pp': {frozenset({'WP_005252423_1'})},
#  'ARGDr': {frozenset({'WP_005239717_1'}), frozenset({'WP_005238720_1'})},
#  'ARGN_1': {frozenset({'WP_005244250_1'})},
#  'ARGSL': {frozenset({'WP_025433429_1'}), frozenset({'WP_005247355_1'})},
#  'ARGSS': {frozenset({'WP_005247359_1'})},
#  'ARGt2r': {frozenset({'WP_005240049_1'}), frozenset({'WP_025433612_1'})},
#  'ARGt3pp': {frozenset({'WP_025433626_1'})},
#  'ARGt5r': {frozenset({'WP_025433611_1'})},
#  'ARUH': {frozenset({'WP_005239926_1'})},
#  'ASAD': {frozenset({'WP_005248516_1'})},
#  'ASNN': {frozenset({'WP_005244922_1'}),
#   frozenset({'WP_005245583_1'}),
#   frozenset({'WP_025432017_1'})},
#  'ASNNpp': {frozenset({'WP_005245583_1'})},
#  'ASNS1': {frozenset({'WP_005247722_1'}), frozenset({'WP_005244070_1'})},
#  'ASNS2': {frozenset({'WP_005245583_1'})},
#  'ASNt2r': {frozenset({'WP_005244919_1'})},
#  'ASNt2rpp': {frozenset({'WP_005244919_1'})},
#  'ASO3t4pp': {frozenset({'WP_005249897_1'})},
#  'ASO3t8pp': {frozenset({'WP_025432904_1'})},
#  'ASO4t4pp': {frozenset({'WP_005249897_1'})},
#  'ASP1DC': {frozenset({'WP_005262154_1'})},
#  'ASPabc': {frozenset({'WP_025432387_1'})},
#  'ASPabcpp': {frozenset({'WP_005251655_1', 'WP_025432387_1'}),
#   frozenset({'WP_025433433_1'}),
#   frozenset({'WP_025432387_1'})},
#  'ASPCT': {frozenset({'WP_025432522_1'})},
#  'ASPK': {frozenset({'WP_005248517_1'})},
#  'ASPO1': {frozenset({'WP_005247538_1'})},
#  'ASPO5': {frozenset({'WP_005247538_1'})},
#  'ASPT': {frozenset({'WP_025431778_1'}),
#   frozenset({'WP_025431758_1'}),
#   frozenset({'WP_025432018_1'})},
#  'ASPt2_2': {frozenset({'WP_005244433_1'})},
#  'ASPt2_2pp': {frozenset({'WP_005251008_1'}), frozenset({'WP_005244433_1'})},
#  'ASPt2pp': {frozenset({'WP_025433399_1'}), frozenset({'WP_005252416_1'})},
#  'ASPt2r': {frozenset({'WP_005252416_1'})},
#  'ASPTA': {frozenset({'WP_005238257_1'}),
#   frozenset({'WP_005239926_1'}),
#   frozenset({'WP_005240147_1'}),
#   frozenset({'WP_005239188_1'}),
#   frozenset({'WP_005244454_1'}),
#   frozenset({'WP_005250042_1'})},
#  'ASR': {frozenset({'WP_005238721_1'})},
#  'ASR2': {frozenset({'WP_005249896_1'})},
#  'ATPHs': {frozenset({'spontaneous'})},
#  'ATPPRT': {frozenset({'WP_005243011_1'})},
#  'ATPS4rpp': {frozenset({'WP_005252955_1'}), frozenset({'WP_005246796_1'})},
#  'BALAt2pp': {frozenset({'WP_005251594_1'})},
#  'BALAt2r': {frozenset({'WP_005250455_1'}), frozenset({'WP_005251210_1'})},
#  'BCOALIG': {frozenset({'WP_025432750_1'})},
#  'BCOALIG2': {frozenset({'WP_025432750_1'})},
#  'BCT1_syn': {frozenset({'WP_005248551_1', 'WP_025433347_1'})},
#  'BETALDHx': {frozenset({'WP_005245755_1'}),
#   frozenset({'WP_005250047_1'}),
#   frozenset({'WP_005252291_1'}),
#   frozenset({'WP_005242102_1'})},
#  'BETALDHy': {frozenset({'WP_005245755_1'}),
#   frozenset({'WP_005250047_1'}),
#   frozenset({'WP_005252291_1'}),
#   frozenset({'WP_005242102_1'})},
#  'BG_CELLB': {frozenset({'WP_005247533_1'})},
#  'BGLA': {frozenset({'WP_005250470_1'})},
#  'BG_MADG': {frozenset({'WP_005247533_1'})},
#  'BG_MBDG': {frozenset({'WP_005247533_1'})},
#  'BMOCOS': {frozenset({'WP_005240266_1'}), frozenset({'WP_005238688_1'})},
#  'BMOGDS1': {frozenset({'WP_037179130_1'})},
#  'BMOGDS2': {frozenset({'WP_037179130_1'})},
#  'BPNT': {frozenset({'WP_005252904_1'})},
#  'BSCT': {frozenset({'WP_143767471_1'})},
#  'BTDD_RR': {frozenset({'WP_005252717_1'})},
#  'BTS2': {frozenset({'WP_005247552_1'})},
#  'BTS3r': {frozenset({'WP_005247552_1'})},
#  'BUTCT': {frozenset({'WP_005251310_1'}),
#   frozenset({'WP_005241236_1'}),
#   frozenset({'WP_005244597_1'}),
#   frozenset({'WP_005244597_1', 'WP_005251310_1'}),
#   frozenset({'WP_005241236_1', 'WP_005251310_1'})},
#  'BUTSabc': {frozenset({'WP_005242735_1',
#              'WP_005244174_1',
#              'WP_025432312_1'})},
#  'BUTSO3abcpp': {frozenset({'WP_005244174_1', 'WP_025432639_1'}),
#   frozenset({'WP_005240904_1', 'WP_005246633_1', 'WP_025432639_1'}),
#   frozenset({'WP_025433455_1'}),
#   frozenset({'WP_005240904_1', 'WP_005250729_1', 'WP_025432411_1'}),
#   frozenset({'WP_005240904_1', 'WP_005244169_1'}),
#   frozenset({'WP_005244176_1', 'WP_005246633_1', 'WP_025432639_1'}),
#   frozenset({'WP_005252777_1', 'WP_143767463_1'}),
#   frozenset({'WP_005252777_1', 'WP_025433347_1'}),
#   frozenset({'WP_005240905_1', 'WP_005244194_1'}),
#   frozenset({'WP_005250729_1', 'WP_143767463_1'}),
#   frozenset({'WP_005250729_1', 'WP_025433347_1'}),
#   frozenset({'WP_005240904_1', 'WP_005244174_1', 'WP_025432639_1'}),
#   frozenset({'WP_005252777_1', 'WP_025432411_1'}),
#   frozenset({'WP_005250729_1', 'WP_025432411_1'}),
#   frozenset({'WP_005240904_1'}),
#   frozenset({'WP_005240904_1', 'WP_025432639_1'})},
#  'BUTt2r': {frozenset({'WP_005251827_1'})},
#  'BUTt2rpp': {frozenset({'WP_005251827_1'}), frozenset({'WP_005243991_1'})},
#  'BUTt4pp': {frozenset({'WP_005243991_1'})},
#  'BZ12DOX': {frozenset({'WP_005251368_1', 'WP_005251370_1'}),
#   frozenset({'WP_005251368_1', 'WP_005251370_1', 'WP_005251372_1'}),
#   frozenset({'WP_005245655_1', 'WP_005250462_1', 'WP_025433214_1'})},
#  'BZALDH': {frozenset({'WP_005245621_1'}), frozenset({'WP_025433317_1'})},
#  'BZDH': {frozenset({'WP_025432003_1'}), frozenset({'WP_005250914_1'})},
#  'BZDIOLDH': {frozenset({'WP_005251366_1'})},
#  'BZSCD': {frozenset({'WP_005250197_1'})},
#  'BZSCT': {frozenset({'WP_025432662_1'})},
#  'BZt': {frozenset({'spontaneous'})},
#  'BZt1pp': {frozenset({'WP_085990806_1'}), frozenset({'WP_005244433_1'})},
#  'C100SN': {frozenset({'WP_005239602_1'}),
#   frozenset({'WP_005239602_1', 'WP_025433357_1'})},
#  'C120SN': {frozenset({'WP_005252932_1'})},
#  'C140SN': {frozenset({'WP_005244469_1'}), frozenset({'WP_005252932_1'})},
#  'C141SN': {frozenset({'WP_005252932_1'})},
#  'C160SN': {frozenset({'WP_005244469_1'}), frozenset({'WP_005252932_1'})},
#  'C161SN': {frozenset({'WP_005252932_1'})},
#  'C180SN': {frozenset({'WP_005244469_1'})},
#  'C181SN': {frozenset({'WP_005244469_1'}), frozenset({'WP_005252932_1'})},
#  'CA2abc': {frozenset({'WP_005237961_1'})},
#  'CA2abc1': {frozenset({'WP_005237961_1'})},
#  'CA2abcpp': {frozenset({'WP_025431926_1'})},
#  'CAATPS': {frozenset({'WP_037182701_1'})},
#  'CACOAHA': {frozenset({'WP_005245231_1'})},
#  'CAT23DOX': {frozenset({'WP_005237880_1'})},
#  'CAt4': {frozenset({'WP_005246609_1'})},
#  'CATDOX': {frozenset({'WP_005251389_1'}), frozenset({'WP_005251124_1'})},
#  'CBFC2pp': {frozenset({'WP_005238365_1', 'WP_005239743_1'})},
#  'CBIAT': {frozenset({'WP_005240608_1'})},
#  'CBLAT': {frozenset({'WP_005240608_1'})},
#  'CBMD': {frozenset({'spontaneous'})},
#  'CBPS': {frozenset({'WP_005241721_1'}), frozenset({'WP_037179238_1'})},
#  'CD2t3pp': {frozenset({'WP_005238136_1'})},
#  'CD2t4': {frozenset({'WP_005238442_1'})},
#  'CDGUNPD': {frozenset({'WP_005238828_1'}),
#   frozenset({'WP_037180746_1'}),
#   frozenset({'WP_005241038_1'}),
#   frozenset({'WP_025432363_1'}),
#   frozenset({'WP_005247902_1'})},
#  'CDPMEK': {frozenset({'WP_005238750_1'})},
#  'CDPPT160': {frozenset({'WP_025432418_1'})},
#  'CGLYabcpp': {frozenset({'WP_005237762_1',
#              'WP_005237763_1',
#              'WP_025433508_1'}),
#   frozenset({'WP_005237762_1',
#              'WP_005237763_1',
#              'WP_025433508_1',
#              'WP_050983264_1'}),
#   frozenset({'WP_005237762_1',
#              'WP_005237763_1',
#              'WP_005248477_1',
#              'WP_025433508_1'}),
#   frozenset({'WP_005237762_1',
#              'WP_005237763_1',
#              'WP_005248477_1',
#              'WP_025431616_1',
#              'WP_025433508_1'})},
#  'CHLabc': {frozenset({'WP_005239314_1',
#              'WP_005239327_1',
#              'WP_025432197_1',
#              'WP_025432198_1'}),
#   frozenset({'WP_005244444_1', 'WP_005254252_1'}),
#   frozenset({'WP_005247765_1', 'WP_005247766_1'}),
#   frozenset({'WP_005247765_1', 'WP_005254252_1'})},
#  'CHLabcpp': {frozenset({'WP_005244444_1'}),
#   frozenset({'WP_005247765_1', 'WP_005247768_1'}),
#   frozenset({'WP_005247765_1', 'WP_005247766_1', 'WP_005247768_1'})},
#  'CHLt2': {frozenset({'WP_025431781_1'})},
#  'CHOLD': {frozenset({'WP_005244787_1'}),
#   frozenset({'WP_025432458_1'}),
#   frozenset({'WP_025433218_1'})},
#  'CHOLD2': {frozenset({'WP_025433620_1'})},
#  'CHOLSabc_1': {frozenset({'WP_005247765_1', 'WP_005247766_1'})},
#  'CHOLSH': {frozenset({'WP_005247983_1'})},
#  'CHORM': {frozenset({'WP_005249089_1'}), frozenset({'WP_005239570_1'})},
#  'CHORS': {frozenset({'WP_025432519_1'})},
#  'CIGAMS': {frozenset({'WP_005243057_1'})},
#  'CITACt': {frozenset({'WP_025431623_1'})},
#  'CITL': {frozenset({'WP_005250676_1'}),
#   frozenset({'WP_005239273_1'}),
#   frozenset({'WP_025432225_1'}),
#   frozenset({'WP_025432481_1'})},
#  'CITt14': {frozenset({'WP_025431984_1'})},
#  'CITt2r': {frozenset({'WP_025431623_1'})},
#  'CITt7': {frozenset({'WP_005250457_1'})},
#  'CITt7pp': {frozenset({'WP_005250457_1'})},
#  'CITt_kt': {frozenset({'WP_025431984_1'}), frozenset({'WP_005244287_1'})},
#  'CLBtex': {frozenset({'WP_025432619_1'})},
#  'CMCMSAD': {frozenset({'WP_005248570_1'}), frozenset({'WP_025431636_1'})},
#  'CMLDC': {frozenset({'WP_005244588_1'})},
#  'CO2t': {frozenset({'spontaneous'})},
#  'CO2tpp': {frozenset({'spontaneous'})},
#  'COabc': {frozenset({'WP_005243611_1'})},
#  'COALDDH': {frozenset({'WP_005241339_1'})},
#  'Cobalt2abcppI': {frozenset({'WP_025431920_1'})},
#  'COBALT2t3pp': {frozenset({'WP_005238136_1'})},
#  'COBALTt5': {frozenset({'WP_025432195_1'})},
#  'CODH2r': {frozenset({'WP_005243653_1', 'WP_005243655_1', 'WP_005243657_1'})},
#  'CPMPS': {frozenset({'WP_005240264_1'}),
#   frozenset({'WP_005240264_1', 'WP_025433438_1'})},
#  'CPPPGO': {frozenset({'WP_025432924_1'})},
#  'CRNabc': {frozenset({'WP_005239314_1',
#              'WP_005239327_1',
#              'WP_025432197_1',
#              'WP_025432198_1'}),
#   frozenset({'WP_005244444_1', 'WP_005254252_1'}),
#   frozenset({'WP_005247765_1', 'WP_005247766_1'}),
#   frozenset({'WP_005247765_1', 'WP_005254252_1'})},
#  'CRNabcpp': {frozenset({'WP_005247765_1', 'WP_005247768_1'}),
#   frozenset({'WP_005247765_1', 'WP_005247766_1', 'WP_005247768_1'})},
#  'CRNCBCT': {frozenset({'WP_025433593_1'})},
#  'CRNCDH': {frozenset({'WP_005251559_1'})},
#  'CRNDt2rpp': {frozenset({'WP_005261289_1'})},
#  'CRNt2rpp': {frozenset({'WP_005261289_1'})},
#  'CRO4abcpp': {frozenset({'WP_085990787_1'})},
#  'CRO4t3pp': {frozenset({'WP_005245512_1'})},
#  'CS': {frozenset({'WP_005244092_1'}),
#   frozenset({'WP_005252757_1'}),
#   frozenset({'WP_005244097_1'})},
#  'CSND': {frozenset({'WP_025431960_1'}), frozenset({'WP_025431681_1'})},
#  'CSNt2': {frozenset({'WP_005244607_1'}), frozenset({'WP_187300235_1'})},
#  'CTBTabc': {frozenset({'WP_005247765_1', 'WP_005247766_1'})},
#  'CTBTt2rpp': {frozenset({'WP_005261289_1'})},
#  'CTECOAI6': {frozenset({'WP_005240908_1'}),
#   frozenset({'WP_005240312_1'}),
#   frozenset({'WP_005251515_1'}),
#   frozenset({'WP_005244486_1'}),
#   frozenset({'WP_005248946_1'}),
#   frozenset({'WP_005250863_1'}),
#   frozenset({'WP_005248565_1'}),
#   frozenset({'WP_005246568_1'}),
#   frozenset({'WP_005248530_1'}),
#   frozenset({'WP_005242233_1'})},
#  'CTECOAI7': {frozenset({'WP_005240908_1'}),
#   frozenset({'WP_005240312_1'}),
#   frozenset({'WP_005251515_1'}),
#   frozenset({'WP_005244486_1'}),
#   frozenset({'WP_005248946_1'}),
#   frozenset({'WP_005250863_1'}),
#   frozenset({'WP_005248565_1'}),
#   frozenset({'WP_005246568_1'}),
#   frozenset({'WP_005248530_1'}),
#   frozenset({'WP_005242233_1'})},
#  'CTECOAI8': {frozenset({'WP_005240908_1'}),
#   frozenset({'WP_005240312_1'}),
#   frozenset({'WP_005251515_1'}),
#   frozenset({'WP_005244486_1'}),
#   frozenset({'WP_005248946_1'}),
#   frozenset({'WP_005250863_1'}),
#   frozenset({'WP_005248565_1'}),
#   frozenset({'WP_005246568_1'}),
#   frozenset({'WP_005248530_1'}),
#   frozenset({'WP_005242233_1'})},
#  'CTPS1': {frozenset({'WP_025432832_1'})},
#  'CTPS2': {frozenset({'WP_025432832_1'})},
#  'CU1Opp': {frozenset({'WP_025431722_1'})},
#  'Cuabc': {frozenset({'WP_005249240_1'})},
#  'CUabcpp': {frozenset({'WP_005244870_1', 'WP_025433261_1'})},
#  'Cut1': {frozenset({'WP_005249238_1'}),
#   frozenset({'WP_005249240_1'}),
#   frozenset({'WP_005248910_1'})},
#  'CYNTt2': {frozenset({'WP_025432304_1'})},
#  'CYO1a': {frozenset({'WP_005247712_1', 'WP_005247713_1', 'WP_043943950_1'})},
#  'CYO1b': {frozenset({'WP_005240299_1',
#              'WP_005241796_1',
#              'WP_016880030_1',
#              'WP_025432889_1'})},
#  'CYS': {frozenset({'WP_043944116_1'})},
#  'CYSabcpp': {frozenset({'WP_005242882_1',
#              'WP_025433179_1',
#              'WP_164709508_1'})},
#  'CYSS': {frozenset({'WP_005248316_1'}),
#   frozenset({'WP_005252021_1'}),
#   frozenset({'WP_043944116_1'})},
#  'CYSTGL': {frozenset({'WP_005240414_1'})},
#  'CYSTL': {frozenset({'WP_005246211_1'}), frozenset({'WP_005243958_1'})},
#  'CYStpp': {frozenset({'WP_025431693_1'})},
#  'CYSTS': {frozenset({'WP_005238969_1'}), frozenset({'WP_043944116_1'})},
#  'CYTBD': {frozenset({'WP_005244367_1',
#              'WP_025431869_1',
#              'WP_025431870_1',
#              'WP_080578207_1'}),
#   frozenset({'WP_037181097_1'})},
#  'CYTBD2': {frozenset({'WP_005244367_1',
#              'WP_025431869_1',
#              'WP_025431870_1',
#              'WP_080578207_1'})},
#  'CYTBD2pp': {frozenset({'WP_037181097_1'}), frozenset({'WP_025432838_1'})},
#  'CYTBDpp': {frozenset({'WP_037181097_1'})},
#  'CYTD': {frozenset({'WP_005239890_1'})},
#  'CYTDH': {frozenset({'WP_025432641_1'})},
#  'CYTDK1': {frozenset({'WP_005237815_1'})},
#  'CYTDK2': {frozenset({'WP_005237815_1'})},
#  'CYTDt2': {frozenset({'WP_143767469_1'})},
#  'CYTDt2pp': {frozenset({'WP_143767469_1'})},
#  'CYTK1': {frozenset({'WP_005562874_1'})},
#  'CYTK2': {frozenset({'WP_005562874_1'})},
#  'CYTMQOR3pp': {frozenset({'WP_005245019_1'}), frozenset({'WP_005238365_1'})},
#  'DAAD': {frozenset({'WP_025432946_1'}), frozenset({'WP_025433631_1'})},
#  'DADA': {frozenset({'WP_025432207_1'})},
#  'DADK': {frozenset({'WP_005249132_1'})},
#  'DADNt2': {frozenset({'WP_143767469_1'}), frozenset({'WP_005244607_1'})},
#  'DADNt2pp': {frozenset({'WP_143767469_1'})},
#  'DAGK120': {frozenset({'WP_025432298_1'})},
#  'DAGK140': {frozenset({'WP_025432298_1'})},
#  'DAGK141': {frozenset({'WP_025432298_1'})},
#  'DAGK160': {frozenset({'WP_025432298_1'}), frozenset({'WP_005251969_1'})},
#  'DAGK161': {frozenset({'WP_025432298_1'})},
#  'DAGK180': {frozenset({'WP_025432298_1'})},
#  'DAGK181': {frozenset({'WP_025432298_1'})},
#  'DALAOX': {frozenset({'WP_005242135_1'})},
#  'DALAt2pp': {frozenset({'WP_005251594_1'})},
#  'DALAt2r': {frozenset({'WP_025432629_1'}),
#   frozenset({'WP_005250600_1'}),
#   frozenset({'WP_005251594_1'})},
#  'DAPDC': {frozenset({'WP_025433888_1'}), frozenset({'WP_005252943_1'})},
#  'DAPE': {frozenset({'WP_005240761_1'})},
#  'DARBabcpp': {frozenset({'WP_005243476_1'}), frozenset({'WP_025433359_1'})},
#  'DARBt3ipp': {frozenset({'WP_025431793_1'}), frozenset({'WP_005249330_1'})},
#  'DARBtex': {frozenset({'WP_025432619_1'})},
#  'DASYN120': {frozenset({'WP_025432370_1'})},
#  'DASYN140': {frozenset({'WP_025432370_1'})},
#  'DASYN160': {frozenset({'WP_025432370_1'}), frozenset({'WP_025432353_1'})},
#  'DASYN160190': {frozenset({'WP_025432353_1'})},
#  'DASYN161': {frozenset({'WP_025432370_1'})},
#  'DASYN180': {frozenset({'WP_025432370_1'})},
#  'DASYN181': {frozenset({'WP_025432370_1'})},
#  'DASYN190190': {frozenset({'WP_025432353_1'})},
#  'DASYN_HP': {frozenset({'WP_080578250_1'})},
#  'DATPHs': {frozenset({'spontaneous'})},
#  'DB4PS': {frozenset({'WP_005250334_1'}), frozenset({'WP_025433534_1'})},
#  'DCTPD': {frozenset({'WP_005238072_1'})},
#  'DCTPD2': {frozenset({'WP_005238072_1'})},
#  'DCYTt2': {frozenset({'WP_143767469_1'})},
#  'DCYTt2pp': {frozenset({'WP_143767469_1'})},
#  'DDGALK': {frozenset({'WP_005248341_1'})},
#  'DDGLK': {frozenset({'WP_025433301_1'})},
#  'DDPA': {frozenset({'WP_005244219_1'}), frozenset({'WP_005247669_1'})},
#  'DDPGALA': {frozenset({'WP_005248344_1'})},
#  'DESAT16': {frozenset({'WP_005240079_1'})},
#  'DESAT18': {frozenset({'WP_025431878_1'})},
#  'DGK1': {frozenset({'WP_025432524_1'})},
#  'DGSNt2': {frozenset({'WP_143767469_1'})},
#  'DGSNt2pp': {frozenset({'WP_143767469_1'})},
#  'DGUNC': {frozenset({'WP_005238828_1'}),
#   frozenset({'WP_005251624_1'}),
#   frozenset({'WP_005244086_1'}),
#   frozenset({'WP_005248813_1'}),
#   frozenset({'WP_005248812_1'}),
#   frozenset({'WP_037179214_1'}),
#   frozenset({'WP_025432363_1'}),
#   frozenset({'WP_005238658_1'})},
#  'DH3MCHCDH': {frozenset({'WP_005251366_1'})},
#  'DH4MCHCDH': {frozenset({'WP_005251366_1'})},
#  'DHACOAH': {frozenset({'WP_005244558_1'}),
#   frozenset({'WP_005246568_1'}),
#   frozenset({'WP_005240908_1'}),
#   frozenset({'WP_005250863_1'})},
#  'DHAD1': {frozenset({'WP_005239148_1'}),
#   frozenset({'WP_009478121_1'}),
#   frozenset({'WP_025433531_1'}),
#   frozenset({'WP_005240376_1'})},
#  'DHAD2': {frozenset({'WP_005239148_1'}),
#   frozenset({'WP_025433531_1'}),
#   frozenset({'WP_005240376_1'})},
#  'DHAD3': {frozenset({'WP_025433531_1'})},
#  'DHAK': {frozenset({'WP_005250844_1'})},
#  'DHAPT': {frozenset({'WP_005252341_1', 'WP_025432990_1'})},
#  'DHBD': {frozenset({'WP_005249181_1'}),
#   frozenset({'WP_005238946_1'}),
#   frozenset({'WP_005244441_1'})},
#  'DHBS': {frozenset({'WP_005244442_1'}), frozenset({'WP_005242411_1'})},
#  'DHBSr': {frozenset({'WP_005242411_1'})},
#  'DHCINDO': {frozenset({'WP_005245205_1'})},
#  'DHDPRy': {frozenset({'WP_005240723_1'})},
#  'DHDPS': {frozenset({'WP_005250735_1'}),
#   frozenset({'WP_005250602_1'}),
#   frozenset({'WP_025431780_1'}),
#   frozenset({'WP_005240731_1'}),
#   frozenset({'WP_005242818_1'})},
#  'DHEDAA': {frozenset({'WP_025432001_1'}),
#   frozenset({'WP_005243411_1'}),
#   frozenset({'WP_005243411_1', 'WP_025432001_1'})},
#  'DHFR': {frozenset({'WP_005251635_1'})},
#  'DHFS': {frozenset({'WP_005248089_1'})},
#  'DHNAOT': {frozenset({'WP_005252033_1'})},
#  'DHNCOAS': {frozenset({'WP_005250877_1'})},
#  'DHNPA2r': {frozenset({'WP_005262144_1'})},
#  'DHORD2': {frozenset({'WP_005256369_1'})},
#  'DHORD3': {frozenset({'WP_005256369_1'})},
#  'DHORD5': {frozenset({'WP_005256369_1'})},
#  'DHORTS': {frozenset({'WP_037179235_1'})},
#  'DHPACCOAHIT': {frozenset({'WP_005248565_1',
#              'WP_005250764_1',
#              'WP_005250766_1'}),
#   frozenset({'WP_005250764_1', 'WP_005250766_1', 'WP_005250771_1'})},
#  'DHPPDA': {frozenset({'WP_005241759_1'})},
#  'DHPPDA2': {frozenset({'WP_005241759_1'})},
#  'DHPS': {frozenset({'WP_025433075_1'})},
#  'DHPS2': {frozenset({'WP_005239236_1'}),
#   frozenset({'WP_025433075_1'}),
#   frozenset({'WP_005244970_1'})},
#  'DHQS': {frozenset({'WP_005262316_1'})},
#  'DHQTi': {frozenset({'WP_005250083_1'}), frozenset({'WP_005248177_1'})},
#  'DHSKDH': {frozenset({'WP_025432960_1'})},
#  'DINSt2': {frozenset({'WP_143767469_1'})},
#  'DINSt2pp': {frozenset({'WP_143767469_1'})},
#  'DIPEPabc15': {frozenset({'WP_005237763_1',
#              'WP_005237765_1',
#              'WP_005248476_1',
#              'WP_179443151_1'})},
#  'D_LACt2pp': {frozenset({'WP_025432372_1'})},
#  'DMALRED': {frozenset({'WP_005240602_1'})},
#  'DMATT': {frozenset({'WP_005252086_1'}), frozenset({'WP_187300232_1'})},
#  'DMPPS': {frozenset({'WP_005239003_1'}), frozenset({'WP_025432847_1'})},
#  'DNMPPA': {frozenset({'WP_005248057_1'}), frozenset({'WP_005247681_1'})},
#  'DNTPPA': {frozenset({'WP_005248057_1'}), frozenset({'WP_025432322_1'})},
#  'DPCOAK': {frozenset({'WP_025432846_1'})},
#  'DPHAPC100': {frozenset({'WP_025431576_1'})},
#  'DPHAPC120': {frozenset({'WP_025431576_1'})},
#  'DPHAPC121': {frozenset({'WP_025431576_1'})},
#  'DPHAPC140': {frozenset({'WP_025431576_1'})},
#  'DPHAPC141': {frozenset({'WP_025431576_1'})},
#  'DPHAPC60': {frozenset({'WP_025431576_1'})},
#  'DPHAPC80': {frozenset({'WP_025431576_1'})},
#  'DPR': {frozenset({'WP_005249332_1'})},
#  'DRIBabc': {frozenset({'WP_005242938_1',
#              'WP_005242941_1',
#              'WP_005248814_1',
#              'WP_025431785_1'})},
#  'DRPA': {frozenset({'WP_005251893_1'})},
#  'DSERDHr': {frozenset({'WP_005251916_1'})},
#  'DSERt2': {frozenset({'WP_025432629_1'}), frozenset({'WP_005251594_1'})},
#  'DSERt2pp': {frozenset({'WP_005251594_1'})},
#  'DTARTD': {frozenset({'WP_005239073_1'})},
#  'DTMPK': {frozenset({'WP_025432290_1'})},
#  'DURIt2': {frozenset({'WP_143767469_1'})},
#  'DURIt2pp': {frozenset({'WP_143767469_1'})},
#  'DUTPDP': {frozenset({'WP_025432828_1'}),
#   frozenset({'WP_025432322_1'}),
#   frozenset({'WP_025432405_1'}),
#   frozenset({'WP_005238835_1'})},
#  'DXPRIi': {frozenset({'WP_025432356_1'})},
#  'DXPS': {frozenset({'WP_025432409_1'})},
#  'EAR100x': {frozenset({'WP_005244599_1'}), frozenset({'WP_037180448_1'})},
#  'EAR100y': {frozenset({'WP_037180448_1'})},
#  'EAR120x': {frozenset({'WP_005244599_1'}), frozenset({'WP_037180448_1'})},
#  'EAR120y': {frozenset({'WP_037180448_1'})},
#  'EAR121x': {frozenset({'WP_005244599_1'}), frozenset({'WP_037180448_1'})},
#  'EAR121y': {frozenset({'WP_037180448_1'})},
#  'EAR140x': {frozenset({'WP_005244599_1'}), frozenset({'WP_037180448_1'})},
#  'EAR140y': {frozenset({'WP_037180448_1'})},
#  'EAR141x': {frozenset({'WP_005244599_1'}), frozenset({'WP_037180448_1'})},
#  'EAR141y': {frozenset({'WP_037180448_1'})},
#  'EAR160x': {frozenset({'WP_005244599_1'}), frozenset({'WP_037180448_1'})},
#  'EAR160y': {frozenset({'WP_037180448_1'})},
#  'EAR161x': {frozenset({'WP_005244599_1'}), frozenset({'WP_037180448_1'})},
#  'EAR161y': {frozenset({'WP_037180448_1'})},
#  'EAR180x': {frozenset({'WP_005244599_1'}), frozenset({'WP_037180448_1'})},
#  'EAR180y': {frozenset({'WP_037180448_1'})},
#  'EAR181x': {frozenset({'WP_005244599_1'}), frozenset({'WP_037180448_1'})},
#  'EAR181y': {frozenset({'WP_037180448_1'})},
#  'EAR40x': {frozenset({'WP_005244599_1'}), frozenset({'WP_037180448_1'})},
#  'EAR40y': {frozenset({'WP_037180448_1'})},
#  'EAR60x': {frozenset({'WP_005244599_1'}), frozenset({'WP_037180448_1'})},
#  'EAR60y': {frozenset({'WP_037180448_1'})},
#  'EAR80x': {frozenset({'WP_005244599_1'}), frozenset({'WP_037180448_1'})},
#  'EAR80y': {frozenset({'WP_037180448_1'})},
#  'ECOAH1': {frozenset({'WP_005242640_1'}),
#   frozenset({'WP_005240908_1'}),
#   frozenset({'WP_005240312_1'}),
#   frozenset({'WP_005251515_1'}),
#   frozenset({'WP_005244486_1'}),
#   frozenset({'WP_005248946_1'}),
#   frozenset({'WP_005250863_1'}),
#   frozenset({'WP_005248530_1'}),
#   frozenset({'WP_005248565_1'}),
#   frozenset({'WP_005246568_1'}),
#   frozenset({'WP_005241264_1'}),
#   frozenset({'WP_005242233_1'})},
#  'ECOAH1_2': {frozenset({'WP_005250878_1'}), frozenset({'WP_005240312_1'})},
#  'ECOAH2': {frozenset({'WP_005240908_1'}),
#   frozenset({'WP_005240312_1'}),
#   frozenset({'WP_005250878_1'}),
#   frozenset({'WP_005251515_1'}),
# ...
#   frozenset({'WP_005240752_1', 'WP_025432387_1', 'WP_025433622_1'})},
#  'GLNabcpp': {frozenset({'WP_005255435_1', 'WP_164709508_1'}),
#   frozenset({'WP_005243810_1', 'WP_005245035_1', 'WP_164709508_1'}),
#   frozenset({'WP_005243810_1', 'WP_005245035_1', 'WP_179443303_1'}),
#   frozenset({'WP_005245035_1', 'WP_005247432_1', 'WP_164709508_1'}),
#   frozenset({'WP_005247450_1',
#              'WP_005247455_1',
#              'WP_005247457_1',
#              'WP_025432851_1',
#              'WP_025432852_1'})},
#  'GLNS': {frozenset({'WP_025433328_1'}),
#   frozenset({'WP_005246580_1',
#              'WP_005247755_1',
#              'WP_005247775_1',
#              'WP_025433050_1'})},
#  'GLS': {frozenset({'WP_037179298_1'}), frozenset({'WP_005250470_1'})},
#  'GLS2': {frozenset({'WP_037179298_1'}), frozenset({'WP_005250470_1'})},
#  'GLTPD': {frozenset({'WP_005251305_1'})},
#  'GLU5K': {frozenset({'WP_005248066_1'})},
#  'GLUabc': {frozenset({'WP_005255435_1', 'WP_025432117_1'}),
#   frozenset({'WP_025432387_1'})},
#  'GLUabcpp': {frozenset({'WP_005251655_1', 'WP_025432387_1'}),
#   frozenset({'WP_025433433_1'}),
#   frozenset({'WP_025432387_1'})},
#  'GLUABUTt7': {frozenset({'WP_037182248_1'})},
#  'GLUABUTt7pp': {frozenset({'WP_037182248_1'})},
#  'GLUCYS': {frozenset({'WP_143548665_1'})},
#  'GLUDC': {frozenset({'WP_005239357_1'})},
#  'GLUDxi': {frozenset({'WP_005241423_1'}),
#   frozenset({'WP_005248237_1'}),
#   frozenset({'WP_005242136_1'}),
#   frozenset({'WP_005250093_1'})},
#  'GLUDy': {frozenset({'WP_005241423_1'}),
#   frozenset({'WP_005248256_1'}),
#   frozenset({'WP_005250093_1'})},
#  'GLUN': {frozenset({'WP_005240884_1'}), frozenset({'WP_005245583_1'})},
#  'GLUNpp': {frozenset({'WP_005245583_1'})},
#  'GLUPRT': {frozenset({'WP_005247515_1'}),
#   frozenset({'WP_005254820_1'}),
#   frozenset({'WP_005250834_1'})},
#  'GLUR': {frozenset({'WP_005239426_1'})},
#  'GLUSx': {frozenset({'WP_005252414_1'}),
#   frozenset({'WP_005252421_1'}),
#   frozenset({'WP_005250834_1'}),
#   frozenset({'WP_005252421_1', 'WP_025433095_1'})},
#  'GLUSy': {frozenset({'WP_005248272_1', 'WP_005250836_1'}),
#   frozenset({'WP_005249055_1', 'WP_025431556_1'}),
#   frozenset({'WP_005246031_1'}),
#   frozenset({'WP_005252414_1'}),
#   frozenset({'WP_005246031_1', 'WP_005252414_1'})},
#  'GLUt2r': {frozenset({'WP_025433399_1'}), frozenset({'WP_005252416_1'})},
#  'GLUt2rpp': {frozenset({'WP_025433399_1'}), frozenset({'WP_005252416_1'})},
#  'GLUt4': {frozenset({'WP_025433399_1'}), frozenset({'WP_005252416_1'})},
#  'GLUTCOADHc': {frozenset({'WP_005251522_1'})},
#  'GLUTRR': {frozenset({'WP_005251983_1'})},
#  'GLUTRS': {frozenset({'WP_005248712_1'})},
#  'GLXCL': {frozenset({'WP_080578309_1'}), frozenset({'WP_025433274_1'})},
#  'GLXO1': {frozenset({'WP_005239499_1'}), frozenset({'WP_005251153_1'})},
#  'GLYabc': {frozenset({'WP_005250966_1'})},
#  'GLYabcpp': {frozenset({'WP_005247450_1',
#              'WP_005247455_1',
#              'WP_005247457_1',
#              'WP_025432851_1',
#              'WP_025432852_1'}),
#   frozenset({'WP_025432387_1'})},
#  'GLYALDDr': {frozenset({'WP_005239499_1'}), frozenset({'WP_005251153_1'})},
#  'GLYALDt': {frozenset({'WP_187300246_1'})},
#  'GLYAT': {frozenset({'WP_037179256_1'})},
#  'GLYBabc': {frozenset({'WP_005239314_1',
#              'WP_005239327_1',
#              'WP_025432197_1',
#              'WP_025432198_1'}),
#   frozenset({'WP_005244444_1', 'WP_005254252_1'}),
#   frozenset({'WP_005247765_1', 'WP_005247766_1'}),
#   frozenset({'WP_005247765_1', 'WP_005254252_1'})},
#  'GLYBabcpp': {frozenset({'WP_005244444_1'}),
#   frozenset({'WP_025432505_1'}),
#   frozenset({'WP_005247765_1', 'WP_005247768_1'}),
#   frozenset({'WP_005247765_1', 'WP_005247766_1', 'WP_005247768_1'})},
#  'GLYBt2pp': {frozenset({'WP_005261289_1'})},
#  'GLYBt2r': {frozenset({'WP_025432111_1'})},
#  'GLYC3Pabc': {frozenset({'WP_025432120_1', 'WP_025432775_1'}),
#   frozenset({'WP_005242675_1', 'WP_005242678_1', 'WP_025432776_1'}),
#   frozenset({'WP_005243861_1',
#              'WP_005243872_1',
#              'WP_025431951_1',
#              'WP_063624747_1'}),
#   frozenset({'WP_025432775_1'})},
#  'GLYC3Pabcpp': {frozenset({'WP_005250166_1'}),
#   frozenset({'WP_025432775_1'}),
#   frozenset({'WP_005238763_1', 'WP_025432775_1'}),
#   frozenset({'WP_005249635_1'}),
#   frozenset({'WP_025432775_1', 'WP_025432776_1'})},
#  'GLYCAt2rpp': {frozenset({'WP_005243916_1'}), frozenset({'WP_005243363_1'})},
#  'GLYCK': {frozenset({'WP_187300184_1'}),
#   frozenset({'WP_005251015_1'}),
#   frozenset({'WP_187300237_1'}),
#   frozenset({'WP_005241220_1'}),
#   frozenset({'WP_005247726_1'})},
#  'GLYCK2': {frozenset({'WP_187300184_1'}), frozenset({'WP_005251015_1'})},
#  'GLYCL': {frozenset({'WP_005243124_1'}), frozenset({'WP_005250549_1'})},
#  'GLYCL_2': {frozenset({'WP_005250550_1'})},
#  'GLYCLTDx': {frozenset({'WP_005244238_1'}), frozenset({'WP_005243405_1'})},
#  'GLYCLTt2rpp': {frozenset({'WP_025432372_1'})},
#  'GLYCLTt4pp': {frozenset({'WP_025433374_1'})},
#  'GLYCt': {frozenset({'WP_187300246_1'})},
#  'GLYCTO1': {frozenset({'WP_005249489_1'}),
#   frozenset({'WP_025433016_1'}),
#   frozenset({'WP_005252792_1'}),
#   frozenset({'WP_005242149_1'})},
#  'GLYCTO2': {frozenset({'WP_005252792_1'}), frozenset({'WP_005242149_1'})},
#  'GLYCTO3': {frozenset({'WP_005239374_1'}),
#   frozenset({'WP_005252792_1'}),
#   frozenset({'WP_005242149_1'})},
#  'GLYCTO4': {frozenset({'WP_005252792_1'}), frozenset({'WP_005242149_1'})},
#  'GLYK': {frozenset({'WP_005244734_1'}), frozenset({'WP_005239928_1'})},
#  'GLYO1': {frozenset({'WP_005242135_1'})},
#  'GLYOX': {frozenset({'WP_005566972_1'}),
#   frozenset({'WP_025432844_1'}),
#   frozenset({'WP_005250992_1'})},
#  'GLYt2pp': {frozenset({'WP_005251594_1'})},
#  'GLYt2r': {frozenset({'WP_025432629_1'}), frozenset({'WP_005251594_1'})},
#  'GM2LIPAabcpp': {frozenset({'WP_005248726_1'})},
#  'GM2LIPAabctex': {frozenset({'WP_005252054_1'})},
#  'GMPS': {frozenset({'WP_005238105_1'})},
#  'GMPS2': {frozenset({'WP_005238105_1'}), frozenset({'WP_005239791_1'})},
#  'GND': {frozenset({'WP_005249106_1'}), frozenset({'WP_005246074_1'})},
#  'GNK': {frozenset({'WP_005250032_1'}), frozenset({'WP_005573887_1'})},
#  'GNNUC': {frozenset({'WP_025432641_1'})},
#  'GPDDA2': {frozenset({'WP_005248875_1'})},
#  'GRTT': {frozenset({'WP_005252086_1'}),
#   frozenset({'WP_005572244_1'}),
#   frozenset({'WP_005247661_1'})},
#  'GSNt2': {frozenset({'WP_143767469_1'}), frozenset({'WP_005244607_1'})},
#  'GSNt2pp': {frozenset({'WP_143767469_1'})},
#  'GTHOr': {frozenset({'WP_005240598_1'})},
#  'GTHPi': {frozenset({'WP_025431863_1'})},
#  'GTHRDabcpp': {frozenset({'WP_005238097_1',
#              'WP_005251668_1',
#              'WP_025433059_1'}),
#   frozenset({'WP_005238097_1', 'WP_005251668_1', 'WP_005252514_1'}),
#   frozenset({'WP_005238097_1',
#              'WP_005251668_1',
#              'WP_005252514_1',
#              'WP_025433059_1'}),
#   frozenset({'WP_005238097_1',
#              'WP_005251668_1',
#              'WP_005252514_1',
#              'WP_025433178_1'}),
#   frozenset({'WP_005238097_1', 'WP_005248476_1', 'WP_005251668_1'}),
#   frozenset({'WP_005238097_1',
#              'WP_005248476_1',
#              'WP_005251668_1',
#              'WP_025433059_1'})},
#  'GTHS': {frozenset({'WP_005241143_1'})},
#  'GTMLT': {frozenset({'WP_005245018_1', 'WP_037181684_1'})},
#  'GTPCI': {frozenset({'WP_025431746_1'}), frozenset({'WP_187300243_1'})},
#  'GTPCII': {frozenset({'WP_005250334_1'}),
#   frozenset({'WP_005241764_1'}),
#   frozenset({'WP_025433534_1'}),
#   frozenset({'WP_187300227_1'})},
#  'GTPCII2': {frozenset({'WP_025433534_1'})},
#  'GTPDPK': {frozenset({'WP_005241006_1'})},
#  'GTPH1': {frozenset({'WP_005241006_1'})},
#  'GTPHs': {frozenset({'spontaneous'})},
#  'GUACYC': {frozenset({'WP_043943784_1'})},
#  'GUAD': {frozenset({'WP_005244272_1'}),
#   frozenset({'WP_025431586_1'}),
#   frozenset({'WP_005238484_1'}),
#   frozenset({'WP_005244099_1'})},
#  'GUAt2r': {frozenset({'WP_005244137_1'})},
#  'GUDBUTNAH': {frozenset({'WP_005249250_1'})},
#  'H2CO3D': {frozenset({'WP_005244926_1'}), frozenset({'WP_005243937_1'})},
#  'H2Ot': {frozenset({'WP_025432932_1'}),
#   frozenset({'WP_187300245_1'}),
#   frozenset({'spontaneous'})},
#  'H2Otex': {frozenset({'spontaneous'})},
#  'H2Otpp': {frozenset({'WP_025432932_1'}), frozenset({'spontaneous'})},
#  'H2St': {frozenset({'spontaneous'})},
#  'HACD1': {frozenset({'WP_005246568_1'}),
#   frozenset({'WP_005250769_1'}),
#   frozenset({'WP_005240908_1'}),
#   frozenset({'WP_005251685_1'})},
#  'HACD1_2': {frozenset({'WP_005251685_1'})},
#  'HACD1i': {frozenset({'WP_005242640_1'}),
#   frozenset({'WP_005246568_1'}),
#   frozenset({'WP_005249833_1'}),
#   frozenset({'WP_005240908_1'})},
#  'HACD2': {frozenset({'WP_005246568_1'}),
#   frozenset({'WP_005250769_1'}),
#   frozenset({'WP_005240908_1'}),
#   frozenset({'WP_005251685_1'})},
#  'HACD2i': {frozenset({'WP_005246568_1'}),
#   frozenset({'WP_005249833_1'}),
#   frozenset({'WP_005240908_1'})},
#  'HACD3': {frozenset({'WP_005246568_1'}),
#   frozenset({'WP_005250769_1'}),
#   frozenset({'WP_005240908_1'}),
#   frozenset({'WP_005251685_1'})},
#  'HACD3i': {frozenset({'WP_005246568_1'}),
#   frozenset({'WP_005249833_1'}),
#   frozenset({'WP_005240908_1'})},
#  'HACD4': {frozenset({'WP_005246568_1'}),
#   frozenset({'WP_005250769_1'}),
#   frozenset({'WP_005240908_1'}),
#   frozenset({'WP_005251685_1'})},
#  'HACD4i': {frozenset({'WP_005246568_1'}),
#   frozenset({'WP_005249833_1'}),
#   frozenset({'WP_005240908_1'})},
#  'HACD5': {frozenset({'WP_005246568_1'}),
#   frozenset({'WP_005250769_1'}),
#   frozenset({'WP_005240908_1'}),
#   frozenset({'WP_005251685_1'})},
#  'HACD5i': {frozenset({'WP_005246568_1'}),
#   frozenset({'WP_005249833_1'}),
#   frozenset({'WP_005240908_1'})},
#  'HACD6': {frozenset({'WP_005246568_1'}),
#   frozenset({'WP_005250769_1'}),
#   frozenset({'WP_005240908_1'}),
#   frozenset({'WP_005251685_1'})},
#  'HACD6i': {frozenset({'WP_005246568_1'}),
#   frozenset({'WP_005249833_1'}),
#   frozenset({'WP_005240908_1'})},
#  'HACD7': {frozenset({'WP_005246568_1'}),
#   frozenset({'WP_005250769_1'}),
#   frozenset({'WP_005240908_1'}),
#   frozenset({'WP_005251685_1'})},
#  'HACD7i': {frozenset({'WP_005246568_1'}),
#   frozenset({'WP_005249833_1'}),
#   frozenset({'WP_005240908_1'})},
#  'HACD8': {frozenset({'WP_005246568_1'}),
#   frozenset({'WP_005250769_1'}),
#   frozenset({'WP_005240908_1'}),
#   frozenset({'WP_005251685_1'})},
#  'HACD8i': {frozenset({'WP_005246568_1'}), frozenset({'WP_005240908_1'})},
#  'HADPCOADH3': {frozenset({'WP_005243351_1'})},
#  'HCINNMt2r': {frozenset({'WP_005237868_1'})},
#  'HCINNMt2rpp': {frozenset({'WP_005237868_1'})},
#  'HCO3E': {frozenset({'WP_005240214_1'}),
#   frozenset({'WP_005244926_1'}),
#   frozenset({'WP_005243937_1'}),
#   frozenset({'spontaneous'})},
#  'HCYSMT': {frozenset({'WP_005251986_1'})},
#  'HDCAt2pp': {frozenset({'WP_005238237_1'})},
#  'HEX1': {frozenset({'WP_005251402_1'}),
#   frozenset({'WP_037179861_1'}),
#   frozenset({'WP_025433212_1'}),
#   frozenset({'WP_025432958_1'}),
#   frozenset({'WP_005248548_1'})},
#  'HEX7': {frozenset({'WP_005251924_1'}), frozenset({'WP_025433325_1'})},
#  'HEXSabc': {frozenset({'WP_005242735_1',
#              'WP_005244174_1',
#              'WP_025432312_1'})},
#  'HEXt2rpp': {frozenset({'WP_005251827_1'})},
#  'HG2t3pp': {frozenset({'WP_005238136_1'})},
#  'HHDDI': {frozenset({'WP_005241487_1'}),
#   frozenset({'WP_005245351_1'}),
#   frozenset({'WP_005245411_1'}),
#   frozenset({'WP_005249944_1'}),
#   frozenset({'WP_005240391_1'})},
#  'HIBDkt': {frozenset({'WP_005249801_1'}), frozenset({'WP_005252877_1'})},
#  'HISabc': {frozenset({'WP_005247430_1', 'WP_179443303_1'})},
#  'HISabcpp': {frozenset({'WP_005255435_1', 'WP_164709508_1'}),
#   frozenset({'WP_179443303_1'}),
#   frozenset({'WP_025432387_1'}),
#   frozenset({'WP_005247430_1', 'WP_179443303_1'}),
#   frozenset({'WP_005247450_1',
#              'WP_005247455_1',
#              'WP_005247457_1',
#              'WP_025432851_1',
#              'WP_025432852_1'})},
#  'HISDr': {frozenset({'WP_005250990_1'})},
#  'HISt2r': {frozenset({'WP_005245474_1'}), frozenset({'WP_005246692_1'})},
#  'HISTD': {frozenset({'WP_005247527_1'}),
#   frozenset({'WP_005241304_1'}),
#   frozenset({'WP_005244770_1'})},
#  'HISTP': {frozenset({'WP_005240212_1'})},
#  'HKNDDH': {frozenset({'WP_005244806_1'})},
#  'HKNTDH': {frozenset({'WP_005244806_1'})},
#  'HKtpp': {frozenset({'WP_005247909_1', 'WP_025432918_1'})},
#  'HMBS': {frozenset({'WP_005251984_1'})},
#  'HMGCOASi': {frozenset({'WP_005245652_1'})},
#  'HMGL': {frozenset({'WP_037179844_1'}), frozenset({'WP_005250875_1'})},
#  'HMPK1': {frozenset({'WP_005251723_1'})},
#  'HMPK2': {frozenset({'WP_005251723_1'})},
#  'HMPK3': {frozenset({'WP_005251723_1'})},
#  'HMPK4': {frozenset({'WP_005251723_1'})},
#  'HMPSCD': {frozenset({'WP_005239833_1', 'WP_005245262_1'})},
#  'HMSD': {frozenset({'WP_005250165_1'})},
#  'HMSD2': {frozenset({'WP_005250165_1'})},
#  'HMSH': {frozenset({'WP_005245189_1'})},
#  'HMSH2': {frozenset({'WP_005245189_1'})},
#  'HMSH3': {frozenset({'WP_005245189_1'})},
#  'HOPNTAL': {frozenset({'WP_005245212_1'}), frozenset({'WP_005244820_1'})},
#  'HOPNTAL2': {frozenset({'WP_005245212_1'})},
#  'HOPNTAL3': {frozenset({'WP_005245212_1'})},
#  'HPA3MO': {frozenset({'WP_025433337_1'}),
#   frozenset({'WP_005251125_1'}),
#   frozenset({'WP_005251125_1', 'WP_025433337_1'})},
#  'HPACt2r': {frozenset({'WP_025433549_1'})},
#  'HPAtex': {frozenset({'WP_025432619_1'})},
#  'HPPK': {frozenset({'WP_025431747_1'})},
#  'HPPPNDO': {frozenset({'WP_005245205_1'})},
#  'HPPPNt2r': {frozenset({'WP_005237868_1'})},
#  'HPPPNt2rpp': {frozenset({'WP_005237868_1'})},
#  'HPYRI': {frozenset({'WP_005251011_1'})},
#  'HPYRRx': {frozenset({'WP_037179823_1'}), frozenset({'WP_005244238_1'})},
#  'HSDx': {frozenset({'WP_005252944_1'})},
#  'HSDy': {frozenset({'WP_005252944_1'})},
#  'HSERTA': {frozenset({'WP_025433060_1'}), frozenset({'WP_005239866_1'})},
#  'HSK': {frozenset({'WP_005252946_1'})},
#  'HSTPT': {frozenset({'WP_005247524_1'}),
#   frozenset({'WP_025432906_1'}),
#   frozenset({'WP_025431674_1'})},
#  'HXAND': {frozenset({'WP_005250330_1'}),
#   frozenset({'WP_005250106_1', 'WP_025431770_1'}),
#   frozenset({'WP_005244063_1'}),
#   frozenset({'WP_005244063_1', 'WP_005246310_1'}),
#   frozenset({'WP_005250256_1'})},
#  'HXANt2r': {frozenset({'WP_005244137_1'})},
#  'HXCT': {frozenset({'WP_005251310_1'}),
#   frozenset({'WP_005241236_1'}),
#   frozenset({'WP_005244597_1'}),
#   frozenset({'WP_005244597_1', 'WP_005251310_1'}),
#   frozenset({'WP_005241236_1', 'WP_005251310_1'})},
#  'HXPRT': {frozenset({'WP_005244976_1'})},
#  'HYD1': {frozenset({'WP_005244676_1'}),
#   frozenset({'WP_005244676_1', 'WP_005244678_1'})},
#  'HYD1pp': {frozenset({'WP_005244676_1'}),
#   frozenset({'WP_005244676_1', 'WP_005244678_1'})},
#  'HYD2': {frozenset({'WP_005244642_1',
#              'WP_005244670_1',
#              'WP_005244678_1',
#              'WP_005246900_1'}),
#   frozenset({'WP_005244676_1'}),
#   frozenset({'WP_005244676_1', 'WP_005244678_1'})},
#  'HYD2pp': {frozenset({'WP_005244676_1'}),
#   frozenset({'WP_005244676_1', 'WP_005244678_1'})},
#  'HYD3': {frozenset({'WP_005244676_1'}),
#   frozenset({'WP_005244676_1', 'WP_005244678_1'})},
#  'HYD3pp': {frozenset({'WP_005244676_1'}),
#   frozenset({'WP_005244676_1', 'WP_005244678_1'})},
#  'HYDA1': {frozenset({'WP_005244678_1', 'WP_187300187_1'})},
#  'I2FE2SR': {frozenset({'WP_005240338_1', 'WP_025432540_1'})},
#  'I2FE2SS2': {frozenset({'WP_005240338_1', 'WP_025432540_1'})},
#  'I2FE2ST': {frozenset({'WP_005240338_1', 'WP_025432540_1'}),
#   frozenset({'WP_005247725_1'})},
#  'I4FE4SR': {frozenset({'WP_005240338_1', 'WP_025432540_1'})},
#  'I4FE4ST': {frozenset({'WP_005240338_1', 'WP_025432540_1'}),
#   frozenset({'WP_005247725_1'})},
#  'ICDHx': {frozenset({'WP_005248976_1'})},
#  'ICDHyr': {frozenset({'WP_005239870_1'}), frozenset({'WP_005242822_1'})},
#  'ICHORS': {frozenset({'WP_005244440_1'})},
#  'ICHORT': {frozenset({'WP_005251483_1'})},
#  'ICITt_kt': {frozenset({'WP_025431984_1'}), frozenset({'WP_005244287_1'})},
#  'ICL': {frozenset({'WP_005251848_1'})},
#  'ICYSDS': {frozenset({'WP_005240338_1'})},
#  'IDOND': {frozenset({'WP_005258023_1'})},
#  'IDOND2': {frozenset({'WP_005258023_1'})},
#  'IG3PS': {frozenset({'WP_005247506_1'})},
#  'IGPDH': {frozenset({'WP_005247522_1'})},
#  'IGPS': {frozenset({'WP_005247490_1'})},
#  'ILEabc': {frozenset({'WP_005244316_1', 'WP_005244318_1', 'WP_005244465_1'})},
#  ...}

# %% [markdown]
# ## E-Flux2

# %% [markdown]
# ### Set non-zero lower and upper bounds to 0.0 or +/-Inf

# %%
for r in model.reactions:
    if r.lower_bound < 0.0 and r.lower_bound > -1000.0:
        print(r.id, r.lower_bound, r.upper_bound)
        r.lower_bound = -1000.0
    elif r.lower_bound > 0.0:
        print(r.id, r.lower_bound, r.upper_bound)
        r.lower_bound = 0.0
    elif r.upper_bound > 0.0 and r.upper_bound < 1000.0:
        print(r.id, r.lower_bound, r.upper_bound)
        r.upper_bound = 1000.0
    elif r.upper_bound < 0.0:
        print(r.id, r.lower_bound, r.upper_bound)
        r.upper_bound = 0.0
# Out:
# EX_glc__D_e -10.0 1000.0
# EX_h2o_e -10.0 1000.0
# EX_h_e -10.0 1000.0
# EX_cl_e -10.0 1000.0
# EX_pi_e -10.0 1000.0
# EX_nh4_e -10.0 1000.0
# EX_fe3_e -10.0 1000.0
# EX_k_e -10.0 1000.0
# EX_ca2_e -10.0 1000.0
# EX_mg2_e -10.0 1000.0
# EX_mn2_e -10.0 1000.0
# EX_cobalt2_e -10.0 1000.0
# EX_zn2_e -10.0 1000.0
# EX_cu2_e -10.0 1000.0
# EX_o2_e -10.0 1000.0
# EX_fe2_e -10.0 1000.0
# EX_mobd_e -10.0 1000.0
# EX_so4_e -10.0 1000.0

# %%
for r in model.reactions:
    if r.lower_bound == -1000.0:
        r.lower_bound = -np.Inf
    if r.upper_bound == 1000.0:
        r.upper_bound = np.Inf

# %% [markdown]
# ### Load transcriptomics data and calculate lower and upper bounds

# %%
Transcriptomics = pd.read_csv('ishii-trans-1.csv', index_col=0, header=None)
Transcriptomics.head()
# Out:
#                1
# 0
# b0957  45.278681
# b0929  42.173087
# b1480  38.351485
# b3299  29.201456
# b2093  36.778437

# %%
lb = []
ub = []
for r in model.reactions:
    if r.gene_reaction_rule:
        t = np.sum([np.min([Transcriptomics.loc[g].values if g in Transcriptomics.index 
                            else np.array([np.Inf]) for g in p])
                    for p in gpr_dict[r.id]])
        if r.lower_bound < 0.0:
            lb.append(-t)
        else:
            lb.append(r.lower_bound)
        if r.upper_bound > 0.0:
            ub.append(t)
        else:
            ub.append(r.upper_bound)
    else:
        lb.append(r.lower_bound)
        ub.append(r.upper_bound)

# %% [markdown]
# ### Build a CPLEX model of E-Flux2 and solve

# %%
EFlux2 = cplex.Cplex()
EFlux2.parameters.simplex.tolerances.optimality.set(1e-9)
EFlux2.parameters.simplex.tolerances.feasibility.set(1e-9)

EFlux2.linear_constraints.add(rhs=[0]*nrow, senses='E'*nrow, names=mets)
EFlux2.variables.add(obj=c, lb=lb, ub=ub, names=rxns)
for r in model.reactions:
    for m, v in r.metabolites.items():
        EFlux2.linear_constraints.set_coefficients(m.id, r.id, v)
        
EFlux2.objective.set_sense(EFlux2.objective.sense.maximize)
EFlux2.solve()
EFlux2_sol = EFlux2.solution.get_objective_value()
print
print(EFlux2.solution.get_status_string())
print(EFlux2_sol)
# Out:
# CPXPARAM_Simplex_Tolerances_Optimality           1.0000000000000001e-09
# CPXPARAM_Simplex_Tolerances_Feasibility          1.0000000000000001e-09
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 812 rows and 1098 columns.
# Aggregator did 523 substitutions.
# Reduced LP has 470 rows, 962 columns, and 4747 nonzeros.
# Presolve time = 0.01 sec. (2.87 ticks)
# Initializing dual steep norms . . .
#
# Iteration log . . .
# Iteration:     1   Scaled dual infeas =             0.786571
# Iteration:    86   Scaled dual infeas =             0.009009
# Iteration:    88   Dual objective     =             3.664956
# Iteration:   162   Dual objective     =             1.755820
# Iteration:   230   Dual objective     =             1.223704
# Iteration:   294   Dual objective     =             0.914004
# Iteration:   356   Dual objective     =             0.698602
# Perturbation started.
# Iteration:   394   Dual objective     =             0.698602
# Iteration:   456   Dual objective     =             0.519676
# Iteration:   520   Dual objective     =             0.334820
# Iteration:   582   Dual objective     =             0.334813
# Iteration:   644   Dual objective     =             0.334810
# Removing perturbation.
# optimal
# 0.3348274891377517

# %% [markdown]
# ### Build a CPLEX model to minimize L2 norm and solve

# %%
Q = [1.0 for r in model.reactions]

# %%
EFlux2_min = cplex.Cplex()
EFlux2_min.parameters.simplex.tolerances.optimality.set(1e-9)
EFlux2_min.parameters.simplex.tolerances.feasibility.set(1e-9)

EFlux2_min.linear_constraints.add(rhs=[0]*nrow, senses='E'*nrow, names=mets)
EFlux2_min.variables.add(obj=[0]*ncol, lb=lb, ub=ub, names=rxns)
for r in model.reactions:
    for m, v in r.metabolites.items():
        EFlux2_min.linear_constraints.set_coefficients(m.id, r.id, v)

EFlux2_min.variables.set_lower_bounds('Ec_biomass_iJO1366_core_53p95M', 1.0*EFlux2_sol)
EFlux2_min.objective.set_quadratic(Q)
EFlux2_min.objective.set_sense(EFlux2_min.objective.sense.minimize)
EFlux2_min.solve()
EFlux2_min_sol = EFlux2_min.solution.get_objective_value()
EFlux2_min.solution.get_status_string()
# Out:
# CPXPARAM_Simplex_Tolerances_Optimality           1.0000000000000001e-09
# CPXPARAM_Simplex_Tolerances_Feasibility          1.0000000000000001e-09
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# QP Presolve eliminated 235 rows and 259 columns.
# Reduced QP has 1570 rows, 2324 columns, and 9095 nonzeros.
# Reduced QP objective Q matrix has 2324 nonzeros.
# Presolve time = 0.01 sec. (1.50 ticks)
# Parallel mode: using up to 32 threads for barrier.
#
# ***NOTE: Found 2 dense columns.
#
# Number of nonzeros in lower triangle of A*A' = 8874
# Using Approximate Minimum Degree ordering
# Total time for automatic ordering = 0.01 sec. (1.32 ticks)
# Summary statistics for Cholesky factor:
#   Threads                   = 32
#   Rows in Factor            = 1572
#   Integer space required    = 5931
#   Total non-zeros in factor = 26893
#   Total FP ops to factor    = 803867
#  Itn      Primal Obj        Dual Obj  Prim Inf Upper Inf  Dual Inf
#    0   9.9323679e+06  -5.1907136e+07  8.91e+04  1.30e+05  8.28e+05
#    1   6.6167056e+05  -2.0567993e+07  2.19e+04  3.20e+04  2.03e+05
#    2   8.2698859e+04  -8.6839122e+06  6.71e+03  9.82e+03  6.23e+04
#    3   8.6531338e+03  -4.7737611e+06  2.22e+03  3.25e+03  2.07e+04
#    4   7.0448077e+03  -4.3621161e+06  1.72e+03  2.52e+03  1.60e+04
#    5   3.3712955e+03  -2.6505347e+06  8.28e+02  1.21e+03  7.69e+03
#    6   1.9736448e+03  -1.1001654e+06  2.82e+02  4.12e+02  2.62e+03
#    7   1.7803732e+03  -5.4106189e+05  1.15e+02  1.68e+02  1.07e+03
#    8   1.6610208e+03  -3.5788496e+05  5.58e+01  8.16e+01  5.18e+02
#    9   1.6615928e+03  -3.0099917e+05  4.12e+01  6.03e+01  3.83e+02
#   10   1.7067292e+03  -1.9817058e+05  1.68e+01  2.46e+01  1.56e+02
#   11   1.7213429e+03  -1.7280114e+05  1.27e+01  1.86e+01  1.18e+02
#   12   1.7403526e+03  -7.9878570e+04  4.10e+00  6.00e+00  3.81e+01
#   13   1.6849102e+03  -2.6405793e+04  6.35e-01  9.29e-01  5.90e+00
#   14   1.4991168e+03  -1.4494178e+04  2.58e-01  3.77e-01  2.39e+00
#   15   1.3826730e+03  -6.7084852e+03  1.12e-01  1.64e-01  1.04e+00
#   16   1.2998007e+03  -1.9862851e+03  1.66e-02  2.42e-02  1.54e-01
#   17   1.1738632e+03  -8.1318786e+02  9.93e-03  1.45e-02  9.22e-02
#   18   1.1317661e+03  -5.6112326e+02  8.47e-03  1.24e-02  7.87e-02
#   19   1.1235870e+03  -3.8639114e+02  7.56e-03  1.11e-02  7.02e-02
#   20   1.0275402e+03   4.1798602e+01  4.93e-03  7.21e-03  4.58e-02
#   21   9.5202811e+02   4.2202785e+02  2.65e-03  3.87e-03  2.46e-02
#   22   9.1956041e+02   5.5897465e+02  1.80e-03  2.64e-03  1.67e-02
#   23   8.7406080e+02   7.7598861e+02  4.90e-04  7.17e-04  4.55e-03
#   24   8.6526099e+02   8.1869527e+02  2.33e-04  3.41e-04  2.16e-03
#   25   8.5989136e+02   8.4454352e+02  7.67e-05  1.12e-04  7.12e-04
#   26   8.5934726e+02   8.4752680e+02  5.91e-05  8.65e-05  5.49e-04
#   27   8.5781489e+02   8.5502154e+02  1.39e-05  2.04e-05  1.29e-04
#   28   8.5740782e+02   8.5700082e+02  2.02e-06  2.96e-06  1.88e-05
#   29   8.5734666e+02   8.5729445e+02  2.57e-07  3.75e-07  2.38e-06
#   30   8.5733770e+02   8.5733684e+02  3.50e-09  5.12e-09  3.43e-08
#   31   8.5733752e+02   8.5733747e+02  1.25e-10  1.82e-10  4.26e-09
#   32   8.5733751e+02   8.5733750e+02  9.20e-12  1.39e-11  2.85e-09
# Barrier time = 0.34 sec. (28.34 ticks)
#
# Total time on 32 threads = 0.34 sec. (28.34 ticks)
# 'optimal'

# %% [markdown]
# ### Get the E-Flux2 solution and plot against 13C experimental data

# %%
# E-Flux2 solution
EFlux2_fluxdict = dict(zip(rxns,EFlux2_min.solution.get_values()))
# Ishii flux data, WT reference strain [mmol/gDW/h]: http://ecoli.iab.keio.ac.jp/ > Fluxome > Fluxome data
reactionDict = {'PGI':2076,'PFK':2063,'FBA':1150,'TPI':2455,'PYK':2265,'PDH':2046,'GND':1422,'RPE':2311,'RPI':2312,'TALA':2397,'ICL':1551,'MALS':1713}
ishiiDict = {2076:2.247179186,2063:2.495301258,1150:2.495301258,2455:2.495301258,2265:1.399624166,2046:3.722827564,1422:.6439079794,2311:.2684455913,2312:.3754514687,2397:.1783978343,1551:.3268244693,1713:.3268244693}

# %%
Exp, EFlux2_flux = [],[]
for k, v in reactionDict.items():
    Exp.append(ishiiDict[v])
    EFlux2_flux.append(EFlux2_fluxdict[k])
Exp = np.array(Exp)
EFlux2_flux = np.array(EFlux2_flux)

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.scatter(Exp,EFlux2_flux)
ax.set_xlim(-1,5)
ax.set_ylim(-1,5)
ax.plot(ax.get_xlim(), ax.get_ylim(), ls="--", c=".3")
Labels = [i for i in reactionDict]
for i in range(len(Exp)):
    xy = (Exp[i]+.1,EFlux2_flux[i]+.1)
    ax.annotate(Labels[i],xy)
plt.xlabel(r'Ishii $et$ $al$ experimental flux measurement (mmol/gDW/h)')
plt.ylabel(r'E-Flux2 flux prediction (mmol/gDW/h)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## SPOT

# %% [markdown]
# ### Split reversible reactions into two irreversible reactions

# %%
rev_rxns = ['rev_'+r.id for r in model.reactions if r.reversibility]
rev_ncol = len(rev_rxns)
print(rev_ncol)
# Out:
# 636

# %%
lb = [0.0 if r.reversibility else r.lower_bound for r in model.reactions] + [0.0 for r in model.reactions if r.reversibility]
ub = [r.upper_bound for r in model.reactions] + [-r.lower_bound for r in model.reactions if r.reversibility]

# %% [markdown]
# ### Calculate objective function coefficients from transcriptomics

# %%
c = []
for r in model.reactions:
    if r.gene_reaction_rule:
        t = np.sum([np.min([Transcriptomics.loc[g].values if g in Transcriptomics.index 
                            else np.array([np.Inf]) for g in p])
                    for p in gpr_dict[r.id]])
        if t == np.Inf:
            t = 0
        c.append(t)
    else:
        c.append(0.0)
for r in model.reactions:
    if r.reversibility:
        if r.gene_reaction_rule:
            t = np.sum([np.min([Transcriptomics.loc[g].values if g in Transcriptomics.index 
                                else np.array([np.Inf]) for g in p])
                        for p in gpr_dict[r.id]])
            if t == np.Inf:
                t = 0
            c.append(t)
        else:
            c.append(0.0)

# %% [markdown]
# ### Build a CPLEX model of SPOT and solve

# %%
SPOT = cplex.Cplex()
SPOT.parameters.simplex.tolerances.optimality.set(1e-9)
SPOT.parameters.simplex.tolerances.feasibility.set(1e-9)

SPOT.linear_constraints.add(rhs=[0]*nrow, senses='E'*nrow, names=mets)
SPOT.variables.add(obj=c, lb=lb, ub=ub, names=rxns+rev_rxns)
for r in model.reactions:
    for m, v in r.metabolites.items():
        SPOT.linear_constraints.set_coefficients(m.id, r.id, v)
for r in model.reactions:
    if r.reversibility:
        for m, v in r.metabolites.items():
            SPOT.linear_constraints.set_coefficients(m.id, 'rev_'+r.id, -v)
SPOT.quadratic_constraints.add(quad_expr=[rxns+rev_rxns, rxns+rev_rxns, [1]*len(c)],
                               sense='L', rhs=100000.0, name='L2norm')
SPOT.objective.set_sense(SPOT.objective.sense.maximize)
SPOT.solve()
SPOT_sol = SPOT.solution.get_objective_value()
print
print(SPOT.solution.get_status_string())
print(SPOT_sol)
# Out:
# CPXPARAM_Simplex_Tolerances_Optimality           1.0000000000000001e-09
# CPXPARAM_Simplex_Tolerances_Feasibility          1.0000000000000001e-09
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# QCP Presolve eliminated 199 rows and 222 columns.
# Reduced QCP has 4604 rows, 2998 columns, and 13937 nonzeros.
# Reduced QCP has 1 quadratic constraints.
# Presolve time = 0.01 sec. (2.32 ticks)
# Parallel mode: using up to 32 threads for barrier.
#
# ***NOTE: Found 3 dense columns.
#
# Number of nonzeros in lower triangle of A*A' = 19608
# Using Approximate Minimum Degree ordering
# Total time for automatic ordering = 0.01 sec. (1.72 ticks)
# Summary statistics for Cholesky factor:
#   Threads                   = 32
#   Rows in Factor            = 4604
#   Integer space required    = 12299
#   Total non-zeros in factor = 52314
#   Total FP ops to factor    = 1022224
#  Itn      Primal Obj        Dual Obj  Prim Inf Upper Inf  Dual Inf Inf Ratio
#    0   0.0000000e+00   0.0000000e+00  3.31e+03  0.00e+00  4.65e+04  1.00e+00
#    1   3.5652364e+02   3.5651994e+02  3.31e+03  0.00e+00  4.65e+04  9.97e-01
#    2   3.0567156e+03   3.0566838e+03  3.31e+03  0.00e+00  4.65e+04  9.72e-01
#    3   3.5386482e+03   3.5385034e+03  3.30e+03  0.00e+00  4.64e+04  8.78e-01
#    4   5.7887832e+03   5.7886159e+03  3.29e+03  0.00e+00  4.62e+04  8.65e-01
#    5   1.3564252e+04   1.3564016e+04  3.27e+03  0.00e+00  4.60e+04  8.28e-01
#    6   8.6854819e+04   8.6853445e+04  3.22e+03  0.00e+00  4.52e+04  4.57e-01
#    7   2.4608526e+05   2.4608251e+05  2.70e+03  0.00e+00  3.79e+04  3.09e-01
#    8   2.4921046e+05   2.4920777e+05  1.62e+03  0.00e+00  2.28e+04  3.14e-01
#    9   4.2293724e+05   4.2293602e+05  1.60e+03  0.00e+00  2.25e+04  7.41e-01
#   10   4.5971554e+05   4.5971509e+05  4.12e+02  0.00e+00  5.78e+03  2.01e+00
#   11   4.7308903e+05   4.7308883e+05  1.58e+02  0.00e+00  2.22e+03  4.69e+00
#   12   4.7652674e+05   4.7652661e+05  6.54e+01  0.00e+00  9.18e+02  7.26e+00
#   13   4.7803813e+05   4.7803804e+05  4.16e+01  0.00e+00  5.84e+02  9.78e+00
#   14   4.7918416e+05   4.7918409e+05  3.11e+01  0.00e+00  4.37e+02  1.24e+01
#   15   4.8108862e+05   4.8108858e+05  2.32e+01  0.00e+00  3.25e+02  2.73e+01
#   16   4.8122841e+05   4.8122838e+05  9.92e+00  0.00e+00  1.39e+02  2.96e+01
#   17   4.8136714e+05   4.8136712e+05  8.95e+00  0.00e+00  1.26e+02  3.34e+01
#   18   4.8223152e+05   4.8223152e+05  7.99e+00  0.00e+00  1.12e+02  1.28e+02
#   19   4.8248951e+05   4.8248951e+05  1.96e+00  0.00e+00  2.75e+01  1.58e+03
#   20   4.8250273e+05   4.8250273e+05  1.57e-01  0.00e+00  2.20e+00  3.58e+03
#   21   4.8251028e+05   4.8251028e+05  6.44e-02  0.00e+00  9.05e-01  2.00e+04
#   22   4.8251128e+05   4.8251128e+05  1.14e-02  0.00e+00  1.61e-01  5.05e+04
# optimal
# 482511.2769459807

# %% [markdown]
# ### Get the SPOT solution and plot against 13C experimental data

# %%
SPOT_fluxdict = dict(zip(rxns,SPOT.solution.get_values()))

# %%
plt.hist(SPOT_fluxdict.values())
plt.show()

# %%
SPOT_flux = []
for k, v in reactionDict.items():
    SPOT_flux.append(SPOT_fluxdict[k])
SPOT_flux = np.array(SPOT_flux)

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.scatter(Exp,SPOT_flux)
ax.set_xlim(-1,5)
ax.set_ylim(-1,5)
ax.plot(ax.get_xlim(), ax.get_ylim(), ls="--", c=".3")
Labels = [i for i in reactionDict]
for i in range(len(Exp)):
    xy = (Exp[i]+.1,SPOT_flux[i]+.1)
    ax.annotate(Labels[i],xy)
plt.xlabel(r'Ishii $et$ $al$ experimental flux measurement (mmol/gDW/h)')
plt.ylabel(r'SPOT flux prediction (mmol/gDW/h)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### Load Ishii flux data

# %%
# Load reaction names
reactionNames = np.loadtxt('ishii-flux-names.csv', delimiter=',', skiprows=0, usecols=0, dtype='str')
# Load train and test data
# Training data is from eflux2 samples 2 to 8, representing different KEIO KO strains and growth conditions
# Test data is eflux2 sample1, the WT reference sample
train_x, train_y = [],[]
for i in range(2,9):
    train_x.append(np.loadtxt('ishii-trans-'+str(i)+'.csv', delimiter=',', skiprows=0, usecols=1))
    train_y.append(np.loadtxt('ishii-flux-'+str(i)+'.csv'))
test_x, test_y = np.loadtxt('ishii-trans-1.csv', delimiter=',', skiprows=0, usecols=1), np.loadtxt('ishii-flux-1.csv')
train_x, train_y = np.array(train_x), np.array(train_y)

# %% [markdown]
# ### Define and run random forest for each reaction

# %%
# Load data into arrays for plotting
RF_array, eflux2, absError = [],[],[]
for r in range(len(reactionNames)):
    # Define type of random forest
    rf = RandomForestRegressor(n_estimators=20, oob_score=False, random_state=0, n_jobs=8, max_features=10, max_leaf_nodes=10)
    rf.fit(train_x, train_y[:,r])
    # Use the forest's predict method on the test data
    predictions = rf.predict(test_x.reshape(1, -1))
    i = r
    print('Working on reaction:', reactionNames[i])
    print('   Random Forest:', predictions[0], '|   Eflux2 prediction:', test_y[i])
    RF_array.append(predictions[0])
    eflux2.append(float(test_y[i]))
    absError.append(abs(predictions[0]-float(test_y[i])))
RF_array = np.array(RF_array)
eflux2 = np.array(eflux2)

# %% [markdown]
# ### Find optimal stoichiometric nudge - very slow, need to update using CPLEX or conopt

# %%
xf = np.transpose(RF_array)
x0 = np.zeros(len(test_y))+.000005

# Weight factor for relative importance of Sv over the length of the nudging vector= b
weightFactor = 1000.0
print('Initial ||Sv|| = ',np.dot(np.matmul(S.values,xf),np.matmul(S.values,xf)))
print('   Now find nudging vector minimizeResult.x which reduces Sv to zero')

def rosen(x):
    adjusted_fluxes =xf[:]-x[:]
    a = np.matmul(S.values,adjusted_fluxes)
    Sloss = np.dot(a,a)*weightFactor
    bLength = sum((x[:])**2)
    
    # Get occasional updates on solver progress
    if np.random.rand()<.001:
        print('||S(v-b)||=',Sloss/weightFactor,', ||b||=',bLength)
    return bLength + Sloss

# Minimize f = ||S(v-b)||*weightFactor + ||b||
minimizeResult = minimize(rosen, x0, method='BFGS', options={'disp': True, 'maxiter': 10})
# Out:
# Initial ||Sv|| =  15.548938970576701
#    Now find nudging vector minimizeResult.x which reduces Sv to zero
# ||S(v-b)||= 15.528776506058254 , ||b||= 6.457514923365838e-08
# ||S(v-b)||= 15.528776613974294 , ||b||= 6.457514923365838e-08
# ||S(v-b)||= 15.528776443305757 , ||b||= 6.457514923365838e-08
# ||S(v-b)||= 15.528776675683932 , ||b||= 6.457514923365838e-08
# ||S(v-b)||= 15.528776516269188 , ||b||= 6.457514923365838e-08
# ||S(v-b)||= 15.52877654820239 , ||b||= 6.457514923365838e-08
# ||S(v-b)||= 27147.274457530064 , ||b||= 1.0201711597986858
# ||S(v-b)||= 27147.274454921775 , ||b||= 1.0201711595786773
# ||S(v-b)||= 27147.27445492143 , ||b||= 1.0201711595787022
# ||S(v-b)||= 27147.27445753042 , ||b||= 1.0201711597986884
# ||S(v-b)||= 27147.274461619312 , ||b||= 1.020171159762512
# ||S(v-b)||= 27147.274460097768 , ||b||= 1.0201711600313632
# ||S(v-b)||= 27147.274468459742 , ||b||= 1.0201711601436985
# ||S(v-b)||= 12.5175499539586 , ||b||= 0.00011166132365471474
# ||S(v-b)||= 12.517549948941156 , ||b||= 0.00011166132384003866
# ||S(v-b)||= 12.517549964741512 , ||b||= 0.00011166132149598839
# ||S(v-b)||= 12.517549956777923 , ||b||= 0.00011166132520663219
# ||S(v-b)||= 8.061969700825829 , ||b||= 0.001659812346823884
# ||S(v-b)||= 8.061969704546314 , ||b||= 0.001659812345085557
# ||S(v-b)||= 5.34439844236671 , ||b||= 0.02581460486304177
# ||S(v-b)||= 5.344398477443369 , ||b||= 0.02581460495854685
# ||S(v-b)||= 3.828815944952763 , ||b||= 0.0806453716531583
# ||S(v-b)||= 3.828815961344254 , ||b||= 0.08064537166186662
# ||S(v-b)||= 5.13670068427114 , ||b||= 0.15995394271312027
# ||S(v-b)||= 3.2925601684021637 , ||b||= 0.10088525909420869
# ||S(v-b)||= 3.2925601655578256 , ||b||= 0.10088525901566577
# ||S(v-b)||= 4.510975644597334 , ||b||= 0.14062516573734654
# ||S(v-b)||= 4.510975644600593 , ||b||= 0.1406251657373379
# ||S(v-b)||= 4.510975682252107 , ||b||= 0.14062516571154351
# ||S(v-b)||= 3.1651109462150746 , ||b||= 0.10750305647852247
# ||S(v-b)||= 3.16511098706057 , ||b||= 0.10750305640389485
# ||S(v-b)||= 2.966613334060907 , ||b||= 0.11673234078354065
# ||S(v-b)||= 2.9666132642247596 , ||b||= 0.11673234005565201
# ||S(v-b)||= 2.966613294659466 , ||b||= 0.11673234069366267
# ||S(v-b)||= 2.966613300576698 , ||b||= 0.11673234073129259
# ||S(v-b)||= 2.966613299374702 , ||b||= 0.11673234061735856
# ||S(v-b)||= 2.7330350214127375 , ||b||= 0.13965610474415394
# ||S(v-b)||= 2.7330349611369424 , ||b||= 0.13965610473145226
# ||S(v-b)||= 2.733035002731287 , ||b||= 0.1396561046727691
# ||S(v-b)||= 2.7330349810740184 , ||b||= 0.13965610473992215
# ||S(v-b)||= 2.8991264298702806 , ||b||= 0.1889514612997566
# ||S(v-b)||= 2.899126303015711 , ||b||= 0.18895146176681565
# ||S(v-b)||= 2.8991264299985406 , ||b||= 0.18895146089653514
# ||S(v-b)||= 2.899126372970177 , ||b||= 0.18895146006159896
# ||S(v-b)||= 2.8991263993509486 , ||b||= 0.18895146115927433
# ||S(v-b)||= 2.6457925842402306 , ||b||= 0.1542996227820168
# ||S(v-b)||= 2.64579258912105 , ||b||= 0.1542996227042564
# ||S(v-b)||= 2.591276420315004 , ||b||= 0.17444131043149264
# ||S(v-b)||= 2.591276436265554 , ||b||= 0.17444131025827211
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 2591.450856
#          Iterations: 10
#          Function evaluations: 38775
#          Gradient evaluations: 15

# %% [markdown]
# ### Apply the stoichiometric nudge to the Random Forest solution and plot against E-Flux2 and 13C experimental data

# %%
# Use the forest's predict method on the test data
predictions = RF_array - minimizeResult.x
# Calculate the absolute errors of random forest vs eflux2
allAbsError = abs(predictions - test_y)

# %%
# Load data into arrays for plotting
RF_flux, eflux2, absError = [],[],[]
for i in reactionDict.values():
    print('Working on reaction:',reactionNames[i])
    print('   Random Forest:',predictions[i],'Eflux2 prediction:',test_y[i])
    RF_flux.append(predictions[i])
    eflux2.append(float(test_y[i]))
    absError.append(abs(predictions[i]-float(test_y[i])))
RF_flux = np.array(RF_flux)
eflux2 = np.array(eflux2)
# Out:
# Working on reaction: R_PGI
#    Random Forest: 2.2506128746601224 Eflux2 prediction: 2.296128682
# Working on reaction: R_PFK
#    Random Forest: 2.1787934581434 Eflux2 prediction: 1.790151679
# Working on reaction: R_FBA
#    Random Forest: 2.1728773525184186 Eflux2 prediction: 1.790151679
# Working on reaction: R_TPI
#    Random Forest: 3.9568565697581426 Eflux2 prediction: 3.378207362
# Working on reaction: R_PYK
#    Random Forest: 2.904161249011642 Eflux2 prediction: 1.563415101
# Working on reaction: R_PDH
#    Random Forest: 0.6667795095367863 Eflux2 prediction: 1.100181514
# Working on reaction: R_GND
#    Random Forest: 1.988202822727557 Eflux2 prediction: 1.691451557
# Working on reaction: R_RPE
#    Random Forest: 1.0734950574800828 Eflux2 prediction: 0.867799311
# Working on reaction: R_RPI
#    Random Forest: -0.903366013207484 Eflux2 prediction: -0.810324773
# Working on reaction: R_TALA
#    Random Forest: -1.0150652146373342 Eflux2 prediction: -0.861606754
# Working on reaction: R_ICL
#    Random Forest: 0.20392940982909671 Eflux2 prediction: 1.98e-11
# Working on reaction: R_MALS
#    Random Forest: 0.2838086662669786 Eflux2 prediction: 0.000224

# %%
fig, [ax1, ax2] = plt.subplots(1, 2, figsize=(10, 5))

ax1.scatter(EFlux2_flux,RF_flux)
ax1.set_xlim(-2,5)
ax1.set_ylim(-2,5)
ax1.plot(ax1.get_xlim(), ax1.get_ylim(), ls="--", c=".3")
Labels = [i for i in reactionDict]
for i in range(len(EFlux2_flux)):
    xy = (EFlux2_flux[i]+.1,RF_flux[i]+.1)
    ax1.annotate(Labels[i],xy)
ax1.set_xlabel(r'E-Flux2 flux prediction (mmol/gDW/h)')
ax1.set_ylabel(r'Random Forest flux prediction (mmol/gDW/h)')

ax2.scatter(Exp,RF_flux)
ax2.set_xlim(-2,5)
ax2.set_ylim(-2,5)
ax2.plot(ax2.get_xlim(), ax2.get_ylim(), ls="--", c=".3")
Labels = [i for i in reactionDict]
for i in range(len(Exp)):
    xy = (Exp[i]+.1,RF_flux[i]+.1)
    ax2.annotate(Labels[i],xy)
ax2.set_xlabel(r'Ishii $et$ $al$ experimental flux measurement (mmol/gDW/h)')
ax2.set_ylabel(r'Random Forest flux prediction (mmol/gDW/h)')

plt.tight_layout()
plt.show()

# %%
# Histogram plot of errors
g=sns.distplot(absError,hist=True)
plt.xlabel(r'Abolute error of Random Forest vs Eflux2 base (mmol/gDW/h)')
plt.ylabel(r'Normalized frequency')
plt.xlim(0,3)
#plt.show()
#plt.savefig('rf-eflux2-nudging-error.pdf')
# Out:
# (0, 3)

# %%
# Zoom of histogram error
g=sns.distplot(absError,hist=True)
plt.xlabel(r'Abolute error of Random Forest vs Eflux2 base (mmol/gDW/h)')
plt.ylabel(r'Normalized frequency')
plt.xlim(0,3)
plt.ylim(0,1.5)
#plt.show()
#plt.savefig('rf-eflux2-error-nudging-zoom.pdf')
# Out:
# (0, 1.5)

# %%
# Histogram plot of all errors
g=sns.distplot(allAbsError,hist=True)
plt.xlabel(r'Abolute error of Random Forest vs Eflux2 base (mmol/gDW/h)')
plt.ylabel(r'Normalized frequency')
plt.xlim(0,3)
#plt.show()
#plt.savefig('rf-eflux2-allReactions-nudging-error.pdf')
# Out:
# (0, 3)

# %%
# Zoom of histogram all errors
g=sns.distplot(allAbsError,hist=True)
plt.xlabel(r'Abolute error of Random Forest vs Eflux2 base (mmol/gDW/h)')
plt.ylabel(r'Normalized frequency')
plt.xlim(0,3)
plt.ylim(0,.2)
#plt.show()
#plt.savefig('rf-eflux2-allReactions-error-nudging-zoom.pdf')
# Out:
# (0, 0.2)
