# %% [markdown]
# ## **Notebook to make predictions with reprocessed Yoneda data and EFLUX2**
#
# By Christina Schenk and Garrett Roell
#
# Tested on biodesign_3.7 kernel on jprime

# %% [markdown]
# ### EFLUX2 predictions and evaluations
# This notebook predicts fluxes for R. opacus cultures growing with glucose. The data was published in [Yoneda (2016)](https://academic.oup.com/nar/article/44/5/2240/2465306).
#
#
#
# #### **Data Labels**:
#
# #### Yoneda transcriptomics data:
# * WT 1.0 g/L Glucose, 0.05g/L ammonium sulfate (**WT-LN-G**) (3 trials)
#
# #### Combined with Rhiannon 2018 metabolomics and OD data:
# * Metabolomics and OD data for WT Glucose (before **WT-G** but now **WT-LN-G**)
#
#
# ### Method:
# <ol>
# <li>Predict fluxes with EFLUX2</li>
# <li>Compare predictions with 13CMFA: Scatter plots and flux maps</li>
# <li>Load file with observed growth rates (Notebook E)</li>
# <li>Save growth rate predictions to csv file</li>
# </ol>

# %% [markdown]
# ##### **Import python packages**

# %%
import os
import sys
import pandas as pd
import numpy as np
import cobra
import scipy.stats
#import cplex
# %matplotlib inline

import matplotlib
from matplotlib import pyplot as plt
from matplotlib.offsetbox import (TextArea, DrawingArea, OffsetImage,
                                  AnnotationBbox)
from matplotlib.cbook import get_sample_data
import matplotlib.image as mpimg
import matplotlib.cm as cm

from edd_utils import login, export_study, export_metadata

from sklearn.metrics import r2_score

SourceDir = '../src'
sys.path.append(SourceDir)
from ensemblemethods import EFlux2
from utils import *

output_dir = '../plots/CPM/'
from plot import *

# %% [markdown]
# ##### **Load data**

# %%
# # Study to Download
# study_slug = 'biodesign_yoneda_set3_reprocessed'
# # EDD server
# edd_server = 'public-edd.jbei.org'
# user       = 'schenkch'

# %%
# session = login(edd_server=edd_server, user=user)

# df = export_study(session, study_slug, edd_server=edd_server)
# #df.head()

# %% [markdown]
# ##### **Filter transcriptomics data from all EDD data into different dataframes**

# %%
# df_Trans = df[df['Protocol'].str.contains('Transcriptomics')]
# df_Trans.head()

# %%
# df_Trans = transcript_measurements['glucose_cpm'] #fpkm
# scratch/OpacusBiodesign/transcript_data/csv/henson_CPM_melted.csv
df_trans = pd.read_csv('../transcript_data/csv/henson_CPM_melted.csv')
df_trans.head()
# Out:
#   Line Name Measurement Type  Time      Count Units
# 0   WT-M-R1   WP_005263480_1    20  19.003420   CPM
# 1   WT-M-R2   WP_005263480_1    20  16.800668   CPM
# 2   WT-M-R3   WP_005263480_1    20  12.955220   CPM
# 3   WT-M-R1   WP_005263480_1    32  10.984975   CPM
# 4   WT-M-R2   WP_005263480_1    32   9.520107   CPM

# %%
# time could be 10 or 13
df_trans = df_trans[df_trans['Time'] == 13 ]
df_trans.head()
# Out:
#       Line Name Measurement Type  Time      Count Units
# 9     WT-Glu-R1   WP_005263480_1    13  15.584245   CPM
# 10    WT-Glu-R2   WP_005263480_1    13  22.444427   CPM
# 11    WT-Glu-R3   WP_005263480_1    13  20.433310   CPM
# 35  PVHG-Glu-R1   WP_005263480_1    13  22.993761   CPM
# 36  PVHG-Glu-R2   WP_005263480_1    13  23.797461   CPM

# %% [markdown]
# ##### **Load Genome Scale Model**

# %%
model = cobra.io.read_sbml_model("../GSMs/Ropacus_annotated.xml")

# %% [markdown]
# #### **1. EFLUX2 Predictions for Wild type**

# %%
spotsol, spotsol_std = spot_pred_for_three_reps(model, df_trans, 'WT-Glu-R1', 'WT-Glu-R2','WT-Glu-R3', 'glucose')
# Out:
# running first replicate
# {'EX_ca2_e': inf,
#  'EX_cl_e': inf,
#  'EX_cobalt2_e': inf,
#  'EX_cu2_e': inf,
#  'EX_fe2_e': inf,
#  'EX_fe3_e': inf,
#  'EX_glc__D_e': inf,
#  'EX_h2o_e': inf,
#  'EX_h_e': inf,
#  'EX_k_e': inf,
#  'EX_mg2_e': inf,
#  'EX_mn2_e': inf,
#  'EX_mobd_e': inf,
#  'EX_nh4_e': inf,
#  'EX_o2_e': inf,
#  'EX_pi_e': inf,
#  'EX_so4_e': inf,
#  'EX_zn2_e': inf}
# running second replicate
# {'EX_ca2_e': inf,
#  'EX_cl_e': inf,
#  'EX_cobalt2_e': inf,
#  'EX_cu2_e': inf,
#  'EX_fe2_e': inf,
#  'EX_fe3_e': inf,
#  'EX_glc__D_e': inf,
#  'EX_h2o_e': inf,
#  'EX_h_e': inf,
#  'EX_k_e': inf,
#  'EX_mg2_e': inf,
#  'EX_mn2_e': inf,
#  'EX_mobd_e': inf,
#  'EX_nh4_e': inf,
#  'EX_o2_e': inf,
#  'EX_pi_e': inf,
#  'EX_so4_e': inf,
#  'EX_zn2_e': inf}
# running first third
# {'EX_ca2_e': inf,
#  'EX_cl_e': inf,
#  'EX_cobalt2_e': inf,
#  'EX_cu2_e': inf,
#  'EX_fe2_e': inf,
#  'EX_fe3_e': inf,
#  'EX_glc__D_e': inf,
#  'EX_h2o_e': inf,
#  'EX_h_e': inf,
#  'EX_k_e': inf,
#  'EX_mg2_e': inf,
#  'EX_mn2_e': inf,
#  'EX_mobd_e': inf,
#  'EX_nh4_e': inf,
#  'EX_o2_e': inf,
#  'EX_pi_e': inf,
#  'EX_so4_e': inf,
#  'EX_zn2_e': inf}

# %%
spotsol.loc['Growth_Glucose',:]
# Out:
# fluxes   -2.512908e-12
# Name: Growth_Glucose, dtype: float64

# %% [markdown]
# ##### **Save solution to data frame**

# %%
spotsoldf = pd.DataFrame(spotsol, columns=['fluxes'])
spotsolstddf = pd.DataFrame(spotsol_std, columns=['stds'])

# %% [markdown]
# #### **2. Plot solutions: Comparison of EFLUX2 WT predictions and 13c measurements**

# %% [markdown]
# ##### **Load 13cdata**

# %% [markdown]
# #####  **Get 13C MFA measured fluxes for glucose**

# %%
glucose_fluxes = pd.read_csv('../13C_flux_data/13C_glucose_flux_data.csv')

# Remove rows that do not have a mapping to the GSM
# glucose_fluxes.dropna(inplace=True)
glucose_fluxes.dropna(subset = ["Forward Reactions"], inplace=True)
print(f'There are {len(glucose_fluxes)} fluxes that can be compared between the MFA and FBA')
glucose_fluxes
# Out:
# There are 44 fluxes that can be compared between the MFA and FBA
#                       Pathway  \
# 0            Substrate Uptake
# 1                 EMP Pathway
# 2                 EMP Pathway
# 3                 EMP Pathway
# 4                 EMP Pathway
# 5                 EMP Pathway
# 6                 EMP Pathway
# 7                 EMP Pathway
# 8                 EMP Pathway
# 9                 EMP Pathway
# 10  Pentose Phosphate Pathway
# 11  Pentose Phosphate Pathway
# 12  Pentose Phosphate Pathway
# 13  Pentose Phosphate Pathway
# 14  Pentose Phosphate Pathway
# 15  Pentose Phosphate Pathway
# 16  Pentose Phosphate Pathway
# 17  Pentose Phosphate Pathway
# 18                 ED Pathway
# 19                 ED Pathway
# 20                 ED Pathway
# 21                  TCA Cycle
# 22                  TCA Cycle
# 23                  TCA Cycle
# 24                  TCA Cycle
# 25                  TCA Cycle
# 26                  TCA Cycle
# 27                  TCA Cycle
# 28                  TCA Cycle
# 29                  TCA Cycle
# 30           Glyoxylate Shunt
# 31           Glyoxylate Shunt
# 32       Anaplerotic Pathways
# 33       Anaplerotic Pathways
# 34       Anaplerotic Pathways
# 35       Anaplerotic Pathways
# 36          Acetate Formation
# 64           Energy Reactions
# 65           Energy Reactions
# 66                  Transport
# 67                  Transport
# 68                  Transport
# 69                  Transport
# 70           Biomass Equation
#
#                                     Forward Reactions  \
# 0                                 reverse_EX_glc__D_e
# 1                                                 PGI
# 2                                  PFK or reverse_FBP
# 3                                                 FBA
# 4                                                 TPI
# 5                          GAPD or reverse_GAPDi_nadp
# 6                                         reverse_PGK
# 7                                         reverse_PGM
# 8                                                 ENO
# 9   ACMANApts or reverse_PPS or PYK or FRUptspp or...
# 10                                                GND
# 11                                                RPE
# 12                                        reverse_RPI
# 13                                               TKT2
# 14                                               TKT2
# 15                                               TKT1
# 16                                               TALA
# 17                                               TALA
# 18                                    G6PDH2r and PGL
# 19                                                EDD
# 20                                                EDA
# 21                                                PDH
# 22                                 CS or reverse_CITL
# 23                      ACONT or ( ACONTa and ACONTb)
# 24                                    ICDHx or ICDHyr
# 25                              AKGDH or reverse_KGD2
# 26  SUCBZT2 or OCOAT1 or SUCBZT1 or reverse_SUCOAS...
# 27  reverse_FRD3 or reverse_FRD2 or reverse_ASPO5 ...
# 28                                                FUM
# 29           MDH or MDH2 or MDH3 or MDH3_1 or DMALRED
# 30                                                ICL
# 31                                               MALS
# 32                                PC or reverse_OAADC
# 33                                         ME1 or ME2
# 34                            PPC or reverse_PEPCK_re
# 35                                           PEPCK_re
# 36  BUTCT or A4HBCT or ACOXT or reverse_ACS or rev...
# 64                                    reverse_NADTRHD
# 65                                               ATPM
# 66                                           EX_co2_e
# 67                                    reverse_EX_o2_e
# 68                                   reverse_EX_so4_e
# 69                                              SO4t2
# 70          Growth or Growth_Phenol or Growth_Glucose
#
#                                              Reaction Location on map    Flux  \
# 0                               Gluc.ext + ATP -> G6P       (50, 460)  100.00
# 1                                         G6P <-> F6P     (-150, 430)   -1.61
# 2                                    F6P + ATP -> FBP     (-220, 195)    0.00
# 3                                  FBP <-> DHAP + GAP     (-140, 115)    0.00
# 4                                        DHAP <-> GAP     (-270, 150)    0.00
# 5                                       GAP <-> G1,3P      (-220, 30)   86.56
# 6                          G1,3P <-> 3PG + ATP + NADH     (-220, -55)   86.56
# 7                                         3PG <-> 2PG    (-220, -135)   78.52
# 8                                         2PG <-> PEP    (-220, -215)   78.52
# 9                                   PEP <-> Pyr + ATP    (-220, -295)   19.02
# 10                         6PG <-> Ru5P + CO2 + NADPH      (275, 350)    6.62
# 11                                       Ru5P <-> X5P      (380, 190)    2.12
# 12                                       Ru5P <-> R5P      (270, 230)    4.50
# 13                                 X5P <-> TKC2 + GAP      (270, 100)    2.12
# 14                                 TKC2 + E4P <-> F6P       (10, 280)    0.15
# 15                                 TKC2 + R5P <-> S7P      (120, 230)    1.96
# 16                                 TAC3 + GAP <-> F6P      (-70, 190)    1.96
# 17                                 S7P <-> TAC3 + E4P       (50, 230)    1.97
# 18                                G6P <-> 6PG + NADPH       (50, 380)  100.00
# 19                                       6PG <-> KDPG     (-300, 350)   93.38
# 20                                 KDPG <-> Pyr + GAP      (-300, 50)   93.38
# 21                         Pyr <-> AcCoA + CO2 + NADH    (-220, -370)  135.41
# 22                                OAC + AcCoA <-> Cit     (-55, -340)   69.04
# 23                                       Cit <-> ICit     (145, -310)   69.04
# 24                         ICit <-> AKG + CO2 + NADPH     (290, -310)   69.04
# 25                        AKG <-> SucCoA + CO2 + NADH     (290, -195)   61.60
# 26                               SucCoA <-> Suc + ATP      (290, -55)   59.88
# 27                                Suc <-> Fum + FADH2      (160, -55)   61.60
# 28                                        Fum <-> Mal       (10, -55)   63.27
# 29                                 Mal <-> OAC + NADH     (-60, -180)   25.97
# 30                                ICit -> Glyox + Suc     (180, -140)    0.00
# 31                               Glyox + AcCoA -> Mal      (90, -140)    0.00
# 32                             Pyr + CO2 + ATP -> OAC             NaN    0.00
# 33                            Mal -> Pyr + CO2 + NADH             NaN   37.31
# 34                                   PEP + CO2 -> OAC             NaN   55.51
# 35                             OAC + ATP -> PEP + CO2             NaN    0.00
# 36                                 AcCoA <-> Ac + ATP             NaN   -1.89
# 64                                     NADH <-> NADPH             NaN   21.31
# 65                                     ATP -> ATP.ext             NaN  527.47
# 66                                     CO2 -> CO2.ext             NaN  264.28
# 67                                       O2.ext -> O2             NaN  198.14
# 68                                     NH3.ext -> NH3             NaN   39.38
# 69                                     SO4.ext -> SO4             NaN    0.64
# 70  0.515*Ala + 0.174*Arg + 0.153*Asn + 0.439*Asp ...             NaN    7.18
#
#     90% Confidence Lower Bound  90% Confidence Upper Bound
# 0                       100.00                      100.00
# 1                        -2.09                        1.42
# 2                         0.00                        1.91
# 3                         0.00                        1.91
# 4                         0.00                        1.91
# 5                        82.61                       88.84
# 6                        82.61                       88.84
# 7                        71.65                       81.26
# 8                        71.65                       81.26
# 9                       -10.89                       75.15
# 10                        2.07                       10.92
# 11                       -0.89                        4.37
# 12                        2.95                        6.55
# 13                       -0.89                        4.37
# 14                       -1.36                        1.11
# 15                        0.46                        3.34
# 16                        0.46                        3.34
# 17                        0.46                        3.34
# 18                       96.96                      100.00
# 19                       89.08                       94.98
# 20                       89.08                       94.98
# 21                      116.26                      196.60
# 22                       58.52                       82.65
# 23                       58.52                       82.65
# 24                       10.08                       82.65
# 25                        2.27                       75.99
# 26                        0.87                       74.45
# 27                       50.51                       75.99
# 28                       22.17                       77.49
# 29                      -50.27                       78.90
# 30                        0.00                       60.46
# 31                        0.00                       60.46
# 32                        0.00                       45.19
# 33                        0.00                      125.96
# 34                       13.63                      127.98
# 35                        0.00                       54.45
# 36                       -2.44                       -1.69
# 64                      -12.18                      134.28
# 65                        0.00                      737.68
# 66                      165.71                      299.18
# 67                       80.16                      239.92
# 68                       35.29                       50.94
# 69                        0.57                        0.83
# 70                        6.43                        9.28

# %% [markdown]
# ##### **Add Glucose EFLUX2 flux values to phenol fluxes dataframe**

# %%
obspred_fluxes = add_pred_fluxes_to_13c_df(glucose_fluxes, spotsoldf, spotsolstddf, 'glucose', 'SPOT', 'WT')
# obspred_fluxes.to_csv('../13C_flux_data/obspredfluxes_Glucose_EFLUX2_CPM.csv', index=True, header= True)
obspred_fluxes.head()
# Out:
#             Pathway    Forward Reactions               Reaction  \
# 0  Substrate Uptake  reverse_EX_glc__D_e  Gluc.ext + ATP -> G6P
# 1       EMP Pathway                  PGI            G6P <-> F6P
# 2       EMP Pathway   PFK or reverse_FBP       F6P + ATP -> FBP
# 3       EMP Pathway                  FBA     FBP <-> DHAP + GAP
# 4       EMP Pathway                  TPI           DHAP <-> GAP
#
#   Location on map    Flux  90% Confidence Lower Bound  \
# 0       (50, 460)  100.00                      100.00
# 1     (-150, 430)   -1.61                       -2.09
# 2     (-220, 195)    0.00                        0.00
# 3     (-140, 115)    0.00                        0.00
# 4     (-270, 150)    0.00                        0.00
#
#    90% Confidence Upper Bound  SPOT WT Value  SPOT WT std Value
# 0                      100.00     100.000000          15.805423
# 1                        1.42      89.420622           6.272692
# 2                        1.91      71.512334           6.953794
# 3                        1.91      71.512334           6.953794
# 4                        1.91      45.884152           7.166429

# %% [markdown]
# ### **Plot EFLUX2 vs 13C MFA**

# %% [markdown]
# ##### **Plot 13C MFA observations vs. EFLUX2 predictions**

# %% [markdown]
# ##### Scatter plot: 13CMFA vs. EFLUX2

# %%
# scatterplotcomp_obs_vs_pred(obspred_fluxes, substrate='glucose', method='E-Flux2', strain='WT')

# %% [markdown]
# ##### **Plot 13C MFA observations vs. EFLUX2 predictions with confidence intervals**

# %% [markdown]
# ##### Scatter plot with standard deviations: 13CMFA vs. EFLUX2

# %%
scatterplotcomp_obs_vs_pred_withstd(obspred_fluxes, substrate='glucose', method='SPOT', strain='WT')

# %% [markdown]
# #### **Glucose EFlux2 WT Flux Map**

# %%
map_flux_results(obspred_fluxes, 'SPOT WT Value')

# %% [markdown]
# ### **3. Load File with observed growth rates**

# %% [markdown]
# ##### **Load observed growth rates and plot glucose growth rates**

# %%
consumption_and_growth_data = pd.read_csv('../consumption_and_growth_data/consumption_and_growth_data.csv', index_col=0)
consumption_and_growth_data
# Out:
#         growth rate  yield coefficient  substrate consumption rate  \
# WT-G       0.260195           0.072789                    3.582471
# WT-P       0.065488           0.048868                    1.352072
# PVHG-P     0.080331           0.040848                    1.967485
#
#         growth rate std dev  yield coefficient std dev  \
# WT-G               0.004749                   0.004117
# WT-P               0.001345                   0.004836
# PVHG-P             0.002672                   0.001757
#
#         substrate consumption rate std dev
# WT-G                              0.141675
# WT-P                              0.122279
# PVHG-P                            0.021785

# %% [markdown]
# ##### **For comparison of predicted and observed growth rates: scale predicted growth rate by multiplying with (observed substrate uptake / predicted substrate uptake)**

# %%
scaledgrowthrate_wtlng = scale_growth_to_sub(
    eflux2soldf.loc['Growth_Glucose',:].values[0], 
    eflux2soldf.loc['EX_glc__D_e',:].values[0],
    consumption_and_growth_data.loc['WT-G', 'substrate consumption rate']
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-0cf6db726cf7> in <module>
#       1 scaledgrowthrate_wtlng = scale_growth_to_sub(
# ----> 2     eflux2soldf.loc['Growth_Glucose',:].values[0],
#       3     eflux2soldf.loc['EX_glc__D_e',:].values[0],
#       4     consumption_and_growth_data.loc['WT-G', 'substrate consumption rate']
#       5 )
#
# NameError: name 'eflux2soldf' is not defined

# %% [markdown]
# ##### **Add scaled values to new dataframe**

# %%
allgrowthrates=pd.DataFrame(index=['WT-G'], columns=['Growth_Glucose_EFLUX2'], dtype=float)
allgrowthrates.at['WT-G','Growth_Glucose_EFLUX2'] = scaledgrowthrate_wtlng
allgrowthrates
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-0080a7e4c887> in <module>
#       1 allgrowthrates=pd.DataFrame(index=['WT-G'], columns=['Growth_Glucose_EFLUX2'], dtype=float)
# ----> 2 allgrowthrates.at['WT-G','Growth_Glucose_EFLUX2'] = scaledgrowthrate_wtlng
#       3 allgrowthrates
#
# NameError: name 'scaledgrowthrate_wtlng' is not defined

# %% [markdown]
# ### **4. Save growth rate predictions to csv file**

# %% [markdown]
# ##### **Save growth rates as csv file**

# %%
allgrowthrates.to_csv('../consumption_and_growth_data/allgrowthratesGlucoseEFLUX2_CPM.csv', index=True, header= True)
