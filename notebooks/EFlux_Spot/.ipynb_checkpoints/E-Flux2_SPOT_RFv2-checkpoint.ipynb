# %% [markdown]
# # Predict metabolic flux distribution from transcriptomics data using E-Flux2 and Random Forest

# %% [markdown]
# ### Load libraries

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from scipy.optimize import minimize
from sklearn.ensemble import RandomForestRegressor
import numpy as np
import pandas as pd
# import seaborn as sns
import cobra
import cplex

# %% [markdown]
# ### Load a metabolic model and parse gene-reaction rules

# %%
model = cobra.io.load_json_model("iJO1366.json")

# %%
mets = [m.id for m in model.metabolites]
rxns = [r.id for r in model.reactions]
nrow = len(mets)
ncol = len(rxns)
print(nrow, ncol)
# Out:
# 1805 2583

# %%
c = [r.objective_coefficient for r in model.reactions]
S = cobra.util.create_stoichiometric_matrix(model, array_type='DataFrame')

# %%
gpr_dict = dict()
for r in model.reactions:
    if r.gene_reaction_rule:
        temp = set()
        for x in [x.strip('() ') for x in r.gene_reaction_rule.split(' or ')]:
            temp.add(frozenset(y.strip('() ') for y in x.split(' and ')))
        gpr_dict[r.id] = temp

# %%
for r in model.reactions[:350]:
    if r.gene_reaction_rule:
        print(r.id, r.gene_reaction_rule)
        temp = set()
        for x in [x.strip('() ') for x in r.gene_reaction_rule.split(' or ')]:
            temp.add(frozenset(y.strip('() ') for y in x.split(' and ')))
        print(temp)
        print()
#         gpr_dict[r.id] = temp
# Out:
# 12PPDRtex (b0241 or b0929 or b1377 or b2215)
# {frozenset({'b0241'}), frozenset({'b1377'}), frozenset({'b0929'}), frozenset({'b2215'})}
#
# 12PPDStex (b0241 or b0929 or b1377 or b2215)
# {frozenset({'b0241'}), frozenset({'b1377'}), frozenset({'b0929'}), frozenset({'b2215'})}
#
# 14GLUCANabcpp (b4034 and b4033 and b4032 and b4035)
# {frozenset({'b4035', 'b4034', 'b4033', 'b4032'})}
#
# 14GLUCANtexi b4036
# {frozenset({'b4036'})}
#
# 23CAMPtex (b0241 or b0929 or b1377 or b2215)
# {frozenset({'b0241'}), frozenset({'b1377'}), frozenset({'b0929'}), frozenset({'b2215'})}
#
# 23CCMPtex (b0241 or b0929 or b1377 or b2215)
# {frozenset({'b0241'}), frozenset({'b1377'}), frozenset({'b0929'}), frozenset({'b2215'})}
#
# 23CGMPtex (b0241 or b0929 or b1377 or b2215)
# {frozenset({'b0241'}), frozenset({'b1377'}), frozenset({'b0929'}), frozenset({'b2215'})}
#
# 23CUMPtex (b0241 or b0929 or b1377 or b2215)
# {frozenset({'b0241'}), frozenset({'b1377'}), frozenset({'b0929'}), frozenset({'b2215'})}

# %% [markdown]
# ## E-Flux2

# %% [markdown]
# ### Set non-zero lower and upper bounds to 0.0 or +/-Inf

# %%
for r in model.reactions:
    if r.lower_bound < 0.0 and r.lower_bound > -1000.0:
        print(r.id, r.lower_bound, r.upper_bound)
        r.lower_bound = -1000.0
    elif r.lower_bound > 0.0:
        print(r.id, r.lower_bound, r.upper_bound)
        r.lower_bound = 0.0
    elif r.upper_bound > 0.0 and r.upper_bound < 1000.0:
        print(r.id, r.lower_bound, r.upper_bound)
        r.upper_bound = 1000.0
    elif r.upper_bound < 0.0:
        print(r.id, r.lower_bound, r.upper_bound)
        r.upper_bound = 0.0
# Out:
# EX_cbl1_LPAREN_e_RPAREN_ -0.01 1000.0
# EX_glc_LPAREN_e_RPAREN_ -10.0 1000.0
# ATPM 3.15 1000.0

# %%
for r in model.reactions:
    if r.lower_bound == -1000.0:
        r.lower_bound = -np.Inf
    if r.upper_bound == 1000.0:
        r.upper_bound = np.Inf

# %% [markdown]
# ### Load transcriptomics data and calculate lower and upper bounds

# %%
Transcriptomics = pd.read_csv('ishii-trans-1.csv', index_col=0, header=None)
Transcriptomics.head()
# Out:
#                1
# 0
# b0957  45.278681
# b0929  42.173087
# b1480  38.351485
# b3299  29.201456
# b2093  36.778437

# %%
lb = []
ub = []
for r in model.reactions:
    if r.gene_reaction_rule:
        t = np.sum([np.min([Transcriptomics.loc[g].values if g in Transcriptomics.index 
                            else np.array([np.Inf]) for g in p])
                    for p in gpr_dict[r.id]])
        if r.lower_bound < 0.0:
            lb.append(-t)
        else:
            lb.append(r.lower_bound)
        if r.upper_bound > 0.0:
            ub.append(t)
        else:
            ub.append(r.upper_bound)
    else:
        lb.append(r.lower_bound)
        ub.append(r.upper_bound)

# %% [markdown]
# ### Build a CPLEX model of E-Flux2 and solve

# %%
EFlux2 = cplex.Cplex()
EFlux2.parameters.simplex.tolerances.optimality.set(1e-9)
EFlux2.parameters.simplex.tolerances.feasibility.set(1e-9)

EFlux2.linear_constraints.add(rhs=[0]*nrow, senses='E'*nrow, names=mets)
EFlux2.variables.add(obj=c, lb=lb, ub=ub, names=rxns)
for r in model.reactions:
    for m, v in r.metabolites.items():
        EFlux2.linear_constraints.set_coefficients(m.id, r.id, v)
        
EFlux2.objective.set_sense(EFlux2.objective.sense.maximize)
EFlux2.solve()
EFlux2_sol = EFlux2.solution.get_objective_value()
print
print(EFlux2.solution.get_status_string())
print(EFlux2_sol)
# Out:
# CPXPARAM_Simplex_Tolerances_Optimality           1.0000000000000001e-09
# CPXPARAM_Simplex_Tolerances_Feasibility          1.0000000000000001e-09
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# LP Presolve eliminated 812 rows and 1098 columns.
# Aggregator did 523 substitutions.
# Reduced LP has 470 rows, 962 columns, and 4747 nonzeros.
# Presolve time = 0.01 sec. (2.87 ticks)
# Initializing dual steep norms . . .
#
# Iteration log . . .
# Iteration:     1   Scaled dual infeas =             0.786571
# Iteration:    86   Scaled dual infeas =             0.009009
# Iteration:    88   Dual objective     =             3.664956
# Iteration:   162   Dual objective     =             1.755820
# Iteration:   230   Dual objective     =             1.223704
# Iteration:   294   Dual objective     =             0.914004
# Iteration:   356   Dual objective     =             0.698602
# Perturbation started.
# Iteration:   394   Dual objective     =             0.698602
# Iteration:   456   Dual objective     =             0.519676
# Iteration:   520   Dual objective     =             0.334820
# Iteration:   582   Dual objective     =             0.334813
# Iteration:   644   Dual objective     =             0.334810
# Removing perturbation.
# optimal
# 0.3348274891377517

# %% [markdown]
# ### Build a CPLEX model to minimize L2 norm and solve

# %%
Q = [1.0 for r in model.reactions]

# %%
EFlux2_min = cplex.Cplex()
EFlux2_min.parameters.simplex.tolerances.optimality.set(1e-9)
EFlux2_min.parameters.simplex.tolerances.feasibility.set(1e-9)

EFlux2_min.linear_constraints.add(rhs=[0]*nrow, senses='E'*nrow, names=mets)
EFlux2_min.variables.add(obj=[0]*ncol, lb=lb, ub=ub, names=rxns)
for r in model.reactions:
    for m, v in r.metabolites.items():
        EFlux2_min.linear_constraints.set_coefficients(m.id, r.id, v)

EFlux2_min.variables.set_lower_bounds('Ec_biomass_iJO1366_core_53p95M', 1.0*EFlux2_sol)
EFlux2_min.objective.set_quadratic(Q)
EFlux2_min.objective.set_sense(EFlux2_min.objective.sense.minimize)
EFlux2_min.solve()
EFlux2_min_sol = EFlux2_min.solution.get_objective_value()
EFlux2_min.solution.get_status_string()
# Out:
# CPXPARAM_Simplex_Tolerances_Optimality           1.0000000000000001e-09
# CPXPARAM_Simplex_Tolerances_Feasibility          1.0000000000000001e-09
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# QP Presolve eliminated 235 rows and 259 columns.
# Reduced QP has 1570 rows, 2324 columns, and 9095 nonzeros.
# Reduced QP objective Q matrix has 2324 nonzeros.
# Presolve time = 0.01 sec. (1.50 ticks)
# Parallel mode: using up to 32 threads for barrier.
#
# ***NOTE: Found 2 dense columns.
#
# Number of nonzeros in lower triangle of A*A' = 8874
# Using Approximate Minimum Degree ordering
# Total time for automatic ordering = 0.01 sec. (1.32 ticks)
# Summary statistics for Cholesky factor:
#   Threads                   = 32
#   Rows in Factor            = 1572
#   Integer space required    = 5931
#   Total non-zeros in factor = 26893
#   Total FP ops to factor    = 803867
#  Itn      Primal Obj        Dual Obj  Prim Inf Upper Inf  Dual Inf
#    0   9.9323679e+06  -5.1907136e+07  8.91e+04  1.30e+05  8.28e+05
#    1   6.6167056e+05  -2.0567993e+07  2.19e+04  3.20e+04  2.03e+05
#    2   8.2698859e+04  -8.6839122e+06  6.71e+03  9.82e+03  6.23e+04
#    3   8.6531338e+03  -4.7737611e+06  2.22e+03  3.25e+03  2.07e+04
#    4   7.0448077e+03  -4.3621161e+06  1.72e+03  2.52e+03  1.60e+04
#    5   3.3712955e+03  -2.6505347e+06  8.28e+02  1.21e+03  7.69e+03
#    6   1.9736448e+03  -1.1001654e+06  2.82e+02  4.12e+02  2.62e+03
#    7   1.7803732e+03  -5.4106189e+05  1.15e+02  1.68e+02  1.07e+03
#    8   1.6610208e+03  -3.5788496e+05  5.58e+01  8.16e+01  5.18e+02
#    9   1.6615928e+03  -3.0099917e+05  4.12e+01  6.03e+01  3.83e+02
#   10   1.7067292e+03  -1.9817058e+05  1.68e+01  2.46e+01  1.56e+02
#   11   1.7213429e+03  -1.7280114e+05  1.27e+01  1.86e+01  1.18e+02
#   12   1.7403526e+03  -7.9878570e+04  4.10e+00  6.00e+00  3.81e+01
#   13   1.6849102e+03  -2.6405793e+04  6.35e-01  9.29e-01  5.90e+00
#   14   1.4991168e+03  -1.4494178e+04  2.58e-01  3.77e-01  2.39e+00
#   15   1.3826730e+03  -6.7084852e+03  1.12e-01  1.64e-01  1.04e+00
#   16   1.2998007e+03  -1.9862851e+03  1.66e-02  2.42e-02  1.54e-01
#   17   1.1738632e+03  -8.1318786e+02  9.93e-03  1.45e-02  9.22e-02
#   18   1.1317661e+03  -5.6112326e+02  8.47e-03  1.24e-02  7.87e-02
#   19   1.1235870e+03  -3.8639114e+02  7.56e-03  1.11e-02  7.02e-02
#   20   1.0275402e+03   4.1798602e+01  4.93e-03  7.21e-03  4.58e-02
#   21   9.5202811e+02   4.2202785e+02  2.65e-03  3.87e-03  2.46e-02
#   22   9.1956041e+02   5.5897465e+02  1.80e-03  2.64e-03  1.67e-02
#   23   8.7406080e+02   7.7598861e+02  4.90e-04  7.17e-04  4.55e-03
#   24   8.6526099e+02   8.1869527e+02  2.33e-04  3.41e-04  2.16e-03
#   25   8.5989136e+02   8.4454352e+02  7.67e-05  1.12e-04  7.12e-04
#   26   8.5934726e+02   8.4752680e+02  5.91e-05  8.65e-05  5.49e-04
#   27   8.5781489e+02   8.5502154e+02  1.39e-05  2.04e-05  1.29e-04
#   28   8.5740782e+02   8.5700082e+02  2.02e-06  2.96e-06  1.88e-05
#   29   8.5734666e+02   8.5729445e+02  2.57e-07  3.75e-07  2.38e-06
#   30   8.5733770e+02   8.5733684e+02  3.50e-09  5.12e-09  3.43e-08
#   31   8.5733752e+02   8.5733747e+02  1.25e-10  1.82e-10  4.26e-09
#   32   8.5733751e+02   8.5733750e+02  9.20e-12  1.39e-11  2.85e-09
# Barrier time = 0.34 sec. (28.34 ticks)
#
# Total time on 32 threads = 0.34 sec. (28.34 ticks)
# 'optimal'

# %% [markdown]
# ### Get the E-Flux2 solution and plot against 13C experimental data

# %%
# E-Flux2 solution
EFlux2_fluxdict = dict(zip(rxns,EFlux2_min.solution.get_values()))
# Ishii flux data, WT reference strain [mmol/gDW/h]: http://ecoli.iab.keio.ac.jp/ > Fluxome > Fluxome data
reactionDict = {'PGI':2076,'PFK':2063,'FBA':1150,'TPI':2455,'PYK':2265,'PDH':2046,'GND':1422,'RPE':2311,'RPI':2312,'TALA':2397,'ICL':1551,'MALS':1713}
ishiiDict = {2076:2.247179186,2063:2.495301258,1150:2.495301258,2455:2.495301258,2265:1.399624166,2046:3.722827564,1422:.6439079794,2311:.2684455913,2312:.3754514687,2397:.1783978343,1551:.3268244693,1713:.3268244693}

# %%
Exp, EFlux2_flux = [],[]
for k, v in reactionDict.items():
    Exp.append(ishiiDict[v])
    EFlux2_flux.append(EFlux2_fluxdict[k])
Exp = np.array(Exp)
EFlux2_flux = np.array(EFlux2_flux)

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.scatter(Exp,EFlux2_flux)
ax.set_xlim(-1,5)
ax.set_ylim(-1,5)
ax.plot(ax.get_xlim(), ax.get_ylim(), ls="--", c=".3")
Labels = [i for i in reactionDict]
for i in range(len(Exp)):
    xy = (Exp[i]+.1,EFlux2_flux[i]+.1)
    ax.annotate(Labels[i],xy)
plt.xlabel(r'Ishii $et$ $al$ experimental flux measurement (mmol/gDW/h)')
plt.ylabel(r'E-Flux2 flux prediction (mmol/gDW/h)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## SPOT

# %% [markdown]
# ### Split reversible reactions into two irreversible reactions

# %%
rev_rxns = ['rev_'+r.id for r in model.reactions if r.reversibility]
rev_ncol = len(rev_rxns)
print(rev_ncol)
# Out:
# 636

# %%
lb = [0.0 if r.reversibility else r.lower_bound for r in model.reactions] + [0.0 for r in model.reactions if r.reversibility]
ub = [r.upper_bound for r in model.reactions] + [-r.lower_bound for r in model.reactions if r.reversibility]

# %% [markdown]
# ### Calculate objective function coefficients from transcriptomics

# %%
c = []
for r in model.reactions:
    if r.gene_reaction_rule:
        t = np.sum([np.min([Transcriptomics.loc[g].values if g in Transcriptomics.index 
                            else np.array([np.Inf]) for g in p])
                    for p in gpr_dict[r.id]])
        if t == np.Inf:
            t = 0
        c.append(t)
    else:
        c.append(0.0)
for r in model.reactions:
    if r.reversibility:
        if r.gene_reaction_rule:
            t = np.sum([np.min([Transcriptomics.loc[g].values if g in Transcriptomics.index 
                                else np.array([np.Inf]) for g in p])
                        for p in gpr_dict[r.id]])
            if t == np.Inf:
                t = 0
            c.append(t)
        else:
            c.append(0.0)

# %% [markdown]
# ### Build a CPLEX model of SPOT and solve

# %%
SPOT = cplex.Cplex()
SPOT.parameters.simplex.tolerances.optimality.set(1e-9)
SPOT.parameters.simplex.tolerances.feasibility.set(1e-9)

SPOT.linear_constraints.add(rhs=[0]*nrow, senses='E'*nrow, names=mets)
SPOT.variables.add(obj=c, lb=lb, ub=ub, names=rxns+rev_rxns)
for r in model.reactions:
    for m, v in r.metabolites.items():
        SPOT.linear_constraints.set_coefficients(m.id, r.id, v)
for r in model.reactions:
    if r.reversibility:
        for m, v in r.metabolites.items():
            SPOT.linear_constraints.set_coefficients(m.id, 'rev_'+r.id, -v)
SPOT.quadratic_constraints.add(quad_expr=[rxns+rev_rxns, rxns+rev_rxns, [1]*len(c)],
                               sense='L', rhs=100000.0, name='L2norm')
SPOT.objective.set_sense(SPOT.objective.sense.maximize)
SPOT.solve()
SPOT_sol = SPOT.solution.get_objective_value()
print
print(SPOT.solution.get_status_string())
print(SPOT_sol)
# Out:
# CPXPARAM_Simplex_Tolerances_Optimality           1.0000000000000001e-09
# CPXPARAM_Simplex_Tolerances_Feasibility          1.0000000000000001e-09
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# QCP Presolve eliminated 199 rows and 222 columns.
# Reduced QCP has 4604 rows, 2998 columns, and 13937 nonzeros.
# Reduced QCP has 1 quadratic constraints.
# Presolve time = 0.01 sec. (2.32 ticks)
# Parallel mode: using up to 32 threads for barrier.
#
# ***NOTE: Found 3 dense columns.
#
# Number of nonzeros in lower triangle of A*A' = 19608
# Using Approximate Minimum Degree ordering
# Total time for automatic ordering = 0.01 sec. (1.72 ticks)
# Summary statistics for Cholesky factor:
#   Threads                   = 32
#   Rows in Factor            = 4604
#   Integer space required    = 12299
#   Total non-zeros in factor = 52314
#   Total FP ops to factor    = 1022224
#  Itn      Primal Obj        Dual Obj  Prim Inf Upper Inf  Dual Inf Inf Ratio
#    0   0.0000000e+00   0.0000000e+00  3.31e+03  0.00e+00  4.65e+04  1.00e+00
#    1   3.5652364e+02   3.5651994e+02  3.31e+03  0.00e+00  4.65e+04  9.97e-01
#    2   3.0567156e+03   3.0566838e+03  3.31e+03  0.00e+00  4.65e+04  9.72e-01
#    3   3.5386482e+03   3.5385034e+03  3.30e+03  0.00e+00  4.64e+04  8.78e-01
#    4   5.7887832e+03   5.7886159e+03  3.29e+03  0.00e+00  4.62e+04  8.65e-01
#    5   1.3564252e+04   1.3564016e+04  3.27e+03  0.00e+00  4.60e+04  8.28e-01
#    6   8.6854819e+04   8.6853445e+04  3.22e+03  0.00e+00  4.52e+04  4.57e-01
#    7   2.4608526e+05   2.4608251e+05  2.70e+03  0.00e+00  3.79e+04  3.09e-01
#    8   2.4921046e+05   2.4920777e+05  1.62e+03  0.00e+00  2.28e+04  3.14e-01
#    9   4.2293724e+05   4.2293602e+05  1.60e+03  0.00e+00  2.25e+04  7.41e-01
#   10   4.5971554e+05   4.5971509e+05  4.12e+02  0.00e+00  5.78e+03  2.01e+00
#   11   4.7308903e+05   4.7308883e+05  1.58e+02  0.00e+00  2.22e+03  4.69e+00
#   12   4.7652674e+05   4.7652661e+05  6.54e+01  0.00e+00  9.18e+02  7.26e+00
#   13   4.7803813e+05   4.7803804e+05  4.16e+01  0.00e+00  5.84e+02  9.78e+00
#   14   4.7918416e+05   4.7918409e+05  3.11e+01  0.00e+00  4.37e+02  1.24e+01
#   15   4.8108862e+05   4.8108858e+05  2.32e+01  0.00e+00  3.25e+02  2.73e+01
#   16   4.8122841e+05   4.8122838e+05  9.92e+00  0.00e+00  1.39e+02  2.96e+01
#   17   4.8136714e+05   4.8136712e+05  8.95e+00  0.00e+00  1.26e+02  3.34e+01
#   18   4.8223152e+05   4.8223152e+05  7.99e+00  0.00e+00  1.12e+02  1.28e+02
#   19   4.8248951e+05   4.8248951e+05  1.96e+00  0.00e+00  2.75e+01  1.58e+03
#   20   4.8250273e+05   4.8250273e+05  1.57e-01  0.00e+00  2.20e+00  3.58e+03
#   21   4.8251028e+05   4.8251028e+05  6.44e-02  0.00e+00  9.05e-01  2.00e+04
#   22   4.8251128e+05   4.8251128e+05  1.14e-02  0.00e+00  1.61e-01  5.05e+04
# optimal
# 482511.2769459807

# %% [markdown]
# ### Get the SPOT solution and plot against 13C experimental data

# %%
SPOT_fluxdict = dict(zip(rxns,SPOT.solution.get_values()))

# %%
plt.hist(SPOT_fluxdict.values())
plt.show()

# %%
SPOT_flux = []
for k, v in reactionDict.items():
    SPOT_flux.append(SPOT_fluxdict[k])
SPOT_flux = np.array(SPOT_flux)

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.scatter(Exp,SPOT_flux)
ax.set_xlim(-1,5)
ax.set_ylim(-1,5)
ax.plot(ax.get_xlim(), ax.get_ylim(), ls="--", c=".3")
Labels = [i for i in reactionDict]
for i in range(len(Exp)):
    xy = (Exp[i]+.1,SPOT_flux[i]+.1)
    ax.annotate(Labels[i],xy)
plt.xlabel(r'Ishii $et$ $al$ experimental flux measurement (mmol/gDW/h)')
plt.ylabel(r'SPOT flux prediction (mmol/gDW/h)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### Load Ishii flux data

# %%
# Load reaction names
reactionNames = np.loadtxt('ishii-flux-names.csv', delimiter=',', skiprows=0, usecols=0, dtype='str')
# Load train and test data
# Training data is from eflux2 samples 2 to 8, representing different KEIO KO strains and growth conditions
# Test data is eflux2 sample1, the WT reference sample
train_x, train_y = [],[]
for i in range(2,9):
    train_x.append(np.loadtxt('ishii-trans-'+str(i)+'.csv', delimiter=',', skiprows=0, usecols=1))
    train_y.append(np.loadtxt('ishii-flux-'+str(i)+'.csv'))
test_x, test_y = np.loadtxt('ishii-trans-1.csv', delimiter=',', skiprows=0, usecols=1), np.loadtxt('ishii-flux-1.csv')
train_x, train_y = np.array(train_x), np.array(train_y)

# %% [markdown]
# ### Define and run random forest for each reaction

# %%
# Load data into arrays for plotting
RF_array, eflux2, absError = [],[],[]
for r in range(len(reactionNames)):
    # Define type of random forest
    rf = RandomForestRegressor(n_estimators=20, oob_score=False, random_state=0, n_jobs=8, max_features=10, max_leaf_nodes=10)
    rf.fit(train_x, train_y[:,r])
    # Use the forest's predict method on the test data
    predictions = rf.predict(test_x.reshape(1, -1))
    i = r
    print('Working on reaction:', reactionNames[i])
    print('   Random Forest:', predictions[0], '|   Eflux2 prediction:', test_y[i])
    RF_array.append(predictions[0])
    eflux2.append(float(test_y[i]))
    absError.append(abs(predictions[0]-float(test_y[i])))
RF_array = np.array(RF_array)
eflux2 = np.array(eflux2)
# Out:
# Working on reaction: R_DM_4CRSOL
#    Random Forest: 7.058428571428571e-05 |   Eflux2 prediction: 7.47e-05
# Working on reaction: R_DM_5DRIB
#    Random Forest: 7.121214285714287e-05 |   Eflux2 prediction: 7.53e-05
# Working on reaction: R_DM_AACALD
#    Random Forest: 1.4368571428571425e-15 |   Eflux2 prediction: 8.65e-16
# Working on reaction: R_DM_AMOB
#    Random Forest: 6.33092857142857e-07 |   Eflux2 prediction: 6.7e-07
# Working on reaction: R_DM_MTHTHF
#    Random Forest: 0.00014169999999999997 |   Eflux2 prediction: 0.00015
# Working on reaction: R_DM_OXAM
#    Random Forest: 2.904466428571429e-13 |   Eflux2 prediction: 7.38e-12
# Working on reaction: R_Ec_biomass_iJO1366_WT_53p95M
#    Random Forest: 6.894428571428571e-17 |   Eflux2 prediction: 1.1e-15
# Working on reaction: R_Ec_biomass_iJO1366_core_53p95M
#    Random Forest: 0.32302039529999993 |   Eflux2 prediction: 0.334827489
# Working on reaction: R_EX_12ppd_DASH_R_LPAREN_e_RPAREN_
#    Random Forest: 4.225843571428571e-12 |   Eflux2 prediction: 7.22e-11
# Working on reaction: R_EX_12ppd_DASH_S_LPAREN_e_RPAREN_
#    Random Forest: 1.2193515000000003e-12 |   Eflux2 prediction: 2.04e-11
# Working on reaction: R_EX_14glucan_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_15dap_LPAREN_e_RPAREN_
#    Random Forest: 1.7882857142857138e-15 |   Eflux2 prediction: 1.03e-15
# Working on reaction: R_EX_23camp_LPAREN_e_RPAREN_
#    Random Forest: 1.508e-16 |   Eflux2 prediction: 3.38e-16
# Working on reaction: R_EX_23ccmp_LPAREN_e_RPAREN_
#    Random Forest: 2.151e-16 |   Eflux2 prediction: 2.92e-16
# Working on reaction: R_EX_23cgmp_LPAREN_e_RPAREN_
#    Random Forest: 1.3432857142857138e-16 |   Eflux2 prediction: 2.36e-16
# Working on reaction: R_EX_23cump_LPAREN_e_RPAREN_
#    Random Forest: 2.4895e-16 |   Eflux2 prediction: 3.44e-16
# Working on reaction: R_EX_23dappa_LPAREN_e_RPAREN_
#    Random Forest: 5.670571428571429e-16 |   Eflux2 prediction: 4.71e-16
# Working on reaction: R_EX_26dap_DASH_M_LPAREN_e_RPAREN_
#    Random Forest: 5.006999999999999e-16 |   Eflux2 prediction: 6.22e-16
# Working on reaction: R_EX_2ddglcn_LPAREN_e_RPAREN_
#    Random Forest: 9.238142857142857e-16 |   Eflux2 prediction: 9.6e-16
# Working on reaction: R_EX_34dhpac_LPAREN_e_RPAREN_
#    Random Forest: 1.3065000000000002e-15 |   Eflux2 prediction: 8.41e-16
# Working on reaction: R_EX_3amp_LPAREN_e_RPAREN_
#    Random Forest: 1.753142857142857e-16 |   Eflux2 prediction: 6.66e-16
# Working on reaction: R_EX_3cmp_LPAREN_e_RPAREN_
#    Random Forest: 2.570714285714286e-16 |   Eflux2 prediction: 5.99e-16
# Working on reaction: R_EX_3gmp_LPAREN_e_RPAREN_
#    Random Forest: 1.5097857142857144e-16 |   Eflux2 prediction: 3.93e-16
# Working on reaction: R_EX_3hcinnm_LPAREN_e_RPAREN_
#    Random Forest: 2.819142857142857e-16 |   Eflux2 prediction: 1.71e-16
# Working on reaction: R_EX_3hpp_LPAREN_e_RPAREN_
#    Random Forest: 8.950224285714286e-13 |   Eflux2 prediction: 2.18e-11
# Working on reaction: R_EX_3hpppn_LPAREN_e_RPAREN_
#    Random Forest: 3.4385e-16 |   Eflux2 prediction: 2.25e-16
# Working on reaction: R_EX_3ump_LPAREN_e_RPAREN_
#    Random Forest: 3.049571428571429e-16 |   Eflux2 prediction: 6.69e-16
# Working on reaction: R_EX_4abut_LPAREN_e_RPAREN_
#    Random Forest: 2.0345000000000003e-13 |   Eflux2 prediction: 4.96e-12
# Working on reaction: R_EX_4hoxpacd_LPAREN_e_RPAREN_
#    Random Forest: 1.3442142857142854e-15 |   Eflux2 prediction: 9.21e-16
# Working on reaction: R_EX_5dglcn_LPAREN_e_RPAREN_
#    Random Forest: 5.2825e-12 |   Eflux2 prediction: 3.56e-11
# Working on reaction: R_EX_5mtr_LPAREN_e_RPAREN_
#    Random Forest: 1.4653747142857145e-13 |   Eflux2 prediction: 3.43e-12
# Working on reaction: R_EX_LalaDglu_LPAREN_e_RPAREN_
#    Random Forest: 4.930500000000001e-16 |   Eflux2 prediction: 6.06e-16
# Working on reaction: R_EX_LalaDgluMdap_LPAREN_e_RPAREN_
#    Random Forest: 3.3558578571428576e-14 |   Eflux2 prediction: 8.09e-13
# Working on reaction: R_EX_LalaDgluMdapDala_LPAREN_e_RPAREN_
#    Random Forest: 2.5646071428571422e-14 |   Eflux2 prediction: 6.18e-13
# Working on reaction: R_EX_LalaLglu_LPAREN_e_RPAREN_
#    Random Forest: 4.8235e-16 |   Eflux2 prediction: 6.07e-16
# Working on reaction: R_EX_ac_LPAREN_e_RPAREN_
#    Random Forest: 1.5170446459684002 |   Eflux2 prediction: 1.997018191
# Working on reaction: R_EX_acac_LPAREN_e_RPAREN_
#    Random Forest: 8.408642857142858e-16 |   Eflux2 prediction: 6.17e-16
# Working on reaction: R_EX_acald_LPAREN_e_RPAREN_
#    Random Forest: 3.2838995000000003e-12 |   Eflux2 prediction: 2.89e-11
# Working on reaction: R_EX_acgal_LPAREN_e_RPAREN_
#    Random Forest: 1.689642857142857e-15 |   Eflux2 prediction: 1.05e-15
# Working on reaction: R_EX_acgal1p_LPAREN_e_RPAREN_
#    Random Forest: 8.371785714285715e-16 |   Eflux2 prediction: 5.09e-16
# Working on reaction: R_EX_acgam_LPAREN_e_RPAREN_
#    Random Forest: 4.793785714285715e-16 |   Eflux2 prediction: 8.01e-16
# Working on reaction: R_EX_acgam1p_LPAREN_e_RPAREN_
#    Random Forest: 3.8129285714285723e-16 |   Eflux2 prediction: 4.2e-16
# Working on reaction: R_EX_acmana_LPAREN_e_RPAREN_
#    Random Forest: 4.2506428571428566e-16 |   Eflux2 prediction: 6.07e-16
# Working on reaction: R_EX_acmum_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_acnam_LPAREN_e_RPAREN_
#    Random Forest: 3.012785714285714e-16 |   Eflux2 prediction: 3.36e-16
# Working on reaction: R_EX_acolipa_LPAREN_e_RPAREN_
#    Random Forest: 9.43676785714286e-14 |   Eflux2 prediction: 2.3e-12
# Working on reaction: R_EX_acser_LPAREN_e_RPAREN_
#    Random Forest: 4.0281871428571427e-13 |   Eflux2 prediction: 9.29e-12
# Working on reaction: R_EX_ade_LPAREN_e_RPAREN_
#    Random Forest: 2.7218007142857146e-14 |   Eflux2 prediction: 6.95e-13
# Working on reaction: R_EX_adn_LPAREN_e_RPAREN_
#    Random Forest: 2.444884285714286e-14 |   Eflux2 prediction: 6.19e-13
# Working on reaction: R_EX_adocbl_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_ag_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_agm_LPAREN_e_RPAREN_
#    Random Forest: 6.17031142857143e-14 |   Eflux2 prediction: 1.5e-12
# Working on reaction: R_EX_akg_LPAREN_e_RPAREN_
#    Random Forest: 2.3140771428571433e-13 |   Eflux2 prediction: 5.91e-12
# Working on reaction: R_EX_ala_DASH_B_LPAREN_e_RPAREN_
#    Random Forest: 6.889e-16 |   Eflux2 prediction: 5.98e-16
# Working on reaction: R_EX_ala_DASH_D_LPAREN_e_RPAREN_
#    Random Forest: 1.6731835714285716e-12 |   Eflux2 prediction: 9.73e-12
# Working on reaction: R_EX_ala_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 1.5904692857142855e-12 |   Eflux2 prediction: 9.72e-12
# Working on reaction: R_EX_alaala_LPAREN_e_RPAREN_
#    Random Forest: 1.1825030714285716e-13 |   Eflux2 prediction: 2.75e-12
# Working on reaction: R_EX_all_DASH_D_LPAREN_e_RPAREN_
#    Random Forest: 4.629571428571429e-16 |   Eflux2 prediction: 4.1e-16
# Working on reaction: R_EX_alltn_LPAREN_e_RPAREN_
#    Random Forest: 4.149304285714285e-14 |   Eflux2 prediction: 1.05e-12
# Working on reaction: R_EX_amp_LPAREN_e_RPAREN_
#    Random Forest: 1.6897857142857143e-16 |   Eflux2 prediction: 6e-16
# Working on reaction: R_EX_anhgm_LPAREN_e_RPAREN_
#    Random Forest: 4.8219628571428574e-14 |   Eflux2 prediction: 1.19e-12
# Working on reaction: R_EX_arab_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 5.681785714285713e-16 |   Eflux2 prediction: 7.77e-16
# Working on reaction: R_EX_arbt_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_arbtn_LPAREN_e_RPAREN_
#    Random Forest: 8.481214285714283e-17 |   Eflux2 prediction: 7.32e-17
# Working on reaction: R_EX_arbtn_DASH_fe3_LPAREN_e_RPAREN_
#    Random Forest: 8.538714285714286e-17 |   Eflux2 prediction: 7.33e-17
# Working on reaction: R_EX_arg_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 4.8140878571428566e-14 |   Eflux2 prediction: 1.17e-12
# Working on reaction: R_EX_ascb_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 2.9391428571428574e-16 |   Eflux2 prediction: 2.74e-16
# Working on reaction: R_EX_asn_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 1.140557142857143e-13 |   Eflux2 prediction: 2.8e-12
# Working on reaction: R_EX_aso3_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_asp_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 2.1304628571428567e-13 |   Eflux2 prediction: 5.01e-12
# Working on reaction: R_EX_btn_LPAREN_e_RPAREN_
#    Random Forest: 7.427142857142858e-17 |   Eflux2 prediction: 4.82e-16
# Working on reaction: R_EX_but_LPAREN_e_RPAREN_
#    Random Forest: 1.0721357142857145e-15 |   Eflux2 prediction: 7.04e-16
# Working on reaction: R_EX_butso3_LPAREN_e_RPAREN_
#    Random Forest: 2.5217857142857143e-16 |   Eflux2 prediction: 2.05e-16
# Working on reaction: R_EX_ca2_LPAREN_e_RPAREN_
#    Random Forest: -0.0016475997357142855 |   Eflux2 prediction: -0.001742777
# Working on reaction: R_EX_cbi_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_cbl1_LPAREN_e_RPAREN_
#    Random Forest: -8.367928571428569e-16 |   Eflux2 prediction: -5.85e-16
# Working on reaction: R_EX_cd2_LPAREN_e_RPAREN_
#    Random Forest: 9.074857142857143e-16 |   Eflux2 prediction: 6.51e-16
# Working on reaction: R_EX_cgly_LPAREN_e_RPAREN_
#    Random Forest: 4.895824285714285e-14 |   Eflux2 prediction: 1.16e-12
# Working on reaction: R_EX_chol_LPAREN_e_RPAREN_
#    Random Forest: 1.3703571428571427e-15 |   Eflux2 prediction: 8.08e-16
# Working on reaction: R_EX_chtbs_LPAREN_e_RPAREN_
#    Random Forest: 2.1495714285714286e-16 |   Eflux2 prediction: 4.1e-16
# Working on reaction: R_EX_cit_LPAREN_e_RPAREN_
#    Random Forest: 2.2426614285714288e-13 |   Eflux2 prediction: 5.33e-12
# Working on reaction: R_EX_cl_LPAREN_e_RPAREN_
#    Random Forest: -0.0016475997357142855 |   Eflux2 prediction: -0.001742777
# Working on reaction: R_EX_cm_LPAREN_e_RPAREN_
#    Random Forest: 9.147071428571427e-16 |   Eflux2 prediction: 6.07e-16
# Working on reaction: R_EX_cmp_LPAREN_e_RPAREN_
#    Random Forest: 2.4734999999999997e-16 |   Eflux2 prediction: 6e-16
# Working on reaction: R_EX_co2_LPAREN_e_RPAREN_
#    Random Forest: 5.67486248665 |   Eflux2 prediction: 5.447171487
# Working on reaction: R_EX_cobalt2_LPAREN_e_RPAREN_
#    Random Forest: -7.912785714285714e-06 |   Eflux2 prediction: -8.37e-06
# Working on reaction: R_EX_colipa_LPAREN_e_RPAREN_
#    Random Forest: 2.1958716428571428e-14 |   Eflux2 prediction: 5.32e-13
# Working on reaction: R_EX_colipap_LPAREN_e_RPAREN_
#    Random Forest: 3.1287007142857145e-14 |   Eflux2 prediction: 7.62e-13
# Working on reaction: R_EX_cpgn_LPAREN_e_RPAREN_
#    Random Forest: 8.538571428571427e-17 |   Eflux2 prediction: 7.33e-17
# Working on reaction: R_EX_cpgn_DASH_un_LPAREN_e_RPAREN_
#    Random Forest: 8.481071428571429e-17 |   Eflux2 prediction: 7.32e-17
# Working on reaction: R_EX_crn_LPAREN_e_RPAREN_
#    Random Forest: 1.0046928571428573e-15 |   Eflux2 prediction: 6.86e-16
# Working on reaction: R_EX_crn_DASH_D_LPAREN_e_RPAREN_
#    Random Forest: 9.832857142857145e-16 |   Eflux2 prediction: 6.27e-16
# Working on reaction: R_EX_csn_LPAREN_e_RPAREN_
#    Random Forest: 3.9774999999999996e-16 |   Eflux2 prediction: 6.07e-16
# Working on reaction: R_EX_cu_LPAREN_e_RPAREN_
#    Random Forest: 2.1756428571428573e-15 |   Eflux2 prediction: 1.11e-15
# Working on reaction: R_EX_cu2_LPAREN_e_RPAREN_
#    Random Forest: -0.00022435714285714284 |   Eflux2 prediction: -0.000237
# Working on reaction: R_EX_cyan_LPAREN_e_RPAREN_
#    Random Forest: 7.1865e-16 |   Eflux2 prediction: 5.17e-16
# Working on reaction: R_EX_cynt_LPAREN_e_RPAREN_
#    Random Forest: 5.908357142857142e-16 |   Eflux2 prediction: 4.1e-16
# Working on reaction: R_EX_cys_DASH_D_LPAREN_e_RPAREN_
#    Random Forest: 4.098571428571429e-16 |   Eflux2 prediction: 4.65e-16
# Working on reaction: R_EX_cys_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 7.266026428571427e-14 |   Eflux2 prediction: 1.68e-12
# Working on reaction: R_EX_cytd_LPAREN_e_RPAREN_
#    Random Forest: 4.2406835714285713e-14 |   Eflux2 prediction: 1.06e-12
# Working on reaction: R_EX_dad_DASH_2_LPAREN_e_RPAREN_
#    Random Forest: 1.7334999999999997e-16 |   Eflux2 prediction: 6.58e-16
# Working on reaction: R_EX_damp_LPAREN_e_RPAREN_
#    Random Forest: 1.4972142857142857e-16 |   Eflux2 prediction: 3.22e-16
# Working on reaction: R_EX_dca_LPAREN_e_RPAREN_
#    Random Forest: 8.114285714285715e-16 |   Eflux2 prediction: 5.89e-16
# Working on reaction: R_EX_dcmp_LPAREN_e_RPAREN_
#    Random Forest: 2.269214285714286e-16 |   Eflux2 prediction: 3.5e-16
# Working on reaction: R_EX_dcyt_LPAREN_e_RPAREN_
#    Random Forest: 2.731642857142857e-16 |   Eflux2 prediction: 6.76e-16
# Working on reaction: R_EX_ddca_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_dgmp_LPAREN_e_RPAREN_
#    Random Forest: 1.4143571428571428e-16 |   Eflux2 prediction: 3.83e-16
# Working on reaction: R_EX_dgsn_LPAREN_e_RPAREN_
#    Random Forest: 1.6239999999999999e-16 |   Eflux2 prediction: 6.99e-16
# Working on reaction: R_EX_dha_LPAREN_e_RPAREN_
#    Random Forest: 3.673053142857143e-12 |   Eflux2 prediction: 4.71e-11
# Working on reaction: R_EX_dimp_LPAREN_e_RPAREN_
#    Random Forest: 1.566642857142857e-16 |   Eflux2 prediction: 3.83e-16
# Working on reaction: R_EX_din_LPAREN_e_RPAREN_
#    Random Forest: 1.8029285714285717e-16 |   Eflux2 prediction: 6.98e-16
# Working on reaction: R_EX_dms_LPAREN_e_RPAREN_
#    Random Forest: 1.27e-15 |   Eflux2 prediction: 9.14e-16
# Working on reaction: R_EX_dmso_LPAREN_e_RPAREN_
#    Random Forest: 5.392857142857144e-16 |   Eflux2 prediction: 3.72e-16
# Working on reaction: R_EX_dopa_LPAREN_e_RPAREN_
#    Random Forest: 5.007142857142856e-16 |   Eflux2 prediction: 2.79e-16
# Working on reaction: R_EX_doxrbcn_LPAREN_e_RPAREN_
#    Random Forest: 9.147071428571427e-16 |   Eflux2 prediction: 6.07e-16
# Working on reaction: R_EX_dtmp_LPAREN_e_RPAREN_
#    Random Forest: 2.5438571428571427e-16 |   Eflux2 prediction: 6.02e-16
# Working on reaction: R_EX_dump_LPAREN_e_RPAREN_
#    Random Forest: 2.4528571428571423e-16 |   Eflux2 prediction: 3.79e-16
# Working on reaction: R_EX_duri_LPAREN_e_RPAREN_
#    Random Forest: 2.9548571428571433e-16 |   Eflux2 prediction: 6.32e-16
# Working on reaction: R_EX_eca4colipa_LPAREN_e_RPAREN_
#    Random Forest: 7.045194285714287e-14 |   Eflux2 prediction: 1.73e-12
# Working on reaction: R_EX_enlipa_LPAREN_e_RPAREN_
#    Random Forest: 3.5269628571428576e-14 |   Eflux2 prediction: 8.52e-13
# Working on reaction: R_EX_enter_LPAREN_e_RPAREN_
#    Random Forest: 2.2074714285714282e-14 |   Eflux2 prediction: 5.36e-13
# Working on reaction: R_EX_etha_LPAREN_e_RPAREN_
#    Random Forest: 4.550529285714287e-13 |   Eflux2 prediction: 1.1e-11
# Working on reaction: R_EX_ethso3_LPAREN_e_RPAREN_
#    Random Forest: 4.013785714285714e-16 |   Eflux2 prediction: 4.07e-16
# Working on reaction: R_EX_etoh_LPAREN_e_RPAREN_
#    Random Forest: 0.2676889578000017 |   Eflux2 prediction: 1.41e-10
# Working on reaction: R_EX_f6p_LPAREN_e_RPAREN_
#    Random Forest: 4.233214285714286e-16 |   Eflux2 prediction: 6.07e-16
# Working on reaction: R_EX_fald_LPAREN_e_RPAREN_
#    Random Forest: 1.2340714285714286e-15 |   Eflux2 prediction: 9.33e-16
# Working on reaction: R_EX_fe2_LPAREN_e_RPAREN_
#    Random Forest: -0.66028432215 |   Eflux2 prediction: -0.005377664
# Working on reaction: R_EX_fe3_LPAREN_e_RPAREN_
#    Random Forest: 0.7592657073024685 |   Eflux2 prediction: 9.09e-11
# Working on reaction: R_EX_fe3dcit_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_fe3dhbzs_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_fe3hox_LPAREN_e_RPAREN_
#    Random Forest: 8.538571428571428e-17 |   Eflux2 prediction: 7.33e-17
# Working on reaction: R_EX_fe3hox_DASH_un_LPAREN_e_RPAREN_
#    Random Forest: 8.481071428571429e-17 |   Eflux2 prediction: 7.32e-17
# Working on reaction: R_EX_fecrm_LPAREN_e_RPAREN_
#    Random Forest: 8.538571428571427e-17 |   Eflux2 prediction: 7.33e-17
# Working on reaction: R_EX_fecrm_DASH_un_LPAREN_e_RPAREN_
#    Random Forest: 8.481071428571429e-17 |   Eflux2 prediction: 7.32e-17
# Working on reaction: R_EX_feenter_LPAREN_e_RPAREN_
#    Random Forest: 2.2234207142857147e-14 |   Eflux2 prediction: 5.41e-13
# Working on reaction: R_EX_feoxam_LPAREN_e_RPAREN_
#    Random Forest: 8.538428571428573e-17 |   Eflux2 prediction: 7.33e-17
# Working on reaction: R_EX_feoxam_DASH_un_LPAREN_e_RPAREN_
#    Random Forest: 8.48092857142857e-17 |   Eflux2 prediction: 7.32e-17
# Working on reaction: R_EX_for_LPAREN_e_RPAREN_
#    Random Forest: 5.597201575250001 |   Eflux2 prediction: 2.499523637
# Working on reaction: R_EX_fru_LPAREN_e_RPAREN_
#    Random Forest: 3.9677857142857146e-16 |   Eflux2 prediction: 3.76e-16
# Working on reaction: R_EX_frulys_LPAREN_e_RPAREN_
#    Random Forest: 3.8907857142857135e-16 |   Eflux2 prediction: 2.01e-16
# Working on reaction: R_EX_fruur_LPAREN_e_RPAREN_
#    Random Forest: 6.808285714285713e-16 |   Eflux2 prediction: 5.76e-16
# Working on reaction: R_EX_fuc_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 5.859142857142858e-16 |   Eflux2 prediction: 6.23e-16
# Working on reaction: R_EX_fum_LPAREN_e_RPAREN_
#    Random Forest: 6.257714285714286e-16 |   Eflux2 prediction: 4.54e-16
# Working on reaction: R_EX_fusa_LPAREN_e_RPAREN_
#    Random Forest: 9.147071428571427e-16 |   Eflux2 prediction: 6.07e-16
# Working on reaction: R_EX_g1p_LPAREN_e_RPAREN_
#    Random Forest: 1.1627142857142855e-15 |   Eflux2 prediction: 7.59e-16
# Working on reaction: R_EX_g3pc_LPAREN_e_RPAREN_
#    Random Forest: 3.8934285714285714e-16 |   Eflux2 prediction: 3.54e-16
# Working on reaction: R_EX_g3pe_LPAREN_e_RPAREN_
#    Random Forest: 1.3784748571428574e-13 |   Eflux2 prediction: 3.31e-12
# Working on reaction: R_EX_g3pg_LPAREN_e_RPAREN_
#    Random Forest: 1.8191239999999995e-13 |   Eflux2 prediction: 4.21e-12
# Working on reaction: R_EX_g3pi_LPAREN_e_RPAREN_
#    Random Forest: 3.872857142857143e-16 |   Eflux2 prediction: 4.25e-16
# Working on reaction: R_EX_g3ps_LPAREN_e_RPAREN_
#    Random Forest: 3.673071428571429e-16 |   Eflux2 prediction: 3.75e-16
# Working on reaction: R_EX_g6p_LPAREN_e_RPAREN_
#    Random Forest: 7.176928571428571e-16 |   Eflux2 prediction: 6.13e-16
# Working on reaction: R_EX_gal_LPAREN_e_RPAREN_
#    Random Forest: 1.5878571428571428e-15 |   Eflux2 prediction: 9.85e-16
# Working on reaction: R_EX_gal_DASH_bD_LPAREN_e_RPAREN_
#    Random Forest: 6.737571428571428e-16 |   Eflux2 prediction: 4.31e-16
# Working on reaction: R_EX_gal1p_LPAREN_e_RPAREN_
#    Random Forest: 8.543571428571429e-16 |   Eflux2 prediction: 5.82e-16
# Working on reaction: R_EX_galct_DASH_D_LPAREN_e_RPAREN_
#    Random Forest: 4.988e-16 |   Eflux2 prediction: 3.69e-16
# Working on reaction: R_EX_galctn_DASH_D_LPAREN_e_RPAREN_
#    Random Forest: 3.616571428571429e-16 |   Eflux2 prediction: 2.92e-16
# Working on reaction: R_EX_galctn_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 3.293714285714286e-16 |   Eflux2 prediction: 1.99e-16
# Working on reaction: R_EX_galt_LPAREN_e_RPAREN_
#    Random Forest: 4.1009999999999995e-16 |   Eflux2 prediction: 4.19e-16
# Working on reaction: R_EX_galur_LPAREN_e_RPAREN_
#    Random Forest: 5.957857142857143e-16 |   Eflux2 prediction: 3.63e-16
# Working on reaction: R_EX_gam_LPAREN_e_RPAREN_
#    Random Forest: 4.3141428571428575e-16 |   Eflux2 prediction: 6.07e-16
# Working on reaction: R_EX_gam6p_LPAREN_e_RPAREN_
#    Random Forest: 3.6765714285714284e-16 |   Eflux2 prediction: 6.22e-16
# Working on reaction: R_EX_gbbtn_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_gdp_LPAREN_e_RPAREN_
#    Random Forest: 1.2257857142857142e-15 |   Eflux2 prediction: 6.84e-16
# Working on reaction: R_EX_glc_LPAREN_e_RPAREN_
#    Random Forest: -4.974688953949999 |   Eflux2 prediction: -4.511895633
# Working on reaction: R_EX_glcn_LPAREN_e_RPAREN_
#    Random Forest: 0.05925995500637543 |   Eflux2 prediction: 5.36e-11
# Working on reaction: R_EX_glcr_LPAREN_e_RPAREN_
#    Random Forest: 4.944285714285716e-16 |   Eflux2 prediction: 3.91e-16
# Working on reaction: R_EX_glcur_LPAREN_e_RPAREN_
#    Random Forest: 6.808285714285713e-16 |   Eflux2 prediction: 5.76e-16
# Working on reaction: R_EX_glcur1p_LPAREN_e_RPAREN_
#    Random Forest: 5.100142857142856e-16 |   Eflux2 prediction: 3.38e-16
# Working on reaction: R_EX_gln_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 5.939857142857143e-16 |   Eflux2 prediction: 5.35e-16
# Working on reaction: R_EX_glu_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 1.6997914285714285e-13 |   Eflux2 prediction: 4.18e-12
# Working on reaction: R_EX_gly_LPAREN_e_RPAREN_
#    Random Forest: 4.775240714285714e-13 |   Eflux2 prediction: 1.1e-11
# Working on reaction: R_EX_glyald_LPAREN_e_RPAREN_
#    Random Forest: 9.843269285714284e-13 |   Eflux2 prediction: 2.05e-11
# Working on reaction: R_EX_glyb_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_glyc_LPAREN_e_RPAREN_
#    Random Forest: 3.958615285714286e-12 |   Eflux2 prediction: 5.34e-11
# Working on reaction: R_EX_glyc_DASH_R_LPAREN_e_RPAREN_
#    Random Forest: 6.745452857142858e-13 |   Eflux2 prediction: 2.07e-11
# Working on reaction: R_EX_glyc2p_LPAREN_e_RPAREN_
#    Random Forest: 5.477071428571428e-16 |   Eflux2 prediction: 3.75e-16
# Working on reaction: R_EX_glyc3p_LPAREN_e_RPAREN_
#    Random Forest: 2.637225642857143e-13 |   Eflux2 prediction: 6.11e-12
# Working on reaction: R_EX_glyclt_LPAREN_e_RPAREN_
#    Random Forest: 1.3908218571428568e-12 |   Eflux2 prediction: 4.32e-11
# Working on reaction: R_EX_gmp_LPAREN_e_RPAREN_
#    Random Forest: 1.4643571428571428e-16 |   Eflux2 prediction: 3.5e-16
# Working on reaction: R_EX_gsn_LPAREN_e_RPAREN_
#    Random Forest: 1.7452142857142858e-16 |   Eflux2 prediction: 7.11e-16
# Working on reaction: R_EX_gthox_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_gthrd_LPAREN_e_RPAREN_
#    Random Forest: 3.4559407142857137e-14 |   Eflux2 prediction: 8.32e-13
# Working on reaction: R_EX_gtp_LPAREN_e_RPAREN_
#    Random Forest: 5.957857142857143e-16 |   Eflux2 prediction: 3.31e-16
# Working on reaction: R_EX_gua_LPAREN_e_RPAREN_
#    Random Forest: 2.590882857142857e-14 |   Eflux2 prediction: 6.57e-13
# Working on reaction: R_EX_h_LPAREN_e_RPAREN_
#    Random Forest: 9.575557550250002 |   Eflux2 prediction: 7.80410019
# Working on reaction: R_EX_h2_LPAREN_e_RPAREN_
#    Random Forest: 1.0151928571428573e-15 |   Eflux2 prediction: 5.37e-16
# Working on reaction: R_EX_h2o_LPAREN_e_RPAREN_
#    Random Forest: 14.140179461950002 |   Eflux2 prediction: 14.28988646
# Working on reaction: R_EX_h2o2_LPAREN_e_RPAREN_
#    Random Forest: 2.278214285714286e-15 |   Eflux2 prediction: 1.49e-15
# Working on reaction: R_EX_h2s_LPAREN_e_RPAREN_
#    Random Forest: 2.1435128571428569e-13 |   Eflux2 prediction: 5.06e-12
# Working on reaction: R_EX_hacolipa_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_halipa_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_hdca_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_hdcea_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_hg2_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_his_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 4.1701299999999995e-14 |   Eflux2 prediction: 1.04e-12
# Working on reaction: R_EX_hom_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 2.7182864285714283e-13 |   Eflux2 prediction: 6.26e-12
# Working on reaction: R_EX_hxa_LPAREN_e_RPAREN_
#    Random Forest: 9.814795e-13 |   Eflux2 prediction: 6.99e-12
# Working on reaction: R_EX_hxan_LPAREN_e_RPAREN_
#    Random Forest: 3.051743571428572e-14 |   Eflux2 prediction: 7.78e-13
# Working on reaction: R_EX_idon_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 0.009678140520703172 |   Eflux2 prediction: 0.231085711
# Working on reaction: R_EX_ile_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 8.529661428571428e-14 |   Eflux2 prediction: 1.96e-12
# Working on reaction: R_EX_imp_LPAREN_e_RPAREN_
#    Random Forest: 1.7567857142857142e-16 |   Eflux2 prediction: 6e-16
# Working on reaction: R_EX_indole_LPAREN_e_RPAREN_
#    Random Forest: 3.9952335714285705e-14 |   Eflux2 prediction: 1e-12
# Working on reaction: R_EX_inost_LPAREN_e_RPAREN_
#    Random Forest: 1.3527142857142858e-15 |   Eflux2 prediction: 8.54e-16
# Working on reaction: R_EX_ins_LPAREN_e_RPAREN_
#    Random Forest: 2.7313671428571432e-14 |   Eflux2 prediction: 6.9e-13
# Working on reaction: R_EX_isetac_LPAREN_e_RPAREN_
#    Random Forest: 3.715571428571429e-16 |   Eflux2 prediction: 3.1e-16
# Working on reaction: R_EX_k_LPAREN_e_RPAREN_
#    Random Forest: -0.06421530759999998 |   Eflux2 prediction: -0.065355982
# Working on reaction: R_EX_kdo2lipid4_LPAREN_e_RPAREN_
#    Random Forest: 9.337784285714284e-15 |   Eflux2 prediction: 2.25e-13
# Working on reaction: R_EX_lac_DASH_D_LPAREN_e_RPAREN_
#    Random Forest: 0.711994821401784 |   Eflux2 prediction: 2.1e-10
# Working on reaction: R_EX_lac_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 1.0647270000000001e-12 |   Eflux2 prediction: 1.97e-11
# Working on reaction: R_EX_lcts_LPAREN_e_RPAREN_
#    Random Forest: 6.567857142857143e-16 |   Eflux2 prediction: 4.56e-16
# Working on reaction: R_EX_leu_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 5.149045e-13 |   Eflux2 prediction: 4.1e-12
# Working on reaction: R_EX_lipa_LPAREN_e_RPAREN_
#    Random Forest: 1.8948874999999998e-14 |   Eflux2 prediction: 4.56e-13
# Working on reaction: R_EX_lipa_cold_LPAREN_e_RPAREN_
#    Random Forest: 3.708980714285714e-14 |   Eflux2 prediction: 8.91e-13
# Working on reaction: R_EX_lipoate_LPAREN_e_RPAREN_
#    Random Forest: 2.874214285714286e-16 |   Eflux2 prediction: 5.74e-16
# Working on reaction: R_EX_lys_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 5.955714285714287e-16 |   Eflux2 prediction: 3.71e-16
# Working on reaction: R_EX_lyx_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 3.097428571428571e-16 |   Eflux2 prediction: 4.97e-16
# Working on reaction: R_EX_mal_DASH_D_LPAREN_e_RPAREN_
#    Random Forest: 5.818571428571428e-16 |   Eflux2 prediction: 3.2e-16
# Working on reaction: R_EX_mal_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 3.6876350000000004e-13 |   Eflux2 prediction: 8.9e-12
# Working on reaction: R_EX_malt_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_malthx_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_maltpt_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_malttr_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_maltttr_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_man_LPAREN_e_RPAREN_
#    Random Forest: 4.979285714285714e-16 |   Eflux2 prediction: 6.07e-16
# Working on reaction: R_EX_man6p_LPAREN_e_RPAREN_
#    Random Forest: 4.214142857142857e-16 |   Eflux2 prediction: 6.07e-16
# Working on reaction: R_EX_manglyc_LPAREN_e_RPAREN_
#    Random Forest: 3.261571428571429e-16 |   Eflux2 prediction: 4.12e-16
# Working on reaction: R_EX_melib_LPAREN_e_RPAREN_
#    Random Forest: 7.752714285714286e-16 |   Eflux2 prediction: 6.07e-16
# Working on reaction: R_EX_meoh_LPAREN_e_RPAREN_
#    Random Forest: 6.33092857142857e-07 |   Eflux2 prediction: 6.7e-07
# Working on reaction: R_EX_met_DASH_D_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_met_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 2.6395000000000003e-16 |   Eflux2 prediction: 5.88e-16
# Working on reaction: R_EX_metsox_DASH_R_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 2.652285714285714e-16 |   Eflux2 prediction: 6.49e-16
# Working on reaction: R_EX_metsox_DASH_S_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 2.647071428571429e-16 |   Eflux2 prediction: 6.01e-16
# Working on reaction: R_EX_mg2_LPAREN_e_RPAREN_
#    Random Forest: -0.002836807288928572 |   Eflux2 prediction: -0.002904628
# Working on reaction: R_EX_mincyc_LPAREN_e_RPAREN_
#    Random Forest: 9.147071428571427e-16 |   Eflux2 prediction: 6.07e-16
# Working on reaction: R_EX_minohp_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_mmet_LPAREN_e_RPAREN_
#    Random Forest: 1.941642857142857e-16 |   Eflux2 prediction: 4.1e-16
# Working on reaction: R_EX_mn2_LPAREN_e_RPAREN_
#    Random Forest: -0.00021864999999999998 |   Eflux2 prediction: -0.000231
# Working on reaction: R_EX_mnl_LPAREN_e_RPAREN_
#    Random Forest: 5.209499999999999e-16 |   Eflux2 prediction: 6.07e-16
# Working on reaction: R_EX_mobd_LPAREN_e_RPAREN_
#    Random Forest: -4.080357142857143e-05 |   Eflux2 prediction: -4.32e-05
# Working on reaction: R_EX_mso3_LPAREN_e_RPAREN_
#    Random Forest: 3.2607142857142855e-16 |   Eflux2 prediction: 3.37e-16
# Working on reaction: R_EX_n2o_LPAREN_e_RPAREN_
#    Random Forest: 4.769357142857144e-16 |   Eflux2 prediction: 5.74e-16
# Working on reaction: R_EX_na1_LPAREN_e_RPAREN_
#    Random Forest: -5.051571428571428e-15 |   Eflux2 prediction: 2.59e-16
# Working on reaction: R_EX_nac_LPAREN_e_RPAREN_
#    Random Forest: 4.292285714285714e-16 |   Eflux2 prediction: 6.23e-16
# Working on reaction: R_EX_nh4_LPAREN_e_RPAREN_
#    Random Forest: -3.5454967534999993 |   Eflux2 prediction: -3.616412781
# Working on reaction: R_EX_ni2_LPAREN_e_RPAREN_
#    Random Forest: -0.00010227357142857143 |   Eflux2 prediction: -0.000108
# Working on reaction: R_EX_nmn_LPAREN_e_RPAREN_
#    Random Forest: 2.1894285714285712e-16 |   Eflux2 prediction: 6.08e-16
# Working on reaction: R_EX_no_LPAREN_e_RPAREN_
#    Random Forest: 5.515285714285716e-16 |   Eflux2 prediction: 5.73e-16
# Working on reaction: R_EX_no2_LPAREN_e_RPAREN_
#    Random Forest: 1.235285714285714e-15 |   Eflux2 prediction: 6.77e-15
# Working on reaction: R_EX_no3_LPAREN_e_RPAREN_
#    Random Forest: 5.019e-16 |   Eflux2 prediction: 1.28e-15
# Working on reaction: R_EX_novbcn_LPAREN_e_RPAREN_
#    Random Forest: 9.295142857142858e-16 |   Eflux2 prediction: 5.49e-16
# Working on reaction: R_EX_o16a4colipa_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_o2_LPAREN_e_RPAREN_
#    Random Forest: -6.56680259175 |   Eflux2 prediction: -6.097985773
# Working on reaction: R_EX_o2s_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_ocdca_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_ocdcea_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_octa_LPAREN_e_RPAREN_
#    Random Forest: 8.511214285714284e-16 |   Eflux2 prediction: 6.04e-16
# Working on reaction: R_EX_orn_LPAREN_e_RPAREN_
#    Random Forest: 9.203209999999999e-14 |   Eflux2 prediction: 2.18e-12
# Working on reaction: R_EX_orot_LPAREN_e_RPAREN_
#    Random Forest: 5.40792857142857e-16 |   Eflux2 prediction: 6.07e-16
# Working on reaction: R_EX_pacald_LPAREN_e_RPAREN_
#    Random Forest: 3.289499999999999e-16 |   Eflux2 prediction: 4.3e-16
# Working on reaction: R_EX_peamn_LPAREN_e_RPAREN_
#    Random Forest: 2.4042142857142857e-16 |   Eflux2 prediction: 2.6e-16
# Working on reaction: R_EX_phe_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 5.27595e-14 |   Eflux2 prediction: 1.29e-12
# Working on reaction: R_EX_pheme_LPAREN_e_RPAREN_
#    Random Forest: 3.300417142857143e-14 |   Eflux2 prediction: 9.11e-13
# Working on reaction: R_EX_pi_LPAREN_e_RPAREN_
#    Random Forest: -0.3126521148 |   Eflux2 prediction: -0.322984976
# Working on reaction: R_EX_pnto_DASH_R_LPAREN_e_RPAREN_
#    Random Forest: 4.185214285714286e-16 |   Eflux2 prediction: 6.06e-16
# Working on reaction: R_EX_ppa_LPAREN_e_RPAREN_
#    Random Forest: 9.370285714285715e-16 |   Eflux2 prediction: 6.06e-16
# Working on reaction: R_EX_ppal_LPAREN_e_RPAREN_
#    Random Forest: 9.155285714285715e-16 |   Eflux2 prediction: 5.23e-16
# Working on reaction: R_EX_pppn_LPAREN_e_RPAREN_
#    Random Forest: 2.8379285714285713e-16 |   Eflux2 prediction: 1.51e-16
# Working on reaction: R_EX_ppt_LPAREN_e_RPAREN_
#    Random Forest: 5.450000000000001e-16 |   Eflux2 prediction: 3.23e-16
# Working on reaction: R_EX_pro_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 1.076661142857143e-13 |   Eflux2 prediction: 2.59e-12
# Working on reaction: R_EX_progly_LPAREN_e_RPAREN_
#    Random Forest: 4.0302142857142854e-16 |   Eflux2 prediction: 3.77e-16
# Working on reaction: R_EX_psclys_LPAREN_e_RPAREN_
#    Random Forest: 3.589571428571429e-16 |   Eflux2 prediction: 1.95e-16
# Working on reaction: R_EX_pser_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 6.888714285714285e-16 |   Eflux2 prediction: 6.02e-16
# Working on reaction: R_EX_ptrc_LPAREN_e_RPAREN_
#    Random Forest: 1.0335525e-13 |   Eflux2 prediction: 2.46e-12
# Working on reaction: R_EX_pydam_LPAREN_e_RPAREN_
#    Random Forest: 3.500357142857143e-16 |   Eflux2 prediction: 5.92e-16
# Working on reaction: R_EX_pydx_LPAREN_e_RPAREN_
#    Random Forest: 3.4479285714285713e-16 |   Eflux2 prediction: 5.89e-16
# Working on reaction: R_EX_pydxn_LPAREN_e_RPAREN_
#    Random Forest: 3.5112142857142863e-16 |   Eflux2 prediction: 6.2e-16
# Working on reaction: R_EX_pyr_LPAREN_e_RPAREN_
#    Random Forest: 3.4779692857142863e-12 |   Eflux2 prediction: 3.01e-11
# Working on reaction: R_EX_quin_LPAREN_e_RPAREN_
#    Random Forest: 1.8194851428571426e-13 |   Eflux2 prediction: 4.38e-12
# Working on reaction: R_EX_r5p_LPAREN_e_RPAREN_
#    Random Forest: 4.758928571428571e-16 |   Eflux2 prediction: 3.75e-16
# Working on reaction: R_EX_rfamp_LPAREN_e_RPAREN_
#    Random Forest: 9.295142857142858e-16 |   Eflux2 prediction: 5.49e-16
# Working on reaction: R_EX_rib_DASH_D_LPAREN_e_RPAREN_
#    Random Forest: 7.506214285714285e-16 |   Eflux2 prediction: 6.84e-16
# Working on reaction: R_EX_rmn_LPAREN_e_RPAREN_
#    Random Forest: 4.1425e-16 |   Eflux2 prediction: 3.59e-16
# Working on reaction: R_EX_sbt_DASH_D_LPAREN_e_RPAREN_
#    Random Forest: 5.2015714285714275e-16 |   Eflux2 prediction: 6.07e-16
# Working on reaction: R_EX_sel_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_ser_DASH_D_LPAREN_e_RPAREN_
#    Random Forest: 6.640357142857143e-16 |   Eflux2 prediction: 6.55e-16
# Working on reaction: R_EX_ser_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 3.244761428571429e-13 |   Eflux2 prediction: 7.35e-12
# Working on reaction: R_EX_skm_LPAREN_e_RPAREN_
#    Random Forest: 4.0068571428571435e-16 |   Eflux2 prediction: 6.01e-16
# Working on reaction: R_EX_slnt_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_so2_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_so3_LPAREN_e_RPAREN_
#    Random Forest: 1.0915714285714288e-15 |   Eflux2 prediction: 7.25e-16
# Working on reaction: R_EX_so4_LPAREN_e_RPAREN_
#    Random Forest: -0.08278865795000001 |   Eflux2 prediction: -0.084446841
# Working on reaction: R_EX_spmd_LPAREN_e_RPAREN_
#    Random Forest: 1.4651335714285718e-13 |   Eflux2 prediction: 3.43e-12
# Working on reaction: R_EX_succ_LPAREN_e_RPAREN_
#    Random Forest: 8.523132142857142e-13 |   Eflux2 prediction: 1.2e-11
# Working on reaction: R_EX_sucr_LPAREN_e_RPAREN_
#    Random Forest: 4.066928571428571e-16 |   Eflux2 prediction: 3.12e-16
# Working on reaction: R_EX_sulfac_LPAREN_e_RPAREN_
#    Random Forest: 3.7015e-16 |   Eflux2 prediction: 3.21e-16
# Working on reaction: R_EX_tartr_DASH_D_LPAREN_e_RPAREN_
#    Random Forest: 4.745928571428571e-16 |   Eflux2 prediction: 3.11e-16
# Working on reaction: R_EX_tartr_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 6.679071428571428e-16 |   Eflux2 prediction: 6.42e-16
# Working on reaction: R_EX_taur_LPAREN_e_RPAREN_
#    Random Forest: 3.961571428571429e-16 |   Eflux2 prediction: 2.88e-16
# Working on reaction: R_EX_tcynt_LPAREN_e_RPAREN_
#    Random Forest: 1.0915714285714286e-15 |   Eflux2 prediction: 7.22e-16
# Working on reaction: R_EX_thm_LPAREN_e_RPAREN_
#    Random Forest: 8.300428571428573e-17 |   Eflux2 prediction: 3.98e-16
# Working on reaction: R_EX_thr_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 1.1493046428571428e-13 |   Eflux2 prediction: 2.7e-12
# Working on reaction: R_EX_thrp_LPAREN_e_RPAREN_
#    Random Forest: 4.591214285714287e-16 |   Eflux2 prediction: 6.07e-16
# Working on reaction: R_EX_thym_LPAREN_e_RPAREN_
#    Random Forest: 1.2113489285714285e-13 |   Eflux2 prediction: 2.97e-12
# Working on reaction: R_EX_thymd_LPAREN_e_RPAREN_
#    Random Forest: 4.684465000000001e-14 |   Eflux2 prediction: 1.15e-12
# Working on reaction: R_EX_tma_LPAREN_e_RPAREN_
#    Random Forest: 1.2426428571428571e-15 |   Eflux2 prediction: 9.13e-16
# Working on reaction: R_EX_tmao_LPAREN_e_RPAREN_
#    Random Forest: 5.356857142857144e-16 |   Eflux2 prediction: 3.7e-16
# Working on reaction: R_EX_tre_LPAREN_e_RPAREN_
#    Random Forest: 7.890142857142859e-16 |   Eflux2 prediction: 5.88e-16
# Working on reaction: R_EX_trp_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 3.5656942857142854e-14 |   Eflux2 prediction: 8.91e-13
# Working on reaction: R_EX_tsul_LPAREN_e_RPAREN_
#    Random Forest: 7.196785714285714e-16 |   Eflux2 prediction: 4.11e-16
# Working on reaction: R_EX_ttdca_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_ttdcea_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_ttrcyc_LPAREN_e_RPAREN_
#    Random Forest: 9.147071428571427e-16 |   Eflux2 prediction: 6.07e-16
# Working on reaction: R_EX_tungs_LPAREN_e_RPAREN_
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_EX_tym_LPAREN_e_RPAREN_
#    Random Forest: 5.082642857142858e-16 |   Eflux2 prediction: 3.18e-16
# Working on reaction: R_EX_tyr_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 5.4902442857142856e-14 |   Eflux2 prediction: 1.34e-12
# Working on reaction: R_EX_tyrp_LPAREN_e_RPAREN_
#    Random Forest: 2.9220714285714286e-16 |   Eflux2 prediction: 6.22e-16
# Working on reaction: R_EX_uacgam_LPAREN_e_RPAREN_
#    Random Forest: 1.5993571428571428e-16 |   Eflux2 prediction: 2.23e-16
# Working on reaction: R_EX_udpacgal_LPAREN_e_RPAREN_
#    Random Forest: 2.035e-16 |   Eflux2 prediction: 2.58e-16
# Working on reaction: R_EX_udpg_LPAREN_e_RPAREN_
#    Random Forest: 2.1552857142857144e-16 |   Eflux2 prediction: 3.07e-16
# Working on reaction: R_EX_udpgal_LPAREN_e_RPAREN_
#    Random Forest: 2.0928571428571428e-16 |   Eflux2 prediction: 2.97e-16
# Working on reaction: R_EX_udpglcur_LPAREN_e_RPAREN_
#    Random Forest: 1.7608571428571428e-16 |   Eflux2 prediction: 2.03e-16
# Working on reaction: R_EX_ump_LPAREN_e_RPAREN_
#    Random Forest: 3.5325e-16 |   Eflux2 prediction: 1.34e-15
# Working on reaction: R_EX_ura_LPAREN_e_RPAREN_
#    Random Forest: 7.807776428571428e-14 |   Eflux2 prediction: 1.95e-12
# Working on reaction: R_EX_urea_LPAREN_e_RPAREN_
#    Random Forest: 4.002735e-13 |   Eflux2 prediction: 9.89e-12
# Working on reaction: R_EX_uri_LPAREN_e_RPAREN_
#    Random Forest: 5.889715e-14 |   Eflux2 prediction: 1.46e-12
# Working on reaction: R_EX_val_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 9.78270357142857e-13 |   Eflux2 prediction: 5.32e-12
# Working on reaction: R_EX_xan_LPAREN_e_RPAREN_
#    Random Forest: 3.180899285714286e-14 |   Eflux2 prediction: 8.07e-13
# Working on reaction: R_EX_xmp_LPAREN_e_RPAREN_
#    Random Forest: 1.766142857142857e-16 |   Eflux2 prediction: 5.87e-16
# Working on reaction: R_EX_xtsn_LPAREN_e_RPAREN_
#    Random Forest: 2.8459578571428575e-14 |   Eflux2 prediction: 7.17e-13
# Working on reaction: R_EX_xyl_DASH_D_LPAREN_e_RPAREN_
#    Random Forest: 3.9874285714285715e-16 |   Eflux2 prediction: 2.95e-16
# Working on reaction: R_EX_xylu_DASH_L_LPAREN_e_RPAREN_
#    Random Forest: 3.8154999999999996e-16 |   Eflux2 prediction: 4.13e-16
# Working on reaction: R_EX_zn2_LPAREN_e_RPAREN_
#    Random Forest: -0.00010800785714285715 |   Eflux2 prediction: -0.000114
# Working on reaction: R_12DGR120tipp
#    Random Forest: 6.583455714285714e-13 |   Eflux2 prediction: 1.68e-11
# Working on reaction: R_12DGR140tipp
#    Random Forest: 6.439858571428573e-13 |   Eflux2 prediction: 1.64e-11
# Working on reaction: R_12DGR141tipp
#    Random Forest: 6.425095000000002e-13 |   Eflux2 prediction: 1.64e-11
# Working on reaction: R_12DGR160tipp
#    Random Forest: 6.942592142857142e-13 |   Eflux2 prediction: 1.77e-11
# Working on reaction: R_12DGR161tipp
#    Random Forest: 7.043275e-13 |   Eflux2 prediction: 1.79e-11
# Working on reaction: R_12DGR180tipp
#    Random Forest: 6.338320714285714e-13 |   Eflux2 prediction: 1.62e-11
# Working on reaction: R_12DGR181tipp
#    Random Forest: 6.409456428571429e-13 |   Eflux2 prediction: 1.64e-11
# Working on reaction: R_12PPDRtex
#    Random Forest: -4.221692571428572e-12 |   Eflux2 prediction: -7.22e-11
# Working on reaction: R_12PPDRtpp
#    Random Forest: -4.225312542857143e-12 |   Eflux2 prediction: -7.22e-11
# Working on reaction: R_12PPDStex
#    Random Forest: -1.2185049285714286e-12 |   Eflux2 prediction: -2.04e-11
# Working on reaction: R_12PPDStpp
#    Random Forest: -1.2172245000000001e-12 |   Eflux2 prediction: -2.04e-11
# Working on reaction: R_14GLUCANabcpp
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_14GLUCANtexi
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_23CAMPtex
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_23CCMPtex
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_23CGMPtex
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_23CUMPtex
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_23DAPPAt2pp
#    Random Forest: 1.2602857142857143e-15 |   Eflux2 prediction: 9.44e-16
# Working on reaction: R_23DAPPAtex
#    Random Forest: 1.7242857142857145e-15 |   Eflux2 prediction: 0.0
# Working on reaction: R_23PDE2pp
#    Random Forest: 1.5026428571428572e-15 |   Eflux2 prediction: 7.1e-16
# Working on reaction: R_23PDE4pp
#    Random Forest: 1.5522142857142858e-15 |   Eflux2 prediction: 5.64e-16
# Working on reaction: R_23PDE7pp
#    Random Forest: 1.5832142857142859e-15 |   Eflux2 prediction: 6.87e-16
# Working on reaction: R_23PDE9pp
#    Random Forest: 1.6406428571428575e-15 |   Eflux2 prediction: 5.64e-16
# Working on reaction: R_26DAHtex
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_2AGPA120tipp
#    Random Forest: 5.057044285714285e-13 |   Eflux2 prediction: 1.31e-11
# Working on reaction: R_2AGPA140tipp
#    Random Forest: 5.373722857142857e-13 |   Eflux2 prediction: 1.39e-11
# Working on reaction: R_2AGPA141tipp
#    Random Forest: 5.401907857142857e-13 |   Eflux2 prediction: 1.39e-11
# Working on reaction: R_2AGPA160tipp
#    Random Forest: 3.949410714285714e-13 |   Eflux2 prediction: 1.02e-11
# Working on reaction: R_2AGPA161tipp
#    Random Forest: 3.9638135714285706e-13 |   Eflux2 prediction: 1.02e-11
# Working on reaction: R_2AGPA180tipp
#    Random Forest: 5.632025e-13 |   Eflux2 prediction: 1.45e-11
# Working on reaction: R_2AGPA181tipp
#    Random Forest: 5.688822857142857e-13 |   Eflux2 prediction: 1.46e-11
# Working on reaction: R_2AGPE120tipp
#    Random Forest: 7.049338571428573e-13 |   Eflux2 prediction: 1.81e-11
# Working on reaction: R_2AGPE140tipp
#    Random Forest: 7.293527857142857e-13 |   Eflux2 prediction: 1.87e-11
# Working on reaction: R_2AGPE141tipp
#    Random Forest: 7.307824285714287e-13 |   Eflux2 prediction: 1.88e-11
# Working on reaction: R_2AGPE160tipp
#    Random Forest: 5.05371357142857e-13 |   Eflux2 prediction: 1.3e-11
# Working on reaction: R_2AGPE161tipp
#    Random Forest: 5.053739285714286e-13 |   Eflux2 prediction: 1.3e-11
# Working on reaction: R_2AGPE180tipp
#    Random Forest: 7.494624999999997e-13 |   Eflux2 prediction: 1.92e-11
# Working on reaction: R_2AGPE181tipp
#    Random Forest: 7.494567142857144e-13 |   Eflux2 prediction: 1.92e-11
# Working on reaction: R_2AGPEAT120
#    Random Forest: 3.5762785714285714e-13 |   Eflux2 prediction: 9.34e-12
# Working on reaction: R_2AGPEAT140
#    Random Forest: 3.6625607142857137e-13 |   Eflux2 prediction: 9.58e-12
# Working on reaction: R_2AGPEAT141
#    Random Forest: 3.67695e-13 |   Eflux2 prediction: 9.62e-12
# Working on reaction: R_2AGPEAT160
#    Random Forest: 3.8342978571428563e-13 |   Eflux2 prediction: 9.95e-12
# Working on reaction: R_2AGPEAT161
#    Random Forest: 3.834332857142858e-13 |   Eflux2 prediction: 9.95e-12
# Working on reaction: R_2AGPEAT180
#    Random Forest: 3.763378571428571e-13 |   Eflux2 prediction: 9.8e-12
# Working on reaction: R_2AGPEAT181
#    Random Forest: 3.792095714285715e-13 |   Eflux2 prediction: 9.88e-12
# Working on reaction: R_2AGPG120tipp
#    Random Forest: 6.663607142857143e-13 |   Eflux2 prediction: 1.72e-11
# Working on reaction: R_2AGPG140tipp
#    Random Forest: 6.922842142857144e-13 |   Eflux2 prediction: 1.79e-11
# Working on reaction: R_2AGPG141tipp
#    Random Forest: 6.951055e-13 |   Eflux2 prediction: 1.8e-11
# Working on reaction: R_2AGPG160tipp
#    Random Forest: 6.289060714285715e-13 |   Eflux2 prediction: 1.62e-11
# Working on reaction: R_2AGPG161tipp
#    Random Forest: 6.289318571428571e-13 |   Eflux2 prediction: 1.62e-11
# Working on reaction: R_2AGPG180tipp
#    Random Forest: 7.166732142857145e-13 |   Eflux2 prediction: 1.84e-11
# Working on reaction: R_2AGPG181tipp
#    Random Forest: 7.223454285714286e-13 |   Eflux2 prediction: 1.86e-11
# Working on reaction: R_2AGPGAT120
#    Random Forest: 3.777248571428572e-13 |   Eflux2 prediction: 9.82e-12
# Working on reaction: R_2AGPGAT140
#    Random Forest: 3.863393571428572e-13 |   Eflux2 prediction: 1.01e-11
# Working on reaction: R_2AGPGAT141
#    Random Forest: 3.8636057142857153e-13 |   Eflux2 prediction: 1.01e-11
# Working on reaction: R_2AGPGAT160
#    Random Forest: 4.2941492857142853e-13 |   Eflux2 prediction: 1.12e-11
# Working on reaction: R_2AGPGAT161
#    Random Forest: 4.294252142857143e-13 |   Eflux2 prediction: 1.12e-11
# Working on reaction: R_2AGPGAT180
#    Random Forest: 3.9499971428571433e-13 |   Eflux2 prediction: 1.03e-11
# Working on reaction: R_2AGPGAT181
#    Random Forest: 3.9786392857142866e-13 |   Eflux2 prediction: 1.03e-11
# Working on reaction: R_2DGULRGx
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_2DGULRGy
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_2DGULRx
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_2DGULRy
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_2MAHMP
#    Random Forest: 4.75112142857143e-13 |   Eflux2 prediction: 7.82e-12
# Working on reaction: R_34dhpactex
#    Random Forest: -1.6251428571428567e-15 |   Eflux2 prediction: 0.0
# Working on reaction: R_3AMACHYD
#    Random Forest: 8.952330714285711e-13 |   Eflux2 prediction: 2.18e-11
# Working on reaction: R_3AMPtex
#    Random Forest: 3.0428571428571434e-15 |   Eflux2 prediction: 0.0
# Working on reaction: R_3CMPtex
#    Random Forest: 3.957e-15 |   Eflux2 prediction: 0.0
# Working on reaction: R_3GMPtex
#    Random Forest: 5.175857142857142e-15 |   Eflux2 prediction: 0.0
# Working on reaction: R_3HAD100
#    Random Forest: 3.0291328571428577e-12 |   Eflux2 prediction: 6.93e-11
# Working on reaction: R_3HAD120
#    Random Forest: 2.8451007142857146e-12 |   Eflux2 prediction: 6.52e-11
# Working on reaction: R_3HAD121
#    Random Forest: 1.7243216428571427e-12 |   Eflux2 prediction: 4.01e-11
# Working on reaction: R_3HAD140
#    Random Forest: 1.0270584285714286e-12 |   Eflux2 prediction: 2.39e-11
# Working on reaction: R_3HAD141
#    Random Forest: 1.7243216428571427e-12 |   Eflux2 prediction: 4.01e-11
# Working on reaction: R_3HAD160
#    Random Forest: 1.8540335714285713e-12 |   Eflux2 prediction: 4.21e-11
# Working on reaction: R_3HAD161
#    Random Forest: 2.3566728571428576e-12 |   Eflux2 prediction: 5.38e-11
# Working on reaction: R_3HAD180
#    Random Forest: 1.2382458571428574e-12 |   Eflux2 prediction: 2.93e-11
# Working on reaction: R_3HAD181
#    Random Forest: 1.5225215714285713e-12 |   Eflux2 prediction: 3.61e-11
# Working on reaction: R_3HAD40
#    Random Forest: 1.8966964999999998e-12 |   Eflux2 prediction: 4.25e-11
# Working on reaction: R_3HAD60
#    Random Forest: 1.896699285714286e-12 |   Eflux2 prediction: 4.25e-11
# Working on reaction: R_3HAD80
#    Random Forest: 1.8960971428571427e-12 |   Eflux2 prediction: 4.25e-11
# Working on reaction: R_3HCINNMH
#    Random Forest: 1.3850714285714283e-15 |   Eflux2 prediction: 6.38e-16
# Working on reaction: R_3HPPPNH
#    Random Forest: 1.0275e-15 |   Eflux2 prediction: 5.81e-16
# Working on reaction: R_3HPPtex
#    Random Forest: -8.96696857142857e-13 |   Eflux2 prediction: -2.18e-11
# Working on reaction: R_3HPPtpp
# ...
# Working on reaction: R_THMDtex
#    Random Forest: -4.6714285714285714e-14 |   Eflux2 prediction: -1.15e-12
# Working on reaction: R_THMabcpp
#    Random Forest: 1.825928571428572e-15 |   Eflux2 prediction: 8.04e-16
# Working on reaction: R_THMtex
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_THRA2i
#    Random Forest: 0.059891783337128524 |   Eflux2 prediction: 4.66e-11
# Working on reaction: R_THRAi
#    Random Forest: 1.7102324999999997e-13 |   Eflux2 prediction: 4.07e-12
# Working on reaction: R_THRD
#    Random Forest: 1.7102325000000002e-13 |   Eflux2 prediction: 4.07e-12
# Working on reaction: R_THRD_L
#    Random Forest: 0.09587367774999997 |   Eflux2 prediction: 0.097277096
# Working on reaction: R_THRPtex
#    Random Forest: 9.649285714285714e-16 |   Eflux2 prediction: 1.42e-14
# Working on reaction: R_THRS
#    Random Forest: 0.17634430430000003 |   Eflux2 prediction: 0.182218477
# Working on reaction: R_THRTRS
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_THRabcpp
#    Random Forest: 5.851032857142859e-13 |   Eflux2 prediction: 1.52e-11
# Working on reaction: R_THRt2pp
#    Random Forest: 1.3660857142857147e-11 |   Eflux2 prediction: 3.27e-11
# Working on reaction: R_THRt2rpp
#    Random Forest: -0.0002845357142857143 |   Eflux2 prediction: -0.000317
# Working on reaction: R_THRt4pp
#    Random Forest: 0.0002845357142857143 |   Eflux2 prediction: 0.000317
# Working on reaction: R_THRtex
#    Random Forest: -1.1371428571428571e-13 |   Eflux2 prediction: -2.7e-12
# Working on reaction: R_THYMt3pp
#    Random Forest: 1.2070879285714285e-13 |   Eflux2 prediction: 2.98e-12
# Working on reaction: R_THYMtex
#    Random Forest: -1.2062842857142857e-13 |   Eflux2 prediction: -2.98e-12
# Working on reaction: R_THZPSN3
#    Random Forest: 7.058428571428573e-05 |   Eflux2 prediction: 7.47e-05
# Working on reaction: R_TKT1
#    Random Forest: 0.5988014099000002 |   Eflux2 prediction: 0.497741548
# Working on reaction: R_TKT2
#    Random Forest: 0.48383346520000003 |   Eflux2 prediction: 0.370057763
# Working on reaction: R_TMAOR1
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_TMAOR1pp
#    Random Forest: 9.48857142857143e-16 |   Eflux2 prediction: 6.22e-16
# Working on reaction: R_TMAOR2
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_TMAOR2pp
#    Random Forest: 1.2185714285714287e-15 |   Eflux2 prediction: 6.22e-16
# Working on reaction: R_TMAOtex
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_TMAtex
#    Random Forest: -9.649285714285714e-16 |   Eflux2 prediction: 0.0
# Working on reaction: R_TMDK1
#    Random Forest: 8.765355714285715e-13 |   Eflux2 prediction: 2.27e-11
# Working on reaction: R_TMDPP
#    Random Forest: 1.2003904285714286e-13 |   Eflux2 prediction: 2.98e-12
# Working on reaction: R_TMDS
#    Random Forest: 0.008629356553333333 |   Eflux2 prediction: 0.008761096
# Working on reaction: R_TMK
#    Random Forest: 1.825928571428572e-15 |   Eflux2 prediction: 8.04e-16
# Working on reaction: R_TMPK
#    Random Forest: 7.058428571428573e-05 |   Eflux2 prediction: 7.47e-05
# Working on reaction: R_TMPPP
#    Random Forest: 7.058428571428573e-05 |   Eflux2 prediction: 7.47e-05
# Working on reaction: R_TPI
#    Random Forest: 3.9431097148500007 |   Eflux2 prediction: 3.378207362
# Working on reaction: R_TPRDCOAS
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_TRDR
#    Random Forest: 0.060617119949999985 |   Eflux2 prediction: 0.049796611
# Working on reaction: R_TRE6PH
#    Random Forest: 1.7223819971428575e-10 |   Eflux2 prediction: 3.38e-11
# Working on reaction: R_TRE6PP
#    Random Forest: 0.007970561412617982 |   Eflux2 prediction: 2.47e-11
# Working on reaction: R_TRE6PS
#    Random Forest: 0.00797056158234153 |   Eflux2 prediction: 5.85e-11
# Working on reaction: R_TREH
#    Random Forest: 0.007970561412617982 |   Eflux2 prediction: 2.47e-11
# Working on reaction: R_TREHpp
#    Random Forest: 7.904642857142858e-16 |   Eflux2 prediction: 5.88e-16
# Working on reaction: R_TREptspp
#    Random Forest: 1.1143571428571425e-15 |   Eflux2 prediction: 5.88e-16
# Working on reaction: R_TREtex
#    Random Forest: 3.957e-15 |   Eflux2 prediction: 0.0
# Working on reaction: R_TRPAS2
#    Random Forest: -0.018737532331666664 |   Eflux2 prediction: -0.019032599
# Working on reaction: R_TRPS1
#    Random Forest: 4.86531857142857e-13 |   Eflux2 prediction: 1.13e-11
# Working on reaction: R_TRPS2
#    Random Forest: 4.851032857142858e-13 |   Eflux2 prediction: 1.13e-11
# Working on reaction: R_TRPS3
#    Random Forest: 0.018737532331666664 |   Eflux2 prediction: 0.019032599
# Working on reaction: R_TRPTRS
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_TRPt2rpp
#    Random Forest: -3.306592857142857e-14 |   Eflux2 prediction: -8.93e-13
# Working on reaction: R_TRPtex
#    Random Forest: -3.557142857142857e-14 |   Eflux2 prediction: -8.95e-13
# Working on reaction: R_TRSARr
#    Random Forest: -0.00018880714285714285 |   Eflux2 prediction: -0.000269
# Working on reaction: R_TSULabcpp
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_TSULtex
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_TTDCAtexi
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_TTDCEAtexi
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_TTRCYCtex
#    Random Forest: 2.756928571428571e-11 |   Eflux2 prediction: 6.54e-11
# Working on reaction: R_TTRCYCtpp
#    Random Forest: 2.756928571428571e-11 |   Eflux2 prediction: 6.54e-11
# Working on reaction: R_TUNGSabcpp
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_TUNGStex
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_TYMtex
#    Random Forest: -9.141428571428572e-16 |   Eflux2 prediction: 0.0
# Working on reaction: R_TYRL
#    Random Forest: 7.058428571428573e-05 |   Eflux2 prediction: 7.47e-05
# Working on reaction: R_TYROXDApp
#    Random Forest: 1.2853571428571427e-15 |   Eflux2 prediction: 7.47e-16
# Working on reaction: R_TYRPpp
#    Random Forest: 1.5248571428571428e-15 |   Eflux2 prediction: 6.22e-16
# Working on reaction: R_TYRPtex
#    Random Forest: 1.6251428571428567e-15 |   Eflux2 prediction: 0.0
# Working on reaction: R_TYRTA
#    Random Forest: -0.04543889429999999 |   Eflux2 prediction: -0.046246038
# Working on reaction: R_TYRTRS
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_TYRt2rpp
#    Random Forest: -5.4576814285714286e-14 |   Eflux2 prediction: -1.35e-12
# Working on reaction: R_TYRtex
#    Random Forest: -5.485714285714286e-14 |   Eflux2 prediction: -1.35e-12
# Working on reaction: R_ThDPAT
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_U23GAAT
#    Random Forest: 0.012859355958333336 |   Eflux2 prediction: 0.013028807
# Working on reaction: R_UAAGDS
#    Random Forest: 0.009040388023333333 |   Eflux2 prediction: 0.009304186
# Working on reaction: R_UACGALPpp
#    Random Forest: 1.6252142857142856e-15 |   Eflux2 prediction: 8.49e-16
# Working on reaction: R_UACGAMPpp
#    Random Forest: 1.7322142857142854e-15 |   Eflux2 prediction: 7.33e-16
# Working on reaction: R_UACGAMtex
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_UACMAMO
#    Random Forest: 2.8155121428571436e-13 |   Eflux2 prediction: 6.9e-12
# Working on reaction: R_UAG2E
#    Random Forest: 2.8162000000000007e-13 |   Eflux2 prediction: 6.9e-12
# Working on reaction: R_UAGAAT
#    Random Forest: 0.012859355958333336 |   Eflux2 prediction: 0.013028807
# Working on reaction: R_UAGCVT
#    Random Forest: 0.009040388023333333 |   Eflux2 prediction: 0.009304186
# Working on reaction: R_UAGDP
#    Random Forest: 0.03111990611666667 |   Eflux2 prediction: 0.03163718
# Working on reaction: R_UAGPT3
#    Random Forest: 0.009040388023333333 |   Eflux2 prediction: 0.009304186
# Working on reaction: R_UAMAGS
#    Random Forest: 0.009040388023333333 |   Eflux2 prediction: 0.009304186
# Working on reaction: R_UAMAS
#    Random Forest: 0.009040388023333333 |   Eflux2 prediction: 0.009304186
# Working on reaction: R_UAPGR
#    Random Forest: 0.009040388023333333 |   Eflux2 prediction: 0.009304186
# Working on reaction: R_UDCPDP
#    Random Forest: 0.009040388023333333 |   Eflux2 prediction: 0.009304186
# Working on reaction: R_UDCPDPS
#    Random Forest: 1.7416428571428573e-05 |   Eflux2 prediction: 1.84e-05
# Working on reaction: R_UDCPDPpp
#    Random Forest: 2.5006542857142863e-13 |   Eflux2 prediction: 6.14e-12
# Working on reaction: R_UDCPPtppi
#    Random Forest: 3.761211428571428e-13 |   Eflux2 prediction: 9.2e-12
# Working on reaction: R_UDPACGALtex
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_UDPG4E
#    Random Forest: -4.291142857142858e-15 |   Eflux2 prediction: -2.66e-15
# Working on reaction: R_UDPGALM
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_UDPGALPpp
#    Random Forest: 1.7340000000000006e-15 |   Eflux2 prediction: 1.09e-15
# Working on reaction: R_UDPGALtex
#    Random Forest: 2.1837857142857136e-15 |   Eflux2 prediction: 0.0
# Working on reaction: R_UDPGD
#    Random Forest: 9.56267142857143e-14 |   Eflux2 prediction: 2.3e-12
# Working on reaction: R_UDPGDC
#    Random Forest: 9.562671428571428e-14 |   Eflux2 prediction: 2.3e-12
# Working on reaction: R_UDPGLCURtex
#    Random Forest: 9.141428571428572e-16 |   Eflux2 prediction: 0.0
# Working on reaction: R_UDPGPpp
#    Random Forest: 1.4592142857142857e-15 |   Eflux2 prediction: 8.32e-16
# Working on reaction: R_UDPGtex
#    Random Forest: 9.141428571428572e-16 |   Eflux2 prediction: 0.0
# Working on reaction: R_UDPKAAT
#    Random Forest: 9.421868571428574e-14 |   Eflux2 prediction: 2.3e-12
# Working on reaction: R_UGLCURPpp
#    Random Forest: 1.6053571428571428e-15 |   Eflux2 prediction: 7.37e-16
# Working on reaction: R_UGLT
#    Random Forest: 4.315714285714285e-15 |   Eflux2 prediction: 3.11e-15
# Working on reaction: R_UGLYCH
#    Random Forest: 1.1705315714285713e-13 |   Eflux2 prediction: 2.91e-12
# Working on reaction: R_UGMDDS
#    Random Forest: 0.009040388023333333 |   Eflux2 prediction: 0.009304186
# Working on reaction: R_UHGADA
#    Random Forest: 0.012859355958333336 |   Eflux2 prediction: 0.013028807
# Working on reaction: R_ULA4NFT
#    Random Forest: 9.436767857142857e-14 |   Eflux2 prediction: 2.3e-12
# Working on reaction: R_ULA4Ntppi
#    Random Forest: 9.43676785714286e-14 |   Eflux2 prediction: 2.3e-12
# Working on reaction: R_UM3PL
#    Random Forest: 1.7367090714285714e-12 |   Eflux2 prediction: 4.25e-11
# Working on reaction: R_UM4PCP
#    Random Forest: 5.456539999999999e-13 |   Eflux2 prediction: 1.35e-11
# Working on reaction: R_UM4PL
#    Random Forest: 5.456539999999999e-13 |   Eflux2 prediction: 1.35e-11
# Working on reaction: R_UMPK
#    Random Forest: 0.12426839810000001 |   Eflux2 prediction: 0.126577849
# Working on reaction: R_UMPtex
#    Random Forest: -9.141428571428572e-16 |   Eflux2 prediction: 0.0
# Working on reaction: R_UPLA4FNF
#    Random Forest: 9.43676785714286e-14 |   Eflux2 prediction: 2.3e-12
# Working on reaction: R_UPLA4FNT
#    Random Forest: 9.436767857142857e-14 |   Eflux2 prediction: 2.3e-12
# Working on reaction: R_UPP3MT
#    Random Forest: 7.058428571428573e-05 |   Eflux2 prediction: 7.47e-05
# Working on reaction: R_UPP3S
#    Random Forest: 0.0001412142857142857 |   Eflux2 prediction: 0.000149
# Working on reaction: R_UPPDC1
#    Random Forest: 7.058428571428573e-05 |   Eflux2 prediction: 7.47e-05
# Working on reaction: R_UPPRT
#    Random Forest: 5.355246428571428e-13 |   Eflux2 prediction: 1.4e-11
# Working on reaction: R_URACPAH
#    Random Forest: 8.952330714285711e-13 |   Eflux2 prediction: 2.18e-11
# Working on reaction: R_URAt2pp
#    Random Forest: 0.00024044285714285712 |   Eflux2 prediction: 0.000316
# Working on reaction: R_URAt2rpp
#    Random Forest: -0.00024044285714285712 |   Eflux2 prediction: -0.000316
# Working on reaction: R_URAtex
#    Random Forest: -7.714285714285713e-14 |   Eflux2 prediction: -1.96e-12
# Working on reaction: R_URDGLYCD
#    Random Forest: 2.9044664285714286e-13 |   Eflux2 prediction: 7.38e-12
# Working on reaction: R_UREAtex
#    Random Forest: -3.9978128571428556e-13 |   Eflux2 prediction: -9.89e-12
# Working on reaction: R_UREAtpp
#    Random Forest: -4.000157857142857e-13 |   Eflux2 prediction: -9.89e-12
# Working on reaction: R_URIC
#    Random Forest: 4.486194285714286e-13 |   Eflux2 prediction: 1.14e-11
# Working on reaction: R_URIH
#    Random Forest: 5.611810714285714e-13 |   Eflux2 prediction: 1.45e-11
# Working on reaction: R_URIK2
#    Random Forest: 5.483817857142857e-13 |   Eflux2 prediction: 1.44e-11
# Working on reaction: R_URIt2pp
#    Random Forest: 0.00023274285714285715 |   Eflux2 prediction: 0.000327
# Working on reaction: R_URIt2rpp
#    Random Forest: -0.0002327428571428571 |   Eflux2 prediction: -0.000327
# Working on reaction: R_URItex
#    Random Forest: -5.867925714285714e-14 |   Eflux2 prediction: -1.46e-12
# Working on reaction: R_USHD
#    Random Forest: 0.0064164471050000005 |   Eflux2 prediction: 0.006514404
# Working on reaction: R_VALTA
#    Random Forest: -0.15376232450000002 |   Eflux2 prediction: -0.15934217
# Working on reaction: R_VALTRS
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_VALabcpp
#    Random Forest: 5.851032857142859e-13 |   Eflux2 prediction: 1.52e-11
# Working on reaction: R_VALt2rpp
#    Random Forest: -1.5637973571428572e-12 |   Eflux2 prediction: -2.05e-11
# Working on reaction: R_VALtex
#    Random Forest: -9.763571428571426e-13 |   Eflux2 prediction: -5.31e-12
# Working on reaction: R_VPAMTr
#    Random Forest: -0.017324881046666667 |   Eflux2 prediction: -0.0176559
# Working on reaction: R_WCOS
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_X5PL3E
#    Random Forest: 3.5257857142857137e-15 |   Eflux2 prediction: 3.01e-15
# Working on reaction: R_XAND
#    Random Forest: 4.4861942857142856e-13 |   Eflux2 prediction: 1.14e-11
# Working on reaction: R_XANt2pp
#    Random Forest: 2.2552142857142853e-11 |   Eflux2 prediction: 5.09e-11
# Working on reaction: R_XANtex
#    Random Forest: -3.1428571428571434e-14 |   Eflux2 prediction: -8.1e-13
# Working on reaction: R_XANtpp
#    Random Forest: -2.258071428571429e-11 |   Eflux2 prediction: -5.17e-11
# Working on reaction: R_XMPtex
#    Random Forest: 0.0 |   Eflux2 prediction: 0.0
# Working on reaction: R_XPPT
#    Random Forest: 1.942407142857143e-12 |   Eflux2 prediction: 5.07e-11
# Working on reaction: R_XTSNH
#    Random Forest: 5.611810714285715e-13 |   Eflux2 prediction: 1.45e-11
# Working on reaction: R_XTSNt2rpp
#    Random Forest: -2.4796428571428577e-14 |   Eflux2 prediction: -7.25e-13
# Working on reaction: R_XTSNtex
#    Random Forest: -2.7260499999999997e-14 |   Eflux2 prediction: -7.25e-13
# Working on reaction: R_XYLI1
#    Random Forest: 2.0085e-15 |   Eflux2 prediction: 8.88e-16
# Working on reaction: R_XYLI2
#    Random Forest: 0.67507964640427 |   Eflux2 prediction: 0.293229682
# Working on reaction: R_XYLK
#    Random Forest: 1.3156428571428575e-15 |   Eflux2 prediction: 7.02e-16
# Working on reaction: R_XYLK2
#    Random Forest: 2.2322857142857147e-15 |   Eflux2 prediction: 2.18e-15
# Working on reaction: R_XYLUt2pp
#    Random Forest: 1.0369285714285712e-15 |   Eflux2 prediction: 6.29e-16
# Working on reaction: R_XYLUtex
#    Random Forest: -9.141428571428572e-16 |   Eflux2 prediction: 0.0
# Working on reaction: R_XYLabcpp
#    Random Forest: 8.278785714285714e-16 |   Eflux2 prediction: 5.14e-16
# Working on reaction: R_XYLt2pp
#    Random Forest: 1.3111428571428571e-15 |   Eflux2 prediction: 5.14e-16
# Working on reaction: R_XYLtex
#    Random Forest: -1.8790714285714282e-15 |   Eflux2 prediction: 0.0
# Working on reaction: R_ZN2abcpp
#    Random Forest: 4.736747142857144e-13 |   Eflux2 prediction: 1.15e-11
# Working on reaction: R_ZN2t3pp
#    Random Forest: 2.2705714285714287e-11 |   Eflux2 prediction: 4.65e-11
# Working on reaction: R_ZN2tpp
#    Random Forest: 0.00010800785714285715 |   Eflux2 prediction: 0.000114
# Working on reaction: R_ZNabcpp
#    Random Forest: 4.765318571428572e-13 |   Eflux2 prediction: 1.35e-11
# Working on reaction: R_Zn2tex
#    Random Forest: 0.00010800785714285715 |   Eflux2 prediction: 0.000114

# %% [markdown]
# ### Find optimal stoichiometric nudge - very slow, need to update using CPLEX or conopt

# %%
xf = np.transpose(RF_array)
x0 = np.zeros(len(test_y))+.000005

# Weight factor for relative importance of Sv over the length of the nudging vector= b
weightFactor = 1000.0
print('Initial ||Sv|| = ',np.dot(np.matmul(S.values,xf),np.matmul(S.values,xf)))
print('   Now find nudging vector minimizeResult.x which reduces Sv to zero')

def rosen(x):
    adjusted_fluxes =xf[:]-x[:]
    a = np.matmul(S.values,adjusted_fluxes)
    Sloss = np.dot(a,a)*weightFactor
    bLength = sum((x[:])**2)
    
    # Get occasional updates on solver progress
    if np.random.rand()<.001:
        print('||S(v-b)||=',Sloss/weightFactor,', ||b||=',bLength)
    return bLength + Sloss

# Minimize f = ||S(v-b)||*weightFactor + ||b||
minimizeResult = minimize(rosen, x0, method='BFGS', options={'disp': True, 'maxiter': 10})
# Out:
# Initial ||Sv|| =  15.548938970576701
#    Now find nudging vector minimizeResult.x which reduces Sv to zero
# ||S(v-b)||= 15.528776506058254 , ||b||= 6.457514923365838e-08
# ||S(v-b)||= 15.528776613974294 , ||b||= 6.457514923365838e-08
# ||S(v-b)||= 15.528776443305757 , ||b||= 6.457514923365838e-08
# ||S(v-b)||= 15.528776675683932 , ||b||= 6.457514923365838e-08
# ||S(v-b)||= 15.528776516269188 , ||b||= 6.457514923365838e-08
# ||S(v-b)||= 15.52877654820239 , ||b||= 6.457514923365838e-08
# ||S(v-b)||= 27147.274457530064 , ||b||= 1.0201711597986858
# ||S(v-b)||= 27147.274454921775 , ||b||= 1.0201711595786773
# ||S(v-b)||= 27147.27445492143 , ||b||= 1.0201711595787022
# ||S(v-b)||= 27147.27445753042 , ||b||= 1.0201711597986884
# ||S(v-b)||= 27147.274461619312 , ||b||= 1.020171159762512
# ||S(v-b)||= 27147.274460097768 , ||b||= 1.0201711600313632
# ||S(v-b)||= 27147.274468459742 , ||b||= 1.0201711601436985
# ||S(v-b)||= 12.5175499539586 , ||b||= 0.00011166132365471474
# ||S(v-b)||= 12.517549948941156 , ||b||= 0.00011166132384003866
# ||S(v-b)||= 12.517549964741512 , ||b||= 0.00011166132149598839
# ||S(v-b)||= 12.517549956777923 , ||b||= 0.00011166132520663219
# ||S(v-b)||= 8.061969700825829 , ||b||= 0.001659812346823884
# ||S(v-b)||= 8.061969704546314 , ||b||= 0.001659812345085557
# ||S(v-b)||= 5.34439844236671 , ||b||= 0.02581460486304177
# ||S(v-b)||= 5.344398477443369 , ||b||= 0.02581460495854685
# ||S(v-b)||= 3.828815944952763 , ||b||= 0.0806453716531583
# ||S(v-b)||= 3.828815961344254 , ||b||= 0.08064537166186662
# ||S(v-b)||= 5.13670068427114 , ||b||= 0.15995394271312027
# ||S(v-b)||= 3.2925601684021637 , ||b||= 0.10088525909420869
# ||S(v-b)||= 3.2925601655578256 , ||b||= 0.10088525901566577
# ||S(v-b)||= 4.510975644597334 , ||b||= 0.14062516573734654
# ||S(v-b)||= 4.510975644600593 , ||b||= 0.1406251657373379
# ||S(v-b)||= 4.510975682252107 , ||b||= 0.14062516571154351
# ||S(v-b)||= 3.1651109462150746 , ||b||= 0.10750305647852247
# ||S(v-b)||= 3.16511098706057 , ||b||= 0.10750305640389485
# ||S(v-b)||= 2.966613334060907 , ||b||= 0.11673234078354065
# ||S(v-b)||= 2.9666132642247596 , ||b||= 0.11673234005565201
# ||S(v-b)||= 2.966613294659466 , ||b||= 0.11673234069366267
# ||S(v-b)||= 2.966613300576698 , ||b||= 0.11673234073129259
# ||S(v-b)||= 2.966613299374702 , ||b||= 0.11673234061735856
# ||S(v-b)||= 2.7330350214127375 , ||b||= 0.13965610474415394
# ||S(v-b)||= 2.7330349611369424 , ||b||= 0.13965610473145226
# ||S(v-b)||= 2.733035002731287 , ||b||= 0.1396561046727691
# ||S(v-b)||= 2.7330349810740184 , ||b||= 0.13965610473992215
# ||S(v-b)||= 2.8991264298702806 , ||b||= 0.1889514612997566
# ||S(v-b)||= 2.899126303015711 , ||b||= 0.18895146176681565
# ||S(v-b)||= 2.8991264299985406 , ||b||= 0.18895146089653514
# ||S(v-b)||= 2.899126372970177 , ||b||= 0.18895146006159896
# ||S(v-b)||= 2.8991263993509486 , ||b||= 0.18895146115927433
# ||S(v-b)||= 2.6457925842402306 , ||b||= 0.1542996227820168
# ||S(v-b)||= 2.64579258912105 , ||b||= 0.1542996227042564
# ||S(v-b)||= 2.591276420315004 , ||b||= 0.17444131043149264
# ||S(v-b)||= 2.591276436265554 , ||b||= 0.17444131025827211
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 2591.450856
#          Iterations: 10
#          Function evaluations: 38775
#          Gradient evaluations: 15

# %% [markdown]
# ### Apply the stoichiometric nudge to the Random Forest solution and plot against E-Flux2 and 13C experimental data

# %%
# Use the forest's predict method on the test data
predictions = RF_array - minimizeResult.x
# Calculate the absolute errors of random forest vs eflux2
allAbsError = abs(predictions - test_y)

# %%
# Load data into arrays for plotting
RF_flux, eflux2, absError = [],[],[]
for i in reactionDict.values():
    print('Working on reaction:',reactionNames[i])
    print('   Random Forest:',predictions[i],'Eflux2 prediction:',test_y[i])
    RF_flux.append(predictions[i])
    eflux2.append(float(test_y[i]))
    absError.append(abs(predictions[i]-float(test_y[i])))
RF_flux = np.array(RF_flux)
eflux2 = np.array(eflux2)
# Out:
# Working on reaction: R_PGI
#    Random Forest: 2.2506128746601224 Eflux2 prediction: 2.296128682
# Working on reaction: R_PFK
#    Random Forest: 2.1787934581434 Eflux2 prediction: 1.790151679
# Working on reaction: R_FBA
#    Random Forest: 2.1728773525184186 Eflux2 prediction: 1.790151679
# Working on reaction: R_TPI
#    Random Forest: 3.9568565697581426 Eflux2 prediction: 3.378207362
# Working on reaction: R_PYK
#    Random Forest: 2.904161249011642 Eflux2 prediction: 1.563415101
# Working on reaction: R_PDH
#    Random Forest: 0.6667795095367863 Eflux2 prediction: 1.100181514
# Working on reaction: R_GND
#    Random Forest: 1.988202822727557 Eflux2 prediction: 1.691451557
# Working on reaction: R_RPE
#    Random Forest: 1.0734950574800828 Eflux2 prediction: 0.867799311
# Working on reaction: R_RPI
#    Random Forest: -0.903366013207484 Eflux2 prediction: -0.810324773
# Working on reaction: R_TALA
#    Random Forest: -1.0150652146373342 Eflux2 prediction: -0.861606754
# Working on reaction: R_ICL
#    Random Forest: 0.20392940982909671 Eflux2 prediction: 1.98e-11
# Working on reaction: R_MALS
#    Random Forest: 0.2838086662669786 Eflux2 prediction: 0.000224

# %%
fig, [ax1, ax2] = plt.subplots(1, 2, figsize=(10, 5))

ax1.scatter(EFlux2_flux,RF_flux)
ax1.set_xlim(-2,5)
ax1.set_ylim(-2,5)
ax1.plot(ax1.get_xlim(), ax1.get_ylim(), ls="--", c=".3")
Labels = [i for i in reactionDict]
for i in range(len(EFlux2_flux)):
    xy = (EFlux2_flux[i]+.1,RF_flux[i]+.1)
    ax1.annotate(Labels[i],xy)
ax1.set_xlabel(r'E-Flux2 flux prediction (mmol/gDW/h)')
ax1.set_ylabel(r'Random Forest flux prediction (mmol/gDW/h)')

ax2.scatter(Exp,RF_flux)
ax2.set_xlim(-2,5)
ax2.set_ylim(-2,5)
ax2.plot(ax2.get_xlim(), ax2.get_ylim(), ls="--", c=".3")
Labels = [i for i in reactionDict]
for i in range(len(Exp)):
    xy = (Exp[i]+.1,RF_flux[i]+.1)
    ax2.annotate(Labels[i],xy)
ax2.set_xlabel(r'Ishii $et$ $al$ experimental flux measurement (mmol/gDW/h)')
ax2.set_ylabel(r'Random Forest flux prediction (mmol/gDW/h)')

plt.tight_layout()
plt.show()

# %%
# Histogram plot of errors
g=sns.distplot(absError,hist=True)
plt.xlabel(r'Abolute error of Random Forest vs Eflux2 base (mmol/gDW/h)')
plt.ylabel(r'Normalized frequency')
plt.xlim(0,3)
#plt.show()
#plt.savefig('rf-eflux2-nudging-error.pdf')
# Out:
# (0, 3)

# %%
# Zoom of histogram error
g=sns.distplot(absError,hist=True)
plt.xlabel(r'Abolute error of Random Forest vs Eflux2 base (mmol/gDW/h)')
plt.ylabel(r'Normalized frequency')
plt.xlim(0,3)
plt.ylim(0,1.5)
#plt.show()
#plt.savefig('rf-eflux2-error-nudging-zoom.pdf')
# Out:
# (0, 1.5)

# %%
# Histogram plot of all errors
g=sns.distplot(allAbsError,hist=True)
plt.xlabel(r'Abolute error of Random Forest vs Eflux2 base (mmol/gDW/h)')
plt.ylabel(r'Normalized frequency')
plt.xlim(0,3)
#plt.show()
#plt.savefig('rf-eflux2-allReactions-nudging-error.pdf')
# Out:
# (0, 3)

# %%
# Zoom of histogram all errors
g=sns.distplot(allAbsError,hist=True)
plt.xlabel(r'Abolute error of Random Forest vs Eflux2 base (mmol/gDW/h)')
plt.ylabel(r'Normalized frequency')
plt.xlim(0,3)
plt.ylim(0,.2)
#plt.show()
#plt.savefig('rf-eflux2-allReactions-error-nudging-zoom.pdf')
# Out:
# (0, 0.2)
