# %% [markdown]
# # Metabolomics Data Inspection
#
# By Garrett Roell and Christina Schenk
#
# Tested on biodesign_3.7 kernel on jprime
#
# This notebook gets metabolite data from the model, and uses it to attempt to match unknown metabolites in LCMS data.
# ### Method:
# <ol>
# <li>Set up imports</li>
# <li>Load model and relevant data</li>
# <li>Extract metabolite data from the genome scale mode</li>
# <li>Check for matches between model metabolites and LCMS data</li>
# </ol>

# %% [markdown]
# ### 1. Set up imports

# %%
import cobra
import pandas as pd

# %% [markdown]
# ### 2. Load model and relevant data

# %%
model = cobra.io.read_sbml_model("../models/r_opacus_annotated_curated.xml")

# load LCMS intracellular data (Can use other file names to get other LCMS data sets)
lcms_df = pd.read_csv('../data/metabolomics/LCMS_extracellular_metabolites_positive.csv')
lcms_df.head(2)
# Out:
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
#          m/z  RT [min]                Name                            Tags  \
# 0  113.03449     3.109              Uracil  Confirmed ID (HIgh Confidence)
# 1  148.06024     5.053  O-Acetyl-DL-serine  Confirmed ID (HIgh Confidence)
#
#    Foston_Ex_1-2 (F6)  Foston_Ex_1-9 (F7)  Foston_Ex_1-10 (F8)  \
# 0         24301.78780        2.754439e+04         2.771969e+04
# 1         82578.31694        3.403751e+07         2.734187e+07
#
#    Foston_Ex_1-11 (F9)  Foston_Ex_1-12 (F10)  Foston_Ex_1-13 (F11)  ...  \
# 0         2.856839e+04          2.582551e+04          2.712706e+04  ...
# 1         4.812323e+07          9.047609e+06          1.943422e+07  ...
#
#    Foston_Ex_4-52 (F73)  Foston_Ex_4-53 (F74)  Foston_Ex_4-54 (F75)  \
# 0          3.933230e+04          3.764701e+04          3.596352e+04
# 1          1.214536e+07          9.120849e+06          1.983100e+07
#
#    Foston_Ex_4-55 (F76)  Foston_Ex_4-56 (F77)  Foston_Ex_4-57 (F78)  \
# 0          2.629989e+04          2.375763e+04          7.987254e+04
# 1          1.141326e+07          5.268308e+06          4.501033e+07
#
#    Foston_Ex_4-58 (F79)  Foston_Ex_4-59 (F80)  Foston_Ex_4-60 (F81)  \
# 0          2.354128e+04          2.235829e+04             22917.143
# 1          4.042393e+06          1.120618e+06           2237182.321
#
#    Foston_Ex_4-64 (F82)
# 0          2.570782e+04
# 1          4.857366e+06
#
# [2 rows x 81 columns]

# %% [markdown]
# ### 3. Extract metabolite data from the genome scale model

# %%
# helper function for getting molecular weight from metanetx.org
def get_metanetx_molecular_weight(metanetx_id):
    url = f'https://www.metanetx.org/chem_info/{metanetx_id}'
    
    metanetx_df = pd.read_html(url)[1]
    
    mass_row = metanetx_df[metanetx_df["Unnamed: 0"] == 'mass']
    
    molecular_weight = float(mass_row.Properties.values[0])
    
    return molecular_weight

get_metanetx_molecular_weight('MNXM61')
# Out:
# 149.05105

# %%
# create a list to hold metabolite data
row_data = []

# loop over the metabolites in the model
for m in model.metabolites:
    print(m)
    
    # get MetaNetX id if present
    if 'metanetx.chemical' in m.annotation.keys():
        metanetx_id = m.annotation['metanetx.chemical']
        metanetx_molecular_weight = get_metanetx_molecular_weight(metanetx_id)
    else:
        metanetx_id = ''
        metanetx_molecular_weight = ''
    
    # get KEGG id if present
    if 'kegg.compound' in m.annotation.keys():
        kegg_id = m.annotation['kegg.compound']
    else:
        kegg_id = ''
        
    # create a dictionary for each metabolite's information
    row_data.append({
        "metanetx_molecular_weight": metanetx_molecular_weight,
        "formula_molecular_weight": m.formula_weight,
        "name": m.name,
        "formula": m.formula,
        "metabolite_id": m.id,
        "metanetx_id": metanetx_id,
        "kegg_id": kegg_id,
    })
    
# convert the row data into a data frame
metabolite_df = pd.DataFrame(row_data)

# sort by molecular weight
metabolite_df.sort_values(by=['formula_molecular_weight'], inplace=True)

metabolite_df.head(5)
# Out:
# 10fthf_c
# 12dag3p_BS_c
# 12dgr140_c
# 12dgr140_p
# 12dgr160_c
# 12dgr160_e
# 12dgr180_e
# 12dgr_BS_c
# 12ppd__R_c
# 12ppd__S_c
# 13dampp_c
# 13dpg_c
# 13ppd_c
# 14dh2napcoa_c
# 14dhncoa_c
# 15dap_c
# 1ag160_e
# 1ag180_e
# 1ag181d9_e
# 1ag182d9d12_e
# 1ag3p_BS_c
# 1agpg160_p
# 1btol_c
# 1ddecg3p_c
# 1hdec9eg3p_c
# 1hdecg3p_c
# 1odec11eg3p_c
# 1odecg3p_c
# 1odecg3p_p
# 1p2cbxl_c
# 1p3h5c_c
# 1pyr5c_c
# 1tdec7eg3p_c
# 23ddhb_c
# 23dhacoa_c
# 23dhb_c
# 23dhba_c
# 23dhbzs2_c
# 23dhbzs3_c
# 23dhbzs_c
# 23dhdp_c
# 23dhmb_c
# 23dhmp_c
# 24dab_c
# 24dhhed_c
# 25aics_c
# 25dhpp_c
# 25dkglcn_c
# 25dkglcn_e
# 25dkglcn_p
# 25dop_c
# 25drapp_c
# 26dap_LL_c
# 26dap__M_c
# 26dap__M_e
# 26dap__M_p
# 2agpe120_c
# 2agpe120_p
# 2agpe141_c
# 2agpe141_p
# 2agpe160_c
# 2agpe160_p
# 2agpe161_c
# 2agpe161_p
# 2agpe180_c
# 2agpe180_p
# 2agpe181_c
# 2agpe181_p
# 2agpg120_c
# 2agpg120_p
# 2agpg140_c
# 2agpg140_p
# 2agpg141_c
# 2agpg141_p
# 2agpg160_c
# 2agpg160_p
# 2agpg161_c
# 2agpg161_p
# 2agpg180_c
# 2agpg180_p
# 2agpg181_c
# 2agpg181_p
# 2ahbut_c
# 2ahethmpp_c
# 2ahhmd_c
# 2ahhmp_c
# 2ameph_c
# 2ameph_e
# 2ameph_p
# 2amsa_c
# 2aobut_c
# 2cpr5p_c
# 2dda7p_c
# 2ddara_c
# 2ddecg3p_c
# 2ddecg3p_p
# 2ddg6p_c
# 2ddglcn_c
# 2dh3dgal6p_c
# 2dh3dgal_c
# 2dhglcn_c
# 2dhglcn_e
# 2dhglcn_p
# 2dhguln_c
# 2dhp_c
# 2dhphaccoa_c
# 2dmmq8_c
# 2dmmql8_c
# 2dr1p_c
# 2dr5p_c
# 2h3oppan_c
# 2hadnt_c
# 2hdec9eg3p_c
# 2hdec9eg3p_p
# 2hdecg3p_c
# 2hdecg3p_p
# 2hh24dd_c
# 2hyoxplac_c
# 2ins_c
# 2ippm_c
# 2kmb_c
# 2m35mdntha_c
# 2m35mdntha_e
# 2maacoa_c
# 2mahmp_c
# 2mb2coa_c
# 2mbcoa_c
# 2mbdhl_c
# 2mcacn_c
# 2mcit_c
# 2me4p_c
# 2mecdp_c
# 2mop_c
# 2mp2coa_c
# 2mpdhl_c
# 2o3mpt_c
# 2obut_c
# 2odec11eg3p_c
# 2odec11eg3p_p
# 2ohed_c
# 2ohph_c
# 2oph_c
# 2oxoadp_c
# 2oxpaccoa_c
# 2p4c2me_c
# 2pg_c
# 2pglyc_c
# 2pglyc_e
# 2ptcoa_c
# 2sephchc_c
# 2shchc_c
# 2tdec7eg3p_c
# 2tdec7eg3p_p
# 34dhbz_c
# 34dhbz_e
# 34dhbz_p
# 34dhpac_e
# 34dhpac_p
# 34dhpacet_c
# 34dhpha_c
# 34dhsa_c
# 34hpp_c
# 35cgmp_c
# 35dnta_c
# 35dnta_e
# 3amac_c
# 3c2hmp_c
# 3c3hmp_c
# 3c4mop_c
# 3dhgulnp_c
# 3dhq_c
# 3dhsk_c
# 3h6athcoa_c
# 3hadpcoa_c
# 3hasp__L_c
# 3hbcoa__R_c
# 3hbcoa_c
# 3hbycoa_c
# 3hcinnm_c
# 3hcinnm_e
# 3hcinnm_p
# 3hdcoa_c
# 3hdd5coa_c
# 3hdd6coa_c
# 3hddccoa_c
# 3hddcoa_c
# 3hdec4coa_c
# 3hhcoa_c
# 3hhd58coa_c
# 3hhd710coa_c
# 3hhdccoa_c
# 3hhdcoa_c
# 3hhdd4coa_c
# 3hhdd7coa_c
# 3hhpcoa_c
# 3hibutcoa_c
# 3hlnlccoa_c
# 3hmbcoa_c
# 3hmp_c
# 3hnonacoa_c
# 3hocoa_c
# 3hodcoa_c
# 3hodecoa_c
# 3hpbcoa_c
# 3hpdecacoa_c
# 3hphpcoa_c
# 3hphxacoa_c
# 3hpnonacoa_c
# 3hpoctacoa_c
# 3hppnl_c
# 3hpppn_c
# 3hpppn_e
# 3hpppn_p
# 3hpptcoa_c
# 3hptcoa_c
# 3hptslacoa_c
# 3hsa_c
# 3htdccoa_c
# 3htdcoa_c
# 3hvacccoa_c
# 3ig3p_c
# 3mb2coa_c
# 3mb_c
# 3mb_e
# 3mb_p
# 3mgcoa_c
# 3mob_c
# 3mop_c
# 3o6athcoa_c
# 3odcoa_c
# 3odd5coa_c
# 3odd6coa_c
# 3oddccoa_c
# 3oddcoa_c
# 3odec4coa_c
# 3ohcoa_c
# 3ohd58coa_c
# 3ohd710coa_c
# 3ohdccoa_c
# 3ohdcoa_c
# 3ohdd4coa_c
# 3ohdd7coa_c
# 3ohodcoa_c
# 3ohpcoa_c
# 3olnlccoa_c
# 3ononacoa_c
# 3oocoa_c
# 3oodecoa_c
# 3opbcoa_c
# 3opdecacoa_c
# 3ophb_c
# 3ophpcoa_c
# 3ophxacoa_c
# 3opnonacoa_c
# 3opoctacoa_c
# 3opptcoa_c
# 3optcoa_c
# 3optslacoa_c
# 3otdccoa_c
# 3otdcoa_c
# 3ovacccoa_c
# 3oxdhscoa_c
# 3oxoadp_c
# 3oxptcoa_c
# 3padsel_c
# 3pg_c
# 3php_c
# 3psme_c
# 3ptcoa_c
# 3sala_c
# 3snpyr_c
# 49dsha_c
# 4aabutn_c
# 4abut_c
# 4abut_e
# 4abut_p
# 4abutn_c
# 4abz_c
# 4abzglu_c
# 4abzglu_e
# 4abzglu_p
# 4adcho_c
# 4ahmmp_c
# 4ampm_c
# 4atb2coa_c
# 4c2me_c
# 4cml_c
# 4fumacac_c
# 4gudbutn_c
# 4h2kpi_c
# 4h2oglt_c
# 4h2opntn_c
# 4hadnt_c
# 4hba_c
# 4hba_e
# 4hbald_c
# 4hbutcoa_c
# 4hbz_c
# 4hbz_e
# 4hbz_p
# 4hbzcoa_c
# 4hoxoh_c
# 4hoxpac_c
# 4hoxpac_e
# 4hoxpac_p
# 4hoxpacd_c
# 4hphac_c
# 4hphac_e
# 4hpro_LT_c
# 4hpro_LT_e
# 4hptcoa_c
# 4hptn_c
# 4hptn_e
# 4hptn_p
# 4izp_c
# 4mhetz_c
# 4mlacac_c
# 4mop_c
# 4mpetz_c
# 4oxptcoa_c
# 4oxptn_c
# 4oxptn_e
# 4oxptn_p
# 4pasp_c
# 4per_c
# 4poptcoa_c
# 4ppan_c
# 4ppcys_c
# 4r5au_c
# 56dura_c
# 5a2opntn_c
# 5aizc_c
# 5aop_c
# 5apentam_c
# 5aprbu_c
# 5apru_c
# 5aptn_c
# 5caiz_c
# 5cmhm_c
# 5cmhmsa_c
# 5cohe_c
# 5d4dglcr_c
# 5dglcn_c
# 5dh4dglc_c
# 5drib_c
# 5drib_e
# 5forthf_c
# 5fthf_c
# 5g2oxpt_c
# 5hiu_c
# 5houdic_c
# 5mcsn_c
# 5mdr1p_c
# 5mdru1p_c
# 5mdru1p_e
# 5mta_c
# 5mthf_c
# 5mtr_c
# 5odhf2a_c
# 5ohhip_c
# 5ohhipcoa_c
# 5oxpro_c
# 5pg35pg_c
# 6a2ohxnt_c
# 6apa_p
# 6ath2coa_c
# 6hmhpt_c
# 6hmhptpp_c
# 6hnac_c
# 6p2dhglcn_c
# 6pgc_c
# 6pgl_c
# 8aonn_c
# 9ohadd_c
# ACP_c
# CCbuttc_c
# L2aadp6sa_c
# L2aadp_c
# LalaDgluMdapDala_c
# LalaDgluMdapDala_p
# LalaDgluMdap_c
# LalaDgluMdap_e
# LalaDgluMdap_p
# LalaDglu_c
# LalaLglu_c
# LalaLglu_e
# LalaLglu_p
# Lcyst_c
# Lcyst_e
# Ncarbsar_c
# Ncbmpts_c
# Pald_c
# R3hdec4coa_c
# R3hdec4e_c
# R_3h4atba_c
# R_3h4atbcoa_c
# R_3h6atha_c
# R_3h6athcoa_c
# R_3hcddec5ecoa_c
# R_3hcmrs7e_c
# R_3hcmrs7ecoa_c
# R_3hdcaa_c
# R_3hdcoa_c
# R_3hdd5ea_c
# R_3hdd5ea_e
# R_3hdd5ea_p
# R_3hdd6coa_c
# R_3hdd6e_c
# R_3hdda_c
# R_3hddcoa_c
# R_3hhcoa_c
# R_3hhdca_c
# R_3hhdcoa_c
# R_3hhpa_c
# R_3hhpcoa_c
# R_3hhxa_c
# R_3hmrscoa_c
# R_3hnonaa_c
# R_3hnonacoa_c
# R_3hocoa_c
# R_3hocta_c
# R_3hpba_c
# R_3hpbcoa_c
# R_3hpdeca_c
# R_3hpdecacoa_c
# R_3hphpa_c
# R_3hphpa_e
# R_3hphpa_p
# R_3hphpcoa_c
# R_3hphxa_c
# R_3hphxacoa_c
# R_3hpnona_c
# R_3hpnonacoa_c
# R_3hpocta_c
# R_3hpocta_e
# R_3hpocta_p
# R_3hpoctacoa_c
# R_3hppta_c
# R_3hppta_e
# R_3hppta_p
# R_3hpptcoa_c
# R_3hpt_c
# R_3hptcoa_c
# R_3htd58coa_c
# R_3htd58e_c
# R_3htd5coa_c
# R_3htd5e_c
# R_3httdca_c
# S2hglut_c
# a24op_c
# a_gal__D_c
# aacald_c
# aacoa_c
# aact_c
# aad_c
# abg4_c
# abg4_e
# abt__L_c
# abt_c
# abt_e
# ac_c
# ac_e
# ac_p
# acac_c
# acac_e
# acac_p
# acadl_c
# acald_c
# acald_e
# accoa_c
# acetol_c
# acg5p_c
# acg5sa_c
# acgam1p_c
# acgam6p_c
# acgam_c
# acgam_e
# acgam_p
# acglu_c
# achms_c
# acmana_c
# acmana_e
# acmanap_c
# acmum6p_c
# acnam_c
# acnam_e
# acnam_p
# acon_C_c
# acon_C_e
# acon_C_p
# acorn_c
# acser_c
# actn__R_c
# actn__R_e
# actn__S_c
# actp_c
# acysbmn_c
# acysbmn_e
# ad_c
# ad_e
# adcobhex_c
# ade_c
# adhlam_c
# adn_c
# adn_e
# adocbi_c
# adocbip_c
# adp_c
# adpglc_c
# adprib_c
# adsel_c
# agm_c
# agm_e
# agm_p
# ah6p__D_c
# ahcys_c
# ahdt_c
# aicar_c
# air_c
# akg_c
# akg_e
# akg_p
# ala_B_c
# ala_B_e
# ala_B_p
# ala_L_asp__L_c
# ala_L_asp__L_e
# ala_L_glu__L_c
# ala_L_glu__L_e
# ala_L_thr__L_c
# ala_L_thr__L_e
# ala__D_c
# ala__D_e
# ala__D_p
# ala__L_c
# ala__L_e
# ala__L_p
# ala_gln_c
# ala_gln_e
# ala_his_c
# ala_his_e
# ala_leu_c
# ala_leu_e
# alaala_c
# alaala_p
# alac__S_c
# alagly_c
# alagly_e
# alahis_c
# alahis_e
# alahis_p
# alaleu_c
# alaleu_e
# alaleu_p
# alathr_c
# alathr_e
# alathr_p
# alatrp_c
# alatrp_e
# alatrp_p
# algac_MG_41_e
# algac_MG_41_p
# allphn_c
# alltn__R_c
# alltn_c
# alltn_e
# alltn_p
# alltt_c
# alpro_c
# amacald_c
# amet_c
# ametam_c
# amob_c
# amp_c
# andrs14dn317dn_c
# andrstndn_c
# anhgm3p_c
# anhgm3p_p
# anhgm4p_c
# anhgm4p_p
# anhgm_c
# anhgm_e
# anhgm_p
# anhm3p_c
# anhm4p_c
# anhm_c
# anth_c
# ap4a_c
# apc_e
# apc_p
# apoACP_c
# appl_c
# applp_c
# aprut_c
# aps_c
# arab__D_c
# arab__D_p
# arab__L_c
# arab__L_e
# arab__L_p
# arachACP_c
# arach_c
# arachcoa_c
# arbt6p_c
# arbt6p_e
# arbt_e
# arg__D_c
# arg__L_c
# arg__L_e
# arg__L_p
# argsuc_c
# ascb6p_c
# ascb__L_e
# asn__L_c
# asn__L_e
# asn__L_p
# aso3_c
# aso3_e
# aso3_p
# aso4_c
# aso4_e
# aso4_p
# asp__L_c
# asp__L_e
# asp__L_p
# aspsa_c
# atp_c
# b2coa_c
# benzcoa_c
# betald_c
# bglyg4n_c
# bhb_c
# bmn_c
# bmn_e
# bmnmsh_c
# btal_c
# btcoa_c
# btd_RR_c
# btn_c
# btn_e
# btoh_c
# but_c
# but_e
# but_p
# buts_c
# buts_e
# butso3_c
# butso3_e
# butso3_p
# bz12diol_c
# bz_c
# bz_e
# bz_p
# bzal_c
# bzalc_c
# bzalc_e
# bzalc_p
# bzsucc_c
# bzsuccoa_c
# ca2_c
# ca2_e
# ca2_p
# cala_c
# camp_c
# carn_c
# carn_e
# carn_p
# catechol_c
# cbasp_c
# cbm_c
# cbp_c
# cchol_c
# ccmuac_c
# cd2_c
# cd2_p
# cdigmp_c
# cdp_c
# cdpc16c19g_c
# cdpc19c19g_c
# cdpdddecg_c
# cdpdhdec9eg_c
# cdpdhdecg_c
# cdpdodec11eg_c
# cdpdodecg_c
# cdpdtdec7eg_c
# cdpdtdecg_c
# cdpglyc_c
# cellb_c
# cellb_e
# cgly_c
# cgly_e
# cgly_p
# chol4en3one_c
# chol_c
# chol_e
# chol_p
# cholc3coa_c
# cholc5coa_c
# cholc8coa_c
# cholenec3coa_c
# cholenec5coa_c
# cholenec8coa_c
# chols_c
# chols_e
# chor_c
# chsterol_c
# chsterol_e
# cigam_c
# cit_c
# cit_e
# cit_p
# citr__L_c
# cl_c
# cl_e
# clpn140_p
# cm_c
# cm_e
# cm_p
# cmcbtt_c
# cmcbtt_e
# cmcbtt_p
# cmp_c
# co2_c
# co2_e
# co2_p
# co_c
# co_e
# co_p
# coa_c
# cobalt2_c
# cobalt2_e
# cobalt2_p
# cpppg3_c
# creat_c
# creat_e
# creat_p
# crn__D_c
# crn__D_p
# crn_c
# crn_e
# crn_p
# cro4_c
# cro4_p
# crtn_c
# crtn_e
# crtn_p
# csn_c
# csn_e
# ctbt_c
# ctbt_p
# ctncoa_c
# ctp_c
# cu2_c
# cu2_e
# cu2_p
# cyan_c
# cyan_e
# cyan_p
# cys__L_c
# cys__L_e
# cys__L_p
# cyst__L_c
# cytd_c
# d12dg_BS_c
# d5kg_c
# d5kgp_c
# dad_2_c
# dad_2_e
# dad_5_c
# dadp_c
# dag181d9_e
# dag182d9d12_e
# damp_c
# dann_c
# dap24_c
# datp_c
# db4p_c
# dc2coa_c
# dcaACP_c
# dca_c
# dca_e
# dca_p
# dcacoa_c
# dcamp_c
# dccoa_c
# dcdp_c
# dcmp_c
# dctp_c
# dcyt_c
# dd2coa_c
# dd6_2_coa_c
# dd_3_6_coa_c
# ddcaACP_c
# ddca_c
# ddca_p
# ddcacoa_c
# ddcap_c
# ddcoa_c
# dde2coa_c
# dded3coa_c
# dec4_2_coa_c
# dec4coa_c
# decoa_c
# dgal6p_c
# dgdp_c
# dgmp_c
# dgsn_c
# dgtp_c
# dha_c
# dhap_c
# dhcinnm_c
# dhcrn_c
# dhcrncoa_c
# dhf_c
# dhlam_c
# dhlpro_c
# dhna_c
# dhnpt_c
# dhor__S_c
# dhpmp_c
# dhpppn_c
# dhpt_c
# dhpyr_c
# diact_c
# dimp_c
# din_c
# ditp_c
# dkdi_c
# dmgly_c
# dmlgnc_c
# dmlz_c
# dmpp_c
# dmso2_c
# dmso2_e
# dmso2_p
# dnad_c
# dopa_e
# dopa_p
# dpcoa_c
# drib_c
# drib_e
# dscl_c
# dtbt_c
# dtdp_c
# dtmp_c
# dttp_c
# dudp_c
# dump_c
# duri_c
# dutp_c
# dxyl5p_c
# dxyl_c
# dxyl_e
# dxyl_p
# e4hglu_c
# e4p_c
# eig3p_c
# enter_c
# enter_e
# enter_p
# entermg_c
# etha_c
# etha_e
# etha_p
# eths_c
# eths_e
# ethso3_c
# ethso3_e
# ethso3_p
# etoh_c
# f1p_c
# f6p_c
# fa11_c
# fa11coa_c
# fa12_c
# fa12coa_c
# fa1_c
# fa1coa_c
# fa3_c
# fa3coa_c
# fa4_c
# fa4coa_c
# fa6_c
# fa6coa_c
# fad_c
# fadh2_c
# fald_c
# fald_p
# fbac_kt_c
# fbac_kt_p
# fc1p_c
# fcmcbtt_c
# fdp_c
# fdxo_2_2_c
# fdxox_c
# fdxrd_c
# fe2_c
# fe2_e
# fe2_p
# fe3_c
# fe3_e
# fe3_p
# fe3dcit_c
# fe3dcit_e
# fe3dcit_p
# fe3dhbzs3_c
# fe3pyovd_kt_e
# feenter_c
# feenter_e
# feenter_p
# feoxam_c
# feoxam_e
# feoxam_p
# feoxam_un_c
# feoxam_un_e
# feoxam_un_p
# fer_c
# fer_e
# fer_p
# ferulcoa_c
# fgam_c
# ficytc_c
# fmcbtt_c
# fmnRD_c
# fmn_c
# fmnh2_c
# focytc_c
# fol_c
# fol_e
# for_c
# forcoa_c
# forglu_c
# fpram_c
# fprica_c
# frdp_c
# frmd_c
# fru_c
# fru_e
# fru_p
# fruur_c
# fuc_e
# fum_c
# fum_e
# fum_p
# g1p_c
# g3p_c
# g3pe_c
# g3pe_e
# g3pe_p
# g3pg_c
# g3pg_p
# g6p_A_c
# g6p_B_c
# g6p_c
# ga_c
# ga_e
# ga_p
# gal1p_c
# gal_bD_c
# gal_bD_e
# gal_c
# gal_e
# gal_p
# galct__D_c
# galct__D_e
# galct__D_p
# galctn__D_c
# galctn__D_e
# galctn__D_p
# galman4_c
# galman4_e
# galman6_c
# galman6_e
# galt1p_c
# galt_e
# galur_c
# galur_e
# gam1p_c
# gam6p_c
# gam_e
# gar_c
# gcald_c
# gcvHL_ADPr_c
# gcvHL_nhLA_c
# gdbtal_c
# gdp_c
# gdpmann_c
# gdpmanur_c
# gdptp_c
# gg13dampp_c
# gg15dap_c
# gg4abut_c
# ggala_B_c
# ggaptn_c
# ggbamppal_c
# ggbdapal_c
# ggbutal_c
# ggdp_c
# ggspmd_c
# glc_D_B_c
# glc__D_c
# glc__D_e
# glc__D_p
# glc__aD_c
# glc__aD_e
# glc__bD_c
# glcman4_c
# glcman4_e
# glcman6_c
# glcman6_e
# glcn_c
# glcn_e
# glcn_p
# glcr_c
# glcr_e
# glcr_p
# glcur_c
# glcur_e
# glcur_p
# gln__L_c
# gln__L_e
# gln__L_p
# glu1sa_c
# glu5p_c
# glu5sa_c
# glu__D_c
# glu__L_c
# glu__L_e
# glu__L_p
# gluala_c
# glucan4_c
# glucan4_e
# glucan6_c
# glucan6_e
# glucys_c
# glutar_c
# glutar_e
# glutar_p
# glutcoa_c
# glutrna_c
# glx_c
# gly_asn__L_c
# gly_asn__L_e
# gly_asp__L_c
# gly_asp__L_e
# gly_c
# gly_cys_c
# gly_cys_e
# gly_e
# gly_gln_c
# gly_gln_e
# gly_glu__L_c
# gly_glu__L_e
# gly_leu_c
# gly_leu_e
# gly_met_c
# gly_met_e
# gly_p
# gly_phe_c
# gly_phe_e
# gly_pro__L_c
# gly_pro__L_e
# gly_tyr_c
# gly_tyr_e
# glyald_c
# glyb_c
# glyb_e
# glyb_p
# glybcoa_c
# glyc3p_c
# glyc3p_e
# glyc3p_p
# glyc__R_c
# glyc__R_e
# glyc__R_p
# glyc_c
# glyc_e
# glyc_p
# glyclt_c
# glyclt_e
# glyclt_p
# glyg4n_c
# glygln_c
# glygln_e
# glygln_p
# glyglu_c
# glyglu_e
# glyglu_p
# glygly_c
# glyglygln_c
# glyglygln_e
# glymet_c
# glymet_e
# glymet_p
# glyphe_c
# glyphe_e
# glyphe_p
# glyser_c
# glyser_e
# glyser_p
# gmp_c
# grdp_c
# grxox_c
# grxrd_c
# gsn_c
# gsn_e
# gsn_p
# gtca1_45_BS_c
# gtca2_45_BS_c
# gtca3_45_BS_c
# gthox_c
# gthrd_c
# gthrd_e
# gthrd_p
# gtp_c
# gua_c
# gua_e
# gua_p
# h2_c
# h2co3_c
# h2isocap_c
# h2isocapcoa_c
# h2mb4p_c
# h2o2_c
# h2o2_p
# h2o_c
# h2o_e
# h2o_p
# h2s_c
# h2s_e
# h4but_c
# h_c
# h_e
# h_p
# hchol_c
# hcholc3coa_c
# hcholc5coa_c
# hcholc8coa_c
# hcit_c
# hco3_c
# hco3_e
# hco3_p
# hcys__L_c
# hd2coa_c
# hd710_2_coa_c
# hd_7_10_coa_c
# hdca_c
# hdca_e
# hdca_p
# hdcap_c
# hdcea_c
# hdcea_p
# hdceap_c
# hdcoa_c
# hdd2coa_c
# hdd4_2_coa_c
# hdd4coa_c
# hdd7_2_coa_c
# hdd7coa_c
# hdeACP_c
# hemeO_c
# hepdp_c
# hethmpp_c
# hexdp_c
# hexs_c
# hexs_e
# hg2_c
# hg2_p
# hgentis_c
# hhd_c
# hia_c
# hia_e
# hicit_c
# hip_c
# hipcoa_c
# hipecoa_c
# hipocoa_c
# hipohcoa_c
# his__L_c
# his__L_e
# his__L_p
# hisgly_c
# hisgly_e
# hisgly_p
# hishis_c
# hishis_e
# hishis_p
# hisp_c
# histd_c
# histda_c
# hkndd_c
# hkntd_c
# hmbil_c
# hmbpp_c
# hmgcoa_c
# hmpscoa_c
# hom__L_c
# hom__L_e
# hom__L_p
# hp2coa_c
# hpglu_c
# hpta_c
# hpta_e
# hpta_p
# hptcoa_c
# hpyr_c
# hx2coa_c
# hxa_c
# hxa_e
# hxa_p
# hxal_c
# hxan_c
# hxan_e
# hxan_p
# hxcoa_c
# iasp_c
# ibcoa_c
# ichor_c
# icit_c
# icit_e
# icit_p
# id3acald_c
# idon__L_c
# idp_c
# igam_c
# ile__L_c
# ile__L_e
# ile__L_p
# imacp_c
# imp_c
# ind3ac_c
# ind3ac_e
# ind3ac_p
# indole_c
# indole_e
# indole_p
# indpyr_c
# inost_c
# inost_e
# ins_c
# ins_e
# ins_p
# ipdp_c
# isetac_c
# isetac_e
# isetac_p
# isocap_c
# isocap_e
# isocapcoa_c
# isocaprecoa_c
# istfrnA_e
# istfrnB_e
# istnt_c
# istnt_e
# itp_c
# ivcoa_c
# k_c
# k_e
# k_p
# lac__D_c
# lac__D_e
# lac__L_c
# lac__L_e
# lald__D_c
# lald__L_c
# lcts_c
# lcts_e
# lcts_p
# leu__L_c
# leu__L_e
# leu__L_p
# leuleu_c
# leuleu_e
# leuleu_p
# lgt__S_c
# lgt_s_c
# lipo1_24_BS_c
# lipo2_24_BS_c
# lipo3_24_BS_c
# lipo4_24_BS_c
# lmn2_c
# lmn2_e
# lnlc2coa_c
# lnlc_c
# lnlc_e
# lnlc_p
# lnlccoa_c
# lpam_c
# lpro_c
# lys__D_c
# lys__L_c
# lys__L_e
# lys__L_p
# lysglugly_c
# lysglugly_e
# m2bcoa_c
# m_xyl_c
# m_xyl_e
# m_xyl_p
# mal__D_c
# mal__D_e
# mal__D_p
# mal__L_c
# mal__L_e
# mal__L_p
# malcoa_c
# male_c
# malm_c
# malt1p_c
# malt6p_c
# malt_c
# malt_e
# malt_p
# malthp_c
# malthp_e
# malthx_c
# malthx_e
# malthx_p
# maltpt_c
# malttr_c
# malttr_e
# malttre_c
# maltttr_c
# man1p_c
# man6p_c
# man_c
# man_e
# man_p
# mana_c
# manb_c
# mantr_c
# manttr_c
# manttr_e
# mbhn_c
# mcbtt_c
# melib_c
# melib_e
# melib_p
# meoh_c
# meoh_e
# meoh_p
# mercppyr_c
# met_L_ala__L_c
# met_L_ala__L_e
# met__D_c
# met__D_e
# met__L_c
# met__L_e
# met__L_p
# methf_c
# metox__R_c
# metox__R_e
# metox_c
# metox_e
# metsox_R__L_c
# metsox_R__L_e
# metsox_S__L_c
# metsox_S__L_e
# mg2_c
# mg2_e
# mg2_p
# mhpglu_c
# mi1p__D_c
# mi3p__D_c
# micit_c
# mlthf_c
# mmal_c
# mmalsa__S_c
# mmcoa__R_c
# mmcoa__S_c
# mmtsa_c
# mn2_c
# mn2_e
# mn2_p
# mnl1p_c
# mnl_e
# mobd_c
# mobd_e
# mql7_c
# mql8_c
# mqn7_c
# mqn8_c
# msa_c
# msh_c
# mso3_c
# mso3_e
# mssg_c
# mthd_c
# mthgxl_c
# mththf_c
# mththf_p
# mucl_c
# murein3p3p_p
# murein4p3p_p
# murein4p4p_p
# murein4px4p4p_p
# murein4px4p_p
# murein4px4px4p_p
# murein5p3p_p
# murein5p4p_p
# murein5p5p5p_p
# murein5p5p_p
# murein5px3p_p
# murein5px4p_p
# murein5px4px4p_p
# myrsACP_c
# n2o_c
# n2o_e
# n2o_p
# n4abutn_c
# n5horn_c
# n6all26d_c
# na1_c
# na1_e
# na1_p
# nac_c
# nad_c
# nadh_c
# nadhx__R_c
# nadhx__S_c
# nadp_c
# nadph_c
# nadphx__R_c
# nadphx__S_c
# ncam_c
# nfmalm_c
# nh3_c
# nh4_c
# nh4_e
# nh4_p
# nh4oh_c
# ni2_c
# ni2_e
# ni2_p
# nicrns_c
# nicrnt_c
# nmn_c
# no2_c
# no2_e
# no3_c
# no3_e
# no3_p
# no_c
# no_e
# nona2coa_c
# nona_c
# nonacoa_c
# o2_c
# o2_e
# o2_p
# o2s_c
# oaa_c
# oaa_e
# oaa_p
# oc2coa_c
# ocACP_c
# oca_c
# occoa_c
# ocdcaACP_c
# ocdca_c
# ocdca_e
# ocdca_p
# ocdcap_c
# ocdcea_c
# ocdcea_e
# ocdcea_p
# ocdceap_c
# ochol_c
# ocholc5coa_c
# ocholc8coa_c
# octa_c
# octa_e
# octa_p
# octdp_c
# octeACP_c
# od2coa_c
# ode2coa_c
# odecoa_c
# ohpb_c
# omaenol_c
# omaketo_c
# op4en_c
# orn__D_c
# orn__D_e
# orn__D_p
# orn__L_c
# orn_c
# orn_e
# orn_p
# orot5p_c
# orot_c
# orot_e
# orot_p
# oxa_c
# oxa_e
# oxadpcoa_c
# oxalcoa_c
# oxptn_c
# p1p3b5adtp_c
# p_xyl_c
# p_xyl_e
# p_xyl_p
# pa120_c
# pa120_p
# pa140_c
# pa140_p
# pa141_c
# pa141_p
# pa160190_c
# pa160_c
# pa160_p
# pa161_c
# pa161_p
# pa180_c
# pa180_p
# pa181_c
# pa181_p
# pa190190_c
# pac_c
# pac_p
# pacald_c
# pacald_e
# pacald_p
# pad_c
# palmACP_c
# pan4p_c
# pant__R_c
# pap_c
# paps_c
# pb2coa_c
# pbcoa_c
# pdca2coa_c
# pdima_c
# pdima_e
# pdx5p_c
# pe120_c
# pe120_p
# pe141_c
# pe141_p
# pe160_c
# pe160_p
# pe161_c
# pe161_p
# pe180_c
# pe180_p
# pe181_c
# pe181_p
# pea_c
# pea_e
# peamn_c
# peamn_e
# peamn_p
# pendp_c
# peng_p
# pentso3_c
# pentso3_e
# pentso3_p
# pep_c
# peptido_BS_c
# pg120_c
# pg120_p
# pg140_c
# pg140_p
# pg141_c
# pg141_p
# pg160_c
# pg160_p
# pg161_c
# pg161_p
# pg180_c
# pg180_p
# pg181_c
# pg181_p
# pgp120_c
# pgp120_p
# pgp140_c
# pgp140_p
# pgp141_c
# pgp141_p
# pgp160_c
# pgp160_p
# pgp161_c
# pgp161_p
# pgp180_c
# pgp180_p
# pgp181_c
# pgp181_p
# phaccoa_c
# phe__D_c
# phe__L_c
# phe__L_e
# phehpa_e
# phehpa_p
# phehxa_e
# phehxa_p
# pheme_c
# pheme_e
# pheme_p
# pheocta_e
# pheocta_p
# phept_e
# phept_p
# phitcoa_c
# phom_c
# php2coa_c
# phpcoa_c
# phpyr_c
# phthdl_c
# phthiocerol_c
# phthr_c
# phxa2coa_c
# phxacoa_c
# pi_c
# pi_e
# pi_p
# pime_c
# pime_e
# pmcoa_c
# pmtcoa_c
# pnona2coa_c
# pnto__R_c
# pnto__R_e
# pnto__R_p
# poaac_c
# pocta2coa_c
# poctacoa_c
# ppa_c
# ppa_e
# ppa_p
# ppad_c
# ppal_c
# ppap_c
# ppat_c
# ppat_e
# ppbng_c
# ppcoa_c
# ppgpp_c
# pphn_c
# ppi_c
# ppp9_c
# pppg9_c
# pppgpp_c
# pppi_c
# ppt2coa_c
# pptcoa_c
# pram_c
# pran_c
# prbamp_c
# prbatp_c
# prealgac_M4_p
# prealginate__M_p
# prephthACP_c
# prephth_c
# prephthcoa_c
# prfp_c
# prlp_c
# pro__D_c
# pro__L_c
# pro__L_e
# pro__L_p
# progly_c
# progly_e
# progly_p
# prohisglu_c
# prohisglu_e
# prpncoa_c
# prpp_c
# ps120_c
# ps141_c
# ps160_c
# ps180_c
# ps181_c
# psd5p_c
# pser__L_c
# pt2coa_c
# pta_c
# pta_e
# pta_p
# ptal_c
# ptcoa_c
# ptcys_c
# ptd1ino160_c
# ptrc_c
# ptrc_e
# ptrc_p
# ptsla2coa_c
# ptsla_e
# ptsla_p
# ptslacoa_c
# ptth_c
# pvdiq_p
# pyam5p_c
# pydam_c
# pydx5p_c
# pydx_c
# pydxn_c
# pydxn_e
# pyovd_kt_e
# pyovd_kt_p
# pyr_c
# pyr_e
# pyr_p
# q8_c
# q8h2_c
# quin_c
# quin_p
# quln_c
# r1p_c
# r5p_c
# raffin_c
# raffin_e
# rbflvrd_c
# rbl__D_c
# rephaccoa_c
# rhcys_c
# rib__D_c
# rib__D_e
# rib__D_p
# ribflv_c
# ribflv_e
# rml1p_c
# rml_c
# rmn_c
# rmn_e
# rnam_c
# ru5p__D_c
# ru5p__L_c
# s17bp_c
# s7p_c
# s_c
# s_e
# salc_c
# salc_e
# salchs4_c
# salchs4_e
# salchs4_p
# salchs4fe_c
# salchs4fe_e
# salchs4fe_p
# sarcs_c
# sbt6p_c
# sbt__D_c
# sbt__D_e
# sbzcoa_c
# scl_c
# scys__L_c
# sdhlam_c
# sel_c
# sel_e
# sel_p
# ser__D_c
# ser__D_e
# ser__D_p
# ser__L_c
# ser__L_e
# ser__L_p
# seramp_c
# serglugly_c
# serglugly_e
# sheme_c
# skm5p_c
# skm_c
# skm_e
# skm_p
# sl26da_c
# sl2a6o_c
# slnt_c
# slnt_e
# slnt_p
# so3_c
# so3_e
# so3_p
# so4_c
# so4_e
# so4_p
# spmd_c
# spmd_e
# spmd_p
# stcoa_c
# stfrnA_c
# stfrnA_e
# stfrnB_c
# stfrnB_e
# strcoa_c
# suc6p_c
# sucbz_c
# succ_c
# succ_e
# succ_p
# succoa_c
# suchms_c
# sucr_c
# sucr_e
# sucr_p
# sucsal_c
# sula_c
# sula_e
# sulfac_c
# sulfac_e
# sulfac_p
# tag160_e
# tag180_e
# tag181d9_e
# tag182d9d12_e
# tag6p__D_c
# tagdp__D_c
# tamocta_c
# tartr__D_c
# tartr__D_e
# tartr__L_c
# tartr__L_e
# taur_c
# taur_e
# tcynt_c
# tcynt_e
# tcynt_p
# td2coa_c
# td58_2_coa_c
# td_5_8_coa_c
# tdcoa_c
# tde2coa_c
# tdeACP_c
# tde_2Z_coa_c
# tdecoa_c
# tded5_2_coa_c
# tded5coa_c
# tet_e
# tet_p
# thdp_c
# thf_c
# thm_c
# thm_e
# thmmp_c
# thmpp_c
# thr__L_c
# thr__L_e
# thr__L_p
# thrp_c
# thym_c
# thym_e
# thym_p
# thymd_c
# tmhexc_c
# tnt_c
# tnt_e
# tnt_p
# tntmdh_c
# tntmmh_c
# tol_c
# tol_e
# tol_p
# trans_dd2coa_c
# trdox_c
# trdrd_c
# tre6p_c
# tre_c
# tre_e
# tre_p
# trnaglu_c
# trp__L_c
# trp__L_e
# trypta_c
# tsul_c
# tsul_e
# tsul_p
# ttdca_c
# ttdca_p
# ttdcea_c
# ttdcea_p
# ttdceap_c
# tton_e
# ttrcyc_c
# ttrcyc_e
# ttrcyc_p
# tyr__L_c
# tyr__L_e
# uaGgla_c
# uaaGgla_c
# uaagmda_c
# uaccg_c
# uacgam_c
# uacmam_c
# uagmda_c
# uama_c
# uamag_c
# uamr_c
# udcpdp_c
# udcpp_c
# udp_c
# udpg_c
# udpgal_c
# ugmd_c
# ugmda_c
# um4p_c
# ump_c
# uppg3_c
# ura_c
# ura_e
# ura_p
# uracp_c
# urate_c
# urcan_c
# urdglyc_c
# urea_c
# urea_p
# uri_c
# utp_c
# vacc2coa_c
# vacc_c
# vacc_p
# vacccoa_c
# vaccoa_c
# val__D_c
# val__D_e
# val__D_p
# val__L_c
# val__L_e
# val__L_p
# vanln_c
# vanln_e
# vanln_p
# vanlt_c
# vanlt_e
# vanlt_p
# xan_c
# xan_e
# xan_p
# xmp_c
# xtp_c
# xtsn_c
# xtsn_e
# xu5p__D_c
# xu5p__L_c
# xyl3_c
# xyl3_e
# xyl4_c
# xyl__D_c
# xyl__D_e
# xyl__D_p
# xylan4_c
# xylan4_e
# xylb_c
# xylb_e
# xylu__D_c
# zn2_c
# zn2_e
# zn2_p
# phenol_e
# phenol_c
# guaiacol_e
# guaiacol_c
# tag_c
# ficytc6_p
# focytc6_p
# pq_p
# pqh2_p
#      metanetx_molecular_weight  formula_molecular_weight                name  \
# 1955                                             0.00000        Plastoquinol
# 1953                                             0.00000  Ferrocytochrome c6
# 1952                                             0.00000  Ferricytochrome c6
# 1954                                             0.00000       Plastoquinone
# 1131                   1.00794                   1.00794                  H+
#
#      formula metabolite_id metanetx_id kegg_id
# 1955                pqh2_p
# 1953             focytc6_p
# 1952             ficytc6_p
# 1954                  pq_p
# 1131       H           h_c       MNXM1  C00080

# %% [markdown]
# Save metabolite data from the model as a csv

# %%
metabolite_df.to_csv('../data/metabolomics/model_metabolites.csv', index=False, header=True)

# %% [markdown]
# ### 4. Check for matches between model metabolites and LCMS data

# %%
# define a helper function to get the model metabilte data from a given molecular weight
def molecular_weight_to_metabolite_data(molecular_weight):

    # keep track of the closest mass distance between the given 
    # molecular weight and model metabolite's molecular weight
    minimum_mass_difference = 1000
    
    # define an arbitrary closest metabolite
    closest_molecular_weight_data = metabolite_df[0]
    
    # loop over metabolite data
    for _, row in metabolite_df.iterrows():
        
        # check if this metabolite is the closest in mass to the given molecular weight
        if abs(row.formula_molecular_weight - molecular_weight) < minimum_mass_difference:
            # if so, the update the data for the the closest metabolite and the min mass distance
            closest_molecular_weight_data = row
            minimum_mass_difference = abs(row.formula_molecular_weight - molecular_weight)

    # return the data from the metabolite with the closest molecular weight
    return closest_molecular_weight_data

# a testing function
# molecular_weight_to_metabolite_data(148.06024)

# %%
lcms_df[['m/z', 'RT [min]', 'Name', 'Tags', 'Foston_Ex_1-2 (F6)']].head(5)
# Out:
#          m/z  RT [min]                       Name  \
# 0  113.03449     3.109                     Uracil
# 1  148.06024     5.053         O-Acetyl-DL-serine
# 2  162.07599     4.449   N-Methyl-L-Glutamic acid
# 3  124.03935     3.352      Nicotinic acid/Niacin
# 4  190.07092     4.881  N-Acetyl-DL-glutamic acid
#
#                              Tags  Foston_Ex_1-2 (F6)
# 0  Confirmed ID (HIgh Confidence)        2.430179e+04
# 1  Confirmed ID (HIgh Confidence)        8.257832e+04
# 2  Confirmed ID (HIgh Confidence)        1.386673e+04
# 3  Confirmed ID (HIgh Confidence)        1.735242e+06
# 4  Confirmed ID (HIgh Confidence)        9.956026e+03

# %%
# loop over metabolites that have LCMS measurements
for _, row in lcms_df.iterrows():
    molecular_weight = row['m/z']
    print(row.Name, molecular_weight_to_metabolite_data(molecular_weight))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/genome_scale_model_paper/OpacusBiodesignGR/venv/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/genome_scale_model_paper/OpacusBiodesignGR/venv/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/genome_scale_model_paper/OpacusBiodesignGR/venv/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/rt/6n0vbsp923xg2bbmtt_k12900000gn/T/ipykernel_30884/1858243329.py in <module>
#       2 for _, row in lcms_df.iterrows():
#       3     molecular_weight = row['m/z']
# ----> 4     print(row.Name, molecular_weight_to_metabolite_data(molecular_weight))
#
# /var/folders/rt/6n0vbsp923xg2bbmtt_k12900000gn/T/ipykernel_30884/3813119778.py in molecular_weight_to_metabolite_data(molecular_weight)
#       7
#       8     # define an arbitrary closest metabolite
# ----> 9     closest_molecular_weight_data = metabolite_df[0]
#      10
#      11     # loop over metabolite data
#
# ~/genome_scale_model_paper/OpacusBiodesignGR/venv/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/genome_scale_model_paper/OpacusBiodesignGR/venv/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 0
