# %% [markdown]
# ## **Notebook to make predictions with reprocessed Henson data and SPOT**
#
# By Christina Schenk and Garrett Roell
#
# Tested on biodesign_3.7 kernel on jprime

# %% [markdown]
# ### SPOT predictions and evaluations
# This notebook predicts fluxes for R. opacus cultures growing with phenol. The data was published in [Henson (2018)](https://www.sciencedirect.com/science/article/pii/S1096717618300910).
#
# #### **Data Labels:**
#
# #### Henson:
# * WT 0.5g/L Phenol 		(**WT-P**)
# * PVHG6 0.5g/L  Phenol 	(**PVHG-P**)
#
# ### Method:
# <ul>
#     <li>WT</li>
#     <ol>
#     <li>Predict fluxes with SPOT</li>
#     <li>Compare predictions with 13CMFA: Scatter plots and flux maps</li>
#    </ol>
#     <li>PVHG</li>
#     <ol>
#     <li>Predict fluxes with SPOT</li>
#     <li>Compare predictions with 13CMFA: Scatter plots and flux maps</li>
#    </ol>
# </ul>
#
# 3. Load file with observed growth rates (Notebook E)
#
# 4. Compare growth rate predictions with growth rate observations

# %% [markdown]
# ##### **Import python packages**

# %%
import os
import sys
import pandas as pd
import numpy as np
import cobra
import scipy.stats
#import cplex
# %matplotlib inline

import matplotlib
from matplotlib import pyplot as plt
from matplotlib.offsetbox import (TextArea, DrawingArea, OffsetImage,
                                  AnnotationBbox)
from matplotlib.cbook import get_sample_data
import matplotlib.image as mpimg
import matplotlib.cm as cm

from edd_utils import login, export_study, export_metadata

from sklearn.metrics import r2_score

# %% [markdown]
# ##### **Load data**

# %%
# # Study to Download
# study_slug = 'biodesign_henson2018_reprocessed'
# # EDD server
# edd_server = 'public-edd.jbei.org'
# user       = 'schenkch'

# %%
# session = login(edd_server=edd_server, user=user)

# df = export_study(session, study_slug, edd_server=edd_server)
# #df.head()

# %%
# define blank dictionary and fill with transcript measurements from different conditions and carbon sources
transcript_measurements = {}
# add glucose conditions to data set object
# transcript_measurements['glucose_cpm'] = pd.read_csv('../winston_data/october_19_2021/yoneda/yoneda_reprocess_CPM_melted.csv')
# transcript_measurements['glucose_fpkm'] = pd.read_csv('../winston_data/october_19_2021/yoneda/yoneda_reprocess_FPKM_melted.csv')
# transcript_measurements['glucose_mr'] = pd.read_csv('../winston_data/october_19_2021/yoneda/yoneda_reprocess_MR_melted.csv')
# transcript_measurements['glucose_tmm'] = pd.read_csv('../winston_data/october_19_2021/yoneda/yoneda_reprocess_TMM_melted.csv')
# add phenol conditions to data set object
transcript_measurements['phenol_cpm'] = pd.read_csv('../winston_data/october_19_2021/henson/henson_reprocess_CPM_melted.csv')
transcript_measurements['phenol_fpkm'] = pd.read_csv('../winston_data/october_19_2021/henson/henson_reprocess_FPKM_melted.csv')
transcript_measurements['phenol_mr'] = pd.read_csv('../winston_data/october_19_2021/henson/henson_reprocess_MR_melted.csv')
transcript_measurements['phenol_tmm'] = pd.read_csv('../winston_data/october_19_2021/henson/henson_reprocess_TMM_melted.csv')

# %% [markdown]
# ##### **Filter transcriptomics data from all EDD data into different dataframes**

# %%
# df_Trans = df[df['Protocol'].str.contains('Transcriptomics')]
# df_Trans.head()

# %%
df_Trans = transcript_measurements['phenol_cpm'] #fpkm

# %% [markdown]
# ##### **Load Genome Scale Model**

# %%
file_name =  '../GSMs/Ropacus_annotated_curated.xml'
model = cobra.io.read_sbml_model(file_name)

# %% [markdown]
# ##### **Import SPOT and other utility functions code**

# %%
SourceDir = '../src'
sys.path.append(SourceDir)
from ensemblemethods import SPOT
from utils import *

# %% [markdown]
# ### Wild Type

# %% [markdown]
# #### **1. SPOT Predictions for Wild type**

# %%
spotsol, spotsol_std = spot_pred_for_three_reps(model, df_Trans, 'WT-P-R1', 'WT-P-R2','WT-P-R3', 'phenol')
# Out:
# {'EX_h2o_e': inf,
#  'EX_h_e': inf,
#  'EX_cl_e': inf,
#  'EX_pi_e': inf,
#  'EX_nh4_e': inf,
#  'EX_fe3_e': inf,
#  'EX_k_e': inf,
#  'EX_ca2_e': inf,
#  'EX_mg2_e': inf,
#  'EX_mn2_e': inf,
#  'EX_cobalt2_e': inf,
#  'EX_zn2_e': inf,
#  'EX_cu2_e': inf,
#  'EX_o2_e': inf,
#  'EX_fe2_e': inf,
#  'EX_mobd_e': inf,
#  'EX_so4_e': inf,
#  'EX_phenol_e': inf}
# {'EX_h2o_e': inf,
#  'EX_h_e': inf,
#  'EX_cl_e': inf,
#  'EX_pi_e': inf,
#  'EX_nh4_e': inf,
#  'EX_fe3_e': inf,
#  'EX_k_e': inf,
#  'EX_ca2_e': inf,
#  'EX_mg2_e': inf,
#  'EX_mn2_e': inf,
#  'EX_cobalt2_e': inf,
#  'EX_zn2_e': inf,
#  'EX_cu2_e': inf,
#  'EX_o2_e': inf,
#  'EX_fe2_e': inf,
#  'EX_mobd_e': inf,
#  'EX_so4_e': inf,
#  'EX_phenol_e': inf}
# {'EX_h2o_e': inf,
#  'EX_h_e': inf,
#  'EX_cl_e': inf,
#  'EX_pi_e': inf,
#  'EX_nh4_e': inf,
#  'EX_fe3_e': inf,
#  'EX_k_e': inf,
#  'EX_ca2_e': inf,
#  'EX_mg2_e': inf,
#  'EX_mn2_e': inf,
#  'EX_cobalt2_e': inf,
#  'EX_zn2_e': inf,
#  'EX_cu2_e': inf,
#  'EX_o2_e': inf,
#  'EX_fe2_e': inf,
#  'EX_mobd_e': inf,
#  'EX_so4_e': inf,
#  'EX_phenol_e': inf}

# %% [markdown]
# ##### **Save solution to data frame**

# %%
spotsoldf = pd.DataFrame(spotsol, columns=['fluxes'])
spotsolstddf = pd.DataFrame(spotsol_std, columns=['stds'])

# %%
spotsol.loc['Growth_Glucose']
# Out:
# fluxes    0.0
# Name: Growth_Glucose, dtype: float64

# %%
spotsol.loc['Growth_Phenol']
# Out:
# fluxes   -1.029960e-11
# Name: Growth_Phenol, dtype: float64

# %%
spotsol.loc['EX_tag']
# Out:
# fluxes    0.0
# Name: EX_tag, dtype: float64

# %% [markdown]
# #### **2. Plot solutions: Comparison of SPOT WT predictions and 13c measurements**

# %% [markdown]
# ##### **Load 13cdata**

# %% [markdown]
# #####  **Get 13C MFA measured fluxes for phenol**

# %%
phenol_fluxes = pd.read_csv('../13C_flux_data/13C_phenol_flux_data.csv')

# Remove rows that do not have a mapping to the GSM
phenol_fluxes.dropna(subset = ["Forward Reactions"], inplace=True)
print(f'There are {len(phenol_fluxes)} fluxes that can be compared between the MFA and FBA')
# Out:
# There are 43 fluxes that can be compared between the MFA and FBA

# %%
obspred_fluxes = add_pred_fluxes_to_13c_df(phenol_fluxes, spotsoldf, spotsolstddf, 'phenol', 'SPOT', 'WT')

# %%
obspred_fluxes
# Out:
#                       Pathway  \
# 0               Phenol Uptake
# 1                 EMP Pathway
# 2                 EMP Pathway
# 3                 EMP Pathway
# 4                 EMP Pathway
# 5                 EMP Pathway
# 6                 EMP Pathway
# 7                 EMP Pathway
# 8                 EMP Pathway
# 9                 EMP Pathway
# 10  Pentose Phosphate Pathway
# 11  Pentose Phosphate Pathway
# 12  Pentose Phosphate Pathway
# 13  Pentose Phosphate Pathway
# 14  Pentose Phosphate Pathway
# 15  Pentose Phosphate Pathway
# 16  Pentose Phosphate Pathway
# 17  Pentose Phosphate Pathway
# 18  Pentose Phosphate Pathway
# 19                 ED Pathway
# 20                 ED Pathway
# 21                  TCA Cycle
# 22                  TCA Cycle
# 23                  TCA Cycle
# 24                  TCA Cycle
# 25                  TCA Cycle
# 26                  TCA Cycle
# 27                  TCA Cycle
# 28                  TCA Cycle
# 29                  TCA Cycle
# 30           Glyoxylate Shunt
# 31           Glyoxylate Shunt
# 32      Anaplerotic Reactions
# 33      Anaplerotic Reactions
# 34      Anaplerotic Reactions
# 35      Anaplerotic Reactions
# 64         Transhydrogenation
# 65                  Transport
# 66                  Transport
# 68                  Transport
# 69                  Transport
# 70                  Transport
# 71           Biomass Equation
#
#                                     Forward Reactions  \
# 0                                              PHEMOX
# 1                                                 PGI
# 2                                  PFK or reverse_FBP
# 3                                                 FBA
# 4                                                 TPI
# 5                                                GAPD
# 6                                         reverse_PGK
# 7                                PGM_1 or reverse_PGM
# 8                                                 ENO
# 9   PPS or reverse_FRUpts2pp or reverse_SBTpts or ...
# 10                                    G6PDH2r and PGL
# 11                                                GND
# 12                                                RPE
# 13                                        reverse_RPI
# 14                                               TKT2
# 15                                               TKT2
# 16                                               TKT1
# 17                                               TALA
# 18                                       reverse_TALA
# 19                                                EDA
# 20                                                EDD
# 21                                                PDH
# 22                                 CS or reverse_CITL
# 23                      ACONT or ( ACONTa and ACONTb)
# 24                                    ICDHx or ICDHyr
# 25                                     AKGDH or OOR3r
# 26  3OADPCOAT or OCOAT3r or SUCBZT1 or SUCBZT2 or ...
# 27  SUCDi or reverse_FRD2 or reverse_FRD3 or rever...
# 28                                                FUM
# 29                     MDH or MDH3 or MDH2 or DMALRED
# 30                                                ICL
# 31                                               MALS
# 32                                   PEPCK_re or PPCK
# 33                                                PPC
# 34                                                 PC
# 35                                         ME1 or ME2
# 64            FRNDPR2r or FLNDPR2r or reverse_NADTRHD
# 65                                               ATPM
# 66                                       reverse_CO2t
# 68                                                O2t
# 69                                               NH4t
# 70                                              SO4t2
# 71          Growth or Growth_Phenol or Growth_Glucose
#
#                                              Reaction Location on map  \
# 0                        Phenol.ext -> AcCoA + SucCoA     ( 80, -450)
# 1                                         G6P <-> F6P     (-150, 430)
# 2                                    F6P + ATP -> FBP     (-220, 195)
# 3                                  FBP <-> DHAP + GAP     (-140, 115)
# 4                                        DHAP <-> GAP     (-270, 150)
# 5                                       GAP <-> G1,3P      (-220, 30)
# 6                          G1,3P <-> 3PG + ATP + NADH     (-220, -55)
# 7                                         3PG <-> 2PG    (-220, -135)
# 8                                         2PG <-> PEP    (-220, -215)
# 9                                   PEP <-> Pyr + ATP    (-220, -295)
# 10                                G6P <-> 6PG + NADPH       (50, 380)
# 11                         6PG <-> Ru5P + CO2 + NADPH      (275, 350)
# 12                                       Ru5P <-> X5P      (380, 190)
# 13                                       Ru5P <-> R5P      (270, 230)
# 14                                 X5P <-> TKC2 + GAP      (270, 100)
# 15                                 TKC2 + E4P <-> F6P       (10, 280)
# 16                                 TKC2 + R5P <-> S7P      (120, 230)
# 17                                 TAC3 + GAP <-> F6P      (-70, 190)
# 18                                 S7P <-> TAC3 + E4P       (50, 230)
# 19                                       6PG <-> KDPG     (-300, 350)
# 20                                 KDPG <-> Pyr + GAP      (-300, 50)
# 21                         Pyr <-> AcCoA + CO2 + NADH    (-220, -370)
# 22                                 OAC + AcCoA -> Cit     (-55, -340)
# 23                                        Cit -> ICit     (145, -310)
# 24                          ICit -> AKG + CO2 + NADPH     (290, -310)
# 25                         AKG -> SucCoA + CO2 + NADH     (290, -195)
# 26                                SucCoA -> Suc + ATP      (290, -55)
# 27                                 Suc -> Fum + FADH2      (160, -55)
# 28                                         Fum -> Mal       (10, -55)
# 29                                  Mal -> OAC + NADH     (-60, -180)
# 30                                ICit -> Glyox + Suc     (180, -140)
# 31                               Glyox + AcCoA -> Mal      (90, -140)
# 32                             OAC + ATP -> PEP + CO2             NaN
# 33                                   PEP + CO2 -> OAC             NaN
# 34                             Pyr + CO2 + ATP -> OAC             NaN
# 35                           Mal <-> Pyr + CO2 + NADH             NaN
# 64                                     NADH <-> NADPH             NaN
# 65                                     ATP -> ATP.ext             NaN
# 66                                     CO2 -> CO2.ext             NaN
# 68                                       O2.ext -> O2             NaN
# 69                                     NH3.ext -> NH3             NaN
# 70                                     SO4.ext -> SO4             NaN
# 71  0.515*Ala + 0.174*Arg + 0.153*Asn + 0.439*Asp ...             NaN
#
#             Flux  90% Confidence Lower Bound  90% Confidence Upper Bound  \
# 0   1.000000e+02                1.000000e+02                    100.0000
# 1  -4.793000e-01               -1.421900e+00                      0.9306
# 2  -2.000000e+00               -2.000000e+00                     -0.7683
# 3  -2.000000e+00               -2.000000e+00                     -0.7683
# 4  -2.000000e+00               -2.000000e+00                     -0.7683
# 5  -1.079070e+01               -1.122350e+01                     -9.1040
# 6  -1.079070e+01               -1.122350e+01                     -9.1040
# 7  -1.625380e+01               -1.695560e+01                    -13.6034
# 8  -1.625380e+01               -1.695560e+01                    -13.6034
# 9   2.999990e+01                0.000000e+00                     30.0000
# 10 -5.767000e-01               -2.018100e+00                      0.3824
# 11  4.646000e-01               -1.659900e+00                      1.8755
# 12 -1.187400e+00               -2.611500e+00                     -0.2468
# 13  1.652100e+00                9.081000e-01                      2.1385
# 14 -1.187400e+00               -2.611500e+00                     -0.2468
# 15 -1.187400e+00               -1.909000e+00                     -0.7099
# 16  2.130000e-14               -7.076000e-01                      0.4698
# 17  7.110000e-15               -7.076000e-01                      0.4698
# 18  8.530000e-14               -7.076000e-01                      0.4698
# 19 -1.041300e+00               -2.524300e+00                      0.2447
# 20 -1.041300e+00               -2.524300e+00                      0.2447
# 21  5.923270e+01                5.668260e+01                     62.0459
# 22  1.144391e+02                1.102766e+02                    118.4800
# 23  1.144391e+02                1.102766e+02                    118.4800
# 24  1.134677e+02                1.068011e+02                    118.4800
# 25  1.086053e+02                1.017297e+02                    113.8305
# 26  2.074789e+02                2.005620e+02                    212.7536
# 27  2.085767e+02                2.032666e+02                    212.8305
# 28  2.096703e+02                2.043514e+02                    213.8762
# 29  1.710231e+02                1.292999e+02                    174.5648
# 30  9.714000e-01                7.110000e-15                      4.5567
# 31  9.714000e-01                0.000000e+00                      4.5567
# 32  9.777180e+01                1.292690e+01                    100.0000
# 33  4.890390e+01                0.000000e+00                     59.1635
# 34  1.000000e-07                0.000000e+00                     44.8577
# 35  3.961870e+01                3.704340e+01                    100.0000
# 64  1.443160e+01                1.108700e+00                     27.2447
# 65  6.800864e+02                6.131475e+02                    787.5166
# 66  3.764570e+02                3.650427e+02                    386.6854
# 68  4.336956e+02                4.207564e+02                    445.9396
# 69  2.575270e+01                2.412740e+01                     27.0206
# 70  4.177000e-01                3.913000e-01                      0.4383
# 71  4.693400e+00                4.397200e+00                      4.9245
#
#     SPOT WT Value  SPOT WT std Value
# 0    1.000000e+02       4.719086e+01
# 1    1.261114e-07       8.920305e-09
# 2    2.043340e-07       1.067032e-07
# 3    2.060180e-07       1.067394e-07
# 4    4.074753e-07       6.084788e-08
# 5    8.009690e-07       1.364018e-07
# 6    8.009690e-07       1.364018e-07
# 7    2.416302e+00       4.185156e+00
# 8    4.170991e+00       7.224367e+00
# 9   -5.505393e+01       2.516876e+01
# 10  -3.374678e-08       1.514296e-08
# 11   1.711759e-08       1.630899e-08
# 12   8.714301e-08       3.816033e-08
# 13  -6.363249e-08       2.090471e-08
# 14   6.167714e-08       2.150891e-08
# 15   6.167714e-08       2.150891e-08
# 16   4.755248e-08       1.646315e-08
# 17   5.712806e-08       1.840482e-08
# 18  -5.712806e-08       1.840482e-08
# 19   5.205010e-09       2.458945e-09
# 20  -5.361630e-09       3.006302e-09
# 21   1.929934e-08       3.730288e-08
# 22   7.297166e+01       1.743434e+01
# 23   7.297166e+01       1.796451e+01
# 24  -1.171101e-07       3.000023e+00
# 25  -1.939405e-08       8.253236e-09
# 26   9.657645e+01       5.067291e+01
# 27   8.162112e+01       2.338470e+01
# 28   7.863416e+01       2.022268e+01
# 29   9.184937e+01       9.627282e+00
# 30   7.297166e+01       1.743434e+01
# 31   1.321521e+01       1.568023e+01
# 32   5.088293e+01       2.375822e+01
# 33   5.340002e-09       1.503992e-08
# 34   3.200522e+01       1.706675e+01
# 35   1.628711e-08       1.873547e-08
# 64   2.242456e+00       3.239727e+00
# 65  -9.628374e-09       2.632831e-09
# 66   1.490257e+02       3.852138e+01
# 68   2.731832e+02       8.454659e+01
# 69   3.003714e+00       2.713803e+00
# 70   4.114812e-08       2.502611e-08
# 71  -1.394346e-08       3.514784e-09

# %% [markdown]
# ### Plot SPOT vs 13C MFA

# %% [markdown]
# ##### **Set plot output directory and import plot functions**

# %%
output_dir = 'Plots/CPM/'
from plot import *

# %% [markdown]
# ##### **Plot 13CMFA vs. SPOT predictions**

# %%
scatterplotcomp_obs_vs_pred(obspred_fluxes, substrate='phenol', method='SPOT', strain='WT', output_dir=output_dir)

# %% [markdown]
# ##### **Plot 13CMFA vs. SPOT predictions with standard deviations**

# %%
scatterplotcomp_obs_vs_pred_withstd(obspred_fluxes, substrate='phenol', method='SPOT', strain='WT', output_dir=output_dir)

# %% [markdown]
# #### **Map phenol SPOT fluxes**

# %%
map_flux_results(obspred_fluxes, 'SPOT WT Value', output_dir=output_dir)

# %% [markdown]
# ### **PVHG**

# %% [markdown]
# #### **1. SPOT Predictions for PVHG**

# %%
spotsol_PVHG, spotsol_std_PVHG = spot_pred_for_three_reps(model, df_Trans, 'PVHG-P-R1', 'PVHG-P-R2','PVHG-P-R3', 'phenol')
# Out:
# {'EX_h2o_e': inf,
#  'EX_h_e': inf,
#  'EX_cl_e': inf,
#  'EX_pi_e': inf,
#  'EX_nh4_e': inf,
#  'EX_fe3_e': inf,
#  'EX_k_e': inf,
#  'EX_ca2_e': inf,
#  'EX_mg2_e': inf,
#  'EX_mn2_e': inf,
#  'EX_cobalt2_e': inf,
#  'EX_zn2_e': inf,
#  'EX_cu2_e': inf,
#  'EX_o2_e': inf,
#  'EX_fe2_e': inf,
#  'EX_mobd_e': inf,
#  'EX_so4_e': inf,
#  'EX_phenol_e': inf}
# {'EX_h2o_e': inf,
#  'EX_h_e': inf,
#  'EX_cl_e': inf,
#  'EX_pi_e': inf,
#  'EX_nh4_e': inf,
#  'EX_fe3_e': inf,
#  'EX_k_e': inf,
#  'EX_ca2_e': inf,
#  'EX_mg2_e': inf,
#  'EX_mn2_e': inf,
#  'EX_cobalt2_e': inf,
#  'EX_zn2_e': inf,
#  'EX_cu2_e': inf,
#  'EX_o2_e': inf,
#  'EX_fe2_e': inf,
#  'EX_mobd_e': inf,
#  'EX_so4_e': inf,
#  'EX_phenol_e': inf}
# {'EX_h2o_e': inf,
#  'EX_h_e': inf,
#  'EX_cl_e': inf,
#  'EX_pi_e': inf,
#  'EX_nh4_e': inf,
#  'EX_fe3_e': inf,
#  'EX_k_e': inf,
#  'EX_ca2_e': inf,
#  'EX_mg2_e': inf,
#  'EX_mn2_e': inf,
#  'EX_cobalt2_e': inf,
#  'EX_zn2_e': inf,
#  'EX_cu2_e': inf,
#  'EX_o2_e': inf,
#  'EX_fe2_e': inf,
#  'EX_mobd_e': inf,
#  'EX_so4_e': inf,
#  'EX_phenol_e': inf}

# %% [markdown]
# ##### **Save solution to data frame**

# %%
spotsoldf_PVHG = pd.DataFrame(spotsol_PVHG, columns=['fluxes'])
spotsolstddf_PVHG = pd.DataFrame(spotsol_std_PVHG, columns=['stds'])

# %% [markdown]
# ##### **Add Phenol PVHG SPOT flux values to phenol fluxes dataframe**

# %%
obspred_fluxes = add_pred_fluxes_to_13c_df(obspred_fluxes, spotsoldf_PVHG, spotsolstddf_PVHG, 'phenol', 'SPOT', 'PVHG')

# %%
obspred_fluxes.to_csv('../13C_flux_data/obspredfluxes_Phenol_SPOT_CPM.csv', index=True, header= True)

# %% [markdown]
# #### **2. Plot solutions: Comparison of SPOT PVHG predictions and 13c measurements**

# %% [markdown]
# ##### **Plot 13CMFA vs. SPOT predictions**

# %%
scatterplotcomp_obs_vs_pred(obspred_fluxes, substrate='phenol', method='SPOT', strain='PVHG', output_dir=output_dir)

# %% [markdown]
# ##### **Plot 13CMFA vs. SPOT predictions with standard deviations**

# %%
scatterplotcomp_obs_vs_pred_withstd(obspred_fluxes, substrate='phenol', method='SPOT', strain='PVHG', output_dir=output_dir)

# %% [markdown]
# ##### **Map phenol SPOT fluxes**

# %%
map_flux_results(obspred_fluxes, 'SPOT PVHG Value', output_dir=output_dir)

# %% [markdown]
# ### **3. Load File with observed growth rates**

# %% [markdown]
# ##### **Load observed growth rates and plot phenol growth rates**

# %%
consumption_and_growth_data = pd.read_csv('../consumption_and_growth_data/consumption_and_growth_data_new.csv', index_col=0)
consumption_and_growth_data
# Out:
#          growth rate  yield coefficient  substrate consumption rate  \
# WT-P        0.065488           0.048868                    1.352072
# PVHG-P      0.080331           0.040848                    1.967485
# WT-LN-G     0.260195           0.072789                    3.582471
#
#          growth rate std dev  yield coefficient std dev  \
# WT-P                0.001345                   0.004836
# PVHG-P              0.002672                   0.001757
# WT-LN-G             0.004749                   0.004117
#
#          substrate consumption rate std dev
# WT-P                               0.122279
# PVHG-P                             0.021785
# WT-LN-G                            0.141675

# %% [markdown]
# ##### **For comparison of predicted and observed growth rates: scale predicted growth rate by multiplying with (observed substrate uptake / predicted substrate uptake)**

# %%
scaledgrowthratespot_wtp = scale_growth_to_sub(spotsoldf.loc['Growth_Phenol',:].values[0], spotsoldf.loc['EX_glc__D_e',:].values[0],consumption_and_growth_data.loc['WT-P', 'substrate consumption rate'])
scaledgrowthratespot_pvhgp = scale_growth_to_sub(spotsoldf_PVHG.loc['Growth_Phenol',:].values[0], spotsoldf_PVHG.loc['EX_glc__D_e',:].values[0],consumption_and_growth_data.loc['PVHG-P',  'substrate consumption rate'])

# %% [markdown]
# ##### **Load Glucose growth rates to compare in same plot**

# %%
allgrowthratesglucose = pd.read_csv('../consumption_and_growth_data/allgrowthratesGlucoseSPOT_CPM.csv', index_col=0)
allgrowthratesglucose
# Out:
#          Growth_Glucose_SPOT
# WT-LN-G        -9.452000e-12

# %% [markdown]
# ##### **Create data frame for all growth rates and save new predictions and previously computed glucose predictions in same data frame**

# %%
allgrowthrates=pd.DataFrame(index=['WT-P', 'PVHG-P', 'WT-LN-G'], columns=['Growth_SPOT'], dtype=float)

# %%
allgrowthrates.at['WT-P','Growth_SPOT'] = scaledgrowthratespot_wtp
allgrowthrates.at['PVHG-P','Growth_SPOT'] = scaledgrowthratespot_pvhgp

# %%
allgrowthrates.at['WT-LN-G','Growth_SPOT'] = allgrowthratesglucose.loc['WT-LN-G','Growth_Glucose_SPOT']
allgrowthrates
# Out:
#           Growth_SPOT
# WT-P    -1.029960e-11
# PVHG-P  -9.076779e-12
# WT-LN-G -9.452000e-12

# %% [markdown]
# ### **4. Compare growth rate predictions with growth rate observations**

# %%
allindices=[str(row) for row in allgrowthrates.index]
scatter_plot_compare(consumption_and_growth_data.loc[allindices, 'growth rate'], allgrowthrates.loc[allindices,'Growth_SPOT'], allindices, 'SPOT', output_dir=output_dir)

# %% [markdown]
# ##### **Save growth rates as csv file**

# %%
allgrowthrates.to_csv('../consumption_and_growth_data/allgrowthratesSPOT_CPM.csv', index=True, header= True)
